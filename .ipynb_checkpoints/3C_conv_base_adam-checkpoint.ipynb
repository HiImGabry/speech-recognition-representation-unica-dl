# %% [markdown]
# # Modello convolutivo di base - Dataset rumore
# In precedenza abbiamo visto l'addestramento del nostro modello convolutivo di base sul dataset originale, e dopodiché abbiamo parlato della data augmentation.
#
# AGGIORNARE

# %% [markdown]
# Come al solito, implementiamo le librerie funzioni necessarie. Inoltre otteniamo il nuovo dataset attraverso le tecniche viste nel notebook relativo alla data augmentation.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd
import numpy as np
import scipy.fftpack as scipy
import random
import os
import time
# per il modello con estensione .onnx
import onnxruntime as rt
import tf2onnx
import onnx

# %% [markdown]
# ## Classe per la conversione del dataset
# Questa classe l'abbiamo già vista implementata nel notebook riguardante l'addestramento dei filterbanks e degli mfcc.

# %%
class DatasetConverter:
    def __init__(self, dataset):
        self.dataset = dataset

    def convert(self, option):
        available_options = ['spettrogrammi', 'filterbanks', 'mfcc']
        
        if option == available_options[0]:
            return self.get_spectrogram_dataset()
        elif option == available_options[1]:
            return self.get_filterbanks_dataset()
        elif option == available_options[2]:
            return self.get_mfcc_dataset()
        else:
            raise ValueError(f"Opzione non disponibile: inserire una delle seguenti opzioni: {available_options}")
    
    # INIZIO SPETTROGRAMMI
    def squeeze(self, audio, labels):
        audio = tf.squeeze(audio, axis=-1)
        return audio, labels
    
    def get_spectrogram(self, waveform):
    # applichiamo la short-time Fourier transorm
        spectrogram = tf.signal.stft(waveform, frame_length=255, frame_step=128)
        spectrogram = tf.abs(spectrogram)
        
        return spectrogram[..., tf.newaxis]
    
    def get_spectrogram_dataset(self):
        # squeeze
        self.dataset = self.dataset.map(self.squeeze, tf.data.AUTOTUNE)
        self.dataset = self.dataset.map(lambda x, y: (self.get_spectrogram(x), y), num_parallel_calls=tf.data.AUTOTUNE)
        
        return self.dataset

    # FINE SPETTROGRAMMI

    def convert_to_numpy(self, dataset):
        audio_data = []
        labels = []
    
        dataset = dataset.unbatch()
        
        for audio, label in dataset:
            audio_data.append(audio.numpy())  # Assuming audio is a tensor, convert to numpy array
            labels.append(label.numpy())      # Assuming label is a tensor, convert to numpy array
        
        audio_data = np.array(audio_data)
        labels = np.array(labels)
        
        return audio_data, labels
    
    # INIZIO FILTERBANKS
    def makeHamming(self, M):
        R = (( M - 1 ) / 2 , M / 2)[M % 2 == 0]
        w = (np.hamming(M), np.hamming(M + 1))[M % 2 == 0]
        if M % 2 != 0:
            w[0] = w[0]/2
            w[M-1] = w[M-1]/2
        else:
            w = w[:M]
    
        return w

    def hztomel(self, hz):
        return (2595 * np.log10(1 + hz / 700))

    def meltohz(self, mel):
        return (700 * (10**(mel / 2595) - 1))

    def compute_filterbanks(self, audios_np, pre_emphasis=0.97, sample_rate=16000, frame_size=0.025, frame_stride=0.01, NFFT=512, nfilt=40):
        filterbanks_np = []
        
        for samples in audios_np:
            emphasized_audio = np.append(samples[0], samples[1:] - pre_emphasis * samples[:-1])
            audio_length = len(emphasized_audio)
    
            frame_length, frame_step = int(frame_size * sample_rate), int(frame_stride * sample_rate)
    
            num_frames = int(np.ceil(float(np.abs(audio_length - frame_length)) / frame_step))
    
            pad_audio_length = num_frames * frame_step + frame_length
            z = np.zeros((pad_audio_length - audio_length))
            pad_audio = np.append(emphasized_audio, z)
    
            indices = np.tile(np.arange(0, frame_length), (num_frames, 1)) + np.tile(np.arange(0, num_frames * frame_step, frame_step), (frame_length, 1)).T
            frames = pad_audio[indices.astype(np.int32, copy=False)]
    
            # Usiamo la funzione di Hamming
            hamming_window = self.makeHamming(frame_length)
    
            mag_frames = np.absolute(np.fft.rfft(frames, NFFT))  # Magnitudo della FFT
            pow_frames = ((1.0 / NFFT) * ((mag_frames) ** 2))
    
            # convertiamo hz in mel
            low_freq_mel = self.hztomel(0)
            high_freq_mel = self.hztomel(sample_rate / 2)
    
            mel_points = np.linspace(low_freq_mel, high_freq_mel, nfilt + 2)
            hz_points = self.meltohz(mel_points) 
    
            bin = np.floor((NFFT + 1) * hz_points / sample_rate)
    
            fbank = np.zeros((nfilt, int(np.floor(NFFT / 2 + 1))))
    
            for m in range(1, nfilt + 1):
                f_m_minus = int(bin[m - 1])
                f_m = int(bin[m])
                f_m_plus = int(bin[m + 1])
    
                for k in range(f_m_minus, f_m):
                    fbank[m - 1, k] = (k - bin[m - 1]) / (bin[m] - bin[m - 1])
                for k in range(f_m, f_m_plus):
                    fbank[m - 1, k] = (bin[m + 1] - k) / (bin[m + 1] - bin[m])
    
            # in questo momento invece calcoliamo i filter banks per i segmenti di audio, utilizzando i filtri triangolari appena creati
            filter_banks = np.dot(pow_frames, fbank.T)
            filter_banks = np.where(filter_banks == 0, np.finfo(float).eps, filter_banks)
            filter_banks = 20 * np.log10(filter_banks)
    
            filterbanks_np.append(filter_banks)
        
        return np.array(filterbanks_np)
    
    def get_filterbanks_dataset(self): 
        audios, labels = self.convert_to_numpy(self.dataset)

        filterbanks = self.compute_filterbanks(audios)
        filterbanks = np.expand_dims(filterbanks, axis=-1)

        self.dataset = tf.data.Dataset.from_tensor_slices((filterbanks, labels))
        self.dataset = self.dataset.batch(32)
        
        return self.dataset
    # FINE FILTERBANKS

    # INIZIO MFCC
    def compute_mfcc(self, filter_banks, num_ceps=12, cep_lifter=22):
        mfcc_np = []
        
        for f in filter_banks:
            mfcc = scipy.dct(f, type=2, axis=1, norm='ortho')[:, 1 : (num_ceps + 1)]

            (nframes, ncoeff) = mfcc.shape
            n = np.arange(ncoeff)
            
            lift = 1 + (cep_lifter / 2) * np.sin(np.pi * n / cep_lifter)
            mfcc *= lift

            mfcc_np.append(mfcc)
        
        return np.array(mfcc_np)
    
    
    def get_mfcc_dataset(self):
        audios, labels = self.convert_to_numpy(self.dataset)

        filterbanks = self.compute_filterbanks(audios)
        mfcc = self.compute_mfcc(filterbanks)
        
        mfcc = np.expand_dims(mfcc, axis=-1)
        
        self.dataset = tf.data.Dataset.from_tensor_slices((mfcc, labels))
        self.dataset = self.dataset.batch(32)
        
        return self.dataset
    
    # FINE MFCC

# %% [markdown]
# ## Importazione funzioni ulteriori
# In aggiunta alla classe per la conversione del dataset, ci serviremo delle seguenti funzioni:
# - `convert_history_to_csv` - salva l'history dell'addestramento in un csv
# - `convert_model_to_onnx` - converte il miglior modello **.keras** in **.onnx**
# - `create_train_val_plot` - visualizza l'andamento dell'accuratezza e della perdita durante l'addestramento
# - `evaluate_onnx_model` - valuta il modello sui dati di test con il modello **.onnx**
# - `create_distribution_plot` - visualizza la distribuzione di accuratezza delle classi su un'immagine casuale
#
# Anch'esse sono già state viste, perciò non ci soffermeremo troppo su di esse.

# %%
def convert_history_to_csv(model_history):
    # converto la history del dataframe in un dataframe pandas
    model_history_df = pd.DataFrame(model_history.history)
    # cambio il nome dell'indice e lo imposto a partire da 1
    model_history_df.index = range(1, len(model_history_df) + 1)
    model_history_df.index.name = "epochs"

    return model_history_df

def convert_model_to_onnx(model_path, input_shape):
    model = tf.keras.models.load_model(model_path)

    onnx_path = model_path.split(".")[:-1] + ["onnx"]
    onnx_path = ".".join(onnx_path)
    
    input_signature = [tf.TensorSpec((None, *input_shape), tf.float32, name="input")]
    onnx_model, _ = tf2onnx.convert.from_keras(model, input_signature=input_signature)

    onnx.save(onnx_model, onnx_path)

def create_train_val_plot(history, overfit=True):
    # definisco numero epoche
    epochs = range(1, len(history['accuracy']) + 1)

    # Accuracy
    accuracy = history['accuracy']
    val_accuracy = history['val_accuracy']

    fig_acc, ax_acc = plt.subplots()

    # linea di base
    ax_acc.plot(epochs, [0.5 for x in range(len(epochs))], color="lightgray", linestyle="--", label="Base")
    # linee di accuratezza
    ax_acc.plot(epochs, accuracy, color="slategray", label="Accuratezza in addestramento")
    ax_acc.plot(epochs, val_accuracy, color="indianred", label="Accuratezza in validazione")
    # miglior accuratezza validazione
    ax_acc.axhline(y=max(val_accuracy), c='indianred', alpha=0.7, linestyle='--')
    ax_acc.text(len(epochs) * 1.07, max(val_accuracy), round(max(val_accuracy), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_acc.spines["right"].set_visible(False)
    ax_acc.spines["top"].set_visible(False)
    ax_acc.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_acc.set_title("Accuratezza in addestramento e validazione")
    ax_acc.set_xlabel("Epoche")
    ax_acc.set_ylabel("Accuratezza (%)")
    ax_acc.legend()

    # Loss
    loss = history['loss']
    val_loss = history['val_loss']

    fig_loss, ax_loss = plt.subplots()

    # linee di loss
    ax_loss.plot(epochs, loss, color="slategray", label="Perdita in addestramento")
    ax_loss.plot(epochs, val_loss, color="indianred", label="Perdita in validazione")
    # miglior loss validazione
    ax_loss.axhline(y=min(val_loss), c='indianred', alpha=0.7, linestyle='--')
    ax_loss.text(len(epochs) * 1.07, min(val_loss), round(min(val_loss), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_loss.spines["right"].set_visible(False)
    ax_loss.spines["top"].set_visible(False)
    ax_loss.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_loss.set_title("Perdita in addestramento e validazione")
    ax_loss.set_xlabel("Epoche")
    ax_loss.set_ylabel("Perdita")

    handles, _ = ax_loss.get_legend_handles_labels()

    if overfit:
        # area overfit
        rect = mpatches.Rectangle((np.argmin(val_loss) + 1, 0), width=100 - np.argmin(val_loss), height=max(max(loss), max(val_loss)), color='lightcoral', alpha=0.3)
        ax_loss.add_patch(rect)
        # patch overfit per legenda
        overfit = mpatches.Patch(color='indianred', alpha=0.3, label='Area overfit')
        handles, _ = ax_loss.get_legend_handles_labels()
        handles.append(overfit)

    # legenda
    ax_loss.legend(handles=handles)

    plt.show()

def evaluate_onnx_model(path_model_onnx, test_ds):
    # il fatto che sia suddiviso in batch mi crea problemi, perciò lo risolvo togliendoli
    test_ds = test_ds.unbatch()
    
    # carico il modello utilizzando il file onnx
    m = rt.InferenceSession(path_model_onnx)
    
    # trasformo il dataset in array numpy
    spectrogram_np = np.array([spectrogram.numpy() for spectrogram, _ in test_ds], dtype=np.float32)
    labels_np = np.array([label.numpy() for _, label in test_ds])
    
    # eseguo le predizione del modello
    pred_onnx = m.run(None, {'input': spectrogram_np})
    # ottengo la predizione corretta
    predictions = np.argmax(pred_onnx[0], axis=1)
    # computo la accuratezza
    accuracy = np.mean(predictions == labels_np)
    # stampo l'accuratezza
    print(f"Accuratezza: {accuracy:.3f}")

def create_distribution_plot(model, audio, label):
    label_names = audio_label_names
    
    prediction = model(audio) # otteniamo la predizione del modello sull'audio preso in input

    random_audio_index = np.random.randint(0, len(prediction) - 1) # abbiamo notato che mostravamo sempre la classe no, magari così cambia un po' le classi che mostriamo

    softmax_pred = tf.nn.softmax(prediction[random_audio_index]) # dobbiamo applicare nuovamente la softmax in modo tale da avere dei dati leggibili
    pred_label = np.argmax(softmax_pred) # ci salviamo l'indice della label predetta dal nostro modello, quella con la probabilità più alta

    colors = ['indianred'] * len(label_names) # creiamo un vettore di lunghezza 30 (la quantità delle nostre label) colorate di rosso

    if pred_label == label[random_audio_index].numpy(): # se la label che abbiamo predetto è corretta, allora la coloriamo di verde
        colors[pred_label] = 'seagreen'
    else: # se la label che abbiamo predetto è sbagliata, allora coloriamo di verde la corretta e di gialla la predetta
        colors[pred_label] = 'khaki'
        colors[label[random_audio_index].numpy()] = 'seagreen'

    plt.figure(figsize=(12, 4))
    
    plt.bar(label_names, softmax_pred.numpy(), color=colors)
    plt.xticks(rotation=45)

    # dichiariamo i colori della legenda
    other_values_patch = mpatches.Patch(color='indianred', label='Altre classi')
    pred_value_patch = mpatches.Patch(color='khaki', label='Classe predetta')
    correct_value_patch = mpatches.Patch(color='green', label='Classe corretta')

    # disegniamo la legenda con i colori necessari
    if pred_label == label[random_audio_index].numpy(): # se abbiamo predetto correttamente la label, non è necessario mostrare il colore giallo (non è presente nel plot)
        plt.legend(handles=[other_values_patch, correct_value_patch])
    else:
        plt.legend(handles=[other_values_patch, pred_value_patch, correct_value_patch])

    plt.show()

# %%
train_ds, validation_ds = tf.keras.utils.audio_dataset_from_directory(
    directory ='../reduced_dataset/dataset/audio',
    validation_split=0.4, # stiamo mettendo da parte il 40% del dataset, che sarà suddiviso in validation set e test set
    shuffle=True,
    subset='both', # necessario se stiamo utilizzando validation_split
    seed=0 # necessario se stiamo utilizzando sia shuffle che validation_split 
)
audio_label_names = train_ds.class_names

noise_ds = tf.keras.utils.audio_dataset_from_directory(
    directory='../noise_dataset',
    batch_size = 1
)

noise_label_names = noise_ds.class_names
# Out:
# Found 12933 files belonging to 30 classes.
# Using 7760 files for training.
# Using 5173 files for validation.
# Found 14 files belonging to 14 classes.

# %% [markdown]
# ## Applicazione tecniche data augmentation
# Abbiamo già visto l'utilizzo delle tecniche che andremo a applicare in questo momento, perciò non ci soffermeremo sulla loro spiegazione ma descriveremo i passaggi molto sinteticamnete.

# %% [markdown]
# Tagliamo gli audio del dataset rumoroso.

# %%
def cut_audios(dataset, length):
    new_audios = [] # inizializziamo una lista dove inseriremo i nostri audio tagliati
    labels = []
    
    # iteriamo nel dataset
    for audio, label in dataset:
        # tagliamo l'audio ad un secondo e lo appendiamo a una lista 
        labels.append(label.numpy())
        
        audio = tf.reshape(audio, [-1])[np.shape(audio)[1]//2:np.shape(audio)[1]//2 + length]
        new_audios.append(audio.numpy()) # convertiamo in array per poterli modificare
        
    return new_audios, labels

cut_noise_audios, cut_noise_labels = cut_audios(noise_ds, 16000)

# %% [markdown]
# Creiamo il nuovo dataset, unendo l'originale con quello rumoroso. L'output che otteneremo è una lista.

# %%
def mix_audios(original_audios, noise_audios):
    mixed_dataset = [] # inizializziamo la lista dove inseriremo gli audio uniti al rumore

    original_audios = original_audios.unbatch() # il nostro training set ha una batch_size di 32, per rendere il processo più semplice unbatchiamo
    
    # per ogni audio del dataset originale
    for audio, label in original_audios:    
        audio = np.squeeze(audio, axis=-1) # rimuoviamo l'ultima asse inutile (quella dei canali)
        
        # Scegliamo in modo randomico un audio dalla lista degli audio rumorosi
        noise_sample = random.choice(noise_audios)

        # calcolo l'ampiezza massima dell'audio rumoroso
        max_amplitude_audio = np.max(np.abs(audio))
        max_amplitude_noise = np.max(np.abs(noise_sample))
        # calcolo un noise factor che varia a seconda dell'ampiezza massima di entrambi gli audio
        noise_factor = max_amplitude_audio / max_amplitude_noise
        noise_factor = min(noise_factor, 1.0)
        
        noise_sample = noise_sample * noise_factor
        
        mixed_audio = audio + noise_sample # uniamo l'audio original al rumore

        # aggiungiamo l'audio con noise alla lista
        mixed_dataset.append((mixed_audio, label))

    return mixed_dataset

mixed_train_list = mix_audios(train_ds, cut_noise_audios)
mixed_val_list = mix_audios(validation_ds, cut_noise_audios)

# %% [markdown]
# Convertiamo la lista in un dataset di tensori.

# %%
def create_mixed_ds(dataset_list):
    audio_data = [tf.convert_to_tensor(audio, dtype=tf.float32) for audio, label in dataset_list]
    labels = [label for _, label in dataset_list]

    audio_data = tf.expand_dims(audio_data, axis=-1)
    
    mixed_train_ds = tf.data.Dataset.from_tensor_slices((audio_data, labels))
    mixed_train_ds = mixed_train_ds.batch(32)
    return mixed_train_ds

mixed_train_ds = create_mixed_ds(mixed_train_list)
mixed_validation_ds = create_mixed_ds(mixed_val_list)

# %% [markdown]
# ## Suddivisione dataset
# Ottenuto il dataset rumoroso possiamo procedere a convertirlo e suddividerlo.

# %%
spect_mixed_train_ds = DatasetConverter(mixed_train_ds)
spect_mixed_train_ds = spect_mixed_train_ds.convert("spettrogrammi")

spect_mixed_validation_ds = DatasetConverter(mixed_validation_ds)
spect_mixed_validation_ds = spect_mixed_validation_ds.convert("spettrogrammi")

spect_mixed_val_ds = spect_mixed_validation_ds.take(spect_mixed_validation_ds.cardinality() // 2) # ho cambiato nome del validation_ds in modo tale da non creare problemi con l'istruzione seguente
spect_mixed_test_ds = spect_mixed_validation_ds.skip(spect_mixed_validation_ds.cardinality() // 2)

# %% [markdown]
# Adesso siamo pronti per addestrare i modelli su un dataset rumoroso.

# %% [markdown]
# ## Addestramento (spettrogrammi)
# Come già detto, le reti neurali convolutive che andremo a trattare sono le stesse presenti nel notebook del modello convolutivo base. Stiamo addestrando gli stessi modelli in modo da poter confrontare le loro prestazioni in un notebook a parte.
#
# Iniziamo con il primo modello base.

# %%
def get_basic_model(input_shape):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=input_shape, name="inputs")
    x = tf.keras.layers.Normalization(name="normalizzazione")(inputs)

    # Blocco di apprendimento delle caratteristiche
    conv2D_1 = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same", name="conv2D_1")(x)
    MaxPooling2D_1 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_1")(conv2D_1)
    conv2D_2 = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same", name="conv2D_2")(MaxPooling2D_1)
    MaxPooling2D_2 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_2")(conv2D_2)
    conv2D_3 = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same", name="conv2D_3")(MaxPooling2D_2)
    MaxPooling2D_3 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_3")(conv2D_3)
    conv2D_4 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_4")(MaxPooling2D_3)
    MaxPooling2D_4 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_4")(conv2D_4)
    conv2D_5 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_5")(MaxPooling2D_4)

    # Blocco di classificazione
    Flatten = tf.keras.layers.Flatten(name="Flatten")(conv2D_5)
    outputs = tf.keras.layers.Dense(30, activation="softmax", name="dense_output")(Flatten)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
for audio, label in spect_mixed_train_ds:
    basic_model = get_basic_model(audio.shape[1:])
    break

basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/noise/adam/spectrogram/basic_model.keras", save_best_only=True, monitor="val_loss")]
basic_model_history = basic_model.fit(spect_mixed_train_ds, epochs=30, validation_data=spect_mixed_val_ds, callbacks=basic_model_callbacks)
# Out:
# Epoch 1/30
# 243/243 [==============================] - 9s 12ms/step - loss: 2.9413 - accuracy: 0.1601 - val_loss: 2.3631 - val_accuracy: 0.3063
# Epoch 2/30
# 243/243 [==============================] - 3s 11ms/step - loss: 1.9101 - accuracy: 0.4534 - val_loss: 1.7153 - val_accuracy: 0.5301
# Epoch 3/30
# 243/243 [==============================] - 3s 10ms/step - loss: 1.2017 - accuracy: 0.6463 - val_loss: 1.4357 - val_accuracy: 0.6119
# Epoch 4/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.8464 - accuracy: 0.7428 - val_loss: 1.2787 - val_accuracy: 0.6539
# Epoch 5/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.6295 - accuracy: 0.8079 - val_loss: 1.3167 - val_accuracy: 0.6644
# Epoch 6/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.4930 - accuracy: 0.8517 - val_loss: 1.4923 - val_accuracy: 0.6933
# Epoch 7/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.3954 - accuracy: 0.8831 - val_loss: 1.5257 - val_accuracy: 0.6968
# Epoch 8/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2988 - accuracy: 0.9072 - val_loss: 1.5444 - val_accuracy: 0.6983
# Epoch 9/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2659 - accuracy: 0.9202 - val_loss: 1.4560 - val_accuracy: 0.7045
# Epoch 10/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2452 - accuracy: 0.9271 - val_loss: 1.6123 - val_accuracy: 0.7095
# Epoch 11/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1874 - accuracy: 0.9461 - val_loss: 1.9512 - val_accuracy: 0.6956
# Epoch 12/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1886 - accuracy: 0.9472 - val_loss: 1.5825 - val_accuracy: 0.7118
# Epoch 13/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1789 - accuracy: 0.9503 - val_loss: 1.7567 - val_accuracy: 0.6964
# Epoch 14/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1528 - accuracy: 0.9559 - val_loss: 1.7420 - val_accuracy: 0.7334
# Epoch 15/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1273 - accuracy: 0.9643 - val_loss: 1.6886 - val_accuracy: 0.6998
# Epoch 16/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1078 - accuracy: 0.9691 - val_loss: 2.1665 - val_accuracy: 0.7099
# Epoch 17/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1111 - accuracy: 0.9682 - val_loss: 2.0158 - val_accuracy: 0.7218
# Epoch 18/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0812 - accuracy: 0.9763 - val_loss: 2.0088 - val_accuracy: 0.7076
# Epoch 19/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1036 - accuracy: 0.9704 - val_loss: 2.0073 - val_accuracy: 0.6944
# Epoch 20/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1326 - accuracy: 0.9665 - val_loss: 2.0319 - val_accuracy: 0.6960
# Epoch 21/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1009 - accuracy: 0.9709 - val_loss: 2.2666 - val_accuracy: 0.6867
# Epoch 22/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0896 - accuracy: 0.9753 - val_loss: 2.6714 - val_accuracy: 0.7060
# Epoch 23/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0973 - accuracy: 0.9749 - val_loss: 1.9991 - val_accuracy: 0.6968
# Epoch 24/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1072 - accuracy: 0.9698 - val_loss: 1.8838 - val_accuracy: 0.6956
# Epoch 25/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0964 - accuracy: 0.9733 - val_loss: 2.0446 - val_accuracy: 0.7137
# Epoch 26/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1003 - accuracy: 0.9711 - val_loss: 2.4464 - val_accuracy: 0.6894
# Epoch 27/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1010 - accuracy: 0.9726 - val_loss: 2.1137 - val_accuracy: 0.7191
# Epoch 28/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0459 - accuracy: 0.9862 - val_loss: 2.8982 - val_accuracy: 0.7130
# Epoch 29/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0686 - accuracy: 0.9818 - val_loss: 2.4358 - val_accuracy: 0.7114
# Epoch 30/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0610 - accuracy: 0.9817 - val_loss: 2.3975 - val_accuracy: 0.7261

# %% [markdown]
# Salviamo i dati della history del modello in un file csv

# %%
basic_model_history_df = convert_history_to_csv(basic_model_history)
basic_model_history_df.to_csv("model_histories/noise/adam/spectrogram/basic_model_history.csv")

# %% [markdown]
# Salviamo il miglior modello come file csv nella seguente directory `model_histories/noise/adam/` con il nome `basic_model_history`. Inoltre, per prevenire errori di salvataggio causati da versioni differenti di python o dei pacchetti, procediamo con la conversione del file in formato standard `.onnx`.

# %%
convert_model_to_onnx("bestmodels/noise/adam/spectrogram/basic_model.keras", (124, 129, 1))

# %% [markdown]
# Utilizziamo la funzione `create_train_val_plot` per mostrare l'andamento dell'accurateza e della perdita durante l'addestramento.

# %%
create_train_val_plot(basic_model_history.history)

# %% [markdown]
# Questi grafici mostrano come il nostro modello sia andato immediatamente in overfitting. L'accuratezza dell'addestramento aumenta col tempo e raggiunge quasi il **100%**, mentre l'accuratezza della validazione si attesta sull'**75%**. La **perdita nel set di addestramento** continua a diminuire dopo la **quinta epoca**, mentre la **perdita nel set di validazione** aumenta.
#
# Non siamo riusciti a raggiungere una buona accuratezza nella validazione.

# %% [markdown]
# Possiamo verificare l'accuratezza della migliore versione del nostro modello di base ricaricando il file **basic_model.keras**

# %%
best_basic_model = tf.keras.models.load_model("bestmodels/noise/adam/spectrogram/basic_model.keras")
test_loss, test_acc = best_basic_model.evaluate(spect_mixed_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 5ms/step - loss: 1.3056 - accuracy: 0.6486
# Accuratezza: 0.649

# %%
evaluate_onnx_model("bestmodels/noise/adam/spectrogram/basic_model.onnx", spect_mixed_test_ds)
# Out:
# Accuratezza: 0.649

# %% [markdown]
# Abbiamo ottenuto un'**accuratezza** del **64.9%**, possiamo già notare un peggioramento notevole. Visualizziamo la distribuzione di accuratezza delle classi su un'immagine casuale.

# %%
for audio, label in spect_mixed_test_ds: # prendiamo un audio a caso del test e creiamo la distribuzione
    create_distribution_plot(best_basic_model, audio, label)
    break

# %% [markdown]
# ### Risoluzione dell'overfitting
# Il modello è andato immediatamente in **overfitting**, e lo possiamo notare dalla loss di validazione che inizia a salire dalla quinta epoca in poi. Cercheremo di ritardarla leggermente seguendo le stesse procedure del notebook di riferimento.

# %%
def get_improved_basic_model(input_shape):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=input_shape)
    x = tf.keras.layers.Normalization()(inputs)

    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
for audio, label in spect_mixed_train_ds:
    improved_basic_model = get_improved_basic_model(audio.shape[1:])
    break

improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/noise/adam/spectrogram/improved_basic_model.keras", save_best_only=True, monitor="val_loss")]
improved_history = improved_basic_model.fit(spect_mixed_train_ds, epochs=100, validation_data=spect_mixed_val_ds, callbacks=improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 4s 13ms/step - loss: 3.0349 - accuracy: 0.1399 - val_loss: 2.5813 - val_accuracy: 0.2465
# Epoch 2/100
# 243/243 [==============================] - 3s 12ms/step - loss: 2.1651 - accuracy: 0.3742 - val_loss: 1.8218 - val_accuracy: 0.4726
# Epoch 3/100
# 243/243 [==============================] - 3s 10ms/step - loss: 1.5210 - accuracy: 0.5506 - val_loss: 1.4716 - val_accuracy: 0.5864
# Epoch 4/100
# 243/243 [==============================] - 3s 10ms/step - loss: 1.1406 - accuracy: 0.6577 - val_loss: 1.2631 - val_accuracy: 0.6331
# Epoch 5/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.8846 - accuracy: 0.7352 - val_loss: 1.1399 - val_accuracy: 0.6628
# Epoch 6/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.7289 - accuracy: 0.7747 - val_loss: 1.1778 - val_accuracy: 0.6856
# Epoch 7/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.6010 - accuracy: 0.8121 - val_loss: 1.2270 - val_accuracy: 0.7029
# Epoch 8/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.4889 - accuracy: 0.8490 - val_loss: 1.2825 - val_accuracy: 0.7064
# Epoch 9/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.4424 - accuracy: 0.8649 - val_loss: 1.3412 - val_accuracy: 0.7010
# Epoch 10/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.4151 - accuracy: 0.8729 - val_loss: 1.3985 - val_accuracy: 0.7180
# Epoch 11/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.3398 - accuracy: 0.8956 - val_loss: 1.2580 - val_accuracy: 0.7226
# Epoch 12/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.3098 - accuracy: 0.9043 - val_loss: 1.3384 - val_accuracy: 0.7106
# Epoch 13/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2582 - accuracy: 0.9189 - val_loss: 1.3063 - val_accuracy: 0.7396
# Epoch 14/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2691 - accuracy: 0.9182 - val_loss: 1.3432 - val_accuracy: 0.7442
# Epoch 15/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2565 - accuracy: 0.9222 - val_loss: 1.3867 - val_accuracy: 0.7226
# Epoch 16/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2247 - accuracy: 0.9314 - val_loss: 1.3108 - val_accuracy: 0.7446
# Epoch 17/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2182 - accuracy: 0.9326 - val_loss: 1.6197 - val_accuracy: 0.7446
# Epoch 18/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2226 - accuracy: 0.9367 - val_loss: 1.2721 - val_accuracy: 0.7546
# Epoch 19/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1828 - accuracy: 0.9457 - val_loss: 1.2604 - val_accuracy: 0.7396
# Epoch 20/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1548 - accuracy: 0.9528 - val_loss: 1.5216 - val_accuracy: 0.7207
# Epoch 21/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1830 - accuracy: 0.9465 - val_loss: 1.4084 - val_accuracy: 0.7577
# Epoch 22/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1546 - accuracy: 0.9543 - val_loss: 1.3825 - val_accuracy: 0.7589
# Epoch 23/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1429 - accuracy: 0.9561 - val_loss: 1.5276 - val_accuracy: 0.7539
# Epoch 24/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1896 - accuracy: 0.9477 - val_loss: 1.5043 - val_accuracy: 0.7720
# Epoch 25/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1559 - accuracy: 0.9513 - val_loss: 1.4965 - val_accuracy: 0.7446
# Epoch 26/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1736 - accuracy: 0.9510 - val_loss: 1.4616 - val_accuracy: 0.7650
# Epoch 27/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1294 - accuracy: 0.9644 - val_loss: 1.5491 - val_accuracy: 0.7604
# Epoch 28/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1313 - accuracy: 0.9622 - val_loss: 1.7431 - val_accuracy: 0.7654
# Epoch 29/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1624 - accuracy: 0.9572 - val_loss: 1.4930 - val_accuracy: 0.7542
# Epoch 30/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1441 - accuracy: 0.9601 - val_loss: 1.7679 - val_accuracy: 0.7542
# Epoch 31/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1214 - accuracy: 0.9664 - val_loss: 1.6495 - val_accuracy: 0.7519
# Epoch 32/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1198 - accuracy: 0.9669 - val_loss: 1.5769 - val_accuracy: 0.7481
# Epoch 33/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1309 - accuracy: 0.9629 - val_loss: 1.7961 - val_accuracy: 0.7461
# Epoch 34/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1159 - accuracy: 0.9670 - val_loss: 1.6454 - val_accuracy: 0.7677
# Epoch 35/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1209 - accuracy: 0.9665 - val_loss: 1.6950 - val_accuracy: 0.7442
# Epoch 36/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1200 - accuracy: 0.9656 - val_loss: 1.6493 - val_accuracy: 0.7519
# Epoch 37/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1232 - accuracy: 0.9653 - val_loss: 1.5466 - val_accuracy: 0.7600
# Epoch 38/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1214 - accuracy: 0.9675 - val_loss: 1.7211 - val_accuracy: 0.7515
# Epoch 39/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1086 - accuracy: 0.9693 - val_loss: 1.6574 - val_accuracy: 0.7620
# Epoch 40/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1071 - accuracy: 0.9702 - val_loss: 1.8079 - val_accuracy: 0.7604
# Epoch 41/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1353 - accuracy: 0.9647 - val_loss: 1.7749 - val_accuracy: 0.7620
# Epoch 42/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.0986 - accuracy: 0.9735 - val_loss: 1.8932 - val_accuracy: 0.7438
# Epoch 43/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1071 - accuracy: 0.9687 - val_loss: 1.9224 - val_accuracy: 0.7635
# Epoch 44/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1042 - accuracy: 0.9745 - val_loss: 1.8567 - val_accuracy: 0.7681
# Epoch 45/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1198 - accuracy: 0.9693 - val_loss: 1.7067 - val_accuracy: 0.7465
# Epoch 46/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1143 - accuracy: 0.9701 - val_loss: 1.9522 - val_accuracy: 0.7446
# Epoch 47/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1386 - accuracy: 0.9615 - val_loss: 1.5852 - val_accuracy: 0.7519
# Epoch 48/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.0908 - accuracy: 0.9773 - val_loss: 1.8228 - val_accuracy: 0.7643
# Epoch 49/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1071 - accuracy: 0.9726 - val_loss: 1.7349 - val_accuracy: 0.7581
# Epoch 50/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.0854 - accuracy: 0.9777 - val_loss: 1.7112 - val_accuracy: 0.7639
# Epoch 51/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.0913 - accuracy: 0.9754 - val_loss: 1.8745 - val_accuracy: 0.7527
# Epoch 52/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.0796 - accuracy: 0.9755 - val_loss: 1.8622 - val_accuracy: 0.7596
# Epoch 53/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.0783 - accuracy: 0.9771 - val_loss: 2.1265 - val_accuracy: 0.7616
# Epoch 54/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1420 - accuracy: 0.9666 - val_loss: 2.2287 - val_accuracy: 0.7581
# Epoch 55/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1298 - accuracy: 0.9660 - val_loss: 2.2168 - val_accuracy: 0.7442
# Epoch 56/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0915 - accuracy: 0.9742 - val_loss: 2.3572 - val_accuracy: 0.7461
# Epoch 57/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1263 - accuracy: 0.9710 - val_loss: 2.0704 - val_accuracy: 0.7292
# Epoch 58/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.0998 - accuracy: 0.9731 - val_loss: 2.1996 - val_accuracy: 0.7527
# Epoch 59/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0896 - accuracy: 0.9747 - val_loss: 2.0019 - val_accuracy: 0.7643
# Epoch 60/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0755 - accuracy: 0.9793 - val_loss: 2.1050 - val_accuracy: 0.7596
# Epoch 61/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.0784 - accuracy: 0.9776 - val_loss: 2.0460 - val_accuracy: 0.7762
# Epoch 62/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.0821 - accuracy: 0.9780 - val_loss: 2.2673 - val_accuracy: 0.7535
# Epoch 63/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.0953 - accuracy: 0.9759 - val_loss: 2.0701 - val_accuracy: 0.7446
# Epoch 64/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1204 - accuracy: 0.9692 - val_loss: 1.9954 - val_accuracy: 0.7635
# Epoch 65/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0917 - accuracy: 0.9776 - val_loss: 1.8735 - val_accuracy: 0.7620
# Epoch 66/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0946 - accuracy: 0.9749 - val_loss: 1.9938 - val_accuracy: 0.7566
# Epoch 67/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0952 - accuracy: 0.9778 - val_loss: 2.3123 - val_accuracy: 0.7550
# Epoch 68/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0918 - accuracy: 0.9750 - val_loss: 2.1808 - val_accuracy: 0.7654
# Epoch 69/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0875 - accuracy: 0.9769 - val_loss: 1.9187 - val_accuracy: 0.7758
# Epoch 70/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.0620 - accuracy: 0.9817 - val_loss: 2.5960 - val_accuracy: 0.7689
# Epoch 71/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1219 - accuracy: 0.9693 - val_loss: 2.8989 - val_accuracy: 0.7577
# Epoch 72/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1362 - accuracy: 0.9692 - val_loss: 2.5633 - val_accuracy: 0.7554
# Epoch 73/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0748 - accuracy: 0.9805 - val_loss: 2.1250 - val_accuracy: 0.7542
# Epoch 74/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0917 - accuracy: 0.9782 - val_loss: 2.0283 - val_accuracy: 0.7801
# Epoch 75/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.0824 - accuracy: 0.9796 - val_loss: 2.1004 - val_accuracy: 0.7716
# Epoch 76/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.0722 - accuracy: 0.9814 - val_loss: 2.1023 - val_accuracy: 0.7774
# Epoch 77/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.0743 - accuracy: 0.9831 - val_loss: 2.3147 - val_accuracy: 0.7728
# Epoch 78/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0878 - accuracy: 0.9789 - val_loss: 2.3431 - val_accuracy: 0.7596
# Epoch 79/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0653 - accuracy: 0.9826 - val_loss: 2.3768 - val_accuracy: 0.7654
# Epoch 80/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0919 - accuracy: 0.9773 - val_loss: 2.1647 - val_accuracy: 0.7677
# Epoch 81/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1025 - accuracy: 0.9738 - val_loss: 2.8220 - val_accuracy: 0.7523
# Epoch 82/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1205 - accuracy: 0.9740 - val_loss: 2.4347 - val_accuracy: 0.7685
# Epoch 83/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0937 - accuracy: 0.9780 - val_loss: 2.4424 - val_accuracy: 0.7589
# Epoch 84/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0907 - accuracy: 0.9799 - val_loss: 2.6056 - val_accuracy: 0.7685
# Epoch 85/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.0897 - accuracy: 0.9785 - val_loss: 2.0887 - val_accuracy: 0.7662
# Epoch 86/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.0576 - accuracy: 0.9848 - val_loss: 2.1325 - val_accuracy: 0.7685
# Epoch 87/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0481 - accuracy: 0.9866 - val_loss: 2.4864 - val_accuracy: 0.7693
# Epoch 88/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0680 - accuracy: 0.9821 - val_loss: 2.4251 - val_accuracy: 0.7604
# Epoch 89/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0989 - accuracy: 0.9790 - val_loss: 2.4271 - val_accuracy: 0.7361
# Epoch 90/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0796 - accuracy: 0.9794 - val_loss: 2.3227 - val_accuracy: 0.7631
# Epoch 91/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0795 - accuracy: 0.9816 - val_loss: 2.8386 - val_accuracy: 0.7431
# Epoch 92/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1106 - accuracy: 0.9751 - val_loss: 2.3261 - val_accuracy: 0.7558
# Epoch 93/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0840 - accuracy: 0.9791 - val_loss: 2.7711 - val_accuracy: 0.7620
# Epoch 94/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0878 - accuracy: 0.9799 - val_loss: 2.3373 - val_accuracy: 0.7728
# Epoch 95/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0980 - accuracy: 0.9787 - val_loss: 2.4352 - val_accuracy: 0.7361
# Epoch 96/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0816 - accuracy: 0.9805 - val_loss: 2.4639 - val_accuracy: 0.7724
# Epoch 97/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0732 - accuracy: 0.9838 - val_loss: 2.8702 - val_accuracy: 0.7481
# Epoch 98/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0931 - accuracy: 0.9768 - val_loss: 2.7248 - val_accuracy: 0.7631
# Epoch 99/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1276 - accuracy: 0.9751 - val_loss: 2.7325 - val_accuracy: 0.7492
# Epoch 100/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0972 - accuracy: 0.9782 - val_loss: 2.6677 - val_accuracy: 0.7697

# %% [markdown]
# Salviamo come prima la history del modello in un file csv, e convertiamo il miglior modello nel formato **.onnx**.

# %%
improved_history_df = convert_history_to_csv(improved_history)
improved_history_df.to_csv("model_histories/noise/adam/spectrogram/improved_history.csv")

convert_model_to_onnx("bestmodels/noise/adam/spectrogram/improved_basic_model.keras", (124, 129, 1))

# %% [markdown]
# Visualizziamo la curva dell'accuratezza e della perdita durante l'addestramento.

# %%
create_train_val_plot(improved_history.history)

# %% [markdown]
# Le prestazioni sono leggermente migliorate rispetto all'applicazione precedente. Verifichiamo l'accuratezza nel dataset di test.

# %%
improved_best_model = tf.keras.models.load_model("bestmodels/noise/adam/spectrogram/improved_basic_model.keras")
test_loss, test_acc = improved_best_model.evaluate(spect_mixed_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 4ms/step - loss: 1.1606 - accuracy: 0.6656
# Accuratezza: 0.666

# %%
evaluate_onnx_model("bestmodels/noise/adam/spectrogram/improved_basic_model.onnx", spect_mixed_test_ds)
# Out:
# Accuratezza: 0.666

# %% [markdown]
# Abbiamo ottenuto un notevole miglioramento dell'accuratezza, attualmente siamo a quota **70.1%**! Visualizziamo anche la solita distribuzione.

# %%
for audio, label in spect_mixed_test_ds:
    create_distribution_plot(improved_best_model, audio, label)
    break

# %% [markdown]
# ### Fine tuning
# In questa sezione andremo a effettuare il fine tuning del modello convolutivo con la stessa metodologia del notebook di riferimento.
#
# Per ora non abbiamo ottenuto delle buone prestazioni, la validazione non riesce a perciò proveremo a aumentare, bloccandosi troppo presto. Cerchiamo di capire attraverso le funzioni `tuner` e `plot_models` qual è il problema.

# %%
def get_improved_basic_model_tuning(start_filters):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(124, 129, 1))
    x = tf.keras.layers.Normalization()(inputs)

    if not isinstance(start_filters, int):
        raise Exception("start_filters must be type integer")

    filters = [start_filters * (2 ** i) for i in range(4)]
    
    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=filters[0], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[1], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[2], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[3], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[3], kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

def tuner(filters, learning_rates, max_epochs, train_dataset, validation_dataset):
    start_time = time.time()

    counter = 1
    
    if not isinstance(filters, list):
        raise Exception("parameter filters must be type list")

    if not isinstance(learning_rates, list):
        raise Exception("parameter learning_rates must be type list")

    callbacks = [tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5)]

    best_learning_rate = 0 
    best_filters = 0
    best_val_accuracy = 0

    best_model = 0
    
    for f in filters:
        for lr in learning_rates:
            print(f"\nAddestrando con filtri {[f * (2 ** i) for i in range(4)]} e tasso di apprendimento {lr}")
            
            model = get_improved_basic_model_tuning(start_filters=f)
            model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=lr), metrics=["accuracy"])
            model_history = model.fit(train_dataset, epochs=max_epochs, validation_data=validation_dataset, callbacks=callbacks)

            model_history_df = convert_history_to_csv(model_history)

            model_history_df[["filters"]] = f
            model_history_df[["learning_rate"]] = lr
            
            path = "model_tuning/noise/adam/spectrogram/model_" + str(counter) + ".csv"
            model_history_df.to_csv(path)
            
            if best_val_accuracy < model_history_df.iloc[-1]["val_accuracy"]:
                best_val_accuracy = model_history_df.iloc[-1]["val_accuracy"]
                best_filters = f
                best_learning_rate = lr
                epoch = len(model_history_df)

            del model

            counter += 1

    total_time = time.time() - start_time
    minutes, seconds = divmod(total_time, 60)
    print(f"\nTempo totale trascorso: {int(minutes)} minuti e {int(seconds)} secondi")
    # print(f"Il miglior modello ha un filtro di partenza pari a {best_filters}, un learning rate pari a {best_learning_rate} con un'accuracy pari a {best_val_accuracy:.3f}")

    return best_filters, best_learning_rate

best_filter, best_learning_rate = tuner([16, 32, 64], [1e-3, 1e-4, 1e-5], 30, spect_mixed_train_ds, spect_mixed_val_ds)
# Out:
# Addestrando con filtri [16, 32, 64, 128] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.0975 - accuracy: 0.1237 - val_loss: 2.6021 - val_accuracy: 0.2446
# Epoch 2/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.2879 - accuracy: 0.3345 - val_loss: 2.0263 - val_accuracy: 0.4545
# Epoch 3/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.6338 - accuracy: 0.5211 - val_loss: 1.5480 - val_accuracy: 0.5737
# Epoch 4/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.2719 - accuracy: 0.6236 - val_loss: 1.2862 - val_accuracy: 0.6362
# Epoch 5/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.0359 - accuracy: 0.6952 - val_loss: 1.1980 - val_accuracy: 0.6454
# Epoch 6/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.8613 - accuracy: 0.7403 - val_loss: 1.0762 - val_accuracy: 0.6979
# Epoch 7/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.7274 - accuracy: 0.7771 - val_loss: 1.1081 - val_accuracy: 0.6987
# Epoch 8/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.6366 - accuracy: 0.8028 - val_loss: 1.1320 - val_accuracy: 0.7091
# Epoch 9/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.5461 - accuracy: 0.8238 - val_loss: 1.0374 - val_accuracy: 0.7361
# Epoch 10/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.4838 - accuracy: 0.8503 - val_loss: 1.1364 - val_accuracy: 0.7099
# Epoch 11/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.4278 - accuracy: 0.8644 - val_loss: 1.0778 - val_accuracy: 0.7438
# Epoch 12/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.4024 - accuracy: 0.8759 - val_loss: 1.1177 - val_accuracy: 0.7365
# Epoch 13/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.3501 - accuracy: 0.8919 - val_loss: 1.1302 - val_accuracy: 0.7542
# Epoch 14/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.3174 - accuracy: 0.9008 - val_loss: 1.1399 - val_accuracy: 0.7431
#
# Addestrando con filtri [16, 32, 64, 128] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.3379 - accuracy: 0.0656 - val_loss: 3.1711 - val_accuracy: 0.1192
# Epoch 2/30
# 243/243 [==============================] - 2s 6ms/step - loss: 3.0522 - accuracy: 0.1468 - val_loss: 2.8872 - val_accuracy: 0.2025
# Epoch 3/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.8093 - accuracy: 0.2085 - val_loss: 2.6930 - val_accuracy: 0.2620
# Epoch 4/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.6156 - accuracy: 0.2726 - val_loss: 2.5219 - val_accuracy: 0.3194
# Epoch 5/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.4195 - accuracy: 0.3213 - val_loss: 2.3521 - val_accuracy: 0.3677
# Epoch 6/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.2421 - accuracy: 0.3664 - val_loss: 2.1950 - val_accuracy: 0.4105
# Epoch 7/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.0869 - accuracy: 0.4169 - val_loss: 2.0523 - val_accuracy: 0.4583
# Epoch 8/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.9140 - accuracy: 0.4679 - val_loss: 1.9247 - val_accuracy: 0.4981
# Epoch 9/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.7642 - accuracy: 0.5075 - val_loss: 1.8271 - val_accuracy: 0.5201
# Epoch 10/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.6290 - accuracy: 0.5427 - val_loss: 1.7100 - val_accuracy: 0.5509
# Epoch 11/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.5172 - accuracy: 0.5686 - val_loss: 1.6728 - val_accuracy: 0.5613
# Epoch 12/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.4226 - accuracy: 0.5938 - val_loss: 1.6314 - val_accuracy: 0.5671
# Epoch 13/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.3492 - accuracy: 0.6077 - val_loss: 1.5686 - val_accuracy: 0.5887
# Epoch 14/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.2661 - accuracy: 0.6410 - val_loss: 1.5030 - val_accuracy: 0.5976
# Epoch 15/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.1840 - accuracy: 0.6631 - val_loss: 1.4747 - val_accuracy: 0.6065
# Epoch 16/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.1234 - accuracy: 0.6720 - val_loss: 1.4466 - val_accuracy: 0.6154
# Epoch 17/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.0842 - accuracy: 0.6847 - val_loss: 1.4371 - val_accuracy: 0.6181
# Epoch 18/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.0142 - accuracy: 0.7021 - val_loss: 1.4072 - val_accuracy: 0.6308
# Epoch 19/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.9597 - accuracy: 0.7202 - val_loss: 1.3865 - val_accuracy: 0.6431
# Epoch 20/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.9183 - accuracy: 0.7313 - val_loss: 1.3594 - val_accuracy: 0.6547
# Epoch 21/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.8986 - accuracy: 0.7370 - val_loss: 1.3816 - val_accuracy: 0.6439
# Epoch 22/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.8491 - accuracy: 0.7537 - val_loss: 1.3880 - val_accuracy: 0.6424
# Epoch 23/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.8124 - accuracy: 0.7580 - val_loss: 1.3580 - val_accuracy: 0.6671
# Epoch 24/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.7807 - accuracy: 0.7673 - val_loss: 1.3632 - val_accuracy: 0.6578
# Epoch 25/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.7649 - accuracy: 0.7692 - val_loss: 1.3141 - val_accuracy: 0.6798
# Epoch 26/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.7009 - accuracy: 0.7884 - val_loss: 1.3267 - val_accuracy: 0.6775
# Epoch 27/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.7091 - accuracy: 0.7930 - val_loss: 1.3645 - val_accuracy: 0.6794
# Epoch 28/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.6727 - accuracy: 0.8001 - val_loss: 1.3378 - val_accuracy: 0.6752
# Epoch 29/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.6297 - accuracy: 0.8081 - val_loss: 1.3700 - val_accuracy: 0.6779
# Epoch 30/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.6178 - accuracy: 0.8133 - val_loss: 1.3429 - val_accuracy: 0.6833
#
# Addestrando con filtri [16, 32, 64, 128] e tasso di apprendimento 1e-05
# Epoch 1/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.3952 - accuracy: 0.0456 - val_loss: 3.3843 - val_accuracy: 0.0397
# Epoch 2/30
# 243/243 [==============================] - 2s 6ms/step - loss: 3.3771 - accuracy: 0.0515 - val_loss: 3.3676 - val_accuracy: 0.0637
# Epoch 3/30
# 243/243 [==============================] - 2s 6ms/step - loss: 3.3570 - accuracy: 0.0660 - val_loss: 3.3439 - val_accuracy: 0.0799
# Epoch 4/30
# 243/243 [==============================] - 2s 6ms/step - loss: 3.3282 - accuracy: 0.0780 - val_loss: 3.3084 - val_accuracy: 0.1069
# Epoch 5/30
# 243/243 [==============================] - 2s 6ms/step - loss: 3.2966 - accuracy: 0.0861 - val_loss: 3.2615 - val_accuracy: 0.1262
# Epoch 6/30
# 243/243 [==============================] - 2s 6ms/step - loss: 3.2451 - accuracy: 0.1014 - val_loss: 3.2037 - val_accuracy: 0.1451
# Epoch 7/30
# 243/243 [==============================] - 2s 6ms/step - loss: 3.2004 - accuracy: 0.1095 - val_loss: 3.1500 - val_accuracy: 0.1551
# Epoch 8/30
# 243/243 [==============================] - 2s 6ms/step - loss: 3.1511 - accuracy: 0.1238 - val_loss: 3.1019 - val_accuracy: 0.1690
# Epoch 9/30
# 243/243 [==============================] - 2s 6ms/step - loss: 3.1139 - accuracy: 0.1334 - val_loss: 3.0633 - val_accuracy: 0.1786
# Epoch 10/30
# 243/243 [==============================] - 2s 6ms/step - loss: 3.0676 - accuracy: 0.1456 - val_loss: 3.0254 - val_accuracy: 0.1875
# Epoch 11/30
# 243/243 [==============================] - 2s 6ms/step - loss: 3.0257 - accuracy: 0.1553 - val_loss: 2.9916 - val_accuracy: 0.1925
# Epoch 12/30
# 243/243 [==============================] - 2s 6ms/step - loss: 3.0058 - accuracy: 0.1604 - val_loss: 2.9642 - val_accuracy: 0.2049
# Epoch 13/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.9744 - accuracy: 0.1682 - val_loss: 2.9368 - val_accuracy: 0.2157
# Epoch 14/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.9547 - accuracy: 0.1737 - val_loss: 2.9136 - val_accuracy: 0.2176
# Epoch 15/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.9272 - accuracy: 0.1813 - val_loss: 2.8929 - val_accuracy: 0.2184
# Epoch 16/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.8910 - accuracy: 0.1972 - val_loss: 2.8680 - val_accuracy: 0.2296
# Epoch 17/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.8809 - accuracy: 0.1981 - val_loss: 2.8461 - val_accuracy: 0.2380
# Epoch 18/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.8419 - accuracy: 0.2049 - val_loss: 2.8231 - val_accuracy: 0.2404
# Epoch 19/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.8261 - accuracy: 0.2076 - val_loss: 2.8009 - val_accuracy: 0.2492
# Epoch 20/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.7995 - accuracy: 0.2133 - val_loss: 2.7794 - val_accuracy: 0.2508
# Epoch 21/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.7873 - accuracy: 0.2187 - val_loss: 2.7626 - val_accuracy: 0.2581
# Epoch 22/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.7693 - accuracy: 0.2291 - val_loss: 2.7465 - val_accuracy: 0.2658
# Epoch 23/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.7503 - accuracy: 0.2308 - val_loss: 2.7253 - val_accuracy: 0.2704
# Epoch 24/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.7189 - accuracy: 0.2358 - val_loss: 2.7064 - val_accuracy: 0.2728
# Epoch 25/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.7051 - accuracy: 0.2427 - val_loss: 2.6891 - val_accuracy: 0.2778
# Epoch 26/30
# 243/243 [==============================] - 1s 6ms/step - loss: 2.6781 - accuracy: 0.2474 - val_loss: 2.6691 - val_accuracy: 0.2812
# Epoch 27/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.6596 - accuracy: 0.2584 - val_loss: 2.6514 - val_accuracy: 0.2905
# Epoch 28/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.6355 - accuracy: 0.2579 - val_loss: 2.6344 - val_accuracy: 0.2978
# Epoch 29/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.6096 - accuracy: 0.2726 - val_loss: 2.6149 - val_accuracy: 0.3002
# Epoch 30/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.5961 - accuracy: 0.2845 - val_loss: 2.5969 - val_accuracy: 0.3079
#
# Addestrando con filtri [32, 64, 128, 256] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 3s 11ms/step - loss: 3.0484 - accuracy: 0.1309 - val_loss: 2.5402 - val_accuracy: 0.2639
# Epoch 2/30
# 243/243 [==============================] - 3s 10ms/step - loss: 2.2180 - accuracy: 0.3577 - val_loss: 1.8710 - val_accuracy: 0.4691
# Epoch 3/30
# 243/243 [==============================] - 3s 10ms/step - loss: 1.5619 - accuracy: 0.5425 - val_loss: 1.4641 - val_accuracy: 0.5945
# Epoch 4/30
# 243/243 [==============================] - 3s 10ms/step - loss: 1.1309 - accuracy: 0.6647 - val_loss: 1.1880 - val_accuracy: 0.6590
# Epoch 5/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.8946 - accuracy: 0.7341 - val_loss: 1.1333 - val_accuracy: 0.6620
# Epoch 6/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.7216 - accuracy: 0.7817 - val_loss: 1.0372 - val_accuracy: 0.7068
# Epoch 7/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.5988 - accuracy: 0.8143 - val_loss: 1.0525 - val_accuracy: 0.7195
# Epoch 8/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.4935 - accuracy: 0.8490 - val_loss: 1.0804 - val_accuracy: 0.7114
# Epoch 9/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.4393 - accuracy: 0.8625 - val_loss: 1.2085 - val_accuracy: 0.7018
# Epoch 10/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.3911 - accuracy: 0.8764 - val_loss: 1.2376 - val_accuracy: 0.7288
# Epoch 11/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.3460 - accuracy: 0.8952 - val_loss: 1.1402 - val_accuracy: 0.7369
#
# Addestrando con filtri [32, 64, 128, 256] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 3s 10ms/step - loss: 3.2608 - accuracy: 0.0881 - val_loss: 3.0226 - val_accuracy: 0.1686
# Epoch 2/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.8809 - accuracy: 0.1923 - val_loss: 2.7000 - val_accuracy: 0.2697
# Epoch 3/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.5757 - accuracy: 0.2695 - val_loss: 2.4505 - val_accuracy: 0.3167
# Epoch 4/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.2737 - accuracy: 0.3640 - val_loss: 2.1621 - val_accuracy: 0.4074
# Epoch 5/30
# 243/243 [==============================] - 2s 10ms/step - loss: 1.9716 - accuracy: 0.4470 - val_loss: 1.9578 - val_accuracy: 0.4688
# Epoch 6/30
# 243/243 [==============================] - 2s 10ms/step - loss: 1.7083 - accuracy: 0.5177 - val_loss: 1.7519 - val_accuracy: 0.5197
# Epoch 7/30
# 243/243 [==============================] - 2s 10ms/step - loss: 1.4883 - accuracy: 0.5731 - val_loss: 1.6182 - val_accuracy: 0.5625
# Epoch 8/30
# 243/243 [==============================] - 2s 10ms/step - loss: 1.3319 - accuracy: 0.6210 - val_loss: 1.5268 - val_accuracy: 0.5880
# Epoch 9/30
# 243/243 [==============================] - 2s 10ms/step - loss: 1.1842 - accuracy: 0.6584 - val_loss: 1.4874 - val_accuracy: 0.5965
# Epoch 10/30
# 243/243 [==============================] - 2s 10ms/step - loss: 1.0685 - accuracy: 0.6838 - val_loss: 1.4217 - val_accuracy: 0.6246
# Epoch 11/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.9863 - accuracy: 0.7147 - val_loss: 1.4102 - val_accuracy: 0.6339
# Epoch 12/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.8998 - accuracy: 0.7372 - val_loss: 1.3420 - val_accuracy: 0.6593
# Epoch 13/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.8313 - accuracy: 0.7562 - val_loss: 1.3707 - val_accuracy: 0.6671
# Epoch 14/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.7641 - accuracy: 0.7738 - val_loss: 1.3532 - val_accuracy: 0.6551
# Epoch 15/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.7080 - accuracy: 0.7890 - val_loss: 1.4066 - val_accuracy: 0.6578
# Epoch 16/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.6410 - accuracy: 0.8102 - val_loss: 1.3824 - val_accuracy: 0.6833
# Epoch 17/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.5966 - accuracy: 0.8237 - val_loss: 1.4523 - val_accuracy: 0.6732
#
# Addestrando con filtri [32, 64, 128, 256] e tasso di apprendimento 1e-05
# Epoch 1/30
# 243/243 [==============================] - 3s 11ms/step - loss: 3.3900 - accuracy: 0.0421 - val_loss: 3.3672 - val_accuracy: 0.0671
# Epoch 2/30
# 243/243 [==============================] - 2s 10ms/step - loss: 3.3494 - accuracy: 0.0665 - val_loss: 3.3196 - val_accuracy: 0.0972
# Epoch 3/30
# 243/243 [==============================] - 3s 10ms/step - loss: 3.2797 - accuracy: 0.0918 - val_loss: 3.2265 - val_accuracy: 0.1366
# Epoch 4/30
# 243/243 [==============================] - 3s 10ms/step - loss: 3.1788 - accuracy: 0.1222 - val_loss: 3.1122 - val_accuracy: 0.1543
# Epoch 5/30
# 243/243 [==============================] - 3s 11ms/step - loss: 3.0898 - accuracy: 0.1401 - val_loss: 3.0280 - val_accuracy: 0.1802
# Epoch 6/30
# 243/243 [==============================] - 3s 11ms/step - loss: 3.0115 - accuracy: 0.1652 - val_loss: 2.9676 - val_accuracy: 0.1933
# Epoch 7/30
# 243/243 [==============================] - 3s 11ms/step - loss: 2.9619 - accuracy: 0.1683 - val_loss: 2.9224 - val_accuracy: 0.2141
# Epoch 8/30
# 243/243 [==============================] - 3s 10ms/step - loss: 2.9127 - accuracy: 0.1896 - val_loss: 2.8819 - val_accuracy: 0.2238
# Epoch 9/30
# 243/243 [==============================] - 3s 11ms/step - loss: 2.8623 - accuracy: 0.2055 - val_loss: 2.8418 - val_accuracy: 0.2299
# Epoch 10/30
# 243/243 [==============================] - 3s 11ms/step - loss: 2.8250 - accuracy: 0.2205 - val_loss: 2.8037 - val_accuracy: 0.2465
# Epoch 11/30
# 243/243 [==============================] - 3s 11ms/step - loss: 2.7696 - accuracy: 0.2271 - val_loss: 2.7644 - val_accuracy: 0.2600
# Epoch 12/30
# 243/243 [==============================] - 3s 11ms/step - loss: 2.7306 - accuracy: 0.2410 - val_loss: 2.7338 - val_accuracy: 0.2677
# Epoch 13/30
# 243/243 [==============================] - 3s 10ms/step - loss: 2.6982 - accuracy: 0.2521 - val_loss: 2.6991 - val_accuracy: 0.2789
# Epoch 14/30
# 243/243 [==============================] - 3s 10ms/step - loss: 2.6528 - accuracy: 0.2702 - val_loss: 2.6656 - val_accuracy: 0.2863
# Epoch 15/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.6245 - accuracy: 0.2735 - val_loss: 2.6420 - val_accuracy: 0.2959
# Epoch 16/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.5810 - accuracy: 0.2887 - val_loss: 2.6135 - val_accuracy: 0.3102
# Epoch 17/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.5456 - accuracy: 0.2943 - val_loss: 2.5793 - val_accuracy: 0.3171
# Epoch 18/30
# 243/243 [==============================] - 3s 10ms/step - loss: 2.5080 - accuracy: 0.3072 - val_loss: 2.5495 - val_accuracy: 0.3198
# Epoch 19/30
# 243/243 [==============================] - 3s 10ms/step - loss: 2.4867 - accuracy: 0.3138 - val_loss: 2.5266 - val_accuracy: 0.3356
# Epoch 20/30
# 243/243 [==============================] - 3s 11ms/step - loss: 2.4491 - accuracy: 0.3280 - val_loss: 2.5000 - val_accuracy: 0.3430
# Epoch 21/30
# 243/243 [==============================] - 3s 11ms/step - loss: 2.4121 - accuracy: 0.3318 - val_loss: 2.4713 - val_accuracy: 0.3495
# Epoch 22/30
# 243/243 [==============================] - 3s 11ms/step - loss: 2.3888 - accuracy: 0.3433 - val_loss: 2.4527 - val_accuracy: 0.3519
# Epoch 23/30
# 243/243 [==============================] - 3s 10ms/step - loss: 2.3469 - accuracy: 0.3531 - val_loss: 2.4237 - val_accuracy: 0.3638
# Epoch 24/30
# 243/243 [==============================] - 3s 11ms/step - loss: 2.3107 - accuracy: 0.3599 - val_loss: 2.3997 - val_accuracy: 0.3785
# Epoch 25/30
# 243/243 [==============================] - 3s 11ms/step - loss: 2.2837 - accuracy: 0.3768 - val_loss: 2.3751 - val_accuracy: 0.3812
# Epoch 26/30
# 243/243 [==============================] - 3s 11ms/step - loss: 2.2424 - accuracy: 0.3871 - val_loss: 2.3408 - val_accuracy: 0.3916
# Epoch 27/30
# 243/243 [==============================] - 3s 11ms/step - loss: 2.2038 - accuracy: 0.3976 - val_loss: 2.3252 - val_accuracy: 0.3970
# Epoch 28/30
# 243/243 [==============================] - 3s 10ms/step - loss: 2.1859 - accuracy: 0.4034 - val_loss: 2.3024 - val_accuracy: 0.4070
# Epoch 29/30
# 243/243 [==============================] - 3s 10ms/step - loss: 2.1560 - accuracy: 0.4121 - val_loss: 2.2789 - val_accuracy: 0.4128
# Epoch 30/30
# 243/243 [==============================] - 3s 11ms/step - loss: 2.1120 - accuracy: 0.4174 - val_loss: 2.2539 - val_accuracy: 0.4240
#
# Addestrando con filtri [64, 128, 256, 512] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 7s 23ms/step - loss: 3.0324 - accuracy: 0.1405 - val_loss: 2.4094 - val_accuracy: 0.2998
# Epoch 2/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.0850 - accuracy: 0.3952 - val_loss: 1.7756 - val_accuracy: 0.5108
# Epoch 3/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.3974 - accuracy: 0.5897 - val_loss: 1.3627 - val_accuracy: 0.6150
# Epoch 4/30
# 243/243 [==============================] - 5s 21ms/step - loss: 1.0143 - accuracy: 0.6959 - val_loss: 1.1420 - val_accuracy: 0.6636
# Epoch 5/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.7829 - accuracy: 0.7631 - val_loss: 1.0616 - val_accuracy: 0.6956
# Epoch 6/30
# 243/243 [==============================] - 5s 20ms/step - loss: 0.6304 - accuracy: 0.8066 - val_loss: 1.2114 - val_accuracy: 0.6860
# Epoch 7/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.5325 - accuracy: 0.8366 - val_loss: 1.1410 - val_accuracy: 0.7296
# Epoch 8/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.4369 - accuracy: 0.8677 - val_loss: 1.1939 - val_accuracy: 0.7292
# Epoch 9/30
# 243/243 [==============================] - 5s 20ms/step - loss: 0.3686 - accuracy: 0.8838 - val_loss: 1.2896 - val_accuracy: 0.7191
# Epoch 10/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.3349 - accuracy: 0.9005 - val_loss: 1.3810 - val_accuracy: 0.7215
#
# Addestrando con filtri [64, 128, 256, 512] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 6s 21ms/step - loss: 3.2010 - accuracy: 0.1050 - val_loss: 2.8897 - val_accuracy: 0.1975
# Epoch 2/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.6904 - accuracy: 0.2477 - val_loss: 2.4667 - val_accuracy: 0.3121
# Epoch 3/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.2309 - accuracy: 0.3737 - val_loss: 2.0455 - val_accuracy: 0.4414
# Epoch 4/30
# 243/243 [==============================] - 5s 21ms/step - loss: 1.7672 - accuracy: 0.5061 - val_loss: 1.7016 - val_accuracy: 0.5405
# Epoch 5/30
# 243/243 [==============================] - 5s 21ms/step - loss: 1.4213 - accuracy: 0.6052 - val_loss: 1.5839 - val_accuracy: 0.5714
# Epoch 6/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.1923 - accuracy: 0.6622 - val_loss: 1.4225 - val_accuracy: 0.6246
# Epoch 7/30
# 243/243 [==============================] - 5s 21ms/step - loss: 1.0226 - accuracy: 0.7026 - val_loss: 1.3819 - val_accuracy: 0.6358
# Epoch 8/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.8843 - accuracy: 0.7447 - val_loss: 1.3434 - val_accuracy: 0.6694
# Epoch 9/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.7641 - accuracy: 0.7744 - val_loss: 1.3416 - val_accuracy: 0.6698
# Epoch 10/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.6581 - accuracy: 0.8053 - val_loss: 1.2714 - val_accuracy: 0.6941
# Epoch 11/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.5931 - accuracy: 0.8236 - val_loss: 1.3442 - val_accuracy: 0.6863
# Epoch 12/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.5059 - accuracy: 0.8526 - val_loss: 1.2957 - val_accuracy: 0.7072
# Epoch 13/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.4569 - accuracy: 0.8634 - val_loss: 1.3450 - val_accuracy: 0.7130
# Epoch 14/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.4407 - accuracy: 0.8711 - val_loss: 1.3506 - val_accuracy: 0.7226
# Epoch 15/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.3856 - accuracy: 0.8853 - val_loss: 1.5245 - val_accuracy: 0.7180
#
# Addestrando con filtri [64, 128, 256, 512] e tasso di apprendimento 1e-05
# Epoch 1/30
# 243/243 [==============================] - 5s 21ms/step - loss: 3.3811 - accuracy: 0.0544 - val_loss: 3.3456 - val_accuracy: 0.0999
# Epoch 2/30
# 243/243 [==============================] - 5s 21ms/step - loss: 3.2824 - accuracy: 0.0878 - val_loss: 3.1822 - val_accuracy: 0.1354
# Epoch 3/30
# 243/243 [==============================] - 5s 21ms/step - loss: 3.1197 - accuracy: 0.1332 - val_loss: 3.0265 - val_accuracy: 0.1775
# Epoch 4/30
# 243/243 [==============================] - 6s 24ms/step - loss: 2.9937 - accuracy: 0.1655 - val_loss: 2.9364 - val_accuracy: 0.2103
# Epoch 5/30
# 243/243 [==============================] - 6s 24ms/step - loss: 2.9006 - accuracy: 0.1947 - val_loss: 2.8588 - val_accuracy: 0.2226
# Epoch 6/30
# 243/243 [==============================] - 7s 30ms/step - loss: 2.8227 - accuracy: 0.2117 - val_loss: 2.7946 - val_accuracy: 0.2431
# Epoch 7/30
# 243/243 [==============================] - 7s 28ms/step - loss: 2.7381 - accuracy: 0.2374 - val_loss: 2.7251 - val_accuracy: 0.2654
# Epoch 8/30
# 243/243 [==============================] - 7s 29ms/step - loss: 2.6533 - accuracy: 0.2668 - val_loss: 2.6651 - val_accuracy: 0.2836
# Epoch 9/30
# 243/243 [==============================] - 9s 36ms/step - loss: 2.6020 - accuracy: 0.2813 - val_loss: 2.6167 - val_accuracy: 0.2921
# Epoch 10/30
# 243/243 [==============================] - 10s 41ms/step - loss: 2.5316 - accuracy: 0.2986 - val_loss: 2.5567 - val_accuracy: 0.3175
# Epoch 11/30
# 243/243 [==============================] - 11s 45ms/step - loss: 2.4472 - accuracy: 0.3246 - val_loss: 2.5026 - val_accuracy: 0.3302
# Epoch 12/30
# 243/243 [==============================] - 6s 23ms/step - loss: 2.3794 - accuracy: 0.3456 - val_loss: 2.4528 - val_accuracy: 0.3484
# Epoch 13/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.3236 - accuracy: 0.3629 - val_loss: 2.4026 - val_accuracy: 0.3642
# Epoch 14/30
# 243/243 [==============================] - 5s 22ms/step - loss: 2.2571 - accuracy: 0.3786 - val_loss: 2.3491 - val_accuracy: 0.3800
# Epoch 15/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.1930 - accuracy: 0.4079 - val_loss: 2.2962 - val_accuracy: 0.4020
# Epoch 16/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.1197 - accuracy: 0.4294 - val_loss: 2.2626 - val_accuracy: 0.4117
# Epoch 17/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.0515 - accuracy: 0.4451 - val_loss: 2.2200 - val_accuracy: 0.4213
# Epoch 18/30
# 243/243 [==============================] - 5s 21ms/step - loss: 1.9960 - accuracy: 0.4524 - val_loss: 2.1742 - val_accuracy: 0.4379
# Epoch 19/30
# 243/243 [==============================] - 5s 21ms/step - loss: 1.9532 - accuracy: 0.4621 - val_loss: 2.1461 - val_accuracy: 0.4545
# Epoch 20/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.8865 - accuracy: 0.4897 - val_loss: 2.1139 - val_accuracy: 0.4556
# Epoch 21/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.8410 - accuracy: 0.4970 - val_loss: 2.0632 - val_accuracy: 0.4819
# Epoch 22/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.7819 - accuracy: 0.5137 - val_loss: 2.0356 - val_accuracy: 0.4900
# Epoch 23/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.7278 - accuracy: 0.5327 - val_loss: 2.0052 - val_accuracy: 0.4996
# Epoch 24/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.7088 - accuracy: 0.5343 - val_loss: 1.9711 - val_accuracy: 0.5023
# Epoch 25/30
# 243/243 [==============================] - 5s 21ms/step - loss: 1.6514 - accuracy: 0.5485 - val_loss: 1.9487 - val_accuracy: 0.5143
# Epoch 26/30
# 243/243 [==============================] - 5s 21ms/step - loss: 1.6051 - accuracy: 0.5577 - val_loss: 1.9225 - val_accuracy: 0.5228
# Epoch 27/30
# 243/243 [==============================] - 5s 21ms/step - loss: 1.5669 - accuracy: 0.5755 - val_loss: 1.8909 - val_accuracy: 0.5363
# Epoch 28/30
# 243/243 [==============================] - 5s 21ms/step - loss: 1.5131 - accuracy: 0.5907 - val_loss: 1.8942 - val_accuracy: 0.5270
# Epoch 29/30
# 243/243 [==============================] - 5s 21ms/step - loss: 1.4851 - accuracy: 0.5959 - val_loss: 1.8544 - val_accuracy: 0.5471
# Epoch 30/30
# 243/243 [==============================] - 5s 21ms/step - loss: 1.4471 - accuracy: 0.6061 - val_loss: 1.8541 - val_accuracy: 0.5529
#
# Tempo totale trascorso: 9 minuti e 41 secondi

# %% [markdown]
# Il tempo necessario per la ricerca dei migliori iperparametri è stata di **9 minuti e 41
# secondi**.

# %% [markdown]
# Definiamo e utilizziamo la funzione `plot_models` per visualizzare l'accuratezza e la perdita di tutti i modelli che il tuner ha addestrato.

# %%
def plot_models(path, reverse=False, show="accuracy", overfit=True):
    n_models = len(os.listdir(path))
    # creo il subplot a seconda di quanti modelli dispongo
    best_pair = None
    min_diff = float("inf")
    
    for idx_model in range(1, int(np.sqrt(n_models)) + 1):
        if n_models % idx_model == 0:
            diff = abs(idx_model - n_models // idx_model)

            if diff < min_diff:
                min_diff = diff
                best_pair = (idx_model, n_models // idx_model)

    if reverse:
        rows = best_pair[1]
        cols = best_pair[0]
    else:
        rows = best_pair[0]
        cols = best_pair[1]
    
    fig, axes = plt.subplots(rows, cols, figsize=(14, 10))

    max_loss_value = 0
    
    for index, model in enumerate(os.listdir(path)):
        row = index // cols
        col = index % cols
    
        ax = axes[row][col]
        
        newpath = path + "/" + model
        df = pd.read_csv(newpath)

        value1 = df[show].values
        value2 = df["val_" + show].values
        
        ax.plot(range(1, len(value1) + 1), value1, color="slategray", label="Addestramento")
        ax.plot(range(1, len(value2) + 1), value2, color="indianred", label="Validazione")

        if show == "accuracy":
            ax.set_yticks(np.arange(0, 1.2, 0.2))
        elif max_loss_value < max(df[show].max(), df["val_" + show].max()):
            max_loss_value = max(df[show].max(), df["val_" + show].max())

        if (row in range(rows)) and col == 0:
            ax.set_ylabel("Accuratezza (%)" if show == "accuracy" else "Perdita", fontweight="semibold", fontsize=10)

        if (col in range(cols)) and row == 2:
            ax.set_xlabel("Epoche", fontweight="semibold", fontsize=10)

        ax.set_title("Filtro " + str(df["filters"][0]) + " & lr " + str(df["learning_rate"][0]), fontsize=12)
            
        ax.set_ylim(0)
        ax.set_xlim(0)

        ax.spines["left"].set_visible(False)
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)

        ax.grid(True, color="gainsboro", alpha=0.3, linestyle="--")

        handles, _ = ax.get_legend_handles_labels()
        
        if overfit and show == "loss":
            # area overfit
            
            rect = mpatches.Rectangle((np.argmin(value2) + 1, 0), width=len(value1) - np.argmin(value2), height=max(max(value1), max(value2)), color='lightcoral', alpha=0.3)
            ax.add_patch(rect)
            # patch overfit per legenda
            overfit = mpatches.Patch(color='lightcoral', alpha=0.3, label='Area overfit')
           
            handles.append(overfit)

        ax.legend(handles=handles)

    if show == "loss":
        for row in axes:
            for ax in row:
                ax.set_ylim(0, max_loss_value)

    plt.subplots_adjust(wspace=0.3, hspace=0.3)
    plt.show()

# %%
plot_models(path="model_tuning/noise/adam/spectrogram", show="accuracy")
plot_models(path="model_tuning/noise/adam/spectrogram", show="loss")

# %% [markdown]
# Dai grafici emerge che la combinazione più performante è composta da **XX filtri di partenza** e un **tasso di apprendimento di XX**, poiché ritarda maggiormente l'overfitting. Altre combinazioni, come **XX filtri di partenza** e un **tasso di apprendimento di 1e-5**, mostrano buone prestazioni ma anche un inizio di overfitting, evidenziato dallo distaccamento tra la perdita di addestramento e quella di validazione.
#
# Procediamo quindi con l'addestramento del modello con **XX filtri di partenza** e un **tasso di apprendimento di XX**. Come di consueto, salviamo i risultati in un file `keras` e la cronologia (history) in un file `csv`. Infine, convertiamo il file in formato `onnx`.

# %%
for audio, label in spect_mixed_train_ds:
    tuned_improved_basic_model = get_improved_basic_model(audio.shape[1:])
    
tuned_improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), metrics=["accuracy"])

# %%
tuned_improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/noise/adam/spectrogram/tuned_improved_basic_model.keras", save_best_only=True, monitor="val_loss")]
tuned_improved_history = tuned_improved_basic_model.fit(spect_mixed_train_ds, epochs=100, validation_data=spect_mixed_val_ds, callbacks=tuned_improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 8s 12ms/step - loss: 3.2701 - accuracy: 0.0825 - val_loss: 3.0265 - val_accuracy: 0.1539
# Epoch 2/100
# 243/243 [==============================] - 2s 10ms/step - loss: 2.8965 - accuracy: 0.1887 - val_loss: 2.6798 - val_accuracy: 0.2677
# Epoch 3/100
# 243/243 [==============================] - 2s 10ms/step - loss: 2.5532 - accuracy: 0.2889 - val_loss: 2.3802 - val_accuracy: 0.3414
# Epoch 4/100
# 243/243 [==============================] - 2s 10ms/step - loss: 2.2086 - accuracy: 0.3735 - val_loss: 2.1122 - val_accuracy: 0.4155
# Epoch 5/100
# 243/243 [==============================] - 2s 10ms/step - loss: 1.8905 - accuracy: 0.4653 - val_loss: 1.9014 - val_accuracy: 0.4765
# Epoch 6/100
# 243/243 [==============================] - 2s 10ms/step - loss: 1.6246 - accuracy: 0.5385 - val_loss: 1.7421 - val_accuracy: 0.5301
# Epoch 7/100
# 243/243 [==============================] - 2s 10ms/step - loss: 1.4476 - accuracy: 0.5892 - val_loss: 1.6070 - val_accuracy: 0.5617
# Epoch 8/100
# 243/243 [==============================] - 2s 10ms/step - loss: 1.2926 - accuracy: 0.6264 - val_loss: 1.4944 - val_accuracy: 0.5910
# Epoch 9/100
# 243/243 [==============================] - 2s 10ms/step - loss: 1.1454 - accuracy: 0.6700 - val_loss: 1.4055 - val_accuracy: 0.6219
# Epoch 10/100
# 243/243 [==============================] - 2s 10ms/step - loss: 1.0554 - accuracy: 0.6894 - val_loss: 1.4504 - val_accuracy: 0.6173
# Epoch 11/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.9587 - accuracy: 0.7244 - val_loss: 1.4167 - val_accuracy: 0.6188
# Epoch 12/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.8959 - accuracy: 0.7376 - val_loss: 1.3642 - val_accuracy: 0.6370
# Epoch 13/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.8086 - accuracy: 0.7660 - val_loss: 1.3640 - val_accuracy: 0.6566
# Epoch 14/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.7385 - accuracy: 0.7816 - val_loss: 1.3726 - val_accuracy: 0.6570
# Epoch 15/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.6853 - accuracy: 0.8021 - val_loss: 1.4035 - val_accuracy: 0.6636
# Epoch 16/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.6583 - accuracy: 0.8000 - val_loss: 1.3712 - val_accuracy: 0.6752
# Epoch 17/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.5962 - accuracy: 0.8240 - val_loss: 1.3463 - val_accuracy: 0.6732
# Epoch 18/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.5391 - accuracy: 0.8399 - val_loss: 1.4020 - val_accuracy: 0.6906
# Epoch 19/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.5247 - accuracy: 0.8427 - val_loss: 1.3863 - val_accuracy: 0.6813
# Epoch 20/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.5053 - accuracy: 0.8469 - val_loss: 1.4792 - val_accuracy: 0.6887
# Epoch 21/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.4479 - accuracy: 0.8634 - val_loss: 1.5171 - val_accuracy: 0.6806
# Epoch 22/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.4583 - accuracy: 0.8652 - val_loss: 1.5174 - val_accuracy: 0.6987
# Epoch 23/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.4179 - accuracy: 0.8767 - val_loss: 1.5313 - val_accuracy: 0.7037
# Epoch 24/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.3778 - accuracy: 0.8870 - val_loss: 1.5330 - val_accuracy: 0.6964
# Epoch 25/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.3653 - accuracy: 0.8905 - val_loss: 1.5449 - val_accuracy: 0.7010
# Epoch 26/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.3325 - accuracy: 0.9026 - val_loss: 1.5324 - val_accuracy: 0.7049
# Epoch 27/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.3302 - accuracy: 0.8982 - val_loss: 1.6195 - val_accuracy: 0.6998
# Epoch 28/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.3172 - accuracy: 0.9045 - val_loss: 1.6001 - val_accuracy: 0.7014
# Epoch 29/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.3116 - accuracy: 0.9066 - val_loss: 1.6055 - val_accuracy: 0.7018
# Epoch 30/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2894 - accuracy: 0.9142 - val_loss: 1.6374 - val_accuracy: 0.6975
# Epoch 31/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.3096 - accuracy: 0.9120 - val_loss: 1.4701 - val_accuracy: 0.7045
# Epoch 32/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2776 - accuracy: 0.9170 - val_loss: 1.7475 - val_accuracy: 0.6998
# Epoch 33/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2532 - accuracy: 0.9282 - val_loss: 1.6252 - val_accuracy: 0.7052
# Epoch 34/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2292 - accuracy: 0.9314 - val_loss: 1.5656 - val_accuracy: 0.7033
# Epoch 35/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2714 - accuracy: 0.9209 - val_loss: 1.7674 - val_accuracy: 0.7114
# Epoch 36/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2311 - accuracy: 0.9316 - val_loss: 1.6747 - val_accuracy: 0.7164
# Epoch 37/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2207 - accuracy: 0.9343 - val_loss: 1.6590 - val_accuracy: 0.7149
# Epoch 38/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2034 - accuracy: 0.9420 - val_loss: 1.6316 - val_accuracy: 0.7095
# Epoch 39/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2075 - accuracy: 0.9379 - val_loss: 1.8237 - val_accuracy: 0.7014
# Epoch 40/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1957 - accuracy: 0.9389 - val_loss: 1.7520 - val_accuracy: 0.7126
# Epoch 41/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2050 - accuracy: 0.9430 - val_loss: 1.6418 - val_accuracy: 0.7064
# Epoch 42/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1997 - accuracy: 0.9410 - val_loss: 1.7024 - val_accuracy: 0.7160
# Epoch 43/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1698 - accuracy: 0.9504 - val_loss: 1.6313 - val_accuracy: 0.7045
# Epoch 44/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1775 - accuracy: 0.9490 - val_loss: 1.8289 - val_accuracy: 0.7060
# Epoch 45/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1613 - accuracy: 0.9524 - val_loss: 1.9129 - val_accuracy: 0.7176
# Epoch 46/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1695 - accuracy: 0.9505 - val_loss: 1.8690 - val_accuracy: 0.7122
# Epoch 47/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1741 - accuracy: 0.9519 - val_loss: 1.6351 - val_accuracy: 0.6960
# Epoch 48/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1659 - accuracy: 0.9531 - val_loss: 1.8900 - val_accuracy: 0.7172
# Epoch 49/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1470 - accuracy: 0.9579 - val_loss: 1.8237 - val_accuracy: 0.7195
# Epoch 50/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1390 - accuracy: 0.9576 - val_loss: 1.8123 - val_accuracy: 0.7145
# Epoch 51/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1418 - accuracy: 0.9585 - val_loss: 1.8229 - val_accuracy: 0.7103
# Epoch 52/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1433 - accuracy: 0.9598 - val_loss: 1.8093 - val_accuracy: 0.7149
# Epoch 53/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1249 - accuracy: 0.9647 - val_loss: 2.0244 - val_accuracy: 0.7099
# Epoch 54/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1191 - accuracy: 0.9653 - val_loss: 2.1668 - val_accuracy: 0.7141
# Epoch 55/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1154 - accuracy: 0.9675 - val_loss: 1.9735 - val_accuracy: 0.7234
# Epoch 56/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1366 - accuracy: 0.9653 - val_loss: 2.0245 - val_accuracy: 0.7184
# Epoch 57/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1320 - accuracy: 0.9630 - val_loss: 1.9855 - val_accuracy: 0.7130
# Epoch 58/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1152 - accuracy: 0.9695 - val_loss: 2.0833 - val_accuracy: 0.7242
# Epoch 59/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1123 - accuracy: 0.9691 - val_loss: 1.7534 - val_accuracy: 0.7145
# Epoch 60/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1068 - accuracy: 0.9710 - val_loss: 2.0765 - val_accuracy: 0.7195
# Epoch 61/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1144 - accuracy: 0.9689 - val_loss: 2.1174 - val_accuracy: 0.7164
# Epoch 62/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1094 - accuracy: 0.9715 - val_loss: 1.7466 - val_accuracy: 0.7257
# Epoch 63/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1130 - accuracy: 0.9674 - val_loss: 2.0468 - val_accuracy: 0.7137
# Epoch 64/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1087 - accuracy: 0.9696 - val_loss: 1.9215 - val_accuracy: 0.7238
# Epoch 65/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1181 - accuracy: 0.9674 - val_loss: 1.9946 - val_accuracy: 0.7180
# Epoch 66/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1109 - accuracy: 0.9683 - val_loss: 1.8279 - val_accuracy: 0.7303
# Epoch 67/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0875 - accuracy: 0.9760 - val_loss: 2.0407 - val_accuracy: 0.7361
# Epoch 68/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1150 - accuracy: 0.9679 - val_loss: 2.0882 - val_accuracy: 0.7191
# Epoch 69/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1014 - accuracy: 0.9749 - val_loss: 1.8286 - val_accuracy: 0.7226
# Epoch 70/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1084 - accuracy: 0.9704 - val_loss: 2.1447 - val_accuracy: 0.7130
# Epoch 71/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1004 - accuracy: 0.9727 - val_loss: 2.0634 - val_accuracy: 0.7265
# Epoch 72/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0777 - accuracy: 0.9768 - val_loss: 2.3058 - val_accuracy: 0.7257
# Epoch 73/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0858 - accuracy: 0.9765 - val_loss: 2.0665 - val_accuracy: 0.7207
# Epoch 74/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1214 - accuracy: 0.9679 - val_loss: 2.4714 - val_accuracy: 0.7041
# Epoch 75/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0946 - accuracy: 0.9740 - val_loss: 2.0831 - val_accuracy: 0.7388
# Epoch 76/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0867 - accuracy: 0.9771 - val_loss: 1.9061 - val_accuracy: 0.7276
# Epoch 77/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0917 - accuracy: 0.9756 - val_loss: 2.4004 - val_accuracy: 0.7145
# Epoch 78/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0815 - accuracy: 0.9785 - val_loss: 2.0639 - val_accuracy: 0.7307
# Epoch 79/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0877 - accuracy: 0.9782 - val_loss: 2.1263 - val_accuracy: 0.7218
# Epoch 80/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0772 - accuracy: 0.9791 - val_loss: 2.1817 - val_accuracy: 0.7330
# Epoch 81/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0978 - accuracy: 0.9742 - val_loss: 1.9556 - val_accuracy: 0.7211
# Epoch 82/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0864 - accuracy: 0.9794 - val_loss: 2.0342 - val_accuracy: 0.7164
# Epoch 83/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0751 - accuracy: 0.9793 - val_loss: 2.1307 - val_accuracy: 0.7122
# Epoch 84/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0871 - accuracy: 0.9769 - val_loss: 2.1799 - val_accuracy: 0.7207
# Epoch 85/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0863 - accuracy: 0.9781 - val_loss: 2.2803 - val_accuracy: 0.7184
# Epoch 86/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0736 - accuracy: 0.9809 - val_loss: 2.1357 - val_accuracy: 0.7296
# Epoch 87/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0782 - accuracy: 0.9787 - val_loss: 2.1201 - val_accuracy: 0.7404
# Epoch 88/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.0672 - accuracy: 0.9814 - val_loss: 1.9959 - val_accuracy: 0.7323
# Epoch 89/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0921 - accuracy: 0.9777 - val_loss: 1.6813 - val_accuracy: 0.7307
# Epoch 90/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.0850 - accuracy: 0.9787 - val_loss: 2.0243 - val_accuracy: 0.7326
# Epoch 91/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1001 - accuracy: 0.9745 - val_loss: 2.4655 - val_accuracy: 0.7130
# Epoch 92/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0609 - accuracy: 0.9834 - val_loss: 2.0964 - val_accuracy: 0.7396
# Epoch 93/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0541 - accuracy: 0.9853 - val_loss: 2.4990 - val_accuracy: 0.7384
# Epoch 94/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0723 - accuracy: 0.9798 - val_loss: 2.5270 - val_accuracy: 0.7384
# Epoch 95/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0655 - accuracy: 0.9811 - val_loss: 2.0941 - val_accuracy: 0.7384
# Epoch 96/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0577 - accuracy: 0.9860 - val_loss: 2.4952 - val_accuracy: 0.7307
# Epoch 97/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0647 - accuracy: 0.9821 - val_loss: 2.4110 - val_accuracy: 0.7296
# Epoch 98/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0584 - accuracy: 0.9840 - val_loss: 2.2601 - val_accuracy: 0.7407
# Epoch 99/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0841 - accuracy: 0.9798 - val_loss: 2.5871 - val_accuracy: 0.7284
# Epoch 100/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0697 - accuracy: 0.9803 - val_loss: 2.0743 - val_accuracy: 0.7423

# %%
tuned_improved_history_df = convert_history_to_csv(tuned_improved_history)
tuned_improved_history_df.to_csv("model_histories/noise/adam/spectrogram/tuned_improved_history.csv")

convert_model_to_onnx("bestmodels/noise/adam/spectrogram/tuned_improved_basic_model.keras", (124, 129, 1))

# %%
create_train_val_plot(tuned_improved_history.history)

# %%
tuned_improved_best_model = tf.keras.models.load_model("bestmodels/noise/adam/spectrogram/tuned_improved_basic_model.keras")
test_loss, test_acc = tuned_improved_best_model.evaluate(spect_mixed_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 8ms/step - loss: 1.4257 - accuracy: 0.6773
# Accuratezza: 0.677

# %%
evaluate_onnx_model("bestmodels/noise/adam/spectrogram/tuned_improved_basic_model.onnx", spect_mixed_test_ds)
# Out:
# Accuratezza: 0.677

# %% [markdown]
# AGGIUNGERE COMMENTO SU COME SI E' AGGIORNATO. L'accuratezza è attualmente **XX%**.

# %%
for audio, label in spect_mixed_test_ds:
    create_distribution_plot(tuned_improved_best_model, audio, label)
    break

# %% [markdown]
# ### Miglioramenti all'architettura del modello
# Procediamo quindi con la fase corrispettiva al notebook di riferimento.

# %%
def residual_block(x, filters, pooling=False):
    residual = x

    x = tf.keras.layers.SeparableConv2D(filters, 3, padding="same", use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    if pooling:
      x = tf.keras.layers.MaxPooling2D(pool_size=2, padding="same")(x)
      residual = tf.keras.layers.Conv2D(filters, 1, strides=2)(residual)
    elif filters != residual.shape[-1]:
      residual = tf.keras.layers.Conv2D(filters, 1)(residual)

    x = tf.keras.layers.add([x, residual])
    return x

# %%
def bp_basic_model():
    # input e pre processamento
    inputs = tf.keras.Input(shape=(124, 129, 1))
    
    x = residual_block(inputs, 32, pooling=True)
    x = residual_block(x, 64, pooling=True)
    x = residual_block(x, 128, pooling=True)
    x = residual_block(x, 256, pooling=True)
    x = residual_block(x, 256, pooling=False)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Livelli per la classificazione
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
bp_basic_model = bp_basic_model()
bp_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
bp_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/noise/adam/spectrogram/bp_basic_model.keras", save_best_only=True, monitor="val_loss")]
bp_model_history = bp_basic_model.fit(spect_mixed_train_ds, epochs=100, validation_data=spect_mixed_val_ds, callbacks=bp_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 6s 20ms/step - loss: 3.4229 - accuracy: 0.0647 - val_loss: 3.3903 - val_accuracy: 0.0432
# Epoch 2/100
# 243/243 [==============================] - 5s 20ms/step - loss: 3.0831 - accuracy: 0.1250 - val_loss: 3.0395 - val_accuracy: 0.1420
# Epoch 3/100
# 243/243 [==============================] - 5s 19ms/step - loss: 2.8690 - accuracy: 0.1796 - val_loss: 2.7849 - val_accuracy: 0.1991
# Epoch 4/100
# 243/243 [==============================] - 5s 20ms/step - loss: 2.6451 - accuracy: 0.2394 - val_loss: 2.6321 - val_accuracy: 0.2542
# Epoch 5/100
# 243/243 [==============================] - 5s 20ms/step - loss: 2.3799 - accuracy: 0.3253 - val_loss: 2.3088 - val_accuracy: 0.3623
# Epoch 6/100
# 243/243 [==============================] - 5s 20ms/step - loss: 2.1431 - accuracy: 0.3985 - val_loss: 2.0565 - val_accuracy: 0.4136
# Epoch 7/100
# 243/243 [==============================] - 5s 20ms/step - loss: 1.9179 - accuracy: 0.4631 - val_loss: 1.8390 - val_accuracy: 0.4830
# Epoch 8/100
# 243/243 [==============================] - 5s 20ms/step - loss: 1.7362 - accuracy: 0.5022 - val_loss: 1.7829 - val_accuracy: 0.4834
# Epoch 9/100
# 243/243 [==============================] - 5s 20ms/step - loss: 1.5717 - accuracy: 0.5526 - val_loss: 1.7187 - val_accuracy: 0.5019
# Epoch 10/100
# 243/243 [==============================] - 5s 20ms/step - loss: 1.4283 - accuracy: 0.5863 - val_loss: 1.5187 - val_accuracy: 0.5586
# Epoch 11/100
# 243/243 [==============================] - 5s 20ms/step - loss: 1.3167 - accuracy: 0.6206 - val_loss: 1.6805 - val_accuracy: 0.5220
# Epoch 12/100
# 243/243 [==============================] - 5s 20ms/step - loss: 1.2013 - accuracy: 0.6504 - val_loss: 1.7371 - val_accuracy: 0.5042
# Epoch 13/100
# 243/243 [==============================] - 5s 20ms/step - loss: 1.1113 - accuracy: 0.6754 - val_loss: 1.6553 - val_accuracy: 0.5359
# Epoch 14/100
# 243/243 [==============================] - 5s 20ms/step - loss: 1.0353 - accuracy: 0.6955 - val_loss: 1.4996 - val_accuracy: 0.5683
# Epoch 15/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.9634 - accuracy: 0.7157 - val_loss: 1.6417 - val_accuracy: 0.5312
# Epoch 16/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.9045 - accuracy: 0.7351 - val_loss: 1.7941 - val_accuracy: 0.5112
# Epoch 17/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.8378 - accuracy: 0.7575 - val_loss: 1.4244 - val_accuracy: 0.5930
# Epoch 18/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.7844 - accuracy: 0.7686 - val_loss: 1.4052 - val_accuracy: 0.6030
# Epoch 19/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.7314 - accuracy: 0.7822 - val_loss: 1.7379 - val_accuracy: 0.5602
# Epoch 20/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.7078 - accuracy: 0.7901 - val_loss: 1.9468 - val_accuracy: 0.5459
# Epoch 21/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.6576 - accuracy: 0.8095 - val_loss: 1.7583 - val_accuracy: 0.5571
# Epoch 22/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.6198 - accuracy: 0.8235 - val_loss: 1.4257 - val_accuracy: 0.6335
# Epoch 23/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.5708 - accuracy: 0.8356 - val_loss: 1.5893 - val_accuracy: 0.6080
# Epoch 24/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.5568 - accuracy: 0.8414 - val_loss: 1.8039 - val_accuracy: 0.5829
# Epoch 25/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.5149 - accuracy: 0.8541 - val_loss: 1.5376 - val_accuracy: 0.6142
# Epoch 26/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.4812 - accuracy: 0.8628 - val_loss: 1.5611 - val_accuracy: 0.6277
# Epoch 27/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.4839 - accuracy: 0.8575 - val_loss: 1.7310 - val_accuracy: 0.6030
# Epoch 28/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.4653 - accuracy: 0.8639 - val_loss: 1.9264 - val_accuracy: 0.5806
# Epoch 29/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.4511 - accuracy: 0.8728 - val_loss: 1.5106 - val_accuracy: 0.6362
# Epoch 30/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.3919 - accuracy: 0.8885 - val_loss: 1.4379 - val_accuracy: 0.6304
# Epoch 31/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.3939 - accuracy: 0.8847 - val_loss: 1.6552 - val_accuracy: 0.6292
# Epoch 32/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.3701 - accuracy: 0.8955 - val_loss: 1.6300 - val_accuracy: 0.6304
# Epoch 33/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.3635 - accuracy: 0.8979 - val_loss: 1.6796 - val_accuracy: 0.6022
# Epoch 34/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.3780 - accuracy: 0.8905 - val_loss: 1.9697 - val_accuracy: 0.5864
# Epoch 35/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.4310 - accuracy: 0.8711 - val_loss: 1.8904 - val_accuracy: 0.5856
# Epoch 36/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.3328 - accuracy: 0.9075 - val_loss: 1.5474 - val_accuracy: 0.6370
# Epoch 37/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.3153 - accuracy: 0.9093 - val_loss: 1.6358 - val_accuracy: 0.6354
# Epoch 38/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2979 - accuracy: 0.9128 - val_loss: 1.5880 - val_accuracy: 0.6443
# Epoch 39/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2610 - accuracy: 0.9284 - val_loss: 1.8845 - val_accuracy: 0.5860
# Epoch 40/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2940 - accuracy: 0.9168 - val_loss: 2.1786 - val_accuracy: 0.5802
# Epoch 41/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2822 - accuracy: 0.9229 - val_loss: 1.8601 - val_accuracy: 0.6061
# Epoch 42/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2769 - accuracy: 0.9228 - val_loss: 1.6802 - val_accuracy: 0.6281
# Epoch 43/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.2753 - accuracy: 0.9188 - val_loss: 1.7967 - val_accuracy: 0.6242
# Epoch 44/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.2471 - accuracy: 0.9303 - val_loss: 1.9920 - val_accuracy: 0.6188
# Epoch 45/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2774 - accuracy: 0.9228 - val_loss: 1.6122 - val_accuracy: 0.6451
# Epoch 46/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.2778 - accuracy: 0.9215 - val_loss: 1.6746 - val_accuracy: 0.6285
# Epoch 47/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.2505 - accuracy: 0.9265 - val_loss: 5.1583 - val_accuracy: 0.4016
# Epoch 48/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.2425 - accuracy: 0.9325 - val_loss: 1.8493 - val_accuracy: 0.6242
# Epoch 49/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.2487 - accuracy: 0.9287 - val_loss: 1.8728 - val_accuracy: 0.6157
# Epoch 50/100
# 243/243 [==============================] - 6s 23ms/step - loss: 0.1913 - accuracy: 0.9488 - val_loss: 2.2062 - val_accuracy: 0.5810
# Epoch 51/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.2265 - accuracy: 0.9375 - val_loss: 1.7734 - val_accuracy: 0.6663
# Epoch 52/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.2220 - accuracy: 0.9331 - val_loss: 1.7335 - val_accuracy: 0.6651
# Epoch 53/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1907 - accuracy: 0.9482 - val_loss: 2.7604 - val_accuracy: 0.5475
# Epoch 54/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.2344 - accuracy: 0.9330 - val_loss: 2.1183 - val_accuracy: 0.6038
# Epoch 55/100
# 243/243 [==============================] - 6s 23ms/step - loss: 0.2023 - accuracy: 0.9445 - val_loss: 2.7469 - val_accuracy: 0.5459
# Epoch 56/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.2072 - accuracy: 0.9442 - val_loss: 2.9965 - val_accuracy: 0.5374
# Epoch 57/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.2199 - accuracy: 0.9376 - val_loss: 1.9391 - val_accuracy: 0.6304
# Epoch 58/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.2039 - accuracy: 0.9430 - val_loss: 2.7330 - val_accuracy: 0.5702
# Epoch 59/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1814 - accuracy: 0.9488 - val_loss: 2.0423 - val_accuracy: 0.6061
# Epoch 60/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1904 - accuracy: 0.9473 - val_loss: 2.5316 - val_accuracy: 0.5883
# Epoch 61/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1997 - accuracy: 0.9376 - val_loss: 2.5318 - val_accuracy: 0.5687
# Epoch 62/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1991 - accuracy: 0.9407 - val_loss: 2.6138 - val_accuracy: 0.5802
# Epoch 63/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1652 - accuracy: 0.9531 - val_loss: 1.9451 - val_accuracy: 0.6343
# Epoch 64/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1839 - accuracy: 0.9469 - val_loss: 3.1999 - val_accuracy: 0.5247
# Epoch 65/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1941 - accuracy: 0.9448 - val_loss: 2.7149 - val_accuracy: 0.5806
# Epoch 66/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1635 - accuracy: 0.9546 - val_loss: 2.9289 - val_accuracy: 0.5598
# Epoch 67/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1400 - accuracy: 0.9610 - val_loss: 3.6930 - val_accuracy: 0.4981
# Epoch 68/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1756 - accuracy: 0.9463 - val_loss: 2.1683 - val_accuracy: 0.6111
# Epoch 69/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1537 - accuracy: 0.9586 - val_loss: 2.3578 - val_accuracy: 0.6015
# Epoch 70/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1771 - accuracy: 0.9479 - val_loss: 1.8068 - val_accuracy: 0.6485
# Epoch 71/100
# 243/243 [==============================] - 6s 23ms/step - loss: 0.2038 - accuracy: 0.9392 - val_loss: 2.0624 - val_accuracy: 0.6127
# Epoch 72/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.2052 - accuracy: 0.9369 - val_loss: 2.1594 - val_accuracy: 0.6111
# Epoch 73/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1582 - accuracy: 0.9570 - val_loss: 1.9711 - val_accuracy: 0.6238
# Epoch 74/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1337 - accuracy: 0.9622 - val_loss: 2.3946 - val_accuracy: 0.5995
# Epoch 75/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1533 - accuracy: 0.9550 - val_loss: 1.8358 - val_accuracy: 0.6578
# Epoch 76/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1301 - accuracy: 0.9622 - val_loss: 1.9181 - val_accuracy: 0.6416
# Epoch 77/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1283 - accuracy: 0.9634 - val_loss: 2.0533 - val_accuracy: 0.6397
# Epoch 78/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1590 - accuracy: 0.9540 - val_loss: 3.0894 - val_accuracy: 0.5498
# Epoch 79/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1353 - accuracy: 0.9624 - val_loss: 2.6380 - val_accuracy: 0.5810
# Epoch 80/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1338 - accuracy: 0.9607 - val_loss: 2.8669 - val_accuracy: 0.5810
# Epoch 81/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1511 - accuracy: 0.9570 - val_loss: 2.2524 - val_accuracy: 0.6134
# Epoch 82/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1738 - accuracy: 0.9473 - val_loss: 2.0494 - val_accuracy: 0.6424
# Epoch 83/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1665 - accuracy: 0.9505 - val_loss: 1.7272 - val_accuracy: 0.6605
# Epoch 84/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1322 - accuracy: 0.9607 - val_loss: 3.2271 - val_accuracy: 0.5621
# Epoch 85/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1265 - accuracy: 0.9651 - val_loss: 2.4313 - val_accuracy: 0.6123
# Epoch 86/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1517 - accuracy: 0.9541 - val_loss: 2.4587 - val_accuracy: 0.6084
# Epoch 87/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1547 - accuracy: 0.9528 - val_loss: 2.6596 - val_accuracy: 0.6107
# Epoch 88/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1248 - accuracy: 0.9634 - val_loss: 2.8578 - val_accuracy: 0.5775
# Epoch 89/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0992 - accuracy: 0.9726 - val_loss: 2.1647 - val_accuracy: 0.6296
# Epoch 90/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.0995 - accuracy: 0.9711 - val_loss: 2.0143 - val_accuracy: 0.6424
# Epoch 91/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1433 - accuracy: 0.9595 - val_loss: 2.8872 - val_accuracy: 0.5667
# Epoch 92/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1393 - accuracy: 0.9561 - val_loss: 3.4084 - val_accuracy: 0.5347
# Epoch 93/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1375 - accuracy: 0.9611 - val_loss: 1.7307 - val_accuracy: 0.6671
# Epoch 94/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1372 - accuracy: 0.9588 - val_loss: 2.9876 - val_accuracy: 0.5436
# Epoch 95/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1297 - accuracy: 0.9640 - val_loss: 1.9516 - val_accuracy: 0.6744
# Epoch 96/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1381 - accuracy: 0.9594 - val_loss: 2.2387 - val_accuracy: 0.6443
# Epoch 97/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1168 - accuracy: 0.9666 - val_loss: 3.1031 - val_accuracy: 0.5529
# Epoch 98/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.0899 - accuracy: 0.9747 - val_loss: 1.7375 - val_accuracy: 0.6802
# Epoch 99/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.0852 - accuracy: 0.9764 - val_loss: 1.9535 - val_accuracy: 0.6481
# Epoch 100/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1309 - accuracy: 0.9633 - val_loss: 2.1880 - val_accuracy: 0.6343

# %% [markdown]
# Salviamo nuovamente la history del modello in un file csv e convertiamo il miglior modello nel formato **.onnx**.

# %%
bp_model_history_df = convert_history_to_csv(bp_model_history)
bp_model_history_df.to_csv("model_histories/noise/adam/spectrogram/bp_model_history.csv")

convert_model_to_onnx("bestmodels/noise/adam/spectrogram/bp_basic_model.keras", (124, 129, 1))

# %%
create_train_val_plot(bp_model_history.history)

# %% [markdown]
# In questo caso il modello **HA raggiunto una fase di overfitting**, inoltre le prestazioni sono diminuite di parecchio sotto qualsiasi aspetto.

# %%
best_bp_basic_model = tf.keras.models.load_model("bestmodels/noise/adam/spectrogram/bp_basic_model.keras")
test_loss, test_acc = best_bp_basic_model.evaluate(spect_mixed_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 5ms/step - loss: 1.4223 - accuracy: 0.6048
# Accuratezza: 0.605

# %%
evaluate_onnx_model("bestmodels/noise/adam/spectrogram/bp_basic_model.onnx", spect_mixed_test_ds)
# Out:
# Accuratezza: 0.605

# %% [markdown]
# Abbiamo ottenuto un forte peggioramento per quanto riguarda l'accuratezza, ottenendo un **60.5%**.

# %%
for audio, label in spect_mixed_test_ds:
    create_distribution_plot(best_bp_basic_model, audio, label)
    break

# %% [markdown]
# ## Addestramento (filterbanks)
# Procederemo con lo stesso approccio degli spettrogrammi, ma dando in input dei filterbanks con rumore.

# %%
fb_mixed_train_ds = DatasetConverter(mixed_train_ds)
fb_mixed_train_ds = fb_mixed_train_ds.convert("filterbanks")

fb_mixed_validation_ds = DatasetConverter(mixed_validation_ds)
fb_mixed_validation_ds = fb_mixed_validation_ds.convert("filterbanks")

fb_mixed_val_ds = fb_mixed_validation_ds.take(fb_mixed_validation_ds.cardinality() // 2) # ho cambiato nome del validation_ds in modo tale da non creare problemi con l'istruzione seguente
fb_mixed_test_ds = fb_mixed_validation_ds.skip(fb_mixed_validation_ds.cardinality() // 2)

# %%
for audio, label in fb_mixed_train_ds:
    basic_model = get_basic_model(audio.shape[1:])
    break
    
basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/noise/adam/filterbanks/basic_model_fb.keras", save_best_only=True, monitor="val_loss")]
basic_model_history = basic_model.fit(fb_mixed_train_ds, epochs=30, validation_data=fb_mixed_val_ds, callbacks=basic_model_callbacks)
# Out:
# Epoch 1/30
# 243/243 [==============================] - 2s 5ms/step - loss: 3.5082 - accuracy: 0.0438 - val_loss: 3.2233 - val_accuracy: 0.0818
# Epoch 2/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.8704 - accuracy: 0.1572 - val_loss: 2.5327 - val_accuracy: 0.2627
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.1196 - accuracy: 0.3716 - val_loss: 1.7601 - val_accuracy: 0.4977
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.4408 - accuracy: 0.5649 - val_loss: 1.5062 - val_accuracy: 0.5590
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.0720 - accuracy: 0.6731 - val_loss: 1.3738 - val_accuracy: 0.6061
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8409 - accuracy: 0.7366 - val_loss: 1.4531 - val_accuracy: 0.5980
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6903 - accuracy: 0.7794 - val_loss: 1.3372 - val_accuracy: 0.6555
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5595 - accuracy: 0.8207 - val_loss: 1.3619 - val_accuracy: 0.6659
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4927 - accuracy: 0.8441 - val_loss: 1.6354 - val_accuracy: 0.6485
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4395 - accuracy: 0.8631 - val_loss: 1.5479 - val_accuracy: 0.6659
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3628 - accuracy: 0.8843 - val_loss: 1.4994 - val_accuracy: 0.6914
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2986 - accuracy: 0.9059 - val_loss: 1.7933 - val_accuracy: 0.6740
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2605 - accuracy: 0.9187 - val_loss: 1.8519 - val_accuracy: 0.6844
# Epoch 14/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2630 - accuracy: 0.9195 - val_loss: 2.1597 - val_accuracy: 0.6744
# Epoch 15/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1992 - accuracy: 0.9396 - val_loss: 2.0636 - val_accuracy: 0.6740
# Epoch 16/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2075 - accuracy: 0.9345 - val_loss: 2.0875 - val_accuracy: 0.6813
# Epoch 17/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2006 - accuracy: 0.9398 - val_loss: 2.0276 - val_accuracy: 0.6732
# Epoch 18/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1688 - accuracy: 0.9482 - val_loss: 2.1812 - val_accuracy: 0.6906
# Epoch 19/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1792 - accuracy: 0.9476 - val_loss: 2.0584 - val_accuracy: 0.6890
# Epoch 20/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1317 - accuracy: 0.9613 - val_loss: 2.1178 - val_accuracy: 0.7033
# Epoch 21/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1616 - accuracy: 0.9575 - val_loss: 2.1474 - val_accuracy: 0.6852
# Epoch 22/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1616 - accuracy: 0.9483 - val_loss: 2.4714 - val_accuracy: 0.6782
# Epoch 23/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1293 - accuracy: 0.9639 - val_loss: 2.2887 - val_accuracy: 0.7056
# Epoch 24/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1304 - accuracy: 0.9635 - val_loss: 2.1350 - val_accuracy: 0.7041
# Epoch 25/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1215 - accuracy: 0.9647 - val_loss: 2.3769 - val_accuracy: 0.7087
# Epoch 26/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1644 - accuracy: 0.9558 - val_loss: 2.7541 - val_accuracy: 0.6420
# Epoch 27/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1730 - accuracy: 0.9526 - val_loss: 2.4703 - val_accuracy: 0.6813
# Epoch 28/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1317 - accuracy: 0.9638 - val_loss: 2.7841 - val_accuracy: 0.6659
# Epoch 29/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1340 - accuracy: 0.9630 - val_loss: 2.6436 - val_accuracy: 0.6921
# Epoch 30/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1111 - accuracy: 0.9678 - val_loss: 2.8460 - val_accuracy: 0.6840

# %% [markdown]
# Salviamo i dati della history del modello in un file csv

# %%
basic_model_history_df = convert_history_to_csv(basic_model_history)
basic_model_history_df.to_csv("model_histories/noise/adam/filterbanks/basic_model_history_fb.csv")

convert_model_to_onnx("bestmodels/noise/adam/filterbanks/basic_model_fb.keras", (98, 40, 1))

# %% [markdown]
# Visualizziamo l'andamento dell'accuratezza e della perdita durante l'addestramento.

# %%
create_train_val_plot(basic_model_history.history)

# %% [markdown]
# Verifichiamo l'accuratezza della migliore versione del nostro modello di base ricaricando il file **basic_model.keras**.

# %%
best_basic_model = tf.keras.models.load_model("bestmodels/noise/adam/filterbanks/basic_model_fb.keras")
test_loss, test_acc = best_basic_model.evaluate(fb_mixed_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 2ms/step - loss: 1.3054 - accuracy: 0.6618
# Accuratezza: 0.662

# %%
evaluate_onnx_model("bestmodels/noise/adam/filterbanks/basic_model_fb.onnx", fb_mixed_test_ds)
# Out:
# Accuratezza: 0.662

# %% [markdown]
# Abbiamo ottenuto un'**accuratezza** del **70.6%**, possiamo già notare un piccolo miglioramento rispetto agli spettrogrammi. Visualizziamo la distribuzione di accuratezza delle classi su un'immagine casuale.

# %%
for audio, label in fb_mixed_test_ds: # prendiamo un audio a caso del test e creiamo la distribuzione
    create_distribution_plot(best_basic_model, audio, label)
    break

# %% [markdown]
# ### Risoluzione dell'overfitting
# Ovviamente il modello è andato immediatamente in **overfitting**, perciò ripetiamo i metodi applicati precedentemente.

# %%
for audio, label in fb_mixed_train_ds:
    improved_basic_model = get_improved_basic_model(audio.shape[1:])
    break

improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/noise/adam/filterbanks/improved_basic_model_fb.keras", save_best_only=True, monitor="val_loss")]
improved_history = improved_basic_model.fit(fb_mixed_train_ds, epochs=100, validation_data=fb_mixed_val_ds, callbacks=improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 1s 5ms/step - loss: 3.4982 - accuracy: 0.0349 - val_loss: 3.3953 - val_accuracy: 0.0316
# Epoch 2/100
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2801 - accuracy: 0.0684 - val_loss: 3.0466 - val_accuracy: 0.1208
# Epoch 3/100
# 243/243 [==============================] - 1s 4ms/step - loss: 2.8588 - accuracy: 0.1608 - val_loss: 2.4272 - val_accuracy: 0.2894
# Epoch 4/100
# 243/243 [==============================] - 1s 4ms/step - loss: 2.2406 - accuracy: 0.3410 - val_loss: 1.8288 - val_accuracy: 0.4522
# Epoch 5/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.6138 - accuracy: 0.5165 - val_loss: 1.3348 - val_accuracy: 0.5995
# Epoch 6/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.2325 - accuracy: 0.6274 - val_loss: 1.1522 - val_accuracy: 0.6632
# Epoch 7/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.0363 - accuracy: 0.6844 - val_loss: 1.1645 - val_accuracy: 0.6651
# Epoch 8/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.9137 - accuracy: 0.7152 - val_loss: 1.1803 - val_accuracy: 0.6682
# Epoch 9/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8129 - accuracy: 0.7470 - val_loss: 1.0460 - val_accuracy: 0.7049
# Epoch 10/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6638 - accuracy: 0.7903 - val_loss: 1.0330 - val_accuracy: 0.7168
# Epoch 11/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5960 - accuracy: 0.8128 - val_loss: 0.9896 - val_accuracy: 0.7438
# Epoch 12/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5292 - accuracy: 0.8318 - val_loss: 1.0170 - val_accuracy: 0.7269
# Epoch 13/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5100 - accuracy: 0.8392 - val_loss: 1.0222 - val_accuracy: 0.7299
# Epoch 14/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4753 - accuracy: 0.8504 - val_loss: 1.0501 - val_accuracy: 0.7415
# Epoch 15/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4277 - accuracy: 0.8626 - val_loss: 1.1835 - val_accuracy: 0.7257
# Epoch 16/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4368 - accuracy: 0.8608 - val_loss: 1.1146 - val_accuracy: 0.7411
# Epoch 17/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3919 - accuracy: 0.8765 - val_loss: 1.1717 - val_accuracy: 0.7434
# Epoch 18/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3683 - accuracy: 0.8847 - val_loss: 1.2270 - val_accuracy: 0.7454
# Epoch 19/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3212 - accuracy: 0.8968 - val_loss: 1.2151 - val_accuracy: 0.7589
# Epoch 20/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3346 - accuracy: 0.8952 - val_loss: 1.2960 - val_accuracy: 0.7284
# Epoch 21/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3137 - accuracy: 0.9022 - val_loss: 1.3141 - val_accuracy: 0.7388
# Epoch 22/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3068 - accuracy: 0.9045 - val_loss: 1.3166 - val_accuracy: 0.7373
# Epoch 23/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2677 - accuracy: 0.9142 - val_loss: 1.2765 - val_accuracy: 0.7504
# Epoch 24/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2606 - accuracy: 0.9200 - val_loss: 1.3919 - val_accuracy: 0.7411
# Epoch 25/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2378 - accuracy: 0.9273 - val_loss: 1.3665 - val_accuracy: 0.7512
# Epoch 26/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2577 - accuracy: 0.9219 - val_loss: 1.3570 - val_accuracy: 0.7627
# Epoch 27/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2473 - accuracy: 0.9265 - val_loss: 1.5456 - val_accuracy: 0.7319
# Epoch 28/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2252 - accuracy: 0.9320 - val_loss: 1.3424 - val_accuracy: 0.7485
# Epoch 29/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1946 - accuracy: 0.9383 - val_loss: 1.3926 - val_accuracy: 0.7720
# Epoch 30/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2013 - accuracy: 0.9365 - val_loss: 1.7287 - val_accuracy: 0.7160
# Epoch 31/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2594 - accuracy: 0.9312 - val_loss: 1.3272 - val_accuracy: 0.7519
# Epoch 32/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1962 - accuracy: 0.9423 - val_loss: 1.6413 - val_accuracy: 0.7419
# Epoch 33/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2155 - accuracy: 0.9369 - val_loss: 1.5062 - val_accuracy: 0.7427
# Epoch 34/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2028 - accuracy: 0.9399 - val_loss: 1.3963 - val_accuracy: 0.7488
# Epoch 35/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2003 - accuracy: 0.9468 - val_loss: 1.4948 - val_accuracy: 0.7666
# Epoch 36/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2144 - accuracy: 0.9365 - val_loss: 1.6116 - val_accuracy: 0.7504
# Epoch 37/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2093 - accuracy: 0.9405 - val_loss: 1.5440 - val_accuracy: 0.7415
# Epoch 38/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1970 - accuracy: 0.9433 - val_loss: 1.5424 - val_accuracy: 0.7492
# Epoch 39/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1917 - accuracy: 0.9452 - val_loss: 1.5974 - val_accuracy: 0.7438
# Epoch 40/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1946 - accuracy: 0.9434 - val_loss: 1.6065 - val_accuracy: 0.7573
# Epoch 41/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1851 - accuracy: 0.9477 - val_loss: 1.7339 - val_accuracy: 0.7164
# Epoch 42/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2065 - accuracy: 0.9419 - val_loss: 1.6642 - val_accuracy: 0.7577
# Epoch 43/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1938 - accuracy: 0.9442 - val_loss: 1.7822 - val_accuracy: 0.7635
# Epoch 44/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1505 - accuracy: 0.9570 - val_loss: 1.8339 - val_accuracy: 0.7612
# Epoch 45/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1741 - accuracy: 0.9550 - val_loss: 1.7531 - val_accuracy: 0.7461
# Epoch 46/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1841 - accuracy: 0.9500 - val_loss: 1.6772 - val_accuracy: 0.7623
# Epoch 47/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1578 - accuracy: 0.9563 - val_loss: 1.6343 - val_accuracy: 0.7631
# Epoch 48/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1520 - accuracy: 0.9566 - val_loss: 1.7348 - val_accuracy: 0.7562
# Epoch 49/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1941 - accuracy: 0.9501 - val_loss: 1.5713 - val_accuracy: 0.7739
# Epoch 50/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1819 - accuracy: 0.9500 - val_loss: 1.8973 - val_accuracy: 0.7326
# Epoch 51/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1702 - accuracy: 0.9530 - val_loss: 1.9825 - val_accuracy: 0.7400
# Epoch 52/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1590 - accuracy: 0.9581 - val_loss: 1.8212 - val_accuracy: 0.7566
# Epoch 53/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1561 - accuracy: 0.9549 - val_loss: 1.9173 - val_accuracy: 0.7550
# Epoch 54/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1848 - accuracy: 0.9495 - val_loss: 1.8085 - val_accuracy: 0.7461
# Epoch 55/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1745 - accuracy: 0.9532 - val_loss: 1.8713 - val_accuracy: 0.7434
# Epoch 56/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1630 - accuracy: 0.9575 - val_loss: 1.8161 - val_accuracy: 0.7681
# Epoch 57/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1535 - accuracy: 0.9579 - val_loss: 1.9424 - val_accuracy: 0.7581
# Epoch 58/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1244 - accuracy: 0.9648 - val_loss: 2.1484 - val_accuracy: 0.7488
# Epoch 59/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1401 - accuracy: 0.9665 - val_loss: 2.0025 - val_accuracy: 0.7512
# Epoch 60/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1791 - accuracy: 0.9553 - val_loss: 1.9533 - val_accuracy: 0.7647
# Epoch 61/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1291 - accuracy: 0.9656 - val_loss: 2.1804 - val_accuracy: 0.7523
# Epoch 62/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1360 - accuracy: 0.9630 - val_loss: 1.8838 - val_accuracy: 0.7674
# Epoch 63/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1268 - accuracy: 0.9679 - val_loss: 2.0232 - val_accuracy: 0.7577
# Epoch 64/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1757 - accuracy: 0.9577 - val_loss: 1.9853 - val_accuracy: 0.7469
# Epoch 65/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1543 - accuracy: 0.9579 - val_loss: 2.0131 - val_accuracy: 0.7569
# Epoch 66/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1762 - accuracy: 0.9559 - val_loss: 2.0703 - val_accuracy: 0.7585
# Epoch 67/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1653 - accuracy: 0.9601 - val_loss: 2.1508 - val_accuracy: 0.7450
# Epoch 68/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1799 - accuracy: 0.9584 - val_loss: 2.1632 - val_accuracy: 0.7485
# Epoch 69/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1473 - accuracy: 0.9634 - val_loss: 1.9603 - val_accuracy: 0.7581
# Epoch 70/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1257 - accuracy: 0.9668 - val_loss: 2.0992 - val_accuracy: 0.7361
# Epoch 71/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1565 - accuracy: 0.9593 - val_loss: 2.0243 - val_accuracy: 0.7554
# Epoch 72/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1720 - accuracy: 0.9599 - val_loss: 2.0236 - val_accuracy: 0.7542
# Epoch 73/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1262 - accuracy: 0.9673 - val_loss: 2.3110 - val_accuracy: 0.7539
# Epoch 74/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1889 - accuracy: 0.9572 - val_loss: 2.2214 - val_accuracy: 0.7577
# Epoch 75/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1937 - accuracy: 0.9537 - val_loss: 2.1601 - val_accuracy: 0.7593
# Epoch 76/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1368 - accuracy: 0.9678 - val_loss: 2.1642 - val_accuracy: 0.7527
# Epoch 77/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1070 - accuracy: 0.9715 - val_loss: 2.3083 - val_accuracy: 0.7488
# Epoch 78/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1090 - accuracy: 0.9716 - val_loss: 1.9654 - val_accuracy: 0.7531
# Epoch 79/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1126 - accuracy: 0.9710 - val_loss: 2.1204 - val_accuracy: 0.7612
# Epoch 80/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1093 - accuracy: 0.9729 - val_loss: 2.3277 - val_accuracy: 0.7500
# Epoch 81/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1544 - accuracy: 0.9649 - val_loss: 2.2470 - val_accuracy: 0.7469
# Epoch 82/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2272 - accuracy: 0.9491 - val_loss: 2.3391 - val_accuracy: 0.7346
# Epoch 83/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1903 - accuracy: 0.9572 - val_loss: 1.9812 - val_accuracy: 0.7542
# Epoch 84/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1455 - accuracy: 0.9653 - val_loss: 2.2779 - val_accuracy: 0.7519
# Epoch 85/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1558 - accuracy: 0.9615 - val_loss: 2.2584 - val_accuracy: 0.7535
# Epoch 86/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1454 - accuracy: 0.9682 - val_loss: 2.1787 - val_accuracy: 0.7527
# Epoch 87/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1557 - accuracy: 0.9635 - val_loss: 2.2644 - val_accuracy: 0.7504
# Epoch 88/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1220 - accuracy: 0.9715 - val_loss: 2.1297 - val_accuracy: 0.7473
# Epoch 89/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1021 - accuracy: 0.9728 - val_loss: 2.3061 - val_accuracy: 0.7508
# Epoch 90/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1603 - accuracy: 0.9635 - val_loss: 2.7049 - val_accuracy: 0.7215
# Epoch 91/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2110 - accuracy: 0.9524 - val_loss: 2.2685 - val_accuracy: 0.7581
# Epoch 92/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1465 - accuracy: 0.9628 - val_loss: 2.2562 - val_accuracy: 0.7523
# Epoch 93/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1368 - accuracy: 0.9631 - val_loss: 2.2648 - val_accuracy: 0.7500
# Epoch 94/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1856 - accuracy: 0.9559 - val_loss: 2.4119 - val_accuracy: 0.7666
# Epoch 95/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1648 - accuracy: 0.9644 - val_loss: 2.5550 - val_accuracy: 0.7469
# Epoch 96/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1245 - accuracy: 0.9709 - val_loss: 2.7828 - val_accuracy: 0.7477
# Epoch 97/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2247 - accuracy: 0.9549 - val_loss: 2.7619 - val_accuracy: 0.7296
# Epoch 98/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1625 - accuracy: 0.9633 - val_loss: 2.3423 - val_accuracy: 0.7778
# Epoch 99/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1468 - accuracy: 0.9693 - val_loss: 2.7362 - val_accuracy: 0.7438
# Epoch 100/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1188 - accuracy: 0.9746 - val_loss: 2.4072 - val_accuracy: 0.7531

# %% [markdown]
# Salviamo come prima la history del modello in un file csv, e convertiamo il miglior modello nel formato **.onnx**.

# %%
improved_history_df = convert_history_to_csv(improved_history)
improved_history_df.to_csv("model_histories/noise/adam/filterbanks/improved_history_fb.csv")

convert_model_to_onnx("bestmodels/noise/adam/filterbanks/improved_basic_model_fb.keras", (98, 40, 1))

# %% [markdown]
# Visualizziamo la curva dell'accuratezza e della perdita durante l'addestramento.

# %%
create_train_val_plot(improved_history.history)

# %% [markdown]
# Le prestazioni sono migliorate rispetto all'applicazione precedente. Verifichiamo l'accuratezza nel dataset di test.

# %%
improved_best_model = tf.keras.models.load_model("bestmodels/noise/adam/filterbanks/improved_basic_model_fb.keras")
test_loss, test_acc = improved_best_model.evaluate(fb_mixed_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 2ms/step - loss: 1.0412 - accuracy: 0.7269
# Accuratezza: 0.727

# %%
evaluate_onnx_model("bestmodels/noise/adam/filterbanks/improved_basic_model_fb.onnx", fb_mixed_test_ds)
# Out:
# Accuratezza: 0.727

# %% [markdown]
# Abbiamo ottenuto un notevole miglioramento dell'accuratezza, attualmente siamo a quota **75.4%**! Visualizziamo anche la solita distribuzione.

# %%
for audio, label in fb_mixed_test_ds:
    create_distribution_plot(improved_best_model, audio, label)
    break

# %% [markdown]
# ### Fine tuning
# Anche per questa sezione, andiamo a ripetere gli stessi passaggi degli spettrogrammi.

# %%
def get_improved_basic_model_tuning(start_filters):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(98, 40, 1))
    x = tf.keras.layers.Normalization()(inputs)

    if not isinstance(start_filters, int):
        raise Exception("start_filters must be type integer")

    filters = [start_filters * (2 ** i) for i in range(4)]
    
    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=filters[0], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[1], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[2], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[3], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[3], kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

def tuner(filters, learning_rates, max_epochs, train_dataset, validation_dataset):
    start_time = time.time()

    counter = 1
    
    if not isinstance(filters, list):
        raise Exception("parameter filters must be type list")

    if not isinstance(learning_rates, list):
        raise Exception("parameter learning_rates must be type list")

    callbacks = [tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5)]

    best_learning_rate = 0 
    best_filters = 0
    best_val_accuracy = 0

    best_model = 0
    
    for f in filters:
        for lr in learning_rates:
            print(f"\nAddestrando con filtri {[f * (2 ** i) for i in range(4)]} e tasso di apprendimento {lr}")
            
            model = get_improved_basic_model_tuning(start_filters=f)
            model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=lr), metrics=["accuracy"])
            model_history = model.fit(train_dataset, epochs=max_epochs, validation_data=validation_dataset, callbacks=callbacks)

            model_history_df = convert_history_to_csv(model_history)

            model_history_df[["filters"]] = f
            model_history_df[["learning_rate"]] = lr
            
            path = "model_tuning/noise/adam/filterbanks/model_" + str(counter) + ".csv"
            model_history_df.to_csv(path)
            
            if best_val_accuracy < model_history_df.iloc[-1]["val_accuracy"]:
                best_val_accuracy = model_history_df.iloc[-1]["val_accuracy"]
                best_filters = f
                best_learning_rate = lr
                epoch = len(model_history_df)

            del model

            counter += 1

    total_time = time.time() - start_time
    minutes, seconds = divmod(total_time, 60)
    print(f"\nTempo totale trascorso: {int(minutes)} minuti e {int(seconds)} secondi")
    # print(f"Il miglior modello ha un filtro di partenza pari a {best_filters}, un learning rate pari a {best_learning_rate} con un'accuracy pari a {best_val_accuracy:.3f}")

    return best_filters, best_learning_rate

best_filter, best_learning_rate = tuner([16, 32, 64], [1e-3, 1e-4, 1e-5], 30, fb_mixed_train_ds, fb_mixed_val_ds)
# Out:
# Addestrando con filtri [16, 32, 64, 128] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.4807 - accuracy: 0.0336 - val_loss: 3.3935 - val_accuracy: 0.0278
# Epoch 2/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3949 - accuracy: 0.0405 - val_loss: 3.3921 - val_accuracy: 0.0293
# Epoch 3/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.1580 - accuracy: 0.0979 - val_loss: 2.9262 - val_accuracy: 0.1416
# Epoch 4/30
# 243/243 [==============================] - 1s 3ms/step - loss: 2.6666 - accuracy: 0.2063 - val_loss: 2.3932 - val_accuracy: 0.2867
# Epoch 5/30
# 243/243 [==============================] - 1s 3ms/step - loss: 2.0744 - accuracy: 0.3800 - val_loss: 1.6714 - val_accuracy: 0.4973
# Epoch 6/30
# 243/243 [==============================] - 1s 3ms/step - loss: 1.6317 - accuracy: 0.5035 - val_loss: 1.3655 - val_accuracy: 0.5903
# Epoch 7/30
# 243/243 [==============================] - 1s 3ms/step - loss: 1.3336 - accuracy: 0.5977 - val_loss: 1.2079 - val_accuracy: 0.6327
# Epoch 8/30
# 243/243 [==============================] - 1s 3ms/step - loss: 1.1106 - accuracy: 0.6666 - val_loss: 1.1659 - val_accuracy: 0.6532
# Epoch 9/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.9580 - accuracy: 0.7023 - val_loss: 1.1334 - val_accuracy: 0.6678
# Epoch 10/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.8633 - accuracy: 0.7336 - val_loss: 1.0632 - val_accuracy: 0.6860
# Epoch 11/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.7714 - accuracy: 0.7591 - val_loss: 1.0385 - val_accuracy: 0.7087
# Epoch 12/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.7045 - accuracy: 0.7787 - val_loss: 1.0597 - val_accuracy: 0.7049
# Epoch 13/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.6372 - accuracy: 0.7995 - val_loss: 1.0839 - val_accuracy: 0.7002
# Epoch 14/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.5924 - accuracy: 0.8116 - val_loss: 1.1131 - val_accuracy: 0.7095
# Epoch 15/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.5350 - accuracy: 0.8237 - val_loss: 1.0419 - val_accuracy: 0.7203
# Epoch 16/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.4967 - accuracy: 0.8432 - val_loss: 1.0780 - val_accuracy: 0.7357
#
# Addestrando con filtri [16, 32, 64, 128] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.6205 - accuracy: 0.0401 - val_loss: 3.3932 - val_accuracy: 0.0413
# Epoch 2/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.3928 - accuracy: 0.0456 - val_loss: 3.3771 - val_accuracy: 0.0444
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3731 - accuracy: 0.0576 - val_loss: 3.3484 - val_accuracy: 0.0556
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3241 - accuracy: 0.0720 - val_loss: 3.2569 - val_accuracy: 0.0822
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1731 - accuracy: 0.1035 - val_loss: 3.0103 - val_accuracy: 0.1400
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.9498 - accuracy: 0.1494 - val_loss: 2.7649 - val_accuracy: 0.2091
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.7552 - accuracy: 0.1960 - val_loss: 2.5643 - val_accuracy: 0.2616
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.5570 - accuracy: 0.2510 - val_loss: 2.3677 - val_accuracy: 0.3086
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.3405 - accuracy: 0.3026 - val_loss: 2.2167 - val_accuracy: 0.3657
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.1543 - accuracy: 0.3625 - val_loss: 2.0509 - val_accuracy: 0.3989
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.9903 - accuracy: 0.4095 - val_loss: 1.8850 - val_accuracy: 0.4510
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.8104 - accuracy: 0.4664 - val_loss: 1.7271 - val_accuracy: 0.5012
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.6953 - accuracy: 0.4925 - val_loss: 1.6038 - val_accuracy: 0.5328
# Epoch 14/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.5703 - accuracy: 0.5267 - val_loss: 1.5230 - val_accuracy: 0.5675
# Epoch 15/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.4484 - accuracy: 0.5684 - val_loss: 1.4092 - val_accuracy: 0.5910
# Epoch 16/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.3567 - accuracy: 0.5918 - val_loss: 1.3522 - val_accuracy: 0.6146
# Epoch 17/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.2532 - accuracy: 0.6206 - val_loss: 1.3086 - val_accuracy: 0.6211
# Epoch 18/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.1826 - accuracy: 0.6403 - val_loss: 1.2616 - val_accuracy: 0.6370
# Epoch 19/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.1063 - accuracy: 0.6602 - val_loss: 1.2085 - val_accuracy: 0.6501
# Epoch 20/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.0532 - accuracy: 0.6755 - val_loss: 1.1810 - val_accuracy: 0.6547
# Epoch 21/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.9828 - accuracy: 0.7024 - val_loss: 1.1825 - val_accuracy: 0.6528
# Epoch 22/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.9258 - accuracy: 0.7170 - val_loss: 1.1492 - val_accuracy: 0.6620
# Epoch 23/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8799 - accuracy: 0.7247 - val_loss: 1.1057 - val_accuracy: 0.6763
# Epoch 24/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8352 - accuracy: 0.7447 - val_loss: 1.0849 - val_accuracy: 0.6794
# Epoch 25/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7866 - accuracy: 0.7577 - val_loss: 1.0772 - val_accuracy: 0.6852
# Epoch 26/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7631 - accuracy: 0.7606 - val_loss: 1.0661 - val_accuracy: 0.6910
# Epoch 27/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.7207 - accuracy: 0.7760 - val_loss: 1.0644 - val_accuracy: 0.6879
# Epoch 28/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.6846 - accuracy: 0.7849 - val_loss: 1.0725 - val_accuracy: 0.6941
# Epoch 29/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6495 - accuracy: 0.7986 - val_loss: 1.0269 - val_accuracy: 0.7087
# Epoch 30/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6269 - accuracy: 0.8024 - val_loss: 1.0186 - val_accuracy: 0.7087
#
# Addestrando con filtri [16, 32, 64, 128] e tasso di apprendimento 1e-05
# Epoch 1/30
# 243/243 [==============================] - 1s 4ms/step - loss: 6.0772 - accuracy: 0.0360 - val_loss: 3.4370 - val_accuracy: 0.0467
# Epoch 2/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.6811 - accuracy: 0.0401 - val_loss: 3.3977 - val_accuracy: 0.0413
# Epoch 3/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.4777 - accuracy: 0.0393 - val_loss: 3.3875 - val_accuracy: 0.0428
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.4199 - accuracy: 0.0436 - val_loss: 3.3789 - val_accuracy: 0.0440
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3915 - accuracy: 0.0443 - val_loss: 3.3741 - val_accuracy: 0.0502
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3878 - accuracy: 0.0473 - val_loss: 3.3699 - val_accuracy: 0.0517
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3760 - accuracy: 0.0540 - val_loss: 3.3651 - val_accuracy: 0.0552
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3734 - accuracy: 0.0532 - val_loss: 3.3618 - val_accuracy: 0.0563
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3647 - accuracy: 0.0582 - val_loss: 3.3547 - val_accuracy: 0.0617
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3562 - accuracy: 0.0598 - val_loss: 3.3504 - val_accuracy: 0.0698
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3525 - accuracy: 0.0584 - val_loss: 3.3448 - val_accuracy: 0.0706
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3491 - accuracy: 0.0655 - val_loss: 3.3410 - val_accuracy: 0.0664
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3384 - accuracy: 0.0665 - val_loss: 3.3328 - val_accuracy: 0.0698
# Epoch 14/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3306 - accuracy: 0.0662 - val_loss: 3.3296 - val_accuracy: 0.0806
# Epoch 15/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3235 - accuracy: 0.0726 - val_loss: 3.3169 - val_accuracy: 0.0768
# Epoch 16/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.3167 - accuracy: 0.0755 - val_loss: 3.3069 - val_accuracy: 0.0837
# Epoch 17/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3049 - accuracy: 0.0765 - val_loss: 3.2953 - val_accuracy: 0.0941
# Epoch 18/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2979 - accuracy: 0.0831 - val_loss: 3.2897 - val_accuracy: 0.0930
# Epoch 19/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2848 - accuracy: 0.0893 - val_loss: 3.2756 - val_accuracy: 0.0980
# Epoch 20/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2736 - accuracy: 0.0871 - val_loss: 3.2587 - val_accuracy: 0.1065
# Epoch 21/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2613 - accuracy: 0.0945 - val_loss: 3.2496 - val_accuracy: 0.1073
# Epoch 22/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2504 - accuracy: 0.0937 - val_loss: 3.2319 - val_accuracy: 0.1173
# Epoch 23/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2366 - accuracy: 0.0961 - val_loss: 3.2193 - val_accuracy: 0.1103
# Epoch 24/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2186 - accuracy: 0.1122 - val_loss: 3.2044 - val_accuracy: 0.1204
# Epoch 25/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2105 - accuracy: 0.1048 - val_loss: 3.1840 - val_accuracy: 0.1231
# Epoch 26/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1950 - accuracy: 0.1093 - val_loss: 3.1696 - val_accuracy: 0.1265
# Epoch 27/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1714 - accuracy: 0.1180 - val_loss: 3.1488 - val_accuracy: 0.1400
# Epoch 28/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1528 - accuracy: 0.1197 - val_loss: 3.1263 - val_accuracy: 0.1466
# Epoch 29/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1357 - accuracy: 0.1249 - val_loss: 3.1086 - val_accuracy: 0.1539
# Epoch 30/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1230 - accuracy: 0.1216 - val_loss: 3.0906 - val_accuracy: 0.1489
#
# Addestrando con filtri [32, 64, 128, 256] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 1s 5ms/step - loss: 3.4821 - accuracy: 0.0357 - val_loss: 3.4016 - val_accuracy: 0.0355
# Epoch 2/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2891 - accuracy: 0.0659 - val_loss: 3.0292 - val_accuracy: 0.1080
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.7220 - accuracy: 0.2036 - val_loss: 2.1609 - val_accuracy: 0.3785
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.9286 - accuracy: 0.4274 - val_loss: 1.4890 - val_accuracy: 0.5590
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.4109 - accuracy: 0.5695 - val_loss: 1.2693 - val_accuracy: 0.6154
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.1236 - accuracy: 0.6649 - val_loss: 1.1085 - val_accuracy: 0.6725
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.9216 - accuracy: 0.7174 - val_loss: 1.0588 - val_accuracy: 0.6925
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7995 - accuracy: 0.7558 - val_loss: 1.0111 - val_accuracy: 0.7064
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6998 - accuracy: 0.7799 - val_loss: 1.0724 - val_accuracy: 0.7118
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6322 - accuracy: 0.8001 - val_loss: 1.0457 - val_accuracy: 0.7191
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5605 - accuracy: 0.8280 - val_loss: 1.1893 - val_accuracy: 0.7037
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4960 - accuracy: 0.8450 - val_loss: 1.2102 - val_accuracy: 0.7215
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4550 - accuracy: 0.8580 - val_loss: 1.2379 - val_accuracy: 0.7330
#
# Addestrando con filtri [32, 64, 128, 256] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 1s 5ms/step - loss: 3.5095 - accuracy: 0.0409 - val_loss: 3.3859 - val_accuracy: 0.0467
# Epoch 2/30
# 243/243 [==============================] - 1s 5ms/step - loss: 3.3633 - accuracy: 0.0598 - val_loss: 3.2744 - val_accuracy: 0.0829
# Epoch 3/30
# 243/243 [==============================] - 1s 5ms/step - loss: 3.1332 - accuracy: 0.1140 - val_loss: 2.9452 - val_accuracy: 0.1447
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.8147 - accuracy: 0.1885 - val_loss: 2.6391 - val_accuracy: 0.2357
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.5451 - accuracy: 0.2554 - val_loss: 2.3959 - val_accuracy: 0.3056
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.2304 - accuracy: 0.3463 - val_loss: 2.0686 - val_accuracy: 0.4140
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.9219 - accuracy: 0.4345 - val_loss: 1.7548 - val_accuracy: 0.4961
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.6505 - accuracy: 0.5116 - val_loss: 1.5601 - val_accuracy: 0.5571
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.4150 - accuracy: 0.5826 - val_loss: 1.3946 - val_accuracy: 0.5849
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.2228 - accuracy: 0.6321 - val_loss: 1.2863 - val_accuracy: 0.6231
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.0943 - accuracy: 0.6692 - val_loss: 1.1831 - val_accuracy: 0.6451
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.9598 - accuracy: 0.7119 - val_loss: 1.1292 - val_accuracy: 0.6705
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8730 - accuracy: 0.7285 - val_loss: 1.0672 - val_accuracy: 0.6775
# Epoch 14/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7850 - accuracy: 0.7649 - val_loss: 1.0241 - val_accuracy: 0.7006
# Epoch 15/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6940 - accuracy: 0.7887 - val_loss: 0.9914 - val_accuracy: 0.7133
# Epoch 16/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6273 - accuracy: 0.8101 - val_loss: 0.9944 - val_accuracy: 0.7176
# Epoch 17/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5735 - accuracy: 0.8264 - val_loss: 0.9794 - val_accuracy: 0.7184
# Epoch 18/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5209 - accuracy: 0.8432 - val_loss: 0.9918 - val_accuracy: 0.7234
# Epoch 19/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4704 - accuracy: 0.8512 - val_loss: 0.9906 - val_accuracy: 0.7307
# Epoch 20/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4393 - accuracy: 0.8669 - val_loss: 0.9989 - val_accuracy: 0.7265
# Epoch 21/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3987 - accuracy: 0.8723 - val_loss: 1.0027 - val_accuracy: 0.7330
# Epoch 22/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3644 - accuracy: 0.8843 - val_loss: 0.9882 - val_accuracy: 0.7415
#
# Addestrando con filtri [32, 64, 128, 256] e tasso di apprendimento 1e-05
# Epoch 1/30
# 243/243 [==============================] - 1s 4ms/step - loss: 4.1511 - accuracy: 0.0380 - val_loss: 3.4004 - val_accuracy: 0.0378
# Epoch 2/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.4542 - accuracy: 0.0405 - val_loss: 3.3760 - val_accuracy: 0.0482
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3949 - accuracy: 0.0506 - val_loss: 3.3657 - val_accuracy: 0.0517
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3741 - accuracy: 0.0545 - val_loss: 3.3591 - val_accuracy: 0.0529
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3571 - accuracy: 0.0598 - val_loss: 3.3485 - val_accuracy: 0.0548
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3420 - accuracy: 0.0682 - val_loss: 3.3314 - val_accuracy: 0.0721
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3286 - accuracy: 0.0680 - val_loss: 3.3210 - val_accuracy: 0.0640
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3138 - accuracy: 0.0771 - val_loss: 3.3072 - val_accuracy: 0.0822
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2945 - accuracy: 0.0889 - val_loss: 3.2846 - val_accuracy: 0.0914
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2700 - accuracy: 0.0884 - val_loss: 3.2580 - val_accuracy: 0.0999
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2438 - accuracy: 0.1032 - val_loss: 3.2341 - val_accuracy: 0.1100
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2080 - accuracy: 0.1080 - val_loss: 3.1995 - val_accuracy: 0.1204
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1911 - accuracy: 0.1084 - val_loss: 3.1717 - val_accuracy: 0.1273
# Epoch 14/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1538 - accuracy: 0.1253 - val_loss: 3.1317 - val_accuracy: 0.1404
# Epoch 15/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1118 - accuracy: 0.1320 - val_loss: 3.0944 - val_accuracy: 0.1512
# Epoch 16/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.0792 - accuracy: 0.1399 - val_loss: 3.0554 - val_accuracy: 0.1667
# Epoch 17/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.0374 - accuracy: 0.1506 - val_loss: 3.0139 - val_accuracy: 0.1728
# Epoch 18/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.9914 - accuracy: 0.1673 - val_loss: 2.9686 - val_accuracy: 0.1852
# Epoch 19/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.9396 - accuracy: 0.1769 - val_loss: 2.9236 - val_accuracy: 0.1875
# Epoch 20/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.9109 - accuracy: 0.1786 - val_loss: 2.8846 - val_accuracy: 0.2087
# Epoch 21/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.8672 - accuracy: 0.1876 - val_loss: 2.8452 - val_accuracy: 0.2199
# Epoch 22/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.8234 - accuracy: 0.2041 - val_loss: 2.8079 - val_accuracy: 0.2203
# Epoch 23/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.7911 - accuracy: 0.2091 - val_loss: 2.7690 - val_accuracy: 0.2288
# Epoch 24/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.7456 - accuracy: 0.2175 - val_loss: 2.7276 - val_accuracy: 0.2411
# Epoch 25/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.7134 - accuracy: 0.2253 - val_loss: 2.6959 - val_accuracy: 0.2523
# Epoch 26/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.6806 - accuracy: 0.2357 - val_loss: 2.6610 - val_accuracy: 0.2531
# Epoch 27/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.6419 - accuracy: 0.2478 - val_loss: 2.6290 - val_accuracy: 0.2677
# Epoch 28/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.5994 - accuracy: 0.2550 - val_loss: 2.5926 - val_accuracy: 0.2805
# Epoch 29/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.5732 - accuracy: 0.2652 - val_loss: 2.5600 - val_accuracy: 0.2963
# Epoch 30/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.5411 - accuracy: 0.2731 - val_loss: 2.5347 - val_accuracy: 0.2990
#
# Addestrando con filtri [64, 128, 256, 512] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 2s 8ms/step - loss: 3.5059 - accuracy: 0.0374 - val_loss: 3.3924 - val_accuracy: 0.0351
# Epoch 2/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.2230 - accuracy: 0.0786 - val_loss: 2.9547 - val_accuracy: 0.1416
# Epoch 3/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.6672 - accuracy: 0.2196 - val_loss: 2.2722 - val_accuracy: 0.3360
# Epoch 4/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.0116 - accuracy: 0.4059 - val_loss: 1.6738 - val_accuracy: 0.5166
# Epoch 5/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.5921 - accuracy: 0.5188 - val_loss: 1.5380 - val_accuracy: 0.5552
# Epoch 6/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.2743 - accuracy: 0.6188 - val_loss: 1.4197 - val_accuracy: 0.5934
# Epoch 7/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.0982 - accuracy: 0.6621 - val_loss: 1.4663 - val_accuracy: 0.5864
# Epoch 8/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.9734 - accuracy: 0.7058 - val_loss: 1.5464 - val_accuracy: 0.5787
# Epoch 9/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.8404 - accuracy: 0.7429 - val_loss: 1.5049 - val_accuracy: 0.6034
# Epoch 10/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.7378 - accuracy: 0.7718 - val_loss: 1.4610 - val_accuracy: 0.6181
# Epoch 11/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.6632 - accuracy: 0.7942 - val_loss: 1.4127 - val_accuracy: 0.6539
# Epoch 12/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.5937 - accuracy: 0.8133 - val_loss: 1.5538 - val_accuracy: 0.6532
# Epoch 13/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.5593 - accuracy: 0.8213 - val_loss: 1.5466 - val_accuracy: 0.6493
# Epoch 14/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.4960 - accuracy: 0.8512 - val_loss: 1.5383 - val_accuracy: 0.6532
# Epoch 15/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.4588 - accuracy: 0.8586 - val_loss: 1.6277 - val_accuracy: 0.6593
# Epoch 16/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.4507 - accuracy: 0.8579 - val_loss: 1.7526 - val_accuracy: 0.6393
#
# Addestrando con filtri [64, 128, 256, 512] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.5122 - accuracy: 0.0399 - val_loss: 3.3912 - val_accuracy: 0.0328
# Epoch 2/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.3705 - accuracy: 0.0555 - val_loss: 3.2705 - val_accuracy: 0.0802
# Epoch 3/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.0217 - accuracy: 0.1327 - val_loss: 2.7239 - val_accuracy: 0.2114
# Epoch 4/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.5593 - accuracy: 0.2528 - val_loss: 2.1851 - val_accuracy: 0.3742
# Epoch 5/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.9941 - accuracy: 0.4090 - val_loss: 1.6667 - val_accuracy: 0.5039
# Epoch 6/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.5232 - accuracy: 0.5379 - val_loss: 1.3246 - val_accuracy: 0.6165
# Epoch 7/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.1826 - accuracy: 0.6448 - val_loss: 1.1690 - val_accuracy: 0.6566
# Epoch 8/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.9639 - accuracy: 0.7122 - val_loss: 1.0775 - val_accuracy: 0.6879
# Epoch 9/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.8058 - accuracy: 0.7521 - val_loss: 1.0313 - val_accuracy: 0.6898
# Epoch 10/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.6658 - accuracy: 0.7963 - val_loss: 0.9803 - val_accuracy: 0.7095
# Epoch 11/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.5588 - accuracy: 0.8269 - val_loss: 0.8936 - val_accuracy: 0.7465
# Epoch 12/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.4782 - accuracy: 0.8550 - val_loss: 0.9002 - val_accuracy: 0.7554
# Epoch 13/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.4142 - accuracy: 0.8744 - val_loss: 0.9297 - val_accuracy: 0.7566
# Epoch 14/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.3594 - accuracy: 0.8879 - val_loss: 0.9921 - val_accuracy: 0.7350
# Epoch 15/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.3066 - accuracy: 0.9084 - val_loss: 0.9597 - val_accuracy: 0.7581
# Epoch 16/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.2778 - accuracy: 0.9126 - val_loss: 1.0088 - val_accuracy: 0.7523
#
# Addestrando con filtri [64, 128, 256, 512] e tasso di apprendimento 1e-05
# Epoch 1/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.6919 - accuracy: 0.0378 - val_loss: 3.3900 - val_accuracy: 0.0432
# Epoch 2/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.4099 - accuracy: 0.0387 - val_loss: 3.3669 - val_accuracy: 0.0583
# Epoch 3/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.3673 - accuracy: 0.0581 - val_loss: 3.3485 - val_accuracy: 0.0706
# Epoch 4/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.3432 - accuracy: 0.0665 - val_loss: 3.3223 - val_accuracy: 0.0822
# Epoch 5/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.3086 - accuracy: 0.0844 - val_loss: 3.2875 - val_accuracy: 0.0926
# Epoch 6/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.2628 - accuracy: 0.0995 - val_loss: 3.2328 - val_accuracy: 0.1092
# Epoch 7/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.1947 - accuracy: 0.1142 - val_loss: 3.1512 - val_accuracy: 0.1250
# Epoch 8/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.1103 - accuracy: 0.1351 - val_loss: 3.0551 - val_accuracy: 0.1474
# Epoch 9/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.0211 - accuracy: 0.1510 - val_loss: 2.9635 - val_accuracy: 0.1705
# Epoch 10/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.9254 - accuracy: 0.1786 - val_loss: 2.8715 - val_accuracy: 0.1902
# Epoch 11/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.8403 - accuracy: 0.2006 - val_loss: 2.7945 - val_accuracy: 0.2164
# Epoch 12/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.7603 - accuracy: 0.2138 - val_loss: 2.7207 - val_accuracy: 0.2257
# Epoch 13/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.6781 - accuracy: 0.2308 - val_loss: 2.6495 - val_accuracy: 0.2473
# Epoch 14/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.5934 - accuracy: 0.2644 - val_loss: 2.5633 - val_accuracy: 0.2805
# Epoch 15/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.5228 - accuracy: 0.2777 - val_loss: 2.4964 - val_accuracy: 0.3017
# Epoch 16/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.4564 - accuracy: 0.3003 - val_loss: 2.4405 - val_accuracy: 0.3167
# Epoch 17/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.3987 - accuracy: 0.3112 - val_loss: 2.3862 - val_accuracy: 0.3395
# Epoch 18/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.3304 - accuracy: 0.3316 - val_loss: 2.3095 - val_accuracy: 0.3619
# Epoch 19/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.2587 - accuracy: 0.3512 - val_loss: 2.2577 - val_accuracy: 0.3750
# Epoch 20/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.1813 - accuracy: 0.3727 - val_loss: 2.1981 - val_accuracy: 0.3900
# Epoch 21/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.1374 - accuracy: 0.3816 - val_loss: 2.1398 - val_accuracy: 0.4136
# Epoch 22/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.0663 - accuracy: 0.4031 - val_loss: 2.0969 - val_accuracy: 0.4171
# Epoch 23/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.0179 - accuracy: 0.4120 - val_loss: 2.0353 - val_accuracy: 0.4394
# Epoch 24/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.9472 - accuracy: 0.4363 - val_loss: 1.9880 - val_accuracy: 0.4556
# Epoch 25/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.8911 - accuracy: 0.4567 - val_loss: 1.9577 - val_accuracy: 0.4529
# Epoch 26/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.8426 - accuracy: 0.4682 - val_loss: 1.9024 - val_accuracy: 0.4730
# Epoch 27/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.7910 - accuracy: 0.4817 - val_loss: 1.8599 - val_accuracy: 0.4873
# Epoch 28/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.7354 - accuracy: 0.4979 - val_loss: 1.8215 - val_accuracy: 0.4988
# Epoch 29/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.6840 - accuracy: 0.5110 - val_loss: 1.7957 - val_accuracy: 0.5046
# Epoch 30/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.6459 - accuracy: 0.5179 - val_loss: 1.7568 - val_accuracy: 0.5193
#
# Tempo totale trascorso: 4 minuti e 2 secondi

# %% [markdown]
# Il tempo necessario per la ricerca dei migliori iperparametri è stata di **4 minuti**.

# %%
plot_models(path="model_tuning/noise/adam/filterbanks", show="accuracy")
plot_models(path="model_tuning/noise/adam/filterbanks", show="loss")

# %% [markdown]
# Dai grafici emerge che la combinazione più performante è composta da **XX filtri di partenza** e un **tasso di apprendimento di XX**, poiché ritarda maggiormente l'overfitting. Altre combinazioni, come **XX filtri di partenza** e un **tasso di apprendimento di 1e-5**, mostrano buone prestazioni ma anche un inizio di overfitting, evidenziato dallo distaccamento tra la perdita di addestramento e quella di validazione.
#
# Procediamo quindi con l'addestramento del modello con **XX filtri di partenza** e un **tasso di apprendimento di XX**. Come di consueto, salviamo i risultati in un file `keras` e la cronologia (history) in un file `csv`. Infine, convertiamo il file in formato `onnx`.

# %%
for audio, label in fb_mixed_train_ds:
    tuned_improved_basic_model = get_improved_basic_model(audio.shape[1:])
    
tuned_improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), metrics=["accuracy"])

tuned_improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/noise/adam/filterbanks/tuned_improved_basic_model_fb.keras", save_best_only=True, monitor="val_loss")]
tuned_improved_history = tuned_improved_basic_model.fit(fb_mixed_train_ds, epochs=100, validation_data=fb_mixed_val_ds, callbacks=tuned_improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 2s 5ms/step - loss: 3.5624 - accuracy: 0.0389 - val_loss: 3.3950 - val_accuracy: 0.0285
# Epoch 2/100
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3945 - accuracy: 0.0415 - val_loss: 3.3848 - val_accuracy: 0.0494
# Epoch 3/100
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3624 - accuracy: 0.0544 - val_loss: 3.2647 - val_accuracy: 0.0829
# Epoch 4/100
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1025 - accuracy: 0.1169 - val_loss: 2.8981 - val_accuracy: 0.1547
# Epoch 5/100
# 243/243 [==============================] - 1s 4ms/step - loss: 2.8053 - accuracy: 0.1871 - val_loss: 2.5793 - val_accuracy: 0.2566
# Epoch 6/100
# 243/243 [==============================] - 1s 4ms/step - loss: 2.5263 - accuracy: 0.2613 - val_loss: 2.3511 - val_accuracy: 0.3090
# Epoch 7/100
# 243/243 [==============================] - 1s 4ms/step - loss: 2.2643 - accuracy: 0.3387 - val_loss: 2.0579 - val_accuracy: 0.4062
# Epoch 8/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.9872 - accuracy: 0.4138 - val_loss: 1.8426 - val_accuracy: 0.4641
# Epoch 9/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.7258 - accuracy: 0.4889 - val_loss: 1.6681 - val_accuracy: 0.5143
# Epoch 10/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.5118 - accuracy: 0.5486 - val_loss: 1.4798 - val_accuracy: 0.5667
# Epoch 11/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.3107 - accuracy: 0.6086 - val_loss: 1.3292 - val_accuracy: 0.6146
# Epoch 12/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.1567 - accuracy: 0.6523 - val_loss: 1.2574 - val_accuracy: 0.6196
# Epoch 13/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.0256 - accuracy: 0.6874 - val_loss: 1.2131 - val_accuracy: 0.6416
# Epoch 14/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.9140 - accuracy: 0.7260 - val_loss: 1.1486 - val_accuracy: 0.6559
# Epoch 15/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8346 - accuracy: 0.7464 - val_loss: 1.1043 - val_accuracy: 0.6698
# Epoch 16/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7600 - accuracy: 0.7655 - val_loss: 1.0719 - val_accuracy: 0.6821
# Epoch 17/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6658 - accuracy: 0.7941 - val_loss: 1.0490 - val_accuracy: 0.7037
# Epoch 18/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6025 - accuracy: 0.8129 - val_loss: 1.0198 - val_accuracy: 0.7079
# Epoch 19/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5580 - accuracy: 0.8280 - val_loss: 0.9876 - val_accuracy: 0.7145
# Epoch 20/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5052 - accuracy: 0.8409 - val_loss: 1.0147 - val_accuracy: 0.7076
# Epoch 21/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4505 - accuracy: 0.8615 - val_loss: 1.0217 - val_accuracy: 0.7118
# Epoch 22/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4191 - accuracy: 0.8692 - val_loss: 1.0295 - val_accuracy: 0.7072
# Epoch 23/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3859 - accuracy: 0.8811 - val_loss: 1.0865 - val_accuracy: 0.7083
# Epoch 24/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3417 - accuracy: 0.8937 - val_loss: 1.0598 - val_accuracy: 0.7245
# Epoch 25/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3241 - accuracy: 0.8947 - val_loss: 1.0454 - val_accuracy: 0.7218
# Epoch 26/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2789 - accuracy: 0.9147 - val_loss: 1.1188 - val_accuracy: 0.7242
# Epoch 27/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2686 - accuracy: 0.9139 - val_loss: 1.0667 - val_accuracy: 0.7234
# Epoch 28/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2411 - accuracy: 0.9235 - val_loss: 1.0817 - val_accuracy: 0.7319
# Epoch 29/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2284 - accuracy: 0.9298 - val_loss: 1.0827 - val_accuracy: 0.7211
# Epoch 30/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2204 - accuracy: 0.9291 - val_loss: 1.0729 - val_accuracy: 0.7299
# Epoch 31/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1912 - accuracy: 0.9401 - val_loss: 1.0538 - val_accuracy: 0.7400
# Epoch 32/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1790 - accuracy: 0.9434 - val_loss: 1.1786 - val_accuracy: 0.7265
# Epoch 33/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1815 - accuracy: 0.9394 - val_loss: 1.1375 - val_accuracy: 0.7315
# Epoch 34/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1620 - accuracy: 0.9500 - val_loss: 1.1869 - val_accuracy: 0.7191
# Epoch 35/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1568 - accuracy: 0.9495 - val_loss: 1.1134 - val_accuracy: 0.7419
# Epoch 36/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1480 - accuracy: 0.9550 - val_loss: 1.1494 - val_accuracy: 0.7319
# Epoch 37/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1377 - accuracy: 0.9540 - val_loss: 1.1506 - val_accuracy: 0.7346
# Epoch 38/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1202 - accuracy: 0.9608 - val_loss: 1.1672 - val_accuracy: 0.7357
# Epoch 39/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1167 - accuracy: 0.9635 - val_loss: 1.1618 - val_accuracy: 0.7434
# Epoch 40/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1238 - accuracy: 0.9621 - val_loss: 1.1875 - val_accuracy: 0.7280
# Epoch 41/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1132 - accuracy: 0.9655 - val_loss: 1.2904 - val_accuracy: 0.7269
# Epoch 42/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1106 - accuracy: 0.9674 - val_loss: 1.2453 - val_accuracy: 0.7415
# Epoch 43/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1021 - accuracy: 0.9691 - val_loss: 1.2181 - val_accuracy: 0.7396
# Epoch 44/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0832 - accuracy: 0.9745 - val_loss: 1.3163 - val_accuracy: 0.7380
# Epoch 45/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0846 - accuracy: 0.9740 - val_loss: 1.2621 - val_accuracy: 0.7334
# Epoch 46/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0956 - accuracy: 0.9688 - val_loss: 1.2622 - val_accuracy: 0.7465
# Epoch 47/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0931 - accuracy: 0.9705 - val_loss: 1.2635 - val_accuracy: 0.7400
# Epoch 48/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0906 - accuracy: 0.9731 - val_loss: 1.3283 - val_accuracy: 0.7307
# Epoch 49/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0796 - accuracy: 0.9764 - val_loss: 1.2534 - val_accuracy: 0.7527
# Epoch 50/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0768 - accuracy: 0.9762 - val_loss: 1.1661 - val_accuracy: 0.7585
# Epoch 51/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0711 - accuracy: 0.9781 - val_loss: 1.2117 - val_accuracy: 0.7519
# Epoch 52/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0668 - accuracy: 0.9787 - val_loss: 1.3722 - val_accuracy: 0.7411
# Epoch 53/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0590 - accuracy: 0.9817 - val_loss: 1.2476 - val_accuracy: 0.7569
# Epoch 54/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0708 - accuracy: 0.9793 - val_loss: 1.2652 - val_accuracy: 0.7500
# Epoch 55/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0595 - accuracy: 0.9829 - val_loss: 1.2054 - val_accuracy: 0.7612
# Epoch 56/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0541 - accuracy: 0.9838 - val_loss: 1.2785 - val_accuracy: 0.7596
# Epoch 57/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0538 - accuracy: 0.9834 - val_loss: 1.3027 - val_accuracy: 0.7469
# Epoch 58/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0601 - accuracy: 0.9808 - val_loss: 1.2824 - val_accuracy: 0.7593
# Epoch 59/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0658 - accuracy: 0.9794 - val_loss: 1.4139 - val_accuracy: 0.7373
# Epoch 60/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0649 - accuracy: 0.9799 - val_loss: 1.2782 - val_accuracy: 0.7654
# Epoch 61/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0542 - accuracy: 0.9839 - val_loss: 1.3869 - val_accuracy: 0.7465
# Epoch 62/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0504 - accuracy: 0.9844 - val_loss: 1.2983 - val_accuracy: 0.7627
# Epoch 63/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0475 - accuracy: 0.9856 - val_loss: 1.2855 - val_accuracy: 0.7627
# Epoch 64/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0570 - accuracy: 0.9826 - val_loss: 1.3244 - val_accuracy: 0.7581
# Epoch 65/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0625 - accuracy: 0.9813 - val_loss: 1.2879 - val_accuracy: 0.7685
# Epoch 66/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0405 - accuracy: 0.9887 - val_loss: 1.2555 - val_accuracy: 0.7670
# Epoch 67/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0498 - accuracy: 0.9853 - val_loss: 1.2958 - val_accuracy: 0.7542
# Epoch 68/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0508 - accuracy: 0.9834 - val_loss: 1.2300 - val_accuracy: 0.7635
# Epoch 69/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0446 - accuracy: 0.9852 - val_loss: 1.3235 - val_accuracy: 0.7577
# Epoch 70/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0461 - accuracy: 0.9851 - val_loss: 1.2749 - val_accuracy: 0.7685
# Epoch 71/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0436 - accuracy: 0.9858 - val_loss: 1.3493 - val_accuracy: 0.7620
# Epoch 72/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0481 - accuracy: 0.9857 - val_loss: 1.3550 - val_accuracy: 0.7573
# Epoch 73/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0419 - accuracy: 0.9876 - val_loss: 1.2883 - val_accuracy: 0.7608
# Epoch 74/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0413 - accuracy: 0.9866 - val_loss: 1.2840 - val_accuracy: 0.7666
# Epoch 75/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0381 - accuracy: 0.9884 - val_loss: 1.3103 - val_accuracy: 0.7650
# Epoch 76/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0499 - accuracy: 0.9851 - val_loss: 1.2824 - val_accuracy: 0.7662
# Epoch 77/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0388 - accuracy: 0.9893 - val_loss: 1.2717 - val_accuracy: 0.7666
# Epoch 78/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0460 - accuracy: 0.9851 - val_loss: 1.2685 - val_accuracy: 0.7677
# Epoch 79/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0401 - accuracy: 0.9885 - val_loss: 1.3159 - val_accuracy: 0.7554
# Epoch 80/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0343 - accuracy: 0.9907 - val_loss: 1.3446 - val_accuracy: 0.7816
# Epoch 81/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0360 - accuracy: 0.9879 - val_loss: 1.2639 - val_accuracy: 0.7697
# Epoch 82/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0290 - accuracy: 0.9901 - val_loss: 1.3284 - val_accuracy: 0.7739
# Epoch 83/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0356 - accuracy: 0.9890 - val_loss: 1.3511 - val_accuracy: 0.7650
# Epoch 84/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0399 - accuracy: 0.9887 - val_loss: 1.3603 - val_accuracy: 0.7701
# Epoch 85/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0341 - accuracy: 0.9889 - val_loss: 1.4123 - val_accuracy: 0.7585
# Epoch 86/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0325 - accuracy: 0.9892 - val_loss: 1.3749 - val_accuracy: 0.7693
# Epoch 87/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0311 - accuracy: 0.9892 - val_loss: 1.4579 - val_accuracy: 0.7635
# Epoch 88/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0441 - accuracy: 0.9858 - val_loss: 1.3236 - val_accuracy: 0.7677
# Epoch 89/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0361 - accuracy: 0.9883 - val_loss: 1.2569 - val_accuracy: 0.7809
# Epoch 90/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0258 - accuracy: 0.9918 - val_loss: 1.3368 - val_accuracy: 0.7774
# Epoch 91/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0274 - accuracy: 0.9923 - val_loss: 1.4158 - val_accuracy: 0.7662
# Epoch 92/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0305 - accuracy: 0.9896 - val_loss: 1.3526 - val_accuracy: 0.7758
# Epoch 93/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0343 - accuracy: 0.9897 - val_loss: 1.4177 - val_accuracy: 0.7751
# Epoch 94/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0320 - accuracy: 0.9901 - val_loss: 1.3988 - val_accuracy: 0.7731
# Epoch 95/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0333 - accuracy: 0.9898 - val_loss: 1.3792 - val_accuracy: 0.7755
# Epoch 96/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0281 - accuracy: 0.9910 - val_loss: 1.4416 - val_accuracy: 0.7755
# Epoch 97/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0256 - accuracy: 0.9914 - val_loss: 1.3959 - val_accuracy: 0.7720
# Epoch 98/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0314 - accuracy: 0.9902 - val_loss: 1.3791 - val_accuracy: 0.7708
# Epoch 99/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0215 - accuracy: 0.9939 - val_loss: 1.4853 - val_accuracy: 0.7785
# Epoch 100/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0227 - accuracy: 0.9947 - val_loss: 1.3338 - val_accuracy: 0.7708

# %%
tuned_improved_history_df = convert_history_to_csv(tuned_improved_history)
tuned_improved_history_df.to_csv("model_histories/noise/adam/filterbanks/tuned_improved_history_fb.csv")

convert_model_to_onnx("bestmodels/noise/adam/filterbanks/tuned_improved_basic_model_fb.keras", (98, 40, 1))

# %%
create_train_val_plot(tuned_improved_history.history)

# %%
tuned_improved_best_model = tf.keras.models.load_model("bestmodels/noise/adam/filterbanks/tuned_improved_basic_model_fb.keras")
test_loss, test_acc = tuned_improved_best_model.evaluate(fb_mixed_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 3ms/step - loss: 0.9975 - accuracy: 0.7133
# Accuratezza: 0.713

# %%
evaluate_onnx_model("bestmodels/noise/adam/filterbanks/tuned_improved_basic_model_fb.onnx", fb_mixed_test_ds)
# Out:
# Accuratezza: 0.713

# %% [markdown]
# AGGIUNGERE COMMENTO SU COME SI E' AGGIORNATO. L'accuratezza è attualmente **XX%**.

# %%
for audio, label in fb_mixed_test_ds:
    create_distribution_plot(tuned_improved_best_model, audio, label)
    break

# %% [markdown]
# ### Miglioramenti all'architettura del modello
# Procediamo quindi con la fase corrispettiva al notebook di riferimento.

# %%
def bp_basic_model():
    # input e pre processamento
    inputs = tf.keras.Input(shape=(98, 40, 1))
    
    x = residual_block(inputs, 32, pooling=True)
    x = residual_block(x, 64, pooling=True)
    x = residual_block(x, 128, pooling=True)
    x = residual_block(x, 256, pooling=True)
    x = residual_block(x, 256, pooling=False)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Livelli per la classificazione
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
bp_basic_model = bp_basic_model()
bp_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

bp_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/noise/adam/filterbanks/bp_basic_model_fb.keras", save_best_only=True, monitor="val_loss")]
bp_model_history = bp_basic_model.fit(fb_mixed_train_ds, epochs=100, validation_data=fb_mixed_val_ds, callbacks=bp_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 3s 7ms/step - loss: 5.1627 - accuracy: 0.0415 - val_loss: 3.6774 - val_accuracy: 0.0355
# Epoch 2/100
# 243/243 [==============================] - 2s 7ms/step - loss: 3.4074 - accuracy: 0.0769 - val_loss: 3.3301 - val_accuracy: 0.0841
# Epoch 3/100
# 243/243 [==============================] - 2s 6ms/step - loss: 3.0465 - accuracy: 0.1396 - val_loss: 3.4346 - val_accuracy: 0.1250
# Epoch 4/100
# 243/243 [==============================] - 2s 7ms/step - loss: 2.7249 - accuracy: 0.2133 - val_loss: 3.0005 - val_accuracy: 0.1794
# Epoch 5/100
# 243/243 [==============================] - 2s 7ms/step - loss: 2.4236 - accuracy: 0.2911 - val_loss: 2.3931 - val_accuracy: 0.3090
# Epoch 6/100
# 243/243 [==============================] - 2s 7ms/step - loss: 2.1290 - accuracy: 0.3742 - val_loss: 2.5015 - val_accuracy: 0.3144
# Epoch 7/100
# 243/243 [==============================] - 2s 7ms/step - loss: 1.8748 - accuracy: 0.4495 - val_loss: 2.0495 - val_accuracy: 0.3881
# Epoch 8/100
# 243/243 [==============================] - 2s 7ms/step - loss: 1.6597 - accuracy: 0.5059 - val_loss: 2.4256 - val_accuracy: 0.3569
# Epoch 9/100
# 243/243 [==============================] - 2s 7ms/step - loss: 1.4992 - accuracy: 0.5602 - val_loss: 1.8540 - val_accuracy: 0.4437
# Epoch 10/100
# 243/243 [==============================] - 2s 7ms/step - loss: 1.3434 - accuracy: 0.5966 - val_loss: 1.8643 - val_accuracy: 0.4468
# Epoch 11/100
# 243/243 [==============================] - 2s 7ms/step - loss: 1.2140 - accuracy: 0.6429 - val_loss: 1.6223 - val_accuracy: 0.5297
# Epoch 12/100
# 243/243 [==============================] - 2s 7ms/step - loss: 1.1184 - accuracy: 0.6687 - val_loss: 2.0285 - val_accuracy: 0.4672
# Epoch 13/100
# 243/243 [==============================] - 2s 7ms/step - loss: 1.0251 - accuracy: 0.7004 - val_loss: 1.6785 - val_accuracy: 0.5235
# Epoch 14/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.9506 - accuracy: 0.7139 - val_loss: 1.3637 - val_accuracy: 0.5914
# Epoch 15/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.8737 - accuracy: 0.7434 - val_loss: 1.6031 - val_accuracy: 0.5343
# Epoch 16/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.8010 - accuracy: 0.7680 - val_loss: 1.8429 - val_accuracy: 0.4988
# Epoch 17/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.7469 - accuracy: 0.7729 - val_loss: 1.6459 - val_accuracy: 0.5139
# Epoch 18/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.6915 - accuracy: 0.7914 - val_loss: 1.7627 - val_accuracy: 0.5421
# Epoch 19/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.6648 - accuracy: 0.8017 - val_loss: 1.5014 - val_accuracy: 0.5806
# Epoch 20/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.5911 - accuracy: 0.8179 - val_loss: 1.9561 - val_accuracy: 0.5285
# Epoch 21/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.5635 - accuracy: 0.8278 - val_loss: 1.9866 - val_accuracy: 0.5548
# Epoch 22/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.5138 - accuracy: 0.8476 - val_loss: 2.0727 - val_accuracy: 0.5050
# Epoch 23/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.4762 - accuracy: 0.8549 - val_loss: 3.1558 - val_accuracy: 0.4348
# Epoch 24/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.4228 - accuracy: 0.8778 - val_loss: 2.3527 - val_accuracy: 0.4927
# Epoch 25/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.4017 - accuracy: 0.8791 - val_loss: 1.4939 - val_accuracy: 0.6292
# Epoch 26/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.4068 - accuracy: 0.8778 - val_loss: 2.0137 - val_accuracy: 0.5424
# Epoch 27/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.3602 - accuracy: 0.8905 - val_loss: 2.9622 - val_accuracy: 0.4676
# Epoch 28/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.3479 - accuracy: 0.8950 - val_loss: 2.8043 - val_accuracy: 0.4853
# Epoch 29/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.3115 - accuracy: 0.9077 - val_loss: 2.6212 - val_accuracy: 0.5081
# Epoch 30/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.3133 - accuracy: 0.9066 - val_loss: 2.1213 - val_accuracy: 0.5745
# Epoch 31/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.2894 - accuracy: 0.9117 - val_loss: 1.8129 - val_accuracy: 0.6084
# Epoch 32/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.2579 - accuracy: 0.9260 - val_loss: 2.7998 - val_accuracy: 0.4865
# Epoch 33/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.2708 - accuracy: 0.9198 - val_loss: 1.8513 - val_accuracy: 0.6057
# Epoch 34/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.2497 - accuracy: 0.9263 - val_loss: 2.5826 - val_accuracy: 0.4919
# Epoch 35/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.2425 - accuracy: 0.9276 - val_loss: 3.2544 - val_accuracy: 0.4707
# Epoch 36/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.2208 - accuracy: 0.9334 - val_loss: 2.2006 - val_accuracy: 0.5741
# Epoch 37/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.2423 - accuracy: 0.9259 - val_loss: 1.6659 - val_accuracy: 0.6227
# Epoch 38/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.2492 - accuracy: 0.9227 - val_loss: 3.9159 - val_accuracy: 0.4317
# Epoch 39/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1981 - accuracy: 0.9416 - val_loss: 2.6855 - val_accuracy: 0.5660
# Epoch 40/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.2055 - accuracy: 0.9376 - val_loss: 2.9530 - val_accuracy: 0.5085
# Epoch 41/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.2159 - accuracy: 0.9358 - val_loss: 2.8486 - val_accuracy: 0.5359
# Epoch 42/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1978 - accuracy: 0.9415 - val_loss: 3.3136 - val_accuracy: 0.4950
# Epoch 43/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1618 - accuracy: 0.9503 - val_loss: 1.5706 - val_accuracy: 0.6628
# Epoch 44/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1601 - accuracy: 0.9506 - val_loss: 3.9293 - val_accuracy: 0.4877
# Epoch 45/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1652 - accuracy: 0.9492 - val_loss: 2.4256 - val_accuracy: 0.5710
# Epoch 46/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1772 - accuracy: 0.9468 - val_loss: 2.6020 - val_accuracy: 0.5833
# Epoch 47/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1827 - accuracy: 0.9402 - val_loss: 1.9941 - val_accuracy: 0.6277
# Epoch 48/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1582 - accuracy: 0.9506 - val_loss: 1.8554 - val_accuracy: 0.6262
# Epoch 49/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1471 - accuracy: 0.9544 - val_loss: 3.8065 - val_accuracy: 0.4931
# Epoch 50/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1291 - accuracy: 0.9588 - val_loss: 3.6649 - val_accuracy: 0.5278
# Epoch 51/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1349 - accuracy: 0.9571 - val_loss: 2.4966 - val_accuracy: 0.5860
# Epoch 52/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1467 - accuracy: 0.9550 - val_loss: 5.8034 - val_accuracy: 0.4093
# Epoch 53/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1490 - accuracy: 0.9515 - val_loss: 2.8820 - val_accuracy: 0.5571
# Epoch 54/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1371 - accuracy: 0.9601 - val_loss: 4.6110 - val_accuracy: 0.4734
# Epoch 55/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1377 - accuracy: 0.9571 - val_loss: 3.4402 - val_accuracy: 0.4954
# Epoch 56/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1415 - accuracy: 0.9552 - val_loss: 2.8720 - val_accuracy: 0.5482
# Epoch 57/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1358 - accuracy: 0.9564 - val_loss: 2.1772 - val_accuracy: 0.6404
# Epoch 58/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1049 - accuracy: 0.9691 - val_loss: 1.7334 - val_accuracy: 0.6644
# Epoch 59/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1107 - accuracy: 0.9638 - val_loss: 2.0056 - val_accuracy: 0.6323
# Epoch 60/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1225 - accuracy: 0.9610 - val_loss: 2.1959 - val_accuracy: 0.6289
# Epoch 61/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1338 - accuracy: 0.9559 - val_loss: 4.8484 - val_accuracy: 0.4263
# Epoch 62/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1448 - accuracy: 0.9539 - val_loss: 3.8406 - val_accuracy: 0.5058
# Epoch 63/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1243 - accuracy: 0.9577 - val_loss: 2.6822 - val_accuracy: 0.5926
# Epoch 64/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1097 - accuracy: 0.9657 - val_loss: 1.7216 - val_accuracy: 0.6686
# Epoch 65/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1017 - accuracy: 0.9686 - val_loss: 2.0197 - val_accuracy: 0.6447
# Epoch 66/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0995 - accuracy: 0.9705 - val_loss: 2.2447 - val_accuracy: 0.6184
# Epoch 67/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1372 - accuracy: 0.9564 - val_loss: 1.9346 - val_accuracy: 0.6597
# Epoch 68/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1227 - accuracy: 0.9603 - val_loss: 1.8504 - val_accuracy: 0.6582
# Epoch 69/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0946 - accuracy: 0.9722 - val_loss: 2.4078 - val_accuracy: 0.6150
# Epoch 70/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0953 - accuracy: 0.9705 - val_loss: 2.6420 - val_accuracy: 0.6161
# Epoch 71/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1001 - accuracy: 0.9678 - val_loss: 1.9313 - val_accuracy: 0.6678
# Epoch 72/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1324 - accuracy: 0.9620 - val_loss: 2.1551 - val_accuracy: 0.6130
# Epoch 73/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1248 - accuracy: 0.9595 - val_loss: 3.0943 - val_accuracy: 0.5718
# Epoch 74/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0895 - accuracy: 0.9697 - val_loss: 1.9720 - val_accuracy: 0.6489
# Epoch 75/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0777 - accuracy: 0.9759 - val_loss: 2.1116 - val_accuracy: 0.6497
# Epoch 76/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0918 - accuracy: 0.9723 - val_loss: 2.4329 - val_accuracy: 0.6296
# Epoch 77/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1087 - accuracy: 0.9644 - val_loss: 2.2375 - val_accuracy: 0.6350
# Epoch 78/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.1015 - accuracy: 0.9687 - val_loss: 1.7162 - val_accuracy: 0.6879
# Epoch 79/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0849 - accuracy: 0.9729 - val_loss: 1.9419 - val_accuracy: 0.6605
# Epoch 80/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0858 - accuracy: 0.9720 - val_loss: 1.9524 - val_accuracy: 0.6655
# Epoch 81/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1070 - accuracy: 0.9628 - val_loss: 2.6772 - val_accuracy: 0.5995
# Epoch 82/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1100 - accuracy: 0.9631 - val_loss: 2.4298 - val_accuracy: 0.6238
# Epoch 83/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1091 - accuracy: 0.9656 - val_loss: 2.0316 - val_accuracy: 0.6323
# Epoch 84/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0854 - accuracy: 0.9731 - val_loss: 2.6133 - val_accuracy: 0.6096
# Epoch 85/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0929 - accuracy: 0.9697 - val_loss: 2.0408 - val_accuracy: 0.6327
# Epoch 86/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0845 - accuracy: 0.9729 - val_loss: 2.0584 - val_accuracy: 0.6590
# Epoch 87/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0600 - accuracy: 0.9803 - val_loss: 2.2653 - val_accuracy: 0.6431
# Epoch 88/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0631 - accuracy: 0.9795 - val_loss: 1.8792 - val_accuracy: 0.6636
# Epoch 89/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0820 - accuracy: 0.9728 - val_loss: 1.9819 - val_accuracy: 0.6659
# Epoch 90/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0992 - accuracy: 0.9697 - val_loss: 2.4411 - val_accuracy: 0.6173
# Epoch 91/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0886 - accuracy: 0.9701 - val_loss: 2.6670 - val_accuracy: 0.5883
# Epoch 92/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0727 - accuracy: 0.9771 - val_loss: 3.6555 - val_accuracy: 0.5285
# Epoch 93/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0788 - accuracy: 0.9738 - val_loss: 2.3534 - val_accuracy: 0.6235
# Epoch 94/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0994 - accuracy: 0.9696 - val_loss: 2.3467 - val_accuracy: 0.6408
# Epoch 95/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0944 - accuracy: 0.9700 - val_loss: 3.0915 - val_accuracy: 0.5660
# Epoch 96/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0786 - accuracy: 0.9751 - val_loss: 1.9723 - val_accuracy: 0.6613
# Epoch 97/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0653 - accuracy: 0.9802 - val_loss: 2.0866 - val_accuracy: 0.6539
# Epoch 98/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0716 - accuracy: 0.9763 - val_loss: 3.1604 - val_accuracy: 0.5841
# Epoch 99/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1025 - accuracy: 0.9662 - val_loss: 2.0757 - val_accuracy: 0.6732
# Epoch 100/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0841 - accuracy: 0.9727 - val_loss: 1.9739 - val_accuracy: 0.6381

# %% [markdown]
# Salviamo nuovamente la history del modello in un file csv e convertiamo il miglior modello nel formato **.onnx**.

# %%
bp_model_history_df = convert_history_to_csv(bp_model_history)
bp_model_history_df.to_csv("model_histories/noise/adam/filterbanks/bp_model_history_fb.csv")

convert_model_to_onnx("bestmodels/noise/adam/filterbanks/bp_basic_model_fb.keras", (98, 40, 1))

# %%
create_train_val_plot(bp_model_history.history)

# %% [markdown]
# In questo caso il modello **HA raggiunto una fase di overfitting**, inoltre le prestazioni sono diminuite di parecchio sotto qualsiasi aspetto.

# %%
best_bp_basic_model = tf.keras.models.load_model("bestmodels/noise/adam/filterbanks/bp_basic_model_fb.keras")
test_loss, test_acc = best_bp_basic_model.evaluate(fb_mixed_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 2ms/step - loss: 1.3533 - accuracy: 0.6017
# Accuratezza: 0.602

# %%
evaluate_onnx_model("bestmodels/noise/adam/filterbanks/bp_basic_model_fb.onnx", fb_mixed_test_ds)
# Out:
# Accuratezza: 0.602

# %% [markdown]
# Abbiamo ottenuto un forte peggioramento per quanto riguarda l'accuratezza, ottenendo un **62%**.

# %%
for audio, label in fb_mixed_test_ds:
    create_distribution_plot(best_bp_basic_model, audio, label)
    break

# %% [markdown]
# ## Addestramento (MFCC)
# Ripetiamo nuovamente tutti i passaggi ma per gli mfcc.

# %%
mfcc_mixed_train_ds = DatasetConverter(mixed_train_ds)
mfcc_mixed_train_ds = mfcc_mixed_train_ds.convert("mfcc")

mfcc_mixed_validation_ds = DatasetConverter(mixed_validation_ds)
mfcc_mixed_validation_ds = mfcc_mixed_validation_ds.convert("mfcc")

mfcc_mixed_val_ds = mfcc_mixed_validation_ds.take(mfcc_mixed_validation_ds.cardinality() // 2) # ho cambiato nome del validation_ds in modo tale da non creare problemi con l'istruzione seguente
mfcc_mixed_test_ds = mfcc_mixed_validation_ds.skip(mfcc_mixed_validation_ds.cardinality() // 2)

# %%
def get_basic_model(input_shape):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=input_shape, name="inputs")
    x = tf.keras.layers.Normalization(name="normalizzazione")(inputs)

    # Blocco di apprendimento delle caratteristiche
    conv2D_1 = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same", name="conv2D_1")(x)
    MaxPooling2D_1 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_1")(conv2D_1)
    conv2D_2 = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same", name="conv2D_2")(MaxPooling2D_1)
    MaxPooling2D_2 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_2")(conv2D_2)
    conv2D_3 = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same", name="conv2D_3")(MaxPooling2D_2)
    MaxPooling2D_3 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_3")(conv2D_3)
    conv2D_4 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_4")(MaxPooling2D_3)
    MaxPooling2D_4 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_4", padding="same")(conv2D_4)
    conv2D_5 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_5")(MaxPooling2D_4)

    # Blocco di classificazione
    Flatten = tf.keras.layers.Flatten(name="Flatten")(conv2D_5)
    outputs = tf.keras.layers.Dense(30, activation="softmax", name="dense_output")(Flatten)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
for audio, label in mfcc_mixed_train_ds:
    basic_model = get_basic_model(audio.shape[1:])
    break
    
basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/noise/adam/mfcc/basic_model_mfcc.keras", save_best_only=True, monitor="val_loss")]
basic_model_history = basic_model.fit(mfcc_mixed_train_ds, epochs=30, validation_data=mfcc_mixed_val_ds, callbacks=basic_model_callbacks)
# Out:
# Epoch 1/30
# 243/243 [==============================] - 2s 5ms/step - loss: 3.3545 - accuracy: 0.0682 - val_loss: 2.9868 - val_accuracy: 0.1420
# Epoch 2/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.6207 - accuracy: 0.2352 - val_loss: 2.2073 - val_accuracy: 0.3650
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.9435 - accuracy: 0.4249 - val_loss: 1.7801 - val_accuracy: 0.4834
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.4955 - accuracy: 0.5495 - val_loss: 1.6907 - val_accuracy: 0.5089
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.2382 - accuracy: 0.6214 - val_loss: 1.7241 - val_accuracy: 0.5343
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.0508 - accuracy: 0.6780 - val_loss: 1.8849 - val_accuracy: 0.5347
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.9052 - accuracy: 0.7157 - val_loss: 1.9185 - val_accuracy: 0.5502
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7955 - accuracy: 0.7452 - val_loss: 2.0963 - val_accuracy: 0.5625
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6768 - accuracy: 0.7835 - val_loss: 2.3061 - val_accuracy: 0.5571
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6120 - accuracy: 0.8050 - val_loss: 2.3037 - val_accuracy: 0.5490
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5852 - accuracy: 0.8177 - val_loss: 2.2007 - val_accuracy: 0.5795
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4910 - accuracy: 0.8495 - val_loss: 2.2201 - val_accuracy: 0.5980
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4616 - accuracy: 0.8553 - val_loss: 2.7287 - val_accuracy: 0.5745
# Epoch 14/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3703 - accuracy: 0.8823 - val_loss: 2.5682 - val_accuracy: 0.5918
# Epoch 15/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3693 - accuracy: 0.8865 - val_loss: 2.6892 - val_accuracy: 0.5806
# Epoch 16/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3755 - accuracy: 0.8889 - val_loss: 2.9354 - val_accuracy: 0.5910
# Epoch 17/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3713 - accuracy: 0.8890 - val_loss: 2.8845 - val_accuracy: 0.5610
# Epoch 18/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3087 - accuracy: 0.9067 - val_loss: 3.0034 - val_accuracy: 0.5818
# Epoch 19/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2764 - accuracy: 0.9169 - val_loss: 2.8072 - val_accuracy: 0.5918
# Epoch 20/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3161 - accuracy: 0.9110 - val_loss: 3.2713 - val_accuracy: 0.5706
# Epoch 21/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.2578 - accuracy: 0.9240 - val_loss: 3.1760 - val_accuracy: 0.5799
# Epoch 22/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2696 - accuracy: 0.9206 - val_loss: 3.1142 - val_accuracy: 0.5783
# Epoch 23/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2740 - accuracy: 0.9226 - val_loss: 3.4479 - val_accuracy: 0.5667
# Epoch 24/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2662 - accuracy: 0.9258 - val_loss: 3.3728 - val_accuracy: 0.5768
# Epoch 25/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2314 - accuracy: 0.9343 - val_loss: 3.7375 - val_accuracy: 0.5640
# Epoch 26/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2680 - accuracy: 0.9278 - val_loss: 3.6284 - val_accuracy: 0.5752
# Epoch 27/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.2715 - accuracy: 0.9245 - val_loss: 3.3778 - val_accuracy: 0.5814
# Epoch 28/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.2019 - accuracy: 0.9451 - val_loss: 3.7382 - val_accuracy: 0.5841
# Epoch 29/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.2164 - accuracy: 0.9362 - val_loss: 3.5515 - val_accuracy: 0.5895
# Epoch 30/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1882 - accuracy: 0.9506 - val_loss: 3.9799 - val_accuracy: 0.5930

# %% [markdown]
# Salviamo i dati della history del modello in un file csv

# %%
basic_model_history_df = convert_history_to_csv(basic_model_history)
basic_model_history_df.to_csv("model_histories/noise/adam/mfcc/basic_model_history_mfcc.csv")

convert_model_to_onnx("bestmodels/noise/adam/mfcc/basic_model_mfcc.keras", (98, 12, 1))

# %% [markdown]
# Visualizziamo l'andamento dell'accuratezza e della perdita durante l'addestramento.

# %%
create_train_val_plot(basic_model_history.history)

# %% [markdown]
# Verifichiamo l'accuratezza della migliore versione del nostro modello di base ricaricando il file **basic_model.keras**.

# %%
best_basic_model = tf.keras.models.load_model("bestmodels/noise/adam/mfcc/basic_model_mfcc.keras")
test_loss, test_acc = best_basic_model.evaluate(mfcc_mixed_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 2ms/step - loss: 1.7100 - accuracy: 0.4955
# Accuratezza: 0.496

# %%
evaluate_onnx_model("bestmodels/noise/adam/mfcc/basic_model_mfcc.onnx", mfcc_mixed_test_ds)
# Out:
# Accuratezza: 0.496

# %% [markdown]
# Abbiamo ottenuto un'**accuratezza** del **60.8%**. Il modello è di poco al disto del lancio della moneta, perciò non è per niente buono.

# %%
for audio, label in mfcc_mixed_test_ds: # prendiamo un audio a caso del test e creiamo la distribuzione
    create_distribution_plot(best_basic_model, audio, label)
    break

# %% [markdown]
# Possiamo notare molta indecisione nella distribuzione dei dati.

# %% [markdown]
# ### Risoluzione dell'overfitting
# Ovviamente il modello è andato immediatamente in **overfitting**, perciò ripetiamo i metodi applicati precedentemente.

# %%
def get_improved_basic_model(input_shape):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=input_shape)
    x = tf.keras.layers.Normalization()(inputs)

    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2, padding="same")(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
for audio, label in mfcc_mixed_train_ds:
    improved_basic_model = get_improved_basic_model(audio.shape[1:])
    break

improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/noise/adam/mfcc/improved_basic_model_mfcc.keras", save_best_only=True, monitor="val_loss")]
improved_history = improved_basic_model.fit(mfcc_mixed_train_ds, epochs=100, validation_data=mfcc_mixed_val_ds, callbacks=improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 1s 4ms/step - loss: 3.4415 - accuracy: 0.0474 - val_loss: 3.2395 - val_accuracy: 0.0714
# Epoch 2/100
# 243/243 [==============================] - 1s 4ms/step - loss: 3.0922 - accuracy: 0.1070 - val_loss: 2.9041 - val_accuracy: 0.1489
# Epoch 3/100
# 243/243 [==============================] - 1s 4ms/step - loss: 2.6915 - accuracy: 0.2090 - val_loss: 2.2792 - val_accuracy: 0.3449
# Epoch 4/100
# 243/243 [==============================] - 1s 4ms/step - loss: 2.2285 - accuracy: 0.3448 - val_loss: 1.9652 - val_accuracy: 0.4348
# Epoch 5/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.8795 - accuracy: 0.4427 - val_loss: 1.9447 - val_accuracy: 0.4410
# Epoch 6/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.5915 - accuracy: 0.5171 - val_loss: 1.5887 - val_accuracy: 0.5517
# Epoch 7/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.4235 - accuracy: 0.5697 - val_loss: 1.5074 - val_accuracy: 0.5783
# Epoch 8/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.2574 - accuracy: 0.6228 - val_loss: 1.4881 - val_accuracy: 0.5984
# Epoch 9/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.1409 - accuracy: 0.6549 - val_loss: 1.5357 - val_accuracy: 0.5864
# Epoch 10/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.0681 - accuracy: 0.6758 - val_loss: 1.5255 - val_accuracy: 0.5934
# Epoch 11/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.9515 - accuracy: 0.7059 - val_loss: 1.5741 - val_accuracy: 0.6069
# Epoch 12/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.9137 - accuracy: 0.7142 - val_loss: 1.4864 - val_accuracy: 0.6254
# Epoch 13/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8315 - accuracy: 0.7418 - val_loss: 1.5253 - val_accuracy: 0.6304
# Epoch 14/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8001 - accuracy: 0.7523 - val_loss: 1.6158 - val_accuracy: 0.6092
# Epoch 15/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7552 - accuracy: 0.7675 - val_loss: 1.6344 - val_accuracy: 0.6254
# Epoch 16/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7116 - accuracy: 0.7827 - val_loss: 1.6454 - val_accuracy: 0.6215
# Epoch 17/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6483 - accuracy: 0.7957 - val_loss: 1.6727 - val_accuracy: 0.6358
# Epoch 18/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6535 - accuracy: 0.8059 - val_loss: 1.5944 - val_accuracy: 0.6439
# Epoch 19/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6220 - accuracy: 0.8055 - val_loss: 1.7422 - val_accuracy: 0.6335
# Epoch 20/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5705 - accuracy: 0.8226 - val_loss: 1.8117 - val_accuracy: 0.6335
# Epoch 21/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5767 - accuracy: 0.8223 - val_loss: 1.8440 - val_accuracy: 0.6130
# Epoch 22/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5061 - accuracy: 0.8392 - val_loss: 1.8850 - val_accuracy: 0.6373
# Epoch 23/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5112 - accuracy: 0.8445 - val_loss: 2.0202 - val_accuracy: 0.6235
# Epoch 24/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5026 - accuracy: 0.8447 - val_loss: 2.0093 - val_accuracy: 0.6250
# Epoch 25/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4933 - accuracy: 0.8521 - val_loss: 2.2355 - val_accuracy: 0.6038
# Epoch 26/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4765 - accuracy: 0.8559 - val_loss: 2.0661 - val_accuracy: 0.6304
# Epoch 27/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4641 - accuracy: 0.8625 - val_loss: 1.9093 - val_accuracy: 0.6354
# Epoch 28/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4421 - accuracy: 0.8657 - val_loss: 2.0920 - val_accuracy: 0.6397
# Epoch 29/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4406 - accuracy: 0.8715 - val_loss: 2.1676 - val_accuracy: 0.6404
# Epoch 30/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4651 - accuracy: 0.8612 - val_loss: 2.1106 - val_accuracy: 0.6640
# Epoch 31/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4843 - accuracy: 0.8619 - val_loss: 2.3191 - val_accuracy: 0.6246
# Epoch 32/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4562 - accuracy: 0.8686 - val_loss: 2.2934 - val_accuracy: 0.6443
# Epoch 33/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4370 - accuracy: 0.8702 - val_loss: 2.3572 - val_accuracy: 0.6327
# Epoch 34/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4183 - accuracy: 0.8759 - val_loss: 2.4273 - val_accuracy: 0.6358
# Epoch 35/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4605 - accuracy: 0.8677 - val_loss: 2.2885 - val_accuracy: 0.6281
# Epoch 36/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4283 - accuracy: 0.8811 - val_loss: 2.5484 - val_accuracy: 0.6435
# Epoch 37/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3870 - accuracy: 0.8845 - val_loss: 2.3347 - val_accuracy: 0.6316
# Epoch 38/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4022 - accuracy: 0.8847 - val_loss: 2.2475 - val_accuracy: 0.6566
# Epoch 39/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3581 - accuracy: 0.8986 - val_loss: 2.2311 - val_accuracy: 0.6667
# Epoch 40/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3227 - accuracy: 0.9045 - val_loss: 2.5839 - val_accuracy: 0.6443
# Epoch 41/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4103 - accuracy: 0.8902 - val_loss: 2.2813 - val_accuracy: 0.6520
# Epoch 42/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4063 - accuracy: 0.8860 - val_loss: 2.3703 - val_accuracy: 0.6493
# Epoch 43/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3995 - accuracy: 0.8871 - val_loss: 2.4518 - val_accuracy: 0.6597
# Epoch 44/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4367 - accuracy: 0.8844 - val_loss: 2.4857 - val_accuracy: 0.6458
# Epoch 45/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4305 - accuracy: 0.8812 - val_loss: 2.4847 - val_accuracy: 0.6424
# Epoch 46/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3557 - accuracy: 0.9005 - val_loss: 2.4708 - val_accuracy: 0.6505
# Epoch 47/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3064 - accuracy: 0.9131 - val_loss: 2.4789 - val_accuracy: 0.6593
# Epoch 48/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3235 - accuracy: 0.9032 - val_loss: 2.6338 - val_accuracy: 0.6493
# Epoch 49/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4307 - accuracy: 0.8856 - val_loss: 2.7053 - val_accuracy: 0.6586
# Epoch 50/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3728 - accuracy: 0.9019 - val_loss: 2.5428 - val_accuracy: 0.6559
# Epoch 51/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.3423 - accuracy: 0.9091 - val_loss: 2.6188 - val_accuracy: 0.6725
# Epoch 52/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.3635 - accuracy: 0.9034 - val_loss: 2.4462 - val_accuracy: 0.6520
# Epoch 53/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.3460 - accuracy: 0.9035 - val_loss: 2.6784 - val_accuracy: 0.6686
# Epoch 54/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2902 - accuracy: 0.9216 - val_loss: 2.6510 - val_accuracy: 0.6524
# Epoch 55/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.3365 - accuracy: 0.9076 - val_loss: 2.7957 - val_accuracy: 0.6570
# Epoch 56/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.4144 - accuracy: 0.8923 - val_loss: 2.8261 - val_accuracy: 0.6478
# Epoch 57/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3896 - accuracy: 0.9015 - val_loss: 3.1171 - val_accuracy: 0.6570
# Epoch 58/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4288 - accuracy: 0.8938 - val_loss: 2.7024 - val_accuracy: 0.6462
# Epoch 59/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3395 - accuracy: 0.9099 - val_loss: 2.9733 - val_accuracy: 0.6478
# Epoch 60/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3841 - accuracy: 0.8994 - val_loss: 2.7763 - val_accuracy: 0.6582
# Epoch 61/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3568 - accuracy: 0.9098 - val_loss: 2.8063 - val_accuracy: 0.6547
# Epoch 62/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3770 - accuracy: 0.9034 - val_loss: 2.7930 - val_accuracy: 0.6636
# Epoch 63/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3024 - accuracy: 0.9240 - val_loss: 2.8322 - val_accuracy: 0.6644
# Epoch 64/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3556 - accuracy: 0.9066 - val_loss: 2.9102 - val_accuracy: 0.6481
# Epoch 65/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3289 - accuracy: 0.9086 - val_loss: 3.0144 - val_accuracy: 0.6512
# Epoch 66/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3375 - accuracy: 0.9159 - val_loss: 2.7405 - val_accuracy: 0.6617
# Epoch 67/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3256 - accuracy: 0.9164 - val_loss: 2.7295 - val_accuracy: 0.6647
# Epoch 68/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3193 - accuracy: 0.9189 - val_loss: 3.0273 - val_accuracy: 0.6620
# Epoch 69/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3783 - accuracy: 0.9079 - val_loss: 2.8495 - val_accuracy: 0.6485
# Epoch 70/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4200 - accuracy: 0.8956 - val_loss: 2.6172 - val_accuracy: 0.6501
# Epoch 71/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3281 - accuracy: 0.9155 - val_loss: 2.8887 - val_accuracy: 0.6516
# Epoch 72/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3249 - accuracy: 0.9180 - val_loss: 3.0223 - val_accuracy: 0.6481
# Epoch 73/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4199 - accuracy: 0.8986 - val_loss: 3.2057 - val_accuracy: 0.6505
# Epoch 74/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.3698 - accuracy: 0.9112 - val_loss: 3.3697 - val_accuracy: 0.6686
# Epoch 75/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.4311 - accuracy: 0.8981 - val_loss: 2.8943 - val_accuracy: 0.6659
# Epoch 76/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.3169 - accuracy: 0.9175 - val_loss: 2.9917 - val_accuracy: 0.6663
# Epoch 77/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.3078 - accuracy: 0.9260 - val_loss: 3.0594 - val_accuracy: 0.6458
# Epoch 78/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.3845 - accuracy: 0.9058 - val_loss: 3.2954 - val_accuracy: 0.6454
# Epoch 79/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3771 - accuracy: 0.9071 - val_loss: 2.9545 - val_accuracy: 0.6400
# Epoch 80/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3636 - accuracy: 0.9102 - val_loss: 3.1802 - val_accuracy: 0.6501
# Epoch 81/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3373 - accuracy: 0.9184 - val_loss: 3.0091 - val_accuracy: 0.6590
# Epoch 82/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3146 - accuracy: 0.9237 - val_loss: 3.4195 - val_accuracy: 0.6543
# Epoch 83/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3998 - accuracy: 0.9067 - val_loss: 2.9327 - val_accuracy: 0.6586
# Epoch 84/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3533 - accuracy: 0.9131 - val_loss: 3.4261 - val_accuracy: 0.6454
# Epoch 85/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4038 - accuracy: 0.9110 - val_loss: 3.4396 - val_accuracy: 0.6474
# Epoch 86/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.4144 - accuracy: 0.9072 - val_loss: 3.0800 - val_accuracy: 0.6609
# Epoch 87/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3762 - accuracy: 0.9086 - val_loss: 3.3010 - val_accuracy: 0.6578
# Epoch 88/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.3312 - accuracy: 0.9210 - val_loss: 3.5137 - val_accuracy: 0.6709
# Epoch 89/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3922 - accuracy: 0.9106 - val_loss: 3.0448 - val_accuracy: 0.6667
# Epoch 90/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3616 - accuracy: 0.9144 - val_loss: 3.1943 - val_accuracy: 0.6397
# Epoch 91/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.3241 - accuracy: 0.9269 - val_loss: 3.7098 - val_accuracy: 0.6501
# Epoch 92/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.2819 - accuracy: 0.9313 - val_loss: 3.5749 - val_accuracy: 0.6555
# Epoch 93/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2899 - accuracy: 0.9305 - val_loss: 3.6222 - val_accuracy: 0.6551
# Epoch 94/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.3128 - accuracy: 0.9278 - val_loss: 3.7981 - val_accuracy: 0.6524
# Epoch 95/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3762 - accuracy: 0.9146 - val_loss: 3.4293 - val_accuracy: 0.6424
# Epoch 96/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.3548 - accuracy: 0.9159 - val_loss: 3.6672 - val_accuracy: 0.6620
# Epoch 97/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3569 - accuracy: 0.9166 - val_loss: 4.1023 - val_accuracy: 0.6508
# Epoch 98/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3599 - accuracy: 0.9188 - val_loss: 3.9117 - val_accuracy: 0.6547
# Epoch 99/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.3719 - accuracy: 0.9162 - val_loss: 3.8030 - val_accuracy: 0.6474
# Epoch 100/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3884 - accuracy: 0.9165 - val_loss: 3.8632 - val_accuracy: 0.6497

# %% [markdown]
# Salviamo come prima la history del modello in un file csv, e convertiamo il miglior modello nel formato **.onnx**.

# %%
improved_history_df = convert_history_to_csv(improved_history)
improved_history_df.to_csv("model_histories/noise/adam/mfcc/improved_history_mfcc.csv")

convert_model_to_onnx("bestmodels/noise/adam/mfcc/improved_basic_model_mfcc.keras", (98, 12, 1))

# %% [markdown]
# Visualizziamo la curva dell'accuratezza e della perdita durante l'addestramento.

# %%
create_train_val_plot(improved_history.history)

# %% [markdown]
# Le prestazioni sono migliorate rispetto all'applicazione precedente. Verifichiamo l'accuratezza nel dataset di test.

# %%
improved_best_model = tf.keras.models.load_model("bestmodels/noise/adam/mfcc/improved_basic_model_mfcc.keras")
test_loss, test_acc = improved_best_model.evaluate(mfcc_mixed_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 2ms/step - loss: 1.4783 - accuracy: 0.6226
# Accuratezza: 0.623

# %%
evaluate_onnx_model("bestmodels/noise/adam/mfcc/improved_basic_model_mfcc.onnx", mfcc_mixed_test_ds)
# Out:
# Accuratezza: 0.623

# %% [markdown]
# Abbiamo ottenuto un notevole miglioramento dell'accuratezza, attualmente siamo a quota **63.8%**! Visualizziamo anche la solita distribuzione.

# %%
for audio, label in mfcc_mixed_test_ds:
    create_distribution_plot(improved_best_model, audio, label)
    break

# %% [markdown]
# ### Fine tuning
# Anche per questa sezione, andiamo a ripetere gli stessi passaggi degli spettrogrammi.

# %%
def get_improved_basic_model_tuning(start_filters):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(98, 12, 1))
    x = tf.keras.layers.Normalization()(inputs)

    if not isinstance(start_filters, int):
        raise Exception("start_filters must be type integer")

    filters = [start_filters * (2 ** i) for i in range(4)]
    
    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=filters[0], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[1], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[2], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[3], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2, padding="same")(x)
    x = tf.keras.layers.Conv2D(filters=filters[3], kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

def tuner(filters, learning_rates, max_epochs, train_dataset, validation_dataset):
    start_time = time.time()

    counter = 1
    
    if not isinstance(filters, list):
        raise Exception("parameter filters must be type list")

    if not isinstance(learning_rates, list):
        raise Exception("parameter learning_rates must be type list")

    callbacks = [tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5)]

    best_learning_rate = 0 
    best_filters = 0
    best_val_accuracy = 0

    best_model = 0
    
    for f in filters:
        for lr in learning_rates:
            print(f"\nAddestrando con filtri {[f * (2 ** i) for i in range(4)]} e tasso di apprendimento {lr}")
            
            model = get_improved_basic_model_tuning(start_filters=f)
            model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=lr), metrics=["accuracy"])
            model_history = model.fit(train_dataset, epochs=max_epochs, validation_data=validation_dataset, callbacks=callbacks)

            model_history_df = convert_history_to_csv(model_history)

            model_history_df[["filters"]] = f
            model_history_df[["learning_rate"]] = lr
            
            path = "model_tuning/noise/adam/mfcc/model_" + str(counter) + ".csv"
            model_history_df.to_csv(path)
            
            if best_val_accuracy < model_history_df.iloc[-1]["val_accuracy"]:
                best_val_accuracy = model_history_df.iloc[-1]["val_accuracy"]
                best_filters = f
                best_learning_rate = lr
                epoch = len(model_history_df)

            del model

            counter += 1

    total_time = time.time() - start_time
    minutes, seconds = divmod(total_time, 60)
    print(f"\nTempo totale trascorso: {int(minutes)} minuti e {int(seconds)} secondi")
    # print(f"Il miglior modello ha un filtro di partenza pari a {best_filters}, un learning rate pari a {best_learning_rate} con un'accuracy pari a {best_val_accuracy:.3f}")

    return best_filters, best_learning_rate

best_filter, best_learning_rate = tuner([16, 32, 64], [1e-3, 1e-4, 1e-5], 30, mfcc_mixed_train_ds, mfcc_mixed_val_ds)
# Out:
# Addestrando con filtri [16, 32, 64, 128] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.5179 - accuracy: 0.0374 - val_loss: 3.3854 - val_accuracy: 0.0428
# Epoch 2/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.3587 - accuracy: 0.0521 - val_loss: 3.2183 - val_accuracy: 0.0802
# Epoch 3/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.1579 - accuracy: 0.0861 - val_loss: 2.9553 - val_accuracy: 0.1516
# Epoch 4/30
# 243/243 [==============================] - 1s 3ms/step - loss: 2.8930 - accuracy: 0.1582 - val_loss: 2.7105 - val_accuracy: 0.2041
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.6361 - accuracy: 0.2197 - val_loss: 2.5098 - val_accuracy: 0.2716
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.3782 - accuracy: 0.2919 - val_loss: 2.2112 - val_accuracy: 0.3526
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.1521 - accuracy: 0.3545 - val_loss: 2.0171 - val_accuracy: 0.4136
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.9475 - accuracy: 0.4174 - val_loss: 1.8607 - val_accuracy: 0.4549
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.7621 - accuracy: 0.4679 - val_loss: 1.7854 - val_accuracy: 0.4738
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.6200 - accuracy: 0.5022 - val_loss: 1.7359 - val_accuracy: 0.5008
# Epoch 11/30
# 243/243 [==============================] - 1s 3ms/step - loss: 1.5145 - accuracy: 0.5385 - val_loss: 1.6841 - val_accuracy: 0.5193
# Epoch 12/30
# 243/243 [==============================] - 1s 3ms/step - loss: 1.4037 - accuracy: 0.5727 - val_loss: 1.5473 - val_accuracy: 0.5532
# Epoch 13/30
# 243/243 [==============================] - 1s 3ms/step - loss: 1.2891 - accuracy: 0.5986 - val_loss: 1.5398 - val_accuracy: 0.5606
# Epoch 14/30
# 243/243 [==============================] - 1s 3ms/step - loss: 1.2136 - accuracy: 0.6245 - val_loss: 1.5975 - val_accuracy: 0.5640
# Epoch 15/30
# 243/243 [==============================] - 1s 3ms/step - loss: 1.1510 - accuracy: 0.6469 - val_loss: 1.5778 - val_accuracy: 0.5629
# Epoch 16/30
# 243/243 [==============================] - 1s 3ms/step - loss: 1.0711 - accuracy: 0.6729 - val_loss: 1.5498 - val_accuracy: 0.5802
# Epoch 17/30
# 243/243 [==============================] - 1s 3ms/step - loss: 1.0193 - accuracy: 0.6834 - val_loss: 1.5048 - val_accuracy: 0.5961
# Epoch 18/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.9757 - accuracy: 0.6932 - val_loss: 1.4648 - val_accuracy: 0.5995
# Epoch 19/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.9394 - accuracy: 0.7021 - val_loss: 1.5162 - val_accuracy: 0.5976
# Epoch 20/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.9099 - accuracy: 0.7126 - val_loss: 1.5458 - val_accuracy: 0.6080
# Epoch 21/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8587 - accuracy: 0.7314 - val_loss: 1.5976 - val_accuracy: 0.6034
# Epoch 22/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8541 - accuracy: 0.7351 - val_loss: 1.5601 - val_accuracy: 0.6100
# Epoch 23/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8064 - accuracy: 0.7473 - val_loss: 1.6565 - val_accuracy: 0.6130
#
# Addestrando con filtri [16, 32, 64, 128] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.8176 - accuracy: 0.0363 - val_loss: 3.3991 - val_accuracy: 0.0355
# Epoch 2/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.3946 - accuracy: 0.0479 - val_loss: 3.3853 - val_accuracy: 0.0390
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3757 - accuracy: 0.0559 - val_loss: 3.3629 - val_accuracy: 0.0475
# Epoch 4/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.3456 - accuracy: 0.0628 - val_loss: 3.3235 - val_accuracy: 0.0633
# Epoch 5/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.2927 - accuracy: 0.0776 - val_loss: 3.2480 - val_accuracy: 0.0957
# Epoch 6/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.2061 - accuracy: 0.1028 - val_loss: 3.1227 - val_accuracy: 0.1304
# Epoch 7/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.0892 - accuracy: 0.1349 - val_loss: 2.9842 - val_accuracy: 0.1686
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.9595 - accuracy: 0.1604 - val_loss: 2.8732 - val_accuracy: 0.1921
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.8340 - accuracy: 0.1879 - val_loss: 2.7363 - val_accuracy: 0.2215
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.7202 - accuracy: 0.2169 - val_loss: 2.6499 - val_accuracy: 0.2477
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.6037 - accuracy: 0.2487 - val_loss: 2.5506 - val_accuracy: 0.2805
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.4915 - accuracy: 0.2840 - val_loss: 2.4463 - val_accuracy: 0.3059
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.4145 - accuracy: 0.2960 - val_loss: 2.3820 - val_accuracy: 0.3233
# Epoch 14/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.3132 - accuracy: 0.3213 - val_loss: 2.3461 - val_accuracy: 0.3318
# Epoch 15/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.2163 - accuracy: 0.3501 - val_loss: 2.2685 - val_accuracy: 0.3488
# Epoch 16/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.1429 - accuracy: 0.3702 - val_loss: 2.2104 - val_accuracy: 0.3565
# Epoch 17/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.0531 - accuracy: 0.3961 - val_loss: 2.1546 - val_accuracy: 0.3738
# Epoch 18/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.9940 - accuracy: 0.4168 - val_loss: 2.0999 - val_accuracy: 0.3981
# Epoch 19/30
# 243/243 [==============================] - 1s 3ms/step - loss: 1.9095 - accuracy: 0.4379 - val_loss: 2.0628 - val_accuracy: 0.4032
# Epoch 20/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.8681 - accuracy: 0.4501 - val_loss: 2.0641 - val_accuracy: 0.4035
# Epoch 21/30
# 243/243 [==============================] - 1s 3ms/step - loss: 1.7868 - accuracy: 0.4675 - val_loss: 2.0288 - val_accuracy: 0.4136
# Epoch 22/30
# 243/243 [==============================] - 1s 3ms/step - loss: 1.7228 - accuracy: 0.4920 - val_loss: 1.9840 - val_accuracy: 0.4298
# Epoch 23/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.6659 - accuracy: 0.5040 - val_loss: 1.9412 - val_accuracy: 0.4433
# Epoch 24/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.5899 - accuracy: 0.5247 - val_loss: 1.9111 - val_accuracy: 0.4514
# Epoch 25/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.5431 - accuracy: 0.5387 - val_loss: 1.8784 - val_accuracy: 0.4537
# Epoch 26/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.4900 - accuracy: 0.5572 - val_loss: 1.8595 - val_accuracy: 0.4699
# Epoch 27/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.4431 - accuracy: 0.5683 - val_loss: 1.8537 - val_accuracy: 0.4684
# Epoch 28/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.3908 - accuracy: 0.5756 - val_loss: 1.8089 - val_accuracy: 0.4796
# Epoch 29/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.3362 - accuracy: 0.5978 - val_loss: 1.8352 - val_accuracy: 0.4703
# Epoch 30/30
# 243/243 [==============================] - 1s 3ms/step - loss: 1.3090 - accuracy: 0.5999 - val_loss: 1.7786 - val_accuracy: 0.4865
#
# Addestrando con filtri [16, 32, 64, 128] e tasso di apprendimento 1e-05
# Epoch 1/30
# 243/243 [==============================] - 1s 4ms/step - loss: 7.7456 - accuracy: 0.0345 - val_loss: 3.8050 - val_accuracy: 0.0285
# Epoch 2/30
# 243/243 [==============================] - 1s 4ms/step - loss: 4.1791 - accuracy: 0.0335 - val_loss: 3.5328 - val_accuracy: 0.0363
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.6898 - accuracy: 0.0363 - val_loss: 3.4594 - val_accuracy: 0.0405
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.5389 - accuracy: 0.0372 - val_loss: 3.4289 - val_accuracy: 0.0401
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.4765 - accuracy: 0.0356 - val_loss: 3.4115 - val_accuracy: 0.0382
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.4343 - accuracy: 0.0397 - val_loss: 3.4027 - val_accuracy: 0.0370
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.4177 - accuracy: 0.0409 - val_loss: 3.3988 - val_accuracy: 0.0374
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.4063 - accuracy: 0.0442 - val_loss: 3.3949 - val_accuracy: 0.0401
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.4033 - accuracy: 0.0432 - val_loss: 3.3918 - val_accuracy: 0.0363
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3950 - accuracy: 0.0414 - val_loss: 3.3893 - val_accuracy: 0.0390
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3931 - accuracy: 0.0437 - val_loss: 3.3881 - val_accuracy: 0.0386
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3845 - accuracy: 0.0433 - val_loss: 3.3846 - val_accuracy: 0.0424
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3843 - accuracy: 0.0495 - val_loss: 3.3841 - val_accuracy: 0.0440
# Epoch 14/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3780 - accuracy: 0.0519 - val_loss: 3.3816 - val_accuracy: 0.0498
# Epoch 15/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3762 - accuracy: 0.0472 - val_loss: 3.3785 - val_accuracy: 0.0552
# Epoch 16/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3689 - accuracy: 0.0522 - val_loss: 3.3774 - val_accuracy: 0.0556
# Epoch 17/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.3655 - accuracy: 0.0555 - val_loss: 3.3738 - val_accuracy: 0.0583
# Epoch 18/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.3622 - accuracy: 0.0545 - val_loss: 3.3704 - val_accuracy: 0.0536
# Epoch 19/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.3575 - accuracy: 0.0550 - val_loss: 3.3671 - val_accuracy: 0.0563
# Epoch 20/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.3513 - accuracy: 0.0581 - val_loss: 3.3630 - val_accuracy: 0.0548
# Epoch 21/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3467 - accuracy: 0.0577 - val_loss: 3.3565 - val_accuracy: 0.0629
# Epoch 22/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3399 - accuracy: 0.0608 - val_loss: 3.3530 - val_accuracy: 0.0629
# Epoch 23/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3334 - accuracy: 0.0652 - val_loss: 3.3472 - val_accuracy: 0.0671
# Epoch 24/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3230 - accuracy: 0.0710 - val_loss: 3.3390 - val_accuracy: 0.0675
# Epoch 25/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3160 - accuracy: 0.0679 - val_loss: 3.3326 - val_accuracy: 0.0733
# Epoch 26/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3101 - accuracy: 0.0760 - val_loss: 3.3262 - val_accuracy: 0.0772
# Epoch 27/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2966 - accuracy: 0.0769 - val_loss: 3.3149 - val_accuracy: 0.0772
# Epoch 28/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2919 - accuracy: 0.0763 - val_loss: 3.3063 - val_accuracy: 0.0826
# Epoch 29/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2815 - accuracy: 0.0847 - val_loss: 3.2992 - val_accuracy: 0.0818
# Epoch 30/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2683 - accuracy: 0.0860 - val_loss: 3.2900 - val_accuracy: 0.0876
#
# Addestrando con filtri [32, 64, 128, 256] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 1s 5ms/step - loss: 3.4207 - accuracy: 0.0589 - val_loss: 3.0759 - val_accuracy: 0.1130
# Epoch 2/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.8699 - accuracy: 0.1671 - val_loss: 2.4932 - val_accuracy: 0.2812
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.3376 - accuracy: 0.3189 - val_loss: 2.0206 - val_accuracy: 0.4263
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.8894 - accuracy: 0.4394 - val_loss: 1.7152 - val_accuracy: 0.5062
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.5816 - accuracy: 0.5277 - val_loss: 1.6170 - val_accuracy: 0.5255
# Epoch 6/30
# 243/243 [==============================] - 1s 3ms/step - loss: 1.3852 - accuracy: 0.5814 - val_loss: 1.4923 - val_accuracy: 0.5586
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.2161 - accuracy: 0.6260 - val_loss: 1.4704 - val_accuracy: 0.5702
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.0859 - accuracy: 0.6634 - val_loss: 1.4869 - val_accuracy: 0.5853
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.9832 - accuracy: 0.7032 - val_loss: 1.4691 - val_accuracy: 0.6107
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8888 - accuracy: 0.7296 - val_loss: 1.4667 - val_accuracy: 0.6173
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8270 - accuracy: 0.7447 - val_loss: 1.5036 - val_accuracy: 0.6092
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7614 - accuracy: 0.7635 - val_loss: 1.5106 - val_accuracy: 0.6254
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7391 - accuracy: 0.7689 - val_loss: 1.5520 - val_accuracy: 0.6250
# Epoch 14/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6838 - accuracy: 0.7889 - val_loss: 1.6065 - val_accuracy: 0.6397
# Epoch 15/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6499 - accuracy: 0.8017 - val_loss: 1.6299 - val_accuracy: 0.6389
#
# Addestrando con filtri [32, 64, 128, 256] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.5497 - accuracy: 0.0468 - val_loss: 3.3556 - val_accuracy: 0.0610
# Epoch 2/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3383 - accuracy: 0.0657 - val_loss: 3.2457 - val_accuracy: 0.0988
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1900 - accuracy: 0.1052 - val_loss: 3.0068 - val_accuracy: 0.1748
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.9818 - accuracy: 0.1517 - val_loss: 2.7845 - val_accuracy: 0.2269
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.7472 - accuracy: 0.2162 - val_loss: 2.5659 - val_accuracy: 0.2770
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.5211 - accuracy: 0.2688 - val_loss: 2.3852 - val_accuracy: 0.3148
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.3283 - accuracy: 0.3204 - val_loss: 2.2679 - val_accuracy: 0.3657
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.1532 - accuracy: 0.3727 - val_loss: 2.1317 - val_accuracy: 0.3997
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.9871 - accuracy: 0.4169 - val_loss: 2.0142 - val_accuracy: 0.4363
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.8381 - accuracy: 0.4649 - val_loss: 1.9046 - val_accuracy: 0.4630
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.6777 - accuracy: 0.5027 - val_loss: 1.8219 - val_accuracy: 0.4853
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.5228 - accuracy: 0.5457 - val_loss: 1.7667 - val_accuracy: 0.4880
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.4155 - accuracy: 0.5767 - val_loss: 1.6912 - val_accuracy: 0.5123
# Epoch 14/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.3018 - accuracy: 0.6089 - val_loss: 1.6815 - val_accuracy: 0.5193
# Epoch 15/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.1905 - accuracy: 0.6472 - val_loss: 1.6554 - val_accuracy: 0.5154
# Epoch 16/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.0919 - accuracy: 0.6688 - val_loss: 1.6595 - val_accuracy: 0.5208
# Epoch 17/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.9892 - accuracy: 0.6990 - val_loss: 1.5831 - val_accuracy: 0.5436
# Epoch 18/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.9229 - accuracy: 0.7204 - val_loss: 1.6740 - val_accuracy: 0.5224
# Epoch 19/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8511 - accuracy: 0.7384 - val_loss: 1.6137 - val_accuracy: 0.5444
# Epoch 20/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7911 - accuracy: 0.7591 - val_loss: 1.6070 - val_accuracy: 0.5513
# Epoch 21/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.7236 - accuracy: 0.7771 - val_loss: 1.4808 - val_accuracy: 0.5841
# Epoch 22/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6600 - accuracy: 0.7977 - val_loss: 1.6027 - val_accuracy: 0.5617
# Epoch 23/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6158 - accuracy: 0.8128 - val_loss: 1.5865 - val_accuracy: 0.5741
# Epoch 24/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5722 - accuracy: 0.8277 - val_loss: 1.5618 - val_accuracy: 0.5814
# Epoch 25/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5364 - accuracy: 0.8356 - val_loss: 1.5561 - val_accuracy: 0.5737
# Epoch 26/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4933 - accuracy: 0.8514 - val_loss: 1.5916 - val_accuracy: 0.5802
#
# Addestrando con filtri [32, 64, 128, 256] e tasso di apprendimento 1e-05
# Epoch 1/30
# 243/243 [==============================] - 1s 4ms/step - loss: 5.2490 - accuracy: 0.0335 - val_loss: 3.4780 - val_accuracy: 0.0455
# Epoch 2/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.6088 - accuracy: 0.0401 - val_loss: 3.4068 - val_accuracy: 0.0451
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.4489 - accuracy: 0.0443 - val_loss: 3.3796 - val_accuracy: 0.0478
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.4019 - accuracy: 0.0570 - val_loss: 3.3617 - val_accuracy: 0.0556
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3745 - accuracy: 0.0549 - val_loss: 3.3514 - val_accuracy: 0.0602
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3533 - accuracy: 0.0631 - val_loss: 3.3373 - val_accuracy: 0.0671
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3336 - accuracy: 0.0684 - val_loss: 3.3208 - val_accuracy: 0.0752
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3134 - accuracy: 0.0760 - val_loss: 3.3052 - val_accuracy: 0.0826
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2882 - accuracy: 0.0835 - val_loss: 3.2823 - val_accuracy: 0.0826
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2624 - accuracy: 0.0930 - val_loss: 3.2639 - val_accuracy: 0.0918
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2453 - accuracy: 0.0948 - val_loss: 3.2415 - val_accuracy: 0.0988
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2052 - accuracy: 0.1030 - val_loss: 3.2113 - val_accuracy: 0.1076
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1764 - accuracy: 0.1157 - val_loss: 3.1785 - val_accuracy: 0.1184
# Epoch 14/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1405 - accuracy: 0.1175 - val_loss: 3.1467 - val_accuracy: 0.1312
# Epoch 15/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1078 - accuracy: 0.1295 - val_loss: 3.1141 - val_accuracy: 0.1416
# Epoch 16/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.0759 - accuracy: 0.1390 - val_loss: 3.0788 - val_accuracy: 0.1493
# Epoch 17/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.0351 - accuracy: 0.1510 - val_loss: 3.0524 - val_accuracy: 0.1601
# Epoch 18/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.0035 - accuracy: 0.1591 - val_loss: 3.0155 - val_accuracy: 0.1744
# Epoch 19/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.9528 - accuracy: 0.1726 - val_loss: 2.9829 - val_accuracy: 0.1813
# Epoch 20/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.9159 - accuracy: 0.1769 - val_loss: 2.9478 - val_accuracy: 0.1867
# Epoch 21/30
# 243/243 [==============================] - 1s 3ms/step - loss: 2.8954 - accuracy: 0.1874 - val_loss: 2.9152 - val_accuracy: 0.2033
# Epoch 22/30
# 243/243 [==============================] - 1s 3ms/step - loss: 2.8522 - accuracy: 0.1974 - val_loss: 2.8845 - val_accuracy: 0.2041
# Epoch 23/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.8105 - accuracy: 0.2070 - val_loss: 2.8544 - val_accuracy: 0.2083
# Epoch 24/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.7779 - accuracy: 0.2160 - val_loss: 2.8223 - val_accuracy: 0.2141
# Epoch 25/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.7375 - accuracy: 0.2247 - val_loss: 2.7911 - val_accuracy: 0.2226
# Epoch 26/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.7104 - accuracy: 0.2325 - val_loss: 2.7670 - val_accuracy: 0.2388
# Epoch 27/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.6723 - accuracy: 0.2420 - val_loss: 2.7398 - val_accuracy: 0.2369
# Epoch 28/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.6400 - accuracy: 0.2465 - val_loss: 2.7211 - val_accuracy: 0.2539
# Epoch 29/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.6110 - accuracy: 0.2577 - val_loss: 2.6910 - val_accuracy: 0.2527
# Epoch 30/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.5833 - accuracy: 0.2601 - val_loss: 2.6669 - val_accuracy: 0.2562
#
# Addestrando con filtri [64, 128, 256, 512] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 2s 5ms/step - loss: 3.4158 - accuracy: 0.0611 - val_loss: 3.0392 - val_accuracy: 0.1235
# Epoch 2/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.7701 - accuracy: 0.1905 - val_loss: 2.4829 - val_accuracy: 0.2515
# Epoch 3/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.2438 - accuracy: 0.3316 - val_loss: 1.9740 - val_accuracy: 0.4144
# Epoch 4/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.8391 - accuracy: 0.4481 - val_loss: 1.7896 - val_accuracy: 0.4803
# Epoch 5/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.5696 - accuracy: 0.5231 - val_loss: 1.6141 - val_accuracy: 0.5471
# Epoch 6/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.3334 - accuracy: 0.5985 - val_loss: 1.5814 - val_accuracy: 0.5532
# Epoch 7/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.2202 - accuracy: 0.6356 - val_loss: 1.6153 - val_accuracy: 0.5648
# Epoch 8/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.0937 - accuracy: 0.6643 - val_loss: 1.6325 - val_accuracy: 0.5799
# Epoch 9/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.0053 - accuracy: 0.6996 - val_loss: 1.5485 - val_accuracy: 0.6046
# Epoch 10/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8933 - accuracy: 0.7265 - val_loss: 1.6617 - val_accuracy: 0.6007
# Epoch 11/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8571 - accuracy: 0.7410 - val_loss: 1.5937 - val_accuracy: 0.6065
# Epoch 12/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7496 - accuracy: 0.7745 - val_loss: 1.6379 - val_accuracy: 0.6227
# Epoch 13/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7217 - accuracy: 0.7784 - val_loss: 1.7335 - val_accuracy: 0.6231
# Epoch 14/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7065 - accuracy: 0.7867 - val_loss: 1.7575 - val_accuracy: 0.6211
#
# Addestrando con filtri [64, 128, 256, 512] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 1s 5ms/step - loss: 3.4771 - accuracy: 0.0546 - val_loss: 3.2183 - val_accuracy: 0.1100
# Epoch 2/30
# 243/243 [==============================] - 1s 5ms/step - loss: 3.0713 - accuracy: 0.1372 - val_loss: 2.7521 - val_accuracy: 0.2326
# Epoch 3/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.6433 - accuracy: 0.2363 - val_loss: 2.4081 - val_accuracy: 0.3218
# Epoch 4/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.2912 - accuracy: 0.3356 - val_loss: 2.1397 - val_accuracy: 0.4032
# Epoch 5/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.9833 - accuracy: 0.4245 - val_loss: 1.8990 - val_accuracy: 0.4653
# Epoch 6/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.7037 - accuracy: 0.5101 - val_loss: 1.7799 - val_accuracy: 0.4934
# Epoch 7/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.4403 - accuracy: 0.5719 - val_loss: 1.5860 - val_accuracy: 0.5328
# Epoch 8/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.2422 - accuracy: 0.6282 - val_loss: 1.5408 - val_accuracy: 0.5559
# Epoch 9/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.0480 - accuracy: 0.6853 - val_loss: 1.4634 - val_accuracy: 0.5826
# Epoch 10/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8895 - accuracy: 0.7311 - val_loss: 1.4009 - val_accuracy: 0.5941
# Epoch 11/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7691 - accuracy: 0.7688 - val_loss: 1.3496 - val_accuracy: 0.6181
# Epoch 12/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6458 - accuracy: 0.8023 - val_loss: 1.3594 - val_accuracy: 0.6211
# Epoch 13/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5541 - accuracy: 0.8314 - val_loss: 1.3510 - val_accuracy: 0.6269
# Epoch 14/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4722 - accuracy: 0.8535 - val_loss: 1.3369 - val_accuracy: 0.6389
# Epoch 15/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4249 - accuracy: 0.8680 - val_loss: 1.3582 - val_accuracy: 0.6412
# Epoch 16/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3630 - accuracy: 0.8897 - val_loss: 1.4104 - val_accuracy: 0.6435
# Epoch 17/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3005 - accuracy: 0.9104 - val_loss: 1.4773 - val_accuracy: 0.6335
# Epoch 18/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2837 - accuracy: 0.9120 - val_loss: 1.3876 - val_accuracy: 0.6582
# Epoch 19/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2582 - accuracy: 0.9200 - val_loss: 1.4539 - val_accuracy: 0.6370
#
# Addestrando con filtri [64, 128, 256, 512] e tasso di apprendimento 1e-05
# Epoch 1/30
# 243/243 [==============================] - 1s 5ms/step - loss: 3.8988 - accuracy: 0.0405 - val_loss: 3.3665 - val_accuracy: 0.0521
# Epoch 2/30
# 243/243 [==============================] - 1s 5ms/step - loss: 3.3991 - accuracy: 0.0563 - val_loss: 3.3231 - val_accuracy: 0.0741
# Epoch 3/30
# 243/243 [==============================] - 1s 5ms/step - loss: 3.3286 - accuracy: 0.0707 - val_loss: 3.2755 - val_accuracy: 0.0922
# Epoch 4/30
# 243/243 [==============================] - 1s 5ms/step - loss: 3.2549 - accuracy: 0.0914 - val_loss: 3.2175 - val_accuracy: 0.1165
# Epoch 5/30
# 243/243 [==============================] - 1s 5ms/step - loss: 3.1854 - accuracy: 0.1153 - val_loss: 3.1537 - val_accuracy: 0.1420
# Epoch 6/30
# 243/243 [==============================] - 1s 5ms/step - loss: 3.1081 - accuracy: 0.1349 - val_loss: 3.0668 - val_accuracy: 0.1713
# Epoch 7/30
# 243/243 [==============================] - 1s 5ms/step - loss: 3.0200 - accuracy: 0.1570 - val_loss: 2.9855 - val_accuracy: 0.1860
# Epoch 8/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.9179 - accuracy: 0.1879 - val_loss: 2.8991 - val_accuracy: 0.2153
# Epoch 9/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.8309 - accuracy: 0.2046 - val_loss: 2.8149 - val_accuracy: 0.2319
# Epoch 10/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.7328 - accuracy: 0.2269 - val_loss: 2.7447 - val_accuracy: 0.2423
# Epoch 11/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.6454 - accuracy: 0.2539 - val_loss: 2.6683 - val_accuracy: 0.2623
# Epoch 12/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.5495 - accuracy: 0.2702 - val_loss: 2.5971 - val_accuracy: 0.2824
# Epoch 13/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.5006 - accuracy: 0.2898 - val_loss: 2.5491 - val_accuracy: 0.2967
# Epoch 14/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.4079 - accuracy: 0.3112 - val_loss: 2.4986 - val_accuracy: 0.2932
# Epoch 15/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.3469 - accuracy: 0.3308 - val_loss: 2.4483 - val_accuracy: 0.3167
# Epoch 16/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.2852 - accuracy: 0.3430 - val_loss: 2.4061 - val_accuracy: 0.3314
# Epoch 17/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.2301 - accuracy: 0.3635 - val_loss: 2.3618 - val_accuracy: 0.3441
# Epoch 18/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.1539 - accuracy: 0.3809 - val_loss: 2.3223 - val_accuracy: 0.3530
# Epoch 19/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.0984 - accuracy: 0.3964 - val_loss: 2.2814 - val_accuracy: 0.3607
# Epoch 20/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.0616 - accuracy: 0.4041 - val_loss: 2.2538 - val_accuracy: 0.3692
# Epoch 21/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.0013 - accuracy: 0.4294 - val_loss: 2.2273 - val_accuracy: 0.3673
# Epoch 22/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.9479 - accuracy: 0.4437 - val_loss: 2.2019 - val_accuracy: 0.3854
# Epoch 23/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.9118 - accuracy: 0.4532 - val_loss: 2.1681 - val_accuracy: 0.3927
# Epoch 24/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.8479 - accuracy: 0.4692 - val_loss: 2.1331 - val_accuracy: 0.4051
# Epoch 25/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.8116 - accuracy: 0.4869 - val_loss: 2.0994 - val_accuracy: 0.4194
# Epoch 26/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.7527 - accuracy: 0.5021 - val_loss: 2.0764 - val_accuracy: 0.4213
# Epoch 27/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.7313 - accuracy: 0.5012 - val_loss: 2.0547 - val_accuracy: 0.4294
# Epoch 28/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.6855 - accuracy: 0.5153 - val_loss: 2.0359 - val_accuracy: 0.4321
# Epoch 29/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.6344 - accuracy: 0.5309 - val_loss: 2.0140 - val_accuracy: 0.4479
# Epoch 30/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.5973 - accuracy: 0.5347 - val_loss: 1.9867 - val_accuracy: 0.4487
#
# Tempo totale trascorso: 3 minuti e 31 secondi

# %% [markdown]
# Il tempo necessario per la ricerca dei migliori iperparametri è stata di **3 minuti e 31 secondi**.

# %%
plot_models(path="model_tuning/noise/adam/mfcc", show="accuracy")
plot_models(path="model_tuning/noise/adam/mfcc", show="loss")

# %% [markdown]
# Dai grafici emerge che la combinazione più performante è composta da **XX filtri di partenza** e un **tasso di apprendimento di XX**, poiché ritarda maggiormente l'overfitting. Altre combinazioni, come **XX filtri di partenza** e un **tasso di apprendimento di 1e-5**, mostrano buone prestazioni ma anche un inizio di overfitting, evidenziato dallo distaccamento tra la perdita di addestramento e quella di validazione.
#
# Procediamo quindi con l'addestramento del modello con **XX filtri di partenza** e un **tasso di apprendimento di XX**. Come di consueto, salviamo i risultati in un file `keras` e la cronologia (history) in un file `csv`. Infine, convertiamo il file in formato `onnx`.

# %%
for audio, label in mfcc_mixed_train_ds:
    tuned_improved_basic_model = get_improved_basic_model(audio.shape[1:])
    
tuned_improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), metrics=["accuracy"])

tuned_improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/noise/adam/mfcc/tuned_improved_basic_model_mfcc.keras", save_best_only=True, monitor="val_loss")]
tuned_improved_history = tuned_improved_basic_model.fit(mfcc_mixed_train_ds, epochs=100, validation_data=mfcc_mixed_val_ds, callbacks=tuned_improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 2s 5ms/step - loss: 3.5418 - accuracy: 0.0465 - val_loss: 3.3334 - val_accuracy: 0.0687
# Epoch 2/100
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2904 - accuracy: 0.0776 - val_loss: 3.1290 - val_accuracy: 0.1246
# Epoch 3/100
# 243/243 [==============================] - 1s 4ms/step - loss: 3.0404 - accuracy: 0.1367 - val_loss: 2.8531 - val_accuracy: 0.1860
# Epoch 4/100
# 243/243 [==============================] - 1s 4ms/step - loss: 2.7613 - accuracy: 0.2064 - val_loss: 2.6427 - val_accuracy: 0.2388
# Epoch 5/100
# 243/243 [==============================] - 1s 4ms/step - loss: 2.5315 - accuracy: 0.2689 - val_loss: 2.4345 - val_accuracy: 0.3032
# Epoch 6/100
# 243/243 [==============================] - 1s 4ms/step - loss: 2.3282 - accuracy: 0.3282 - val_loss: 2.2802 - val_accuracy: 0.3465
# Epoch 7/100
# 243/243 [==============================] - 1s 4ms/step - loss: 2.1150 - accuracy: 0.3903 - val_loss: 2.1929 - val_accuracy: 0.3746
# Epoch 8/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.9389 - accuracy: 0.4336 - val_loss: 2.0680 - val_accuracy: 0.4032
# Epoch 9/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.7615 - accuracy: 0.4808 - val_loss: 1.9930 - val_accuracy: 0.4217
# Epoch 10/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.6124 - accuracy: 0.5231 - val_loss: 1.8946 - val_accuracy: 0.4599
# Epoch 11/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.4684 - accuracy: 0.5652 - val_loss: 1.8211 - val_accuracy: 0.4815
# Epoch 12/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.3559 - accuracy: 0.6080 - val_loss: 1.7817 - val_accuracy: 0.4977
# Epoch 13/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.2339 - accuracy: 0.6340 - val_loss: 1.7217 - val_accuracy: 0.5023
# Epoch 14/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.1205 - accuracy: 0.6670 - val_loss: 1.6795 - val_accuracy: 0.5258
# Epoch 15/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.0192 - accuracy: 0.6990 - val_loss: 1.6661 - val_accuracy: 0.5309
# Epoch 16/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.9469 - accuracy: 0.7157 - val_loss: 1.6470 - val_accuracy: 0.5417
# Epoch 17/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8537 - accuracy: 0.7433 - val_loss: 1.6033 - val_accuracy: 0.5536
# Epoch 18/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7752 - accuracy: 0.7642 - val_loss: 1.6097 - val_accuracy: 0.5498
# Epoch 19/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7180 - accuracy: 0.7871 - val_loss: 1.6004 - val_accuracy: 0.5563
# Epoch 20/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6600 - accuracy: 0.7965 - val_loss: 1.6332 - val_accuracy: 0.5478
# Epoch 21/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5808 - accuracy: 0.8246 - val_loss: 1.6088 - val_accuracy: 0.5679
# Epoch 22/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5611 - accuracy: 0.8284 - val_loss: 1.6697 - val_accuracy: 0.5540
# Epoch 23/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5176 - accuracy: 0.8405 - val_loss: 1.6665 - val_accuracy: 0.5556
# Epoch 24/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4778 - accuracy: 0.8559 - val_loss: 1.7725 - val_accuracy: 0.5525
# Epoch 25/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4315 - accuracy: 0.8668 - val_loss: 1.7079 - val_accuracy: 0.5606
# Epoch 26/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4066 - accuracy: 0.8755 - val_loss: 1.7638 - val_accuracy: 0.5532
# Epoch 27/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3791 - accuracy: 0.8816 - val_loss: 1.7568 - val_accuracy: 0.5594
# Epoch 28/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3573 - accuracy: 0.8915 - val_loss: 1.7316 - val_accuracy: 0.5683
# Epoch 29/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3298 - accuracy: 0.9000 - val_loss: 1.7004 - val_accuracy: 0.5714
# Epoch 30/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3113 - accuracy: 0.9068 - val_loss: 1.7602 - val_accuracy: 0.5671
# Epoch 31/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2789 - accuracy: 0.9162 - val_loss: 1.7124 - val_accuracy: 0.5814
# Epoch 32/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.2645 - accuracy: 0.9193 - val_loss: 1.7356 - val_accuracy: 0.5837
# Epoch 33/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2553 - accuracy: 0.9218 - val_loss: 1.7052 - val_accuracy: 0.5810
# Epoch 34/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2269 - accuracy: 0.9339 - val_loss: 1.7276 - val_accuracy: 0.5903
# Epoch 35/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2214 - accuracy: 0.9339 - val_loss: 1.7370 - val_accuracy: 0.5926
# Epoch 36/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.2115 - accuracy: 0.9363 - val_loss: 1.7207 - val_accuracy: 0.6042
# Epoch 37/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1910 - accuracy: 0.9434 - val_loss: 1.7446 - val_accuracy: 0.5961
# Epoch 38/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2052 - accuracy: 0.9371 - val_loss: 1.6941 - val_accuracy: 0.6046
# Epoch 39/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.1771 - accuracy: 0.9494 - val_loss: 1.7825 - val_accuracy: 0.5968
# Epoch 40/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.1658 - accuracy: 0.9488 - val_loss: 1.7641 - val_accuracy: 0.6111
# Epoch 41/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.1712 - accuracy: 0.9499 - val_loss: 1.8949 - val_accuracy: 0.5899
# Epoch 42/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.1638 - accuracy: 0.9468 - val_loss: 1.8326 - val_accuracy: 0.6030
# Epoch 43/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.1585 - accuracy: 0.9548 - val_loss: 1.7737 - val_accuracy: 0.6034
# Epoch 44/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.1369 - accuracy: 0.9593 - val_loss: 1.8576 - val_accuracy: 0.5976
# Epoch 45/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1329 - accuracy: 0.9603 - val_loss: 1.8465 - val_accuracy: 0.6026
# Epoch 46/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.1275 - accuracy: 0.9610 - val_loss: 1.8737 - val_accuracy: 0.5961
# Epoch 47/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.1381 - accuracy: 0.9588 - val_loss: 1.8196 - val_accuracy: 0.6138
# Epoch 48/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.1229 - accuracy: 0.9635 - val_loss: 1.9488 - val_accuracy: 0.6065
# Epoch 49/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1253 - accuracy: 0.9607 - val_loss: 1.8907 - val_accuracy: 0.5972
# Epoch 50/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1207 - accuracy: 0.9631 - val_loss: 1.8143 - val_accuracy: 0.6123
# Epoch 51/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1128 - accuracy: 0.9671 - val_loss: 1.8388 - val_accuracy: 0.6173
# Epoch 52/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1279 - accuracy: 0.9617 - val_loss: 1.8802 - val_accuracy: 0.6026
# Epoch 53/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0949 - accuracy: 0.9713 - val_loss: 1.9755 - val_accuracy: 0.6173
# Epoch 54/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1032 - accuracy: 0.9698 - val_loss: 1.9216 - val_accuracy: 0.6165
# Epoch 55/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1049 - accuracy: 0.9695 - val_loss: 1.9279 - val_accuracy: 0.6165
# Epoch 56/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0853 - accuracy: 0.9741 - val_loss: 1.9399 - val_accuracy: 0.6115
# Epoch 57/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0994 - accuracy: 0.9688 - val_loss: 2.0788 - val_accuracy: 0.5999
# Epoch 58/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0961 - accuracy: 0.9713 - val_loss: 2.0291 - val_accuracy: 0.5999
# Epoch 59/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0997 - accuracy: 0.9704 - val_loss: 2.0113 - val_accuracy: 0.6053
# Epoch 60/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0942 - accuracy: 0.9728 - val_loss: 1.9931 - val_accuracy: 0.6080
# Epoch 61/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0949 - accuracy: 0.9720 - val_loss: 2.0040 - val_accuracy: 0.6154
# Epoch 62/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0760 - accuracy: 0.9780 - val_loss: 2.0173 - val_accuracy: 0.6219
# Epoch 63/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0932 - accuracy: 0.9719 - val_loss: 1.9566 - val_accuracy: 0.6192
# Epoch 64/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0793 - accuracy: 0.9764 - val_loss: 1.9640 - val_accuracy: 0.6150
# Epoch 65/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0743 - accuracy: 0.9796 - val_loss: 1.9237 - val_accuracy: 0.6254
# Epoch 66/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0826 - accuracy: 0.9762 - val_loss: 1.9705 - val_accuracy: 0.6304
# Epoch 67/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0721 - accuracy: 0.9803 - val_loss: 1.9608 - val_accuracy: 0.6192
# Epoch 68/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0691 - accuracy: 0.9794 - val_loss: 2.0534 - val_accuracy: 0.6188
# Epoch 69/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0765 - accuracy: 0.9776 - val_loss: 1.9924 - val_accuracy: 0.6254
# Epoch 70/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0824 - accuracy: 0.9755 - val_loss: 2.0611 - val_accuracy: 0.6123
# Epoch 71/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0711 - accuracy: 0.9786 - val_loss: 1.9950 - val_accuracy: 0.6235
# Epoch 72/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0608 - accuracy: 0.9816 - val_loss: 2.0133 - val_accuracy: 0.6235
# Epoch 73/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0611 - accuracy: 0.9829 - val_loss: 2.1324 - val_accuracy: 0.6169
# Epoch 74/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0725 - accuracy: 0.9756 - val_loss: 2.1849 - val_accuracy: 0.6138
# Epoch 75/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0632 - accuracy: 0.9791 - val_loss: 2.0508 - val_accuracy: 0.6312
# Epoch 76/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0529 - accuracy: 0.9835 - val_loss: 2.0949 - val_accuracy: 0.6289
# Epoch 77/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0651 - accuracy: 0.9809 - val_loss: 2.1387 - val_accuracy: 0.6235
# Epoch 78/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0662 - accuracy: 0.9802 - val_loss: 2.0327 - val_accuracy: 0.6184
# Epoch 79/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0675 - accuracy: 0.9799 - val_loss: 2.0563 - val_accuracy: 0.6335
# Epoch 80/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0693 - accuracy: 0.9795 - val_loss: 2.0089 - val_accuracy: 0.6258
# Epoch 81/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0500 - accuracy: 0.9857 - val_loss: 2.1637 - val_accuracy: 0.6231
# Epoch 82/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0532 - accuracy: 0.9827 - val_loss: 2.2076 - val_accuracy: 0.6188
# Epoch 83/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0503 - accuracy: 0.9843 - val_loss: 2.1416 - val_accuracy: 0.6358
# Epoch 84/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0607 - accuracy: 0.9802 - val_loss: 2.2106 - val_accuracy: 0.6184
# Epoch 85/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0513 - accuracy: 0.9840 - val_loss: 2.2308 - val_accuracy: 0.6242
# Epoch 86/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0503 - accuracy: 0.9862 - val_loss: 2.1711 - val_accuracy: 0.6381
# Epoch 87/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0517 - accuracy: 0.9839 - val_loss: 2.2487 - val_accuracy: 0.6238
# Epoch 88/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0656 - accuracy: 0.9821 - val_loss: 2.1821 - val_accuracy: 0.6161
# Epoch 89/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0666 - accuracy: 0.9787 - val_loss: 2.1224 - val_accuracy: 0.6412
# Epoch 90/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0581 - accuracy: 0.9835 - val_loss: 2.3047 - val_accuracy: 0.6134
# Epoch 91/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0585 - accuracy: 0.9817 - val_loss: 2.1371 - val_accuracy: 0.6296
# Epoch 92/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0525 - accuracy: 0.9832 - val_loss: 2.2163 - val_accuracy: 0.6312
# Epoch 93/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.0439 - accuracy: 0.9876 - val_loss: 2.2623 - val_accuracy: 0.6285
# Epoch 94/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.0460 - accuracy: 0.9860 - val_loss: 2.1884 - val_accuracy: 0.6238
# Epoch 95/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0499 - accuracy: 0.9840 - val_loss: 2.1881 - val_accuracy: 0.6296
# Epoch 96/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0425 - accuracy: 0.9880 - val_loss: 2.2764 - val_accuracy: 0.6223
# Epoch 97/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0487 - accuracy: 0.9831 - val_loss: 2.1339 - val_accuracy: 0.6393
# Epoch 98/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0520 - accuracy: 0.9840 - val_loss: 2.2442 - val_accuracy: 0.6289
# Epoch 99/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0534 - accuracy: 0.9838 - val_loss: 2.2855 - val_accuracy: 0.6316
# Epoch 100/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0564 - accuracy: 0.9823 - val_loss: 2.1873 - val_accuracy: 0.6404

# %%
tuned_improved_history_df = convert_history_to_csv(tuned_improved_history)
tuned_improved_history_df.to_csv("model_histories/noise/adam/mfcc/tuned_improved_history_mfcc.csv")

convert_model_to_onnx("bestmodels/noise/adam/mfcc/tuned_improved_basic_model_mfcc.keras", (98, 12, 1))

# %%
create_train_val_plot(tuned_improved_history.history)

# %%
tuned_improved_best_model = tf.keras.models.load_model("bestmodels/noise/adam/mfcc/tuned_improved_basic_model_mfcc.keras")
test_loss, test_acc = tuned_improved_best_model.evaluate(mfcc_mixed_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 2ms/step - loss: 1.5363 - accuracy: 0.5668
# Accuratezza: 0.567

# %%
evaluate_onnx_model("bestmodels/noise/adam/mfcc/tuned_improved_basic_model_mfcc.onnx", mfcc_mixed_test_ds)
# Out:
# Accuratezza: 0.566

# %% [markdown]
# AGGIUNGERE COMMENTO SU COME SI E' AGGIORNATO. L'accuratezza è attualmente **XX%**.

# %%
for audio, label in mfcc_mixed_test_ds:
    create_distribution_plot(tuned_improved_best_model, audio, label)
    break

# %% [markdown]
# ### Miglioramenti all'architettura del modello
# Procediamo quindi con la fase corrispettiva al notebook di riferimento.

# %%
def bp_basic_model():
    # input e pre processamento
    inputs = tf.keras.Input(shape=(98, 12, 1))
    
    x = residual_block(inputs, 32, pooling=True)
    x = residual_block(x, 64, pooling=True)
    x = residual_block(x, 128, pooling=True)
    x = residual_block(x, 256, pooling=True)
    x = residual_block(x, 256, pooling=False)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Livelli per la classificazione
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
bp_basic_model = bp_basic_model()
bp_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

bp_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/noise/adam/mfcc/bp_basic_model_mfcc.keras", save_best_only=True, monitor="val_loss")]
bp_model_history = bp_basic_model.fit(mfcc_mixed_train_ds, epochs=100, validation_data=mfcc_mixed_val_ds, callbacks=bp_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 2s 6ms/step - loss: 5.2090 - accuracy: 0.0521 - val_loss: 3.4368 - val_accuracy: 0.0883
# Epoch 2/100
# 243/243 [==============================] - 1s 5ms/step - loss: 3.4367 - accuracy: 0.0970 - val_loss: 3.2160 - val_accuracy: 0.1223
# Epoch 3/100
# 243/243 [==============================] - 1s 5ms/step - loss: 3.1663 - accuracy: 0.1347 - val_loss: 3.0941 - val_accuracy: 0.1462
# Epoch 4/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.9698 - accuracy: 0.1710 - val_loss: 2.8425 - val_accuracy: 0.1898
# Epoch 5/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.7695 - accuracy: 0.2164 - val_loss: 2.8219 - val_accuracy: 0.1906
# Epoch 6/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.5888 - accuracy: 0.2622 - val_loss: 3.0888 - val_accuracy: 0.2122
# Epoch 7/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.4374 - accuracy: 0.2972 - val_loss: 2.9680 - val_accuracy: 0.2388
# Epoch 8/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.2808 - accuracy: 0.3446 - val_loss: 2.4244 - val_accuracy: 0.3272
# Epoch 9/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.1498 - accuracy: 0.3759 - val_loss: 2.4633 - val_accuracy: 0.3279
# Epoch 10/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.0202 - accuracy: 0.4140 - val_loss: 2.2103 - val_accuracy: 0.3846
# Epoch 11/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.8650 - accuracy: 0.4575 - val_loss: 2.0391 - val_accuracy: 0.4306
# Epoch 12/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.7526 - accuracy: 0.4888 - val_loss: 2.1168 - val_accuracy: 0.4201
# Epoch 13/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.6488 - accuracy: 0.5201 - val_loss: 1.7380 - val_accuracy: 0.5042
# Epoch 14/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.5140 - accuracy: 0.5561 - val_loss: 1.6893 - val_accuracy: 0.5189
# Epoch 15/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.4213 - accuracy: 0.5796 - val_loss: 1.7698 - val_accuracy: 0.4942
# Epoch 16/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.3483 - accuracy: 0.6012 - val_loss: 1.7489 - val_accuracy: 0.5066
# Epoch 17/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.2612 - accuracy: 0.6286 - val_loss: 1.6398 - val_accuracy: 0.5413
# Epoch 18/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.1809 - accuracy: 0.6534 - val_loss: 1.8664 - val_accuracy: 0.4904
# Epoch 19/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.1206 - accuracy: 0.6588 - val_loss: 1.6311 - val_accuracy: 0.5467
# Epoch 20/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.0551 - accuracy: 0.6825 - val_loss: 1.4955 - val_accuracy: 0.5810
# Epoch 21/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.0146 - accuracy: 0.6928 - val_loss: 1.3995 - val_accuracy: 0.6076
# Epoch 22/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.9678 - accuracy: 0.7032 - val_loss: 1.4827 - val_accuracy: 0.5841
# Epoch 23/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8888 - accuracy: 0.7298 - val_loss: 1.4471 - val_accuracy: 0.5995
# Epoch 24/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8267 - accuracy: 0.7477 - val_loss: 1.5322 - val_accuracy: 0.5845
# Epoch 25/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8257 - accuracy: 0.7423 - val_loss: 1.4180 - val_accuracy: 0.6115
# Epoch 26/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7605 - accuracy: 0.7628 - val_loss: 1.4930 - val_accuracy: 0.5995
# Epoch 27/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7188 - accuracy: 0.7782 - val_loss: 1.5574 - val_accuracy: 0.5984
# Epoch 28/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6747 - accuracy: 0.7896 - val_loss: 1.5030 - val_accuracy: 0.6030
# Epoch 29/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6158 - accuracy: 0.8081 - val_loss: 1.5654 - val_accuracy: 0.5980
# Epoch 30/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5761 - accuracy: 0.8178 - val_loss: 1.6768 - val_accuracy: 0.5992
# Epoch 31/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5331 - accuracy: 0.8345 - val_loss: 1.6914 - val_accuracy: 0.5826
# Epoch 32/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5216 - accuracy: 0.8387 - val_loss: 1.7491 - val_accuracy: 0.5914
# Epoch 33/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4872 - accuracy: 0.8490 - val_loss: 1.7013 - val_accuracy: 0.5968
# Epoch 34/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4697 - accuracy: 0.8478 - val_loss: 1.5102 - val_accuracy: 0.6208
# Epoch 35/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4488 - accuracy: 0.8541 - val_loss: 1.6755 - val_accuracy: 0.6177
# Epoch 36/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4196 - accuracy: 0.8625 - val_loss: 1.5935 - val_accuracy: 0.6231
# Epoch 37/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3903 - accuracy: 0.8776 - val_loss: 1.8997 - val_accuracy: 0.5718
# Epoch 38/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3510 - accuracy: 0.8889 - val_loss: 1.9580 - val_accuracy: 0.5583
# Epoch 39/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3432 - accuracy: 0.8894 - val_loss: 1.7533 - val_accuracy: 0.6046
# Epoch 40/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3238 - accuracy: 0.8929 - val_loss: 1.9870 - val_accuracy: 0.5829
# Epoch 41/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3204 - accuracy: 0.9014 - val_loss: 1.7369 - val_accuracy: 0.5972
# Epoch 42/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2958 - accuracy: 0.9066 - val_loss: 1.7828 - val_accuracy: 0.6127
# Epoch 43/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.2739 - accuracy: 0.9089 - val_loss: 1.9227 - val_accuracy: 0.6019
# Epoch 44/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.2715 - accuracy: 0.9138 - val_loss: 1.9035 - val_accuracy: 0.6065
# Epoch 45/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.2782 - accuracy: 0.9119 - val_loss: 1.8061 - val_accuracy: 0.6154
# Epoch 46/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.2504 - accuracy: 0.9188 - val_loss: 1.8167 - val_accuracy: 0.6227
# Epoch 47/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2431 - accuracy: 0.9175 - val_loss: 1.7808 - val_accuracy: 0.6208
# Epoch 48/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2292 - accuracy: 0.9264 - val_loss: 1.6385 - val_accuracy: 0.6501
# Epoch 49/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2190 - accuracy: 0.9305 - val_loss: 2.0558 - val_accuracy: 0.6100
# Epoch 50/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2239 - accuracy: 0.9250 - val_loss: 1.9470 - val_accuracy: 0.6200
# Epoch 51/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2137 - accuracy: 0.9304 - val_loss: 1.8866 - val_accuracy: 0.6215
# Epoch 52/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.2149 - accuracy: 0.9284 - val_loss: 1.8961 - val_accuracy: 0.6308
# Epoch 53/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2176 - accuracy: 0.9312 - val_loss: 1.7482 - val_accuracy: 0.6474
# Epoch 54/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1921 - accuracy: 0.9351 - val_loss: 2.0306 - val_accuracy: 0.6181
# Epoch 55/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.2007 - accuracy: 0.9345 - val_loss: 1.8840 - val_accuracy: 0.6308
# Epoch 56/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1734 - accuracy: 0.9437 - val_loss: 1.7970 - val_accuracy: 0.6343
# Epoch 57/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1657 - accuracy: 0.9468 - val_loss: 2.1953 - val_accuracy: 0.6069
# Epoch 58/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1771 - accuracy: 0.9425 - val_loss: 1.9363 - val_accuracy: 0.6343
# Epoch 59/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1867 - accuracy: 0.9416 - val_loss: 2.0522 - val_accuracy: 0.6057
# Epoch 60/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1707 - accuracy: 0.9436 - val_loss: 2.0376 - val_accuracy: 0.6223
# Epoch 61/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1917 - accuracy: 0.9367 - val_loss: 2.0435 - val_accuracy: 0.6026
# Epoch 62/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1898 - accuracy: 0.9369 - val_loss: 1.8935 - val_accuracy: 0.6404
# Epoch 63/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1370 - accuracy: 0.9553 - val_loss: 2.1685 - val_accuracy: 0.6127
# Epoch 64/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1476 - accuracy: 0.9514 - val_loss: 1.7524 - val_accuracy: 0.6593
# Epoch 65/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1503 - accuracy: 0.9531 - val_loss: 1.9714 - val_accuracy: 0.6343
# Epoch 66/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1530 - accuracy: 0.9490 - val_loss: 2.4297 - val_accuracy: 0.6042
# Epoch 67/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1545 - accuracy: 0.9485 - val_loss: 2.3609 - val_accuracy: 0.6003
# Epoch 68/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1648 - accuracy: 0.9452 - val_loss: 1.9446 - val_accuracy: 0.6439
# Epoch 69/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1490 - accuracy: 0.9512 - val_loss: 2.2091 - val_accuracy: 0.6196
# Epoch 70/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1559 - accuracy: 0.9472 - val_loss: 2.0473 - val_accuracy: 0.6393
# Epoch 71/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1404 - accuracy: 0.9550 - val_loss: 2.1022 - val_accuracy: 0.6169
# Epoch 72/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1518 - accuracy: 0.9492 - val_loss: 2.2672 - val_accuracy: 0.6150
# Epoch 73/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1415 - accuracy: 0.9553 - val_loss: 2.2637 - val_accuracy: 0.6007
# Epoch 74/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1485 - accuracy: 0.9510 - val_loss: 2.5467 - val_accuracy: 0.5938
# Epoch 75/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1381 - accuracy: 0.9559 - val_loss: 2.5218 - val_accuracy: 0.6022
# Epoch 76/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1219 - accuracy: 0.9607 - val_loss: 2.0463 - val_accuracy: 0.6505
# Epoch 77/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1251 - accuracy: 0.9602 - val_loss: 2.2764 - val_accuracy: 0.6138
# Epoch 78/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1314 - accuracy: 0.9567 - val_loss: 2.2635 - val_accuracy: 0.6196
# Epoch 79/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1274 - accuracy: 0.9595 - val_loss: 2.0658 - val_accuracy: 0.6489
# Epoch 80/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1361 - accuracy: 0.9540 - val_loss: 2.1690 - val_accuracy: 0.6366
# Epoch 81/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1309 - accuracy: 0.9561 - val_loss: 2.1865 - val_accuracy: 0.6424
# Epoch 82/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1355 - accuracy: 0.9566 - val_loss: 2.0451 - val_accuracy: 0.6559
# Epoch 83/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1165 - accuracy: 0.9615 - val_loss: 2.0628 - val_accuracy: 0.6358
# Epoch 84/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1219 - accuracy: 0.9598 - val_loss: 2.0887 - val_accuracy: 0.6339
# Epoch 85/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1302 - accuracy: 0.9561 - val_loss: 2.3299 - val_accuracy: 0.6177
# Epoch 86/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1415 - accuracy: 0.9575 - val_loss: 2.1066 - val_accuracy: 0.6373
# Epoch 87/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1238 - accuracy: 0.9563 - val_loss: 2.2199 - val_accuracy: 0.6254
# Epoch 88/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1066 - accuracy: 0.9643 - val_loss: 2.3487 - val_accuracy: 0.6339
# Epoch 89/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1058 - accuracy: 0.9665 - val_loss: 2.2969 - val_accuracy: 0.6323
# Epoch 90/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1222 - accuracy: 0.9607 - val_loss: 2.3909 - val_accuracy: 0.6157
# Epoch 91/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1273 - accuracy: 0.9593 - val_loss: 2.2594 - val_accuracy: 0.6246
# Epoch 92/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1257 - accuracy: 0.9603 - val_loss: 2.5296 - val_accuracy: 0.6204
# Epoch 93/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1131 - accuracy: 0.9629 - val_loss: 2.1931 - val_accuracy: 0.6420
# Epoch 94/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1080 - accuracy: 0.9639 - val_loss: 2.2095 - val_accuracy: 0.6458
# Epoch 95/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1099 - accuracy: 0.9646 - val_loss: 2.1109 - val_accuracy: 0.6532
# Epoch 96/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0989 - accuracy: 0.9686 - val_loss: 2.3168 - val_accuracy: 0.6427
# Epoch 97/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0995 - accuracy: 0.9659 - val_loss: 2.6478 - val_accuracy: 0.6092
# Epoch 98/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1101 - accuracy: 0.9622 - val_loss: 2.1196 - val_accuracy: 0.6512
# Epoch 99/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1435 - accuracy: 0.9521 - val_loss: 2.0722 - val_accuracy: 0.6404
# Epoch 100/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1205 - accuracy: 0.9590 - val_loss: 2.3822 - val_accuracy: 0.6381

# %% [markdown]
# Salviamo nuovamente la history del modello in un file csv e convertiamo il miglior modello nel formato **.onnx**.

# %%
bp_model_history_df = convert_history_to_csv(bp_model_history)
bp_model_history_df.to_csv("model_histories/noise/adam/mfcc/bp_model_history_mfcc.csv")

convert_model_to_onnx("bestmodels/noise/adam/mfcc/bp_basic_model_mfcc.keras", (98, 12, 1))

# %%
create_train_val_plot(bp_model_history.history)

# %% [markdown]
# In questo caso il modello **HA raggiunto una fase di overfitting**, inoltre le prestazioni sono diminuite di parecchio sotto qualsiasi aspetto.

# %%
best_bp_basic_model = tf.keras.models.load_model("bestmodels/noise/adam/mfcc/bp_basic_model_mfcc.keras")
test_loss, test_acc = best_bp_basic_model.evaluate(mfcc_mixed_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 2ms/step - loss: 1.3730 - accuracy: 0.5967
# Accuratezza: 0.597

# %%
evaluate_onnx_model("bestmodels/noise/adam/mfcc/bp_basic_model_mfcc.onnx", mfcc_mixed_test_ds)
# Out:
# Accuratezza: 0.597

# %% [markdown]
# Abbiamo ottenuto un forte peggioramento per quanto riguarda l'accuratezza, ottenendo un **62.1%**.

# %%
for audio, label in mfcc_mixed_test_ds:
    create_distribution_plot(best_bp_basic_model, audio, label)
    break
