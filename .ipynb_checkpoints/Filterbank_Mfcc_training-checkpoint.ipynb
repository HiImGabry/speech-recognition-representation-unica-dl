# %% [markdown]
# # Addestramento modello convolutivo
# Nel seguente notebook verranno addestrati i modelli presenti nel notebook [Modello convolutivo](Modello_convolutivo.ipynb), utilizzando come tipo di dati i **filterbanks** e gli **mfcc**. Ci aspettiamo di ottenere risultati differenti e sarà interessante analizzare quale dataset riuscirà ad ottenere prestazioni migliori.
#
# *oppure "Ci aspettiamo di ottenere risultati differenti e sarà interessante analizzare le differenze"* scegliete voi @Andre

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import scipy.fftpack as scipy
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# per il modello con estensione .onnx
import onnxruntime as rt
import tf2onnx
import onnx

# %% [markdown]
# ## Classe per la conversione del dataset
# Vista la quantità di opzioni disponibili, si è scelto di creare una classe. Essa contiene il metodo `convert` in grado di trasformare il dataset di audio in spettrogrammi, filterbanks, o mfcc in base all'argomento dato in input. Gli altri metodi presenti al suo interno sono già stati spiegati e ne abbiamo visto l'utilizzo nei precedenti notebook.

# %%
class DatasetConverter:
    def __init__(self, dataset):
        self.dataset = dataset

    def convert(self, option):
        available_options = ['spettrogrammi', 'filterbanks', 'mfcc']
        
        if option == available_options[0]:
            return self.get_spectrogram_dataset()
        elif option == available_options[1]:
            return self.get_filterbanks_dataset()
        elif option == available_options[2]:
            return self.get_mfcc_dataset()
        else:
            raise ValueError(f"Opzione non disponibile: inserire una delle seguenti opzioni: {available_options}")
    
    # INIZIO SPETTROGRAMMI
    def squeeze(self, audio, labels):
        audio = tf.squeeze(audio, axis=-1)
        return audio, labels
    
    def get_spectrogram(self, waveform):
    # applichiamo la short-time Fourier transorm
        spectrogram = tf.signal.stft(waveform, frame_length=255, frame_step=128)
        spectrogram = tf.abs(spectrogram)
        
        return spectrogram[..., tf.newaxis]
    
    def get_spectrogram_dataset(self):
        # squeeze
        self.dataset = self.dataset.map(self.squeeze, tf.data.AUTOTUNE)
        self.dataset = self.dataset.map(lambda x, y: (self.get_spectrogram(x), y), num_parallel_calls=tf.data.AUTOTUNE)
        
        return self.dataset

    # FINE SPETTROGRAMMI

    def convert_to_numpy(self, dataset):
        audio_data = []
        labels = []
    
        dataset = dataset.unbatch()
        
        for audio, label in dataset:
            audio_data.append(audio.numpy())  # Assuming audio is a tensor, convert to numpy array
            labels.append(label.numpy())      # Assuming label is a tensor, convert to numpy array
        
        audio_data = np.array(audio_data)
        labels = np.array(labels)
        
        return audio_data, labels
    
    # INIZIO FILTERBANKS
    def makeHamming(self, M):
        R = (( M - 1 ) / 2 , M / 2)[M % 2 == 0]
        w = (np.hamming(M), np.hamming(M + 1))[M % 2 == 0]
        if M % 2 != 0:
            w[0] = w[0]/2
            w[M-1] = w[M-1]/2
        else:
            w = w[:M]
    
        return w

    def hztomel(self, hz):
        return (2595 * np.log10(1 + hz / 700))

    def meltohz(self, mel):
        return (700 * (10**(mel / 2595) - 1))

    def compute_filterbanks(self, audios_np, pre_emphasis=0.97, sample_rate=16000, frame_size=0.025, frame_stride=0.01, NFFT=512, nfilt=40):
        filterbanks_np = []
        
        for samples in audios_np:
            emphasized_audio = np.append(samples[0], samples[1:] - pre_emphasis * samples[:-1])
            audio_length = len(emphasized_audio)
    
            frame_length, frame_step = int(frame_size * sample_rate), int(frame_stride * sample_rate)
    
            num_frames = int(np.ceil(float(np.abs(audio_length - frame_length)) / frame_step))
    
            pad_audio_length = num_frames * frame_step + frame_length
            z = np.zeros((pad_audio_length - audio_length))
            pad_audio = np.append(emphasized_audio, z)
    
            indices = np.tile(np.arange(0, frame_length), (num_frames, 1)) + np.tile(np.arange(0, num_frames * frame_step, frame_step), (frame_length, 1)).T
            frames = pad_audio[indices.astype(np.int32, copy=False)]
    
            # Usiamo la funzione di Hamming
            hamming_window = self.makeHamming(frame_length)
    
            mag_frames = np.absolute(np.fft.rfft(frames, NFFT))  # Magnitudo della FFT
            pow_frames = ((1.0 / NFFT) * ((mag_frames) ** 2))
    
            # convertiamo hz in mel
            low_freq_mel = self.hztomel(0)
            high_freq_mel = self.hztomel(sample_rate / 2)
    
            mel_points = np.linspace(low_freq_mel, high_freq_mel, nfilt + 2)
            hz_points = self.meltohz(mel_points) 
    
            bin = np.floor((NFFT + 1) * hz_points / sample_rate)
    
            fbank = np.zeros((nfilt, int(np.floor(NFFT / 2 + 1))))
    
            for m in range(1, nfilt + 1):
                f_m_minus = int(bin[m - 1])
                f_m = int(bin[m])
                f_m_plus = int(bin[m + 1])
    
                for k in range(f_m_minus, f_m):
                    fbank[m - 1, k] = (k - bin[m - 1]) / (bin[m] - bin[m - 1])
                for k in range(f_m, f_m_plus):
                    fbank[m - 1, k] = (bin[m + 1] - k) / (bin[m + 1] - bin[m])
    
            # in questo momento invece calcoliamo i filter banks per i segmenti di audio, utilizzando i filtri triangolari appena creati
            filter_banks = np.dot(pow_frames, fbank.T)
            filter_banks = np.where(filter_banks == 0, np.finfo(float).eps, filter_banks)
            filter_banks = 20 * np.log10(filter_banks)
    
            filterbanks_np.append(filter_banks)
        
        return np.array(filterbanks_np)
    
    def get_filterbanks_dataset(self): 
        audios, labels = self.convert_to_numpy(self.dataset)

        filterbanks = self.compute_filterbanks(audios)
        filterbanks = np.expand_dims(filterbanks, axis=-1)

        self.dataset = tf.data.Dataset.from_tensor_slices((filterbanks, labels))
        self.dataset = self.dataset.batch(32)
        
        return self.dataset
    # FINE FILTERBANKS

    # INIZIO MFCC
    def compute_mfcc(self, filter_banks, num_ceps=12, cep_lifter=22):
        mfcc_np = []
        
        for f in filter_banks:
            mfcc = scipy.dct(f, type=2, axis=1, norm='ortho')[:, 1 : (num_ceps + 1)]

            (nframes, ncoeff) = mfcc.shape
            n = np.arange(ncoeff)
            
            lift = 1 + (cep_lifter / 2) * np.sin(np.pi * n / cep_lifter)
            mfcc *= lift

            mfcc_np.append(mfcc)
        
        return np.array(mfcc_np)
    
    
    def get_mfcc_dataset(self):
        audios, labels = self.convert_to_numpy(self.dataset)

        filterbanks = self.compute_filterbanks(audios)
        mfcc = self.compute_mfcc(filterbanks)
        
        mfcc = np.expand_dims(mfcc, axis=-1)
        
        self.dataset = tf.data.Dataset.from_tensor_slices((mfcc, labels))
        self.dataset = self.dataset.batch(32)
        
        return self.dataset
    
    # FINE MFCC

# %% [markdown]
# ## Importazione funzioni ulteriori
# In aggiunta alla classe per la conversione del dataset, ci serviremo delle seguenti funzioni:
# - `convert_history_to_csv` - salva l'history dell'addestramento in un csv
# - `convert_model_to_onnx` - converte il miglior modello **.keras** in **.onnx**
# - `create_train_val_plot` - visualizza l'andamento dell'accuratezza e della perdita durante l'addestramento
# - `evaluate_onnx_model` - valuta il modello sui dati di test con il modello **.onnx**
# - `create_distribution_plot` - visualizza la distribuzione di accuratezza delle classi su un'immagine casuale
#
# Anch'esse sono già state viste, perciò non ci soffermeremo troppo su di esse.

# %%
def convert_history_to_csv(model_history):
    # converto la history del dataframe in un dataframe pandas
    model_history_df = pd.DataFrame(model_history.history)
    # cambio il nome dell'indice e lo imposto a partire da 1
    model_history_df.index = range(1, len(model_history_df) + 1)
    model_history_df.index.name = "epochs"

    return model_history_df

def convert_model_to_onnx(model_path, input_shape):
    model = tf.keras.models.load_model(model_path)

    onnx_path = model_path.split(".")[:-1] + ["onnx"]
    onnx_path = ".".join(onnx_path)
    
    input_signature = [tf.TensorSpec((None, *input_shape), tf.float32, name="input")]
    onnx_model, _ = tf2onnx.convert.from_keras(model, input_signature=input_signature)

    onnx.save(onnx_model, onnx_path)

def create_train_val_plot(history, overfit=True):
    # definisco numero epoche
    epochs = range(1, len(history['accuracy']) + 1)

    # Accuracy
    accuracy = history['accuracy']
    val_accuracy = history['val_accuracy']

    fig_acc, ax_acc = plt.subplots()

    # linea di base
    ax_acc.plot(epochs, [0.5 for x in range(len(epochs))], color="lightgray", linestyle="--", label="Base")
    # linee di accuratezza
    ax_acc.plot(epochs, accuracy, color="slategray", label="Accuratezza in addestramento")
    ax_acc.plot(epochs, val_accuracy, color="indianred", label="Accuratezza in validazione")
    # miglior accuratezza validazione
    ax_acc.axhline(y=max(val_accuracy), c='indianred', alpha=0.7, linestyle='--')
    ax_acc.text(len(epochs) * 1.07, max(val_accuracy), round(max(val_accuracy), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_acc.spines["right"].set_visible(False)
    ax_acc.spines["top"].set_visible(False)
    ax_acc.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_acc.set_title("Accuratezza in addestramento e validazione")
    ax_acc.set_xlabel("Epoche")
    ax_acc.set_ylabel("Accuratezza (%)")
    ax_acc.legend()

    # Loss
    loss = history['loss']
    val_loss = history['val_loss']

    fig_loss, ax_loss = plt.subplots()

    # linee di loss
    ax_loss.plot(epochs, loss, color="slategray", label="Perdita in addestramento")
    ax_loss.plot(epochs, val_loss, color="indianred", label="Perdita in validazione")
    # miglior loss validazione
    ax_loss.axhline(y=min(val_loss), c='indianred', alpha=0.7, linestyle='--')
    ax_loss.text(len(epochs) * 1.07, min(val_loss), round(min(val_loss), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_loss.spines["right"].set_visible(False)
    ax_loss.spines["top"].set_visible(False)
    ax_loss.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_loss.set_title("Perdita in addestramento e validazione")
    ax_loss.set_xlabel("Epoche")
    ax_loss.set_ylabel("Perdita")

    handles, _ = ax_loss.get_legend_handles_labels()

    if overfit:
        # area overfit
        rect = mpatches.Rectangle((np.argmin(val_loss) + 1, 0), width=100 - np.argmin(val_loss), height=max(max(loss), max(val_loss)), color='lightcoral', alpha=0.3)
        ax_loss.add_patch(rect)
        # patch overfit per legenda
        overfit = mpatches.Patch(color='indianred', alpha=0.3, label='Area overfit')
        handles, _ = ax_loss.get_legend_handles_labels()
        handles.append(overfit)

    # legenda
    ax_loss.legend(handles=handles)

    plt.show()

def evaluate_onnx_model(path_model_onnx, test_ds):
    # il fatto che sia suddiviso in batch mi crea problemi, perciò lo risolvo togliendoli
    test_ds = test_ds.unbatch()
    
    # carico il modello utilizzando il file onnx
    m = rt.InferenceSession(path_model_onnx)
    
    # trasformo il dataset in array numpy
    spectrogram_np = np.array([spectrogram.numpy() for spectrogram, _ in test_ds], dtype=np.float32)
    labels_np = np.array([label.numpy() for _, label in test_ds])
    
    # eseguo le predizione del modello
    pred_onnx = m.run(None, {'input': spectrogram_np})
    # ottengo la predizione corretta
    predictions = np.argmax(pred_onnx[0], axis=1)
    # computo la accuratezza
    accuracy = np.mean(predictions == labels_np)
    # stampo l'accuratezza
    print(f"Accuratezza: {accuracy:.3f}")

def create_distribution_plot(model, audio, label):
    prediction = model(audio) # otteniamo la predizione del modello sull'audio preso in input

    random_audio_index = np.random.randint(0, len(prediction) - 1) # abbiamo notato che mostravamo sempre la classe no, magari così cambia un po' le classi che mostriamo

    softmax_pred = tf.nn.softmax(prediction[random_audio_index]) # dobbiamo applicare nuovamente la softmax in modo tale da avere dei dati leggibili
    pred_label = np.argmax(softmax_pred) # ci salviamo l'indice della label predetta dal nostro modello, quella con la probabilità più alta

    colors = ['indianred'] * len(label_names) # creiamo un vettore di lunghezza 30 (la quantità delle nostre label) colorate di rosso

    if pred_label == label[random_audio_index].numpy(): # se la label che abbiamo predetto è corretta, allora la coloriamo di verde
        colors[pred_label] = 'seagreen'
    else: # se la label che abbiamo predetto è sbagliata, allora coloriamo di verde la corretta e di gialla la predetta
        colors[pred_label] = 'khaki'
        colors[label[random_audio_index].numpy()] = 'seagreen'

    plt.figure(figsize=(12, 4))

    plt.bar(label_names, softmax_pred.numpy(), color=colors)
    plt.xticks(rotation=45)

    # dichiariamo i colori della legenda
    other_values_patch = mpatches.Patch(color='indianred', label='Altre classi')
    pred_value_patch = mpatches.Patch(color='khaki', label='Classe predetta')
    correct_value_patch = mpatches.Patch(color='green', label='Classe corretta')

    # disegniamo la legenda con i colori necessari
    if pred_label == label[random_audio_index].numpy(): # se abbiamo predetto correttamente la label, non è necessario mostrare il colore giallo (non è presente nel plot)
        plt.legend(handles=[other_values_patch, correct_value_patch])
    else:
        plt.legend(handles=[other_values_patch, pred_value_patch, correct_value_patch])

    plt.show()

# %% [markdown]
# Importiamo il dataset e lo dividiamo in set di allenamento e set di validazione. Sucessivamente salviamo la lista delle etichette disponibili.

# %%
train_ds, validation_ds = tf.keras.utils.audio_dataset_from_directory(
    directory='../reduced_dataset/dataset/audio',
    validation_split=0.4, # stiamo mettendo da parte il 40% del dataset, che sarà suddiviso in validation set e test set
    shuffle=True,
    subset='both', # necessario se stiamo utilizzando validation_split (se no darebbe errore)
    seed=0 # necessario se stiamo utilizzando sia shuffle che validation_split (se no darebbe errore)
)

label_names = train_ds.class_names
# Out:
# Found 12933 files belonging to 30 classes.
# Using 7760 files for training.
# Using 5173 files for validation.

# %% [markdown]
# ## Addestramento modello convolutivo base (filterbanks)
# L'addestramento delle reti convolutive sugli spettrogrammi sono già state effettuate, perciò di seguito ci focalizzeremo sui filterbank.

# %% [markdown]
# Si parte chiamando la classe **DatasetConvert** e passandole in input il set di allenamento. Di seguito, con il metodo **convert**, scegliamo di mutare gli audio in filterbanks.
#
# Ripetiamo gli stessi passaggi anche per il set di validazione. Questo viene ulteriormente diviso per creare il set di test.

# %%
fb_train_ds = DatasetConverter(train_ds)
fb_train_ds = fb_train_ds.convert('filterbanks')

fb_validation_ds = DatasetConverter(validation_ds)
fb_validation_ds = fb_validation_ds.convert('filterbanks')

fb_val_ds = fb_validation_ds.take(fb_validation_ds.cardinality() // 2)
fb_test_ds = fb_validation_ds.skip(fb_validation_ds.cardinality() // 2)

# %% [markdown]
# Ora che abbiamo convertiro con successo il dataset in filterbank, possiamo creare il modello, identico a quello usato per gli spettrogrammi, e procedere all'addestramento utilizzando l'ottimizzatore rmsprop.

# %%
def get_basic_model(input_shape):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=input_shape, name="inputs")
    x = tf.keras.layers.Normalization(name="normalizzazione")(inputs)

    # Blocco di apprendimento delle caratteristiche
    conv2D_1 = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same", name="conv2D_1")(x)
    MaxPooling2D_1 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_1")(conv2D_1)
    conv2D_2 = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same", name="conv2D_2")(MaxPooling2D_1)
    MaxPooling2D_2 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_2")(conv2D_2)
    conv2D_3 = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same", name="conv2D_3")(MaxPooling2D_2)
    MaxPooling2D_3 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_3")(conv2D_3)
    conv2D_4 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_4")(MaxPooling2D_3)
    MaxPooling2D_4 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_4")(conv2D_4)
    conv2D_5 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_5")(MaxPooling2D_4)

    # Blocco di classificazione
    Flatten = tf.keras.layers.Flatten(name="Flatten")(conv2D_5)
    outputs = tf.keras.layers.Dense(30, activation="softmax", name="dense_output")(Flatten)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
for audio, label in fb_train_ds:
    basic_model = get_basic_model(audio.shape[1:])
    break
    
basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

basic_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inputs (InputLayer)         [(None, 98, 40, 1)]       0
#
#  normalizzazione (Normalizat  (None, 98, 40, 1)        3
#  ion)
#
#  conv2D_1 (Conv2D)           (None, 98, 40, 32)        320
#
#  MaxPooling2D_1 (MaxPooling2  (None, 49, 20, 32)       0
#  D)
#
#  conv2D_2 (Conv2D)           (None, 49, 20, 64)        18496
#
#  MaxPooling2D_2 (MaxPooling2  (None, 24, 10, 64)       0
#  D)
#
#  conv2D_3 (Conv2D)           (None, 24, 10, 128)       73856
#
#  MaxPooling2D_3 (MaxPooling2  (None, 12, 5, 128)       0
#  D)
#
#  conv2D_4 (Conv2D)           (None, 12, 5, 256)        295168
#
#  MaxPooling2D_4 (MaxPooling2  (None, 6, 2, 256)        0
#  D)
#
#  conv2D_5 (Conv2D)           (None, 6, 2, 256)         590080
#
#  Flatten (Flatten)           (None, 3072)              0
#
#  dense_output (Dense)        (None, 30)                92190
#
# =================================================================
# Total params: 1,070,113
# Trainable params: 1,070,110
# Non-trainable params: 3
# _________________________________________________________________

# %% [markdown]
# Essendo l'input shape di **98 x 40**, anche il numero di parametri sarà minore rispetto al modello addestrato sugli spettrogrammi, passando da circa **1.4 milioni di parametri** a poco meno di **1.1 milioni di parametri**.

# %%
basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/basic_model_fb.keras", save_best_only=True, monitor="val_loss")]
basic_model_history = basic_model.fit(fb_train_ds, epochs=30, batch_size=32, validation_data=fb_val_ds, callbacks=basic_model_callbacks)
# Out:
# Epoch 1/30
# 243/243 [==============================] - 4s 6ms/step - loss: 3.8829 - accuracy: 0.0836 - val_loss: 2.6250 - val_accuracy: 0.2141
# Epoch 2/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.7339 - accuracy: 0.4996 - val_loss: 1.0748 - val_accuracy: 0.6829
# Epoch 3/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7808 - accuracy: 0.7661 - val_loss: 0.8471 - val_accuracy: 0.7832
# Epoch 4/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4543 - accuracy: 0.8644 - val_loss: 0.8830 - val_accuracy: 0.7878
# Epoch 5/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3206 - accuracy: 0.9034 - val_loss: 0.7640 - val_accuracy: 0.8218
# Epoch 6/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2368 - accuracy: 0.9280 - val_loss: 0.9828 - val_accuracy: 0.8117
# Epoch 7/30
# 243/243 [==============================] - 1s 6ms/step - loss: 0.2143 - accuracy: 0.9369 - val_loss: 0.6805 - val_accuracy: 0.8742
# Epoch 8/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1799 - accuracy: 0.9472 - val_loss: 0.7018 - val_accuracy: 0.8819
# Epoch 9/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1533 - accuracy: 0.9561 - val_loss: 0.7525 - val_accuracy: 0.8862
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1601 - accuracy: 0.9590 - val_loss: 1.1656 - val_accuracy: 0.8522
# Epoch 11/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1330 - accuracy: 0.9649 - val_loss: 1.2725 - val_accuracy: 0.8160
# Epoch 12/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1565 - accuracy: 0.9621 - val_loss: 1.1388 - val_accuracy: 0.8414
# Epoch 13/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1253 - accuracy: 0.9682 - val_loss: 1.0512 - val_accuracy: 0.8650
# Epoch 14/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1232 - accuracy: 0.9702 - val_loss: 1.2439 - val_accuracy: 0.8630
# Epoch 15/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1101 - accuracy: 0.9713 - val_loss: 1.2883 - val_accuracy: 0.8785
# Epoch 16/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1112 - accuracy: 0.9735 - val_loss: 1.3714 - val_accuracy: 0.8700
# Epoch 17/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1149 - accuracy: 0.9713 - val_loss: 1.2881 - val_accuracy: 0.8476
# Epoch 18/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1064 - accuracy: 0.9749 - val_loss: 1.3982 - val_accuracy: 0.8804
# Epoch 19/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1180 - accuracy: 0.9774 - val_loss: 1.4522 - val_accuracy: 0.8654
# Epoch 20/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1095 - accuracy: 0.9764 - val_loss: 1.3882 - val_accuracy: 0.8870
# Epoch 21/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1112 - accuracy: 0.9763 - val_loss: 1.2107 - val_accuracy: 0.8858
# Epoch 22/30
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1106 - accuracy: 0.9809 - val_loss: 1.5851 - val_accuracy: 0.8657
# Epoch 23/30
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1041 - accuracy: 0.9782 - val_loss: 1.6239 - val_accuracy: 0.8708
# Epoch 24/30
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1327 - accuracy: 0.9790 - val_loss: 2.1126 - val_accuracy: 0.8476
# Epoch 25/30
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1163 - accuracy: 0.9802 - val_loss: 2.2258 - val_accuracy: 0.8326
# Epoch 26/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1280 - accuracy: 0.9790 - val_loss: 2.6741 - val_accuracy: 0.8387
# Epoch 27/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1181 - accuracy: 0.9802 - val_loss: 2.2136 - val_accuracy: 0.8746
# Epoch 28/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1276 - accuracy: 0.9822 - val_loss: 1.7381 - val_accuracy: 0.8893
# Epoch 29/30
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1477 - accuracy: 0.9807 - val_loss: 1.7114 - val_accuracy: 0.8858
# Epoch 30/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1210 - accuracy: 0.9802 - val_loss: 3.0966 - val_accuracy: 0.8356

# %% [markdown]
# Salviamo i dati della cronologia del modello in un file csv e convertiamo il miglior modello nell'estensione **.onnx**.

# %%
basic_model_history_df = convert_history_to_csv(basic_model_history)
basic_model_history_df.to_csv("model_histories/rmsprop/basic_model_history_fb.csv")

convert_model_to_onnx("bestmodels/rmsprop/basic_model_fb.keras", (98, 40, 1))

# %% [markdown]
# Analizziamo l'andamento dell'accurateza e della perdita durante l'addestramento.

# %%
create_train_val_plot(basic_model_history.history)

# %% [markdown]
# Dal grafico si evince che il modello entra in overfitting poco dopo la quinta epoca, raggiungendo comunque ottimi risultati per quanto riguarda l'accuratezza del validation set, con **87** punti percentile.
#
# La rete, inoltre, sembra essere lievemente migliore del modello addestrato sugli spettrogrammi, ma comparazioni più approffondite saranno affrontate su un notebook dedicato.

# %% [markdown]
# Verifichiamo l'accuratezza della migliore versione del modello di base.

# %%
best_basic_model = tf.keras.models.load_model("bestmodels/rmsprop/basic_model_fb.keras")
test_loss, test_acc = best_basic_model.evaluate(fb_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 2s 4ms/step - loss: 0.7222 - accuracy: 0.8625
# Accuratezza: 0.862

# %%
evaluate_onnx_model("bestmodels/rmsprop/basic_model_fb.onnx", fb_test_ds)
# Out:
# Accuratezza: 0.862

# %% [markdown]
# Abbiamo ottenuto un'**accuratezza** del **86.2%**! Attualmente abbiamo riscontrato un miglioramento utilizzando i filter banks. Visualizziamo la distribuzione di accuratezza delle classi.

# %%
for audio, label in fb_test_ds: # prendiamo un audio a caso del test e creiamo la distribuzione
    create_distribution_plot(best_basic_model, audio, label)
    break

# %% [markdown]
# In questo specifico caso il modello ha **sbagliato totalmente** la classe predetta.

# %% [markdown]
# ### Convolutivo base risoluzione dell'overfitting
# In questa parte implementiamo il secondo modello presente nel notebook di riferimento, ovvero quello riguardante il paragrafo **risoluzione dell'overfitting**, dove viene aggiunto uno strato di dropout.

# %% [markdown]
# Come fatto prima, si procede con la creazione e l'addestramento del modello con l'ottimizzatore rmsprop.

# %%
def get_improved_basic_model(input_shape):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=input_shape)
    x = tf.keras.layers.Normalization()(inputs)

    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
for audio, label in fb_train_ds:
    improved_basic_model = get_improved_basic_model(audio.shape[1:])
    break

improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

# %%
improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/improved_basic_model_fb.keras", save_best_only=True, monitor="val_loss")]
improved_history = improved_basic_model.fit(fb_train_ds, epochs=100, validation_data=fb_val_ds, callbacks=improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 2s 6ms/step - loss: 3.5965 - accuracy: 0.0432 - val_loss: 3.3016 - val_accuracy: 0.0810
# Epoch 2/100
# 243/243 [==============================] - 1s 6ms/step - loss: 2.5751 - accuracy: 0.2539 - val_loss: 1.6168 - val_accuracy: 0.5228
# Epoch 3/100
# 243/243 [==============================] - 1s 6ms/step - loss: 1.2971 - accuracy: 0.6219 - val_loss: 1.1457 - val_accuracy: 0.6817
# Epoch 4/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.7455 - accuracy: 0.7840 - val_loss: 0.8335 - val_accuracy: 0.7785
# Epoch 5/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4957 - accuracy: 0.8540 - val_loss: 0.7823 - val_accuracy: 0.8059
# Epoch 6/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3952 - accuracy: 0.8821 - val_loss: 0.4872 - val_accuracy: 0.8719
# Epoch 7/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3114 - accuracy: 0.9053 - val_loss: 0.5860 - val_accuracy: 0.8638
# Epoch 8/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2797 - accuracy: 0.9171 - val_loss: 0.5866 - val_accuracy: 0.8831
# Epoch 9/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2401 - accuracy: 0.9308 - val_loss: 0.5445 - val_accuracy: 0.8858
# Epoch 10/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2386 - accuracy: 0.9304 - val_loss: 0.6029 - val_accuracy: 0.8873
# Epoch 11/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2249 - accuracy: 0.9388 - val_loss: 0.5098 - val_accuracy: 0.8912
# Epoch 12/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2074 - accuracy: 0.9401 - val_loss: 0.5233 - val_accuracy: 0.8893
# Epoch 13/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2087 - accuracy: 0.9424 - val_loss: 0.5903 - val_accuracy: 0.8796
# Epoch 14/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1959 - accuracy: 0.9461 - val_loss: 0.5697 - val_accuracy: 0.9055
# Epoch 15/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1917 - accuracy: 0.9512 - val_loss: 0.7584 - val_accuracy: 0.8762
# Epoch 16/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1869 - accuracy: 0.9526 - val_loss: 0.8437 - val_accuracy: 0.8854
# Epoch 17/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1833 - accuracy: 0.9540 - val_loss: 0.7309 - val_accuracy: 0.9016
# Epoch 18/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1941 - accuracy: 0.9541 - val_loss: 0.7629 - val_accuracy: 0.8924
# Epoch 19/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1722 - accuracy: 0.9603 - val_loss: 0.7171 - val_accuracy: 0.8966
# Epoch 20/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1778 - accuracy: 0.9603 - val_loss: 0.6106 - val_accuracy: 0.9051
# Epoch 21/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1839 - accuracy: 0.9557 - val_loss: 0.8086 - val_accuracy: 0.8966
# Epoch 22/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1621 - accuracy: 0.9634 - val_loss: 0.9608 - val_accuracy: 0.8380
# Epoch 23/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1825 - accuracy: 0.9608 - val_loss: 0.8418 - val_accuracy: 0.9016
# Epoch 24/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1852 - accuracy: 0.9579 - val_loss: 1.0410 - val_accuracy: 0.8800
# Epoch 25/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1909 - accuracy: 0.9593 - val_loss: 0.8979 - val_accuracy: 0.8958
# Epoch 26/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1710 - accuracy: 0.9646 - val_loss: 0.9146 - val_accuracy: 0.9136
# Epoch 27/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1736 - accuracy: 0.9647 - val_loss: 1.5834 - val_accuracy: 0.8241
# Epoch 28/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2048 - accuracy: 0.9634 - val_loss: 0.9013 - val_accuracy: 0.9090
# Epoch 29/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1860 - accuracy: 0.9661 - val_loss: 0.9993 - val_accuracy: 0.9086
# Epoch 30/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1865 - accuracy: 0.9624 - val_loss: 0.9693 - val_accuracy: 0.8947
# Epoch 31/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1792 - accuracy: 0.9637 - val_loss: 1.8827 - val_accuracy: 0.8850
# Epoch 32/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1970 - accuracy: 0.9662 - val_loss: 1.2340 - val_accuracy: 0.8935
# Epoch 33/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1607 - accuracy: 0.9700 - val_loss: 1.0810 - val_accuracy: 0.9093
# Epoch 34/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2235 - accuracy: 0.9629 - val_loss: 1.1686 - val_accuracy: 0.8885
# Epoch 35/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1865 - accuracy: 0.9677 - val_loss: 1.0687 - val_accuracy: 0.8962
# Epoch 36/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1987 - accuracy: 0.9678 - val_loss: 1.4260 - val_accuracy: 0.8750
# Epoch 37/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1786 - accuracy: 0.9686 - val_loss: 1.6189 - val_accuracy: 0.9043
# Epoch 38/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1828 - accuracy: 0.9697 - val_loss: 1.4666 - val_accuracy: 0.8962
# Epoch 39/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.2038 - accuracy: 0.9691 - val_loss: 1.2827 - val_accuracy: 0.9097
# Epoch 40/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1811 - accuracy: 0.9715 - val_loss: 1.4079 - val_accuracy: 0.8966
# Epoch 41/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2181 - accuracy: 0.9675 - val_loss: 1.1962 - val_accuracy: 0.8993
# Epoch 42/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1844 - accuracy: 0.9726 - val_loss: 1.4205 - val_accuracy: 0.9055
# Epoch 43/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1803 - accuracy: 0.9715 - val_loss: 1.3351 - val_accuracy: 0.9062
# Epoch 44/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1919 - accuracy: 0.9691 - val_loss: 1.1353 - val_accuracy: 0.9109
# Epoch 45/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1611 - accuracy: 0.9701 - val_loss: 1.0848 - val_accuracy: 0.8997
# Epoch 46/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2030 - accuracy: 0.9674 - val_loss: 1.4177 - val_accuracy: 0.8927
# Epoch 47/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1835 - accuracy: 0.9719 - val_loss: 1.3639 - val_accuracy: 0.9120
# Epoch 48/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1930 - accuracy: 0.9722 - val_loss: 1.8298 - val_accuracy: 0.8873
# Epoch 49/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1956 - accuracy: 0.9733 - val_loss: 1.3418 - val_accuracy: 0.9113
# Epoch 50/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1906 - accuracy: 0.9745 - val_loss: 1.8399 - val_accuracy: 0.8943
# Epoch 51/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1926 - accuracy: 0.9747 - val_loss: 1.2387 - val_accuracy: 0.9182
# Epoch 52/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1784 - accuracy: 0.9737 - val_loss: 1.4752 - val_accuracy: 0.9066
# Epoch 53/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1943 - accuracy: 0.9732 - val_loss: 1.6790 - val_accuracy: 0.9020
# Epoch 54/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1718 - accuracy: 0.9763 - val_loss: 1.7132 - val_accuracy: 0.9020
# Epoch 55/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1727 - accuracy: 0.9798 - val_loss: 1.8783 - val_accuracy: 0.8854
# Epoch 56/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2016 - accuracy: 0.9732 - val_loss: 1.8975 - val_accuracy: 0.9051
# Epoch 57/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2048 - accuracy: 0.9763 - val_loss: 1.8174 - val_accuracy: 0.9171
# Epoch 58/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1901 - accuracy: 0.9738 - val_loss: 1.6487 - val_accuracy: 0.9163
# Epoch 59/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2174 - accuracy: 0.9742 - val_loss: 1.7559 - val_accuracy: 0.9035
# Epoch 60/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2119 - accuracy: 0.9760 - val_loss: 1.7535 - val_accuracy: 0.9159
# Epoch 61/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1624 - accuracy: 0.9793 - val_loss: 2.0960 - val_accuracy: 0.8827
# Epoch 62/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1875 - accuracy: 0.9785 - val_loss: 1.9833 - val_accuracy: 0.9221
# Epoch 63/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2419 - accuracy: 0.9742 - val_loss: 1.6773 - val_accuracy: 0.9120
# Epoch 64/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1955 - accuracy: 0.9751 - val_loss: 1.8024 - val_accuracy: 0.9047
# Epoch 65/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2098 - accuracy: 0.9750 - val_loss: 2.1617 - val_accuracy: 0.9178
# Epoch 66/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2048 - accuracy: 0.9774 - val_loss: 2.2179 - val_accuracy: 0.9225
# Epoch 67/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2327 - accuracy: 0.9780 - val_loss: 2.0834 - val_accuracy: 0.9159
# Epoch 68/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2514 - accuracy: 0.9764 - val_loss: 2.4871 - val_accuracy: 0.9159
# Epoch 69/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2701 - accuracy: 0.9759 - val_loss: 1.9712 - val_accuracy: 0.9228
# Epoch 70/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2226 - accuracy: 0.9773 - val_loss: 1.8537 - val_accuracy: 0.9028
# Epoch 71/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2134 - accuracy: 0.9762 - val_loss: 1.4916 - val_accuracy: 0.9028
# Epoch 72/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2162 - accuracy: 0.9780 - val_loss: 1.8352 - val_accuracy: 0.9163
# Epoch 73/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1824 - accuracy: 0.9807 - val_loss: 2.1509 - val_accuracy: 0.9082
# Epoch 74/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2387 - accuracy: 0.9789 - val_loss: 2.2783 - val_accuracy: 0.9032
# Epoch 75/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2206 - accuracy: 0.9784 - val_loss: 2.9401 - val_accuracy: 0.9093
# Epoch 76/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2159 - accuracy: 0.9781 - val_loss: 2.7718 - val_accuracy: 0.9105
# Epoch 77/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2348 - accuracy: 0.9794 - val_loss: 3.1141 - val_accuracy: 0.9151
# Epoch 78/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2439 - accuracy: 0.9795 - val_loss: 2.4268 - val_accuracy: 0.9082
# Epoch 79/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2405 - accuracy: 0.9777 - val_loss: 2.5018 - val_accuracy: 0.9167
# Epoch 80/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2505 - accuracy: 0.9787 - val_loss: 2.1391 - val_accuracy: 0.9035
# Epoch 81/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2311 - accuracy: 0.9768 - val_loss: 3.1759 - val_accuracy: 0.9043
# Epoch 82/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2128 - accuracy: 0.9787 - val_loss: 3.5710 - val_accuracy: 0.9012
# Epoch 83/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1916 - accuracy: 0.9826 - val_loss: 3.1860 - val_accuracy: 0.9155
# Epoch 84/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2756 - accuracy: 0.9763 - val_loss: 2.5115 - val_accuracy: 0.9171
# Epoch 85/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2019 - accuracy: 0.9843 - val_loss: 3.1229 - val_accuracy: 0.9213
# Epoch 86/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2764 - accuracy: 0.9809 - val_loss: 2.5710 - val_accuracy: 0.9221
# Epoch 87/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2429 - accuracy: 0.9809 - val_loss: 3.2586 - val_accuracy: 0.9163
# Epoch 88/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2750 - accuracy: 0.9789 - val_loss: 3.5049 - val_accuracy: 0.8935
# Epoch 89/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2195 - accuracy: 0.9816 - val_loss: 3.5699 - val_accuracy: 0.9128
# Epoch 90/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3027 - accuracy: 0.9778 - val_loss: 3.4514 - val_accuracy: 0.9120
# Epoch 91/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3417 - accuracy: 0.9787 - val_loss: 3.9395 - val_accuracy: 0.9024
# Epoch 92/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3272 - accuracy: 0.9799 - val_loss: 4.6955 - val_accuracy: 0.9132
# Epoch 93/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2673 - accuracy: 0.9814 - val_loss: 4.0001 - val_accuracy: 0.9140
# Epoch 94/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2457 - accuracy: 0.9820 - val_loss: 3.2346 - val_accuracy: 0.9124
# Epoch 95/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2306 - accuracy: 0.9813 - val_loss: 2.7410 - val_accuracy: 0.9082
# Epoch 96/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2602 - accuracy: 0.9823 - val_loss: 2.7924 - val_accuracy: 0.9267
# Epoch 97/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2696 - accuracy: 0.9802 - val_loss: 3.7318 - val_accuracy: 0.9093
# Epoch 98/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2471 - accuracy: 0.9841 - val_loss: 3.6046 - val_accuracy: 0.9221
# Epoch 99/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3605 - accuracy: 0.9808 - val_loss: 3.3464 - val_accuracy: 0.9171
# Epoch 100/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3046 - accuracy: 0.9827 - val_loss: 3.4994 - val_accuracy: 0.9163

# %% [markdown]
# Seguiamo lo stesso ordine di prima per le operazione post-addestramento.

# %%
improved_history_df = convert_history_to_csv(improved_history)
improved_history_df.to_csv("model_histories/rmsprop/improved_history_fb.csv")

convert_model_to_onnx("bestmodels/rmsprop/improved_basic_model_fb.keras", (98, 40, 1))

# %%
create_train_val_plot(improved_history.history)

# %% [markdown]
# I risultati sono decisamente positivi. Siamo riusciti a ritardare il sovradattamento, arrivando a livelli di perdita molto più bassi rispetto al precedente. Inoltre, l'accuratezza nel set di valutazione è salita del **4%**.

# %%
improved_best_model = tf.keras.models.load_model("bestmodels/rmsprop/improved_basic_model_fb.keras")
test_loss, test_acc = improved_best_model.evaluate(fb_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 5ms/step - loss: 0.5311 - accuracy: 0.8578
# Accuratezza: 0.858

# %%
evaluate_onnx_model("bestmodels/rmsprop/improved_basic_model_fb.onnx", fb_test_ds)
# Out:
# Accuratezza: 0.858

# %% [markdown]
# L'aumento di prestazioni non vengono però rispecchiate nel test set, dove si giunge a un'accuratezza di **85.8%**, leggermente inferiore rispetto al precedente.

# %%
for audio, label in fb_test_ds:
    create_distribution_plot(improved_best_model, audio, label)
    break

# %% [markdown]
# ### Modello convolutivo tuned
# In questa fase andremo ad addestrare lo stesso modello appena addestrato ma con un **tasso di apprendimento di 1e-5**, lo stesso utilizzato per il modello fine tuned sugli spettrogrammi.

# %%
for audio, label in fb_train_ds:
    tuned_improved_basic_model = get_improved_basic_model(audio.shape[1:])
    break

tuned_improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-5), metrics=["accuracy"])

# %%
tuned_improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/tuned_improved_basic_model_fb.keras", save_best_only=True, monitor="val_loss")]
tuned_improved_history = tuned_improved_basic_model.fit(fb_train_ds, epochs=100, validation_data=fb_val_ds, callbacks=tuned_improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 2s 6ms/step - loss: 5.1715 - accuracy: 0.0378 - val_loss: 3.3684 - val_accuracy: 0.0486
# Epoch 2/100
# 243/243 [==============================] - 1s 5ms/step - loss: 3.4523 - accuracy: 0.0481 - val_loss: 3.3232 - val_accuracy: 0.0745
# Epoch 3/100
# 243/243 [==============================] - 1s 5ms/step - loss: 3.3576 - accuracy: 0.0616 - val_loss: 3.2900 - val_accuracy: 0.0980
# Epoch 4/100
# 243/243 [==============================] - 1s 5ms/step - loss: 3.3056 - accuracy: 0.0826 - val_loss: 3.2444 - val_accuracy: 0.1238
# Epoch 5/100
# 243/243 [==============================] - 1s 5ms/step - loss: 3.2642 - accuracy: 0.0963 - val_loss: 3.1910 - val_accuracy: 0.1524
# Epoch 6/100
# 243/243 [==============================] - 1s 5ms/step - loss: 3.2123 - accuracy: 0.1059 - val_loss: 3.1449 - val_accuracy: 0.1636
# Epoch 7/100
# 243/243 [==============================] - 1s 5ms/step - loss: 3.1641 - accuracy: 0.1309 - val_loss: 3.0849 - val_accuracy: 0.1771
# Epoch 8/100
# 243/243 [==============================] - 1s 5ms/step - loss: 3.0996 - accuracy: 0.1486 - val_loss: 3.0105 - val_accuracy: 0.2033
# Epoch 9/100
# 243/243 [==============================] - 1s 6ms/step - loss: 3.0344 - accuracy: 0.1652 - val_loss: 2.9477 - val_accuracy: 0.2168
# Epoch 10/100
# 243/243 [==============================] - 1s 6ms/step - loss: 2.9797 - accuracy: 0.1764 - val_loss: 2.8632 - val_accuracy: 0.2504
# Epoch 11/100
# 243/243 [==============================] - 1s 6ms/step - loss: 2.8967 - accuracy: 0.1909 - val_loss: 2.7914 - val_accuracy: 0.2488
# Epoch 12/100
# 243/243 [==============================] - 1s 6ms/step - loss: 2.8313 - accuracy: 0.2175 - val_loss: 2.7207 - val_accuracy: 0.2770
# Epoch 13/100
# 243/243 [==============================] - 1s 6ms/step - loss: 2.7647 - accuracy: 0.2329 - val_loss: 2.6488 - val_accuracy: 0.2924
# Epoch 14/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.6935 - accuracy: 0.2488 - val_loss: 2.5741 - val_accuracy: 0.3164
# Epoch 15/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.6191 - accuracy: 0.2670 - val_loss: 2.5002 - val_accuracy: 0.3295
# Epoch 16/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.5530 - accuracy: 0.2845 - val_loss: 2.4347 - val_accuracy: 0.3360
# Epoch 17/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.4927 - accuracy: 0.2996 - val_loss: 2.3666 - val_accuracy: 0.3654
# Epoch 18/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.4322 - accuracy: 0.3111 - val_loss: 2.3006 - val_accuracy: 0.3796
# Epoch 19/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.3681 - accuracy: 0.3256 - val_loss: 2.2565 - val_accuracy: 0.3858
# Epoch 20/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.3087 - accuracy: 0.3460 - val_loss: 2.1860 - val_accuracy: 0.4186
# Epoch 21/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.2649 - accuracy: 0.3659 - val_loss: 2.1431 - val_accuracy: 0.4271
# Epoch 22/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.1935 - accuracy: 0.3706 - val_loss: 2.0830 - val_accuracy: 0.4309
# Epoch 23/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.1502 - accuracy: 0.3854 - val_loss: 2.0353 - val_accuracy: 0.4556
# Epoch 24/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.0869 - accuracy: 0.4036 - val_loss: 1.9877 - val_accuracy: 0.4676
# Epoch 25/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.0415 - accuracy: 0.4143 - val_loss: 1.9421 - val_accuracy: 0.4780
# Epoch 26/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.0017 - accuracy: 0.4357 - val_loss: 1.8803 - val_accuracy: 0.5046
# Epoch 27/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.9434 - accuracy: 0.4452 - val_loss: 1.8411 - val_accuracy: 0.5031
# Epoch 28/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.8982 - accuracy: 0.4532 - val_loss: 1.8001 - val_accuracy: 0.5116
# Epoch 29/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.8462 - accuracy: 0.4715 - val_loss: 1.7502 - val_accuracy: 0.5289
# Epoch 30/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.8060 - accuracy: 0.4849 - val_loss: 1.7106 - val_accuracy: 0.5401
# Epoch 31/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.7594 - accuracy: 0.4966 - val_loss: 1.6716 - val_accuracy: 0.5459
# Epoch 32/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.7255 - accuracy: 0.5104 - val_loss: 1.6437 - val_accuracy: 0.5571
# Epoch 33/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.6759 - accuracy: 0.5170 - val_loss: 1.5888 - val_accuracy: 0.5729
# Epoch 34/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.6345 - accuracy: 0.5358 - val_loss: 1.5731 - val_accuracy: 0.5783
# Epoch 35/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.5992 - accuracy: 0.5396 - val_loss: 1.5179 - val_accuracy: 0.5930
# Epoch 36/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.5600 - accuracy: 0.5537 - val_loss: 1.4913 - val_accuracy: 0.6034
# Epoch 37/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.5209 - accuracy: 0.5648 - val_loss: 1.4544 - val_accuracy: 0.6076
# Epoch 38/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.4639 - accuracy: 0.5866 - val_loss: 1.4094 - val_accuracy: 0.6211
# Epoch 39/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.4363 - accuracy: 0.5863 - val_loss: 1.3870 - val_accuracy: 0.6254
# Epoch 40/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.4127 - accuracy: 0.5934 - val_loss: 1.3589 - val_accuracy: 0.6269
# Epoch 41/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.3747 - accuracy: 0.6108 - val_loss: 1.3341 - val_accuracy: 0.6366
# Epoch 42/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.3409 - accuracy: 0.6137 - val_loss: 1.2969 - val_accuracy: 0.6547
# Epoch 43/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.3087 - accuracy: 0.6214 - val_loss: 1.2769 - val_accuracy: 0.6532
# Epoch 44/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.2651 - accuracy: 0.6367 - val_loss: 1.2464 - val_accuracy: 0.6547
# Epoch 45/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.2370 - accuracy: 0.6452 - val_loss: 1.2178 - val_accuracy: 0.6682
# Epoch 46/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.2166 - accuracy: 0.6509 - val_loss: 1.1935 - val_accuracy: 0.6744
# Epoch 47/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.1845 - accuracy: 0.6594 - val_loss: 1.1707 - val_accuracy: 0.6790
# Epoch 48/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.1491 - accuracy: 0.6678 - val_loss: 1.1478 - val_accuracy: 0.6836
# Epoch 49/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.1228 - accuracy: 0.6831 - val_loss: 1.1338 - val_accuracy: 0.6902
# Epoch 50/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.1037 - accuracy: 0.6767 - val_loss: 1.1093 - val_accuracy: 0.6898
# Epoch 51/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.0662 - accuracy: 0.6947 - val_loss: 1.0855 - val_accuracy: 0.7041
# Epoch 52/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.0638 - accuracy: 0.6928 - val_loss: 1.0665 - val_accuracy: 0.7083
# Epoch 53/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.0155 - accuracy: 0.7054 - val_loss: 1.0426 - val_accuracy: 0.7106
# Epoch 54/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.0122 - accuracy: 0.7135 - val_loss: 1.0334 - val_accuracy: 0.7110
# Epoch 55/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.9765 - accuracy: 0.7186 - val_loss: 1.0104 - val_accuracy: 0.7230
# Epoch 56/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.9536 - accuracy: 0.7259 - val_loss: 0.9985 - val_accuracy: 0.7238
# Epoch 57/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.9349 - accuracy: 0.7268 - val_loss: 0.9892 - val_accuracy: 0.7280
# Epoch 58/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.9246 - accuracy: 0.7334 - val_loss: 0.9716 - val_accuracy: 0.7280
# Epoch 59/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8864 - accuracy: 0.7456 - val_loss: 0.9548 - val_accuracy: 0.7380
# Epoch 60/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8632 - accuracy: 0.7567 - val_loss: 0.9388 - val_accuracy: 0.7338
# Epoch 61/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.8586 - accuracy: 0.7501 - val_loss: 0.9162 - val_accuracy: 0.7446
# Epoch 62/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.8360 - accuracy: 0.7589 - val_loss: 0.9127 - val_accuracy: 0.7450
# Epoch 63/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.8139 - accuracy: 0.7630 - val_loss: 0.8959 - val_accuracy: 0.7461
# Epoch 64/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.7989 - accuracy: 0.7679 - val_loss: 0.8850 - val_accuracy: 0.7531
# Epoch 65/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.7721 - accuracy: 0.7751 - val_loss: 0.8793 - val_accuracy: 0.7542
# Epoch 66/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.7606 - accuracy: 0.7827 - val_loss: 0.8649 - val_accuracy: 0.7585
# Epoch 67/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7575 - accuracy: 0.7804 - val_loss: 0.8531 - val_accuracy: 0.7616
# Epoch 68/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7251 - accuracy: 0.7902 - val_loss: 0.8386 - val_accuracy: 0.7623
# Epoch 69/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7096 - accuracy: 0.7959 - val_loss: 0.8527 - val_accuracy: 0.7558
# Epoch 70/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7027 - accuracy: 0.7918 - val_loss: 0.8229 - val_accuracy: 0.7720
# Epoch 71/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6746 - accuracy: 0.8021 - val_loss: 0.8079 - val_accuracy: 0.7728
# Epoch 72/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6652 - accuracy: 0.8062 - val_loss: 0.8091 - val_accuracy: 0.7739
# Epoch 73/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6619 - accuracy: 0.8064 - val_loss: 0.7949 - val_accuracy: 0.7832
# Epoch 74/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6490 - accuracy: 0.8115 - val_loss: 0.7837 - val_accuracy: 0.7828
# Epoch 75/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6388 - accuracy: 0.8066 - val_loss: 0.7774 - val_accuracy: 0.7855
# Epoch 76/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6298 - accuracy: 0.8187 - val_loss: 0.7749 - val_accuracy: 0.7832
# Epoch 77/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6144 - accuracy: 0.8175 - val_loss: 0.7617 - val_accuracy: 0.7851
# Epoch 78/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6036 - accuracy: 0.8215 - val_loss: 0.7498 - val_accuracy: 0.7905
# Epoch 79/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5773 - accuracy: 0.8336 - val_loss: 0.7680 - val_accuracy: 0.7816
# Epoch 80/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5753 - accuracy: 0.8345 - val_loss: 0.7428 - val_accuracy: 0.7886
# Epoch 81/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5577 - accuracy: 0.8363 - val_loss: 0.7438 - val_accuracy: 0.7948
# Epoch 82/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5515 - accuracy: 0.8393 - val_loss: 0.7331 - val_accuracy: 0.7978
# Epoch 83/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5254 - accuracy: 0.8401 - val_loss: 0.7234 - val_accuracy: 0.7990
# Epoch 84/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5272 - accuracy: 0.8459 - val_loss: 0.7168 - val_accuracy: 0.7959
# Epoch 85/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5189 - accuracy: 0.8487 - val_loss: 0.7148 - val_accuracy: 0.8017
# Epoch 86/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5133 - accuracy: 0.8515 - val_loss: 0.7140 - val_accuracy: 0.8002
# Epoch 87/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5027 - accuracy: 0.8515 - val_loss: 0.7041 - val_accuracy: 0.8029
# Epoch 88/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4949 - accuracy: 0.8535 - val_loss: 0.6967 - val_accuracy: 0.8029
# Epoch 89/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4825 - accuracy: 0.8572 - val_loss: 0.6929 - val_accuracy: 0.8056
# Epoch 90/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4860 - accuracy: 0.8554 - val_loss: 0.6808 - val_accuracy: 0.8083
# Epoch 91/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4711 - accuracy: 0.8610 - val_loss: 0.6793 - val_accuracy: 0.8071
# Epoch 92/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4581 - accuracy: 0.8611 - val_loss: 0.6833 - val_accuracy: 0.8071
# Epoch 93/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4458 - accuracy: 0.8689 - val_loss: 0.6906 - val_accuracy: 0.8071
# Epoch 94/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4411 - accuracy: 0.8741 - val_loss: 0.6838 - val_accuracy: 0.8090
# Epoch 95/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4408 - accuracy: 0.8733 - val_loss: 0.6676 - val_accuracy: 0.8113
# Epoch 96/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4328 - accuracy: 0.8745 - val_loss: 0.6616 - val_accuracy: 0.8137
# Epoch 97/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4224 - accuracy: 0.8737 - val_loss: 0.6706 - val_accuracy: 0.8056
# Epoch 98/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4104 - accuracy: 0.8794 - val_loss: 0.6574 - val_accuracy: 0.8106
# Epoch 99/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4046 - accuracy: 0.8780 - val_loss: 0.6822 - val_accuracy: 0.8086
# Epoch 100/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4078 - accuracy: 0.8777 - val_loss: 0.6519 - val_accuracy: 0.8137

# %%
tuned_improved_history_df = convert_history_to_csv(tuned_improved_history)
tuned_improved_history_df.to_csv("model_histories/rmsprop/tuned_improved_history_fb.csv")

convert_model_to_onnx("bestmodels/rmsprop/tuned_improved_basic_model_fb.keras", (98, 40, 1))

# %%
create_train_val_plot(tuned_improved_history.history)

# %% [markdown]
# In questo caso il modello non è ancora andato in overfitting, perciò magari avremmo potuto addestrarlo per qualche epoca in più. L'accuratezza in addestramento e validazione sono basse rispetto ai modelli precedenti, dovuto molto probabilmente dalla quantità limitata di epoche.

# %%
tuned_improved_best_model = tf.keras.models.load_model("bestmodels/rmsprop/tuned_improved_basic_model_fb.keras")
test_loss, test_acc = tuned_improved_best_model.evaluate(fb_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 3ms/step - loss: 0.6970 - accuracy: 0.8074
# Accuratezza: 0.807

# %%
evaluate_onnx_model("bestmodels/rmsprop/tuned_improved_basic_model_fb.onnx", fb_test_ds)
# Out:
# Accuratezza: 0.807

# %% [markdown]
# Come ci aspettavamo dall'andamento dell'accuratezza, il modello ha registrato delle prestazioni inferiori rispetto a prima ma senza andare in overfitting. L'accuratezza corrisponde a **80.7%**.

# %%
for audio, label in fb_test_ds:
    create_distribution_plot(tuned_improved_best_model, audio, label)
    break

# %% [markdown]
# Un fattore molto positivo riguarda la distinzione corretta di parole molto simili, come in questo caso **three** e **tree**.

# %% [markdown]
# ### Miglioramenti all'architettura del modello convolutivo
# In questa ultima fase riguardante i filterbanks andremo ad addestrare il modello corrispondente alla sezione **miglioramenti all'architettura del modello** del notebook di riferimento.

# %% [markdown]
# Si procede con la creazione dell'architettura composta da blocchi residuali, il suo addestramento e la dimostrazione grafica dell'andamento.

# %%
def residual_block(x, filters, pooling=False):
    residual = x

    x = tf.keras.layers.SeparableConv2D(filters, 3, padding="same", use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    if pooling:
      x = tf.keras.layers.MaxPooling2D(pool_size=2, padding="same")(x)
      residual = tf.keras.layers.Conv2D(filters, 1, strides=2)(residual)
    elif filters != residual.shape[-1]:
      residual = tf.keras.layers.Conv2D(filters, 1)(residual)

    x = tf.keras.layers.add([x, residual])
    return x

def bp_basic_model(input_shape):
    # input e pre processamento
    inputs = tf.keras.Input(shape=input_shape)
    
    x = residual_block(inputs, 32, pooling=True)
    x = residual_block(x, 64, pooling=True)
    x = residual_block(x, 128, pooling=True)
    x = residual_block(x, 256, pooling=True)
    x = residual_block(x, 256, pooling=False)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Livelli per la classificazione
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
for audio, label in fb_train_ds:
    bp_basic_model = bp_basic_model(audio.shape[1:])
    break

bp_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

bp_basic_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 98, 40, 1)]  0           []
#
#  separable_conv2d (SeparableCon  (None, 98, 40, 32)  41          ['input_3[0][0]']
#  v2D)
#
#  batch_normalization (BatchNorm  (None, 98, 40, 32)  128         ['separable_conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 98, 40, 32)   0           ['batch_normalization[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 49, 20, 32)  0           ['activation[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 49, 20, 32)   64          ['input_3[0][0]']
#
#  add (Add)                      (None, 49, 20, 32)   0           ['max_pooling2d_8[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  separable_conv2d_1 (SeparableC  (None, 49, 20, 64)  2336        ['add[0][0]']
#  onv2D)
#
#  batch_normalization_1 (BatchNo  (None, 49, 20, 64)  256         ['separable_conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 49, 20, 64)   0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 25, 10, 64)  0           ['activation_1[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 25, 10, 64)   2112        ['add[0][0]']
#
#  add_1 (Add)                    (None, 25, 10, 64)   0           ['max_pooling2d_9[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  separable_conv2d_2 (SeparableC  (None, 25, 10, 128)  8768       ['add_1[0][0]']
#  onv2D)
#
#  batch_normalization_2 (BatchNo  (None, 25, 10, 128)  512        ['separable_conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 25, 10, 128)  0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 13, 5, 128)  0           ['activation_2[0][0]']
#  )
#
#  conv2d_12 (Conv2D)             (None, 13, 5, 128)   8320        ['add_1[0][0]']
#
#  add_2 (Add)                    (None, 13, 5, 128)   0           ['max_pooling2d_10[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  separable_conv2d_3 (SeparableC  (None, 13, 5, 256)  33920       ['add_2[0][0]']
#  onv2D)
#
#  batch_normalization_3 (BatchNo  (None, 13, 5, 256)  1024        ['separable_conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 13, 5, 256)   0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 7, 3, 256)   0           ['activation_3[0][0]']
#  )
#
#  conv2d_13 (Conv2D)             (None, 7, 3, 256)    33024       ['add_2[0][0]']
#
#  add_3 (Add)                    (None, 7, 3, 256)    0           ['max_pooling2d_11[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 7, 3, 256)   67840       ['add_3[0][0]']
#  onv2D)
#
#  batch_normalization_4 (BatchNo  (None, 7, 3, 256)   1024        ['separable_conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 7, 3, 256)    0           ['batch_normalization_4[0][0]']
#
#  add_4 (Add)                    (None, 7, 3, 256)    0           ['activation_4[0][0]',
#                                                                   'add_3[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['add_4[0][0]']
#  alAveragePooling2D)
#
#  dropout_2 (Dropout)            (None, 256)          0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_2 (Dense)                (None, 30)           7710        ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 167,079
# Trainable params: 165,607
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %% [markdown]
# Il numero di parametri in questo caso non è cambiato rispetto al notebook di riferimento.

# %%
bp_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/bp_basic_model_fb.keras", save_best_only=True, monitor="val_loss")]
bp_model_history = bp_basic_model.fit(fb_train_ds, epochs=100, validation_data=fb_val_ds, callbacks=bp_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 4s 11ms/step - loss: 5.7763 - accuracy: 0.0530 - val_loss: 3.8609 - val_accuracy: 0.0355
# Epoch 2/100
# 243/243 [==============================] - 2s 10ms/step - loss: 2.9183 - accuracy: 0.1841 - val_loss: 3.2534 - val_accuracy: 0.1424
# Epoch 3/100
# 243/243 [==============================] - 2s 10ms/step - loss: 2.0791 - accuracy: 0.3932 - val_loss: 2.2703 - val_accuracy: 0.3584
# Epoch 4/100
# 243/243 [==============================] - 2s 10ms/step - loss: 1.4526 - accuracy: 0.5807 - val_loss: 2.6780 - val_accuracy: 0.3823
# Epoch 5/100
# 243/243 [==============================] - 2s 9ms/step - loss: 1.0838 - accuracy: 0.6872 - val_loss: 3.7444 - val_accuracy: 0.2253
# Epoch 6/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.8619 - accuracy: 0.7575 - val_loss: 1.8909 - val_accuracy: 0.4992
# Epoch 7/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.7006 - accuracy: 0.7996 - val_loss: 1.1722 - val_accuracy: 0.6547
# Epoch 8/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.5947 - accuracy: 0.8327 - val_loss: 1.1224 - val_accuracy: 0.6771
# Epoch 9/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.5228 - accuracy: 0.8531 - val_loss: 1.1114 - val_accuracy: 0.6925
# Epoch 10/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.4561 - accuracy: 0.8707 - val_loss: 1.1594 - val_accuracy: 0.6829
# Epoch 11/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.4048 - accuracy: 0.8888 - val_loss: 0.7993 - val_accuracy: 0.7731
# Epoch 12/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.3600 - accuracy: 0.8978 - val_loss: 0.5996 - val_accuracy: 0.8260
# Epoch 13/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.3201 - accuracy: 0.9085 - val_loss: 0.7917 - val_accuracy: 0.7924
# Epoch 14/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2828 - accuracy: 0.9174 - val_loss: 0.7411 - val_accuracy: 0.7932
# Epoch 15/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2640 - accuracy: 0.9204 - val_loss: 1.1525 - val_accuracy: 0.7122
# Epoch 16/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2257 - accuracy: 0.9393 - val_loss: 1.5325 - val_accuracy: 0.6377
# Epoch 17/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2121 - accuracy: 0.9389 - val_loss: 1.7142 - val_accuracy: 0.6312
# Epoch 18/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1856 - accuracy: 0.9487 - val_loss: 1.8313 - val_accuracy: 0.6227
# Epoch 19/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1772 - accuracy: 0.9519 - val_loss: 0.8282 - val_accuracy: 0.7793
# Epoch 20/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1630 - accuracy: 0.9543 - val_loss: 0.9924 - val_accuracy: 0.7442
# Epoch 21/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.1494 - accuracy: 0.9580 - val_loss: 0.9644 - val_accuracy: 0.7527
# Epoch 22/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.1383 - accuracy: 0.9602 - val_loss: 0.9753 - val_accuracy: 0.7766
# Epoch 23/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1364 - accuracy: 0.9637 - val_loss: 0.7873 - val_accuracy: 0.8071
# Epoch 24/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1315 - accuracy: 0.9649 - val_loss: 1.3980 - val_accuracy: 0.6960
# Epoch 25/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.1182 - accuracy: 0.9660 - val_loss: 0.7966 - val_accuracy: 0.8017
# Epoch 26/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.1187 - accuracy: 0.9684 - val_loss: 1.1660 - val_accuracy: 0.7461
# Epoch 27/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.1038 - accuracy: 0.9727 - val_loss: 0.9619 - val_accuracy: 0.7936
# Epoch 28/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0943 - accuracy: 0.9746 - val_loss: 0.6791 - val_accuracy: 0.8326
# Epoch 29/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0929 - accuracy: 0.9724 - val_loss: 1.3714 - val_accuracy: 0.7153
# Epoch 30/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0916 - accuracy: 0.9759 - val_loss: 0.6478 - val_accuracy: 0.8492
# Epoch 31/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0800 - accuracy: 0.9777 - val_loss: 1.5301 - val_accuracy: 0.7137
# Epoch 32/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0841 - accuracy: 0.9776 - val_loss: 0.6895 - val_accuracy: 0.8329
# Epoch 33/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0750 - accuracy: 0.9786 - val_loss: 0.9579 - val_accuracy: 0.7917
# Epoch 34/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0752 - accuracy: 0.9782 - val_loss: 0.8322 - val_accuracy: 0.8167
# Epoch 35/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0761 - accuracy: 0.9777 - val_loss: 1.0103 - val_accuracy: 0.7909
# Epoch 36/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0708 - accuracy: 0.9811 - val_loss: 0.8553 - val_accuracy: 0.8167
# Epoch 37/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0698 - accuracy: 0.9811 - val_loss: 1.1128 - val_accuracy: 0.7870
# Epoch 38/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0699 - accuracy: 0.9812 - val_loss: 0.8097 - val_accuracy: 0.8171
# Epoch 39/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0591 - accuracy: 0.9847 - val_loss: 0.8475 - val_accuracy: 0.8125
# Epoch 40/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0594 - accuracy: 0.9843 - val_loss: 0.6600 - val_accuracy: 0.8584
# Epoch 41/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0577 - accuracy: 0.9827 - val_loss: 1.7165 - val_accuracy: 0.7269
# Epoch 42/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0624 - accuracy: 0.9822 - val_loss: 1.0585 - val_accuracy: 0.7982
# Epoch 43/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0527 - accuracy: 0.9844 - val_loss: 0.7572 - val_accuracy: 0.8484
# Epoch 44/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0496 - accuracy: 0.9851 - val_loss: 0.9403 - val_accuracy: 0.8106
# Epoch 45/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0532 - accuracy: 0.9849 - val_loss: 0.8117 - val_accuracy: 0.8399
# Epoch 46/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0511 - accuracy: 0.9847 - val_loss: 1.2770 - val_accuracy: 0.7762
# Epoch 47/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0486 - accuracy: 0.9862 - val_loss: 1.0667 - val_accuracy: 0.8044
# Epoch 48/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0458 - accuracy: 0.9879 - val_loss: 0.7547 - val_accuracy: 0.8438
# Epoch 49/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0463 - accuracy: 0.9874 - val_loss: 0.8045 - val_accuracy: 0.8202
# Epoch 50/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0482 - accuracy: 0.9853 - val_loss: 0.6888 - val_accuracy: 0.8573
# Epoch 51/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0407 - accuracy: 0.9881 - val_loss: 0.7128 - val_accuracy: 0.8534
# Epoch 52/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0497 - accuracy: 0.9861 - val_loss: 0.8534 - val_accuracy: 0.8241
# Epoch 53/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0385 - accuracy: 0.9878 - val_loss: 0.6792 - val_accuracy: 0.8623
# Epoch 54/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0393 - accuracy: 0.9875 - val_loss: 0.9630 - val_accuracy: 0.8252
# Epoch 55/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0376 - accuracy: 0.9894 - val_loss: 1.0917 - val_accuracy: 0.7774
# Epoch 56/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0369 - accuracy: 0.9880 - val_loss: 1.0515 - val_accuracy: 0.8059
# Epoch 57/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0332 - accuracy: 0.9903 - val_loss: 0.8046 - val_accuracy: 0.8457
# Epoch 58/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0362 - accuracy: 0.9894 - val_loss: 0.7083 - val_accuracy: 0.8665
# Epoch 59/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0363 - accuracy: 0.9892 - val_loss: 1.0879 - val_accuracy: 0.8048
# Epoch 60/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0355 - accuracy: 0.9888 - val_loss: 0.6269 - val_accuracy: 0.8711
# Epoch 61/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0339 - accuracy: 0.9906 - val_loss: 0.9565 - val_accuracy: 0.8287
# Epoch 62/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0366 - accuracy: 0.9885 - val_loss: 1.1925 - val_accuracy: 0.7909
# Epoch 63/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0281 - accuracy: 0.9921 - val_loss: 1.8020 - val_accuracy: 0.7230
# Epoch 64/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0331 - accuracy: 0.9890 - val_loss: 0.8305 - val_accuracy: 0.8360
# Epoch 65/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0330 - accuracy: 0.9898 - val_loss: 1.0112 - val_accuracy: 0.8337
# Epoch 66/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0339 - accuracy: 0.9881 - val_loss: 1.0202 - val_accuracy: 0.7886
# Epoch 67/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0331 - accuracy: 0.9879 - val_loss: 0.6733 - val_accuracy: 0.8627
# Epoch 68/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0294 - accuracy: 0.9911 - val_loss: 0.7249 - val_accuracy: 0.8526
# Epoch 69/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0284 - accuracy: 0.9897 - val_loss: 0.8703 - val_accuracy: 0.8472
# Epoch 70/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0287 - accuracy: 0.9915 - val_loss: 0.7633 - val_accuracy: 0.8526
# Epoch 71/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0303 - accuracy: 0.9903 - val_loss: 1.2865 - val_accuracy: 0.8005
# Epoch 72/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0361 - accuracy: 0.9889 - val_loss: 1.3017 - val_accuracy: 0.7963
# Epoch 73/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0274 - accuracy: 0.9911 - val_loss: 0.9048 - val_accuracy: 0.8256
# Epoch 74/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0269 - accuracy: 0.9923 - val_loss: 0.9946 - val_accuracy: 0.8179
# Epoch 75/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0306 - accuracy: 0.9910 - val_loss: 1.6068 - val_accuracy: 0.7635
# Epoch 76/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0265 - accuracy: 0.9916 - val_loss: 0.8361 - val_accuracy: 0.8407
# Epoch 77/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0283 - accuracy: 0.9903 - val_loss: 0.8414 - val_accuracy: 0.8461
# Epoch 78/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0252 - accuracy: 0.9915 - val_loss: 1.4977 - val_accuracy: 0.7666
# Epoch 79/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0301 - accuracy: 0.9910 - val_loss: 0.7647 - val_accuracy: 0.8499
# Epoch 80/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0300 - accuracy: 0.9903 - val_loss: 1.4147 - val_accuracy: 0.7936
# Epoch 81/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0285 - accuracy: 0.9901 - val_loss: 1.0348 - val_accuracy: 0.8040
# Epoch 82/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0241 - accuracy: 0.9925 - val_loss: 0.6896 - val_accuracy: 0.8688
# Epoch 83/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0257 - accuracy: 0.9924 - val_loss: 0.8962 - val_accuracy: 0.8449
# Epoch 84/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0239 - accuracy: 0.9924 - val_loss: 0.9647 - val_accuracy: 0.8391
# Epoch 85/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0301 - accuracy: 0.9909 - val_loss: 1.3564 - val_accuracy: 0.7959
# Epoch 86/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0249 - accuracy: 0.9919 - val_loss: 1.0550 - val_accuracy: 0.8287
# Epoch 87/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0262 - accuracy: 0.9914 - val_loss: 1.1257 - val_accuracy: 0.8260
# Epoch 88/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0218 - accuracy: 0.9932 - val_loss: 0.7525 - val_accuracy: 0.8654
# Epoch 89/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0204 - accuracy: 0.9941 - val_loss: 1.1096 - val_accuracy: 0.8314
# Epoch 90/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0235 - accuracy: 0.9937 - val_loss: 1.0657 - val_accuracy: 0.8314
# Epoch 91/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0233 - accuracy: 0.9928 - val_loss: 0.9391 - val_accuracy: 0.8495
# Epoch 92/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0206 - accuracy: 0.9934 - val_loss: 1.9835 - val_accuracy: 0.7747
# Epoch 93/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0216 - accuracy: 0.9925 - val_loss: 1.6765 - val_accuracy: 0.7832
# Epoch 94/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0206 - accuracy: 0.9920 - val_loss: 1.0038 - val_accuracy: 0.8306
# Epoch 95/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0181 - accuracy: 0.9939 - val_loss: 1.0643 - val_accuracy: 0.8368
# Epoch 96/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0228 - accuracy: 0.9920 - val_loss: 0.7022 - val_accuracy: 0.8708
# Epoch 97/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0249 - accuracy: 0.9928 - val_loss: 0.9710 - val_accuracy: 0.8376
# Epoch 98/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0262 - accuracy: 0.9915 - val_loss: 1.0808 - val_accuracy: 0.8167
# Epoch 99/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0259 - accuracy: 0.9912 - val_loss: 1.0495 - val_accuracy: 0.8534
# Epoch 100/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0211 - accuracy: 0.9934 - val_loss: 1.0442 - val_accuracy: 0.8345

# %%
bp_model_history_df = convert_history_to_csv(bp_model_history)
bp_model_history_df.to_csv("model_histories/rmsprop/bp_model_history_fb.csv")

convert_model_to_onnx("bestmodels/rmsprop/bp_basic_model_fb.keras", (98, 40, 1))

# %%
create_train_val_plot(bp_model_history.history, overfit=False)

# %% [markdown]
# In questo caso il modello ha perfomato peggio rispetto al corrispettivo. Il valore minimo di loss è maggiore, mentre il valore massimo di accuratezza è inferiore.

# %%
best_bp_basic_model = tf.keras.models.load_model("bestmodels/rmsprop/bp_basic_model_fb.keras")
test_loss, test_acc = best_bp_basic_model.evaluate(fb_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 4ms/step - loss: 0.6435 - accuracy: 0.8063
# Accuratezza: 0.806

# %%
evaluate_onnx_model("bestmodels/rmsprop/bp_basic_model_fb.onnx", fb_test_ds)
# Out:
# Accuratezza: 0.806

# %% [markdown]
# Essendo l'accuratezza minore presente circa all'epoca 15, il modello salvato corrisponde a quello. Perciò di conseguenza anche l'accuratezza risulta essere minore.

# %%
for audio, label in fb_test_ds:
    create_distribution_plot(best_bp_basic_model, audio, label)
    break

# %% [markdown]
# ## Addestramento modello convolutivo base (mfcc)
# L'ultimo argomento che trattiamo nel notebook riguarda l'uso degli mfcc come dati in input ai modelli.

# %% [markdown]
# Procediamo nello stesso modo fatto sopra, quindi trasformiamo i dati con la nostra classe e otteniamo i set di train, validation e test.

# %%
mfcc_train_ds = DatasetConverter(train_ds)
mfcc_train_ds = mfcc_train_ds.convert('mfcc')

mfcc_validation_ds = DatasetConverter(validation_ds)
mfcc_validation_ds = mfcc_validation_ds.convert('mfcc')

mfcc_val_ds = mfcc_validation_ds.take(mfcc_validation_ds.cardinality() // 2)
mfcc_test_ds = mfcc_validation_ds.skip(mfcc_validation_ds.cardinality() // 2)

# %% [markdown]
# Considerata la grandezza ridotta della matrice degli mfcc, dobbiamo apportare una leggera modifica al modello convolutivo di base, applicando il **padding** nel livello `MaxPooling2D_4`.

# %%
def get_basic_model(input_shape):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=input_shape, name="inputs")
    x = tf.keras.layers.Normalization(name="normalizzazione")(inputs)

    # Blocco di apprendimento delle caratteristiche
    conv2D_1 = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same", name="conv2D_1")(x)
    MaxPooling2D_1 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_1")(conv2D_1)
    conv2D_2 = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same", name="conv2D_2")(MaxPooling2D_1)
    MaxPooling2D_2 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_2")(conv2D_2)
    conv2D_3 = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same", name="conv2D_3")(MaxPooling2D_2)
    MaxPooling2D_3 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_3")(conv2D_3)
    conv2D_4 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_4")(MaxPooling2D_3)
    MaxPooling2D_4 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_4", padding="same")(conv2D_4)
    conv2D_5 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_5")(MaxPooling2D_4)

    # Blocco di classificazione
    Flatten = tf.keras.layers.Flatten(name="Flatten")(conv2D_5)
    outputs = tf.keras.layers.Dense(30, activation="softmax", name="dense_output")(Flatten)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
for audio, label in mfcc_train_ds:
    basic_model = get_basic_model(audio.shape[1:])
    break
    
basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

basic_model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inputs (InputLayer)         [(None, 98, 12, 1)]       0
#
#  normalizzazione (Normalizat  (None, 98, 12, 1)        3
#  ion)
#
#  conv2D_1 (Conv2D)           (None, 98, 12, 32)        320
#
#  MaxPooling2D_1 (MaxPooling2  (None, 49, 6, 32)        0
#  D)
#
#  conv2D_2 (Conv2D)           (None, 49, 6, 64)         18496
#
#  MaxPooling2D_2 (MaxPooling2  (None, 24, 3, 64)        0
#  D)
#
#  conv2D_3 (Conv2D)           (None, 24, 3, 128)        73856
#
#  MaxPooling2D_3 (MaxPooling2  (None, 12, 1, 128)       0
#  D)
#
#  conv2D_4 (Conv2D)           (None, 12, 1, 256)        295168
#
#  MaxPooling2D_4 (MaxPooling2  (None, 6, 1, 256)        0
#  D)
#
#  conv2D_5 (Conv2D)           (None, 6, 1, 256)         590080
#
#  Flatten (Flatten)           (None, 1536)              0
#
#  dense_output (Dense)        (None, 30)                46110
#
# =================================================================
# Total params: 1,024,033
# Trainable params: 1,024,030
# Non-trainable params: 3
# _________________________________________________________________

# %% [markdown]
# Anche in questo caso notiamo una **diminuzione dei parametri di circa 50.0000**, dovuto alla differenza di grandezza della matrice.

# %%
basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/basic_model_mfcc.keras", save_best_only=True, monitor="val_loss")]
basic_model_history = basic_model.fit(mfcc_train_ds, epochs=30, batch_size=32, validation_data=mfcc_val_ds, callbacks=basic_model_callbacks)
# Out:
# Epoch 1/30
# 243/243 [==============================] - 2s 6ms/step - loss: 3.0976 - accuracy: 0.2307 - val_loss: 1.8341 - val_accuracy: 0.4749
# Epoch 2/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.3164 - accuracy: 0.6166 - val_loss: 1.1820 - val_accuracy: 0.6833
# Epoch 3/30
# 243/243 [==============================] - 1s 6ms/step - loss: 0.7657 - accuracy: 0.7714 - val_loss: 1.0194 - val_accuracy: 0.7454
# Epoch 4/30
# 243/243 [==============================] - 1s 6ms/step - loss: 0.5076 - accuracy: 0.8487 - val_loss: 0.9253 - val_accuracy: 0.7905
# Epoch 5/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3870 - accuracy: 0.8857 - val_loss: 2.3024 - val_accuracy: 0.6543
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3116 - accuracy: 0.9081 - val_loss: 1.3706 - val_accuracy: 0.7623
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2939 - accuracy: 0.9184 - val_loss: 1.1739 - val_accuracy: 0.7909
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2604 - accuracy: 0.9273 - val_loss: 3.6178 - val_accuracy: 0.6744
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2515 - accuracy: 0.9357 - val_loss: 1.3248 - val_accuracy: 0.7944
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2313 - accuracy: 0.9402 - val_loss: 1.5402 - val_accuracy: 0.8137
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2165 - accuracy: 0.9447 - val_loss: 1.4856 - val_accuracy: 0.8187
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2217 - accuracy: 0.9509 - val_loss: 2.0856 - val_accuracy: 0.8017
# Epoch 13/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2263 - accuracy: 0.9515 - val_loss: 1.6504 - val_accuracy: 0.8148
# Epoch 14/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2304 - accuracy: 0.9510 - val_loss: 2.2517 - val_accuracy: 0.8040
# Epoch 15/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2498 - accuracy: 0.9531 - val_loss: 3.0939 - val_accuracy: 0.7805
# Epoch 16/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2487 - accuracy: 0.9535 - val_loss: 2.7602 - val_accuracy: 0.8075
# Epoch 17/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2433 - accuracy: 0.9594 - val_loss: 2.6217 - val_accuracy: 0.8044
# Epoch 18/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2381 - accuracy: 0.9608 - val_loss: 2.8807 - val_accuracy: 0.8137
# Epoch 19/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2223 - accuracy: 0.9628 - val_loss: 3.4530 - val_accuracy: 0.8021
# Epoch 20/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2277 - accuracy: 0.9635 - val_loss: 3.6495 - val_accuracy: 0.8059
# Epoch 21/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2235 - accuracy: 0.9661 - val_loss: 3.0295 - val_accuracy: 0.8144
# Epoch 22/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2552 - accuracy: 0.9628 - val_loss: 3.5592 - val_accuracy: 0.8225
# Epoch 23/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2965 - accuracy: 0.9649 - val_loss: 2.9133 - val_accuracy: 0.8329
# Epoch 24/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2503 - accuracy: 0.9695 - val_loss: 3.1361 - val_accuracy: 0.8299
# Epoch 25/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2629 - accuracy: 0.9671 - val_loss: 3.3498 - val_accuracy: 0.8117
# Epoch 26/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2545 - accuracy: 0.9702 - val_loss: 3.5995 - val_accuracy: 0.8252
# Epoch 27/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2913 - accuracy: 0.9697 - val_loss: 4.8790 - val_accuracy: 0.8183
# Epoch 28/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2924 - accuracy: 0.9700 - val_loss: 4.3736 - val_accuracy: 0.8229
# Epoch 29/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2898 - accuracy: 0.9689 - val_loss: 4.3372 - val_accuracy: 0.8356
# Epoch 30/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3249 - accuracy: 0.9709 - val_loss: 4.4978 - val_accuracy: 0.8044

# %% [markdown]
# Salviamo i dati della history del modello in un file csv e convertiamo il miglior modello nell'estensione **.onnx**.

# %%
basic_model_history_df = convert_history_to_csv(basic_model_history)
basic_model_history_df.to_csv("model_histories/rmsprop/basic_model_history_mfcc.csv")

convert_model_to_onnx("bestmodels/rmsprop/basic_model_mfcc.keras", (98, 12, 1))

# %% [markdown]
# Visualizziamo l'andamento dell'accurateza e della perdita durante l'addestramento.

# %%
create_train_val_plot(basic_model_history.history)

# %% [markdown]
# Il modello di base addestrato sugli mfcc non ha performato bene quanto quello con i filterbanks. Raggiunge molto presto un adattamento ai dati e si nota un degradamento dell'accuratezza di **7 punti percentile**, con un aumento importante nel valore della perdita.

# %% [markdown]
# Verifichiamo l'accuratezza della migliore versione del modello di base.

# %%
best_basic_model = tf.keras.models.load_model("bestmodels/rmsprop/basic_model_mfcc.keras")
test_loss, test_acc = best_basic_model.evaluate(mfcc_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 5ms/step - loss: 0.9633 - accuracy: 0.7648
# Accuratezza: 0.765

# %%
evaluate_onnx_model("bestmodels/rmsprop/basic_model_mfcc.onnx", mfcc_test_ds)
# Out:
# Accuratezza: 0.765

# %% [markdown]
# Abbiamo ottenuto un'**accuratezza** del **76.5%**. Vediamo come si evolve con i prossimi modelli.

# %%
for audio, label in mfcc_test_ds: # prendiamo un audio a caso del test e creiamo la distribuzione
    create_distribution_plot(best_basic_model, audio, label)
    break

# %% [markdown]
# ### Convolutivo base risoluzione dell'overfitting
# In questa parte andremo a utilizzare il secondo modello presente nel notebook di riferimento, perciò il modello riguardante il paragrafo **risoluzione dell'overfitting**. Anche in questo caso, a causa della grandezza ridotta della matrice, è necessario applicare la stessa modifica allo stesso livello di MaxPooling.

# %%
def get_improved_basic_model(input_shape):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=input_shape)
    x = tf.keras.layers.Normalization()(inputs)

    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2, padding="same")(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
for audio, label in mfcc_train_ds:
    improved_basic_model = get_improved_basic_model(audio.shape[1:])
    break

improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

# %%
improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/improved_basic_model_mfcc.keras", save_best_only=True, monitor="val_loss")]
improved_history = improved_basic_model.fit(mfcc_train_ds, epochs=100, validation_data=mfcc_val_ds, callbacks=improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 2s 5ms/step - loss: 3.1169 - accuracy: 0.1700 - val_loss: 2.1803 - val_accuracy: 0.3723
# Epoch 2/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.6812 - accuracy: 0.5111 - val_loss: 1.0962 - val_accuracy: 0.6817
# Epoch 3/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.0549 - accuracy: 0.6851 - val_loss: 0.9353 - val_accuracy: 0.7365
# Epoch 4/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7933 - accuracy: 0.7727 - val_loss: 1.0016 - val_accuracy: 0.7500
# Epoch 5/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.6330 - accuracy: 0.8095 - val_loss: 0.7824 - val_accuracy: 0.7809
# Epoch 6/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5135 - accuracy: 0.8451 - val_loss: 0.7870 - val_accuracy: 0.7948
# Epoch 7/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4397 - accuracy: 0.8660 - val_loss: 0.9528 - val_accuracy: 0.8117
# Epoch 8/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.4121 - accuracy: 0.8789 - val_loss: 0.7803 - val_accuracy: 0.8187
# Epoch 9/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3863 - accuracy: 0.8884 - val_loss: 0.9937 - val_accuracy: 0.8040
# Epoch 10/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3721 - accuracy: 0.8947 - val_loss: 0.9000 - val_accuracy: 0.8044
# Epoch 11/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3515 - accuracy: 0.9026 - val_loss: 0.8570 - val_accuracy: 0.8349
# Epoch 12/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3642 - accuracy: 0.9044 - val_loss: 1.0405 - val_accuracy: 0.8144
# Epoch 13/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3589 - accuracy: 0.9081 - val_loss: 1.1261 - val_accuracy: 0.8383
# Epoch 14/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3500 - accuracy: 0.9171 - val_loss: 1.3429 - val_accuracy: 0.8264
# Epoch 15/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3053 - accuracy: 0.9207 - val_loss: 1.3075 - val_accuracy: 0.8233
# Epoch 16/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3455 - accuracy: 0.9170 - val_loss: 1.3699 - val_accuracy: 0.8110
# Epoch 17/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3320 - accuracy: 0.9226 - val_loss: 1.2419 - val_accuracy: 0.8468
# Epoch 18/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.3552 - accuracy: 0.9228 - val_loss: 1.3032 - val_accuracy: 0.8530
# Epoch 19/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3456 - accuracy: 0.9226 - val_loss: 1.6959 - val_accuracy: 0.8237
# Epoch 20/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3788 - accuracy: 0.9191 - val_loss: 1.1665 - val_accuracy: 0.8399
# Epoch 21/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3780 - accuracy: 0.9271 - val_loss: 1.2178 - val_accuracy: 0.8495
# Epoch 22/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3595 - accuracy: 0.9273 - val_loss: 1.1819 - val_accuracy: 0.8573
# Epoch 23/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3790 - accuracy: 0.9282 - val_loss: 2.0735 - val_accuracy: 0.8202
# Epoch 24/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3952 - accuracy: 0.9250 - val_loss: 1.5073 - val_accuracy: 0.8422
# Epoch 25/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4180 - accuracy: 0.9200 - val_loss: 1.8368 - val_accuracy: 0.8326
# Epoch 26/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3910 - accuracy: 0.9268 - val_loss: 1.3756 - val_accuracy: 0.8414
# Epoch 27/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4580 - accuracy: 0.9240 - val_loss: 1.2645 - val_accuracy: 0.8468
# Epoch 28/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3930 - accuracy: 0.9316 - val_loss: 1.8400 - val_accuracy: 0.8619
# Epoch 29/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4259 - accuracy: 0.9280 - val_loss: 1.7709 - val_accuracy: 0.8399
# Epoch 30/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3430 - accuracy: 0.9393 - val_loss: 1.6590 - val_accuracy: 0.8272
# Epoch 31/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4675 - accuracy: 0.9265 - val_loss: 1.8559 - val_accuracy: 0.8476
# Epoch 32/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4304 - accuracy: 0.9287 - val_loss: 2.3081 - val_accuracy: 0.8484
# Epoch 33/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4195 - accuracy: 0.9361 - val_loss: 2.6210 - val_accuracy: 0.8221
# Epoch 34/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4526 - accuracy: 0.9349 - val_loss: 1.6745 - val_accuracy: 0.8295
# Epoch 35/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4426 - accuracy: 0.9360 - val_loss: 2.3939 - val_accuracy: 0.8356
# Epoch 36/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5027 - accuracy: 0.9320 - val_loss: 2.9703 - val_accuracy: 0.8302
# Epoch 37/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4830 - accuracy: 0.9336 - val_loss: 2.3248 - val_accuracy: 0.8306
# Epoch 38/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4621 - accuracy: 0.9338 - val_loss: 1.8231 - val_accuracy: 0.8287
# Epoch 39/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4663 - accuracy: 0.9385 - val_loss: 2.9501 - val_accuracy: 0.8160
# Epoch 40/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4713 - accuracy: 0.9375 - val_loss: 1.9677 - val_accuracy: 0.8611
# Epoch 41/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.5418 - accuracy: 0.9379 - val_loss: 1.9302 - val_accuracy: 0.8711
# Epoch 42/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.4855 - accuracy: 0.9398 - val_loss: 2.2059 - val_accuracy: 0.8040
# Epoch 43/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5938 - accuracy: 0.9371 - val_loss: 1.7606 - val_accuracy: 0.8692
# Epoch 44/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4815 - accuracy: 0.9439 - val_loss: 2.7860 - val_accuracy: 0.8711
# Epoch 45/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5699 - accuracy: 0.9321 - val_loss: 2.4708 - val_accuracy: 0.8380
# Epoch 46/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5548 - accuracy: 0.9387 - val_loss: 2.0283 - val_accuracy: 0.8499
# Epoch 47/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4948 - accuracy: 0.9369 - val_loss: 4.9359 - val_accuracy: 0.7921
# Epoch 48/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5623 - accuracy: 0.9323 - val_loss: 2.0278 - val_accuracy: 0.8418
# Epoch 49/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5274 - accuracy: 0.9247 - val_loss: 3.1714 - val_accuracy: 0.8573
# Epoch 50/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5597 - accuracy: 0.9401 - val_loss: 3.3001 - val_accuracy: 0.8634
# Epoch 51/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5847 - accuracy: 0.9351 - val_loss: 3.0699 - val_accuracy: 0.8638
# Epoch 52/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5334 - accuracy: 0.9415 - val_loss: 2.5295 - val_accuracy: 0.8272
# Epoch 53/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6015 - accuracy: 0.9339 - val_loss: 2.4886 - val_accuracy: 0.8576
# Epoch 54/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6735 - accuracy: 0.9389 - val_loss: 3.0461 - val_accuracy: 0.8573
# Epoch 55/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6145 - accuracy: 0.9432 - val_loss: 3.3124 - val_accuracy: 0.8546
# Epoch 56/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6808 - accuracy: 0.9396 - val_loss: 3.1443 - val_accuracy: 0.8329
# Epoch 57/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6587 - accuracy: 0.9399 - val_loss: 3.0622 - val_accuracy: 0.8557
# Epoch 58/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6752 - accuracy: 0.9418 - val_loss: 4.7455 - val_accuracy: 0.8383
# Epoch 59/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5735 - accuracy: 0.9478 - val_loss: 2.7692 - val_accuracy: 0.8546
# Epoch 60/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6114 - accuracy: 0.9451 - val_loss: 3.8763 - val_accuracy: 0.8534
# Epoch 61/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5939 - accuracy: 0.9499 - val_loss: 3.2340 - val_accuracy: 0.8542
# Epoch 62/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6511 - accuracy: 0.9425 - val_loss: 4.2578 - val_accuracy: 0.8565
# Epoch 63/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6433 - accuracy: 0.9460 - val_loss: 3.0589 - val_accuracy: 0.8395
# Epoch 64/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6676 - accuracy: 0.9456 - val_loss: 4.2784 - val_accuracy: 0.8302
# Epoch 65/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7110 - accuracy: 0.9470 - val_loss: 3.7090 - val_accuracy: 0.8534
# Epoch 66/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6566 - accuracy: 0.9463 - val_loss: 5.7921 - val_accuracy: 0.8600
# Epoch 67/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7499 - accuracy: 0.9509 - val_loss: 3.7710 - val_accuracy: 0.8607
# Epoch 68/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6661 - accuracy: 0.9540 - val_loss: 6.1091 - val_accuracy: 0.8372
# Epoch 69/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8212 - accuracy: 0.9397 - val_loss: 5.8128 - val_accuracy: 0.8507
# Epoch 70/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6846 - accuracy: 0.9517 - val_loss: 4.8900 - val_accuracy: 0.8700
# Epoch 71/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7357 - accuracy: 0.9555 - val_loss: 4.0467 - val_accuracy: 0.8588
# Epoch 72/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6139 - accuracy: 0.9586 - val_loss: 4.8106 - val_accuracy: 0.8580
# Epoch 73/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6979 - accuracy: 0.9518 - val_loss: 5.0720 - val_accuracy: 0.8588
# Epoch 74/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6980 - accuracy: 0.9536 - val_loss: 5.9894 - val_accuracy: 0.8569
# Epoch 75/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8107 - accuracy: 0.9521 - val_loss: 5.4074 - val_accuracy: 0.8584
# Epoch 76/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8188 - accuracy: 0.9514 - val_loss: 4.8038 - val_accuracy: 0.8534
# Epoch 77/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7280 - accuracy: 0.9451 - val_loss: 4.3049 - val_accuracy: 0.8519
# Epoch 78/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6530 - accuracy: 0.9570 - val_loss: 7.5049 - val_accuracy: 0.8715
# Epoch 79/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6864 - accuracy: 0.9543 - val_loss: 3.9080 - val_accuracy: 0.8569
# Epoch 80/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7683 - accuracy: 0.9607 - val_loss: 7.7204 - val_accuracy: 0.8549
# Epoch 81/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8066 - accuracy: 0.9576 - val_loss: 6.2006 - val_accuracy: 0.8576
# Epoch 82/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8528 - accuracy: 0.9564 - val_loss: 4.4174 - val_accuracy: 0.8738
# Epoch 83/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8171 - accuracy: 0.9496 - val_loss: 4.7149 - val_accuracy: 0.8630
# Epoch 84/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7835 - accuracy: 0.9554 - val_loss: 5.6641 - val_accuracy: 0.8534
# Epoch 85/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6889 - accuracy: 0.9543 - val_loss: 5.1469 - val_accuracy: 0.8596
# Epoch 86/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7846 - accuracy: 0.9595 - val_loss: 7.0429 - val_accuracy: 0.8750
# Epoch 87/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8882 - accuracy: 0.9615 - val_loss: 6.4558 - val_accuracy: 0.8654
# Epoch 88/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7868 - accuracy: 0.9622 - val_loss: 7.2056 - val_accuracy: 0.8619
# Epoch 89/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8342 - accuracy: 0.9541 - val_loss: 5.7805 - val_accuracy: 0.8383
# Epoch 90/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7908 - accuracy: 0.9590 - val_loss: 5.9491 - val_accuracy: 0.8530
# Epoch 91/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.9864 - accuracy: 0.9594 - val_loss: 6.5196 - val_accuracy: 0.8708
# Epoch 92/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.8516 - accuracy: 0.9617 - val_loss: 8.0808 - val_accuracy: 0.8600
# Epoch 93/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8767 - accuracy: 0.9570 - val_loss: 10.8869 - val_accuracy: 0.8488
# Epoch 94/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.0027 - accuracy: 0.9573 - val_loss: 6.9260 - val_accuracy: 0.8468
# Epoch 95/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.9427 - accuracy: 0.9606 - val_loss: 6.0480 - val_accuracy: 0.8522
# Epoch 96/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.0125 - accuracy: 0.9617 - val_loss: 7.9435 - val_accuracy: 0.8812
# Epoch 97/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7325 - accuracy: 0.9638 - val_loss: 8.4367 - val_accuracy: 0.8665
# Epoch 98/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7872 - accuracy: 0.9657 - val_loss: 10.9527 - val_accuracy: 0.8391
# Epoch 99/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.9681 - accuracy: 0.9665 - val_loss: 10.8022 - val_accuracy: 0.8742
# Epoch 100/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8727 - accuracy: 0.9675 - val_loss: 12.5669 - val_accuracy: 0.8580

# %%
improved_history_df = convert_history_to_csv(improved_history)
improved_history_df.to_csv("model_histories/rmsprop/improved_history_mfcc.csv")

convert_model_to_onnx("bestmodels/rmsprop/improved_basic_model_mfcc.keras", (98, 12, 1))

# %%
create_train_val_plot(improved_history.history)

# %% [markdown]
# In questo caso abbiamo ottenuto dei miglioramenti nella gestione dell'overfitting, un aumento del valore massimo di accuratezza e un livello di perdita minimo inferiore.

# %%
improved_best_model = tf.keras.models.load_model("bestmodels/rmsprop/improved_basic_model_mfcc.keras")
test_loss, test_acc = improved_best_model.evaluate(mfcc_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 3ms/step - loss: 0.8236 - accuracy: 0.8179
# Accuratezza: 0.818

# %%
evaluate_onnx_model("bestmodels/rmsprop/improved_basic_model_mfcc.onnx", mfcc_test_ds)
# Out:
# Accuratezza: 0.818

# %% [markdown]
# Questi cambiamenti hanno portato ad ottenere un'accuratezza pari a **81.8%** nei dati di test! Un significativo aumento confrontando i precedenti.

# %%
for audio, label in mfcc_test_ds:
    create_distribution_plot(improved_best_model, audio, label)
    break

# %% [markdown]
# ### Modello convolutivo tuned
# In questa fase andremo ad addestrare lo stesso modello appena addestrato ma con un **tasso di apprendimento di 1e-5**, lo stesso utilizzato per il modello fine tuned sugli spettrogrammi.

# %%
for audio, label in mfcc_train_ds:
    tuned_improved_basic_model = get_improved_basic_model(audio.shape[1:])
    break

tuned_improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-5), metrics=["accuracy"])

# %%
tuned_improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/tuned_improved_basic_model_mfcc.keras", save_best_only=True, monitor="val_loss")]
tuned_improved_history = tuned_improved_basic_model.fit(mfcc_train_ds, epochs=100, validation_data=mfcc_val_ds, callbacks=tuned_improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 2s 6ms/step - loss: 4.7610 - accuracy: 0.0375 - val_loss: 3.4252 - val_accuracy: 0.0552
# Epoch 2/100
# 243/243 [==============================] - 1s 5ms/step - loss: 3.5181 - accuracy: 0.0476 - val_loss: 3.3277 - val_accuracy: 0.0748
# Epoch 3/100
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3687 - accuracy: 0.0668 - val_loss: 3.2704 - val_accuracy: 0.0965
# Epoch 4/100
# 243/243 [==============================] - 1s 5ms/step - loss: 3.2853 - accuracy: 0.0897 - val_loss: 3.2089 - val_accuracy: 0.1142
# Epoch 5/100
# 243/243 [==============================] - 1s 5ms/step - loss: 3.2192 - accuracy: 0.1031 - val_loss: 3.1404 - val_accuracy: 0.1358
# Epoch 6/100
# 243/243 [==============================] - 1s 5ms/step - loss: 3.1298 - accuracy: 0.1265 - val_loss: 3.0529 - val_accuracy: 0.1620
# Epoch 7/100
# 243/243 [==============================] - 1s 6ms/step - loss: 3.0412 - accuracy: 0.1512 - val_loss: 2.9601 - val_accuracy: 0.1848
# Epoch 8/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.9662 - accuracy: 0.1675 - val_loss: 2.8720 - val_accuracy: 0.2052
# Epoch 9/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.8949 - accuracy: 0.1795 - val_loss: 2.7916 - val_accuracy: 0.2296
# Epoch 10/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.8171 - accuracy: 0.1960 - val_loss: 2.7142 - val_accuracy: 0.2465
# Epoch 11/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.7382 - accuracy: 0.2207 - val_loss: 2.6414 - val_accuracy: 0.2697
# Epoch 12/100
# 243/243 [==============================] - 1s 6ms/step - loss: 2.6651 - accuracy: 0.2428 - val_loss: 2.5674 - val_accuracy: 0.2982
# Epoch 13/100
# 243/243 [==============================] - 1s 6ms/step - loss: 2.5855 - accuracy: 0.2603 - val_loss: 2.5068 - val_accuracy: 0.3052
# Epoch 14/100
# 243/243 [==============================] - 1s 6ms/step - loss: 2.5373 - accuracy: 0.2680 - val_loss: 2.4496 - val_accuracy: 0.3214
# Epoch 15/100
# 243/243 [==============================] - 1s 6ms/step - loss: 2.4706 - accuracy: 0.2912 - val_loss: 2.3872 - val_accuracy: 0.3380
# Epoch 16/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.4029 - accuracy: 0.3086 - val_loss: 2.3342 - val_accuracy: 0.3457
# Epoch 17/100
# 243/243 [==============================] - 1s 4ms/step - loss: 2.3518 - accuracy: 0.3228 - val_loss: 2.2872 - val_accuracy: 0.3630
# Epoch 18/100
# 243/243 [==============================] - 1s 4ms/step - loss: 2.3196 - accuracy: 0.3367 - val_loss: 2.2504 - val_accuracy: 0.3708
# Epoch 19/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.2628 - accuracy: 0.3479 - val_loss: 2.1992 - val_accuracy: 0.3792
# Epoch 20/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.2031 - accuracy: 0.3624 - val_loss: 2.1542 - val_accuracy: 0.3912
# Epoch 21/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.1689 - accuracy: 0.3687 - val_loss: 2.1217 - val_accuracy: 0.4097
# Epoch 22/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.1137 - accuracy: 0.3834 - val_loss: 2.0817 - val_accuracy: 0.4198
# Epoch 23/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.0722 - accuracy: 0.3952 - val_loss: 2.0458 - val_accuracy: 0.4325
# Epoch 24/100
# 243/243 [==============================] - 1s 5ms/step - loss: 2.0266 - accuracy: 0.4130 - val_loss: 2.0089 - val_accuracy: 0.4402
# Epoch 25/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.9764 - accuracy: 0.4220 - val_loss: 1.9768 - val_accuracy: 0.4514
# Epoch 26/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.9467 - accuracy: 0.4366 - val_loss: 1.9499 - val_accuracy: 0.4599
# Epoch 27/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.8982 - accuracy: 0.4447 - val_loss: 1.9155 - val_accuracy: 0.4726
# Epoch 28/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.8665 - accuracy: 0.4612 - val_loss: 1.8899 - val_accuracy: 0.4811
# Epoch 29/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.8245 - accuracy: 0.4680 - val_loss: 1.8657 - val_accuracy: 0.4834
# Epoch 30/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.7998 - accuracy: 0.4756 - val_loss: 1.8334 - val_accuracy: 0.4946
# Epoch 31/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.7575 - accuracy: 0.4821 - val_loss: 1.8148 - val_accuracy: 0.4985
# Epoch 32/100
# 243/243 [==============================] - 1s 6ms/step - loss: 1.7320 - accuracy: 0.5005 - val_loss: 1.7874 - val_accuracy: 0.5123
# Epoch 33/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.6861 - accuracy: 0.5061 - val_loss: 1.7637 - val_accuracy: 0.5104
# Epoch 34/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.6579 - accuracy: 0.5133 - val_loss: 1.7383 - val_accuracy: 0.5212
# Epoch 35/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.6265 - accuracy: 0.5268 - val_loss: 1.7193 - val_accuracy: 0.5278
# Epoch 36/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.6150 - accuracy: 0.5327 - val_loss: 1.6997 - val_accuracy: 0.5351
# Epoch 37/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.5764 - accuracy: 0.5420 - val_loss: 1.6805 - val_accuracy: 0.5394
# Epoch 38/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.5304 - accuracy: 0.5492 - val_loss: 1.6594 - val_accuracy: 0.5482
# Epoch 39/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.5128 - accuracy: 0.5540 - val_loss: 1.6366 - val_accuracy: 0.5598
# Epoch 40/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.4862 - accuracy: 0.5709 - val_loss: 1.6207 - val_accuracy: 0.5586
# Epoch 41/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.4629 - accuracy: 0.5698 - val_loss: 1.6137 - val_accuracy: 0.5633
# Epoch 42/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.4331 - accuracy: 0.5847 - val_loss: 1.5916 - val_accuracy: 0.5610
# Epoch 43/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.4027 - accuracy: 0.5954 - val_loss: 1.5683 - val_accuracy: 0.5679
# Epoch 44/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.3768 - accuracy: 0.5983 - val_loss: 1.5549 - val_accuracy: 0.5822
# Epoch 45/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.3420 - accuracy: 0.6059 - val_loss: 1.5455 - val_accuracy: 0.5764
# Epoch 46/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.3374 - accuracy: 0.6104 - val_loss: 1.5243 - val_accuracy: 0.5853
# Epoch 47/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.2974 - accuracy: 0.6251 - val_loss: 1.5099 - val_accuracy: 0.5930
# Epoch 48/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.2794 - accuracy: 0.6232 - val_loss: 1.4936 - val_accuracy: 0.5938
# Epoch 49/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.2539 - accuracy: 0.6280 - val_loss: 1.4852 - val_accuracy: 0.5976
# Epoch 50/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.2505 - accuracy: 0.6357 - val_loss: 1.4679 - val_accuracy: 0.6007
# Epoch 51/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.2308 - accuracy: 0.6405 - val_loss: 1.4554 - val_accuracy: 0.6073
# Epoch 52/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.1960 - accuracy: 0.6553 - val_loss: 1.4370 - val_accuracy: 0.6100
# Epoch 53/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.1806 - accuracy: 0.6528 - val_loss: 1.4227 - val_accuracy: 0.6134
# Epoch 54/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.1580 - accuracy: 0.6646 - val_loss: 1.4193 - val_accuracy: 0.6123
# Epoch 55/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.1286 - accuracy: 0.6697 - val_loss: 1.3998 - val_accuracy: 0.6181
# Epoch 56/100
# 243/243 [==============================] - 1s 6ms/step - loss: 1.1146 - accuracy: 0.6697 - val_loss: 1.3981 - val_accuracy: 0.6165
# Epoch 57/100
# 243/243 [==============================] - 1s 6ms/step - loss: 1.0961 - accuracy: 0.6817 - val_loss: 1.3778 - val_accuracy: 0.6223
# Epoch 58/100
# 243/243 [==============================] - 1s 6ms/step - loss: 1.0672 - accuracy: 0.6879 - val_loss: 1.3727 - val_accuracy: 0.6200
# Epoch 59/100
# 243/243 [==============================] - 1s 6ms/step - loss: 1.0692 - accuracy: 0.6860 - val_loss: 1.3546 - val_accuracy: 0.6258
# Epoch 60/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.0434 - accuracy: 0.6925 - val_loss: 1.3426 - val_accuracy: 0.6296
# Epoch 61/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.0249 - accuracy: 0.7044 - val_loss: 1.3396 - val_accuracy: 0.6308
# Epoch 62/100
# 243/243 [==============================] - 1s 6ms/step - loss: 1.0086 - accuracy: 0.7009 - val_loss: 1.3251 - val_accuracy: 0.6377
# Epoch 63/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.9911 - accuracy: 0.7073 - val_loss: 1.3185 - val_accuracy: 0.6362
# Epoch 64/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.9702 - accuracy: 0.7138 - val_loss: 1.3108 - val_accuracy: 0.6393
# Epoch 65/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.9661 - accuracy: 0.7171 - val_loss: 1.3020 - val_accuracy: 0.6416
# Epoch 66/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.9358 - accuracy: 0.7240 - val_loss: 1.2974 - val_accuracy: 0.6385
# Epoch 67/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.9284 - accuracy: 0.7245 - val_loss: 1.2864 - val_accuracy: 0.6435
# Epoch 68/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8974 - accuracy: 0.7329 - val_loss: 1.2623 - val_accuracy: 0.6489
# Epoch 69/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8958 - accuracy: 0.7338 - val_loss: 1.2642 - val_accuracy: 0.6501
# Epoch 70/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8717 - accuracy: 0.7446 - val_loss: 1.2634 - val_accuracy: 0.6485
# Epoch 71/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8642 - accuracy: 0.7472 - val_loss: 1.2448 - val_accuracy: 0.6528
# Epoch 72/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8490 - accuracy: 0.7472 - val_loss: 1.2360 - val_accuracy: 0.6590
# Epoch 73/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8289 - accuracy: 0.7604 - val_loss: 1.2276 - val_accuracy: 0.6582
# Epoch 74/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8147 - accuracy: 0.7571 - val_loss: 1.2237 - val_accuracy: 0.6605
# Epoch 75/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8169 - accuracy: 0.7591 - val_loss: 1.2185 - val_accuracy: 0.6593
# Epoch 76/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7951 - accuracy: 0.7666 - val_loss: 1.2127 - val_accuracy: 0.6647
# Epoch 77/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7712 - accuracy: 0.7689 - val_loss: 1.1987 - val_accuracy: 0.6674
# Epoch 78/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7525 - accuracy: 0.7790 - val_loss: 1.1968 - val_accuracy: 0.6636
# Epoch 79/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7602 - accuracy: 0.7773 - val_loss: 1.1955 - val_accuracy: 0.6655
# Epoch 80/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7324 - accuracy: 0.7809 - val_loss: 1.1894 - val_accuracy: 0.6690
# Epoch 81/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7239 - accuracy: 0.7825 - val_loss: 1.1805 - val_accuracy: 0.6748
# Epoch 82/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.7007 - accuracy: 0.7952 - val_loss: 1.1753 - val_accuracy: 0.6752
# Epoch 83/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7007 - accuracy: 0.7876 - val_loss: 1.1652 - val_accuracy: 0.6744
# Epoch 84/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6884 - accuracy: 0.7951 - val_loss: 1.1664 - val_accuracy: 0.6744
# Epoch 85/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6695 - accuracy: 0.8021 - val_loss: 1.1527 - val_accuracy: 0.6806
# Epoch 86/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6621 - accuracy: 0.7994 - val_loss: 1.1567 - val_accuracy: 0.6794
# Epoch 87/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6601 - accuracy: 0.8009 - val_loss: 1.1511 - val_accuracy: 0.6879
# Epoch 88/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6384 - accuracy: 0.8066 - val_loss: 1.1453 - val_accuracy: 0.6836
# Epoch 89/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6385 - accuracy: 0.8063 - val_loss: 1.1341 - val_accuracy: 0.6848
# Epoch 90/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6144 - accuracy: 0.8196 - val_loss: 1.1315 - val_accuracy: 0.6867
# Epoch 91/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6076 - accuracy: 0.8195 - val_loss: 1.1338 - val_accuracy: 0.6817
# Epoch 92/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6058 - accuracy: 0.8152 - val_loss: 1.1301 - val_accuracy: 0.6887
# Epoch 93/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5827 - accuracy: 0.8287 - val_loss: 1.1217 - val_accuracy: 0.6952
# Epoch 94/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5741 - accuracy: 0.8287 - val_loss: 1.1177 - val_accuracy: 0.6929
# Epoch 95/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5703 - accuracy: 0.8318 - val_loss: 1.1172 - val_accuracy: 0.6917
# Epoch 96/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5707 - accuracy: 0.8316 - val_loss: 1.1103 - val_accuracy: 0.6952
# Epoch 97/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5451 - accuracy: 0.8378 - val_loss: 1.1087 - val_accuracy: 0.6995
# Epoch 98/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5406 - accuracy: 0.8423 - val_loss: 1.1073 - val_accuracy: 0.6971
# Epoch 99/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5367 - accuracy: 0.8387 - val_loss: 1.0953 - val_accuracy: 0.7037
# Epoch 100/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5212 - accuracy: 0.8452 - val_loss: 1.0881 - val_accuracy: 0.7002

# %%
tuned_improved_history_df = convert_history_to_csv(tuned_improved_history)
tuned_improved_history_df.to_csv("model_histories/rmsprop/tuned_improved_history_mfcc.csv")

convert_model_to_onnx("bestmodels/rmsprop/tuned_improved_basic_model_mfcc.keras", (98, 12, 1))

# %%
create_train_val_plot(tuned_improved_history.history)

# %% [markdown]
# Anche in questo caso la rete non ha raggiunto l'overfitting, nonostante ci fosse vicina, perciò avremmo potuto addestrarlo per un numero di epoche maggiore.
#
# D'altro canto le prestazioni non sono delle migliori. L'accuratezza maggiore raggiunge con difficoltà il **70%**. Probabilmente avremmo dovuto utilizzare un'altro **tasso di apprendimento**.

# %%
tuned_improved_best_model = tf.keras.models.load_model("bestmodels/rmsprop/tuned_improved_basic_model_mfcc.keras")
test_loss, test_acc = tuned_improved_best_model.evaluate(mfcc_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 2ms/step - loss: 1.1160 - accuracy: 0.6939
# Accuratezza: 0.694

# %%
evaluate_onnx_model("bestmodels/rmsprop/tuned_improved_basic_model_mfcc.onnx", mfcc_test_ds)
# Out:
# Accuratezza: 0.694

# %% [markdown]
# Di fatto l'accuratezza raggiuta nel set non raggiunge neppure la soglia del **70%**.

# %%
for audio, label in mfcc_test_ds:
    create_distribution_plot(tuned_improved_best_model, audio, label)
    break

# %% [markdown]
# Come prima è riuscito a predire correttamente la classe three, con dell'incertezza verso tree. Accettabile vista la somiglianza tra le parole.

# %% [markdown]
# ### Miglioramenti all'architettura del modello convolutivo
# In questa ultima fase riguardante gli mfcc andremo ad addestrare il modello corrispondente alla sezione **miglioramenti all'architettura del modello** del notebook di riferimento.
#
# In questo caso non è necessario implementare cambiamenti all'architettura del modello.

# %%
def residual_block(x, filters, pooling=False):
    residual = x

    x = tf.keras.layers.SeparableConv2D(filters, 3, padding="same", use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    if pooling:
      x = tf.keras.layers.MaxPooling2D(pool_size=2, padding="same")(x)
      residual = tf.keras.layers.Conv2D(filters, 1, strides=2)(residual)
    elif filters != residual.shape[-1]:
      residual = tf.keras.layers.Conv2D(filters, 1)(residual)

    x = tf.keras.layers.add([x, residual])
    return x

def bp_basic_model(input_shape):
    # input e pre processamento
    inputs = tf.keras.Input(shape=input_shape)
    
    x = residual_block(inputs, 32, pooling=True)
    x = residual_block(x, 64, pooling=True)
    x = residual_block(x, 128, pooling=True)
    x = residual_block(x, 256, pooling=True)
    x = residual_block(x, 256, pooling=False)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Livelli per la classificazione
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
for audio, label in mfcc_train_ds:
    bp_basic_model = bp_basic_model(audio.shape[1:])
    break

bp_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

bp_basic_model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 98, 12, 1)]  0           []
#
#  separable_conv2d_5 (SeparableC  (None, 98, 12, 32)  41          ['input_7[0][0]']
#  onv2D)
#
#  batch_normalization_5 (BatchNo  (None, 98, 12, 32)  128         ['separable_conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 98, 12, 32)   0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_24 (MaxPooling2D  (None, 49, 6, 32)   0           ['activation_5[0][0]']
#  )
#
#  conv2d_28 (Conv2D)             (None, 49, 6, 32)    64          ['input_7[0][0]']
#
#  add_5 (Add)                    (None, 49, 6, 32)    0           ['max_pooling2d_24[0][0]',
#                                                                   'conv2d_28[0][0]']
#
#  separable_conv2d_6 (SeparableC  (None, 49, 6, 64)   2336        ['add_5[0][0]']
#  onv2D)
#
#  batch_normalization_6 (BatchNo  (None, 49, 6, 64)   256         ['separable_conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 49, 6, 64)    0           ['batch_normalization_6[0][0]']
#
#  max_pooling2d_25 (MaxPooling2D  (None, 25, 3, 64)   0           ['activation_6[0][0]']
#  )
#
#  conv2d_29 (Conv2D)             (None, 25, 3, 64)    2112        ['add_5[0][0]']
#
#  add_6 (Add)                    (None, 25, 3, 64)    0           ['max_pooling2d_25[0][0]',
#                                                                   'conv2d_29[0][0]']
#
#  separable_conv2d_7 (SeparableC  (None, 25, 3, 128)  8768        ['add_6[0][0]']
#  onv2D)
#
#  batch_normalization_7 (BatchNo  (None, 25, 3, 128)  512         ['separable_conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 25, 3, 128)   0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_26 (MaxPooling2D  (None, 13, 2, 128)  0           ['activation_7[0][0]']
#  )
#
#  conv2d_30 (Conv2D)             (None, 13, 2, 128)   8320        ['add_6[0][0]']
#
#  add_7 (Add)                    (None, 13, 2, 128)   0           ['max_pooling2d_26[0][0]',
#                                                                   'conv2d_30[0][0]']
#
#  separable_conv2d_8 (SeparableC  (None, 13, 2, 256)  33920       ['add_7[0][0]']
#  onv2D)
#
#  batch_normalization_8 (BatchNo  (None, 13, 2, 256)  1024        ['separable_conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 13, 2, 256)   0           ['batch_normalization_8[0][0]']
#
#  max_pooling2d_27 (MaxPooling2D  (None, 7, 1, 256)   0           ['activation_8[0][0]']
#  )
#
#  conv2d_31 (Conv2D)             (None, 7, 1, 256)    33024       ['add_7[0][0]']
#
#  add_8 (Add)                    (None, 7, 1, 256)    0           ['max_pooling2d_27[0][0]',
#                                                                   'conv2d_31[0][0]']
#
#  separable_conv2d_9 (SeparableC  (None, 7, 1, 256)   67840       ['add_8[0][0]']
#  onv2D)
#
#  batch_normalization_9 (BatchNo  (None, 7, 1, 256)   1024        ['separable_conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 7, 1, 256)    0           ['batch_normalization_9[0][0]']
#
#  add_9 (Add)                    (None, 7, 1, 256)    0           ['activation_9[0][0]',
#                                                                   'add_8[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 256)         0           ['add_9[0][0]']
#  obalAveragePooling2D)
#
#  dropout_5 (Dropout)            (None, 256)          0           ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_5 (Dense)                (None, 30)           7710        ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 167,079
# Trainable params: 165,607
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %% [markdown]
# Il numero di parametri, come per i filterbank, è rimasto invariato.

# %%
bp_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/bp_basic_model_mfcc.keras", save_best_only=True, monitor="val_loss")]
bp_model_history = bp_basic_model.fit(mfcc_train_ds, epochs=100, validation_data=mfcc_val_ds, callbacks=bp_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 3s 8ms/step - loss: 4.5528 - accuracy: 0.0911 - val_loss: 3.0737 - val_accuracy: 0.1335
# Epoch 2/100
# 243/243 [==============================] - 2s 8ms/step - loss: 2.8001 - accuracy: 0.2231 - val_loss: 2.8056 - val_accuracy: 0.2199
# Epoch 3/100
# 243/243 [==============================] - 2s 8ms/step - loss: 2.2301 - accuracy: 0.3577 - val_loss: 2.2214 - val_accuracy: 0.3677
# Epoch 4/100
# 243/243 [==============================] - 2s 8ms/step - loss: 1.8024 - accuracy: 0.4874 - val_loss: 1.7866 - val_accuracy: 0.4834
# Epoch 5/100
# 243/243 [==============================] - 2s 8ms/step - loss: 1.4750 - accuracy: 0.5811 - val_loss: 1.4724 - val_accuracy: 0.5772
# Epoch 6/100
# 243/243 [==============================] - 2s 9ms/step - loss: 1.2365 - accuracy: 0.6461 - val_loss: 1.5259 - val_accuracy: 0.5428
# Epoch 7/100
# 243/243 [==============================] - 2s 9ms/step - loss: 1.0810 - accuracy: 0.6875 - val_loss: 1.2249 - val_accuracy: 0.6451
# Epoch 8/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.9505 - accuracy: 0.7262 - val_loss: 1.1746 - val_accuracy: 0.6663
# Epoch 9/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.8471 - accuracy: 0.7536 - val_loss: 1.0581 - val_accuracy: 0.6898
# Epoch 10/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.7688 - accuracy: 0.7722 - val_loss: 1.0336 - val_accuracy: 0.6998
# Epoch 11/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.6905 - accuracy: 0.7965 - val_loss: 0.9030 - val_accuracy: 0.7380
# Epoch 12/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.6275 - accuracy: 0.8126 - val_loss: 1.0112 - val_accuracy: 0.7114
# Epoch 13/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.5777 - accuracy: 0.8340 - val_loss: 0.7469 - val_accuracy: 0.7847
# Epoch 14/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.5232 - accuracy: 0.8482 - val_loss: 0.9385 - val_accuracy: 0.7504
# Epoch 15/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.4856 - accuracy: 0.8536 - val_loss: 0.8461 - val_accuracy: 0.7731
# Epoch 16/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.4515 - accuracy: 0.8621 - val_loss: 0.8139 - val_accuracy: 0.7716
# Epoch 17/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.4072 - accuracy: 0.8814 - val_loss: 0.8476 - val_accuracy: 0.7731
# Epoch 18/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.3663 - accuracy: 0.8905 - val_loss: 0.8882 - val_accuracy: 0.7685
# Epoch 19/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.3424 - accuracy: 0.8985 - val_loss: 0.7280 - val_accuracy: 0.7998
# Epoch 20/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.3163 - accuracy: 0.9014 - val_loss: 0.7349 - val_accuracy: 0.8036
# Epoch 21/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.2972 - accuracy: 0.9091 - val_loss: 0.7830 - val_accuracy: 0.7963
# Epoch 22/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.2656 - accuracy: 0.9183 - val_loss: 0.7471 - val_accuracy: 0.8156
# Epoch 23/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.2527 - accuracy: 0.9237 - val_loss: 0.8641 - val_accuracy: 0.7847
# Epoch 24/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.2246 - accuracy: 0.9317 - val_loss: 0.7602 - val_accuracy: 0.8183
# Epoch 25/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.2165 - accuracy: 0.9349 - val_loss: 0.7568 - val_accuracy: 0.8102
# Epoch 26/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.1943 - accuracy: 0.9402 - val_loss: 0.8515 - val_accuracy: 0.7948
# Epoch 27/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.2022 - accuracy: 0.9356 - val_loss: 0.8256 - val_accuracy: 0.8075
# Epoch 28/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.1737 - accuracy: 0.9470 - val_loss: 0.8308 - val_accuracy: 0.7982
# Epoch 29/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.1668 - accuracy: 0.9468 - val_loss: 0.9217 - val_accuracy: 0.7870
# Epoch 30/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.1691 - accuracy: 0.9479 - val_loss: 0.8138 - val_accuracy: 0.7959
# Epoch 31/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.1499 - accuracy: 0.9541 - val_loss: 0.8789 - val_accuracy: 0.7978
# Epoch 32/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.1411 - accuracy: 0.9573 - val_loss: 0.7630 - val_accuracy: 0.8191
# Epoch 33/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.1308 - accuracy: 0.9608 - val_loss: 0.7816 - val_accuracy: 0.8171
# Epoch 34/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.1283 - accuracy: 0.9599 - val_loss: 0.9583 - val_accuracy: 0.7975
# Epoch 35/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.1242 - accuracy: 0.9612 - val_loss: 0.9265 - val_accuracy: 0.7990
# Epoch 36/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.1145 - accuracy: 0.9634 - val_loss: 0.8425 - val_accuracy: 0.8121
# Epoch 37/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.1090 - accuracy: 0.9652 - val_loss: 0.7933 - val_accuracy: 0.8237
# Epoch 38/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.1068 - accuracy: 0.9674 - val_loss: 0.8673 - val_accuracy: 0.8191
# Epoch 39/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.1077 - accuracy: 0.9656 - val_loss: 0.8745 - val_accuracy: 0.8117
# Epoch 40/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0916 - accuracy: 0.9711 - val_loss: 0.6768 - val_accuracy: 0.8484
# Epoch 41/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0965 - accuracy: 0.9716 - val_loss: 1.0997 - val_accuracy: 0.7820
# Epoch 42/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0972 - accuracy: 0.9697 - val_loss: 0.7454 - val_accuracy: 0.8279
# Epoch 43/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0842 - accuracy: 0.9729 - val_loss: 0.8774 - val_accuracy: 0.8152
# Epoch 44/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0813 - accuracy: 0.9755 - val_loss: 0.8312 - val_accuracy: 0.8044
# Epoch 45/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0837 - accuracy: 0.9723 - val_loss: 0.8509 - val_accuracy: 0.8148
# Epoch 46/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0775 - accuracy: 0.9741 - val_loss: 0.8093 - val_accuracy: 0.8333
# Epoch 47/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0723 - accuracy: 0.9774 - val_loss: 0.8603 - val_accuracy: 0.8245
# Epoch 48/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0714 - accuracy: 0.9778 - val_loss: 1.0059 - val_accuracy: 0.7971
# Epoch 49/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0680 - accuracy: 0.9793 - val_loss: 0.8517 - val_accuracy: 0.8160
# Epoch 50/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0692 - accuracy: 0.9795 - val_loss: 0.8211 - val_accuracy: 0.8233
# Epoch 51/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0758 - accuracy: 0.9769 - val_loss: 0.8720 - val_accuracy: 0.8164
# Epoch 52/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0676 - accuracy: 0.9771 - val_loss: 0.9819 - val_accuracy: 0.7978
# Epoch 53/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0686 - accuracy: 0.9768 - val_loss: 0.9165 - val_accuracy: 0.8248
# Epoch 54/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0634 - accuracy: 0.9803 - val_loss: 0.8761 - val_accuracy: 0.8233
# Epoch 55/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0648 - accuracy: 0.9791 - val_loss: 0.8293 - val_accuracy: 0.8314
# Epoch 56/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0594 - accuracy: 0.9809 - val_loss: 0.9699 - val_accuracy: 0.8183
# Epoch 57/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0678 - accuracy: 0.9778 - val_loss: 1.2637 - val_accuracy: 0.7770
# Epoch 58/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0602 - accuracy: 0.9791 - val_loss: 0.9631 - val_accuracy: 0.8252
# Epoch 59/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0607 - accuracy: 0.9802 - val_loss: 0.8973 - val_accuracy: 0.8322
# Epoch 60/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0555 - accuracy: 0.9826 - val_loss: 0.8043 - val_accuracy: 0.8430
# Epoch 61/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0549 - accuracy: 0.9829 - val_loss: 0.8290 - val_accuracy: 0.8364
# Epoch 62/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0506 - accuracy: 0.9845 - val_loss: 0.7689 - val_accuracy: 0.8422
# Epoch 63/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0593 - accuracy: 0.9807 - val_loss: 0.8441 - val_accuracy: 0.8391
# Epoch 64/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0542 - accuracy: 0.9827 - val_loss: 1.0569 - val_accuracy: 0.8079
# Epoch 65/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0478 - accuracy: 0.9834 - val_loss: 0.9181 - val_accuracy: 0.8318
# Epoch 66/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0504 - accuracy: 0.9836 - val_loss: 0.9828 - val_accuracy: 0.8295
# Epoch 67/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0457 - accuracy: 0.9847 - val_loss: 0.9790 - val_accuracy: 0.8229
# Epoch 68/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0528 - accuracy: 0.9822 - val_loss: 1.0282 - val_accuracy: 0.8229
# Epoch 69/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0476 - accuracy: 0.9860 - val_loss: 0.8687 - val_accuracy: 0.8380
# Epoch 70/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0412 - accuracy: 0.9862 - val_loss: 0.9221 - val_accuracy: 0.8353
# Epoch 71/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0490 - accuracy: 0.9840 - val_loss: 1.0215 - val_accuracy: 0.8279
# Epoch 72/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0430 - accuracy: 0.9854 - val_loss: 0.8753 - val_accuracy: 0.8329
# Epoch 73/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0520 - accuracy: 0.9832 - val_loss: 0.8168 - val_accuracy: 0.8403
# Epoch 74/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0441 - accuracy: 0.9851 - val_loss: 0.8540 - val_accuracy: 0.8468
# Epoch 75/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0390 - accuracy: 0.9881 - val_loss: 0.9055 - val_accuracy: 0.8295
# Epoch 76/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0426 - accuracy: 0.9865 - val_loss: 0.8914 - val_accuracy: 0.8326
# Epoch 77/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0484 - accuracy: 0.9841 - val_loss: 1.0958 - val_accuracy: 0.8025
# Epoch 78/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0487 - accuracy: 0.9856 - val_loss: 0.9184 - val_accuracy: 0.8275
# Epoch 79/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0433 - accuracy: 0.9865 - val_loss: 1.0327 - val_accuracy: 0.8299
# Epoch 80/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0435 - accuracy: 0.9863 - val_loss: 0.9623 - val_accuracy: 0.8329
# Epoch 81/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0393 - accuracy: 0.9885 - val_loss: 0.8579 - val_accuracy: 0.8468
# Epoch 82/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0426 - accuracy: 0.9857 - val_loss: 0.9123 - val_accuracy: 0.8484
# Epoch 83/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0373 - accuracy: 0.9892 - val_loss: 0.9240 - val_accuracy: 0.8430
# Epoch 84/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0444 - accuracy: 0.9856 - val_loss: 0.9068 - val_accuracy: 0.8499
# Epoch 85/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0389 - accuracy: 0.9862 - val_loss: 0.8457 - val_accuracy: 0.8441
# Epoch 86/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0392 - accuracy: 0.9881 - val_loss: 0.9155 - val_accuracy: 0.8430
# Epoch 87/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0416 - accuracy: 0.9875 - val_loss: 0.8565 - val_accuracy: 0.8441
# Epoch 88/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0321 - accuracy: 0.9902 - val_loss: 0.9244 - val_accuracy: 0.8468
# Epoch 89/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0377 - accuracy: 0.9883 - val_loss: 0.9192 - val_accuracy: 0.8368
# Epoch 90/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0441 - accuracy: 0.9860 - val_loss: 0.9689 - val_accuracy: 0.8418
# Epoch 91/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0337 - accuracy: 0.9892 - val_loss: 0.8387 - val_accuracy: 0.8453
# Epoch 92/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0410 - accuracy: 0.9871 - val_loss: 1.0556 - val_accuracy: 0.8287
# Epoch 93/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0346 - accuracy: 0.9896 - val_loss: 0.9798 - val_accuracy: 0.8322
# Epoch 94/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0368 - accuracy: 0.9869 - val_loss: 0.9694 - val_accuracy: 0.8345
# Epoch 95/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0340 - accuracy: 0.9887 - val_loss: 0.8827 - val_accuracy: 0.8418
# Epoch 96/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0364 - accuracy: 0.9880 - val_loss: 0.8534 - val_accuracy: 0.8503
# Epoch 97/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0352 - accuracy: 0.9887 - val_loss: 0.8546 - val_accuracy: 0.8507
# Epoch 98/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0317 - accuracy: 0.9892 - val_loss: 0.9165 - val_accuracy: 0.8465
# Epoch 99/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0357 - accuracy: 0.9894 - val_loss: 1.0108 - val_accuracy: 0.8356
# Epoch 100/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0387 - accuracy: 0.9884 - val_loss: 0.8879 - val_accuracy: 0.8453

# %%
bp_model_history_df = convert_history_to_csv(bp_model_history)
bp_model_history_df.to_csv("model_histories/rmsprop/bp_model_history_mfcc.csv")

convert_model_to_onnx("bestmodels/rmsprop/bp_basic_model_mfcc.keras", (98, 12, 1))

# %%
create_train_val_plot(bp_model_history.history, overfit=False)

# %% [markdown]
# In questo caso il modello è sotto certi aspetti leggermente migliorato rispetto a prima, ma continua ad avere delle prestazioni peggiori rispetto agli spettrogrammi e filterbanks.

# %%
best_bp_basic_model = tf.keras.models.load_model("bestmodels/rmsprop/bp_basic_model_mfcc.keras")
test_loss, test_acc = best_bp_basic_model.evaluate(mfcc_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 2ms/step - loss: 0.7680 - accuracy: 0.8214
# Accuratezza: 0.821

# %%
evaluate_onnx_model("bestmodels/rmsprop/bp_basic_model_mfcc.onnx", mfcc_test_ds)
# Out:
# Accuratezza: 0.821

# %% [markdown]
# Abbiamo ottenuto un'accuratezza del **82.1%**. A conferma di quanto detto prima, il modello risulta migliore.

# %%
for audio, label in mfcc_test_ds:
    create_distribution_plot(best_bp_basic_model, audio, label)
    break

# %% [markdown]
# La decisione del modello in questo caso è nuovamente molto chiara.
