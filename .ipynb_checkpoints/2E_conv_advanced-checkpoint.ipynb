# %%
# !wget --no-check-certificate 'https://cdn.discordapp.com/attachments/1209871752134529066/1249007689183268864/reduced_dataset.zip?ex=6676e00e&is=66758e8e&hm=ad151f919e12fa80c08cbcb693072d4aa9cf65f19e810a70ff43ada89864fd01&' -O ../reduced_dataset.zip
# !unzip ../reduced_dataset.zip
# !mv reduced_dataset ..
# Out:
# Output streaming troncato alle ultime 5000 righe.
#   inflating: reduced_dataset/dataset/audio/right/b737ee80_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/b7a0754f_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/right/b83c1acf_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/right/b8c48ffb_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/b93528e3_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/b959cd0c_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/b97c9f77_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/b9f46737_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/right/b9f46737_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/right/ba59cab3_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/ba59cab3_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/bcdaa7a9_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/right/bd11a2e7_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/right/bdee441c_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/right/bdee441c_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/right/be91a00a_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/becd5a53_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/bf5d409d_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/c0445658_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/c0c0d87d_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/c0fb6812_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/c120e80e_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/right/c120e80e_nohash_5.wav
#   inflating: reduced_dataset/dataset/audio/right/c120e80e_nohash_6.wav
#   inflating: reduced_dataset/dataset/audio/right/c137814b_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/c1d39ce8_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/right/c1d39ce8_nohash_6.wav
#   inflating: reduced_dataset/dataset/audio/right/c1e0e8e3_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/c205e625_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/c22d3f18_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/c37a72d3_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/c392e01d_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/c44d2a58_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/c4500713_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/c5570933_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/c578beb0_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/c634a189_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/right/c6ee87a7_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/right/c79159aa_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/c84f9b5c_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/c93d5e22_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/c93d5e22_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/right/c93d5e22_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/right/c9b653a0_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/c9b653a0_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/right/cb2929ce_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/right/cb2929ce_nohash_7.wav
#   inflating: reduced_dataset/dataset/audio/right/cb5d2c6e_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/right/cb802c63_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/right/cb8f8307_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/right/cc71bada_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/ccea893d_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/ccfd721c_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/cdbd6969_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/ce7a8e92_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/cf68fad2_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/cfde27ba_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/d069e6ff_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/d0858dce_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/d0f7bef5_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/d0faf7e4_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/right/d197e3ae_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/right/d1a17cbe_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/d2f4f431_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/d31d8dd7_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/d3a18257_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/d4082f3e_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/d430b3cc_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/d486fb84_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/d7529c0c_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/d8521ea0_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/d8a5ace5_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/d8ed3745_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/da2c5f1b_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/da4ef063_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/da584bc0_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/right/da7689f1_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/dabf67d9_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/db7c95b0_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/db8a3397_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/right/dbaf8fc6_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/dbaf8fc6_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/right/dbb40d24_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/dbb40d24_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/right/dbb40d24_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/right/dc75148d_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/dce5041a_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/dce5041a_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/dd6c6806_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/de040337_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/de08912f_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/de6eb27c_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/dedc7fab_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/df1d5024_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/right/e0315cf6_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/right/e0344f60_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/e0344f60_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/e04d7130_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/e2286c18_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/e41a903b_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/e41a903b_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/right/e4b02540_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/e4b02540_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/e53139ad_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/e53139ad_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/right/e53139ad_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/right/e5d2e09d_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/e63b69c5_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/e652590d_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/e7ea8b76_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/e95c70e2_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/eb0676ec_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/eb0676ec_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/right/eb3f7d82_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/right/ec545975_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/edc53350_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/edd8bfe3_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/eee9b9e2_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/right/eee9b9e2_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/right/efbc3952_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/f0ac2522_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/f174517e_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/f19c1390_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/f19c1390_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/right/f1b35ace_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/f1b35ace_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/f292725f_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/f2a90886_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/f4386675_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/f44f440f_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/f550b7dc_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/f5733968_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/right/f5c3de1b_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/f6af2457_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/f7b43563_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/f852895b_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/f8ad3941_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/f8f60f59_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/f8f60f59_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/f92e49f3_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/f92e49f3_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/right/f953e1af_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/f9bdf10e_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/fa44fcf5_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/fac74f6a_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/fafe8101_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/fc2411fe_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/fd395b74_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/right/fde2dee7_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/feb1d305_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/feb1d305_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/right/ffb86d3c_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/right/ffd2ba2f_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/right/fffcabd1_nohash_0.wav
#    creating: reduced_dataset/dataset/audio/seven/
#   inflating: reduced_dataset/dataset/audio/seven/0132a06d_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/0132a06d_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/0137b3f4_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/0137b3f4_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/01bcfc0c_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/023a61ad_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/026290a7_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/02e85b60_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/0362539c_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/0397ecda_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/0447d7c1_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/0474c92a_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/06076b6b_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/070b49af_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/07363607_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/099d52ad_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/0b56bcfe_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/0b77ee66_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/0c2ca723_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/0c40e715_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/0cd323ec_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/0d2bcf9d_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/0e4d22f1_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/0fa1e7a9_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/0ff728b5_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/0ff728b5_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/106a6183_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/10ace7eb_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/10c6d873_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/11099149_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/118261a9_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/11a022ba_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/122c5aa7_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/126403d4_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/126a31d2_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/151bfb79_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/15c563d7_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/15f04ff8_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/1625acd8_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/1706c35f_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/1a9afd33_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/1b4c9b89_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/1b88bf70_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/1bb574f9_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/1bb574f9_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/1c1060b1_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/1c3f4fac_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/1c45ceb2_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/1d919a90_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/1daa5ada_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/1dce06e8_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/1e412fac_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/1ecfb537_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/1ed557b9_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/1f653d27_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/2151b09a_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/2167c2ed_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/21832144_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/21832144_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/2275edbb_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/2275edbb_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/2275edbb_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/229978fd_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/2313e093_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/2313e093_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/23ad12d8_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/24befdb3_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/25c14394_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/264f471d_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/28e47b1a_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/28ef2a01_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/29fb33da_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/2b42e7a2_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/2c7c33e8_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/2cec1d47_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/2d3c8dcb_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/2d82a556_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/2e30f9a5_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/30a09789_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/30aabd44_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/311fde72_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/31e686d2_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/324210dd_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/324210dd_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/32561e9e_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/329eab8a_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/33246bc2_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/333784b7_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/3389305e_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/338dacf5_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/3402e488_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/3411cf4b_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/34263ab3_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/35c8fa78_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/35c8fa78_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/35d1b6ee_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/35d1b6ee_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/36050ef3_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/364c0853_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/364f979f_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/37dca74f_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/37e8db82_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/3824c00e_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/38d78313_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/39a12648_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/39a12648_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/39a12648_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/39a45230_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/39a45230_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/39ec87ac_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/3a182c98_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/3bc21161_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/3bdf05d3_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/3bfd30e6_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/3c1e12cf_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/3c257192_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/3d6bee47_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/3e31dffe_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/3e3b65eb_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/3e3fa7fd_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/3ec05c3d_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/40115b19_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/408de0a4_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/412c675c_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/41777abb_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/4249c833_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/439c84f4_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/439c84f4_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/43b85b64_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/4407ba92_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/44b5720d_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/44c201dd_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/460f2bad_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/46a153d8_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/46a153d8_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/471a0925_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/471a0925_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/47565088_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/479e64cc_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/48a8a69d_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/4954abe8_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/49af4432_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/49af4432_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/4a4e28f1_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/4a803e67_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/4c432947_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/4c432947_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/4c841771_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/4e8c5516_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/50928b05_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/50d1c8e3_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/50f55535_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/51055bda_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/5188de0d_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/5195f0ec_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/5195f0ec_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/520e8c0e_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/52e228e9_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/56eb74ae_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/57376a4c_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/57376a4c_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/589bce2c_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/58df33b5_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/5a9f7324_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/5af0ca83_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/5c39594f_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/5c39594f_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/5c8af87a_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/6071a214_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/6071a214_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/611d2b50_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/611d2b50_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/617de221_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/617de221_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/62581901_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/62581901_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/63996b7c_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/65040d9b_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/65c73b55_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/65d14087_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/65ec06e5_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/66aa0f29_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/6794a793_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/6823565f_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/682e1687_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/686d030b_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/686d030b_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/686d030b_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/6a203e0e_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/6a27a9bf_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/6ac35824_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/6add0595_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/6af4aa07_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/6c429c7b_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/6c9223bd_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/6cb6eee7_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/6d0ad764_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/6d2d3b0d_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/6d818f6c_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/6e8b9b7b_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/6e916de8_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/6f7724f5_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/6f9088d7_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/71904de3_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/71aa5b54_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/71f6fed7_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/71f9bba8_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/723efc4c_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/72d75d96_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/735845ab_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/73f0c1f7_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/742d6431_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/742d6431_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/74551073_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/74b73f88_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/763188c4_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/76e53db9_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/782c1305_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/794cdfc5_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/7ab5b8f7_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/7ab5b8f7_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/7cb5c0b7_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/7cbf645a_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/7d5f87c8_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/7d5f87c8_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/7e2d5caf_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/7e2d5caf_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/7e6bd776_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/7e7f0ed6_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/7e843da8_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/7fd25f7c_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/8056e897_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/82305c3a_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/834f03fe_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/834f03fe_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/840eab5a_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/84bf12ff_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/863880b7_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/86b89661_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/87c62767_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/8830e17f_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/888a0c49_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/888a0c49_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/88f3719f_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/8931f494_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/89865a6f_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/8a0457c9_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/8a325749_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/8c3c4715_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/8d9cc260_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/8eb4a1bf_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/8eb4a1bf_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/8f3f252c_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/8f4c551f_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/8ff44869_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/90804775_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/918a2473_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/918a2473_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/92037d73_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/9229bff9_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/92a9c5e6_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/937b433e_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/953fe1ad_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/964e8cfd_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/964e8cfd_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/96ab6565_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/96c66ab7_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/96c67073_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/97101ef3_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/97101ef3_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/9712cce0_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/9735764a_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/97f493b9_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/97f4c236_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/982babaf_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/9886d8bf_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/99fad6a0_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/99fad6a0_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/9a3f97f8_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/9a69672b_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/9a7c1f83_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/9aa21fa9_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/9b027ecf_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/9b402bc2_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/9bea2ac7_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/9c59dd28_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/9ce7a419_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/9ce7a419_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/9d7036f9_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/9dc1889e_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/9e075bf1_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/9f63152b_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/9ff1b8b6_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/9ff2d2f4_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/9ff2d2f4_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/a0f93943_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/a0f93943_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/a16b3102_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/a1a59b72_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/a1dd919f_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/a243fcc2_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/a2b16113_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/a4e8a997_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/a6285644_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/a827e3a1_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/a902ce9b_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/aac5b7c1_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/ab00c4b2_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/ab3f0c1b_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/ab71c9a7_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/ab7b5acd_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/aba19127_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/ac7840d8_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/ad5aeec2_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/ad63d93c_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/aef8dcf5_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/afd53389_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/b01c8f61_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/b087aa0e_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/b1426003_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/b2fbe484_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/b31ad508_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/b487da60_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/b49caed3_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/b4aa9fef_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/b5552931_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/b63fea9e_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/b71ebf79_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/b7669804_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/b7a0754f_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/b83c1acf_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/b83c1acf_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/b843de62_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/b87bdb22_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/b8897f1c_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/b9515bf3_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/b959cd0c_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/b97c9f77_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/b9cccd01_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/b9f46737_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/b9f46737_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/ba59cab3_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/ba770f9b_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/bbd0bbd0_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/bbd0bbd0_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/bdb26021_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/bdee441c_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/bdee441c_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/bf8d5617_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/bf90a57a_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/c0445658_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/c0445658_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/c08e5058_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/c0c701f1_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/c0e8f5a1_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/c103a2d5_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/c120e80e_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/c120e80e_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/c120e80e_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/c120e80e_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/c1d39ce8_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/c1d39ce8_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/c1d39ce8_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/c205e625_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/c22d3f18_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/c22d3f18_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/c2aeb59d_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/c3538de1_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/c392e01d_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/c518d1b1_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/c6ca5d01_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/c6ee87a7_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/c79159aa_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/c8db14a8_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/c948d727_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/c948d727_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/c948d727_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/c9b653a0_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/ca48dc76_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/cae62f38_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/cb2929ce_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/cb8f8307_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/cb8f8307_nohash_6.wav
#   inflating: reduced_dataset/dataset/audio/seven/cc592808_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/cc6ee39b_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/ccf418a5_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/cd85758f_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/cd911ace_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/cd911ace_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/ced4e2a1_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/cf68fad2_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/d0858dce_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/d0f7bef5_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/d0faf7e4_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/d0faf7e4_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/d1453a87_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/d197e3ae_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/d312f481_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/d312f481_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/d430b3cc_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/d53e25ba_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/d55aa56c_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/d5c41d6a_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/d750966e_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/d7559b2d_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/d7ca14ef_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/d8521ea0_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/d8ed3745_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/d94eb94f_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/d952a17e_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/d9b8fab2_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/d9e9f554_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/da584bc0_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/dabf67d9_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/db9d52d2_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/dbb40d24_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/dc2222d7_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/dc6e9c04_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/dca2797e_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/dca2797e_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/de41f895_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/dea820ce_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/dea820ce_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/dfb6450b_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/e0315cf6_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/e0315cf6_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/e0315cf6_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/e1469561_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/e1469561_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/e2008f39_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/e3411931_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/e41a903b_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/e41a903b_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/e4a2cf79_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/e4b02540_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/e54a0f16_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/e54a0f16_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/e57d35bc_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/e5afa9b0_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/e6db3894_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/e7117d00_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/e7117d00_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/e7334395_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/e805a617_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/e82914c0_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/e8c3c5ca_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/e8c3c5ca_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/ea356919_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/eb0676ec_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/eb0676ec_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/eb0676ec_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/eb3f7d82_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/eb3f7d82_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/f00180d0_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/f0ebef1b_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/f0edc767_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/f17be97f_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/seven/f19c1390_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/f19c1390_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/seven/f1d36c53_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/f264e0df_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/f47d644e_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/f5496439_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/f5733968_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/f5e5e8b0_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/f6af2457_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/f839238a_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/fafe8101_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/fb2f3242_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/fb7c9b3b_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/seven/fc2411fe_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/seven/fce65496_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/fd32732a_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/fd395b74_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/seven/ffd2ba2f_nohash_0.wav
#    creating: reduced_dataset/dataset/audio/sheila/
#   inflating: reduced_dataset/dataset/audio/sheila/004ae714_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/sheila/00f0204f_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/sheila/00f0204f_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/sheila/019fa366_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/sheila/01bb6a2a_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/sheila/023808be_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/sheila/035de8fe_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/sheila/0397ecda_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/sheila/0397ecda_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/sheila/0447d7c1_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/sheila/0616de09_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/sheila/079dfce3_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/sheila/08ab8082_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/sheila/09ddc105_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/sheila/0b09edd3_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/sheila/0b09edd3_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/sheila/0c40e715_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/sheila/0c5027de_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/sheila/0d393936_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/sheila/0d53e045_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/sheila/0ea0e2f4_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/sheila/105a0eea_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/sheila/10627519_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/sheila/10f2bb12_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/sheila/11379f4d_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/sheila/11860c84_nohash_1.wav
# ...
#   inflating: reduced_dataset/dataset/audio/zero/8eb4a1bf_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/8ec6dab6_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/8f0d3c27_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/8f0d3c27_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/8f0d3c27_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/zero/8f4c551f_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/8f4c551f_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/zero/8f4c551f_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/zero/918a2473_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/zero/92037d73_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/92a9c5e6_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/zero/94de6a6a_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/95218ce8_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/953fe1ad_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/zero/9587481f_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/964e8cfd_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/zero/96a48d28_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/96c67073_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/97101ef3_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/982babaf_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/98447c43_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/9886d8bf_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/zero/99081f4d_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/9a356ab9_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/9a3f97f8_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/9a69672b_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/zero/9aa21fa9_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/zero/9aa21fa9_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/zero/9acd0254_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/9c59dd28_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/9d32f10a_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/9d7036f9_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/9db2bfe9_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/9e42ae25_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/9e42ae25_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/9ff1b8b6_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/9ff2d2f4_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/zero/a1a59b72_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/a1cff772_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/a331d9cb_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/a331d9cb_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/a42a88ff_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/a5609cce_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/a6d586b7_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/zero/a759efbc_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/a84dee7b_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/a8f45bdc_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/aac5b7c1_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/zero/ab00c4b2_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/ab3f0c1b_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/ab7b5acd_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/ab81c9c8_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/aba19127_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/abbfc3b4_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/ac899eb7_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/ad5aeec2_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/ad63d93c_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/zero/ad6a46f1_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/ad89eb1e_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/adb45ef2_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/aeb99b1c_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/zero/aeb99b1c_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/zero/b16f2d0d_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/b3327675_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/b36c27c2_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/b36c27c2_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/b36c27c2_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/b3bb4dd6_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/b43de700_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/b4aa9fef_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/zero/b575b5fb_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/b59fa113_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/b59fa113_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/b6ebe225_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/b6ebe225_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/b71ebf79_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/b7669804_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/b7a0754f_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/zero/b7a6f709_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/b83c1acf_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/b84f83d2_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/b87bdb22_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/b87bdb22_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/zero/b8897f1c_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/b8b8cb52_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/b8b8cb52_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/b9515bf3_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/zero/b959cd0c_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/b959cd0c_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/zero/b959cd0c_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/zero/b9db6e42_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/b9db6e42_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/b9f46737_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/b9f46737_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/bbb2eb5b_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/bbbf4fbd_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/bd11c654_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/bdee441c_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/bed06fac_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/bed06fac_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/bf4af1af_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/bf8d5617_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/bfdb9801_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/c0445658_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/c0445658_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/c0445658_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/zero/c099668c_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/c0e8f5a1_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/c120e80e_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/c120e80e_nohash_5.wav
#   inflating: reduced_dataset/dataset/audio/zero/c1d39ce8_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/c1d39ce8_nohash_7.wav
#   inflating: reduced_dataset/dataset/audio/zero/c1e0e8e3_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/c22d3f18_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/c24d96eb_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/c4500713_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/c4533c47_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/c518d1b1_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/c5570933_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/c634a189_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/zero/c692524d_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/c6ee87a7_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/c6ee87a7_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/c8db14a8_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/c93d5e22_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/zero/c948d727_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/zero/ca48dc76_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/ca4eeab0_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/caa4779f_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/caf1803e_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/cb8f8307_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/cb8f8307_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/zero/cb8f8307_nohash_6.wav
#   inflating: reduced_dataset/dataset/audio/zero/cc554de3_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/cc592808_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/cc6ee39b_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/ccfd721c_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/cd7f8c1b_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/cd7f8c1b_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/zero/ce7a8e92_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/ceaadb24_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/cf68fad2_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/d0faf7e4_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/d1a17cbe_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/d3f22f0e_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/d6265c56_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/d6360b32_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/d90b4138_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/d91a159e_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/d933bf5e_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/da584bc0_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/da584bc0_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/zero/dabd70c2_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/db79a764_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/db7c95b0_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/db9cd41d_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/db9d52d2_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/dbb40d24_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/dc75148d_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/dea820ce_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/df1d5024_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/df1d5024_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/df280250_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/e0322f2c_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/e0344f60_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/e0344f60_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/e0ff1e9c_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/e1469561_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/e1469561_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/e1469561_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/zero/e54a0f16_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/e54a0f16_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/e57d35bc_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/e5dadd24_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/e5e54cee_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/e62056e2_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/e6be0830_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/e71b4ce6_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/e7ea8b76_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/e7ebf59c_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/e91d173e_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/e9287461_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/ea12e0d1_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/eb3f7d82_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/eb3f7d82_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/ec201020_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/zero/ee483d85_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/efa16ffd_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/f00180d0_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/f0ac2522_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/f0ac2522_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/f0ebef1b_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/f192e6b4_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/f21893dc_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/f264e0df_nohash_2.wav
#   inflating: reduced_dataset/dataset/audio/zero/f3957e23_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/f4c77b26_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/f4cae173_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/f5733968_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/f5733968_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/zero/f5e5e8b0_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/f638a812_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/f6581345_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/f852895b_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/f8f60f59_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/zero/f8f60f59_nohash_4.wav
#   inflating: reduced_dataset/dataset/audio/zero/f92e49f3_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/f92e49f3_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/f92e49f3_nohash_3.wav
#   inflating: reduced_dataset/dataset/audio/zero/f9bdf10e_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/fa44fcf5_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/fa7895de_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/fad7a69a_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/fb7c9b3b_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/fcb25a78_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/fe1916ba_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/feb1d305_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/ffa76c4a_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/ffbb695d_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/ffd2ba2f_nohash_0.wav
#   inflating: reduced_dataset/dataset/audio/zero/ffd2ba2f_nohash_1.wav
#   inflating: reduced_dataset/dataset/audio/zero/fffcabd1_nohash_0.wav

# %% [markdown]
# # Modello convolutivo avanzato
#
# In questo notebook implementeremo un'architettura affermata nell'ambito del riconoscimento vocale, la **VggVox**.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import scipy.fftpack as scipy
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# per il modello con estensione .onnx
import onnxruntime as rt
import tf2onnx
import onnx

# %% [markdown]
# ## Importazione funzioni
# In aggiunta alla classe per la conversione del dataset, ci serviremo delle seguenti funzioni:
# - `convert_history_to_csv` - salva l'history dell'addestramento in un csv
# - `convert_model_to_onnx` - converte il miglior modello **.keras** in **.onnx**
# - `create_train_val_plot` - visualizza l'andamento dell'accuratezza e della perdita durante l'addestramento
# - `evaluate_onnx_model` - valuta il modello sui dati di test con il modello **.onnx**
# - `create_distribution_plot` - visualizza la distribuzione di accuratezza delle classi su un'immagine casuale
#
# Sia la classe che le funzioni appena citate sono già conosciute dai notebook precedenti, perciò non ci soffermeremo nel dettaglio su di esse.

# %%
def convert_history_to_csv(model_history):
    # converto la history del dataframe in un dataframe pandas
    model_history_df = pd.DataFrame(model_history.history)
    # cambio il nome dell'indice e lo imposto a partire da 1
    model_history_df.index = range(1, len(model_history_df) + 1)
    model_history_df.index.name = "epochs"

    return model_history_df

def convert_model_to_onnx(model_path, input_shape):
    model = tf.keras.models.load_model(model_path)

    onnx_path = model_path.split(".")[:-1] + ["onnx"]
    onnx_path = ".".join(onnx_path)

    input_signature = [tf.TensorSpec((None, *input_shape), tf.float32, name="input")]
    onnx_model, _ = tf2onnx.convert.from_keras(model, input_signature=input_signature)

    onnx.save(onnx_model, onnx_path)

def create_train_val_plot(history, overfit=True):
    # definisco numero epoche
    epochs = range(1, len(history['accuracy']) + 1)

    # Accuracy
    accuracy = history['accuracy']
    val_accuracy = history['val_accuracy']

    fig_acc, ax_acc = plt.subplots()

    # linea di base
    ax_acc.plot(epochs, [0.5 for x in range(len(epochs))], color="lightgray", linestyle="--", label="Base")
    # linee di accuratezza
    ax_acc.plot(epochs, accuracy, color="slategray", label="Accuratezza in addestramento")
    ax_acc.plot(epochs, val_accuracy, color="indianred", label="Accuratezza in validazione")
    # miglior accuratezza validazione
    ax_acc.axhline(y=max(val_accuracy), c='indianred', alpha=0.7, linestyle='--')
    ax_acc.text(len(epochs) * 1.07, max(val_accuracy), round(max(val_accuracy), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_acc.spines["right"].set_visible(False)
    ax_acc.spines["top"].set_visible(False)
    ax_acc.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_acc.set_title("Accuratezza in addestramento e validazione")
    ax_acc.set_xlabel("Epoche")
    ax_acc.set_ylabel("Accuratezza (%)")
    ax_acc.legend()

    # Loss
    loss = history['loss']
    val_loss = history['val_loss']

    fig_loss, ax_loss = plt.subplots()

    # linee di loss
    ax_loss.plot(epochs, loss, color="slategray", label="Perdita in addestramento")
    ax_loss.plot(epochs, val_loss, color="indianred", label="Perdita in validazione")
    # miglior loss validazione
    ax_loss.axhline(y=min(val_loss), c='indianred', alpha=0.7, linestyle='--')
    ax_loss.text(len(epochs) * 1.07, min(val_loss), round(min(val_loss), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_loss.spines["right"].set_visible(False)
    ax_loss.spines["top"].set_visible(False)
    ax_loss.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_loss.set_title("Perdita in addestramento e validazione")
    ax_loss.set_xlabel("Epoche")
    ax_loss.set_ylabel("Perdita")

    handles, _ = ax_loss.get_legend_handles_labels()

    if overfit:
        # area overfit
        rect = mpatches.Rectangle((np.argmin(val_loss) + 1, 0), width=100 - np.argmin(val_loss), height=max(max(loss), max(val_loss)), color='lightcoral', alpha=0.3)
        ax_loss.add_patch(rect)
        # patch overfit per legenda
        overfit = mpatches.Patch(color='indianred', alpha=0.3, label='Area overfit')
        handles, _ = ax_loss.get_legend_handles_labels()
        handles.append(overfit)

    # legenda
    ax_loss.legend(handles=handles)

    plt.show()

def evaluate_onnx_model(path_model_onnx, test_ds):
    # il fatto che sia suddiviso in batch mi crea problemi, perciò lo risolvo togliendoli
    test_ds = test_ds.unbatch()

    # carico il modello utilizzando il file onnx
    m = rt.InferenceSession(path_model_onnx)

    # trasformo il dataset in array numpy
    spectrogram_np = np.array([spectrogram.numpy() for spectrogram, _ in test_ds], dtype=np.float32)
    labels_np = np.array([label.numpy() for _, label in test_ds])

    # eseguo le predizione del modello
    pred_onnx = m.run(None, {'input': spectrogram_np})
    # ottengo la predizione corretta
    predictions = np.argmax(pred_onnx[0], axis=1)
    # computo la accuratezza
    accuracy = np.mean(predictions == labels_np)
    # stampo l'accuratezza
    print(f"Accuratezza: {accuracy:.3f}")

def create_distribution_plot(model, audio, label):
    prediction = model(audio) # otteniamo la predizione del modello sull'audio preso in input

    random_audio_index = np.random.randint(0, len(prediction) - 1) # abbiamo notato che mostravamo sempre la classe no, magari così cambia un po' le classi che mostriamo

    softmax_pred = tf.nn.softmax(prediction[random_audio_index]) # dobbiamo applicare nuovamente la softmax in modo tale da avere dei dati leggibili
    pred_label = np.argmax(softmax_pred) # ci salviamo l'indice della label predetta dal nostro modello, quella con la probabilità più alta

    colors = ['indianred'] * len(label_names) # creiamo un vettore di lunghezza 30 (la quantità delle nostre label) colorate di rosso

    if pred_label == label[random_audio_index].numpy(): # se la label che abbiamo predetto è corretta, allora la coloriamo di verde
        colors[pred_label] = 'seagreen'
    else: # se la label che abbiamo predetto è sbagliata, allora coloriamo di verde la corretta e di gialla la predetta
        colors[pred_label] = 'khaki'
        colors[label[random_audio_index].numpy()] = 'seagreen'

    plt.figure(figsize=(12, 4))

    plt.bar(label_names, softmax_pred.numpy(), color=colors)
    plt.xticks(rotation=45)

    # dichiariamo i colori della legenda
    other_values_patch = mpatches.Patch(color='indianred', label='Altre classi')
    pred_value_patch = mpatches.Patch(color='khaki', label='Classe predetta')
    correct_value_patch = mpatches.Patch(color='green', label='Classe corretta')

    # disegniamo la legenda con i colori necessari
    if pred_label == label[random_audio_index].numpy(): # se abbiamo predetto correttamente la label, non è necessario mostrare il colore giallo (non è presente nel plot)
        plt.legend(handles=[other_values_patch, correct_value_patch])
    else:
        plt.legend(handles=[other_values_patch, pred_value_patch, correct_value_patch])

    plt.show()

# %% [markdown]
# Funzione per mostrare la distribuzione di accuratezza delle classi.

# %% [markdown]
# Funzioni per la conversione del dataset in spettrogrammi, filterbanks, e mfcc.

# %%
class DatasetConverter:
    def __init__(self, dataset):
        self.dataset = dataset

    def convert(self, option):
        available_options = ['spectrogram', 'filterbanks', 'mfcc']

        if option == available_options[0]:
            return self.get_spectrogram_dataset()
        elif option == available_options[1]:
            return self.get_filterbanks_dataset()
        elif option == available_options[2]:
            return self.get_mfcc_dataset()
        else:
            raise ValueError(f"Opzione non disponibile: inserire una delle seguenti opzioni: {available_options}")

    # INIZIO SPETTROGRAMMI
    def squeeze(self, audio, labels):
        audio = tf.squeeze(audio, axis=-1)
        return audio, labels

    def get_spectrogram(self, waveform):
    # applichiamo la short-time Fourier transorm
        spectrogram = tf.signal.stft(waveform, frame_length=255, frame_step=128)
        spectrogram = tf.abs(spectrogram)

        return spectrogram[..., tf.newaxis]

    def get_spectrogram_dataset(self):
        # squeeze
        self.dataset = self.dataset.map(self.squeeze, tf.data.AUTOTUNE)
        self.dataset = self.dataset.map(lambda x, y: (self.get_spectrogram(x), y), num_parallel_calls=tf.data.AUTOTUNE)

        return self.dataset

    # FINE SPETTROGRAMMI

    def convert_to_numpy(self, dataset):
        audio_data = []
        labels = []

        dataset = dataset.unbatch()

        for audio, label in dataset:
            audio_data.append(audio.numpy())  # Assuming audio is a tensor, convert to numpy array
            labels.append(label.numpy())      # Assuming label is a tensor, convert to numpy array

        audio_data = np.array(audio_data)
        labels = np.array(labels)

        return audio_data, labels

    # INIZIO FILTERBANKS
    def makeHamming(self, M):
        R = (( M - 1 ) / 2 , M / 2)[M % 2 == 0]
        w = (np.hamming(M), np.hamming(M + 1))[M % 2 == 0]
        if M % 2 != 0:
            w[0] = w[0]/2
            w[M-1] = w[M-1]/2
        else:
            w = w[:M]

        return w

    def hztomel(self, hz):
        return (2595 * np.log10(1 + hz / 700))

    def meltohz(self, mel):
        return (700 * (10**(mel / 2595) - 1))

    def compute_filterbanks(self, audios_np, pre_emphasis=0.97, sample_rate=16000, frame_size=0.025, frame_stride=0.01, NFFT=512, nfilt=40):
        filterbanks_np = []

        for samples in audios_np:
            emphasized_audio = np.append(samples[0], samples[1:] - pre_emphasis * samples[:-1])
            audio_length = len(emphasized_audio)

            frame_length, frame_step = int(frame_size * sample_rate), int(frame_stride * sample_rate)

            num_frames = int(np.ceil(float(np.abs(audio_length - frame_length)) / frame_step))

            pad_audio_length = num_frames * frame_step + frame_length
            z = np.zeros((pad_audio_length - audio_length))
            pad_audio = np.append(emphasized_audio, z)

            indices = np.tile(np.arange(0, frame_length), (num_frames, 1)) + np.tile(np.arange(0, num_frames * frame_step, frame_step), (frame_length, 1)).T
            frames = pad_audio[indices.astype(np.int32, copy=False)]

            # Usiamo la funzione di Hamming
            hamming_window = self.makeHamming(frame_length)

            mag_frames = np.absolute(np.fft.rfft(frames, NFFT))  # Magnitudo della FFT
            pow_frames = ((1.0 / NFFT) * ((mag_frames) ** 2))

            # convertiamo hz in mel
            low_freq_mel = self.hztomel(0)
            high_freq_mel = self.hztomel(sample_rate / 2)

            mel_points = np.linspace(low_freq_mel, high_freq_mel, nfilt + 2)
            hz_points = self.meltohz(mel_points)

            bin = np.floor((NFFT + 1) * hz_points / sample_rate)

            fbank = np.zeros((nfilt, int(np.floor(NFFT / 2 + 1))))

            for m in range(1, nfilt + 1):
                f_m_minus = int(bin[m - 1])
                f_m = int(bin[m])
                f_m_plus = int(bin[m + 1])

                for k in range(f_m_minus, f_m):
                    fbank[m - 1, k] = (k - bin[m - 1]) / (bin[m] - bin[m - 1])
                for k in range(f_m, f_m_plus):
                    fbank[m - 1, k] = (bin[m + 1] - k) / (bin[m + 1] - bin[m])

            # in questo momento invece calcoliamo i filter banks per i segmenti di audio, utilizzando i filtri triangolari appena creati
            filter_banks = np.dot(pow_frames, fbank.T)
            filter_banks = np.where(filter_banks == 0, np.finfo(float).eps, filter_banks)
            filter_banks = 20 * np.log10(filter_banks)

            filterbanks_np.append(filter_banks)

        return np.array(filterbanks_np)

    def get_filterbanks_dataset(self):
        audios, labels = self.convert_to_numpy(self.dataset)

        filterbanks = self.compute_filterbanks(audios)
        filterbanks = np.expand_dims(filterbanks, axis=-1)

        self.dataset = tf.data.Dataset.from_tensor_slices((filterbanks, labels))
        self.dataset = self.dataset.batch(32)

        return self.dataset
    # FINE FILTERBANKS

    # INIZIO MFCC
    def compute_mfcc(self, filter_banks, num_ceps=12, cep_lifter=22):
        mfcc_np = []

        for f in filter_banks:
            mfcc = scipy.dct(f, type=2, axis=1, norm='ortho')[:, 1 : (num_ceps + 1)]

            (nframes, ncoeff) = mfcc.shape
            n = np.arange(ncoeff)

            lift = 1 + (cep_lifter / 2) * np.sin(np.pi * n / cep_lifter)
            mfcc *= lift

            mfcc_np.append(mfcc)

        return np.array(mfcc_np)


    def get_mfcc_dataset(self):
        audios, labels = self.convert_to_numpy(self.dataset)

        filterbanks = self.compute_filterbanks(audios)
        mfcc = self.compute_mfcc(filterbanks)

        mfcc = np.expand_dims(mfcc, axis=-1)

        self.dataset = tf.data.Dataset.from_tensor_slices((mfcc, labels))
        self.dataset = self.dataset.batch(32)

        return self.dataset

    # FINE MFCC

# %% [markdown]
# Creiamo e convertiamo il dataset.

# %%
train_ds, validation_ds = tf.keras.utils.audio_dataset_from_directory(
    directory='../reduced_dataset/dataset/audio',
    validation_split=0.4, # stiamo mettendo da parte il 40% del dataset, che sarà suddiviso in validation set e test set
    shuffle=True,
    subset='both', # necessario se stiamo utilizzando validation_split (se no darebbe errore)
    seed=0 # necessario se stiamo utilizzando sia shuffle che validation_split (se no darebbe errore)
)

label_names = train_ds.class_names
# Out:
# Found 12933 files belonging to 30 classes.
# Using 7760 files for training.
# Using 5173 files for validation.

# %% [markdown]
# ## VoxProfunda (Spettrogrammi)
# La **VoxProfunda** è un'architettura basata sulla **VggVox** che a sua volta è fondata sulla **ResNet-34**.

# %%
spect_train_ds = DatasetConverter(train_ds)
spect_train_ds = spect_train_ds.convert('spectrogram')

spect_validation_ds = DatasetConverter(validation_ds)
spect_validation_ds = spect_validation_ds.convert('spectrogram')

spect_val_ds = spect_validation_ds.take(spect_validation_ds.cardinality() // 2)
spect_test_ds = spect_validation_ds.skip(spect_validation_ds.cardinality() // 2)

# %% [markdown]
# ### ResNet-34 e VggVox
# La **ResNet** è un'architettura di reti neurali convolutivi composta da 34 livelli. La sua peculiarità s'incentra sull'utilizzo dei blocchi residuali. Quest'ultimi, come abbiamo già imputato, prevengono il problema del **gradiente evanescente**.
#
# Questa architettura, e le sue simili, sono ampiamente utilizzate nell'ambito della **computer vision**.
#
# Dalla modifica della **ResNet-34 e Resnet-50**, le quali differiscono per il numero di livelli e filtri, nasce la **VggVox**. Questa architettura è specializzata nei compiti di elaborazione del parlato. La modifica effettuata consiste nella sostituzione dell'ultimo livello denso con due livelli:
# - un livello densamente connesso 9x1
# - un livello di average pooling 1xN, dove N dipende dalla lunghezza del segmento audio
#
# Adattando la VggVox al nostro task (30 classi di output), abbiamo creato la VoxProfunda.

# %%
class VoxProfunda():
    def __init__(self):
        self.counter = 0

    def conv2D_x(self, filters, kernel_size, conv_n_layers, repeat, strides=1, padding="valid", name=False):
        self.counter += 1

        if name == False:
            if self.counter == repeat:
                name = "conv" + str(self.counter)
            else:
                name = "conv" + str(self.counter) + "_" + str(repeat)

        conv2D =  tf.keras.Sequential(name=name)

        for repetition in range(repeat):
            for layer in range(conv_n_layers):
                conv2D.add(tf.keras.layers.Conv2D(filters=filters, kernel_size=kernel_size, strides=strides, padding=padding))
            conv2D.add(tf.keras.layers.BatchNormalization())
            conv2D.add(tf.keras.layers.Activation("relu"))

        return conv2D

    def residual_block(self, x, filters, kernel_size, conv_n_layers, repeat, strides=1, padding="valid", name=False, pooling=False):
        residual = x
        x = self.conv2D_x(filters, kernel_size, conv_n_layers, repeat, strides, padding, name)(x)
        if pooling:
            x = tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides=2, padding="same")(x)
            residual = tf.keras.layers.Conv2D(filters, 1, strides=4)(residual)
        elif filters != residual.shape[-1]:
            residual = tf.keras.layers.Conv2D(filters, 1)(residual)

        output_layer = tf.keras.layers.add([x, residual])
        return output_layer

    def get_model(self, input_shape):
        inputs = tf.keras.Input(shape=input_shape, name="input")
        normalization = tf.keras.layers.Normalization(name="normalization")(inputs)

        # Blocco di apprendimento delle caratteristiche
        # conv1
        conv1 = self.residual_block(normalization,filters=64, kernel_size=(7,7), conv_n_layers=1, repeat=1, strides=2, padding="same", pooling=True)

        # conv2_x * 3
        conv2_3 = self.residual_block(conv1, filters=64, kernel_size=(3,3), conv_n_layers=2, repeat=3, padding="same")

        # conv3_x * 4
        conv3_4 = self.residual_block(conv2_3, filters=128, kernel_size=(3,3), conv_n_layers=2, repeat=4, padding="same")

        # conv4_x * 6
        conv4_6 = self.residual_block(conv3_4, filters=256, kernel_size=(3,3), conv_n_layers=2, repeat=6, padding="same")

        # conv4_x * 3
        conv5_3 = self.residual_block(conv4_6, filters=512, kernel_size=(3,3), conv_n_layers=2, repeat=3, padding="same")

        # global average pooling
        fc1 = tf.keras.layers.Conv2D(filters=512, kernel_size=(9, 1), strides=1, activation="relu", name="fc1")(conv5_3)

        # pool_time
        avg_pooling = tf.keras.layers.GlobalAveragePooling2D(name="pool_time")(fc1)

        #dropout 1
        dropout_1 = tf.keras.layers.Dropout(0.5, name="dropout_1")(avg_pooling)

        # softmax
        outputs = tf.keras.layers.Dense(30, activation="softmax", name="softmax")(dropout_1)

        return tf.keras.models.Model(inputs=inputs, outputs=outputs)

# %%
voxprofunda = VoxProfunda()

for audio, label in spect_train_ds:
    voxprofunda = voxprofunda.get_model(audio.shape[1:])
    break

voxprofunda.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

voxprofunda.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input (InputLayer)          [(None, 124, 129, 1)]        0         []
#
#  normalization (Normalizati  (None, 124, 129, 1)          3         ['input[0][0]']
#  on)
#
#  conv1 (Sequential)          (None, 62, 65, 64)           3456      ['normalization[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 31, 33, 64)           0         ['conv1[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 31, 33, 64)           128       ['normalization[0][0]']
#
#  add (Add)                   (None, 31, 33, 64)           0         ['max_pooling2d[0][0]',
#                                                                      'conv2d_1[0][0]']
#
#  conv2_3 (Sequential)        (None, 31, 33, 64)           222336    ['add[0][0]']
#
#  add_1 (Add)                 (None, 31, 33, 64)           0         ['conv2_3[0][0]',
#                                                                      'add[0][0]']
#
#  conv3_4 (Sequential)        (None, 31, 33, 128)          1108992   ['add_1[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 31, 33, 128)          8320      ['add_1[0][0]']
#
#  add_2 (Add)                 (None, 31, 33, 128)          0         ['conv3_4[0][0]',
#                                                                      'conv2d_16[0][0]']
#
#  conv4_6 (Sequential)        (None, 31, 33, 256)          6792192   ['add_2[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 31, 33, 256)          33024     ['add_2[0][0]']
#
#  add_3 (Add)                 (None, 31, 33, 256)          0         ['conv4_6[0][0]',
#                                                                      'conv2d_29[0][0]']
#
#  conv5_3 (Sequential)        (None, 31, 33, 512)          1298534   ['add_3[0][0]']
#                                                           4
#
#  conv2d_36 (Conv2D)          (None, 31, 33, 512)          131584    ['add_3[0][0]']
#
#  add_4 (Add)                 (None, 31, 33, 512)          0         ['conv5_3[0][0]',
#                                                                      'conv2d_36[0][0]']
#
#  fc1 (Conv2D)                (None, 23, 33, 512)          2359808   ['add_4[0][0]']
#
#  pool_time (GlobalAveragePo  (None, 512)                  0         ['fc1[0][0]']
#  oling2D)
#
#  dropout_1 (Dropout)         (None, 512)                  0         ['pool_time[0][0]']
#
#  softmax (Dense)             (None, 30)                   15390     ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 23660577 (90.26 MB)
# Trainable params: 23652894 (90.23 MB)
# Non-trainable params: 7683 (30.02 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# Il modello ha un totale di  **23.6 milioni di parametri**, una differenza notevole rispetto al nostro modello di base iniziale il quale ne aveva meno di **1.5 milioni**.

# %%
callback_voxprofunda = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/resnet/voxprofunda_spect.keras", save_best_only=True, monitor="val_loss")]
history_voxprofunda = voxprofunda.fit(spect_train_ds, epochs=100, validation_data=spect_val_ds, callbacks=callback_voxprofunda)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 48s 103ms/step - loss: 3.3533 - accuracy: 0.0769 - val_loss: 7.4286 - val_accuracy: 0.0556
# Epoch 2/100
# 243/243 [==============================] - 19s 76ms/step - loss: 2.7314 - accuracy: 0.2090 - val_loss: 14.5276 - val_accuracy: 0.0509
# Epoch 3/100
# 243/243 [==============================] - 20s 82ms/step - loss: 1.9397 - accuracy: 0.4254 - val_loss: 2.6517 - val_accuracy: 0.3688
# Epoch 4/100
# 243/243 [==============================] - 19s 76ms/step - loss: 1.1849 - accuracy: 0.6477 - val_loss: 3.0567 - val_accuracy: 0.4410
# Epoch 5/100
# 243/243 [==============================] - 20s 82ms/step - loss: 0.8733 - accuracy: 0.7463 - val_loss: 0.8964 - val_accuracy: 0.7728
# Epoch 6/100
# 243/243 [==============================] - 20s 82ms/step - loss: 0.6946 - accuracy: 0.7960 - val_loss: 0.8118 - val_accuracy: 0.7701
# Epoch 7/100
# 243/243 [==============================] - 20s 82ms/step - loss: 0.5607 - accuracy: 0.8325 - val_loss: 0.8048 - val_accuracy: 0.7681
# Epoch 8/100
# 243/243 [==============================] - 20s 82ms/step - loss: 0.5098 - accuracy: 0.8474 - val_loss: 0.5195 - val_accuracy: 0.8492
# Epoch 9/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.4943 - accuracy: 0.8523 - val_loss: 0.7353 - val_accuracy: 0.8152
# Epoch 10/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.4623 - accuracy: 0.8652 - val_loss: 0.6338 - val_accuracy: 0.8364
# Epoch 11/100
# 243/243 [==============================] - 20s 82ms/step - loss: 0.3913 - accuracy: 0.8849 - val_loss: 0.4120 - val_accuracy: 0.8808
# Epoch 12/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.3932 - accuracy: 0.8830 - val_loss: 0.5657 - val_accuracy: 0.8414
# Epoch 13/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.3822 - accuracy: 0.8885 - val_loss: 0.5147 - val_accuracy: 0.8507
# Epoch 14/100
# 243/243 [==============================] - 20s 82ms/step - loss: 0.3592 - accuracy: 0.8899 - val_loss: 0.3783 - val_accuracy: 0.8900
# Epoch 15/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.3166 - accuracy: 0.9048 - val_loss: 0.4822 - val_accuracy: 0.8576
# Epoch 16/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.3174 - accuracy: 0.9063 - val_loss: 0.4251 - val_accuracy: 0.8823
# Epoch 17/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.2942 - accuracy: 0.9117 - val_loss: 0.4231 - val_accuracy: 0.8831
# Epoch 18/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.3137 - accuracy: 0.9040 - val_loss: 0.4168 - val_accuracy: 0.8758
# Epoch 19/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.2891 - accuracy: 0.9165 - val_loss: 0.4562 - val_accuracy: 0.8792
# Epoch 20/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.2945 - accuracy: 0.9139 - val_loss: 0.4041 - val_accuracy: 0.9008
# Epoch 21/100
# 243/243 [==============================] - 19s 77ms/step - loss: 0.2699 - accuracy: 0.9192 - val_loss: 0.4665 - val_accuracy: 0.8785
# Epoch 22/100
# 243/243 [==============================] - 20s 82ms/step - loss: 0.2592 - accuracy: 0.9229 - val_loss: 0.3368 - val_accuracy: 0.9039
# Epoch 23/100
# 243/243 [==============================] - 19s 77ms/step - loss: 0.2561 - accuracy: 0.9233 - val_loss: 0.4702 - val_accuracy: 0.8735
# Epoch 24/100
# 243/243 [==============================] - 19s 77ms/step - loss: 0.2473 - accuracy: 0.9294 - val_loss: 0.3559 - val_accuracy: 0.9032
# Epoch 25/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.2211 - accuracy: 0.9352 - val_loss: 0.3923 - val_accuracy: 0.9012
# Epoch 26/100
# 243/243 [==============================] - 20s 82ms/step - loss: 0.2039 - accuracy: 0.9372 - val_loss: 0.2818 - val_accuracy: 0.9194
# Epoch 27/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.2220 - accuracy: 0.9347 - val_loss: 0.3955 - val_accuracy: 0.8954
# Epoch 28/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.2428 - accuracy: 0.9293 - val_loss: 0.3378 - val_accuracy: 0.9074
# Epoch 29/100
# 243/243 [==============================] - 20s 82ms/step - loss: 0.2441 - accuracy: 0.9293 - val_loss: 0.2762 - val_accuracy: 0.9244
# Epoch 30/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1978 - accuracy: 0.9409 - val_loss: 0.3092 - val_accuracy: 0.9213
# Epoch 31/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.2099 - accuracy: 0.9356 - val_loss: 0.3651 - val_accuracy: 0.9086
# Epoch 32/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.2129 - accuracy: 0.9380 - val_loss: 0.3544 - val_accuracy: 0.9225
# Epoch 33/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.2024 - accuracy: 0.9423 - val_loss: 0.4639 - val_accuracy: 0.8850
# Epoch 34/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1908 - accuracy: 0.9430 - val_loss: 0.4069 - val_accuracy: 0.9074
# Epoch 35/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1963 - accuracy: 0.9405 - val_loss: 0.3723 - val_accuracy: 0.9062
# Epoch 36/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1918 - accuracy: 0.9425 - val_loss: 0.4817 - val_accuracy: 0.8978
# Epoch 37/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1892 - accuracy: 0.9436 - val_loss: 0.3103 - val_accuracy: 0.9155
# Epoch 38/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1910 - accuracy: 0.9443 - val_loss: 0.3779 - val_accuracy: 0.8985
# Epoch 39/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1669 - accuracy: 0.9483 - val_loss: 0.4194 - val_accuracy: 0.9198
# Epoch 40/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1826 - accuracy: 0.9466 - val_loss: 0.3470 - val_accuracy: 0.9232
# Epoch 41/100
# 243/243 [==============================] - 20s 82ms/step - loss: 0.1595 - accuracy: 0.9532 - val_loss: 0.2712 - val_accuracy: 0.9286
# Epoch 42/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1378 - accuracy: 0.9580 - val_loss: 0.3134 - val_accuracy: 0.9271
# Epoch 43/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1476 - accuracy: 0.9555 - val_loss: 0.3397 - val_accuracy: 0.9043
# Epoch 44/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1803 - accuracy: 0.9461 - val_loss: 0.3330 - val_accuracy: 0.9313
# Epoch 45/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1740 - accuracy: 0.9482 - val_loss: 0.3975 - val_accuracy: 0.8939
# Epoch 46/100
# 243/243 [==============================] - 19s 77ms/step - loss: 0.1654 - accuracy: 0.9526 - val_loss: 0.2720 - val_accuracy: 0.9259
# Epoch 47/100
# 243/243 [==============================] - 19s 77ms/step - loss: 0.1353 - accuracy: 0.9607 - val_loss: 0.3713 - val_accuracy: 0.9120
# Epoch 48/100
# 243/243 [==============================] - 19s 77ms/step - loss: 0.1240 - accuracy: 0.9643 - val_loss: 0.3734 - val_accuracy: 0.9275
# Epoch 49/100
# 243/243 [==============================] - 19s 77ms/step - loss: 0.1548 - accuracy: 0.9552 - val_loss: 0.3418 - val_accuracy: 0.9155
# Epoch 50/100
# 243/243 [==============================] - 19s 77ms/step - loss: 0.1490 - accuracy: 0.9591 - val_loss: 0.3462 - val_accuracy: 0.9190
# Epoch 51/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1407 - accuracy: 0.9597 - val_loss: 0.3534 - val_accuracy: 0.9279
# Epoch 52/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1278 - accuracy: 0.9629 - val_loss: 0.3059 - val_accuracy: 0.9259
# Epoch 53/100
# 243/243 [==============================] - 20s 82ms/step - loss: 0.1381 - accuracy: 0.9615 - val_loss: 0.2548 - val_accuracy: 0.9336
# Epoch 54/100
# 243/243 [==============================] - 19s 77ms/step - loss: 0.1329 - accuracy: 0.9597 - val_loss: 0.3533 - val_accuracy: 0.9113
# Epoch 55/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1352 - accuracy: 0.9606 - val_loss: 0.3357 - val_accuracy: 0.9282
# Epoch 56/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1279 - accuracy: 0.9625 - val_loss: 0.4009 - val_accuracy: 0.9279
# Epoch 57/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1241 - accuracy: 0.9626 - val_loss: 0.3112 - val_accuracy: 0.9286
# Epoch 58/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1214 - accuracy: 0.9648 - val_loss: 0.2965 - val_accuracy: 0.9194
# Epoch 59/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1338 - accuracy: 0.9617 - val_loss: 0.3517 - val_accuracy: 0.9348
# Epoch 60/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1070 - accuracy: 0.9691 - val_loss: 0.3455 - val_accuracy: 0.9217
# Epoch 61/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1265 - accuracy: 0.9655 - val_loss: 0.3535 - val_accuracy: 0.9078
# Epoch 62/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1373 - accuracy: 0.9617 - val_loss: 0.2984 - val_accuracy: 0.9336
# Epoch 63/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1246 - accuracy: 0.9639 - val_loss: 0.2671 - val_accuracy: 0.9263
# Epoch 64/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1054 - accuracy: 0.9692 - val_loss: 0.2806 - val_accuracy: 0.9321
# Epoch 65/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1331 - accuracy: 0.9624 - val_loss: 0.3866 - val_accuracy: 0.9290
# Epoch 66/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1394 - accuracy: 0.9634 - val_loss: 0.3506 - val_accuracy: 0.9028
# Epoch 67/100
# 243/243 [==============================] - 19s 77ms/step - loss: 0.1209 - accuracy: 0.9655 - val_loss: 0.2990 - val_accuracy: 0.9352
# Epoch 68/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1457 - accuracy: 0.9593 - val_loss: 0.3363 - val_accuracy: 0.9217
# Epoch 69/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1047 - accuracy: 0.9692 - val_loss: 0.3347 - val_accuracy: 0.9271
# Epoch 70/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.0988 - accuracy: 0.9711 - val_loss: 0.3287 - val_accuracy: 0.9313
# Epoch 71/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1044 - accuracy: 0.9728 - val_loss: 0.4715 - val_accuracy: 0.9062
# Epoch 72/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1001 - accuracy: 0.9701 - val_loss: 0.3033 - val_accuracy: 0.9267
# Epoch 73/100
# 243/243 [==============================] - 19s 77ms/step - loss: 0.1281 - accuracy: 0.9643 - val_loss: 0.3671 - val_accuracy: 0.9236
# Epoch 74/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.0901 - accuracy: 0.9718 - val_loss: 0.2672 - val_accuracy: 0.9360
# Epoch 75/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.0987 - accuracy: 0.9720 - val_loss: 0.3010 - val_accuracy: 0.9267
# Epoch 76/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1151 - accuracy: 0.9677 - val_loss: 0.3815 - val_accuracy: 0.9298
# Epoch 77/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1161 - accuracy: 0.9680 - val_loss: 0.3717 - val_accuracy: 0.9136
# Epoch 78/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1103 - accuracy: 0.9678 - val_loss: 0.3614 - val_accuracy: 0.9205
# Epoch 79/100
# 243/243 [==============================] - 19s 77ms/step - loss: 0.0876 - accuracy: 0.9728 - val_loss: 0.2793 - val_accuracy: 0.9286
# Epoch 80/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1371 - accuracy: 0.9620 - val_loss: 0.3363 - val_accuracy: 0.9390
# Epoch 81/100
# 243/243 [==============================] - 19s 77ms/step - loss: 0.1163 - accuracy: 0.9687 - val_loss: 0.4278 - val_accuracy: 0.9093
# Epoch 82/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1040 - accuracy: 0.9707 - val_loss: 0.3453 - val_accuracy: 0.9363
# Epoch 83/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.0844 - accuracy: 0.9754 - val_loss: 0.4673 - val_accuracy: 0.9151
# Epoch 84/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1116 - accuracy: 0.9696 - val_loss: 0.2855 - val_accuracy: 0.9390
# Epoch 85/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.0774 - accuracy: 0.9758 - val_loss: 0.3261 - val_accuracy: 0.9333
# Epoch 86/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.0963 - accuracy: 0.9724 - val_loss: 0.3591 - val_accuracy: 0.9325
# Epoch 87/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1200 - accuracy: 0.9662 - val_loss: 0.3645 - val_accuracy: 0.9336
# Epoch 88/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.0808 - accuracy: 0.9772 - val_loss: 0.4313 - val_accuracy: 0.9271
# Epoch 89/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.0934 - accuracy: 0.9738 - val_loss: 0.3556 - val_accuracy: 0.9333
# Epoch 90/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.0841 - accuracy: 0.9750 - val_loss: 0.6713 - val_accuracy: 0.9190
# Epoch 91/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1013 - accuracy: 0.9706 - val_loss: 0.3476 - val_accuracy: 0.9267
# Epoch 92/100
# 243/243 [==============================] - 20s 82ms/step - loss: 0.1021 - accuracy: 0.9705 - val_loss: 0.2455 - val_accuracy: 0.9398
# Epoch 93/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.1137 - accuracy: 0.9679 - val_loss: 0.3489 - val_accuracy: 0.9136
# Epoch 94/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.0996 - accuracy: 0.9718 - val_loss: 0.4161 - val_accuracy: 0.9286
# Epoch 95/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.0718 - accuracy: 0.9793 - val_loss: 0.4550 - val_accuracy: 0.9209
# Epoch 96/100
# 243/243 [==============================] - 19s 77ms/step - loss: 0.0840 - accuracy: 0.9763 - val_loss: 0.3796 - val_accuracy: 0.9259
# Epoch 97/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.0844 - accuracy: 0.9742 - val_loss: 0.3653 - val_accuracy: 0.9329
# Epoch 98/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.0619 - accuracy: 0.9814 - val_loss: 0.3334 - val_accuracy: 0.9367
# Epoch 99/100
# 243/243 [==============================] - 19s 76ms/step - loss: 0.0784 - accuracy: 0.9769 - val_loss: 0.3604 - val_accuracy: 0.9306
# Epoch 100/100
# 243/243 [==============================] - 19s 77ms/step - loss: 0.0951 - accuracy: 0.9738 - val_loss: 0.5301 - val_accuracy: 0.9267

# %% [markdown]
# Essendo un modello molto pesante, salviamo i dati della cronologia del modello in un file csv, e convertiamo il miglior modello nell'estensione **.onnx**.

# %%
voxprofunda_df = convert_history_to_csv(history_voxprofunda)
voxprofunda_df.to_csv("model_histories/resnet/voxprofunda_spect.csv")

convert_model_to_onnx("bestmodels/resnet/voxprofunda_spect.keras", (124, 129, 1))

# %% [markdown]
# Analizziamo l'andamento dell'accuratezza e della perdita durante l'addestramento.

# %%
create_train_val_plot(history_voxprofunda.history, overfit=False)

# %% [markdown]
# Dal grafico notiamo che il modello non entra in overfitting, e raggiunge degli ottimi risultati fin da subito. La perdita ottenuta nella validazione è molto bassa, e l'accuratezza in fase di validazione è anch'essa la migliore mai ottenuta.

# %%
best_voxprofunda = tf.keras.models.load_model("bestmodels/resnet/voxprofunda_spect.keras")
test_loss, test_acc = best_voxprofunda.evaluate(spect_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 5s 41ms/step - loss: 0.3290 - accuracy: 0.9318
# Accuratezza: 0.932

# %%
evaluate_onnx_model("bestmodels/resnet/voxprofunda_spect.onnx", spect_test_ds)
# Out:
# Accuratezza: 0.932

# %% [markdown]
# Abbiamo ottenuto un'accuratezza del **92.3%**!
# Il modello ha impiegato 30 minuti a trainare con la GPU A100 con Ram Avanzata.

# %%
for audio, label in spect_test_ds: # prendiamo un audio a caso del test e creiamo la distribuzione
    create_distribution_plot(best_voxprofunda, audio, label)
    break

# %% [markdown]
# ## Addestramento VoxProfunda (Filter bank)
# Procediamo ad addestrare lo stesso modello sui filter bank. Non ripeteremo alcuna spiegazione essendo un passaggio ormai noto.

# %%
fb_train_ds = DatasetConverter(train_ds)
fb_train_ds = fb_train_ds.convert('filterbanks')

fb_validation_ds = DatasetConverter(validation_ds)
fb_validation_ds = fb_validation_ds.convert('filterbanks')

fb_val_ds = fb_validation_ds.take(fb_validation_ds.cardinality() // 2)
fb_test_ds = fb_validation_ds.skip(fb_validation_ds.cardinality() // 2)

# %%
del voxprofunda

voxprofunda = VoxProfunda()

for audio, label in fb_train_ds:
    voxprofunda = voxprofunda.get_model(audio.shape[1:])
    break

voxprofunda.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

voxprofunda.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input (InputLayer)          [(None, 98, 40, 1)]          0         []
#
#  normalization (Normalizati  (None, 98, 40, 1)            3         ['input[0][0]']
#  on)
#
#  conv1 (Sequential)          (None, 49, 20, 64)           3456      ['normalization[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 25, 10, 64)           0         ['conv1[0][0]']
#  g2D)
#
#  conv2d_38 (Conv2D)          (None, 25, 10, 64)           128       ['normalization[0][0]']
#
#  add_5 (Add)                 (None, 25, 10, 64)           0         ['max_pooling2d_1[0][0]',
#                                                                      'conv2d_38[0][0]']
#
#  conv2_3 (Sequential)        (None, 25, 10, 64)           222336    ['add_5[0][0]']
#
#  add_6 (Add)                 (None, 25, 10, 64)           0         ['conv2_3[0][0]',
#                                                                      'add_5[0][0]']
#
#  conv3_4 (Sequential)        (None, 25, 10, 128)          1108992   ['add_6[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 25, 10, 128)          8320      ['add_6[0][0]']
#
#  add_7 (Add)                 (None, 25, 10, 128)          0         ['conv3_4[0][0]',
#                                                                      'conv2d_53[0][0]']
#
#  conv4_6 (Sequential)        (None, 25, 10, 256)          6792192   ['add_7[0][0]']
#
#  conv2d_66 (Conv2D)          (None, 25, 10, 256)          33024     ['add_7[0][0]']
#
#  add_8 (Add)                 (None, 25, 10, 256)          0         ['conv4_6[0][0]',
#                                                                      'conv2d_66[0][0]']
#
#  conv5_3 (Sequential)        (None, 25, 10, 512)          1298534   ['add_8[0][0]']
#                                                           4
#
#  conv2d_73 (Conv2D)          (None, 25, 10, 512)          131584    ['add_8[0][0]']
#
#  add_9 (Add)                 (None, 25, 10, 512)          0         ['conv5_3[0][0]',
#                                                                      'conv2d_73[0][0]']
#
#  fc1 (Conv2D)                (None, 17, 10, 512)          2359808   ['add_9[0][0]']
#
#  pool_time (GlobalAveragePo  (None, 512)                  0         ['fc1[0][0]']
#  oling2D)
#
#  dropout_1 (Dropout)         (None, 512)                  0         ['pool_time[0][0]']
#
#  softmax (Dense)             (None, 30)                   15390     ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 23660577 (90.26 MB)
# Trainable params: 23652894 (90.23 MB)
# Non-trainable params: 7683 (30.02 KB)
# __________________________________________________________________________________________________

# %%
callback_voxprofunda = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/resnet/voxprofunda_fb.keras", save_best_only=True, monitor="val_loss")]
history_voxprofunda = voxprofunda.fit(fb_train_ds, epochs=100, validation_data=fb_val_ds, callbacks=callback_voxprofunda)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 27s 45ms/step - loss: 5.9464 - accuracy: 0.0348 - val_loss: 3.4018 - val_accuracy: 0.0285
# Epoch 2/100
# 243/243 [==============================] - 9s 36ms/step - loss: 3.3934 - accuracy: 0.0429 - val_loss: 3.3625 - val_accuracy: 0.0421
# Epoch 3/100
# 243/243 [==============================] - 9s 36ms/step - loss: 3.3082 - accuracy: 0.0669 - val_loss: 3.2811 - val_accuracy: 0.0671
# Epoch 4/100
# 243/243 [==============================] - 9s 36ms/step - loss: 3.1167 - accuracy: 0.1089 - val_loss: 3.2573 - val_accuracy: 0.0814
# Epoch 5/100
# 243/243 [==============================] - 7s 30ms/step - loss: 2.7548 - accuracy: 0.1981 - val_loss: 4.5284 - val_accuracy: 0.0721
# Epoch 6/100
# 243/243 [==============================] - 9s 36ms/step - loss: 1.9312 - accuracy: 0.4309 - val_loss: 2.6477 - val_accuracy: 0.2261
# Epoch 7/100
# 243/243 [==============================] - 9s 36ms/step - loss: 1.2467 - accuracy: 0.6332 - val_loss: 1.5987 - val_accuracy: 0.5015
# Epoch 8/100
# 243/243 [==============================] - 9s 37ms/step - loss: 0.9074 - accuracy: 0.7339 - val_loss: 1.4190 - val_accuracy: 0.5795
# Epoch 9/100
# 243/243 [==============================] - 9s 37ms/step - loss: 0.7901 - accuracy: 0.7679 - val_loss: 0.7499 - val_accuracy: 0.7778
# Epoch 10/100
# 243/243 [==============================] - 7s 31ms/step - loss: 0.6617 - accuracy: 0.8077 - val_loss: 0.7555 - val_accuracy: 0.7917
# Epoch 11/100
# 243/243 [==============================] - 8s 31ms/step - loss: 0.5845 - accuracy: 0.8276 - val_loss: 0.8710 - val_accuracy: 0.7558
# Epoch 12/100
# 243/243 [==============================] - 9s 37ms/step - loss: 0.5190 - accuracy: 0.8421 - val_loss: 0.6373 - val_accuracy: 0.8179
# Epoch 13/100
# 243/243 [==============================] - 9s 36ms/step - loss: 0.4679 - accuracy: 0.8628 - val_loss: 0.5572 - val_accuracy: 0.8480
# Epoch 14/100
# 243/243 [==============================] - 9s 36ms/step - loss: 0.4199 - accuracy: 0.8745 - val_loss: 0.4819 - val_accuracy: 0.8677
# Epoch 15/100
# 243/243 [==============================] - 9s 36ms/step - loss: 0.4120 - accuracy: 0.8751 - val_loss: 0.4728 - val_accuracy: 0.8623
# Epoch 16/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.4121 - accuracy: 0.8744 - val_loss: 1.3195 - val_accuracy: 0.6759
# Epoch 17/100
# 243/243 [==============================] - 7s 31ms/step - loss: 0.3703 - accuracy: 0.8906 - val_loss: 0.7520 - val_accuracy: 0.8194
# Epoch 18/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.3564 - accuracy: 0.8929 - val_loss: 1.0487 - val_accuracy: 0.7666
# Epoch 19/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.3319 - accuracy: 0.8982 - val_loss: 0.5091 - val_accuracy: 0.8534
# Epoch 20/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.3392 - accuracy: 0.8987 - val_loss: 0.9498 - val_accuracy: 0.7774
# Epoch 21/100
# 243/243 [==============================] - 9s 37ms/step - loss: 0.2891 - accuracy: 0.9130 - val_loss: 0.4524 - val_accuracy: 0.8719
# Epoch 22/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.3089 - accuracy: 0.9059 - val_loss: 0.5105 - val_accuracy: 0.8480
# Epoch 23/100
# 243/243 [==============================] - 9s 36ms/step - loss: 0.3204 - accuracy: 0.9013 - val_loss: 0.4345 - val_accuracy: 0.8789
# Epoch 24/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.2660 - accuracy: 0.9215 - val_loss: 0.9814 - val_accuracy: 0.7311
# Epoch 25/100
# 243/243 [==============================] - 7s 31ms/step - loss: 0.2748 - accuracy: 0.9183 - val_loss: 0.4444 - val_accuracy: 0.8804
# Epoch 26/100
# 243/243 [==============================] - 7s 29ms/step - loss: 0.2840 - accuracy: 0.9205 - val_loss: 0.4733 - val_accuracy: 0.8789
# Epoch 27/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.2620 - accuracy: 0.9233 - val_loss: 0.4880 - val_accuracy: 0.8634
# Epoch 28/100
# 243/243 [==============================] - 7s 29ms/step - loss: 0.2468 - accuracy: 0.9237 - val_loss: 0.5050 - val_accuracy: 0.8704
# Epoch 29/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.2608 - accuracy: 0.9226 - val_loss: 0.7278 - val_accuracy: 0.8025
# Epoch 30/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.2526 - accuracy: 0.9233 - val_loss: 0.5309 - val_accuracy: 0.8557
# Epoch 31/100
# 243/243 [==============================] - 9s 36ms/step - loss: 0.2315 - accuracy: 0.9303 - val_loss: 0.3410 - val_accuracy: 0.9059
# Epoch 32/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.2433 - accuracy: 0.9274 - val_loss: 0.6750 - val_accuracy: 0.8098
# Epoch 33/100
# 243/243 [==============================] - 7s 31ms/step - loss: 0.2353 - accuracy: 0.9303 - val_loss: 0.3659 - val_accuracy: 0.8966
# Epoch 34/100
# 243/243 [==============================] - 9s 36ms/step - loss: 0.2083 - accuracy: 0.9388 - val_loss: 0.3296 - val_accuracy: 0.9120
# Epoch 35/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.1937 - accuracy: 0.9425 - val_loss: 0.6756 - val_accuracy: 0.8341
# Epoch 36/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.1887 - accuracy: 0.9450 - val_loss: 0.3440 - val_accuracy: 0.9086
# Epoch 37/100
# 243/243 [==============================] - 9s 36ms/step - loss: 0.2200 - accuracy: 0.9356 - val_loss: 0.3153 - val_accuracy: 0.9132
# Epoch 38/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.2144 - accuracy: 0.9370 - val_loss: 0.5247 - val_accuracy: 0.8565
# Epoch 39/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.1863 - accuracy: 0.9450 - val_loss: 0.3705 - val_accuracy: 0.9078
# Epoch 40/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.1762 - accuracy: 0.9470 - val_loss: 0.3539 - val_accuracy: 0.9194
# Epoch 41/100
# 243/243 [==============================] - 7s 29ms/step - loss: 0.1698 - accuracy: 0.9491 - val_loss: 0.3167 - val_accuracy: 0.9198
# Epoch 42/100
# 243/243 [==============================] - 7s 29ms/step - loss: 0.1683 - accuracy: 0.9485 - val_loss: 0.3384 - val_accuracy: 0.9221
# Epoch 43/100
# 243/243 [==============================] - 7s 29ms/step - loss: 0.1603 - accuracy: 0.9532 - val_loss: 0.3278 - val_accuracy: 0.9163
# Epoch 44/100
# 243/243 [==============================] - 7s 29ms/step - loss: 0.1603 - accuracy: 0.9505 - val_loss: 0.5539 - val_accuracy: 0.9055
# Epoch 45/100
# 243/243 [==============================] - 7s 29ms/step - loss: 0.1818 - accuracy: 0.9486 - val_loss: 0.3401 - val_accuracy: 0.9070
# Epoch 46/100
# 243/243 [==============================] - 7s 29ms/step - loss: 0.1945 - accuracy: 0.9454 - val_loss: 0.4351 - val_accuracy: 0.8812
# Epoch 47/100
# 243/243 [==============================] - 7s 29ms/step - loss: 0.1567 - accuracy: 0.9530 - val_loss: 0.3219 - val_accuracy: 0.9167
# Epoch 48/100
# 243/243 [==============================] - 7s 31ms/step - loss: 0.1690 - accuracy: 0.9506 - val_loss: 0.5745 - val_accuracy: 0.8839
# Epoch 49/100
# 243/243 [==============================] - 8s 31ms/step - loss: 0.1529 - accuracy: 0.9553 - val_loss: 0.3755 - val_accuracy: 0.9120
# Epoch 50/100
# 243/243 [==============================] - 7s 31ms/step - loss: 0.1270 - accuracy: 0.9594 - val_loss: 0.3660 - val_accuracy: 0.9232
# Epoch 51/100
# 243/243 [==============================] - 8s 31ms/step - loss: 0.1309 - accuracy: 0.9622 - val_loss: 0.4145 - val_accuracy: 0.9117
# Epoch 52/100
# 243/243 [==============================] - 8s 31ms/step - loss: 0.1316 - accuracy: 0.9593 - val_loss: 0.3960 - val_accuracy: 0.9132
# Epoch 53/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.1451 - accuracy: 0.9576 - val_loss: 0.3776 - val_accuracy: 0.9178
# Epoch 54/100
# 243/243 [==============================] - 7s 31ms/step - loss: 0.1605 - accuracy: 0.9531 - val_loss: 0.3867 - val_accuracy: 0.9221
# Epoch 55/100
# 243/243 [==============================] - 8s 31ms/step - loss: 0.1459 - accuracy: 0.9585 - val_loss: 0.7000 - val_accuracy: 0.8873
# Epoch 56/100
# 243/243 [==============================] - 8s 31ms/step - loss: 0.1341 - accuracy: 0.9617 - val_loss: 0.3408 - val_accuracy: 0.9155
# Epoch 57/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.1310 - accuracy: 0.9607 - val_loss: 0.4276 - val_accuracy: 0.9248
# Epoch 58/100
# 243/243 [==============================] - 7s 31ms/step - loss: 0.1420 - accuracy: 0.9606 - val_loss: 0.3835 - val_accuracy: 0.9144
# Epoch 59/100
# 243/243 [==============================] - 7s 31ms/step - loss: 0.1575 - accuracy: 0.9576 - val_loss: 0.3798 - val_accuracy: 0.9205
# Epoch 60/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.1196 - accuracy: 0.9653 - val_loss: 0.3462 - val_accuracy: 0.9190
# Epoch 61/100
# 243/243 [==============================] - 8s 31ms/step - loss: 0.1361 - accuracy: 0.9622 - val_loss: 0.3855 - val_accuracy: 0.9039
# Epoch 62/100
# 243/243 [==============================] - 7s 31ms/step - loss: 0.0967 - accuracy: 0.9726 - val_loss: 0.3439 - val_accuracy: 0.9286
# Epoch 63/100
# 243/243 [==============================] - 9s 37ms/step - loss: 0.1344 - accuracy: 0.9635 - val_loss: 0.3128 - val_accuracy: 0.9182
# Epoch 64/100
# 243/243 [==============================] - 8s 31ms/step - loss: 0.1216 - accuracy: 0.9630 - val_loss: 0.3278 - val_accuracy: 0.9163
# Epoch 65/100
# 243/243 [==============================] - 8s 31ms/step - loss: 0.1272 - accuracy: 0.9656 - val_loss: 0.4268 - val_accuracy: 0.9171
# Epoch 66/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.1273 - accuracy: 0.9637 - val_loss: 0.4398 - val_accuracy: 0.9186
# Epoch 67/100
# 243/243 [==============================] - 8s 31ms/step - loss: 0.1398 - accuracy: 0.9606 - val_loss: 0.4220 - val_accuracy: 0.9109
# Epoch 68/100
# 243/243 [==============================] - 8s 31ms/step - loss: 0.0950 - accuracy: 0.9711 - val_loss: 0.4164 - val_accuracy: 0.9213
# Epoch 69/100
# 243/243 [==============================] - 8s 31ms/step - loss: 0.1158 - accuracy: 0.9683 - val_loss: 0.3779 - val_accuracy: 0.9209
# Epoch 70/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.1148 - accuracy: 0.9670 - val_loss: 0.4357 - val_accuracy: 0.9271
# Epoch 71/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.1382 - accuracy: 0.9621 - val_loss: 0.3534 - val_accuracy: 0.9282
# Epoch 72/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.1204 - accuracy: 0.9659 - val_loss: 0.3529 - val_accuracy: 0.9217
# Epoch 73/100
# 243/243 [==============================] - 7s 29ms/step - loss: 0.1179 - accuracy: 0.9674 - val_loss: 0.4500 - val_accuracy: 0.9294
# Epoch 74/100
# 243/243 [==============================] - 9s 36ms/step - loss: 0.0968 - accuracy: 0.9727 - val_loss: 0.2991 - val_accuracy: 0.9259
# Epoch 75/100
# 243/243 [==============================] - 7s 29ms/step - loss: 0.1112 - accuracy: 0.9683 - val_loss: 0.4428 - val_accuracy: 0.9190
# Epoch 76/100
# 243/243 [==============================] - 7s 29ms/step - loss: 0.0921 - accuracy: 0.9741 - val_loss: 0.3196 - val_accuracy: 0.9228
# Epoch 77/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.1150 - accuracy: 0.9651 - val_loss: 0.5018 - val_accuracy: 0.9174
# Epoch 78/100
# 243/243 [==============================] - 7s 29ms/step - loss: 0.0937 - accuracy: 0.9732 - val_loss: 0.3631 - val_accuracy: 0.9255
# Epoch 79/100
# 243/243 [==============================] - 7s 29ms/step - loss: 0.0777 - accuracy: 0.9768 - val_loss: 0.3647 - val_accuracy: 0.9244
# Epoch 80/100
# 243/243 [==============================] - 7s 29ms/step - loss: 0.1150 - accuracy: 0.9662 - val_loss: 0.4856 - val_accuracy: 0.8777
# Epoch 81/100
# 243/243 [==============================] - 7s 29ms/step - loss: 0.1256 - accuracy: 0.9655 - val_loss: 0.4008 - val_accuracy: 0.9194
# Epoch 82/100
# 243/243 [==============================] - 7s 29ms/step - loss: 0.1181 - accuracy: 0.9671 - val_loss: 0.4000 - val_accuracy: 0.9325
# Epoch 83/100
# 243/243 [==============================] - 7s 29ms/step - loss: 0.1003 - accuracy: 0.9718 - val_loss: 0.3995 - val_accuracy: 0.9217
# Epoch 84/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.1156 - accuracy: 0.9689 - val_loss: 0.6567 - val_accuracy: 0.9155
# Epoch 85/100
# 243/243 [==============================] - 7s 29ms/step - loss: 0.0918 - accuracy: 0.9753 - val_loss: 0.3967 - val_accuracy: 0.9286
# Epoch 86/100
# 243/243 [==============================] - 7s 29ms/step - loss: 0.0885 - accuracy: 0.9747 - val_loss: 0.5321 - val_accuracy: 0.8931
# Epoch 87/100
# 243/243 [==============================] - 7s 29ms/step - loss: 0.1157 - accuracy: 0.9691 - val_loss: 0.3934 - val_accuracy: 0.9201
# Epoch 88/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.0972 - accuracy: 0.9736 - val_loss: 0.3772 - val_accuracy: 0.9371
# Epoch 89/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.0999 - accuracy: 0.9722 - val_loss: 0.3681 - val_accuracy: 0.9290
# Epoch 90/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.0987 - accuracy: 0.9747 - val_loss: 0.4715 - val_accuracy: 0.9248
# Epoch 91/100
# 243/243 [==============================] - 7s 31ms/step - loss: 0.0775 - accuracy: 0.9777 - val_loss: 0.4383 - val_accuracy: 0.9159
# Epoch 92/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.0838 - accuracy: 0.9764 - val_loss: 0.4407 - val_accuracy: 0.9217
# Epoch 93/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.0859 - accuracy: 0.9763 - val_loss: 0.5687 - val_accuracy: 0.9144
# Epoch 94/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.0904 - accuracy: 0.9755 - val_loss: 0.4375 - val_accuracy: 0.9248
# Epoch 95/100
# 243/243 [==============================] - 8s 31ms/step - loss: 0.0913 - accuracy: 0.9740 - val_loss: 0.3458 - val_accuracy: 0.9317
# Epoch 96/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.0846 - accuracy: 0.9769 - val_loss: 0.3701 - val_accuracy: 0.9232
# Epoch 97/100
# 243/243 [==============================] - 7s 31ms/step - loss: 0.0889 - accuracy: 0.9762 - val_loss: 0.3829 - val_accuracy: 0.9317
# Epoch 98/100
# 243/243 [==============================] - 7s 31ms/step - loss: 0.1015 - accuracy: 0.9718 - val_loss: 0.4081 - val_accuracy: 0.9244
# Epoch 99/100
# 243/243 [==============================] - 8s 32ms/step - loss: 0.0793 - accuracy: 0.9785 - val_loss: 0.3415 - val_accuracy: 0.9340
# Epoch 100/100
# 243/243 [==============================] - 7s 30ms/step - loss: 0.0854 - accuracy: 0.9767 - val_loss: 0.4726 - val_accuracy: 0.9259

# %%
voxprofunda_df = convert_history_to_csv(history_voxprofunda)
voxprofunda_df.to_csv("model_histories/resnet/voxprofunda_fb.csv")

convert_model_to_onnx("bestmodels/resnet/voxprofunda_fb.keras", (98, 40, 1))

# %%
create_train_val_plot(history_voxprofunda.history, overfit=False)

# %% [markdown]
# Dal grafico notiamo che il modello non entra in overfitting, e raggiunge degli ottimi risultati fin da subito. La perdita ottenuta nella validazione è molto bassa, e l'accuratezza in fase di validazione è anch'essa la migliore mai ottenuta.

# %%
best_voxprofunda = tf.keras.models.load_model("bestmodels/resnet/voxprofunda_fb.keras")
test_loss, test_acc = best_voxprofunda.evaluate(fb_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 2s 16ms/step - loss: 0.3503 - accuracy: 0.9171
# Accuratezza: 0.917

# %%
evaluate_onnx_model("bestmodels/resnet/voxprofunda_fb.onnx", fb_test_ds)
# Out:
# Accuratezza: 0.917

# %% [markdown]
# Abbiamo ottenuto un'accuratezza del **91.7%**! Leggermente più bassa rispetto alla precedente.
#
# Il modello ha impiegato 13 minuti a trainare con la GPU A100 con Ram Avanzata.

# %%
for audio, label in fb_test_ds: # prendiamo un audio a caso del test e creiamo la distribuzione
    create_distribution_plot(best_voxprofunda, audio, label)
    break

# %% [markdown]
# ## Addestramento VoxProfunda (MFCC)
# Infine ripetiamo il procedimento per gli MFCC

# %%
mfcc_train_ds = DatasetConverter(train_ds)
mfcc_train_ds = mfcc_train_ds.convert('mfcc')

mfcc_validation_ds = DatasetConverter(validation_ds)
mfcc_validation_ds = mfcc_validation_ds.convert('mfcc')

mfcc_val_ds = mfcc_validation_ds.take(mfcc_validation_ds.cardinality() // 2)
mfcc_test_ds = mfcc_validation_ds.skip(mfcc_validation_ds.cardinality() // 2)

# %%
del voxprofunda

voxprofunda = VoxProfunda()

for audio, label in mfcc_train_ds:
    voxprofunda = voxprofunda.get_model(audio.shape[1:])
    break

voxprofunda.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

voxprofunda.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input (InputLayer)          [(None, 98, 12, 1)]          0         []
#
#  normalization (Normalizati  (None, 98, 12, 1)            3         ['input[0][0]']
#  on)
#
#  conv1 (Sequential)          (None, 49, 6, 64)            3456      ['normalization[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 25, 3, 64)            0         ['conv1[0][0]']
#  g2D)
#
#  conv2d_75 (Conv2D)          (None, 25, 3, 64)            128       ['normalization[0][0]']
#
#  add_10 (Add)                (None, 25, 3, 64)            0         ['max_pooling2d_2[0][0]',
#                                                                      'conv2d_75[0][0]']
#
#  conv2_3 (Sequential)        (None, 25, 3, 64)            222336    ['add_10[0][0]']
#
#  add_11 (Add)                (None, 25, 3, 64)            0         ['conv2_3[0][0]',
#                                                                      'add_10[0][0]']
#
#  conv3_4 (Sequential)        (None, 25, 3, 128)           1108992   ['add_11[0][0]']
#
#  conv2d_90 (Conv2D)          (None, 25, 3, 128)           8320      ['add_11[0][0]']
#
#  add_12 (Add)                (None, 25, 3, 128)           0         ['conv3_4[0][0]',
#                                                                      'conv2d_90[0][0]']
#
#  conv4_6 (Sequential)        (None, 25, 3, 256)           6792192   ['add_12[0][0]']
#
#  conv2d_103 (Conv2D)         (None, 25, 3, 256)           33024     ['add_12[0][0]']
#
#  add_13 (Add)                (None, 25, 3, 256)           0         ['conv4_6[0][0]',
#                                                                      'conv2d_103[0][0]']
#
#  conv5_3 (Sequential)        (None, 25, 3, 512)           1298534   ['add_13[0][0]']
#                                                           4
#
#  conv2d_110 (Conv2D)         (None, 25, 3, 512)           131584    ['add_13[0][0]']
#
#  add_14 (Add)                (None, 25, 3, 512)           0         ['conv5_3[0][0]',
#                                                                      'conv2d_110[0][0]']
#
#  fc1 (Conv2D)                (None, 17, 3, 512)           2359808   ['add_14[0][0]']
#
#  pool_time (GlobalAveragePo  (None, 512)                  0         ['fc1[0][0]']
#  oling2D)
#
#  dropout_1 (Dropout)         (None, 512)                  0         ['pool_time[0][0]']
#
#  softmax (Dense)             (None, 30)                   15390     ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 23660577 (90.26 MB)
# Trainable params: 23652894 (90.23 MB)
# Non-trainable params: 7683 (30.02 KB)
# __________________________________________________________________________________________________

# %%
callback_voxprofunda = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/resnet/voxprofunda_mfcc.keras", save_best_only=True, monitor="val_loss")]
history_voxprofunda = voxprofunda.fit(mfcc_train_ds, epochs=100, validation_data=mfcc_val_ds, callbacks=callback_voxprofunda)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 24s 37ms/step - loss: 4.3268 - accuracy: 0.1115 - val_loss: 4.7682 - val_accuracy: 0.1636
# Epoch 2/100
# 243/243 [==============================] - 6s 25ms/step - loss: 2.2094 - accuracy: 0.3610 - val_loss: 7.2337 - val_accuracy: 0.2022
# Epoch 3/100
# 243/243 [==============================] - 6s 25ms/step - loss: 1.4843 - accuracy: 0.5644 - val_loss: 4.9320 - val_accuracy: 0.3600
# Epoch 4/100
# 243/243 [==============================] - 6s 26ms/step - loss: 1.1209 - accuracy: 0.6764 - val_loss: 7.7811 - val_accuracy: 0.3002
# Epoch 5/100
# 243/243 [==============================] - 8s 31ms/step - loss: 0.9716 - accuracy: 0.7159 - val_loss: 1.8096 - val_accuracy: 0.6246
# Epoch 6/100
# 243/243 [==============================] - 8s 32ms/step - loss: 0.8546 - accuracy: 0.7491 - val_loss: 1.2360 - val_accuracy: 0.6809
# Epoch 7/100
# 243/243 [==============================] - 6s 26ms/step - loss: 0.8407 - accuracy: 0.7567 - val_loss: 1.6921 - val_accuracy: 0.6443
# Epoch 8/100
# 243/243 [==============================] - 8s 31ms/step - loss: 0.7831 - accuracy: 0.7764 - val_loss: 0.7322 - val_accuracy: 0.7955
# Epoch 9/100
# 243/243 [==============================] - 6s 26ms/step - loss: 0.6240 - accuracy: 0.8155 - val_loss: 0.8447 - val_accuracy: 0.7874
# Epoch 10/100
# 243/243 [==============================] - 6s 24ms/step - loss: 0.6097 - accuracy: 0.8201 - val_loss: 0.9682 - val_accuracy: 0.7604
# Epoch 11/100
# 243/243 [==============================] - 6s 25ms/step - loss: 0.6044 - accuracy: 0.8219 - val_loss: 0.7588 - val_accuracy: 0.8044
# Epoch 12/100
# 243/243 [==============================] - 6s 24ms/step - loss: 0.5408 - accuracy: 0.8393 - val_loss: 0.8500 - val_accuracy: 0.7762
# Epoch 13/100
# 243/243 [==============================] - 8s 32ms/step - loss: 0.5440 - accuracy: 0.8412 - val_loss: 0.7166 - val_accuracy: 0.8252
# Epoch 14/100
# 243/243 [==============================] - 8s 31ms/step - loss: 0.5303 - accuracy: 0.8418 - val_loss: 0.6111 - val_accuracy: 0.8260
# Epoch 15/100
# 243/243 [==============================] - 6s 24ms/step - loss: 0.4829 - accuracy: 0.8615 - val_loss: 1.1169 - val_accuracy: 0.8029
# Epoch 16/100
# 243/243 [==============================] - 8s 32ms/step - loss: 0.4976 - accuracy: 0.8573 - val_loss: 0.5669 - val_accuracy: 0.8403
# Epoch 17/100
# 243/243 [==============================] - 6s 25ms/step - loss: 0.5082 - accuracy: 0.8564 - val_loss: 0.6951 - val_accuracy: 0.8318
# Epoch 18/100
# 243/243 [==============================] - 6s 25ms/step - loss: 0.4782 - accuracy: 0.8631 - val_loss: 0.6378 - val_accuracy: 0.8438
# Epoch 19/100
# 243/243 [==============================] - 6s 24ms/step - loss: 0.4334 - accuracy: 0.8714 - val_loss: 0.6457 - val_accuracy: 0.8546
# Epoch 20/100
# 243/243 [==============================] - 8s 32ms/step - loss: 0.4266 - accuracy: 0.8750 - val_loss: 0.5581 - val_accuracy: 0.8519
# Epoch 21/100
# 243/243 [==============================] - 6s 25ms/step - loss: 0.4153 - accuracy: 0.8809 - val_loss: 0.6260 - val_accuracy: 0.8376
# Epoch 22/100
# 243/243 [==============================] - 8s 34ms/step - loss: 0.4054 - accuracy: 0.8865 - val_loss: 0.5245 - val_accuracy: 0.8580
# Epoch 23/100
# 243/243 [==============================] - 6s 25ms/step - loss: 0.4103 - accuracy: 0.8798 - val_loss: 0.6518 - val_accuracy: 0.8407
# Epoch 24/100
# 243/243 [==============================] - 6s 25ms/step - loss: 0.4028 - accuracy: 0.8844 - val_loss: 0.9361 - val_accuracy: 0.8063
# Epoch 25/100
# 243/243 [==============================] - 6s 26ms/step - loss: 0.4113 - accuracy: 0.8821 - val_loss: 0.5248 - val_accuracy: 0.8596
# Epoch 26/100
# 243/243 [==============================] - 8s 32ms/step - loss: 0.3727 - accuracy: 0.8921 - val_loss: 0.4834 - val_accuracy: 0.8700
# Epoch 27/100
# 243/243 [==============================] - 6s 26ms/step - loss: 0.4784 - accuracy: 0.8677 - val_loss: 0.7915 - val_accuracy: 0.8657
# Epoch 28/100
# 243/243 [==============================] - 6s 25ms/step - loss: 0.4130 - accuracy: 0.8818 - val_loss: 0.5913 - val_accuracy: 0.8522
# Epoch 29/100
# 243/243 [==============================] - 8s 32ms/step - loss: 0.3375 - accuracy: 0.9004 - val_loss: 0.4403 - val_accuracy: 0.8908
# Epoch 30/100
# 243/243 [==============================] - 6s 24ms/step - loss: 0.3521 - accuracy: 0.9000 - val_loss: 0.5455 - val_accuracy: 0.8673
# Epoch 31/100
# 243/243 [==============================] - 6s 25ms/step - loss: 0.3753 - accuracy: 0.8943 - val_loss: 0.5503 - val_accuracy: 0.8522
# Epoch 32/100
# 243/243 [==============================] - 6s 25ms/step - loss: 0.3035 - accuracy: 0.9133 - val_loss: 0.5072 - val_accuracy: 0.8792
# Epoch 33/100
# 243/243 [==============================] - 6s 25ms/step - loss: 0.2501 - accuracy: 0.9222 - val_loss: 0.6469 - val_accuracy: 0.8711
# Epoch 34/100
# 243/243 [==============================] - 6s 25ms/step - loss: 0.3290 - accuracy: 0.9084 - val_loss: 0.6224 - val_accuracy: 0.8812
# Epoch 35/100
# 243/243 [==============================] - 6s 25ms/step - loss: 0.3746 - accuracy: 0.8981 - val_loss: 0.5220 - val_accuracy: 0.8696
# Epoch 36/100
# 243/243 [==============================] - 6s 24ms/step - loss: 0.2845 - accuracy: 0.9166 - val_loss: 0.5818 - val_accuracy: 0.8750
# Epoch 37/100
# 243/243 [==============================] - 6s 25ms/step - loss: 0.2711 - accuracy: 0.9233 - val_loss: 0.5863 - val_accuracy: 0.8835
# Epoch 38/100
# 243/243 [==============================] - 6s 24ms/step - loss: 0.3069 - accuracy: 0.9126 - val_loss: 0.6264 - val_accuracy: 0.8646
# Epoch 39/100
# 243/243 [==============================] - 6s 25ms/step - loss: 0.2959 - accuracy: 0.9179 - val_loss: 0.5467 - val_accuracy: 0.8792
# Epoch 40/100
# 243/243 [==============================] - 6s 24ms/step - loss: 0.2977 - accuracy: 0.9148 - val_loss: 0.7354 - val_accuracy: 0.8611
# Epoch 41/100
# 243/243 [==============================] - 8s 32ms/step - loss: 0.2782 - accuracy: 0.9235 - val_loss: 0.4260 - val_accuracy: 0.8931
# Epoch 42/100
# 243/243 [==============================] - 6s 25ms/step - loss: 0.2656 - accuracy: 0.9273 - val_loss: 0.5690 - val_accuracy: 0.8819
# Epoch 43/100
# 243/243 [==============================] - 6s 26ms/step - loss: 0.2702 - accuracy: 0.9204 - val_loss: 0.8192 - val_accuracy: 0.8492
# Epoch 44/100
# 243/243 [==============================] - 6s 25ms/step - loss: 0.2619 - accuracy: 0.9259 - val_loss: 0.5101 - val_accuracy: 0.8777
# Epoch 45/100
# 243/243 [==============================] - 6s 25ms/step - loss: 0.2651 - accuracy: 0.9276 - val_loss: 0.5110 - val_accuracy: 0.8719
# Epoch 46/100
# 243/243 [==============================] - 6s 24ms/step - loss: 0.2567 - accuracy: 0.9287 - val_loss: 0.4725 - val_accuracy: 0.8962
# Epoch 47/100
# 243/243 [==============================] - 6s 25ms/step - loss: 0.2355 - accuracy: 0.9335 - val_loss: 0.4792 - val_accuracy: 0.8819
# Epoch 48/100
# 243/243 [==============================] - 6s 24ms/step - loss: 0.2307 - accuracy: 0.9358 - val_loss: 0.6065 - val_accuracy: 0.8731
# Epoch 49/100
# 243/243 [==============================] - 6s 25ms/step - loss: 0.2276 - accuracy: 0.9339 - val_loss: 0.6137 - val_accuracy: 0.8738
# Epoch 50/100
# 243/243 [==============================] - 6s 25ms/step - loss: 0.2296 - accuracy: 0.9351 - val_loss: 0.5966 - val_accuracy: 0.8877
# Epoch 51/100
# 243/243 [==============================] - 6s 27ms/step - loss: 0.2208 - accuracy: 0.9369 - val_loss: 0.4591 - val_accuracy: 0.8870
# Epoch 52/100
# 243/243 [==============================] - 7s 27ms/step - loss: 0.2425 - accuracy: 0.9308 - val_loss: 0.5172 - val_accuracy: 0.8819
# Epoch 53/100
# 243/243 [==============================] - 7s 27ms/step - loss: 0.2407 - accuracy: 0.9331 - val_loss: 0.5447 - val_accuracy: 0.8777
# Epoch 54/100
# 243/243 [==============================] - 7s 27ms/step - loss: 0.2302 - accuracy: 0.9380 - val_loss: 0.7166 - val_accuracy: 0.8893
# Epoch 55/100
# 243/243 [==============================] - 6s 26ms/step - loss: 0.2029 - accuracy: 0.9438 - val_loss: 0.6873 - val_accuracy: 0.8777
# Epoch 56/100
# 243/243 [==============================] - 6s 27ms/step - loss: 0.2422 - accuracy: 0.9331 - val_loss: 0.4622 - val_accuracy: 0.8889
# Epoch 57/100
# 243/243 [==============================] - 6s 26ms/step - loss: 0.2167 - accuracy: 0.9403 - val_loss: 0.5582 - val_accuracy: 0.8831
# Epoch 58/100
# 243/243 [==============================] - 7s 27ms/step - loss: 0.1848 - accuracy: 0.9479 - val_loss: 0.5240 - val_accuracy: 0.8800
# Epoch 59/100
# 243/243 [==============================] - 7s 27ms/step - loss: 0.1885 - accuracy: 0.9490 - val_loss: 0.7655 - val_accuracy: 0.8808
# Epoch 60/100
# 243/243 [==============================] - 7s 27ms/step - loss: 0.1945 - accuracy: 0.9457 - val_loss: 0.5044 - val_accuracy: 0.8746
# Epoch 61/100
# 243/243 [==============================] - 6s 26ms/step - loss: 0.2111 - accuracy: 0.9387 - val_loss: 0.6115 - val_accuracy: 0.8835
# Epoch 62/100
# 243/243 [==============================] - 7s 27ms/step - loss: 0.2366 - accuracy: 0.9381 - val_loss: 0.6924 - val_accuracy: 0.8904
# Epoch 63/100
# 243/243 [==============================] - 7s 27ms/step - loss: 0.2151 - accuracy: 0.9436 - val_loss: 0.5606 - val_accuracy: 0.8927
# Epoch 64/100
# 243/243 [==============================] - 6s 27ms/step - loss: 0.2009 - accuracy: 0.9460 - val_loss: 0.7725 - val_accuracy: 0.8920
# Epoch 65/100
# 243/243 [==============================] - 6s 26ms/step - loss: 0.2381 - accuracy: 0.9374 - val_loss: 0.5349 - val_accuracy: 0.8854
# Epoch 66/100
# 243/243 [==============================] - 6s 27ms/step - loss: 0.2041 - accuracy: 0.9454 - val_loss: 0.5373 - val_accuracy: 0.8785
# Epoch 67/100
# 243/243 [==============================] - 6s 27ms/step - loss: 0.1836 - accuracy: 0.9497 - val_loss: 0.8802 - val_accuracy: 0.8630
# Epoch 68/100
# 243/243 [==============================] - 6s 27ms/step - loss: 0.2120 - accuracy: 0.9459 - val_loss: 0.6581 - val_accuracy: 0.8862
# Epoch 69/100
# 243/243 [==============================] - 7s 28ms/step - loss: 0.2017 - accuracy: 0.9476 - val_loss: 0.6971 - val_accuracy: 0.8924
# Epoch 70/100
# 243/243 [==============================] - 6s 26ms/step - loss: 0.1679 - accuracy: 0.9543 - val_loss: 0.5647 - val_accuracy: 0.9032
# Epoch 71/100
# 243/243 [==============================] - 6s 25ms/step - loss: 0.2265 - accuracy: 0.9430 - val_loss: 0.6321 - val_accuracy: 0.8889
# Epoch 72/100
# 243/243 [==============================] - 6s 25ms/step - loss: 0.1985 - accuracy: 0.9496 - val_loss: 0.5182 - val_accuracy: 0.8900
# Epoch 73/100
# 243/243 [==============================] - 6s 26ms/step - loss: 0.2075 - accuracy: 0.9464 - val_loss: 0.6000 - val_accuracy: 0.8681
# Epoch 74/100
# 243/243 [==============================] - 6s 25ms/step - loss: 0.2073 - accuracy: 0.9441 - val_loss: 0.5726 - val_accuracy: 0.8835
# Epoch 75/100
# 243/243 [==============================] - 6s 26ms/step - loss: 0.1665 - accuracy: 0.9528 - val_loss: 0.7509 - val_accuracy: 0.8897
# Epoch 76/100
# 243/243 [==============================] - 6s 26ms/step - loss: 0.1890 - accuracy: 0.9499 - val_loss: 0.6724 - val_accuracy: 0.8951
# Epoch 77/100
# 243/243 [==============================] - 6s 26ms/step - loss: 0.1487 - accuracy: 0.9582 - val_loss: 0.6429 - val_accuracy: 0.8885
# Epoch 78/100
# 243/243 [==============================] - 6s 25ms/step - loss: 0.1733 - accuracy: 0.9544 - val_loss: 0.5656 - val_accuracy: 0.8993
# Epoch 79/100
# 243/243 [==============================] - 6s 26ms/step - loss: 0.1824 - accuracy: 0.9509 - val_loss: 0.8275 - val_accuracy: 0.8530
# Epoch 80/100
# 243/243 [==============================] - 6s 26ms/step - loss: 0.2041 - accuracy: 0.9500 - val_loss: 0.5788 - val_accuracy: 0.8738
# Epoch 81/100
# 243/243 [==============================] - 6s 26ms/step - loss: 0.1852 - accuracy: 0.9486 - val_loss: 0.8067 - val_accuracy: 0.8669
# Epoch 82/100
# 243/243 [==============================] - 6s 26ms/step - loss: 0.1615 - accuracy: 0.9549 - val_loss: 0.6399 - val_accuracy: 0.8742
# Epoch 83/100
# 243/243 [==============================] - 7s 28ms/step - loss: 0.2037 - accuracy: 0.9468 - val_loss: 0.5222 - val_accuracy: 0.8981
# Epoch 84/100
# 243/243 [==============================] - 7s 27ms/step - loss: 0.1675 - accuracy: 0.9570 - val_loss: 0.8506 - val_accuracy: 0.8904
# Epoch 85/100
# 243/243 [==============================] - 7s 28ms/step - loss: 0.1758 - accuracy: 0.9576 - val_loss: 0.7215 - val_accuracy: 0.8858
# Epoch 86/100
# 243/243 [==============================] - 7s 27ms/step - loss: 0.2242 - accuracy: 0.9436 - val_loss: 1.1289 - val_accuracy: 0.8900
# Epoch 87/100
# 243/243 [==============================] - 7s 27ms/step - loss: 0.1875 - accuracy: 0.9508 - val_loss: 0.7094 - val_accuracy: 0.8908
# Epoch 88/100
# 243/243 [==============================] - 7s 27ms/step - loss: 0.1577 - accuracy: 0.9558 - val_loss: 0.6298 - val_accuracy: 0.8781
# Epoch 89/100
# 243/243 [==============================] - 6s 26ms/step - loss: 0.1880 - accuracy: 0.9518 - val_loss: 0.7993 - val_accuracy: 0.8816
# Epoch 90/100
# 243/243 [==============================] - 7s 27ms/step - loss: 0.1974 - accuracy: 0.9512 - val_loss: 0.6179 - val_accuracy: 0.8873
# Epoch 91/100
# 243/243 [==============================] - 7s 27ms/step - loss: 0.1249 - accuracy: 0.9649 - val_loss: 0.7657 - val_accuracy: 0.9016
# Epoch 92/100
# 243/243 [==============================] - 7s 29ms/step - loss: 0.1631 - accuracy: 0.9566 - val_loss: 0.7455 - val_accuracy: 0.9090
# Epoch 93/100
# 243/243 [==============================] - 7s 27ms/step - loss: 0.1483 - accuracy: 0.9615 - val_loss: 0.6451 - val_accuracy: 0.8881
# Epoch 94/100
# 243/243 [==============================] - 7s 28ms/step - loss: 0.1898 - accuracy: 0.9536 - val_loss: 0.7126 - val_accuracy: 0.8862
# Epoch 95/100
# 243/243 [==============================] - 7s 27ms/step - loss: 0.1831 - accuracy: 0.9545 - val_loss: 0.7036 - val_accuracy: 0.8777
# Epoch 96/100
# 243/243 [==============================] - 7s 27ms/step - loss: 0.1415 - accuracy: 0.9629 - val_loss: 0.6701 - val_accuracy: 0.8877
# Epoch 97/100
# 243/243 [==============================] - 7s 27ms/step - loss: 0.2129 - accuracy: 0.9488 - val_loss: 0.7380 - val_accuracy: 0.9001
# Epoch 98/100
# 243/243 [==============================] - 6s 27ms/step - loss: 0.1497 - accuracy: 0.9584 - val_loss: 0.6583 - val_accuracy: 0.8877
# Epoch 99/100
# 243/243 [==============================] - 6s 26ms/step - loss: 0.1468 - accuracy: 0.9603 - val_loss: 0.6710 - val_accuracy: 0.8692
# Epoch 100/100
# 243/243 [==============================] - 7s 27ms/step - loss: 0.1652 - accuracy: 0.9590 - val_loss: 0.5350 - val_accuracy: 0.8935

# %%
voxprofunda_df = convert_history_to_csv(history_voxprofunda)
voxprofunda_df.to_csv("model_histories/resnet/voxprofunda_mfcc.csv")

convert_model_to_onnx("bestmodels/resnet/voxprofunda_mfcc.keras", (98, 12, 1))

# %%
create_train_val_plot(history_voxprofunda.history, overfit=False)

# %% [markdown]
# Dal grafico notiamo che il modello non entra in overfitting, e raggiunge degli ottimi risultati fin da subito. La perdita ottenuta nella validazione è molto bassa, e l'accuratezza in fase di validazione è anch'essa la migliore mai ottenuta.

# %%
best_voxprofunda = tf.keras.models.load_model("bestmodels/resnet/voxprofunda_mfcc.keras")
test_loss, test_acc = best_voxprofunda.evaluate(mfcc_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 2s 10ms/step - loss: 0.4010 - accuracy: 0.8822
# Accuratezza: 0.882

# %%
evaluate_onnx_model("bestmodels/resnet/voxprofunda_mfcc.onnx", mfcc_test_ds)
# Out:
# Accuratezza: 0.882

# %% [markdown]
# Abbiamo ottenuto un'accuratezza del **88.2%**! Come notato per gli altri modelli convolutivi, questo tipo di dati non fanno performare bene i modelli quanto gli altri e lo stesso vale per la nostra voxProfunda.
#
# Il modello ha impiegato 13 minuti a trainare con la GPU A100 con Ram Avanzata.

# %%
for audio, label in mfcc_test_ds: # prendiamo un audio a caso del test e creiamo la distribuzione
    create_distribution_plot(best_voxprofunda, audio, label)
    break
