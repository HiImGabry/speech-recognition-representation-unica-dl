# %% [markdown]
# # Modello convolutivo di base
# Lo scopo di questo notebook è creare un **modello convolutivo di base** con un'architettura semplice. In seguito, sarà interessante confrontare i risultati di questo primo modello con i risultati ottenuti da modelli più complessi, o addestrati su tipi di dati differenti.

# %% [markdown]
# Come al solito, si procede con l'importazione delle librerie utilizzate e la creazione dei set di allenamento e validazione.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd
import numpy as np
import os
import time
# per il modello con estensione .onnx
import onnxruntime as rt
import tf2onnx
import onnx

# %%
train_ds, validation_ds = tf.keras.utils.audio_dataset_from_directory(
    directory='../reduced_dataset/dataset/audio',
    validation_split=0.4, # stiamo mettendo da parte il 40% del dataset, che sarà suddiviso in validation set e test set
    shuffle=True,
    subset='both', # necessario se stiamo utilizzando validation_split (se no darebbe errore)
    seed=0 # necessario se stiamo utilizzando sia shuffle che validation_split (se no darebbe errore)
)

label_names = train_ds.class_names
# Out:
# Found 12933 files belonging to 30 classes.
# Using 7760 files for training.
# Using 5173 files for validation.

# %% [markdown]
# ## Funzioni per processamento dei dati

# %% [markdown]
# La prima funzione che ci tornerà utile è `squeeze(audio, labels)`, della quale abbiamo già visto l'implementazione e parlato del suo utilizzo nel notebook dedicato agli spettrogrammi.

# %%
def squeeze(audio, labels):
    audio = tf.squeeze(audio, axis=-1)
    return audio, labels

# fonte: funzione presa dal seguente link: https://www.geeksforgeeks.org/audio-recognition-in-tensorflow/

# %%
train_ds = train_ds.map(squeeze, tf.data.AUTOTUNE)
validation_ds = validation_ds.map(squeeze, tf.data.AUTOTUNE)

audio, label = next(iter(train_ds))
print(audio.shape)
print(label.shape)
# Out:
# (32, 16000)
# (32,)

# %% [markdown]
# Una volta eseguito questa semplificazione, a partire dai tensori degli audio, creeremo gli spettrogrammi che sarannò presi come input dal modello convolutivo.

# %% [markdown]
# ## Conversione e suddivisione dataset
# Per la conversione del dataset utilizziamo due funzioni che abbiamo già definito nel notebook dove trattiamo gli spettrogrammi.

# %%
def get_spectrogram(waveform):
    spectrogram = tf.signal.stft(waveform, frame_length=255, frame_step=128)
    spectrogram = tf.abs(spectrogram)

    return spectrogram[..., tf.newaxis]

# fonte: tutorial riconoscimento audio semplice di tensorflow: https://www.tensorflow.org/tutorials/audio/simple_audio?hl=it

# %%
def get_spectrogram_dataset(dataset):
    dataset = dataset.map(lambda x, y: (get_spectrogram(x), y), num_parallel_calls=tf.data.AUTOTUNE)

    return dataset

# %% [markdown]
# Definite le due funzioni possiamo procedere a ottenere il nostro **training set**, **validation set**, e **test set** di spettrogrammi. La suddivisione di dati ricordo essere rispettivamente 60%, 20%, 20%.

# %%
train_ds = get_spectrogram_dataset(train_ds)
validation_ds = get_spectrogram_dataset(validation_ds)

val_ds = validation_ds.take(validation_ds.cardinality() // 2) # ho cambiato nome del validation_ds in modo tale da non creare problemi con l'istruzione seguente
test_ds = validation_ds.skip(validation_ds.cardinality() // 2)

# %%
print("Numero di audio training set:", len(train_ds) * 32)
print("Numero di audio validation set:", len(val_ds) * 32)
print("Numero di audio test set:", len(test_ds) * 32)
# Out:
# Numero di audio training set: 7776
# Numero di audio validation set: 2592
# Numero di audio test set: 2592

# %%
for audio, label in train_ds:
    print("Shape (forma) spettrogrammi:", audio.shape)

    spectrogram = np.squeeze(audio[0], axis=-1)
    spectrogram = np.log(spectrogram.T + np.finfo(float).eps)

    plt.imshow(spectrogram.T)
    plt.colorbar(format='%+2.0f dB') # barra laterale dei dB

    plt.title(f"Classe: {label_names[label[0].numpy()]}")
    break
# Out:
# Shape (forma) spettrogrammi: (32, 124, 129, 1)

# %% [markdown]
# La grandezza degli spettrogrammi, quindi delle immagini ottenute, è di **124x129**.

# %% [markdown]
# ## Creazione modello di base

# %% [markdown]
# Come modello implementiamo una rete neurale convolutiva. Questo modello ha un'architettura semplice e servirà da benchmark per i modelli futuri.
#
# La rete prende in ingresso tensori di forma **altezza x larghezza x canali**, rispettivamente di **124, 129, 1**. Per farla lavorare meglio normalizziamo i dati con la funzione `tf.keras.layers.Normalization()`. Questo livello sposta e ridimensiona gli input in una distribuzione centrata su 0 e con deviazione standard 1.

# %% [markdown]
# L'architettura del modello è suddivisa in **due blocchi** principali: un blocco per l'apprendimento delle caratteristiche e un blocco per la classificazione.
#
# Il **blocco di apprendimento delle caratteristiche** ha un'architettura formata da una serie di livelli convolutivi alternati a livelli di max pooling. Per ciascun livello convolutivo viene anche applicata la funzione di attivazione **ReLu** per applicare non linearità. Il blocco termina con un livello convolutivo di **256 filtri**, che corrispondono alla stessa quantità di filtri applicati dal livello convolutivo precedente.
#
# Terminato il blocco di apprendimento delle caratteristiche, è presente il **blocco di classificazione**, formato da un **livello di Flatten**, necessario per trasformare i dati in un vettore unidimensionali, e un **livello Dense**, necessario per la predizione della classe di appartenenza del dato. Quest'ultimo livello Dense ha **30 unità**, che corrispondono alle 30 classi del nostro task di classificazione multiclasse. La funzione di attivazione applicata dal livello Dense è la **softmax**, ideale per i task di classificazione multiclasse.
#
# La funzione **softmax**, a differenza della funzione **sigmoid** ci fornisce una distribuzione di probabilità sulle classi possibili (questa distribuzione saremo in grado di visualizzarla durante la valutazione del modello).

# %%
def get_basic_model():
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(124, 129, 1), name="inputs")
    x = tf.keras.layers.Normalization(name="normalizzazione")(inputs)

    # Blocco di apprendimento delle caratteristiche
    conv2D_1 = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same", name="conv2D_1")(x)
    MaxPooling2D_1 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_1")(conv2D_1)
    conv2D_2 = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same", name="conv2D_2")(MaxPooling2D_1)
    MaxPooling2D_2 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_2")(conv2D_2)
    conv2D_3 = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same", name="conv2D_3")(MaxPooling2D_2)
    MaxPooling2D_3 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_3")(conv2D_3)
    conv2D_4 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_4")(MaxPooling2D_3)
    MaxPooling2D_4 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_4")(conv2D_4)
    conv2D_5 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_5")(MaxPooling2D_4)

    # Blocco di classificazione
    Flatten = tf.keras.layers.Flatten(name="Flatten")(conv2D_5)
    outputs = tf.keras.layers.Dense(30, activation="softmax", name="dense_output")(Flatten)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# Nella prossima cella di codice dichiariamo l'**ottimizzatore** da utilizzare (rmsprop), le **metriche** di cui tenere traccia (accuratezza), e la funzione di perdita da utilizzare per il calcolo del gradiente. Nel nostro caso la **funzione di perdita** corrisponde alla `sparse_categorical_crossentropy`, una variante della `categorical_crossentropy`.
#
# La **sparse categorical crossentropy** viene utilizzata quando le classi sono rappresentate come interi, proprio come nel nostro caso.

# %%
basic_model = get_basic_model()
basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

basic_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inputs (InputLayer)         [(None, 124, 129, 1)]     0
#
#  normalizzazione (Normalizat  (None, 124, 129, 1)      3
#  ion)
#
#  conv2D_1 (Conv2D)           (None, 124, 129, 32)      320
#
#  MaxPooling2D_1 (MaxPooling2  (None, 62, 64, 32)       0
#  D)
#
#  conv2D_2 (Conv2D)           (None, 62, 64, 64)        18496
#
#  MaxPooling2D_2 (MaxPooling2  (None, 31, 32, 64)       0
#  D)
#
#  conv2D_3 (Conv2D)           (None, 31, 32, 128)       73856
#
#  MaxPooling2D_3 (MaxPooling2  (None, 15, 16, 128)      0
#  D)
#
#  conv2D_4 (Conv2D)           (None, 15, 16, 256)       295168
#
#  MaxPooling2D_4 (MaxPooling2  (None, 7, 8, 256)        0
#  D)
#
#  conv2D_5 (Conv2D)           (None, 7, 8, 256)         590080
#
#  Flatten (Flatten)           (None, 14336)             0
#
#  dense_output (Dense)        (None, 30)                430110
#
# =================================================================
# Total params: 1,408,033
# Trainable params: 1,408,030
# Non-trainable params: 3
# _________________________________________________________________

# %% [markdown]
# Il modello ha un totale di circa **1.4 milioni di parametri**, bilanciando complessità e capacità di apprendimento.

# %%
basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/spectrogram/basic_model.keras", save_best_only=True, monitor="val_loss")]
basic_model_history = basic_model.fit(train_ds, epochs=30, validation_data=val_ds, callbacks=basic_model_callbacks)
# Out:
# Epoch 1/30
# 243/243 [==============================] - 6s 13ms/step - loss: 2.4521 - accuracy: 0.3276 - val_loss: 1.4050 - val_accuracy: 0.5999
# Epoch 2/30
# 243/243 [==============================] - 4s 14ms/step - loss: 1.0542 - accuracy: 0.7043 - val_loss: 0.8306 - val_accuracy: 0.7774
# Epoch 3/30
# 243/243 [==============================] - 3s 14ms/step - loss: 0.5746 - accuracy: 0.8379 - val_loss: 0.8677 - val_accuracy: 0.7867
# Epoch 4/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.3561 - accuracy: 0.8952 - val_loss: 0.7347 - val_accuracy: 0.8395
# Epoch 5/30
# 243/243 [==============================] - 3s 14ms/step - loss: 0.2526 - accuracy: 0.9280 - val_loss: 0.7220 - val_accuracy: 0.8588
# Epoch 6/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1828 - accuracy: 0.9451 - val_loss: 0.9228 - val_accuracy: 0.8183
# Epoch 7/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1370 - accuracy: 0.9621 - val_loss: 0.7184 - val_accuracy: 0.8376
# Epoch 8/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1204 - accuracy: 0.9665 - val_loss: 0.8283 - val_accuracy: 0.8808
# Epoch 9/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1016 - accuracy: 0.9718 - val_loss: 1.0116 - val_accuracy: 0.8507
# Epoch 10/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0952 - accuracy: 0.9728 - val_loss: 1.0198 - val_accuracy: 0.8750
# Epoch 11/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0809 - accuracy: 0.9778 - val_loss: 1.7285 - val_accuracy: 0.8391
# Epoch 12/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0980 - accuracy: 0.9771 - val_loss: 1.1203 - val_accuracy: 0.8654
# Epoch 13/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0963 - accuracy: 0.9791 - val_loss: 0.9519 - val_accuracy: 0.8704
# Epoch 14/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0747 - accuracy: 0.9825 - val_loss: 1.2167 - val_accuracy: 0.8584
# Epoch 15/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1001 - accuracy: 0.9813 - val_loss: 1.6213 - val_accuracy: 0.8627
# Epoch 16/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0812 - accuracy: 0.9823 - val_loss: 1.5153 - val_accuracy: 0.8549
# Epoch 17/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0735 - accuracy: 0.9840 - val_loss: 1.3188 - val_accuracy: 0.8708
# Epoch 18/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0865 - accuracy: 0.9823 - val_loss: 1.6395 - val_accuracy: 0.8549
# Epoch 19/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0736 - accuracy: 0.9843 - val_loss: 1.6270 - val_accuracy: 0.8611
# Epoch 20/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0821 - accuracy: 0.9849 - val_loss: 1.7908 - val_accuracy: 0.8576
# Epoch 21/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0683 - accuracy: 0.9849 - val_loss: 2.2710 - val_accuracy: 0.8696
# Epoch 22/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0732 - accuracy: 0.9854 - val_loss: 2.2192 - val_accuracy: 0.8657
# Epoch 23/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0727 - accuracy: 0.9861 - val_loss: 2.0057 - val_accuracy: 0.8627
# Epoch 24/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0723 - accuracy: 0.9874 - val_loss: 2.7389 - val_accuracy: 0.8279
# Epoch 25/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0848 - accuracy: 0.9866 - val_loss: 2.5606 - val_accuracy: 0.8681
# Epoch 26/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0925 - accuracy: 0.9849 - val_loss: 3.1073 - val_accuracy: 0.8515
# Epoch 27/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1023 - accuracy: 0.9860 - val_loss: 3.4245 - val_accuracy: 0.8592
# Epoch 28/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1029 - accuracy: 0.9867 - val_loss: 4.0107 - val_accuracy: 0.8511
# Epoch 29/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0724 - accuracy: 0.9899 - val_loss: 2.8828 - val_accuracy: 0.8719
# Epoch 30/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0962 - accuracy: 0.9876 - val_loss: 3.8754 - val_accuracy: 0.8503

# %% [markdown]
# Alleniamo il modello per 30 epoche e visualizziamo le **curve di addestramento** e **validazione**.
#
# In modo tale da poter accedere ai dati del modello più facilmente in futuro trasformiamo la cronologia del modello in un dataframe pandas. Questo facilità anche al visualizzazione dei dati salvati per un caso futuro.

# %%
def convert_history_to_csv(model_history):
    # converto la history del dataframe in un dataframe pandas
    model_history_df = pd.DataFrame(model_history.history)
    # cambio il nome dell'indice e lo imposto a partire da 1
    model_history_df.index = range(1, len(model_history_df) + 1)
    model_history_df.index.name = "epochs"

    return model_history_df

# %% [markdown]
# Salviamo i dati della history del modello in un file csv.

# %%
basic_model_history_df = convert_history_to_csv(basic_model_history)
basic_model_history_df.to_csv("model_histories/rmsprop/spectrogram/basic_model_history.csv")

# %% [markdown]
# Salviamo il miglior modello come file csv nella seguente directory `model_histories/rmsprop/spectrogram` con il nome `basic_model_history`. Inoltre, per prevenire errori di salvataggio causati da versioni differenti di python o dei pacchetti, procediamo con la conversione del file in formato standard `.onnx`.

# %% [markdown]
# Per eseguire la conversione utilizzeremo le librerie **tf2onnx** e **onnx**, importate precedentemente.

# %%
def convert_model_to_onnx(model_path, input_shape):
    model = tf.keras.models.load_model(model_path)

    onnx_path = model_path.split(".")[:-1] + ["onnx"]
    onnx_path = ".".join(onnx_path)
    
    input_signature = [tf.TensorSpec((None, *input_shape), tf.float32, name="input")]
    onnx_model, _ = tf2onnx.convert.from_keras(model, input_signature=input_signature)

    onnx.save(onnx_model, onnx_path)

# %%
convert_model_to_onnx("bestmodels/rmsprop/spectrogram/basic_model.keras", (124, 129, 1))

# %% [markdown]
# Utilizziamo la funzione `create_train_val_plot` per mostrare l'andamento dell'accurateza e della perdita durante l'addestramento.

# %%
def create_train_val_plot(history, overfit=True):
    # definisco numero epoche
    epochs = range(1, len(history['accuracy']) + 1)

    # Accuracy
    accuracy = history['accuracy']
    val_accuracy = history['val_accuracy']

    fig_acc, ax_acc = plt.subplots()

    # linea di base
    ax_acc.plot(epochs, [0.5 for x in range(len(epochs))], color="lightgray", linestyle="--", label="Base")
    # linee di accuratezza
    ax_acc.plot(epochs, accuracy, color="slategray", label="Accuratezza in addestramento")
    ax_acc.plot(epochs, val_accuracy, color="indianred", label="Accuratezza in validazione")
    # miglior accuratezza validazione
    ax_acc.axhline(y=max(val_accuracy), c='indianred', alpha=0.7, linestyle='--')
    ax_acc.text(len(epochs) * 1.07, max(val_accuracy), round(max(val_accuracy), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_acc.spines["right"].set_visible(False)
    ax_acc.spines["top"].set_visible(False)
    ax_acc.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_acc.set_title("Accuratezza in addestramento e validazione")
    ax_acc.set_xlabel("Epoche")
    ax_acc.set_ylabel("Accuratezza (%)")
    ax_acc.legend()

    # Loss
    loss = history['loss']
    val_loss = history['val_loss']

    fig_loss, ax_loss = plt.subplots()

    # linee di loss
    ax_loss.plot(epochs, loss, color="slategray", label="Perdita in addestramento")
    ax_loss.plot(epochs, val_loss, color="indianred", label="Perdita in validazione")
    # miglior loss validazione
    ax_loss.axhline(y=min(val_loss), c='indianred', alpha=0.7, linestyle='--')
    ax_loss.text(len(epochs) * 1.07, min(val_loss), round(min(val_loss), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_loss.spines["right"].set_visible(False)
    ax_loss.spines["top"].set_visible(False)
    ax_loss.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_loss.set_title("Perdita in addestramento e validazione")
    ax_loss.set_xlabel("Epoche")
    ax_loss.set_ylabel("Perdita")

    handles, _ = ax_loss.get_legend_handles_labels()

    if overfit:
        # area overfit
        rect = mpatches.Rectangle((np.argmin(val_loss) + 1, 0), width=100 - np.argmin(val_loss), height=max(max(loss), max(val_loss)), color='lightcoral', alpha=0.3)
        ax_loss.add_patch(rect)
        # patch overfit per legenda
        overfit = mpatches.Patch(color='indianred', alpha=0.3, label='Area overfit')
        handles, _ = ax_loss.get_legend_handles_labels()
        handles.append(overfit)

    # legenda
    ax_loss.legend(handles=handles)

    plt.show()

# %%
create_train_val_plot(basic_model_history.history)

# %% [markdown]
# Questi grafici mostrano come il nostro modello sia andato immediatamente in overfitting. L'accuratezza dell'addestramento aumenta col tempo e raggiunge quasi il **100%**, mentre l'accuratezza della validazione si attesta sull'**85%** con un **picco del 88%**. La **perdita nel set di addestramento** continua a diminuire dopo la **quinta epoca**, mentre la **perdita nel set di validazione** aumenta.

# %% [markdown]
# Possiamo verificare l'accuratezza della migliore versione del nostro modello di base ricaricando il file **basic_model.keras**

# %%
best_basic_model = tf.keras.models.load_model("bestmodels/rmsprop/spectrogram/basic_model.keras")
test_loss, test_acc = best_basic_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 7ms/step - loss: 0.8238 - accuracy: 0.8284
# Accuratezza: 0.828

# %% [markdown]
# Oppure, possiamo verificarla con il file **basic_model.onnx**

# %%
def evaluate_onnx_model(path_model_onnx, test_ds):
    # il fatto che sia suddiviso in batch mi crea problemi, perciò lo risolvo togliendoli
    test_ds = test_ds.unbatch()
    
    # carico il modello utilizzando il file onnx
    m = rt.InferenceSession(path_model_onnx)
    
    # trasformo il dataset in array numpy
    spectrogram_np = np.array([spectrogram.numpy() for spectrogram, _ in test_ds])
    labels_np = np.array([label.numpy() for _, label in test_ds])
    
    # eseguo le predizione del modello
    pred_onnx = m.run(None, {'input': spectrogram_np})
    # ottengo la predizione corretta
    predictions = np.argmax(pred_onnx[0], axis=1)
    # computo la accuratezza
    accuracy = np.mean(predictions == labels_np)
    # stampo l'accuratezza
    print(f"Accuratezza: {accuracy:.3f}")

# %%
evaluate_onnx_model("bestmodels/rmsprop/spectrogram/basic_model.onnx", test_ds)
# Out:
# Accuratezza: 0.828

# %% [markdown]
# Abbiamo ottenuto un'**accuratezza** del **82.8%**! Lo riteniamo un ottimo risultato considerato il task non banale.

# %% [markdown]
# Come ultimo, creiamo una funzione utile a visualizzare graficamente la distribuzione di accuratezza delle classi su un'immagine casuale, per capire come ha lavorato il modello. Nel caso il modello non predica correttamente, la **classe corretta** verrà sempre evidenziata di **verde**, mentre la **classe predetta** verrà evidenziata di **giallo**.

# %%
def create_distribution_plot(model, audio, label):
    prediction = model(audio) # otteniamo la predizione del modello sull'audio preso in input

    random_audio_index = np.random.randint(0, len(prediction) - 1) # abbiamo notato che mostravamo sempre la classe no, magari così cambia un po' le classi che mostriamo

    softmax_pred = tf.nn.softmax(prediction[random_audio_index]) # dobbiamo applicare nuovamente la softmax in modo tale da avere dei dati leggibili
    pred_label = np.argmax(softmax_pred) # ci salviamo l'indice della label predetta dal nostro modello, quella con la probabilità più alta

    colors = ['indianred'] * len(label_names) # creiamo un vettore di lunghezza 30 (la quantità delle nostre label) colorate di rosso

    if pred_label == label[random_audio_index].numpy(): # se la label che abbiamo predetto è corretta, allora la coloriamo di verde
        colors[pred_label] = 'seagreen'
    else: # se la label che abbiamo predetto è sbagliata, allora coloriamo di verde la corretta e di gialla la predetta
        colors[pred_label] = 'khaki'
        colors[label[random_audio_index].numpy()] = 'seagreen'

    plt.figure(figsize=(12, 4))

    plt.bar(label_names, softmax_pred.numpy(), color=colors)
    plt.xticks(rotation=45)

    # dichiariamo i colori della legenda
    other_values_patch = mpatches.Patch(color='indianred', label='Altre classi')
    pred_value_patch = mpatches.Patch(color='khaki', label='Classe predetta')
    correct_value_patch = mpatches.Patch(color='green', label='Classe corretta')

    # disegniamo la legenda con i colori necessari
    if pred_label == label[random_audio_index].numpy(): # se abbiamo predetto correttamente la label, non è necessario mostrare il colore giallo (non è presente nel plot)
        plt.legend(handles=[other_values_patch, correct_value_patch])
    else:
        plt.legend(handles=[other_values_patch, pred_value_patch, correct_value_patch])

    plt.show()

# %%
for audio, label in test_ds: # prendiamo un audio a caso del test e creiamo la distribuzione
    create_distribution_plot(best_basic_model, audio, label)
    break

# %% [markdown]
# Possiamo notare dalla distribuzione che il modello in questo caso ha predetto correttamente la **classe three**.

# %% [markdown]
# ### Risoluzione dell'overfitting
# Abbiamo capito che il modello è andato immediatamente in **overfitting**, e lo possiamo notare dalla loss di validazione che inizia a salire dalla quinta epoca in poi. L'obbiettivo principale in questo momento è evitare che vada in overfitting troppo velocemente, applicando le tecniche viste a lezione.

# %% [markdown]
# Attualmente per ridurre l'overfitting applichiamo **un livello di Dropout**. Il livello di dropout imposta **randomicamente** delle attivazioni a 0, perciò stiamo disattivando qualche neurone. Nello specifico stiamo **azzerando** un certo numero di caratteristiche di uscita dello strato Dense. L'idea dietro questa tecnica è quella di mettere in difficoltà il modello.

# %%
def get_improved_basic_model():
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(124, 129, 1))
    x = tf.keras.layers.Normalization()(inputs)

    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
improved_basic_model = get_improved_basic_model()
improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

# %%
improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/spectrogram/improved_basic_model.keras", save_best_only=True, monitor="val_loss")]
improved_history = improved_basic_model.fit(train_ds, epochs=100, validation_data=val_ds, callbacks=improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 4s 13ms/step - loss: 2.5460 - accuracy: 0.2896 - val_loss: 1.6773 - val_accuracy: 0.5235
# Epoch 2/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.1889 - accuracy: 0.6626 - val_loss: 0.9454 - val_accuracy: 0.7249
# Epoch 3/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.7131 - accuracy: 0.7932 - val_loss: 0.7209 - val_accuracy: 0.8067
# Epoch 4/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.4920 - accuracy: 0.8580 - val_loss: 0.6685 - val_accuracy: 0.8272
# Epoch 5/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.3753 - accuracy: 0.8865 - val_loss: 0.6054 - val_accuracy: 0.8619
# Epoch 6/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.2947 - accuracy: 0.9104 - val_loss: 0.5178 - val_accuracy: 0.8742
# Epoch 7/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2339 - accuracy: 0.9313 - val_loss: 1.0281 - val_accuracy: 0.8383
# Epoch 8/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1986 - accuracy: 0.9396 - val_loss: 0.6514 - val_accuracy: 0.8646
# Epoch 9/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1817 - accuracy: 0.9464 - val_loss: 0.6454 - val_accuracy: 0.8831
# Epoch 10/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1605 - accuracy: 0.9536 - val_loss: 0.8325 - val_accuracy: 0.8765
# Epoch 11/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1410 - accuracy: 0.9572 - val_loss: 0.8592 - val_accuracy: 0.8607
# Epoch 12/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1412 - accuracy: 0.9642 - val_loss: 0.9806 - val_accuracy: 0.8665
# Epoch 13/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1283 - accuracy: 0.9660 - val_loss: 0.7264 - val_accuracy: 0.8839
# Epoch 14/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1196 - accuracy: 0.9661 - val_loss: 1.0052 - val_accuracy: 0.8827
# Epoch 15/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1215 - accuracy: 0.9705 - val_loss: 0.7616 - val_accuracy: 0.8885
# Epoch 16/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1239 - accuracy: 0.9697 - val_loss: 1.2783 - val_accuracy: 0.8414
# Epoch 17/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1202 - accuracy: 0.9704 - val_loss: 0.7652 - val_accuracy: 0.8735
# Epoch 18/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1041 - accuracy: 0.9715 - val_loss: 0.8294 - val_accuracy: 0.8789
# Epoch 19/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1158 - accuracy: 0.9707 - val_loss: 0.9973 - val_accuracy: 0.8839
# Epoch 20/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1044 - accuracy: 0.9745 - val_loss: 0.8582 - val_accuracy: 0.8931
# Epoch 21/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1112 - accuracy: 0.9732 - val_loss: 1.0695 - val_accuracy: 0.8603
# Epoch 22/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1192 - accuracy: 0.9731 - val_loss: 1.2508 - val_accuracy: 0.8661
# Epoch 23/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1219 - accuracy: 0.9768 - val_loss: 1.0760 - val_accuracy: 0.8846
# Epoch 24/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1182 - accuracy: 0.9737 - val_loss: 1.4920 - val_accuracy: 0.8769
# Epoch 25/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1022 - accuracy: 0.9753 - val_loss: 2.0784 - val_accuracy: 0.8414
# Epoch 26/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1256 - accuracy: 0.9747 - val_loss: 1.1023 - val_accuracy: 0.8792
# Epoch 27/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1257 - accuracy: 0.9745 - val_loss: 1.3169 - val_accuracy: 0.8816
# Epoch 28/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1097 - accuracy: 0.9756 - val_loss: 1.6130 - val_accuracy: 0.8762
# Epoch 29/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1153 - accuracy: 0.9777 - val_loss: 2.1828 - val_accuracy: 0.8445
# Epoch 30/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1071 - accuracy: 0.9795 - val_loss: 1.6019 - val_accuracy: 0.8765
# Epoch 31/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1241 - accuracy: 0.9804 - val_loss: 1.4444 - val_accuracy: 0.8731
# Epoch 32/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.1082 - accuracy: 0.9794 - val_loss: 1.8521 - val_accuracy: 0.8893
# Epoch 33/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1112 - accuracy: 0.9817 - val_loss: 1.7840 - val_accuracy: 0.8735
# Epoch 34/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1093 - accuracy: 0.9782 - val_loss: 2.0680 - val_accuracy: 0.8665
# Epoch 35/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1265 - accuracy: 0.9800 - val_loss: 1.6473 - val_accuracy: 0.8792
# Epoch 36/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1097 - accuracy: 0.9803 - val_loss: 2.0596 - val_accuracy: 0.8843
# Epoch 37/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1109 - accuracy: 0.9807 - val_loss: 1.5350 - val_accuracy: 0.8819
# Epoch 38/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1093 - accuracy: 0.9805 - val_loss: 2.5511 - val_accuracy: 0.8831
# Epoch 39/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1205 - accuracy: 0.9817 - val_loss: 1.8617 - val_accuracy: 0.8881
# Epoch 40/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1246 - accuracy: 0.9794 - val_loss: 2.1233 - val_accuracy: 0.8796
# Epoch 41/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1166 - accuracy: 0.9834 - val_loss: 2.4449 - val_accuracy: 0.8893
# Epoch 42/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1538 - accuracy: 0.9821 - val_loss: 2.2033 - val_accuracy: 0.8839
# Epoch 43/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1512 - accuracy: 0.9791 - val_loss: 2.3076 - val_accuracy: 0.8877
# Epoch 44/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1260 - accuracy: 0.9823 - val_loss: 2.6570 - val_accuracy: 0.8897
# Epoch 45/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1387 - accuracy: 0.9821 - val_loss: 2.4781 - val_accuracy: 0.8924
# Epoch 46/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1220 - accuracy: 0.9836 - val_loss: 2.4844 - val_accuracy: 0.8843
# Epoch 47/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1118 - accuracy: 0.9852 - val_loss: 3.0310 - val_accuracy: 0.8858
# Epoch 48/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1440 - accuracy: 0.9832 - val_loss: 3.5183 - val_accuracy: 0.8746
# Epoch 49/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1505 - accuracy: 0.9805 - val_loss: 2.3248 - val_accuracy: 0.8839
# Epoch 50/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1384 - accuracy: 0.9826 - val_loss: 3.5016 - val_accuracy: 0.8800
# Epoch 51/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1467 - accuracy: 0.9831 - val_loss: 3.3154 - val_accuracy: 0.8912
# Epoch 52/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1459 - accuracy: 0.9827 - val_loss: 3.1696 - val_accuracy: 0.8754
# Epoch 53/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1482 - accuracy: 0.9829 - val_loss: 2.9824 - val_accuracy: 0.8827
# Epoch 54/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1591 - accuracy: 0.9822 - val_loss: 3.3298 - val_accuracy: 0.8819
# Epoch 55/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1446 - accuracy: 0.9834 - val_loss: 2.5528 - val_accuracy: 0.8819
# Epoch 56/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1229 - accuracy: 0.9845 - val_loss: 3.1277 - val_accuracy: 0.8897
# Epoch 57/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1209 - accuracy: 0.9872 - val_loss: 3.4529 - val_accuracy: 0.8765
# Epoch 58/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1479 - accuracy: 0.9860 - val_loss: 4.3358 - val_accuracy: 0.8607
# Epoch 59/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1787 - accuracy: 0.9831 - val_loss: 3.1946 - val_accuracy: 0.8812
# Epoch 60/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1618 - accuracy: 0.9832 - val_loss: 2.6509 - val_accuracy: 0.8804
# Epoch 61/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1292 - accuracy: 0.9840 - val_loss: 2.8991 - val_accuracy: 0.8939
# Epoch 62/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1464 - accuracy: 0.9870 - val_loss: 4.0645 - val_accuracy: 0.8673
# Epoch 63/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1601 - accuracy: 0.9867 - val_loss: 4.3833 - val_accuracy: 0.8773
# Epoch 64/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.1628 - accuracy: 0.9865 - val_loss: 5.1587 - val_accuracy: 0.8792
# Epoch 65/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.2414 - accuracy: 0.9830 - val_loss: 4.7556 - val_accuracy: 0.8885
# Epoch 66/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1627 - accuracy: 0.9866 - val_loss: 4.6981 - val_accuracy: 0.8754
# Epoch 67/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.1641 - accuracy: 0.9838 - val_loss: 4.1708 - val_accuracy: 0.8924
# Epoch 68/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.1528 - accuracy: 0.9866 - val_loss: 4.4988 - val_accuracy: 0.8765
# Epoch 69/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1909 - accuracy: 0.9852 - val_loss: 5.2516 - val_accuracy: 0.8696
# Epoch 70/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1671 - accuracy: 0.9848 - val_loss: 3.7966 - val_accuracy: 0.8827
# Epoch 71/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1179 - accuracy: 0.9881 - val_loss: 3.9604 - val_accuracy: 0.8870
# Epoch 72/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1282 - accuracy: 0.9872 - val_loss: 5.0970 - val_accuracy: 0.8692
# Epoch 73/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1923 - accuracy: 0.9871 - val_loss: 4.1916 - val_accuracy: 0.8819
# Epoch 74/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1455 - accuracy: 0.9858 - val_loss: 3.3657 - val_accuracy: 0.8951
# Epoch 75/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1663 - accuracy: 0.9866 - val_loss: 4.7897 - val_accuracy: 0.8781
# Epoch 76/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1524 - accuracy: 0.9885 - val_loss: 4.5726 - val_accuracy: 0.8870
# Epoch 77/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1611 - accuracy: 0.9880 - val_loss: 4.4316 - val_accuracy: 0.8935
# Epoch 78/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1608 - accuracy: 0.9869 - val_loss: 5.1130 - val_accuracy: 0.8885
# Epoch 79/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1381 - accuracy: 0.9883 - val_loss: 4.6099 - val_accuracy: 0.8812
# Epoch 80/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.2089 - accuracy: 0.9879 - val_loss: 5.2817 - val_accuracy: 0.8816
# Epoch 81/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.1704 - accuracy: 0.9880 - val_loss: 4.8989 - val_accuracy: 0.8873
# Epoch 82/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1631 - accuracy: 0.9872 - val_loss: 4.8297 - val_accuracy: 0.8897
# Epoch 83/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.2038 - accuracy: 0.9848 - val_loss: 4.7371 - val_accuracy: 0.8881
# Epoch 84/100
# 243/243 [==============================] - 4s 14ms/step - loss: 0.1645 - accuracy: 0.9885 - val_loss: 4.6510 - val_accuracy: 0.8935
# Epoch 85/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.1986 - accuracy: 0.9870 - val_loss: 5.5995 - val_accuracy: 0.8877
# Epoch 86/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.1767 - accuracy: 0.9889 - val_loss: 9.1127 - val_accuracy: 0.8823
# Epoch 87/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.3045 - accuracy: 0.9878 - val_loss: 8.9369 - val_accuracy: 0.8839
# Epoch 88/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.2234 - accuracy: 0.9884 - val_loss: 6.2214 - val_accuracy: 0.8858
# Epoch 89/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.1683 - accuracy: 0.9893 - val_loss: 7.8140 - val_accuracy: 0.8889
# Epoch 90/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1999 - accuracy: 0.9887 - val_loss: 6.1551 - val_accuracy: 0.8897
# Epoch 91/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.2782 - accuracy: 0.9867 - val_loss: 5.2251 - val_accuracy: 0.8889
# Epoch 92/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.1989 - accuracy: 0.9880 - val_loss: 6.1318 - val_accuracy: 0.8789
# Epoch 93/100
# 243/243 [==============================] - 4s 15ms/step - loss: 0.1611 - accuracy: 0.9896 - val_loss: 6.8381 - val_accuracy: 0.8885
# Epoch 94/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.2245 - accuracy: 0.9883 - val_loss: 6.6849 - val_accuracy: 0.8962
# Epoch 95/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1996 - accuracy: 0.9880 - val_loss: 6.3723 - val_accuracy: 0.8843
# Epoch 96/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1658 - accuracy: 0.9889 - val_loss: 6.6541 - val_accuracy: 0.8866
# Epoch 97/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1526 - accuracy: 0.9897 - val_loss: 5.9645 - val_accuracy: 0.8916
# Epoch 98/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.2589 - accuracy: 0.9870 - val_loss: 6.1281 - val_accuracy: 0.8835
# Epoch 99/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1830 - accuracy: 0.9885 - val_loss: 6.6952 - val_accuracy: 0.8939
# Epoch 100/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1817 - accuracy: 0.9899 - val_loss: 7.1520 - val_accuracy: 0.8846

# %% [markdown]
# Salviamo come prima la history del modello in un file csv.

# %%
improved_history_df = convert_history_to_csv(improved_history)
improved_history_df.to_csv("model_histories/rmsprop/spectrogram/improved_history.csv")

# %% [markdown]
# Salviamo nuovamente il miglior modello anche nel formato **.onnx**.

# %%
convert_model_to_onnx("bestmodels/rmsprop/spectrogram/improved_basic_model.keras", (124, 129, 1))

# %%
create_train_val_plot(improved_history.history)

# %% [markdown]
# Alleniamo il modello per 100 epoche e visualizziamo le **curve di addestramento** e **validazione**.

# %%
improved_best_model = tf.keras.models.load_model("bestmodels/rmsprop/spectrogram/improved_basic_model.keras")
test_loss, test_acc = improved_best_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 5ms/step - loss: 0.5505 - accuracy: 0.8632
# Accuratezza: 0.863

# %% [markdown]
# Verifichiamola anche con il modello **.onnx**

# %%
evaluate_onnx_model("bestmodels/rmsprop/spectrogram/improved_basic_model.onnx", test_ds)
# Out:
# Accuratezza: 0.863

# %% [markdown]
# Abbiamo ottenuto un buon miglioramento dell'accuratezza, attualmente siamo a quota **86.3%**!

# %%
for audio, label in test_ds:
    create_distribution_plot(improved_best_model, audio, label)
    break

# %% [markdown]
# In questo caso il modello è stato in grado di predirre la classe corretta **bed**.

# %% [markdown]
# ### Fine tuning
#
# Gli **iperparametri** sono le variabili che governano il processo di addestramento e la topologia di un modello. Queste rimangono costanti durante l'allenamento e influenzano direttamente le prestazioni.

# %% [markdown]
# Per scegliere un insieme ottimale di iperparametri, abbiamo sviluppato una funzione `tuner`, alla quale passiamo come argomenti una lista di filtri, una lista di tassi di apprendimento, un totale massimo di epoche ed i set di dati su cui si vuole fare l'allenamento.
#
# Questa funzione implementa un **ipermodello**, il quale viene addestrato con varie combinazioni di filtri e tassi di apprendimento, salva i risultati in un file csv e resitituisce le corrispondenze migliori. Queste informazioni sono utili sia per determinare la struttura ottimale del modello da implementare, sia per identificare le combinazioni utilizzate nei modelli precedenti, a fronte del fatto che fino ad ora abbiamo sempre usato dei tassi di apprendimento dinamici.
#
# Per usare questa funzione dobbiamo prima definire un **ipermodello**, ovvero l'architettura del modello su cui vogliamo eseguire i test per trovare gli iperparametri più consoni. Esso è implementato attraverso la funzione `get_improved_basic_model_tuning`, che iterando una lista di filtri adatta le dimensioni degli output degli strati convolutivi.

# %%
def get_improved_basic_model_tuning(start_filters):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(124, 129, 1))
    x = tf.keras.layers.Normalization()(inputs)

    if not isinstance(start_filters, int):
        raise Exception("start_filters must be type integer")

    filters = [start_filters * (2 ** i) for i in range(4)]
    
    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=filters[0], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[1], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[2], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[3], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[3], kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# Più nello specifico, la funzione tuner utilizza una callback di tipo EarlyStopping che monitora la perdita sul set di validazione con una pazienza di 5. Questo significa che il modello viene interrotto se la perdita di validazione non diminuisce entro 5 epoche dalla sua minima.
#
# Questa implementazione è utile per risparmiare tempo con i modelli che cessano di migliorare precocemente le loro prestazioni.

# %%
def tuner(filters, learning_rates, max_epochs, train_dataset, validation_dataset):
    start_time = time.time()

    counter = 1
    
    if not isinstance(filters, list):
        raise Exception("parameter filters must be type list")

    if not isinstance(learning_rates, list):
        raise Exception("parameter learning_rates must be type list")

    callbacks = [tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5)]

    best_learning_rate = 0 
    best_filters = 0
    best_val_accuracy = 0

    best_model = 0
    
    for f in filters:
        for lr in learning_rates:
            print(f"\nAddestrando con filtri {[f * (2 ** i) for i in range(4)]} e tasso di apprendimento {lr}")
            
            model = get_improved_basic_model_tuning(start_filters=f)
            model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.RMSprop(learning_rate=lr), metrics=["accuracy"])
            model_history = model.fit(train_dataset, epochs=max_epochs, validation_data=validation_dataset, callbacks=callbacks)

            model_history_df = convert_history_to_csv(model_history)

            model_history_df[["filters"]] = f
            model_history_df[["learning_rate"]] = lr
            
            path = "model_tuning/rmsprop/spectrogram/model_" + str(counter) + ".csv"
            model_history_df.to_csv(path)
            
            if best_val_accuracy < model_history_df.iloc[-1]["val_accuracy"]:
                best_val_accuracy = model_history_df.iloc[-1]["val_accuracy"]
                best_filters = f
                best_learning_rate = lr
                epoch = len(model_history_df)

            del model

            counter += 1

    total_time = time.time() - start_time
    minutes, seconds = divmod(total_time, 60)
    print(f"\nTempo totale trascorso: {int(minutes)} minuti e {int(seconds)} secondi")
    # print(f"Il miglior modello ha un filtro di partenza pari a {best_filters}, un learning rate pari a {best_learning_rate} con un'accuracy pari a {best_val_accuracy:.3f}")

    return best_filters, best_learning_rate

# %%
best_filter, best_learning_rate = tuner([16, 32, 64], [1e-3, 1e-4, 1e-5], 30, train_ds, val_ds)
# Out:
# Addestrando con filtri [16, 32, 64, 128] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 3s 9ms/step - loss: 2.6235 - accuracy: 0.2656 - val_loss: 2.0103 - val_accuracy: 0.4398
# Epoch 2/30
# 243/243 [==============================] - 2s 9ms/step - loss: 1.4256 - accuracy: 0.5982 - val_loss: 1.4142 - val_accuracy: 0.6034
# Epoch 3/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.8773 - accuracy: 0.7548 - val_loss: 0.8287 - val_accuracy: 0.7724
# Epoch 4/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.6194 - accuracy: 0.8200 - val_loss: 0.7248 - val_accuracy: 0.8152
# Epoch 5/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.4684 - accuracy: 0.8666 - val_loss: 0.5462 - val_accuracy: 0.8549
# Epoch 6/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.3805 - accuracy: 0.8865 - val_loss: 0.5258 - val_accuracy: 0.8538
# Epoch 7/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.2982 - accuracy: 0.9107 - val_loss: 0.7852 - val_accuracy: 0.8395
# Epoch 8/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.2615 - accuracy: 0.9213 - val_loss: 0.6493 - val_accuracy: 0.8511
# Epoch 9/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.2282 - accuracy: 0.9299 - val_loss: 0.5908 - val_accuracy: 0.8731
# Epoch 10/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.1911 - accuracy: 0.9427 - val_loss: 0.8129 - val_accuracy: 0.8519
# Epoch 11/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.1734 - accuracy: 0.9486 - val_loss: 0.6197 - val_accuracy: 0.8769
#
# Addestrando con filtri [16, 32, 64, 128] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 3s 9ms/step - loss: 3.2329 - accuracy: 0.1108 - val_loss: 2.9076 - val_accuracy: 0.2647
# Epoch 2/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.8160 - accuracy: 0.2420 - val_loss: 2.5736 - val_accuracy: 0.3573
# Epoch 3/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.5337 - accuracy: 0.3340 - val_loss: 2.3117 - val_accuracy: 0.4201
# Epoch 4/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.2679 - accuracy: 0.4079 - val_loss: 2.0897 - val_accuracy: 0.4830
# Epoch 5/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.0238 - accuracy: 0.4719 - val_loss: 1.8923 - val_accuracy: 0.5189
# Epoch 6/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.8351 - accuracy: 0.5320 - val_loss: 1.7089 - val_accuracy: 0.5833
# Epoch 7/30
# 243/243 [==============================] - 2s 9ms/step - loss: 1.6295 - accuracy: 0.5826 - val_loss: 1.5254 - val_accuracy: 0.6346
# Epoch 8/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.4737 - accuracy: 0.6214 - val_loss: 1.4402 - val_accuracy: 0.6566
# Epoch 9/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.3022 - accuracy: 0.6688 - val_loss: 1.2931 - val_accuracy: 0.6902
# Epoch 10/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.1832 - accuracy: 0.6981 - val_loss: 1.2359 - val_accuracy: 0.7014
# Epoch 11/30
# 243/243 [==============================] - 2s 9ms/step - loss: 1.0752 - accuracy: 0.7237 - val_loss: 1.1322 - val_accuracy: 0.7222
# Epoch 12/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.9983 - accuracy: 0.7437 - val_loss: 1.0562 - val_accuracy: 0.7438
# Epoch 13/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.9123 - accuracy: 0.7652 - val_loss: 1.0009 - val_accuracy: 0.7512
# Epoch 14/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.8511 - accuracy: 0.7749 - val_loss: 1.0202 - val_accuracy: 0.7481
# Epoch 15/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.7710 - accuracy: 0.7979 - val_loss: 0.9319 - val_accuracy: 0.7631
# Epoch 16/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.7313 - accuracy: 0.8041 - val_loss: 0.9187 - val_accuracy: 0.7739
# Epoch 17/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.6850 - accuracy: 0.8131 - val_loss: 0.9199 - val_accuracy: 0.7797
# Epoch 18/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.6455 - accuracy: 0.8259 - val_loss: 0.8961 - val_accuracy: 0.7797
# Epoch 19/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.6178 - accuracy: 0.8336 - val_loss: 0.8490 - val_accuracy: 0.7870
# Epoch 20/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.5798 - accuracy: 0.8425 - val_loss: 0.8285 - val_accuracy: 0.7863
# Epoch 21/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.5397 - accuracy: 0.8566 - val_loss: 0.8542 - val_accuracy: 0.7975
# Epoch 22/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.5241 - accuracy: 0.8546 - val_loss: 0.7880 - val_accuracy: 0.8067
# Epoch 23/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.4844 - accuracy: 0.8651 - val_loss: 0.7897 - val_accuracy: 0.8067
# Epoch 24/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.4655 - accuracy: 0.8691 - val_loss: 0.8263 - val_accuracy: 0.8040
# Epoch 25/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.4538 - accuracy: 0.8729 - val_loss: 0.8044 - val_accuracy: 0.8083
# Epoch 26/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.4258 - accuracy: 0.8826 - val_loss: 0.7947 - val_accuracy: 0.8063
# Epoch 27/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.4150 - accuracy: 0.8840 - val_loss: 0.8065 - val_accuracy: 0.8113
#
# Addestrando con filtri [16, 32, 64, 128] e tasso di apprendimento 1e-05
# Epoch 1/30
# 243/243 [==============================] - 3s 9ms/step - loss: 3.4015 - accuracy: 0.0450 - val_loss: 3.3749 - val_accuracy: 0.0494
# Epoch 2/30
# 243/243 [==============================] - 2s 9ms/step - loss: 3.3721 - accuracy: 0.0612 - val_loss: 3.3452 - val_accuracy: 0.0791
# Epoch 3/30
# 243/243 [==============================] - 2s 9ms/step - loss: 3.3374 - accuracy: 0.0765 - val_loss: 3.3036 - val_accuracy: 0.1103
# Epoch 4/30
# 243/243 [==============================] - 2s 9ms/step - loss: 3.2944 - accuracy: 0.1003 - val_loss: 3.2460 - val_accuracy: 0.1454
# Epoch 5/30
# 243/243 [==============================] - 2s 9ms/step - loss: 3.2354 - accuracy: 0.1137 - val_loss: 3.1725 - val_accuracy: 0.1860
# Epoch 6/30
# 243/243 [==============================] - 2s 9ms/step - loss: 3.1721 - accuracy: 0.1379 - val_loss: 3.0933 - val_accuracy: 0.2137
# Epoch 7/30
# 243/243 [==============================] - 2s 9ms/step - loss: 3.0992 - accuracy: 0.1603 - val_loss: 3.0146 - val_accuracy: 0.2380
# Epoch 8/30
# 243/243 [==============================] - 2s 9ms/step - loss: 3.0434 - accuracy: 0.1689 - val_loss: 2.9466 - val_accuracy: 0.2577
# Epoch 9/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.9912 - accuracy: 0.1887 - val_loss: 2.8844 - val_accuracy: 0.2824
# Epoch 10/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.9372 - accuracy: 0.2080 - val_loss: 2.8298 - val_accuracy: 0.2967
# Epoch 11/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.8861 - accuracy: 0.2142 - val_loss: 2.7833 - val_accuracy: 0.3094
# Epoch 12/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.8399 - accuracy: 0.2326 - val_loss: 2.7378 - val_accuracy: 0.3229
# Epoch 13/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.8061 - accuracy: 0.2464 - val_loss: 2.6991 - val_accuracy: 0.3383
# Epoch 14/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.7719 - accuracy: 0.2616 - val_loss: 2.6619 - val_accuracy: 0.3507
# Epoch 15/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.7158 - accuracy: 0.2696 - val_loss: 2.6221 - val_accuracy: 0.3584
# Epoch 16/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.6869 - accuracy: 0.2844 - val_loss: 2.5879 - val_accuracy: 0.3661
# Epoch 17/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.6522 - accuracy: 0.2923 - val_loss: 2.5557 - val_accuracy: 0.3762
# Epoch 18/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.6175 - accuracy: 0.3003 - val_loss: 2.5234 - val_accuracy: 0.3870
# Epoch 19/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.5842 - accuracy: 0.3188 - val_loss: 2.4899 - val_accuracy: 0.3997
# Epoch 20/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.5503 - accuracy: 0.3250 - val_loss: 2.4626 - val_accuracy: 0.3989
# Epoch 21/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.4930 - accuracy: 0.3330 - val_loss: 2.4311 - val_accuracy: 0.4062
# Epoch 22/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.4844 - accuracy: 0.3407 - val_loss: 2.3976 - val_accuracy: 0.4167
# Epoch 23/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.4407 - accuracy: 0.3626 - val_loss: 2.3714 - val_accuracy: 0.4228
# Epoch 24/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.4223 - accuracy: 0.3594 - val_loss: 2.3420 - val_accuracy: 0.4352
# Epoch 25/30
# 243/243 [==============================] - 3s 10ms/step - loss: 2.3968 - accuracy: 0.3697 - val_loss: 2.3177 - val_accuracy: 0.4383
# Epoch 26/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.3459 - accuracy: 0.3869 - val_loss: 2.2877 - val_accuracy: 0.4479
# Epoch 27/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.3330 - accuracy: 0.3916 - val_loss: 2.2619 - val_accuracy: 0.4510
# Epoch 28/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.3049 - accuracy: 0.4052 - val_loss: 2.2345 - val_accuracy: 0.4587
# Epoch 29/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.2691 - accuracy: 0.4131 - val_loss: 2.2092 - val_accuracy: 0.4649
# Epoch 30/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.2362 - accuracy: 0.4173 - val_loss: 2.1856 - val_accuracy: 0.4726
#
# Addestrando con filtri [32, 64, 128, 256] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 4s 13ms/step - loss: 2.5022 - accuracy: 0.3059 - val_loss: 2.1893 - val_accuracy: 0.4336
# Epoch 2/30
# 243/243 [==============================] - 3s 13ms/step - loss: 1.2066 - accuracy: 0.6599 - val_loss: 0.9686 - val_accuracy: 0.7230
# Epoch 3/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.7064 - accuracy: 0.7933 - val_loss: 0.7060 - val_accuracy: 0.8326
# Epoch 4/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4921 - accuracy: 0.8599 - val_loss: 0.6799 - val_accuracy: 0.8102
# Epoch 5/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.3556 - accuracy: 0.8972 - val_loss: 0.7338 - val_accuracy: 0.8422
# Epoch 6/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2744 - accuracy: 0.9174 - val_loss: 0.7486 - val_accuracy: 0.8542
# Epoch 7/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2325 - accuracy: 0.9347 - val_loss: 0.6128 - val_accuracy: 0.8785
# Epoch 8/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1961 - accuracy: 0.9418 - val_loss: 0.6379 - val_accuracy: 0.8553
# Epoch 9/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1636 - accuracy: 0.9528 - val_loss: 0.8805 - val_accuracy: 0.8546
# Epoch 10/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1551 - accuracy: 0.9546 - val_loss: 0.7669 - val_accuracy: 0.8657
# Epoch 11/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1462 - accuracy: 0.9616 - val_loss: 0.9440 - val_accuracy: 0.8688
# Epoch 12/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1401 - accuracy: 0.9622 - val_loss: 0.7759 - val_accuracy: 0.8769
#
# Addestrando con filtri [32, 64, 128, 256] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 4s 13ms/step - loss: 3.1009 - accuracy: 0.1567 - val_loss: 2.6978 - val_accuracy: 0.3183
# Epoch 2/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.5383 - accuracy: 0.3277 - val_loss: 2.2899 - val_accuracy: 0.4090
# Epoch 3/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.1307 - accuracy: 0.4454 - val_loss: 2.0105 - val_accuracy: 0.4927
# Epoch 4/30
# 243/243 [==============================] - 3s 12ms/step - loss: 1.7658 - accuracy: 0.5432 - val_loss: 1.6758 - val_accuracy: 0.5764
# Epoch 5/30
# 243/243 [==============================] - 3s 12ms/step - loss: 1.4549 - accuracy: 0.6219 - val_loss: 1.4111 - val_accuracy: 0.6447
# Epoch 6/30
# 243/243 [==============================] - 3s 12ms/step - loss: 1.2189 - accuracy: 0.6812 - val_loss: 1.2101 - val_accuracy: 0.6979
# Epoch 7/30
# 243/243 [==============================] - 3s 12ms/step - loss: 1.0630 - accuracy: 0.7254 - val_loss: 1.0946 - val_accuracy: 0.7118
# Epoch 8/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.8917 - accuracy: 0.7615 - val_loss: 0.9627 - val_accuracy: 0.7519
# Epoch 9/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.7859 - accuracy: 0.7916 - val_loss: 0.8903 - val_accuracy: 0.7654
# Epoch 10/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.6903 - accuracy: 0.8157 - val_loss: 0.8799 - val_accuracy: 0.7689
# Epoch 11/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.6004 - accuracy: 0.8339 - val_loss: 0.8229 - val_accuracy: 0.7897
# Epoch 12/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.5392 - accuracy: 0.8485 - val_loss: 0.7493 - val_accuracy: 0.8086
# Epoch 13/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.4768 - accuracy: 0.8691 - val_loss: 0.7623 - val_accuracy: 0.8110
# Epoch 14/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.4335 - accuracy: 0.8758 - val_loss: 0.7332 - val_accuracy: 0.8148
# Epoch 15/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.3950 - accuracy: 0.8885 - val_loss: 0.8017 - val_accuracy: 0.8098
# Epoch 16/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.3538 - accuracy: 0.8954 - val_loss: 0.7865 - val_accuracy: 0.8121
# Epoch 17/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.3282 - accuracy: 0.9077 - val_loss: 0.7631 - val_accuracy: 0.8063
# Epoch 18/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.3072 - accuracy: 0.9116 - val_loss: 0.7535 - val_accuracy: 0.8283
# Epoch 19/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2649 - accuracy: 0.9244 - val_loss: 0.6805 - val_accuracy: 0.8445
# Epoch 20/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2545 - accuracy: 0.9254 - val_loss: 0.6247 - val_accuracy: 0.8480
# Epoch 21/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2427 - accuracy: 0.9295 - val_loss: 0.7662 - val_accuracy: 0.8279
# Epoch 22/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2214 - accuracy: 0.9349 - val_loss: 0.7824 - val_accuracy: 0.8306
# Epoch 23/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2038 - accuracy: 0.9407 - val_loss: 0.6554 - val_accuracy: 0.8538
# Epoch 24/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1916 - accuracy: 0.9429 - val_loss: 0.7129 - val_accuracy: 0.8499
# Epoch 25/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1748 - accuracy: 0.9509 - val_loss: 0.7610 - val_accuracy: 0.8492
#
# Addestrando con filtri [32, 64, 128, 256] e tasso di apprendimento 1e-05
# Epoch 1/30
# 243/243 [==============================] - 3s 12ms/step - loss: 3.3839 - accuracy: 0.0553 - val_loss: 3.3549 - val_accuracy: 0.0926
# Epoch 2/30
# 243/243 [==============================] - 3s 12ms/step - loss: 3.3214 - accuracy: 0.0889 - val_loss: 3.2680 - val_accuracy: 0.1420
# Epoch 3/30
# 243/243 [==============================] - 3s 12ms/step - loss: 3.2140 - accuracy: 0.1268 - val_loss: 3.1324 - val_accuracy: 0.1860
# Epoch 4/30
# 243/243 [==============================] - 3s 12ms/step - loss: 3.0913 - accuracy: 0.1649 - val_loss: 2.9942 - val_accuracy: 0.2280
# Epoch 5/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.9899 - accuracy: 0.1851 - val_loss: 2.8779 - val_accuracy: 0.2697
# Epoch 6/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.8980 - accuracy: 0.2140 - val_loss: 2.7896 - val_accuracy: 0.2982
# Epoch 7/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.8109 - accuracy: 0.2424 - val_loss: 2.7153 - val_accuracy: 0.3233
# Epoch 8/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.7614 - accuracy: 0.2597 - val_loss: 2.6591 - val_accuracy: 0.3449
# Epoch 9/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.6796 - accuracy: 0.2821 - val_loss: 2.5978 - val_accuracy: 0.3615
# Epoch 10/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.6257 - accuracy: 0.3000 - val_loss: 2.5515 - val_accuracy: 0.3692
# Epoch 11/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.5864 - accuracy: 0.3121 - val_loss: 2.5007 - val_accuracy: 0.3931
# Epoch 12/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.5126 - accuracy: 0.3437 - val_loss: 2.4501 - val_accuracy: 0.4113
# Epoch 13/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.4524 - accuracy: 0.3575 - val_loss: 2.4038 - val_accuracy: 0.4275
# Epoch 14/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.4194 - accuracy: 0.3733 - val_loss: 2.3583 - val_accuracy: 0.4390
# Epoch 15/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.3683 - accuracy: 0.3862 - val_loss: 2.3137 - val_accuracy: 0.4502
# Epoch 16/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.3106 - accuracy: 0.4061 - val_loss: 2.2664 - val_accuracy: 0.4622
# Epoch 17/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.2572 - accuracy: 0.4153 - val_loss: 2.2190 - val_accuracy: 0.4757
# Epoch 18/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.2103 - accuracy: 0.4356 - val_loss: 2.1811 - val_accuracy: 0.4803
# Epoch 19/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.1698 - accuracy: 0.4425 - val_loss: 2.1405 - val_accuracy: 0.4919
# Epoch 20/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.1231 - accuracy: 0.4595 - val_loss: 2.0963 - val_accuracy: 0.5039
# Epoch 21/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.0796 - accuracy: 0.4762 - val_loss: 2.0703 - val_accuracy: 0.5116
# Epoch 22/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.0452 - accuracy: 0.4771 - val_loss: 2.0307 - val_accuracy: 0.5185
# Epoch 23/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.0001 - accuracy: 0.4929 - val_loss: 1.9889 - val_accuracy: 0.5336
# Epoch 24/30
# 243/243 [==============================] - 3s 13ms/step - loss: 1.9452 - accuracy: 0.5076 - val_loss: 1.9623 - val_accuracy: 0.5436
# Epoch 25/30
# 243/243 [==============================] - 3s 13ms/step - loss: 1.8997 - accuracy: 0.5215 - val_loss: 1.9194 - val_accuracy: 0.5471
# Epoch 26/30
# 243/243 [==============================] - 3s 13ms/step - loss: 1.8743 - accuracy: 0.5313 - val_loss: 1.8898 - val_accuracy: 0.5529
# Epoch 27/30
# 243/243 [==============================] - 3s 13ms/step - loss: 1.8307 - accuracy: 0.5361 - val_loss: 1.8647 - val_accuracy: 0.5606
# Epoch 28/30
# 243/243 [==============================] - 3s 12ms/step - loss: 1.7942 - accuracy: 0.5500 - val_loss: 1.8393 - val_accuracy: 0.5640
# Epoch 29/30
# 243/243 [==============================] - 3s 12ms/step - loss: 1.7308 - accuracy: 0.5680 - val_loss: 1.8062 - val_accuracy: 0.5737
# Epoch 30/30
# 243/243 [==============================] - 3s 12ms/step - loss: 1.7147 - accuracy: 0.5747 - val_loss: 1.7725 - val_accuracy: 0.5829
#
# Addestrando con filtri [64, 128, 256, 512] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 7s 23ms/step - loss: 2.5791 - accuracy: 0.2918 - val_loss: 1.5220 - val_accuracy: 0.5386
# Epoch 2/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.1030 - accuracy: 0.6813 - val_loss: 0.7817 - val_accuracy: 0.7728
# Epoch 3/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.6354 - accuracy: 0.8162 - val_loss: 0.9805 - val_accuracy: 0.7712
# Epoch 4/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.4270 - accuracy: 0.8746 - val_loss: 0.6306 - val_accuracy: 0.8407
# Epoch 5/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.3342 - accuracy: 0.9021 - val_loss: 0.9526 - val_accuracy: 0.8264
# Epoch 6/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.2719 - accuracy: 0.9193 - val_loss: 0.7519 - val_accuracy: 0.8519
# Epoch 7/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.2147 - accuracy: 0.9393 - val_loss: 0.6979 - val_accuracy: 0.8746
# Epoch 8/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1989 - accuracy: 0.9464 - val_loss: 0.7467 - val_accuracy: 0.8750
# Epoch 9/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1859 - accuracy: 0.9534 - val_loss: 0.7712 - val_accuracy: 0.8642
#
# Addestrando con filtri [64, 128, 256, 512] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 6s 22ms/step - loss: 2.9775 - accuracy: 0.1972 - val_loss: 2.4795 - val_accuracy: 0.3650
# Epoch 2/30
# 243/243 [==============================] - 5s 22ms/step - loss: 2.2017 - accuracy: 0.4137 - val_loss: 1.8590 - val_accuracy: 0.5004
# Epoch 3/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.6095 - accuracy: 0.5780 - val_loss: 2.2857 - val_accuracy: 0.4240
# Epoch 4/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.2156 - accuracy: 0.6807 - val_loss: 1.1861 - val_accuracy: 0.6956
# Epoch 5/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.9465 - accuracy: 0.7563 - val_loss: 1.1746 - val_accuracy: 0.7249
# Epoch 6/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.7478 - accuracy: 0.7963 - val_loss: 0.7646 - val_accuracy: 0.7971
# Epoch 7/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.6048 - accuracy: 0.8343 - val_loss: 0.8294 - val_accuracy: 0.7897
# Epoch 8/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.5132 - accuracy: 0.8591 - val_loss: 0.7325 - val_accuracy: 0.8117
# Epoch 9/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.4154 - accuracy: 0.8829 - val_loss: 0.9240 - val_accuracy: 0.7566
# Epoch 10/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.3480 - accuracy: 0.9015 - val_loss: 0.7608 - val_accuracy: 0.8295
# Epoch 11/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.3087 - accuracy: 0.9106 - val_loss: 1.0849 - val_accuracy: 0.7816
# Epoch 12/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.2654 - accuracy: 0.9242 - val_loss: 0.7744 - val_accuracy: 0.8434
# Epoch 13/30
# 243/243 [==============================] - 6s 24ms/step - loss: 0.2333 - accuracy: 0.9343 - val_loss: 0.5932 - val_accuracy: 0.8584
# Epoch 14/30
# 243/243 [==============================] - 6s 23ms/step - loss: 0.1955 - accuracy: 0.9434 - val_loss: 0.5987 - val_accuracy: 0.8684
# Epoch 15/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1737 - accuracy: 0.9485 - val_loss: 0.8029 - val_accuracy: 0.8534
# Epoch 16/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1488 - accuracy: 0.9552 - val_loss: 0.7506 - val_accuracy: 0.8553
# Epoch 17/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1360 - accuracy: 0.9599 - val_loss: 0.7758 - val_accuracy: 0.8557
# Epoch 18/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1297 - accuracy: 0.9612 - val_loss: 0.7669 - val_accuracy: 0.8673
#
# Addestrando con filtri [64, 128, 256, 512] e tasso di apprendimento 1e-05
# Epoch 1/30
# 243/243 [==============================] - 6s 22ms/step - loss: 3.3532 - accuracy: 0.0729 - val_loss: 3.2733 - val_accuracy: 0.1373
# Epoch 2/30
# 243/243 [==============================] - 5s 22ms/step - loss: 3.1687 - accuracy: 0.1456 - val_loss: 3.0096 - val_accuracy: 0.2419
# Epoch 3/30
# 243/243 [==============================] - 5s 22ms/step - loss: 2.9574 - accuracy: 0.2049 - val_loss: 2.7975 - val_accuracy: 0.3032
# Epoch 4/30
# 243/243 [==============================] - 5s 22ms/step - loss: 2.8076 - accuracy: 0.2460 - val_loss: 2.6622 - val_accuracy: 0.3430
# Epoch 5/30
# 243/243 [==============================] - 5s 22ms/step - loss: 2.6708 - accuracy: 0.2927 - val_loss: 2.5467 - val_accuracy: 0.3765
# Epoch 6/30
# 243/243 [==============================] - 5s 22ms/step - loss: 2.5612 - accuracy: 0.3196 - val_loss: 2.4528 - val_accuracy: 0.4147
# Epoch 7/30
# 243/243 [==============================] - 5s 22ms/step - loss: 2.4611 - accuracy: 0.3544 - val_loss: 2.3650 - val_accuracy: 0.4425
# Epoch 8/30
# 243/243 [==============================] - 5s 22ms/step - loss: 2.3613 - accuracy: 0.3911 - val_loss: 2.2825 - val_accuracy: 0.4626
# Epoch 9/30
# 243/243 [==============================] - 5s 22ms/step - loss: 2.2798 - accuracy: 0.4147 - val_loss: 2.2060 - val_accuracy: 0.4884
# Epoch 10/30
# 243/243 [==============================] - 5s 22ms/step - loss: 2.1818 - accuracy: 0.4492 - val_loss: 2.1274 - val_accuracy: 0.5062
# Epoch 11/30
# 243/243 [==============================] - 5s 22ms/step - loss: 2.0982 - accuracy: 0.4719 - val_loss: 2.0605 - val_accuracy: 0.5239
# Epoch 12/30
# 243/243 [==============================] - 5s 22ms/step - loss: 2.0017 - accuracy: 0.5048 - val_loss: 2.0001 - val_accuracy: 0.5378
# Epoch 13/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.9231 - accuracy: 0.5313 - val_loss: 1.9341 - val_accuracy: 0.5567
# Epoch 14/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.8531 - accuracy: 0.5443 - val_loss: 1.8716 - val_accuracy: 0.5779
# Epoch 15/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.7684 - accuracy: 0.5662 - val_loss: 1.8170 - val_accuracy: 0.5945
# Epoch 16/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.7260 - accuracy: 0.5829 - val_loss: 1.7599 - val_accuracy: 0.6092
# Epoch 17/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.6574 - accuracy: 0.6032 - val_loss: 1.7395 - val_accuracy: 0.6061
# Epoch 18/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.5927 - accuracy: 0.6140 - val_loss: 1.6827 - val_accuracy: 0.6235
# Epoch 19/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.5409 - accuracy: 0.6372 - val_loss: 1.6448 - val_accuracy: 0.6381
# Epoch 20/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.4834 - accuracy: 0.6509 - val_loss: 1.5938 - val_accuracy: 0.6505
# Epoch 21/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.3969 - accuracy: 0.6678 - val_loss: 1.5786 - val_accuracy: 0.6520
# Epoch 22/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.3664 - accuracy: 0.6816 - val_loss: 1.5394 - val_accuracy: 0.6644
# Epoch 23/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.3459 - accuracy: 0.6869 - val_loss: 1.5144 - val_accuracy: 0.6701
# Epoch 24/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.2990 - accuracy: 0.6995 - val_loss: 1.4761 - val_accuracy: 0.6875
# Epoch 25/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.2399 - accuracy: 0.7098 - val_loss: 1.4579 - val_accuracy: 0.6925
# Epoch 26/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.2068 - accuracy: 0.7179 - val_loss: 1.4310 - val_accuracy: 0.6944
# Epoch 27/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.1667 - accuracy: 0.7296 - val_loss: 1.4031 - val_accuracy: 0.7064
# Epoch 28/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.1269 - accuracy: 0.7394 - val_loss: 1.3831 - val_accuracy: 0.7072
# Epoch 29/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.0988 - accuracy: 0.7441 - val_loss: 1.3503 - val_accuracy: 0.7118
# Epoch 30/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.0565 - accuracy: 0.7544 - val_loss: 1.3341 - val_accuracy: 0.7211
#
# Tempo totale trascorso: 11 minuti e 10 secondi

# %% [markdown]
# Il tempo necessario per la ricerca dei migliori iperparametri è stata di quasi 13 minuti.

# %% [markdown]
# Grazie alla funzione `plot_models`, possiamo visualizzare l'accuratezza e la perdita di tutti i modelli che il tuner ha addestrato. Questa funzione adatta automaticamente il grafico al numero di modelli addestrati (in questo caso 9).

# %%
def plot_models(path, reverse=False, show="accuracy", overfit=True):
    n_models = len(os.listdir(path))
    # creo il subplot a seconda di quanti modelli dispongo
    best_pair = None
    min_diff = float("inf")
    
    for idx_model in range(1, int(np.sqrt(n_models)) + 1):
        if n_models % idx_model == 0:
            diff = abs(idx_model - n_models // idx_model)

            if diff < min_diff:
                min_diff = diff
                best_pair = (idx_model, n_models // idx_model)

    if reverse:
        rows = best_pair[1]
        cols = best_pair[0]
    else:
        rows = best_pair[0]
        cols = best_pair[1]
    
    fig, axes = plt.subplots(rows, cols, figsize=(14, 10))

    max_loss_value = 0
    
    for index, model in enumerate(os.listdir(path)):
        row = index // cols
        col = index % cols
    
        ax = axes[row][col]
        
        newpath = path + "/" + model
        df = pd.read_csv(newpath)

        value1 = df[show].values
        value2 = df["val_" + show].values
        
        ax.plot(range(1, len(value1) + 1), value1, color="slategray", label="Addestramento")
        ax.plot(range(1, len(value2) + 1), value2, color="indianred", label="Validazione")

        if show == "accuracy":
            ax.set_yticks(np.arange(0, 1.2, 0.2))
        elif max_loss_value < max(df[show].max(), df["val_" + show].max()):
            max_loss_value = max(df[show].max(), df["val_" + show].max())

        if (row in range(rows)) and col == 0:
            ax.set_ylabel("Accuratezza (%)" if show == "accuracy" else "Perdita", fontweight="semibold", fontsize=10)

        if (col in range(cols)) and row == 2:
            ax.set_xlabel("Epoche", fontweight="semibold", fontsize=10)

        ax.set_title("Filtro " + str(df["filters"][0]) + " & lr " + str(df["learning_rate"][0]), fontsize=12)
            
        ax.set_ylim(0)
        ax.set_xlim(0)

        ax.spines["left"].set_visible(False)
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)

        ax.grid(True, color="gainsboro", alpha=0.3, linestyle="--")

        handles, _ = ax.get_legend_handles_labels()
        
        if overfit and show == "loss":
            # area overfit
            
            rect = mpatches.Rectangle((np.argmin(value2) + 1, 0), width=len(value1) - np.argmin(value2), height=max(max(value1), max(value2)), color='lightcoral', alpha=0.3)
            ax.add_patch(rect)
            # patch overfit per legenda
            overfit = mpatches.Patch(color='lightcoral', alpha=0.3, label='Area overfit')
           
            handles.append(overfit)

        ax.legend(handles=handles)

    if show == "loss":
        for row in axes:
            for ax in row:
                ax.set_ylim(0, max_loss_value)

    plt.subplots_adjust(wspace=0.3, hspace=0.3)
    plt.show()

# %%
plot_models(path="model_tuning/rmsprop/spectrogram", show="accuracy")
plot_models(path="model_tuning/rmsprop/spectrogram", show="loss")

# %% [markdown]
# Dai grafici emerge che la combinazione più performante è composta da **32 filtri di partenza** e un **tasso di apprendimento di 1e-5**, poiché ritarda maggiormente l'overfitting. Altre combinazioni, come **64 filtri di partenza** e un **tasso di apprendimento di 1e-5**, mostrano buone prestazioni ma anche un inizio di overfitting, evidenziato dallo distaccamento tra la perdita di addestramento e quella di validazione.
#
# Procediamo quindi con l'addestramento del modello con **32 filtri di partenza** e un **tasso di apprendimento di 1e-5**. Come di consueto, salviamo i risultati in un file `keras` e la cronologia (history) in un file `csv`. Infine, convertiamo il file in formato `onnx`.

# %%
tuned_improved_basic_model = get_improved_basic_model()
tuned_improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-5), metrics=["accuracy"])

# %%
tuned_improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/spectrogram/tuned_improved_basic_model.keras", save_best_only=True, monitor="val_loss")]
tuned_improved_history = tuned_improved_basic_model.fit(train_ds, epochs=100, validation_data=val_ds, callbacks=tuned_improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 4s 13ms/step - loss: 3.3818 - accuracy: 0.0625 - val_loss: 3.3571 - val_accuracy: 0.0965
# Epoch 2/100
# 243/243 [==============================] - 3s 13ms/step - loss: 3.3243 - accuracy: 0.0915 - val_loss: 3.2770 - val_accuracy: 0.1238
# Epoch 3/100
# 243/243 [==============================] - 3s 12ms/step - loss: 3.2228 - accuracy: 0.1318 - val_loss: 3.1464 - val_accuracy: 0.1717
# Epoch 4/100
# 243/243 [==============================] - 3s 12ms/step - loss: 3.0964 - accuracy: 0.1619 - val_loss: 3.0000 - val_accuracy: 0.2307
# Epoch 5/100
# 243/243 [==============================] - 3s 12ms/step - loss: 2.9860 - accuracy: 0.1923 - val_loss: 2.8807 - val_accuracy: 0.2704
# Epoch 6/100
# 243/243 [==============================] - 3s 14ms/step - loss: 2.8957 - accuracy: 0.2251 - val_loss: 2.7939 - val_accuracy: 0.2951
# Epoch 7/100
# 243/243 [==============================] - 4s 14ms/step - loss: 2.8250 - accuracy: 0.2420 - val_loss: 2.7248 - val_accuracy: 0.3164
# Epoch 8/100
# 243/243 [==============================] - 4s 14ms/step - loss: 2.7489 - accuracy: 0.2613 - val_loss: 2.6572 - val_accuracy: 0.3476
# Epoch 9/100
# 243/243 [==============================] - 4s 15ms/step - loss: 2.6966 - accuracy: 0.2822 - val_loss: 2.6034 - val_accuracy: 0.3654
# Epoch 10/100
# 243/243 [==============================] - 3s 14ms/step - loss: 2.6267 - accuracy: 0.3001 - val_loss: 2.5547 - val_accuracy: 0.3804
# Epoch 11/100
# 243/243 [==============================] - 3s 14ms/step - loss: 2.5900 - accuracy: 0.3119 - val_loss: 2.5115 - val_accuracy: 0.3920
# Epoch 12/100
# 243/243 [==============================] - 3s 13ms/step - loss: 2.5292 - accuracy: 0.3295 - val_loss: 2.4651 - val_accuracy: 0.4059
# Epoch 13/100
# 243/243 [==============================] - 3s 13ms/step - loss: 2.4805 - accuracy: 0.3459 - val_loss: 2.4226 - val_accuracy: 0.4174
# Epoch 14/100
# 243/243 [==============================] - 3s 13ms/step - loss: 2.4287 - accuracy: 0.3702 - val_loss: 2.3738 - val_accuracy: 0.4321
# Epoch 15/100
# 243/243 [==============================] - 3s 13ms/step - loss: 2.3683 - accuracy: 0.3911 - val_loss: 2.3294 - val_accuracy: 0.4456
# Epoch 16/100
# 243/243 [==============================] - 3s 13ms/step - loss: 2.3265 - accuracy: 0.4021 - val_loss: 2.2894 - val_accuracy: 0.4537
# Epoch 17/100
# 243/243 [==============================] - 3s 14ms/step - loss: 2.2814 - accuracy: 0.4168 - val_loss: 2.2502 - val_accuracy: 0.4653
# Epoch 18/100
# 243/243 [==============================] - 3s 14ms/step - loss: 2.2307 - accuracy: 0.4244 - val_loss: 2.2012 - val_accuracy: 0.4865
# Epoch 19/100
# 243/243 [==============================] - 3s 13ms/step - loss: 2.1817 - accuracy: 0.4482 - val_loss: 2.1633 - val_accuracy: 0.4985
# Epoch 20/100
# 243/243 [==============================] - 3s 12ms/step - loss: 2.1413 - accuracy: 0.4571 - val_loss: 2.1251 - val_accuracy: 0.5015
# Epoch 21/100
# 243/243 [==============================] - 3s 12ms/step - loss: 2.0884 - accuracy: 0.4635 - val_loss: 2.0877 - val_accuracy: 0.5189
# Epoch 22/100
# 243/243 [==============================] - 3s 12ms/step - loss: 2.0538 - accuracy: 0.4862 - val_loss: 2.0486 - val_accuracy: 0.5282
# Epoch 23/100
# 243/243 [==============================] - 3s 13ms/step - loss: 2.0012 - accuracy: 0.4946 - val_loss: 2.0147 - val_accuracy: 0.5285
# Epoch 24/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.9753 - accuracy: 0.5048 - val_loss: 1.9819 - val_accuracy: 0.5421
# Epoch 25/100
# 243/243 [==============================] - 3s 14ms/step - loss: 1.9198 - accuracy: 0.5189 - val_loss: 1.9417 - val_accuracy: 0.5548
# Epoch 26/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.8795 - accuracy: 0.5318 - val_loss: 1.9167 - val_accuracy: 0.5571
# Epoch 27/100
# 243/243 [==============================] - 3s 12ms/step - loss: 1.8470 - accuracy: 0.5389 - val_loss: 1.8851 - val_accuracy: 0.5656
# Epoch 28/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.8086 - accuracy: 0.5526 - val_loss: 1.8506 - val_accuracy: 0.5760
# Epoch 29/100
# 243/243 [==============================] - 3s 12ms/step - loss: 1.7777 - accuracy: 0.5639 - val_loss: 1.8229 - val_accuracy: 0.5829
# Epoch 30/100
# 243/243 [==============================] - 4s 14ms/step - loss: 1.7355 - accuracy: 0.5805 - val_loss: 1.7942 - val_accuracy: 0.5941
# Epoch 31/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.7014 - accuracy: 0.5793 - val_loss: 1.7693 - val_accuracy: 0.6022
# Epoch 32/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.6697 - accuracy: 0.5918 - val_loss: 1.7427 - val_accuracy: 0.6069
# Epoch 33/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.6304 - accuracy: 0.6053 - val_loss: 1.7140 - val_accuracy: 0.6192
# Epoch 34/100
# 243/243 [==============================] - 3s 12ms/step - loss: 1.5844 - accuracy: 0.6135 - val_loss: 1.6913 - val_accuracy: 0.6192
# Epoch 35/100
# 243/243 [==============================] - 3s 12ms/step - loss: 1.5579 - accuracy: 0.6182 - val_loss: 1.6664 - val_accuracy: 0.6242
# Epoch 36/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.5288 - accuracy: 0.6312 - val_loss: 1.6410 - val_accuracy: 0.6335
# Epoch 37/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.4990 - accuracy: 0.6370 - val_loss: 1.6120 - val_accuracy: 0.6343
# Epoch 38/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.4747 - accuracy: 0.6415 - val_loss: 1.5977 - val_accuracy: 0.6400
# Epoch 39/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.4445 - accuracy: 0.6476 - val_loss: 1.5777 - val_accuracy: 0.6427
# Epoch 40/100
# 243/243 [==============================] - 4s 14ms/step - loss: 1.4129 - accuracy: 0.6599 - val_loss: 1.5611 - val_accuracy: 0.6474
# Epoch 41/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.3914 - accuracy: 0.6660 - val_loss: 1.5380 - val_accuracy: 0.6512
# Epoch 42/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.3617 - accuracy: 0.6749 - val_loss: 1.5190 - val_accuracy: 0.6532
# Epoch 43/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.3236 - accuracy: 0.6799 - val_loss: 1.4965 - val_accuracy: 0.6644
# Epoch 44/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.2961 - accuracy: 0.6887 - val_loss: 1.4846 - val_accuracy: 0.6686
# Epoch 45/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.2832 - accuracy: 0.6957 - val_loss: 1.4618 - val_accuracy: 0.6786
# Epoch 46/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.2555 - accuracy: 0.6947 - val_loss: 1.4425 - val_accuracy: 0.6794
# Epoch 47/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.2403 - accuracy: 0.7003 - val_loss: 1.4232 - val_accuracy: 0.6852
# Epoch 48/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.2169 - accuracy: 0.7055 - val_loss: 1.4111 - val_accuracy: 0.6883
# Epoch 49/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.1974 - accuracy: 0.7137 - val_loss: 1.3854 - val_accuracy: 0.6968
# Epoch 50/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.1681 - accuracy: 0.7204 - val_loss: 1.3805 - val_accuracy: 0.6944
# Epoch 51/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.1495 - accuracy: 0.7242 - val_loss: 1.3622 - val_accuracy: 0.6998
# Epoch 52/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.1280 - accuracy: 0.7259 - val_loss: 1.3540 - val_accuracy: 0.7029
# Epoch 53/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.1095 - accuracy: 0.7276 - val_loss: 1.3358 - val_accuracy: 0.7045
# Epoch 54/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.0838 - accuracy: 0.7348 - val_loss: 1.3374 - val_accuracy: 0.7076
# Epoch 55/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.0612 - accuracy: 0.7412 - val_loss: 1.3120 - val_accuracy: 0.7106
# Epoch 56/100
# 243/243 [==============================] - 3s 14ms/step - loss: 1.0418 - accuracy: 0.7478 - val_loss: 1.3000 - val_accuracy: 0.7137
# Epoch 57/100
# 243/243 [==============================] - 4s 14ms/step - loss: 1.0338 - accuracy: 0.7461 - val_loss: 1.2854 - val_accuracy: 0.7172
# Epoch 58/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.9999 - accuracy: 0.7580 - val_loss: 1.2727 - val_accuracy: 0.7257
# Epoch 59/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.9850 - accuracy: 0.7666 - val_loss: 1.2631 - val_accuracy: 0.7276
# Epoch 60/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.9785 - accuracy: 0.7606 - val_loss: 1.2557 - val_accuracy: 0.7269
# Epoch 61/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.9570 - accuracy: 0.7687 - val_loss: 1.2426 - val_accuracy: 0.7307
# Epoch 62/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.9292 - accuracy: 0.7756 - val_loss: 1.2450 - val_accuracy: 0.7326
# Epoch 63/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.9158 - accuracy: 0.7746 - val_loss: 1.2470 - val_accuracy: 0.7299
# Epoch 64/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.9014 - accuracy: 0.7787 - val_loss: 1.2274 - val_accuracy: 0.7311
# Epoch 65/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.8851 - accuracy: 0.7879 - val_loss: 1.1933 - val_accuracy: 0.7380
# Epoch 66/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.8692 - accuracy: 0.7890 - val_loss: 1.2003 - val_accuracy: 0.7404
# Epoch 67/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.8628 - accuracy: 0.7867 - val_loss: 1.1901 - val_accuracy: 0.7415
# Epoch 68/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.8571 - accuracy: 0.7934 - val_loss: 1.1863 - val_accuracy: 0.7458
# Epoch 69/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.8183 - accuracy: 0.7957 - val_loss: 1.1735 - val_accuracy: 0.7485
# Epoch 70/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.8291 - accuracy: 0.7987 - val_loss: 1.1720 - val_accuracy: 0.7454
# Epoch 71/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.8015 - accuracy: 0.8040 - val_loss: 1.1517 - val_accuracy: 0.7535
# Epoch 72/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.7988 - accuracy: 0.8050 - val_loss: 1.1511 - val_accuracy: 0.7550
# Epoch 73/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.7781 - accuracy: 0.8054 - val_loss: 1.1604 - val_accuracy: 0.7485
# Epoch 74/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.7713 - accuracy: 0.8068 - val_loss: 1.1330 - val_accuracy: 0.7527
# Epoch 75/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.7531 - accuracy: 0.8170 - val_loss: 1.1414 - val_accuracy: 0.7539
# Epoch 76/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.7386 - accuracy: 0.8166 - val_loss: 1.1321 - val_accuracy: 0.7647
# Epoch 77/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.7285 - accuracy: 0.8215 - val_loss: 1.1213 - val_accuracy: 0.7662
# Epoch 78/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.7168 - accuracy: 0.8198 - val_loss: 1.1082 - val_accuracy: 0.7596
# Epoch 79/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.7081 - accuracy: 0.8220 - val_loss: 1.1012 - val_accuracy: 0.7631
# Epoch 80/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.6974 - accuracy: 0.8222 - val_loss: 1.1073 - val_accuracy: 0.7623
# Epoch 81/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.6779 - accuracy: 0.8311 - val_loss: 1.0982 - val_accuracy: 0.7666
# Epoch 82/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.6724 - accuracy: 0.8289 - val_loss: 1.1005 - val_accuracy: 0.7685
# Epoch 83/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.6543 - accuracy: 0.8338 - val_loss: 1.0880 - val_accuracy: 0.7712
# Epoch 84/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.6463 - accuracy: 0.8380 - val_loss: 1.0891 - val_accuracy: 0.7704
# Epoch 85/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.6532 - accuracy: 0.8352 - val_loss: 1.0758 - val_accuracy: 0.7716
# Epoch 86/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.6327 - accuracy: 0.8402 - val_loss: 1.0808 - val_accuracy: 0.7728
# Epoch 87/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.6232 - accuracy: 0.8416 - val_loss: 1.0839 - val_accuracy: 0.7716
# Epoch 88/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.6003 - accuracy: 0.8433 - val_loss: 1.0697 - val_accuracy: 0.7805
# Epoch 89/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.6087 - accuracy: 0.8457 - val_loss: 1.0822 - val_accuracy: 0.7789
# Epoch 90/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5825 - accuracy: 0.8508 - val_loss: 1.0880 - val_accuracy: 0.7735
# Epoch 91/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.5966 - accuracy: 0.8485 - val_loss: 1.0432 - val_accuracy: 0.7816
# Epoch 92/100
# 243/243 [==============================] - 4s 14ms/step - loss: 0.5784 - accuracy: 0.8528 - val_loss: 1.0745 - val_accuracy: 0.7847
# Epoch 93/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.5745 - accuracy: 0.8519 - val_loss: 1.0572 - val_accuracy: 0.7809
# Epoch 94/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.5624 - accuracy: 0.8566 - val_loss: 1.0428 - val_accuracy: 0.7836
# Epoch 95/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.5505 - accuracy: 0.8595 - val_loss: 1.0420 - val_accuracy: 0.7855
# Epoch 96/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5588 - accuracy: 0.8561 - val_loss: 1.0358 - val_accuracy: 0.7863
# Epoch 97/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5436 - accuracy: 0.8599 - val_loss: 1.0407 - val_accuracy: 0.7863
# Epoch 98/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5233 - accuracy: 0.8606 - val_loss: 1.0479 - val_accuracy: 0.7863
# Epoch 99/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5288 - accuracy: 0.8635 - val_loss: 1.0683 - val_accuracy: 0.7878
# Epoch 100/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5189 - accuracy: 0.8619 - val_loss: 1.0530 - val_accuracy: 0.7867

# %%
tuned_improved_history_df = convert_history_to_csv(tuned_improved_history)
tuned_improved_history_df.to_csv("model_histories/rmsprop/spectrogram/tuned_improved_history.csv")

# %%
convert_model_to_onnx("bestmodels/rmsprop/spectrogram/tuned_improved_basic_model.keras", (124, 129, 1))

# %%
create_train_val_plot(tuned_improved_history.history)

# %%
tuned_improved_best_model = tf.keras.models.load_model("bestmodels/rmsprop/spectrogram/tuned_improved_basic_model.keras")
test_loss, test_acc = tuned_improved_best_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 10ms/step - loss: 1.1017 - accuracy: 0.7745
# Accuratezza: 0.775

# %%
evaluate_onnx_model("bestmodels/rmsprop/spectrogram/tuned_improved_basic_model.onnx", test_ds)
# Out:
# Accuratezza: 0.775

# %% [markdown]
# Il modello ha registrato prestazioni inferiori rispetto a prima, tuttavia è stato osservato un leggero ritardo nell'insorgere dell'overfitting. Inoltre, la perdita non è peggiorata tanto quanto in precedenza con l'avanzare delle epoche. L'accuratezza è attualmente **77.5%**.

# %%
for audio, label in test_ds:
    create_distribution_plot(tuned_improved_best_model, audio, label)
    break

# %% [markdown]
# ## Miglioramenti all'architettura del modello
#
# Durante il corso abbiamo visto anche delle best practice architetturali che possono aiutare a ottenere maggiori prestazioni col modello. Il nostro scopo è provare le tecniche viste e studiate durante il corso e capire come reagiscono al task.

# %% [markdown]
# Le tre tecniche che andremo ad applicare sono:
# - blocchi residuali
# - normalizzazione dei batch
# - convoluzioni separabili

# %% [markdown]
# ### Blocchi residuali
# I blocchi residuali sono un'applicazione efficace quando riscontriamo il problema dei **gradienti che svaniscono**. Non sono una tecnica strettamente legata ai modelli convolutivi, ma sono una best practice generale che viene applicare nella maggior parte delle architetture.
#
# I **gradienti che vaniscono** sono causati dalle **catene di funzioni troppo lunghe**, che nel nostro caso non sono altro che **una sequenza di livelli convolutivi**. Per ogni livello convolutivo **una certa quantità di rumore** viene introdotta, finché essa non arriva a **sopraffare** le informazioni sul gradiente.
#
# Se le informazioni sul gradiente sono sopraffatte la **backpropagation smette di funzionare**, e quindi il nostro **modello non impara**.

# %% [markdown]
# L'**idea basilare** dietro ai blocchi residuali è quella di **salvare l'informazione** contenuta nell'input precedente al livello convolutivo, e **sommarla all'output** dello stesso livello convolutivo.

# %% [markdown]
# Per applicare i blocchi residuali abbiamo implementato la funzione `residual_block(x, filters, pooling=False)` vista a lezione. La funzione è stata adattata al modello da noi implementato, e utilizza le altre due best practice citate precedentemente.

# %%
def residual_block(x, filters, pooling=False):
    residual = x

    x = tf.keras.layers.SeparableConv2D(filters, 3, padding="same", use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    if pooling:
      x = tf.keras.layers.MaxPooling2D(pool_size=2, padding="same")(x)
      residual = tf.keras.layers.Conv2D(filters, 1, strides=2)(residual)
    elif filters != residual.shape[-1]:
      residual = tf.keras.layers.Conv2D(filters, 1)(residual)

    x = tf.keras.layers.add([x, residual])
    return x

# %% [markdown]
# ### Normalizzazione dei batch e convoluzioni separabili
# La **normalizzazione dei batch** è un concetto che abbiamo già affrontato nel notebook, infatti il suo scopo rimane quello di rendere i dati **più simili tra loro** centrandoli sullo zero, e ciò aiuta la **propagazione del gradiente**. Questa normalizzazione, a differenza della precedente, è in grado di normalizzare i dati in modo adattivo anche quando la media e la varianza cambiano durante l'addestramento.

# %% [markdown]
# Le **convoluzione separabili** invece sono un **sostituto** ai livelli convolutivi utilizzati fino ad adesso, e offrono un modello con maggiori prestazioni e meno parametri.

# %%
def bp_basic_model():
    # input e pre processamento
    inputs = tf.keras.Input(shape=(124, 129, 1))
    
    x = residual_block(inputs, 32, pooling=True)
    x = residual_block(x, 64, pooling=True)
    x = residual_block(x, 128, pooling=True)
    x = residual_block(x, 256, pooling=True)
    x = residual_block(x, 256, pooling=False)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Livelli per la classificazione
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
bp_basic_model = bp_basic_model()
bp_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

bp_basic_model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_12 (InputLayer)          [(None, 124, 129, 1  0           []
#                                 )]
#
#  separable_conv2d (SeparableCon  (None, 124, 129, 32  41         ['input_12[0][0]']
#  v2D)                           )
#
#  batch_normalization (BatchNorm  (None, 124, 129, 32  128        ['separable_conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 124, 129, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d_44 (MaxPooling2D  (None, 62, 65, 32)  0           ['activation[0][0]']
#  )
#
#  conv2d_55 (Conv2D)             (None, 62, 65, 32)   64          ['input_12[0][0]']
#
#  add (Add)                      (None, 62, 65, 32)   0           ['max_pooling2d_44[0][0]',
#                                                                   'conv2d_55[0][0]']
#
#  separable_conv2d_1 (SeparableC  (None, 62, 65, 64)  2336        ['add[0][0]']
#  onv2D)
#
#  batch_normalization_1 (BatchNo  (None, 62, 65, 64)  256         ['separable_conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 62, 65, 64)   0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d_45 (MaxPooling2D  (None, 31, 33, 64)  0           ['activation_1[0][0]']
#  )
#
#  conv2d_56 (Conv2D)             (None, 31, 33, 64)   2112        ['add[0][0]']
#
#  add_1 (Add)                    (None, 31, 33, 64)   0           ['max_pooling2d_45[0][0]',
#                                                                   'conv2d_56[0][0]']
#
#  separable_conv2d_2 (SeparableC  (None, 31, 33, 128)  8768       ['add_1[0][0]']
#  onv2D)
#
#  batch_normalization_2 (BatchNo  (None, 31, 33, 128)  512        ['separable_conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 31, 33, 128)  0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_46 (MaxPooling2D  (None, 16, 17, 128)  0          ['activation_2[0][0]']
#  )
#
#  conv2d_57 (Conv2D)             (None, 16, 17, 128)  8320        ['add_1[0][0]']
#
#  add_2 (Add)                    (None, 16, 17, 128)  0           ['max_pooling2d_46[0][0]',
#                                                                   'conv2d_57[0][0]']
#
#  separable_conv2d_3 (SeparableC  (None, 16, 17, 256)  33920      ['add_2[0][0]']
#  onv2D)
#
#  batch_normalization_3 (BatchNo  (None, 16, 17, 256)  1024       ['separable_conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 16, 17, 256)  0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_47 (MaxPooling2D  (None, 8, 9, 256)   0           ['activation_3[0][0]']
#  )
#
#  conv2d_58 (Conv2D)             (None, 8, 9, 256)    33024       ['add_2[0][0]']
#
#  add_3 (Add)                    (None, 8, 9, 256)    0           ['max_pooling2d_47[0][0]',
#                                                                   'conv2d_58[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 8, 9, 256)   67840       ['add_3[0][0]']
#  onv2D)
#
#  batch_normalization_4 (BatchNo  (None, 8, 9, 256)   1024        ['separable_conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 8, 9, 256)    0           ['batch_normalization_4[0][0]']
#
#  add_4 (Add)                    (None, 8, 9, 256)    0           ['activation_4[0][0]',
#                                                                   'add_3[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['add_4[0][0]']
#  alAveragePooling2D)
#
#  dropout_11 (Dropout)           (None, 256)          0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_11 (Dense)               (None, 30)           7710        ['dropout_11[0][0]']
#
# ==================================================================================================
# Total params: 167,079
# Trainable params: 165,607
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %% [markdown]
# Le best practice, insieme al `tf.keras.layers.GlobalAveragePooling2D()` applicato al posto del Flatten, hanno formato un modello con circa **160000 parametri addestrabili** (circa il 12% del modello precedente).

# %%
bp_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/spectrogram/bp_basic_model.keras", save_best_only=True, monitor="val_loss")]
bp_model_history = bp_basic_model.fit(train_ds, epochs=100, validation_data=val_ds, callbacks=bp_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 7s 24ms/step - loss: 3.1960 - accuracy: 0.1205 - val_loss: 3.3259 - val_accuracy: 0.0671
# Epoch 2/100
# 243/243 [==============================] - 6s 23ms/step - loss: 2.6432 - accuracy: 0.2662 - val_loss: 3.0726 - val_accuracy: 0.1516
# Epoch 3/100
# 243/243 [==============================] - 7s 27ms/step - loss: 2.1508 - accuracy: 0.4137 - val_loss: 2.1016 - val_accuracy: 0.4221
# Epoch 4/100
# 243/243 [==============================] - 6s 25ms/step - loss: 1.6642 - accuracy: 0.5611 - val_loss: 2.3176 - val_accuracy: 0.3499
# Epoch 5/100
# 243/243 [==============================] - 6s 24ms/step - loss: 1.3099 - accuracy: 0.6546 - val_loss: 1.3855 - val_accuracy: 0.5833
# Epoch 6/100
# 243/243 [==============================] - 5s 22ms/step - loss: 1.0653 - accuracy: 0.7165 - val_loss: 1.0489 - val_accuracy: 0.7114
# Epoch 7/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.8944 - accuracy: 0.7634 - val_loss: 1.0266 - val_accuracy: 0.7176
# Epoch 8/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.7773 - accuracy: 0.7905 - val_loss: 1.5369 - val_accuracy: 0.5610
# Epoch 9/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.6971 - accuracy: 0.8104 - val_loss: 0.7567 - val_accuracy: 0.7921
# Epoch 10/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.6205 - accuracy: 0.8296 - val_loss: 0.8098 - val_accuracy: 0.7847
# Epoch 11/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.5567 - accuracy: 0.8482 - val_loss: 0.6585 - val_accuracy: 0.8206
# Epoch 12/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.5070 - accuracy: 0.8593 - val_loss: 0.6537 - val_accuracy: 0.8198
# Epoch 13/100
# 243/243 [==============================] - 6s 23ms/step - loss: 0.4659 - accuracy: 0.8710 - val_loss: 0.8262 - val_accuracy: 0.7677
# Epoch 14/100
# 243/243 [==============================] - 6s 23ms/step - loss: 0.4413 - accuracy: 0.8795 - val_loss: 0.6365 - val_accuracy: 0.8183
# Epoch 15/100
# 243/243 [==============================] - 6s 23ms/step - loss: 0.4068 - accuracy: 0.8866 - val_loss: 0.6832 - val_accuracy: 0.8048
# Epoch 16/100
# 243/243 [==============================] - 6s 23ms/step - loss: 0.3812 - accuracy: 0.8941 - val_loss: 0.7263 - val_accuracy: 0.8125
# Epoch 17/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.3649 - accuracy: 0.8976 - val_loss: 0.6181 - val_accuracy: 0.8410
# Epoch 18/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.3440 - accuracy: 0.9041 - val_loss: 0.8379 - val_accuracy: 0.7778
# Epoch 19/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.3216 - accuracy: 0.9111 - val_loss: 0.7119 - val_accuracy: 0.8005
# Epoch 20/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.3030 - accuracy: 0.9157 - val_loss: 0.7921 - val_accuracy: 0.7870
# Epoch 21/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.2800 - accuracy: 0.9223 - val_loss: 1.0888 - val_accuracy: 0.7477
# Epoch 22/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.2806 - accuracy: 0.9246 - val_loss: 0.6685 - val_accuracy: 0.8302
# Epoch 23/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.2560 - accuracy: 0.9293 - val_loss: 0.7408 - val_accuracy: 0.8079
# Epoch 24/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.2441 - accuracy: 0.9331 - val_loss: 0.7395 - val_accuracy: 0.8021
# Epoch 25/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.2337 - accuracy: 0.9360 - val_loss: 1.0027 - val_accuracy: 0.7735
# Epoch 26/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.2274 - accuracy: 0.9396 - val_loss: 0.4380 - val_accuracy: 0.8900
# Epoch 27/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.2223 - accuracy: 0.9384 - val_loss: 0.7318 - val_accuracy: 0.8167
# Epoch 28/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.2094 - accuracy: 0.9403 - val_loss: 0.8098 - val_accuracy: 0.8013
# Epoch 29/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.2057 - accuracy: 0.9423 - val_loss: 0.6370 - val_accuracy: 0.8353
# Epoch 30/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1999 - accuracy: 0.9457 - val_loss: 0.8217 - val_accuracy: 0.8071
# Epoch 31/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1908 - accuracy: 0.9504 - val_loss: 0.5836 - val_accuracy: 0.8422
# Epoch 32/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1879 - accuracy: 0.9473 - val_loss: 0.4350 - val_accuracy: 0.8900
# Epoch 33/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1747 - accuracy: 0.9512 - val_loss: 0.4705 - val_accuracy: 0.8765
# Epoch 34/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1886 - accuracy: 0.9474 - val_loss: 0.5321 - val_accuracy: 0.8684
# Epoch 35/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1620 - accuracy: 0.9553 - val_loss: 1.1563 - val_accuracy: 0.7589
# Epoch 36/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1666 - accuracy: 0.9534 - val_loss: 0.7949 - val_accuracy: 0.8106
# Epoch 37/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1631 - accuracy: 0.9548 - val_loss: 0.7411 - val_accuracy: 0.8245
# Epoch 38/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1673 - accuracy: 0.9524 - val_loss: 0.7065 - val_accuracy: 0.8399
# Epoch 39/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1557 - accuracy: 0.9601 - val_loss: 0.6010 - val_accuracy: 0.8515
# Epoch 40/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1443 - accuracy: 0.9610 - val_loss: 0.6941 - val_accuracy: 0.8430
# Epoch 41/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1448 - accuracy: 0.9601 - val_loss: 0.5800 - val_accuracy: 0.8727
# Epoch 42/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1476 - accuracy: 0.9576 - val_loss: 0.5819 - val_accuracy: 0.8484
# Epoch 43/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1388 - accuracy: 0.9637 - val_loss: 0.6668 - val_accuracy: 0.8380
# Epoch 44/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1372 - accuracy: 0.9656 - val_loss: 0.6067 - val_accuracy: 0.8495
# Epoch 45/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1313 - accuracy: 0.9644 - val_loss: 0.6349 - val_accuracy: 0.8573
# Epoch 46/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1323 - accuracy: 0.9633 - val_loss: 0.7441 - val_accuracy: 0.8530
# Epoch 47/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1272 - accuracy: 0.9649 - val_loss: 0.8047 - val_accuracy: 0.8337
# Epoch 48/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1222 - accuracy: 0.9682 - val_loss: 0.7834 - val_accuracy: 0.8113
# Epoch 49/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1355 - accuracy: 0.9633 - val_loss: 0.6288 - val_accuracy: 0.8669
# Epoch 50/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1197 - accuracy: 0.9668 - val_loss: 0.6882 - val_accuracy: 0.8445
# Epoch 51/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1197 - accuracy: 0.9679 - val_loss: 0.7454 - val_accuracy: 0.8283
# Epoch 52/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1151 - accuracy: 0.9700 - val_loss: 0.6297 - val_accuracy: 0.8600
# Epoch 53/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1180 - accuracy: 0.9675 - val_loss: 1.2938 - val_accuracy: 0.7527
# Epoch 54/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1131 - accuracy: 0.9697 - val_loss: 0.7131 - val_accuracy: 0.8414
# Epoch 55/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1122 - accuracy: 0.9709 - val_loss: 0.7251 - val_accuracy: 0.8356
# Epoch 56/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1131 - accuracy: 0.9695 - val_loss: 0.9409 - val_accuracy: 0.8229
# Epoch 57/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1074 - accuracy: 0.9714 - val_loss: 0.8275 - val_accuracy: 0.8137
# Epoch 58/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1137 - accuracy: 0.9702 - val_loss: 0.5935 - val_accuracy: 0.8573
# Epoch 59/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1061 - accuracy: 0.9718 - val_loss: 0.6104 - val_accuracy: 0.8557
# Epoch 60/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0984 - accuracy: 0.9732 - val_loss: 0.7464 - val_accuracy: 0.8426
# Epoch 61/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1016 - accuracy: 0.9729 - val_loss: 0.5527 - val_accuracy: 0.8796
# Epoch 62/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0998 - accuracy: 0.9742 - val_loss: 0.6044 - val_accuracy: 0.8688
# Epoch 63/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0998 - accuracy: 0.9737 - val_loss: 0.8392 - val_accuracy: 0.8194
# Epoch 64/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1025 - accuracy: 0.9749 - val_loss: 0.6919 - val_accuracy: 0.8538
# Epoch 65/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0952 - accuracy: 0.9745 - val_loss: 1.4098 - val_accuracy: 0.7550
# Epoch 66/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0964 - accuracy: 0.9733 - val_loss: 0.6565 - val_accuracy: 0.8484
# Epoch 67/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0892 - accuracy: 0.9765 - val_loss: 0.6800 - val_accuracy: 0.8499
# Epoch 68/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1032 - accuracy: 0.9746 - val_loss: 0.5869 - val_accuracy: 0.8816
# Epoch 69/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0986 - accuracy: 0.9733 - val_loss: 0.6811 - val_accuracy: 0.8561
# Epoch 70/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0878 - accuracy: 0.9765 - val_loss: 0.9796 - val_accuracy: 0.8071
# Epoch 71/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0950 - accuracy: 0.9751 - val_loss: 0.9952 - val_accuracy: 0.8009
# Epoch 72/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0863 - accuracy: 0.9769 - val_loss: 0.6921 - val_accuracy: 0.8638
# Epoch 73/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0896 - accuracy: 0.9751 - val_loss: 0.5268 - val_accuracy: 0.8792
# Epoch 74/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0908 - accuracy: 0.9742 - val_loss: 0.8969 - val_accuracy: 0.8449
# Epoch 75/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0847 - accuracy: 0.9765 - val_loss: 0.9146 - val_accuracy: 0.8183
# Epoch 76/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0895 - accuracy: 0.9784 - val_loss: 0.8340 - val_accuracy: 0.8407
# Epoch 77/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0928 - accuracy: 0.9759 - val_loss: 0.7269 - val_accuracy: 0.8600
# Epoch 78/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0847 - accuracy: 0.9769 - val_loss: 0.7535 - val_accuracy: 0.8438
# Epoch 79/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0909 - accuracy: 0.9759 - val_loss: 0.5713 - val_accuracy: 0.8696
# Epoch 80/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.0877 - accuracy: 0.9768 - val_loss: 0.6548 - val_accuracy: 0.8573
# Epoch 81/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0829 - accuracy: 0.9773 - val_loss: 0.6751 - val_accuracy: 0.8657
# Epoch 82/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0853 - accuracy: 0.9771 - val_loss: 0.5439 - val_accuracy: 0.8800
# Epoch 83/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0827 - accuracy: 0.9793 - val_loss: 0.7742 - val_accuracy: 0.8418
# Epoch 84/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0781 - accuracy: 0.9805 - val_loss: 0.6672 - val_accuracy: 0.8800
# Epoch 85/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.0821 - accuracy: 0.9778 - val_loss: 0.6982 - val_accuracy: 0.8526
# Epoch 86/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.0765 - accuracy: 0.9795 - val_loss: 0.5856 - val_accuracy: 0.8808
# Epoch 87/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.0838 - accuracy: 0.9786 - val_loss: 0.6212 - val_accuracy: 0.8781
# Epoch 88/100
# 243/243 [==============================] - 6s 24ms/step - loss: 0.0739 - accuracy: 0.9800 - val_loss: 0.7300 - val_accuracy: 0.8492
# Epoch 89/100
# 243/243 [==============================] - 6s 24ms/step - loss: 0.0702 - accuracy: 0.9802 - val_loss: 0.6901 - val_accuracy: 0.8557
# Epoch 90/100
# 243/243 [==============================] - 6s 24ms/step - loss: 0.0720 - accuracy: 0.9809 - val_loss: 1.0441 - val_accuracy: 0.7959
# Epoch 91/100
# 243/243 [==============================] - 6s 26ms/step - loss: 0.0751 - accuracy: 0.9790 - val_loss: 0.8542 - val_accuracy: 0.8368
# Epoch 92/100
# 243/243 [==============================] - 6s 24ms/step - loss: 0.0723 - accuracy: 0.9805 - val_loss: 0.7959 - val_accuracy: 0.8449
# Epoch 93/100
# 243/243 [==============================] - 6s 24ms/step - loss: 0.0729 - accuracy: 0.9800 - val_loss: 0.7192 - val_accuracy: 0.8549
# Epoch 94/100
# 243/243 [==============================] - 6s 26ms/step - loss: 0.0798 - accuracy: 0.9784 - val_loss: 0.8164 - val_accuracy: 0.8414
# Epoch 95/100
# 243/243 [==============================] - 6s 24ms/step - loss: 0.0688 - accuracy: 0.9814 - val_loss: 0.6438 - val_accuracy: 0.8777
# Epoch 96/100
# 243/243 [==============================] - 6s 24ms/step - loss: 0.0685 - accuracy: 0.9825 - val_loss: 0.5877 - val_accuracy: 0.8846
# Epoch 97/100
# 243/243 [==============================] - 6s 24ms/step - loss: 0.0696 - accuracy: 0.9811 - val_loss: 0.6087 - val_accuracy: 0.8846
# Epoch 98/100
# 243/243 [==============================] - 6s 24ms/step - loss: 0.0704 - accuracy: 0.9813 - val_loss: 0.6752 - val_accuracy: 0.8773
# Epoch 99/100
# 243/243 [==============================] - 6s 24ms/step - loss: 0.0701 - accuracy: 0.9802 - val_loss: 0.9841 - val_accuracy: 0.8013
# Epoch 100/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.0717 - accuracy: 0.9807 - val_loss: 0.7475 - val_accuracy: 0.8476

# %% [markdown]
# Salviamo nuovamente la history del modello in un file csv.

# %%
bp_model_history_df = convert_history_to_csv(bp_model_history)
bp_model_history_df.to_csv("model_histories/rmsprop/spectrogram/bp_model_history.csv")

# %% [markdown]
# Convertiamo anche il miglior modello nel formato **.onnx**.

# %%
convert_model_to_onnx("bestmodels/rmsprop/spectrogram/bp_basic_model.keras", (124, 129, 1))

# %%
create_train_val_plot(bp_model_history.history, overfit=False)

# %% [markdown]
# Possiamo notare che il modello **NON ha raggiunto una vera fase di overfitting**, ma la validazione non ha mostrato un incremento sostanziale all'aumentare delle epoche (probabilmente dovuto dalle tecniche di overfitting non totalmente implementate). La **loss della validazione** stava continuando a scendere, e allo stesso tempo **l'accuratezza della validazione era crescente**.

# %%
best_bp_basic_model = tf.keras.models.load_model("bestmodels/rmsprop/spectrogram/bp_basic_model.keras")
test_loss, test_acc = best_bp_basic_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 8ms/step - loss: 0.4368 - accuracy: 0.8907
# Accuratezza: 0.891

# %% [markdown]
# Verifichiamola anche con il modello **.onnx**.

# %%
evaluate_onnx_model("bestmodels/rmsprop/spectrogram/bp_basic_model.onnx", test_ds)
# Out:
# Accuratezza: 0.891

# %% [markdown]
# Abbiamo ottenuto un miglioramento per quanto riguarda l'accuratezza, ottenendo un **89.1%**. Ricordiamo che il modello ha poco meno del **12% dei parametri** rispetto al precedente, perciò il risultato è molto buono.

# %%
for audio, label in test_ds:
    create_distribution_plot(best_bp_basic_model, audio, label)
    break

# %% [markdown]
# La decisione del modello in questo caso è **sbagliata**, possiamo notare la sua indecisione tra tre classi differenti.
