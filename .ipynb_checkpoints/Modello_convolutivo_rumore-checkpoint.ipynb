# %% [markdown]
# # Modello convolutivo di base - Dataset rumore
# In precedenza abbiamo visto l'addestramento del nostro modello convolutivo di base sul dataset originale, e dopodiché abbiamo parlato della data augmentation.
#
# AGGIORNARE

# %% [markdown]
# Come al solito, implementiamo le librerie funzioni necessarie. Inoltre otteniamo il nuovo dataset attraverso le tecniche viste nel notebook relativo alla data augmentation.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd
import numpy as np
import random
import os
import time
# per il modello con estensione .onnx
import onnxruntime as rt
import tf2onnx
import onnx

# %% [markdown]
# ## Classe per la conversione del dataset
# Questa classe l'abbiamo già vista implementata nel notebook riguardante l'addestramento dei filterbanks e degli mfcc.

# %%
class DatasetConverter:
    def __init__(self, dataset):
        self.dataset = dataset

    def convert(self, option):
        available_options = ['spettrogrammi', 'filterbanks', 'mfcc']
        
        if option == available_options[0]:
            return self.get_spectrogram_dataset()
        elif option == available_options[1]:
            return self.get_filterbanks_dataset()
        elif option == available_options[2]:
            return self.get_mfcc_dataset()
        else:
            raise ValueError(f"Opzione non disponibile: inserire una delle seguenti opzioni: {available_options}")
    
    # INIZIO SPETTROGRAMMI
    def squeeze(self, audio, labels):
        audio = tf.squeeze(audio, axis=-1)
        return audio, labels
    
    def get_spectrogram(self, waveform):
    # applichiamo la short-time Fourier transorm
        spectrogram = tf.signal.stft(waveform, frame_length=255, frame_step=128)
        spectrogram = tf.abs(spectrogram)
        
        return spectrogram[..., tf.newaxis]
    
    def get_spectrogram_dataset(self):
        # squeeze
        self.dataset = self.dataset.map(self.squeeze, tf.data.AUTOTUNE)
        self.dataset = self.dataset.map(lambda x, y: (self.get_spectrogram(x), y), num_parallel_calls=tf.data.AUTOTUNE)
        
        return self.dataset

    # FINE SPETTROGRAMMI

    def convert_to_numpy(self, dataset):
        audio_data = []
        labels = []
    
        dataset = dataset.unbatch()
        
        for audio, label in dataset:
            audio_data.append(audio.numpy())  # Assuming audio is a tensor, convert to numpy array
            labels.append(label.numpy())      # Assuming label is a tensor, convert to numpy array
        
        audio_data = np.array(audio_data)
        labels = np.array(labels)
        
        return audio_data, labels
    
    # INIZIO FILTERBANKS
    def makeHamming(self, M):
        R = (( M - 1 ) / 2 , M / 2)[M % 2 == 0]
        w = (np.hamming(M), np.hamming(M + 1))[M % 2 == 0]
        if M % 2 != 0:
            w[0] = w[0]/2
            w[M-1] = w[M-1]/2
        else:
            w = w[:M]
    
        return w

    def hztomel(self, hz):
        return (2595 * np.log10(1 + hz / 700))

    def meltohz(self, mel):
        return (700 * (10**(mel / 2595) - 1))

    def compute_filterbanks(self, audios_np, pre_emphasis=0.97, sample_rate=16000, frame_size=0.025, frame_stride=0.01, NFFT=512, nfilt=40):
        filterbanks_np = []
        
        for samples in audios_np:
            emphasized_audio = np.append(samples[0], samples[1:] - pre_emphasis * samples[:-1])
            audio_length = len(emphasized_audio)
    
            frame_length, frame_step = int(frame_size * sample_rate), int(frame_stride * sample_rate)
    
            num_frames = int(np.ceil(float(np.abs(audio_length - frame_length)) / frame_step))
    
            pad_audio_length = num_frames * frame_step + frame_length
            z = np.zeros((pad_audio_length - audio_length))
            pad_audio = np.append(emphasized_audio, z)
    
            indices = np.tile(np.arange(0, frame_length), (num_frames, 1)) + np.tile(np.arange(0, num_frames * frame_step, frame_step), (frame_length, 1)).T
            frames = pad_audio[indices.astype(np.int32, copy=False)]
    
            # Usiamo la funzione di Hamming
            hamming_window = self.makeHamming(frame_length)
    
            mag_frames = np.absolute(np.fft.rfft(frames, NFFT))  # Magnitudo della FFT
            pow_frames = ((1.0 / NFFT) * ((mag_frames) ** 2))
    
            # convertiamo hz in mel
            low_freq_mel = self.hztomel(0)
            high_freq_mel = self.hztomel(sample_rate / 2)
    
            mel_points = np.linspace(low_freq_mel, high_freq_mel, nfilt + 2)
            hz_points = self.meltohz(mel_points) 
    
            bin = np.floor((NFFT + 1) * hz_points / sample_rate)
    
            fbank = np.zeros((nfilt, int(np.floor(NFFT / 2 + 1))))
    
            for m in range(1, nfilt + 1):
                f_m_minus = int(bin[m - 1])
                f_m = int(bin[m])
                f_m_plus = int(bin[m + 1])
    
                for k in range(f_m_minus, f_m):
                    fbank[m - 1, k] = (k - bin[m - 1]) / (bin[m] - bin[m - 1])
                for k in range(f_m, f_m_plus):
                    fbank[m - 1, k] = (bin[m + 1] - k) / (bin[m + 1] - bin[m])
    
            # in questo momento invece calcoliamo i filter banks per i segmenti di audio, utilizzando i filtri triangolari appena creati
            filter_banks = np.dot(pow_frames, fbank.T)
            filter_banks = np.where(filter_banks == 0, np.finfo(float).eps, filter_banks)
            filter_banks = 20 * np.log10(filter_banks)
    
            filterbanks_np.append(filter_banks)
        
        return np.array(filterbanks_np)
    
    def get_filterbanks_dataset(self): 
        audios, labels = self.convert_to_numpy(self.dataset)

        filterbanks = self.compute_filterbanks(audios)
        filterbanks = np.expand_dims(filterbanks, axis=-1)

        self.dataset = tf.data.Dataset.from_tensor_slices((filterbanks, labels))
        self.dataset = self.dataset.batch(32)
        
        return self.dataset
    # FINE FILTERBANKS

    # INIZIO MFCC
    def compute_mfcc(self, filter_banks, num_ceps=12, cep_lifter=22):
        mfcc_np = []
        
        for f in filter_banks:
            mfcc = scipy.dct(f, type=2, axis=1, norm='ortho')[:, 1 : (num_ceps + 1)]

            (nframes, ncoeff) = mfcc.shape
            n = np.arange(ncoeff)
            
            lift = 1 + (cep_lifter / 2) * np.sin(np.pi * n / cep_lifter)
            mfcc *= lift

            mfcc_np.append(mfcc)
        
        return np.array(mfcc_np)
    
    
    def get_mfcc_dataset(self):
        audios, labels = self.convert_to_numpy(self.dataset)

        filterbanks = self.compute_filterbanks(audios)
        mfcc = self.compute_mfcc(filterbanks)
        
        mfcc = np.expand_dims(mfcc, axis=-1)
        
        self.dataset = tf.data.Dataset.from_tensor_slices((mfcc, labels))
        self.dataset = self.dataset.batch(32)
        
        return self.dataset
    
    # FINE MFCC

# %% [markdown]
# ## Importazione funzioni ulteriori
# In aggiunta alla classe per la conversione del dataset, ci serviremo delle seguenti funzioni:
# - `convert_history_to_csv` - salva l'history dell'addestramento in un csv
# - `convert_model_to_onnx` - converte il miglior modello **.keras** in **.onnx**
# - `create_train_val_plot` - visualizza l'andamento dell'accuratezza e della perdita durante l'addestramento
# - `evaluate_onnx_model` - valuta il modello sui dati di test con il modello **.onnx**
# - `create_distribution_plot` - visualizza la distribuzione di accuratezza delle classi su un'immagine casuale
#
# Anch'esse sono già state viste, perciò non ci soffermeremo troppo su di esse.

# %%
def convert_history_to_csv(model_history):
    # converto la history del dataframe in un dataframe pandas
    model_history_df = pd.DataFrame(model_history.history)
    # cambio il nome dell'indice e lo imposto a partire da 1
    model_history_df.index = range(1, len(model_history_df) + 1)
    model_history_df.index.name = "epochs"

    return model_history_df

def convert_model_to_onnx(model_path, input_shape):
    model = tf.keras.models.load_model(model_path)

    onnx_path = model_path.split(".")[:-1] + ["onnx"]
    onnx_path = ".".join(onnx_path)
    
    input_signature = [tf.TensorSpec((None, *input_shape), tf.float32, name="input")]
    onnx_model, _ = tf2onnx.convert.from_keras(model, input_signature=input_signature)

    onnx.save(onnx_model, onnx_path)

def create_train_val_plot(history, overfit=True):
    # definisco numero epoche
    epochs = range(1, len(history['accuracy']) + 1)

    # Accuracy
    accuracy = history['accuracy']
    val_accuracy = history['val_accuracy']

    fig_acc, ax_acc = plt.subplots()

    # linea di base
    ax_acc.plot(epochs, [0.5 for x in range(len(epochs))], color="lightgray", linestyle="--", label="Base")
    # linee di accuratezza
    ax_acc.plot(epochs, accuracy, color="slategray", label="Accuratezza in addestramento")
    ax_acc.plot(epochs, val_accuracy, color="indianred", label="Accuratezza in validazione")
    # miglior accuratezza validazione
    ax_acc.axhline(y=max(val_accuracy), c='indianred', alpha=0.7, linestyle='--')
    ax_acc.text(len(epochs) * 1.07, max(val_accuracy), round(max(val_accuracy), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_acc.spines["right"].set_visible(False)
    ax_acc.spines["top"].set_visible(False)
    ax_acc.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_acc.set_title("Accuratezza in addestramento e validazione")
    ax_acc.set_xlabel("Epoche")
    ax_acc.set_ylabel("Accuratezza (%)")
    ax_acc.legend()

    # Loss
    loss = history['loss']
    val_loss = history['val_loss']

    fig_loss, ax_loss = plt.subplots()

    # linee di loss
    ax_loss.plot(epochs, loss, color="slategray", label="Perdita in addestramento")
    ax_loss.plot(epochs, val_loss, color="indianred", label="Perdita in validazione")
    # miglior loss validazione
    ax_loss.axhline(y=min(val_loss), c='indianred', alpha=0.7, linestyle='--')
    ax_loss.text(len(epochs) * 1.07, min(val_loss), round(min(val_loss), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_loss.spines["right"].set_visible(False)
    ax_loss.spines["top"].set_visible(False)
    ax_loss.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_loss.set_title("Perdita in addestramento e validazione")
    ax_loss.set_xlabel("Epoche")
    ax_loss.set_ylabel("Perdita")

    handles, _ = ax_loss.get_legend_handles_labels()

    if overfit:
        # area overfit
        rect = mpatches.Rectangle((np.argmin(val_loss) + 1, 0), width=100 - np.argmin(val_loss), height=max(max(loss), max(val_loss)), color='lightcoral', alpha=0.3)
        ax_loss.add_patch(rect)
        # patch overfit per legenda
        overfit = mpatches.Patch(color='indianred', alpha=0.3, label='Area overfit')
        handles, _ = ax_loss.get_legend_handles_labels()
        handles.append(overfit)

    # legenda
    ax_loss.legend(handles=handles)

    plt.show()

def evaluate_onnx_model(path_model_onnx, test_ds):
    # il fatto che sia suddiviso in batch mi crea problemi, perciò lo risolvo togliendoli
    test_ds = test_ds.unbatch()
    
    # carico il modello utilizzando il file onnx
    m = rt.InferenceSession(path_model_onnx)
    
    # trasformo il dataset in array numpy
    spectrogram_np = np.array([spectrogram.numpy() for spectrogram, _ in test_ds], dtype=np.float32)
    labels_np = np.array([label.numpy() for _, label in test_ds])
    
    # eseguo le predizione del modello
    pred_onnx = m.run(None, {'input': spectrogram_np})
    # ottengo la predizione corretta
    predictions = np.argmax(pred_onnx[0], axis=1)
    # computo la accuratezza
    accuracy = np.mean(predictions == labels_np)
    # stampo l'accuratezza
    print(f"Accuratezza: {accuracy:.3f}")

def create_distribution_plot(model, audio, label):
    label_names = audio_label_names
    
    prediction = model(audio) # otteniamo la predizione del modello sull'audio preso in input

    random_audio_index = np.random.randint(0, len(prediction) - 1) # abbiamo notato che mostravamo sempre la classe no, magari così cambia un po' le classi che mostriamo

    softmax_pred = tf.nn.softmax(prediction[random_audio_index]) # dobbiamo applicare nuovamente la softmax in modo tale da avere dei dati leggibili
    pred_label = np.argmax(softmax_pred) # ci salviamo l'indice della label predetta dal nostro modello, quella con la probabilità più alta

    colors = ['indianred'] * len(label_names) # creiamo un vettore di lunghezza 30 (la quantità delle nostre label) colorate di rosso

    if pred_label == label[random_audio_index].numpy(): # se la label che abbiamo predetto è corretta, allora la coloriamo di verde
        colors[pred_label] = 'seagreen'
    else: # se la label che abbiamo predetto è sbagliata, allora coloriamo di verde la corretta e di gialla la predetta
        colors[pred_label] = 'khaki'
        colors[label[random_audio_index].numpy()] = 'seagreen'

    plt.figure(figsize=(12, 4))
    
    plt.bar(label_names, softmax_pred.numpy(), color=colors)
    plt.xticks(rotation=45)

    # dichiariamo i colori della legenda
    other_values_patch = mpatches.Patch(color='indianred', label='Altre classi')
    pred_value_patch = mpatches.Patch(color='khaki', label='Classe predetta')
    correct_value_patch = mpatches.Patch(color='green', label='Classe corretta')

    # disegniamo la legenda con i colori necessari
    if pred_label == label[random_audio_index].numpy(): # se abbiamo predetto correttamente la label, non è necessario mostrare il colore giallo (non è presente nel plot)
        plt.legend(handles=[other_values_patch, correct_value_patch])
    else:
        plt.legend(handles=[other_values_patch, pred_value_patch, correct_value_patch])

    plt.show()

# %%
train_ds, validation_ds = tf.keras.utils.audio_dataset_from_directory(
    directory ='../reduced_dataset/dataset/audio',
    validation_split=0.4, # stiamo mettendo da parte il 40% del dataset, che sarà suddiviso in validation set e test set
    shuffle=True,
    subset='both', # necessario se stiamo utilizzando validation_split
    seed=0 # necessario se stiamo utilizzando sia shuffle che validation_split 
)
audio_label_names = train_ds.class_names

noise_ds = tf.keras.utils.audio_dataset_from_directory(
    directory='../noise_dataset',
    batch_size = 1
)

noise_label_names = noise_ds.class_names
# Out:
# Found 12933 files belonging to 30 classes.
# Using 7760 files for training.
# Using 5173 files for validation.
# Found 14 files belonging to 14 classes.

# %% [markdown]
# ## Applicazione tecniche data augmentation
# Abbiamo già visto l'utilizzo delle tecniche che andremo a applicare in questo momento, perciò non ci soffermeremo sulla loro spiegazione ma descriveremo i passaggi molto sinteticamnete.

# %% [markdown]
# Tagliamo gli audio del dataset rumoroso.

# %%
def cut_audios(dataset, length):
    new_audios = [] # inizializziamo una lista dove inseriremo i nostri audio tagliati
    labels = []
    
    # iteriamo nel dataset
    for audio, label in dataset:
        # tagliamo l'audio ad un secondo e lo appendiamo a una lista 
        labels.append(label.numpy())
        
        audio = tf.reshape(audio, [-1])[np.shape(audio)[1]//2:np.shape(audio)[1]//2 + length]
        new_audios.append(audio.numpy()) # convertiamo in array per poterli modificare
        
    return new_audios, labels

cut_noise_audios, cut_noise_labels = cut_audios(noise_ds, 16000)

# %% [markdown]
# Creiamo il nuovo dataset, unendo l'originale con quello rumoroso. L'output che otteneremo è una lista.

# %%
def mix_audios(original_audios, noise_audios):
    mixed_dataset = [] # inizializziamo la lista dove inseriremo gli audio uniti al rumore

    original_audios = original_audios.unbatch() # il nostro training set ha una batch_size di 32, per rendere il processo più semplice unbatchiamo
    
    # per ogni audio del dataset originale
    for audio, label in original_audios:    
        audio = np.squeeze(audio, axis=-1) # rimuoviamo l'ultima asse inutile (quella dei canali)
        
        # Scegliamo in modo randomico un audio dalla lista degli audio rumorosi
        noise_sample = random.choice(noise_audios)

        # calcolo l'ampiezza massima dell'audio rumoroso
        max_amplitude_audio = np.max(np.abs(audio))
        max_amplitude_noise = np.max(np.abs(noise_sample))
        # calcolo un noise factor che varia a seconda dell'ampiezza massima di entrambi gli audio
        noise_factor = max_amplitude_audio / max_amplitude_noise
        noise_factor = min(noise_factor, 1.0)
        
        noise_sample = noise_sample * noise_factor
        
        mixed_audio = audio + noise_sample # uniamo l'audio original al rumore

        # aggiungiamo l'audio con noise alla lista
        mixed_dataset.append((mixed_audio, label))

    return mixed_dataset

mixed_train_list = mix_audios(train_ds, cut_noise_audios)
mixed_val_list = mix_audios(validation_ds, cut_noise_audios)

# %% [markdown]
# Convertiamo la lista in un dataset di tensori.

# %%
def create_mixed_ds(dataset_list):
    audio_data = [tf.convert_to_tensor(audio, dtype=tf.float32) for audio, label in dataset_list]
    labels = [label for _, label in dataset_list]

    audio_data = tf.expand_dims(audio_data, axis=-1)
    
    mixed_train_ds = tf.data.Dataset.from_tensor_slices((audio_data, labels))
    mixed_train_ds = mixed_train_ds.batch(32)
    return mixed_train_ds

mixed_train_ds = create_mixed_ds(mixed_train_list)
mixed_validation_ds = create_mixed_ds(mixed_val_list)

# %% [markdown]
# ## Suddivisione dataset
# Ottenuto il dataset rumoroso possiamo procedere a convertirlo e suddividerlo.

# %%
mixed_train_ds = DatasetConverter(mixed_train_ds)
mixed_train_ds = mixed_train_ds.convert("spettrogrammi")

mixed_validation_ds = DatasetConverter(mixed_validation_ds)
mixed_validation_ds = mixed_validation_ds.convert("spettrogrammi")

mixed_val_ds = mixed_validation_ds.take(mixed_validation_ds.cardinality() // 2) # ho cambiato nome del validation_ds in modo tale da non creare problemi con l'istruzione seguente
mixed_test_ds = mixed_validation_ds.skip(mixed_validation_ds.cardinality() // 2)

# %% [markdown]
# Adesso siamo pronti per addestrare i modelli su un dataset rumoroso.

# %% [markdown]
# ## Addestramento
# Come già detto, le reti neurali convolutive che andremo a trattare sono le stesse presenti nel notebook del modello convolutivo base. Stiamo addestrando gli stessi modelli in modo da poter confrontare le loro prestazioni in un notebook a parte.
#
# Iniziamo con il primo modello base.

# %%
def get_basic_model():
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(124, 129, 1), name="inputs")
    x = tf.keras.layers.Normalization(name="normalizzazione")(inputs)

    # Blocco di apprendimento delle caratteristiche
    conv2D_1 = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same", name="conv2D_1")(x)
    MaxPooling2D_1 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_1")(conv2D_1)
    conv2D_2 = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same", name="conv2D_2")(MaxPooling2D_1)
    MaxPooling2D_2 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_2")(conv2D_2)
    conv2D_3 = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same", name="conv2D_3")(MaxPooling2D_2)
    MaxPooling2D_3 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_3")(conv2D_3)
    conv2D_4 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_4")(MaxPooling2D_3)
    MaxPooling2D_4 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_4")(conv2D_4)
    conv2D_5 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_5")(MaxPooling2D_4)

    # Blocco di classificazione
    Flatten = tf.keras.layers.Flatten(name="Flatten")(conv2D_5)
    outputs = tf.keras.layers.Dense(30, activation="softmax", name="dense_output")(Flatten)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
basic_model = get_basic_model()
basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/noise/rmsprop/basic_model.keras", save_best_only=True, monitor="val_loss")]
basic_model_history = basic_model.fit(mixed_train_ds, epochs=30, validation_data=mixed_val_ds, callbacks=basic_model_callbacks)
# Out:
# Epoch 1/30
# 243/243 [==============================] - 6s 12ms/step - loss: 2.9934 - accuracy: 0.1598 - val_loss: 2.6077 - val_accuracy: 0.2755
# Epoch 2/30
# 243/243 [==============================] - 3s 10ms/step - loss: 1.9266 - accuracy: 0.4508 - val_loss: 1.6388 - val_accuracy: 0.5243
# Epoch 3/30
# 243/243 [==============================] - 3s 10ms/step - loss: 1.1676 - accuracy: 0.6559 - val_loss: 1.3985 - val_accuracy: 0.5976
# Epoch 4/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.7750 - accuracy: 0.7684 - val_loss: 1.2674 - val_accuracy: 0.6389
# Epoch 5/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.5540 - accuracy: 0.8378 - val_loss: 1.3004 - val_accuracy: 0.6929
# Epoch 6/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.3902 - accuracy: 0.8799 - val_loss: 1.6953 - val_accuracy: 0.6701
# Epoch 7/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2980 - accuracy: 0.9115 - val_loss: 1.6892 - val_accuracy: 0.7438
# Epoch 8/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2507 - accuracy: 0.9269 - val_loss: 1.7401 - val_accuracy: 0.7350
# Epoch 9/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2193 - accuracy: 0.9357 - val_loss: 1.7254 - val_accuracy: 0.7218
# Epoch 10/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2018 - accuracy: 0.9430 - val_loss: 2.1639 - val_accuracy: 0.7303
# Epoch 11/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1743 - accuracy: 0.9506 - val_loss: 1.7227 - val_accuracy: 0.7427
# Epoch 12/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1569 - accuracy: 0.9581 - val_loss: 2.1138 - val_accuracy: 0.7469
# Epoch 13/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1512 - accuracy: 0.9588 - val_loss: 2.6374 - val_accuracy: 0.7299
# Epoch 14/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1512 - accuracy: 0.9604 - val_loss: 2.9611 - val_accuracy: 0.7215
# Epoch 15/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1618 - accuracy: 0.9634 - val_loss: 2.1217 - val_accuracy: 0.7311
# Epoch 16/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1360 - accuracy: 0.9679 - val_loss: 2.3446 - val_accuracy: 0.7450
# Epoch 17/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1176 - accuracy: 0.9682 - val_loss: 3.2498 - val_accuracy: 0.7365
# Epoch 18/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1328 - accuracy: 0.9689 - val_loss: 2.9400 - val_accuracy: 0.7508
# Epoch 19/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1314 - accuracy: 0.9687 - val_loss: 2.8126 - val_accuracy: 0.7492
# Epoch 20/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1281 - accuracy: 0.9705 - val_loss: 2.6530 - val_accuracy: 0.7438
# Epoch 21/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1289 - accuracy: 0.9733 - val_loss: 2.6043 - val_accuracy: 0.7535
# Epoch 22/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1340 - accuracy: 0.9709 - val_loss: 3.6528 - val_accuracy: 0.7045
# Epoch 23/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1122 - accuracy: 0.9728 - val_loss: 3.4371 - val_accuracy: 0.7504
# Epoch 24/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1338 - accuracy: 0.9745 - val_loss: 4.3595 - val_accuracy: 0.7130
# Epoch 25/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1351 - accuracy: 0.9728 - val_loss: 3.3603 - val_accuracy: 0.7380
# Epoch 26/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1301 - accuracy: 0.9737 - val_loss: 4.2269 - val_accuracy: 0.7303
# Epoch 27/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1325 - accuracy: 0.9772 - val_loss: 5.7758 - val_accuracy: 0.7068
# Epoch 28/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1252 - accuracy: 0.9742 - val_loss: 3.9577 - val_accuracy: 0.7272
# Epoch 29/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1290 - accuracy: 0.9747 - val_loss: 4.2539 - val_accuracy: 0.7346
# Epoch 30/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1185 - accuracy: 0.9772 - val_loss: 4.4356 - val_accuracy: 0.7380

# %% [markdown]
# Salviamo i dati della history del modello in un file csv

# %%
basic_model_history_df = convert_history_to_csv(basic_model_history)
basic_model_history_df.to_csv("model_histories/noise/rmsprop/basic_model_history.csv")

# %% [markdown]
# Salviamo il miglior modello come file csv nella seguente directory `model_histories/noise/rmsprop/` con il nome `basic_model_history`. Inoltre, per prevenire errori di salvataggio causati da versioni differenti di python o dei pacchetti, procediamo con la conversione del file in formato standard `.onnx`.

# %%
convert_model_to_onnx("bestmodels/noise/rmsprop/basic_model.keras", (124, 129, 1))

# %% [markdown]
# Utilizziamo la funzione `create_train_val_plot` per mostrare l'andamento dell'accurateza e della perdita durante l'addestramento.

# %%
create_train_val_plot(basic_model_history.history)

# %% [markdown]
# Questi grafici mostrano come il nostro modello sia andato immediatamente in overfitting. L'accuratezza dell'addestramento aumenta col tempo e raggiunge quasi il **100%**, mentre l'accuratezza della validazione si attesta sull'**75%**. La **perdita nel set di addestramento** continua a diminuire dopo la **quinta epoca**, mentre la **perdita nel set di validazione** aumenta.
#
# Non siamo riusciti a raggiungere una buona accuratezza nella validazione.
# ### CAPIAMO IL PERCHE'

# %% [markdown]
# Possiamo verificare l'accuratezza della migliore versione del nostro modello di base ricaricando il file **basic_model.keras**

# %%
best_basic_model = tf.keras.models.load_model("bestmodels/noise/rmsprop/basic_model.keras")
test_loss, test_acc = best_basic_model.evaluate(mixed_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 5ms/step - loss: 1.3221 - accuracy: 0.6366
# Accuratezza: 0.637

# %%
evaluate_onnx_model("bestmodels/noise/rmsprop/basic_model.onnx", mixed_test_ds)
# Out:
# Accuratezza: 0.637

# %% [markdown]
# Abbiamo ottenuto un'**accuratezza** del **63.7%**, possiamo già notare un peggioramento notevole. Visualizziamo la distribuzione di accuratezza delle classi su un'immagine casuale.

# %%
for audio, label in mixed_test_ds: # prendiamo un audio a caso del test e creiamo la distribuzione
    create_distribution_plot(best_basic_model, audio, label)
    break

# %% [markdown]
# ### Risoluzione dell'overfitting
# Il modello è andato immediatamente in **overfitting**, e lo possiamo notare dalla loss di validazione che inizia a salire dalla quinta epoca in poi. Cercheremo di ritardarla leggermente seguendo le stesse procedure del notebook di riferimento.

# %%
def get_improved_basic_model():
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(124, 129, 1))
    x = tf.keras.layers.Normalization()(inputs)

    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
improved_basic_model = get_improved_basic_model()
improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

# %%
improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/noise/rmsprop/improved_basic_model.keras", save_best_only=True, monitor="val_loss")]
improved_history = improved_basic_model.fit(mixed_train_ds, epochs=100, validation_data=mixed_val_ds, callbacks=improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 3s 11ms/step - loss: 3.0145 - accuracy: 0.1518 - val_loss: 2.6400 - val_accuracy: 0.2751
# Epoch 2/100
# 243/243 [==============================] - 3s 11ms/step - loss: 2.0271 - accuracy: 0.4116 - val_loss: 1.7132 - val_accuracy: 0.5100
# Epoch 3/100
# 243/243 [==============================] - 3s 10ms/step - loss: 1.3735 - accuracy: 0.6021 - val_loss: 1.4666 - val_accuracy: 0.6034
# Epoch 4/100
# 243/243 [==============================] - 3s 10ms/step - loss: 1.0042 - accuracy: 0.7004 - val_loss: 1.2374 - val_accuracy: 0.6775
# Epoch 5/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.7602 - accuracy: 0.7758 - val_loss: 1.1048 - val_accuracy: 0.7022
# Epoch 6/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.6111 - accuracy: 0.8137 - val_loss: 1.1703 - val_accuracy: 0.6863
# Epoch 7/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.5022 - accuracy: 0.8479 - val_loss: 1.2141 - val_accuracy: 0.7230
# Epoch 8/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.4123 - accuracy: 0.8705 - val_loss: 1.3858 - val_accuracy: 0.7064
# Epoch 9/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.3712 - accuracy: 0.8894 - val_loss: 1.2062 - val_accuracy: 0.7461
# Epoch 10/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.3381 - accuracy: 0.8990 - val_loss: 1.2472 - val_accuracy: 0.7326
# Epoch 11/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2829 - accuracy: 0.9165 - val_loss: 1.3937 - val_accuracy: 0.7384
# Epoch 12/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2566 - accuracy: 0.9231 - val_loss: 1.3504 - val_accuracy: 0.7573
# Epoch 13/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2551 - accuracy: 0.9255 - val_loss: 1.5920 - val_accuracy: 0.7562
# Epoch 14/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2234 - accuracy: 0.9336 - val_loss: 1.5432 - val_accuracy: 0.7708
# Epoch 15/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2303 - accuracy: 0.9303 - val_loss: 1.4830 - val_accuracy: 0.7589
# Epoch 16/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2105 - accuracy: 0.9411 - val_loss: 1.4961 - val_accuracy: 0.7465
# Epoch 17/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2181 - accuracy: 0.9410 - val_loss: 1.8032 - val_accuracy: 0.7600
# Epoch 18/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1856 - accuracy: 0.9494 - val_loss: 1.8610 - val_accuracy: 0.7585
# Epoch 19/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1920 - accuracy: 0.9485 - val_loss: 1.9629 - val_accuracy: 0.7419
# Epoch 20/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1928 - accuracy: 0.9485 - val_loss: 1.9939 - val_accuracy: 0.7369
# Epoch 21/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1936 - accuracy: 0.9518 - val_loss: 2.1673 - val_accuracy: 0.7596
# Epoch 22/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1780 - accuracy: 0.9514 - val_loss: 1.7350 - val_accuracy: 0.7477
# Epoch 23/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1799 - accuracy: 0.9548 - val_loss: 2.0162 - val_accuracy: 0.7654
# Epoch 24/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2124 - accuracy: 0.9504 - val_loss: 1.7169 - val_accuracy: 0.7627
# Epoch 25/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1929 - accuracy: 0.9537 - val_loss: 2.3759 - val_accuracy: 0.7566
# Epoch 26/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1632 - accuracy: 0.9580 - val_loss: 2.5373 - val_accuracy: 0.7461
# Epoch 27/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1706 - accuracy: 0.9617 - val_loss: 2.9750 - val_accuracy: 0.7407
# Epoch 28/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1921 - accuracy: 0.9580 - val_loss: 2.1398 - val_accuracy: 0.7693
# Epoch 29/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1761 - accuracy: 0.9590 - val_loss: 2.2904 - val_accuracy: 0.7596
# Epoch 30/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1946 - accuracy: 0.9588 - val_loss: 2.6176 - val_accuracy: 0.7485
# Epoch 31/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1884 - accuracy: 0.9601 - val_loss: 2.9062 - val_accuracy: 0.7508
# Epoch 32/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1966 - accuracy: 0.9571 - val_loss: 2.8525 - val_accuracy: 0.7477
# Epoch 33/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1837 - accuracy: 0.9617 - val_loss: 2.6219 - val_accuracy: 0.7542
# Epoch 34/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2014 - accuracy: 0.9585 - val_loss: 2.3850 - val_accuracy: 0.7728
# Epoch 35/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1827 - accuracy: 0.9606 - val_loss: 2.4246 - val_accuracy: 0.7697
# Epoch 36/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1790 - accuracy: 0.9634 - val_loss: 2.3486 - val_accuracy: 0.7654
# Epoch 37/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1894 - accuracy: 0.9620 - val_loss: 3.1310 - val_accuracy: 0.7600
# Epoch 38/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1795 - accuracy: 0.9616 - val_loss: 3.7722 - val_accuracy: 0.7523
# Epoch 39/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1943 - accuracy: 0.9615 - val_loss: 3.6714 - val_accuracy: 0.7562
# Epoch 40/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1968 - accuracy: 0.9616 - val_loss: 3.0899 - val_accuracy: 0.7608
# Epoch 41/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1941 - accuracy: 0.9657 - val_loss: 3.0130 - val_accuracy: 0.7589
# Epoch 42/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1514 - accuracy: 0.9670 - val_loss: 3.9953 - val_accuracy: 0.7438
# Epoch 43/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1857 - accuracy: 0.9640 - val_loss: 2.9056 - val_accuracy: 0.7677
# Epoch 44/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1943 - accuracy: 0.9657 - val_loss: 3.3842 - val_accuracy: 0.7620
# Epoch 45/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2107 - accuracy: 0.9661 - val_loss: 3.4489 - val_accuracy: 0.7620
# Epoch 46/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2207 - accuracy: 0.9662 - val_loss: 3.6564 - val_accuracy: 0.7735
# Epoch 47/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1949 - accuracy: 0.9680 - val_loss: 3.9064 - val_accuracy: 0.7596
# Epoch 48/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2256 - accuracy: 0.9668 - val_loss: 3.6100 - val_accuracy: 0.7693
# Epoch 49/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1946 - accuracy: 0.9633 - val_loss: 5.0843 - val_accuracy: 0.7701
# Epoch 50/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2037 - accuracy: 0.9657 - val_loss: 2.9806 - val_accuracy: 0.7604
# Epoch 51/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2054 - accuracy: 0.9662 - val_loss: 5.4529 - val_accuracy: 0.7639
# Epoch 52/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2176 - accuracy: 0.9684 - val_loss: 5.8103 - val_accuracy: 0.7504
# Epoch 53/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2164 - accuracy: 0.9680 - val_loss: 4.6564 - val_accuracy: 0.7623
# Epoch 54/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2389 - accuracy: 0.9662 - val_loss: 3.7720 - val_accuracy: 0.7677
# Epoch 55/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2269 - accuracy: 0.9662 - val_loss: 3.2600 - val_accuracy: 0.7639
# Epoch 56/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2096 - accuracy: 0.9686 - val_loss: 4.3356 - val_accuracy: 0.7585
# Epoch 57/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2157 - accuracy: 0.9659 - val_loss: 5.3545 - val_accuracy: 0.7488
# Epoch 58/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2268 - accuracy: 0.9683 - val_loss: 4.8193 - val_accuracy: 0.7778
# Epoch 59/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2289 - accuracy: 0.9671 - val_loss: 3.8861 - val_accuracy: 0.7720
# Epoch 60/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2076 - accuracy: 0.9705 - val_loss: 4.6527 - val_accuracy: 0.7542
# Epoch 61/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1757 - accuracy: 0.9709 - val_loss: 5.8901 - val_accuracy: 0.7473
# Epoch 62/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2191 - accuracy: 0.9687 - val_loss: 5.3248 - val_accuracy: 0.7434
# Epoch 63/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2337 - accuracy: 0.9675 - val_loss: 5.3372 - val_accuracy: 0.7585
# Epoch 64/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2172 - accuracy: 0.9702 - val_loss: 4.7834 - val_accuracy: 0.7874
# Epoch 65/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2111 - accuracy: 0.9700 - val_loss: 6.1113 - val_accuracy: 0.7701
# Epoch 66/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2559 - accuracy: 0.9719 - val_loss: 5.3740 - val_accuracy: 0.7612
# Epoch 67/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2050 - accuracy: 0.9718 - val_loss: 6.4256 - val_accuracy: 0.7662
# Epoch 68/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2473 - accuracy: 0.9726 - val_loss: 8.7833 - val_accuracy: 0.7292
# Epoch 69/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2554 - accuracy: 0.9736 - val_loss: 6.3515 - val_accuracy: 0.7620
# Epoch 70/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2695 - accuracy: 0.9704 - val_loss: 5.1499 - val_accuracy: 0.7612
# Epoch 71/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2470 - accuracy: 0.9718 - val_loss: 5.4627 - val_accuracy: 0.7620
# Epoch 72/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2318 - accuracy: 0.9720 - val_loss: 6.2030 - val_accuracy: 0.7643
# Epoch 73/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2406 - accuracy: 0.9710 - val_loss: 5.7785 - val_accuracy: 0.7674
# Epoch 74/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2328 - accuracy: 0.9714 - val_loss: 5.2378 - val_accuracy: 0.7647
# Epoch 75/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2166 - accuracy: 0.9715 - val_loss: 7.5288 - val_accuracy: 0.7612
# Epoch 76/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2477 - accuracy: 0.9728 - val_loss: 7.3106 - val_accuracy: 0.7674
# Epoch 77/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2888 - accuracy: 0.9702 - val_loss: 6.5222 - val_accuracy: 0.7697
# Epoch 78/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2375 - accuracy: 0.9723 - val_loss: 6.5892 - val_accuracy: 0.7816
# Epoch 79/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2531 - accuracy: 0.9716 - val_loss: 6.3653 - val_accuracy: 0.7593
# Epoch 80/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2709 - accuracy: 0.9727 - val_loss: 6.5198 - val_accuracy: 0.7612
# Epoch 81/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2622 - accuracy: 0.9711 - val_loss: 7.3427 - val_accuracy: 0.7809
# Epoch 82/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2866 - accuracy: 0.9713 - val_loss: 6.9183 - val_accuracy: 0.7789
# Epoch 83/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2338 - accuracy: 0.9745 - val_loss: 7.9625 - val_accuracy: 0.7670
# Epoch 84/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2523 - accuracy: 0.9726 - val_loss: 9.1855 - val_accuracy: 0.7654
# Epoch 85/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2586 - accuracy: 0.9746 - val_loss: 8.6276 - val_accuracy: 0.7670
# Epoch 86/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2453 - accuracy: 0.9740 - val_loss: 10.1323 - val_accuracy: 0.7724
# Epoch 87/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.3112 - accuracy: 0.9733 - val_loss: 6.8244 - val_accuracy: 0.7716
# Epoch 88/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2062 - accuracy: 0.9751 - val_loss: 7.9401 - val_accuracy: 0.7623
# Epoch 89/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2620 - accuracy: 0.9733 - val_loss: 8.3239 - val_accuracy: 0.7758
# Epoch 90/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2738 - accuracy: 0.9718 - val_loss: 8.0334 - val_accuracy: 0.7685
# Epoch 91/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2941 - accuracy: 0.9745 - val_loss: 8.2836 - val_accuracy: 0.7766
# Epoch 92/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2985 - accuracy: 0.9710 - val_loss: 7.0281 - val_accuracy: 0.7731
# Epoch 93/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2940 - accuracy: 0.9731 - val_loss: 8.1099 - val_accuracy: 0.7701
# Epoch 94/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.3642 - accuracy: 0.9733 - val_loss: 6.3512 - val_accuracy: 0.7782
# Epoch 95/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2646 - accuracy: 0.9772 - val_loss: 9.0759 - val_accuracy: 0.7863
# Epoch 96/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2881 - accuracy: 0.9772 - val_loss: 9.2430 - val_accuracy: 0.7662
# Epoch 97/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2940 - accuracy: 0.9749 - val_loss: 9.0396 - val_accuracy: 0.7720
# Epoch 98/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.2745 - accuracy: 0.9780 - val_loss: 9.8718 - val_accuracy: 0.7747
# Epoch 99/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.3010 - accuracy: 0.9746 - val_loss: 10.2263 - val_accuracy: 0.7620
# Epoch 100/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.3121 - accuracy: 0.9768 - val_loss: 8.4431 - val_accuracy: 0.7701

# %% [markdown]
# Salviamo come prima la history del modello in un file csv, e convertiamo il miglior modello nel formato **.onnx**.

# %%
improved_history_df = convert_history_to_csv(improved_history)
improved_history_df.to_csv("model_histories/noise/rmsprop/improved_history.csv")

convert_model_to_onnx("bestmodels/noise/rmsprop/improved_basic_model.keras", (124, 129, 1))

# %% [markdown]
# Visualizziamo la curva dell'accuratezza e della perdita durante l'addestramento.

# %%
create_train_val_plot(improved_history.history)

# %% [markdown]
# Le prestazioni sono leggermente migliorate rispetto all'applicazione precedente. Verifichiamo l'accuratezza nel dataset di test.

# %%
improved_best_model = tf.keras.models.load_model("bestmodels/noise/rmsprop/improved_basic_model.keras")
test_loss, test_acc = improved_best_model.evaluate(mixed_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 6ms/step - loss: 1.1378 - accuracy: 0.7148
# Accuratezza: 0.715

# %%
evaluate_onnx_model("bestmodels/noise/rmsprop/improved_basic_model.onnx", mixed_test_ds)
# Out:
# Accuratezza: 0.715

# %% [markdown]
# Abbiamo ottenuto un notevole miglioramento dell'accuratezza, attualmente siamo a quota **71.5%**! Visualizziamo anche la solita distribuzione.

# %%
for audio, label in mixed_test_ds:
    create_distribution_plot(improved_best_model, audio, label)
    break

# %% [markdown]
# ### Fine tuning
# In questa sezione andremo a effettuare il fine tuning del modello convolutivo con la stessa metodologia del notebook di riferimento.
#
# Per ora non abbiamo ottenuto delle buone prestazioni, la validazione non riesce a perciò proveremo a aumentare, bloccandosi troppo presto. Cerchiamo di capire attraverso le funzioni `tuner` e `plot_models` qual è il problema.

# %%
def get_improved_basic_model_tuning(start_filters):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(124, 129, 1))
    x = tf.keras.layers.Normalization()(inputs)

    if not isinstance(start_filters, int):
        raise Exception("start_filters must be type integer")

    filters = [start_filters * (2 ** i) for i in range(4)]
    
    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=filters[0], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[1], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[2], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[3], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[3], kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

def tuner(filters, learning_rates, max_epochs, train_dataset, validation_dataset):
    start_time = time.time()

    counter = 1
    
    if not isinstance(filters, list):
        raise Exception("parameter filters must be type list")

    if not isinstance(learning_rates, list):
        raise Exception("parameter learning_rates must be type list")

    callbacks = [tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5)]

    best_learning_rate = 0 
    best_filters = 0
    best_val_accuracy = 0

    best_model = 0
    
    for f in filters:
        for lr in learning_rates:
            print(f"\nAddestrando con filtri {[f * (2 ** i) for i in range(4)]} e tasso di apprendimento {lr}")
            
            model = get_improved_basic_model_tuning(start_filters=f)
            model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.RMSprop(learning_rate=lr), metrics=["accuracy"])
            model_history = model.fit(train_dataset, epochs=max_epochs, validation_data=validation_dataset, callbacks=callbacks)

            model_history_df = convert_history_to_csv(model_history)

            model_history_df[["filters"]] = f
            model_history_df[["learning_rate"]] = lr
            
            path = "model_tuning/histories/rmsprop/model_" + str(counter) + ".csv"
            model_history_df.to_csv(path)
            
            if best_val_accuracy < model_history_df.iloc[-1]["val_accuracy"]:
                best_val_accuracy = model_history_df.iloc[-1]["val_accuracy"]
                best_filters = f
                best_learning_rate = lr
                epoch = len(model_history_df)

            del model

            counter += 1

    total_time = time.time() - start_time
    minutes, seconds = divmod(total_time, 60)
    print(f"\nTempo totale trascorso: {int(minutes)} minuti e {int(seconds)} secondi")
    # print(f"Il miglior modello ha un filtro di partenza pari a {best_filters}, un learning rate pari a {best_learning_rate} con un'accuracy pari a {best_val_accuracy:.3f}")

    return best_filters, best_learning_rate

best_filter, best_learning_rate = tuner([16, 32, 64], [1e-3, 1e-4, 1e-5], 30, mixed_train_ds, mixed_val_ds)
# Out:
# Addestrando con filtri [16, 32, 64, 128] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.0794 - accuracy: 0.1327 - val_loss: 2.8396 - val_accuracy: 0.2114
# Epoch 2/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.3751 - accuracy: 0.3272 - val_loss: 2.4458 - val_accuracy: 0.3445
# Epoch 3/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.7486 - accuracy: 0.4928 - val_loss: 2.2405 - val_accuracy: 0.4483
# Epoch 4/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.3609 - accuracy: 0.6026 - val_loss: 1.3998 - val_accuracy: 0.5995
# Epoch 5/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.0818 - accuracy: 0.6782 - val_loss: 1.2624 - val_accuracy: 0.6543
# Epoch 6/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.8912 - accuracy: 0.7294 - val_loss: 1.3641 - val_accuracy: 0.6458
# Epoch 7/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.7471 - accuracy: 0.7683 - val_loss: 1.1550 - val_accuracy: 0.6713
# Epoch 8/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.6403 - accuracy: 0.8046 - val_loss: 1.2737 - val_accuracy: 0.6794
# Epoch 9/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.5639 - accuracy: 0.8273 - val_loss: 1.1918 - val_accuracy: 0.7072
# Epoch 10/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.4893 - accuracy: 0.8486 - val_loss: 1.2975 - val_accuracy: 0.7392
# Epoch 11/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.4327 - accuracy: 0.8661 - val_loss: 1.5768 - val_accuracy: 0.7180
# Epoch 12/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.3902 - accuracy: 0.8811 - val_loss: 1.3768 - val_accuracy: 0.7203
#
# Addestrando con filtri [16, 32, 64, 128] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.3437 - accuracy: 0.0617 - val_loss: 3.2070 - val_accuracy: 0.1331
# Epoch 2/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.1160 - accuracy: 0.1383 - val_loss: 2.9788 - val_accuracy: 0.1794
# Epoch 3/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.9309 - accuracy: 0.1838 - val_loss: 2.8374 - val_accuracy: 0.2296
# Epoch 4/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.7669 - accuracy: 0.2353 - val_loss: 2.6914 - val_accuracy: 0.2658
# Epoch 5/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.6042 - accuracy: 0.2832 - val_loss: 2.5570 - val_accuracy: 0.3086
# Epoch 6/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.4480 - accuracy: 0.3200 - val_loss: 2.4498 - val_accuracy: 0.3306
# Epoch 7/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.2863 - accuracy: 0.3638 - val_loss: 2.3458 - val_accuracy: 0.3615
# Epoch 8/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.1640 - accuracy: 0.4000 - val_loss: 2.2290 - val_accuracy: 0.4016
# Epoch 9/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.0116 - accuracy: 0.4433 - val_loss: 2.1169 - val_accuracy: 0.4321
# Epoch 10/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.8916 - accuracy: 0.4747 - val_loss: 1.9718 - val_accuracy: 0.4637
# Epoch 11/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.7815 - accuracy: 0.4982 - val_loss: 1.9162 - val_accuracy: 0.4877
# Epoch 12/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.6620 - accuracy: 0.5320 - val_loss: 1.8752 - val_accuracy: 0.5019
# Epoch 13/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.5830 - accuracy: 0.5563 - val_loss: 1.8792 - val_accuracy: 0.5015
# Epoch 14/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.5005 - accuracy: 0.5733 - val_loss: 1.6961 - val_accuracy: 0.5475
# Epoch 15/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.4171 - accuracy: 0.5987 - val_loss: 1.7024 - val_accuracy: 0.5482
# Epoch 16/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.3647 - accuracy: 0.6119 - val_loss: 1.6565 - val_accuracy: 0.5702
# Epoch 17/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.3078 - accuracy: 0.6282 - val_loss: 1.6640 - val_accuracy: 0.5552
# Epoch 18/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.2492 - accuracy: 0.6415 - val_loss: 1.6563 - val_accuracy: 0.5687
# Epoch 19/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.2083 - accuracy: 0.6558 - val_loss: 1.7561 - val_accuracy: 0.5471
# Epoch 20/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.1570 - accuracy: 0.6655 - val_loss: 1.4982 - val_accuracy: 0.6061
# Epoch 21/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.1113 - accuracy: 0.6813 - val_loss: 1.5352 - val_accuracy: 0.6088
# Epoch 22/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.0688 - accuracy: 0.6923 - val_loss: 1.4323 - val_accuracy: 0.6242
# Epoch 23/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.0243 - accuracy: 0.7101 - val_loss: 1.4838 - val_accuracy: 0.6157
# Epoch 24/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.9919 - accuracy: 0.7177 - val_loss: 1.4819 - val_accuracy: 0.6296
# Epoch 25/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.9587 - accuracy: 0.7284 - val_loss: 1.4877 - val_accuracy: 0.6312
# Epoch 26/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.9167 - accuracy: 0.7339 - val_loss: 1.4556 - val_accuracy: 0.6289
# Epoch 27/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.8884 - accuracy: 0.7396 - val_loss: 2.0696 - val_accuracy: 0.5444
#
# Addestrando con filtri [16, 32, 64, 128] e tasso di apprendimento 1e-05
# Epoch 1/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.3985 - accuracy: 0.0446 - val_loss: 3.3866 - val_accuracy: 0.0490
# Epoch 2/30
# 243/243 [==============================] - 2s 6ms/step - loss: 3.3803 - accuracy: 0.0563 - val_loss: 3.3711 - val_accuracy: 0.0598
# Epoch 3/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.3627 - accuracy: 0.0585 - val_loss: 3.3524 - val_accuracy: 0.0679
# Epoch 4/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.3441 - accuracy: 0.0691 - val_loss: 3.3288 - val_accuracy: 0.0775
# Epoch 5/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.3175 - accuracy: 0.0772 - val_loss: 3.2980 - val_accuracy: 0.0957
# Epoch 6/30
# 243/243 [==============================] - 2s 6ms/step - loss: 3.2854 - accuracy: 0.0927 - val_loss: 3.2596 - val_accuracy: 0.1119
# Epoch 7/30
# 243/243 [==============================] - 2s 6ms/step - loss: 3.2539 - accuracy: 0.1003 - val_loss: 3.2177 - val_accuracy: 0.1215
# Epoch 8/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.2106 - accuracy: 0.1081 - val_loss: 3.1722 - val_accuracy: 0.1381
# Epoch 9/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.1743 - accuracy: 0.1171 - val_loss: 3.1298 - val_accuracy: 0.1478
# Epoch 10/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.1415 - accuracy: 0.1265 - val_loss: 3.0932 - val_accuracy: 0.1586
# Epoch 11/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.1103 - accuracy: 0.1335 - val_loss: 3.0593 - val_accuracy: 0.1651
# Epoch 12/30
# 243/243 [==============================] - 2s 6ms/step - loss: 3.0815 - accuracy: 0.1411 - val_loss: 3.0294 - val_accuracy: 0.1728
# Epoch 13/30
# 243/243 [==============================] - 2s 6ms/step - loss: 3.0493 - accuracy: 0.1548 - val_loss: 3.0022 - val_accuracy: 0.1786
# Epoch 14/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.0234 - accuracy: 0.1576 - val_loss: 2.9787 - val_accuracy: 0.1848
# Epoch 15/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.0134 - accuracy: 0.1626 - val_loss: 2.9591 - val_accuracy: 0.1879
# Epoch 16/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.9842 - accuracy: 0.1718 - val_loss: 2.9387 - val_accuracy: 0.1968
# Epoch 17/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.9645 - accuracy: 0.1701 - val_loss: 2.9183 - val_accuracy: 0.2022
# Epoch 18/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.9424 - accuracy: 0.1728 - val_loss: 2.8997 - val_accuracy: 0.2072
# Epoch 19/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.9120 - accuracy: 0.1890 - val_loss: 2.8804 - val_accuracy: 0.2153
# Epoch 20/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.8974 - accuracy: 0.1957 - val_loss: 2.8626 - val_accuracy: 0.2222
# Epoch 21/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.8823 - accuracy: 0.1973 - val_loss: 2.8450 - val_accuracy: 0.2284
# Epoch 22/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.8575 - accuracy: 0.2059 - val_loss: 2.8276 - val_accuracy: 0.2323
# Epoch 23/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.8336 - accuracy: 0.2126 - val_loss: 2.8102 - val_accuracy: 0.2423
# Epoch 24/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.8258 - accuracy: 0.2120 - val_loss: 2.7936 - val_accuracy: 0.2504
# Epoch 25/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.8001 - accuracy: 0.2232 - val_loss: 2.7784 - val_accuracy: 0.2558
# Epoch 26/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.7856 - accuracy: 0.2236 - val_loss: 2.7619 - val_accuracy: 0.2573
# Epoch 27/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.7699 - accuracy: 0.2345 - val_loss: 2.7471 - val_accuracy: 0.2620
# Epoch 28/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.7550 - accuracy: 0.2348 - val_loss: 2.7342 - val_accuracy: 0.2704
# Epoch 29/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.7378 - accuracy: 0.2432 - val_loss: 2.7156 - val_accuracy: 0.2762
# Epoch 30/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.7193 - accuracy: 0.2500 - val_loss: 2.7005 - val_accuracy: 0.2782
#
# Addestrando con filtri [32, 64, 128, 256] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 3s 10ms/step - loss: 3.0380 - accuracy: 0.1451 - val_loss: 2.7921 - val_accuracy: 0.2319
# Epoch 2/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.0851 - accuracy: 0.4040 - val_loss: 1.9999 - val_accuracy: 0.4483
# Epoch 3/30
# 243/243 [==============================] - 2s 10ms/step - loss: 1.3881 - accuracy: 0.5961 - val_loss: 1.5037 - val_accuracy: 0.5853
# Epoch 4/30
# 243/243 [==============================] - 2s 10ms/step - loss: 1.0054 - accuracy: 0.7037 - val_loss: 1.1022 - val_accuracy: 0.6806
# Epoch 5/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.7705 - accuracy: 0.7713 - val_loss: 1.1380 - val_accuracy: 0.7095
# Epoch 6/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.6031 - accuracy: 0.8159 - val_loss: 1.2105 - val_accuracy: 0.7133
# Epoch 7/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.4907 - accuracy: 0.8441 - val_loss: 1.2241 - val_accuracy: 0.7203
# Epoch 8/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.4252 - accuracy: 0.8687 - val_loss: 1.2318 - val_accuracy: 0.7230
# Epoch 9/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.3673 - accuracy: 0.8893 - val_loss: 1.2682 - val_accuracy: 0.7160
#
# Addestrando con filtri [32, 64, 128, 256] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 3s 10ms/step - loss: 3.2690 - accuracy: 0.0901 - val_loss: 3.0544 - val_accuracy: 0.1586
# Epoch 2/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.9424 - accuracy: 0.1790 - val_loss: 2.8101 - val_accuracy: 0.2242
# Epoch 3/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.6832 - accuracy: 0.2629 - val_loss: 2.6336 - val_accuracy: 0.2778
# Epoch 4/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.4440 - accuracy: 0.3206 - val_loss: 2.4975 - val_accuracy: 0.3314
# Epoch 5/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.2125 - accuracy: 0.3818 - val_loss: 2.2149 - val_accuracy: 0.3947
# Epoch 6/30
# 243/243 [==============================] - 2s 10ms/step - loss: 1.9785 - accuracy: 0.4503 - val_loss: 2.1153 - val_accuracy: 0.4321
# Epoch 7/30
# 243/243 [==============================] - 2s 10ms/step - loss: 1.7712 - accuracy: 0.5058 - val_loss: 1.8921 - val_accuracy: 0.4834
# Epoch 8/30
# 243/243 [==============================] - 2s 10ms/step - loss: 1.6036 - accuracy: 0.5548 - val_loss: 2.1406 - val_accuracy: 0.4572
# Epoch 9/30
# 243/243 [==============================] - 2s 10ms/step - loss: 1.4665 - accuracy: 0.5898 - val_loss: 1.6855 - val_accuracy: 0.5409
# Epoch 10/30
# 243/243 [==============================] - 2s 10ms/step - loss: 1.3380 - accuracy: 0.6245 - val_loss: 1.5942 - val_accuracy: 0.5644
# Epoch 11/30
# 243/243 [==============================] - 2s 10ms/step - loss: 1.2375 - accuracy: 0.6509 - val_loss: 1.6378 - val_accuracy: 0.5660
# Epoch 12/30
# 243/243 [==============================] - 2s 10ms/step - loss: 1.1457 - accuracy: 0.6781 - val_loss: 1.7375 - val_accuracy: 0.5664
# Epoch 13/30
# 243/243 [==============================] - 2s 10ms/step - loss: 1.0561 - accuracy: 0.6981 - val_loss: 1.4891 - val_accuracy: 0.6069
# Epoch 14/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.9801 - accuracy: 0.7233 - val_loss: 1.5037 - val_accuracy: 0.6161
# Epoch 15/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.9058 - accuracy: 0.7344 - val_loss: 1.5089 - val_accuracy: 0.6269
# Epoch 16/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.8460 - accuracy: 0.7509 - val_loss: 1.4219 - val_accuracy: 0.6451
# Epoch 17/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.7890 - accuracy: 0.7716 - val_loss: 1.4293 - val_accuracy: 0.6466
# Epoch 18/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.7300 - accuracy: 0.7883 - val_loss: 1.3670 - val_accuracy: 0.6620
# Epoch 19/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.6961 - accuracy: 0.7985 - val_loss: 1.3742 - val_accuracy: 0.6698
# Epoch 20/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.6511 - accuracy: 0.8106 - val_loss: 1.3431 - val_accuracy: 0.6887
# Epoch 21/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.6078 - accuracy: 0.8211 - val_loss: 1.3416 - val_accuracy: 0.6917
# Epoch 22/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.5814 - accuracy: 0.8298 - val_loss: 1.3501 - val_accuracy: 0.6991
# Epoch 23/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.5344 - accuracy: 0.8406 - val_loss: 1.3318 - val_accuracy: 0.6975
# Epoch 24/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.5101 - accuracy: 0.8508 - val_loss: 1.4445 - val_accuracy: 0.6836
# Epoch 25/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.4860 - accuracy: 0.8522 - val_loss: 1.4873 - val_accuracy: 0.6840
# Epoch 26/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.4566 - accuracy: 0.8633 - val_loss: 1.4134 - val_accuracy: 0.7002
# Epoch 27/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.4320 - accuracy: 0.8688 - val_loss: 1.3915 - val_accuracy: 0.7130
# Epoch 28/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.4083 - accuracy: 0.8813 - val_loss: 1.5237 - val_accuracy: 0.6910
#
# Addestrando con filtri [32, 64, 128, 256] e tasso di apprendimento 1e-05
# Epoch 1/30
# 243/243 [==============================] - 3s 10ms/step - loss: 3.3890 - accuracy: 0.0427 - val_loss: 3.3660 - val_accuracy: 0.0648
# Epoch 2/30
# 243/243 [==============================] - 2s 10ms/step - loss: 3.3529 - accuracy: 0.0701 - val_loss: 3.3288 - val_accuracy: 0.0922
# Epoch 3/30
# 243/243 [==============================] - 2s 10ms/step - loss: 3.3052 - accuracy: 0.0851 - val_loss: 3.2713 - val_accuracy: 0.1150
# Epoch 4/30
# 243/243 [==============================] - 2s 10ms/step - loss: 3.2438 - accuracy: 0.0996 - val_loss: 3.1981 - val_accuracy: 0.1377
# Epoch 5/30
# 243/243 [==============================] - 3s 10ms/step - loss: 3.1837 - accuracy: 0.1157 - val_loss: 3.1285 - val_accuracy: 0.1586
# Epoch 6/30
# 243/243 [==============================] - 3s 11ms/step - loss: 3.1221 - accuracy: 0.1303 - val_loss: 3.0702 - val_accuracy: 0.1755
# Epoch 7/30
# 243/243 [==============================] - 2s 10ms/step - loss: 3.0696 - accuracy: 0.1494 - val_loss: 3.0209 - val_accuracy: 0.1879
# Epoch 8/30
# 243/243 [==============================] - 2s 10ms/step - loss: 3.0318 - accuracy: 0.1548 - val_loss: 2.9807 - val_accuracy: 0.1971
# Epoch 9/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.9974 - accuracy: 0.1651 - val_loss: 2.9455 - val_accuracy: 0.2037
# Epoch 10/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.9390 - accuracy: 0.1857 - val_loss: 2.9071 - val_accuracy: 0.2176
# Epoch 11/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.9067 - accuracy: 0.1973 - val_loss: 2.8731 - val_accuracy: 0.2288
# Epoch 12/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.8736 - accuracy: 0.2055 - val_loss: 2.8430 - val_accuracy: 0.2392
# Epoch 13/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.8351 - accuracy: 0.2107 - val_loss: 2.8133 - val_accuracy: 0.2481
# Epoch 14/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.8021 - accuracy: 0.2273 - val_loss: 2.7823 - val_accuracy: 0.2654
# Epoch 15/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.7615 - accuracy: 0.2357 - val_loss: 2.7512 - val_accuracy: 0.2693
# Epoch 16/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.7439 - accuracy: 0.2468 - val_loss: 2.7291 - val_accuracy: 0.2766
# Epoch 17/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.6972 - accuracy: 0.2594 - val_loss: 2.7000 - val_accuracy: 0.2820
# Epoch 18/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.6679 - accuracy: 0.2695 - val_loss: 2.6766 - val_accuracy: 0.2944
# Epoch 19/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.6345 - accuracy: 0.2768 - val_loss: 2.6495 - val_accuracy: 0.2982
# Epoch 20/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.5981 - accuracy: 0.2893 - val_loss: 2.6232 - val_accuracy: 0.3086
# Epoch 21/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.5754 - accuracy: 0.2966 - val_loss: 2.5945 - val_accuracy: 0.3125
# Epoch 22/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.5459 - accuracy: 0.3054 - val_loss: 2.5719 - val_accuracy: 0.3206
# Epoch 23/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.4954 - accuracy: 0.3193 - val_loss: 2.5474 - val_accuracy: 0.3248
# Epoch 24/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.4900 - accuracy: 0.3201 - val_loss: 2.5296 - val_accuracy: 0.3295
# Epoch 25/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.4493 - accuracy: 0.3272 - val_loss: 2.4989 - val_accuracy: 0.3403
# Epoch 26/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.4216 - accuracy: 0.3367 - val_loss: 2.4766 - val_accuracy: 0.3418
# Epoch 27/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.3919 - accuracy: 0.3501 - val_loss: 2.4524 - val_accuracy: 0.3499
# Epoch 28/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.3615 - accuracy: 0.3543 - val_loss: 2.4346 - val_accuracy: 0.3503
# Epoch 29/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.3378 - accuracy: 0.3628 - val_loss: 2.4083 - val_accuracy: 0.3534
# Epoch 30/30
# 243/243 [==============================] - 2s 10ms/step - loss: 2.3051 - accuracy: 0.3738 - val_loss: 2.3869 - val_accuracy: 0.3584
#
# Addestrando con filtri [64, 128, 256, 512] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 6s 21ms/step - loss: 3.1446 - accuracy: 0.1371 - val_loss: 3.0700 - val_accuracy: 0.2323
# Epoch 2/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.0693 - accuracy: 0.4049 - val_loss: 1.8266 - val_accuracy: 0.4738
# Epoch 3/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.3463 - accuracy: 0.5987 - val_loss: 1.6190 - val_accuracy: 0.5733
# Epoch 4/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.9352 - accuracy: 0.7226 - val_loss: 1.4921 - val_accuracy: 0.6262
# Epoch 5/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.7048 - accuracy: 0.7818 - val_loss: 1.2288 - val_accuracy: 0.7079
# Epoch 6/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.5450 - accuracy: 0.8329 - val_loss: 1.2186 - val_accuracy: 0.7079
# Epoch 7/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.4488 - accuracy: 0.8651 - val_loss: 1.5389 - val_accuracy: 0.7172
# Epoch 8/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.3833 - accuracy: 0.8863 - val_loss: 2.4419 - val_accuracy: 0.6562
# Epoch 9/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.3348 - accuracy: 0.8982 - val_loss: 1.5745 - val_accuracy: 0.7338
# Epoch 10/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.2934 - accuracy: 0.9130 - val_loss: 1.8883 - val_accuracy: 0.7365
# Epoch 11/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.2702 - accuracy: 0.9223 - val_loss: 1.8056 - val_accuracy: 0.7353
#
# Addestrando con filtri [64, 128, 256, 512] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 6s 21ms/step - loss: 3.1876 - accuracy: 0.1113 - val_loss: 2.9590 - val_accuracy: 0.1763
# Epoch 2/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.7454 - accuracy: 0.2344 - val_loss: 2.7572 - val_accuracy: 0.2677
# Epoch 3/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.3609 - accuracy: 0.3406 - val_loss: 2.6231 - val_accuracy: 0.3256
# Epoch 4/30
# 243/243 [==============================] - 5s 21ms/step - loss: 1.9811 - accuracy: 0.4468 - val_loss: 2.5257 - val_accuracy: 0.3889
# Epoch 5/30
# 243/243 [==============================] - 5s 21ms/step - loss: 1.6659 - accuracy: 0.5363 - val_loss: 1.9932 - val_accuracy: 0.4884
# Epoch 6/30
# 243/243 [==============================] - 5s 21ms/step - loss: 1.4156 - accuracy: 0.6024 - val_loss: 1.9184 - val_accuracy: 0.5305
# Epoch 7/30
# 243/243 [==============================] - 5s 21ms/step - loss: 1.2245 - accuracy: 0.6602 - val_loss: 1.7504 - val_accuracy: 0.5729
# Epoch 8/30
# 243/243 [==============================] - 5s 21ms/step - loss: 1.0633 - accuracy: 0.6965 - val_loss: 1.6658 - val_accuracy: 0.6080
# Epoch 9/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.9364 - accuracy: 0.7309 - val_loss: 1.4842 - val_accuracy: 0.6478
# Epoch 10/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.8236 - accuracy: 0.7638 - val_loss: 1.5531 - val_accuracy: 0.6404
# Epoch 11/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.7293 - accuracy: 0.7861 - val_loss: 1.4184 - val_accuracy: 0.6728
# Epoch 12/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.6539 - accuracy: 0.8110 - val_loss: 1.4529 - val_accuracy: 0.6717
# Epoch 13/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.5750 - accuracy: 0.8293 - val_loss: 1.5663 - val_accuracy: 0.6836
# Epoch 14/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.5211 - accuracy: 0.8465 - val_loss: 1.5951 - val_accuracy: 0.6964
# Epoch 15/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.4725 - accuracy: 0.8597 - val_loss: 1.5192 - val_accuracy: 0.7076
# Epoch 16/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.4150 - accuracy: 0.8755 - val_loss: 1.4483 - val_accuracy: 0.7168
#
# Addestrando con filtri [64, 128, 256, 512] e tasso di apprendimento 1e-05
# Epoch 1/30
# 243/243 [==============================] - 6s 22ms/step - loss: 3.3792 - accuracy: 0.0544 - val_loss: 3.3490 - val_accuracy: 0.0802
# Epoch 2/30
# 243/243 [==============================] - 5s 21ms/step - loss: 3.3023 - accuracy: 0.0910 - val_loss: 3.2388 - val_accuracy: 0.1316
# Epoch 3/30
# 243/243 [==============================] - 5s 21ms/step - loss: 3.1834 - accuracy: 0.1206 - val_loss: 3.1027 - val_accuracy: 0.1628
# Epoch 4/30
# 243/243 [==============================] - 5s 21ms/step - loss: 3.0875 - accuracy: 0.1432 - val_loss: 3.0122 - val_accuracy: 0.1802
# Epoch 5/30
# 243/243 [==============================] - 5s 21ms/step - loss: 3.0030 - accuracy: 0.1668 - val_loss: 2.9412 - val_accuracy: 0.1991
# Epoch 6/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.9452 - accuracy: 0.1799 - val_loss: 2.8902 - val_accuracy: 0.2160
# Epoch 7/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.8720 - accuracy: 0.2027 - val_loss: 2.8402 - val_accuracy: 0.2384
# Epoch 8/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.8254 - accuracy: 0.2149 - val_loss: 2.8028 - val_accuracy: 0.2442
# Epoch 9/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.7846 - accuracy: 0.2294 - val_loss: 2.7567 - val_accuracy: 0.2608
# Epoch 10/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.7332 - accuracy: 0.2474 - val_loss: 2.7171 - val_accuracy: 0.2735
# Epoch 11/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.6645 - accuracy: 0.2680 - val_loss: 2.6743 - val_accuracy: 0.2847
# Epoch 12/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.6159 - accuracy: 0.2827 - val_loss: 2.6320 - val_accuracy: 0.3021
# Epoch 13/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.5585 - accuracy: 0.3031 - val_loss: 2.5895 - val_accuracy: 0.3198
# Epoch 14/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.5127 - accuracy: 0.3169 - val_loss: 2.5488 - val_accuracy: 0.3353
# Epoch 15/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.4721 - accuracy: 0.3290 - val_loss: 2.5101 - val_accuracy: 0.3418
# Epoch 16/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.4079 - accuracy: 0.3419 - val_loss: 2.4774 - val_accuracy: 0.3441
# Epoch 17/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.3571 - accuracy: 0.3601 - val_loss: 2.4401 - val_accuracy: 0.3515
# Epoch 18/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.3140 - accuracy: 0.3740 - val_loss: 2.4160 - val_accuracy: 0.3619
# Epoch 19/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.2558 - accuracy: 0.3916 - val_loss: 2.3740 - val_accuracy: 0.3789
# Epoch 20/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.2194 - accuracy: 0.4019 - val_loss: 2.3305 - val_accuracy: 0.3920
# Epoch 21/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.1610 - accuracy: 0.4156 - val_loss: 2.2921 - val_accuracy: 0.4059
# Epoch 22/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.1192 - accuracy: 0.4251 - val_loss: 2.2578 - val_accuracy: 0.4117
# Epoch 23/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.0694 - accuracy: 0.4375 - val_loss: 2.2283 - val_accuracy: 0.4255
# Epoch 24/30
# 243/243 [==============================] - 5s 21ms/step - loss: 2.0376 - accuracy: 0.4530 - val_loss: 2.2176 - val_accuracy: 0.4198
# Epoch 25/30
# 243/243 [==============================] - 5s 21ms/step - loss: 1.9829 - accuracy: 0.4656 - val_loss: 2.1643 - val_accuracy: 0.4352
# Epoch 26/30
# 243/243 [==============================] - 5s 21ms/step - loss: 1.9474 - accuracy: 0.4706 - val_loss: 2.1306 - val_accuracy: 0.4498
# Epoch 27/30
# 243/243 [==============================] - 5s 21ms/step - loss: 1.8995 - accuracy: 0.4862 - val_loss: 2.0923 - val_accuracy: 0.4657
# Epoch 28/30
# 243/243 [==============================] - 5s 21ms/step - loss: 1.8565 - accuracy: 0.4978 - val_loss: 2.0861 - val_accuracy: 0.4618
# Epoch 29/30
# 243/243 [==============================] - 5s 21ms/step - loss: 1.8263 - accuracy: 0.5048 - val_loss: 2.0608 - val_accuracy: 0.4676
# Epoch 30/30
# 243/243 [==============================] - 5s 21ms/step - loss: 1.7662 - accuracy: 0.5273 - val_loss: 2.0211 - val_accuracy: 0.4892
#
# Tempo totale trascorso: 9 minuti e 40 secondi

# %% [markdown]
# Il tempo necessario per la ricerca dei migliori iperparametri è stata di quasi **10 minuti**.

# %% [markdown]
# Definiamo e utilizziamo la funzione `plot_models` per visualizzare l'accuratezza e la perdita di tutti i modelli che il tuner ha addestrato.

# %%
def plot_models(path, reverse=False, show="accuracy", overfit=True):
    n_models = len(os.listdir(path))
    # creo il subplot a seconda di quanti modelli dispongo
    best_pair = None
    min_diff = float("inf")
    
    for idx_model in range(1, int(np.sqrt(n_models)) + 1):
        if n_models % idx_model == 0:
            diff = abs(idx_model - n_models // idx_model)

            if diff < min_diff:
                min_diff = diff
                best_pair = (idx_model, n_models // idx_model)

    if reverse:
        rows = best_pair[1]
        cols = best_pair[0]
    else:
        rows = best_pair[0]
        cols = best_pair[1]
    
    fig, axes = plt.subplots(rows, cols, figsize=(14, 10))
    
    for index, model in enumerate(os.listdir(path)):
        row = index // cols
        col = index % cols
    
        ax = axes[row][col]
        
        newpath = path + "/" + model
        df = pd.read_csv(newpath)

        value1 = df[show].values
        value2 = df["val_" + show].values
        
        ax.plot(range(1, len(value1) + 1), value1, color="slategray", label="Addestramento")
        ax.plot(range(1, len(value2) + 1), value2, color="indianred", label="Validazione")

        if (row in range(rows)) and col == 0:
            ax.set_ylabel("Accuratezza (%)" if show == "accuracy" else "Perdita", fontweight="semibold", fontsize=10)

        if (col in range(cols)) and row == 2:
            ax.set_xlabel("Epoche", fontweight="semibold", fontsize=10)

        ax.set_title("Filtro " + str(df["filters"][0]) + " & lr " + str(df["learning_rate"][0]), fontsize=12)
            
        ax.set_ylim(0)
        ax.set_xlim(0)

        ax.spines["left"].set_visible(False)
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)

        ax.grid(True, color="gainsboro", alpha=0.3, linestyle="--")

        handles, _ = ax.get_legend_handles_labels()
        
        if overfit and show == "loss":
            # area overfit
            
            rect = mpatches.Rectangle((np.argmin(value2) + 1, 0), width=len(value1) - np.argmin(value2), height=max(max(value1), max(value2)), color='lightcoral', alpha=0.3)
            ax.add_patch(rect)
            # patch overfit per legenda
            overfit = mpatches.Patch(color='lightcoral', alpha=0.3, label='Area overfit')
           
            handles.append(overfit)

        ax.legend(handles=handles)

    plt.subplots_adjust(wspace=0.3, hspace=0.3)
    plt.show()

# %%
plot_models(path="model_tuning/histories/rmsprop", show="accuracy")
plot_models(path="model_tuning/histories/rmsprop", show="loss")

# %% [markdown]
# Dai grafici emerge che la combinazione più performante è composta da **XX filtri di partenza** e un **tasso di apprendimento di XX**, poiché ritarda maggiormente l'overfitting. Altre combinazioni, come **XX filtri di partenza** e un **tasso di apprendimento di 1e-5**, mostrano buone prestazioni ma anche un inizio di overfitting, evidenziato dallo distaccamento tra la perdita di addestramento e quella di validazione.
#
# Procediamo quindi con l'addestramento del modello con **XX filtri di partenza** e un **tasso di apprendimento di XX**. Come di consueto, salviamo i risultati in un file `keras` e la cronologia (history) in un file `csv`. Infine, convertiamo il file in formato `onnx`.

# %%
tuned_improved_basic_model = get_improved_basic_model()
tuned_improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.RMSprop(learning_rate=AGGIUNGERE), metrics=["accuracy"])

# %%
tuned_improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/noise/rmsprop/tuned_improved_basic_model.keras", save_best_only=True, monitor="val_loss")]
tuned_improved_history = tuned_improved_basic_model.fit(mixed_train_ds, epochs=100, validation_data=mixed_val_ds, callbacks=tuned_improved_basic_model_callbacks)

# %%
tuned_improved_history_df = convert_history_to_csv(tuned_improved_history)
tuned_improved_history_df.to_csv("model_histories/noise/rmsprop/tuned_improved_history.csv")

convert_model_to_onnx("bestmodels/noise/rmsprop/tuned_improved_basic_model.keras", (124, 129, 1))

# %%
create_train_val_plot(tuned_improved_history.history)

# %%
tuned_improved_best_model = tf.keras.models.load_model("bestmodels/noise/rmsprop/tuned_improved_basic_model.keras")
test_loss, test_acc = tuned_improved_best_model.evaluate(mixed_test_ds)
print(f"Accuratezza: {test_acc:.3f}")

# %%
evaluate_onnx_model("bestmodels/noise/rmsprop/tuned_improved_basic_model.onnx", mixed_test_ds)

# %% [markdown]
# AGGIUNGERE COMMENTO SU COME SI E' AGGIORNATO. L'accuratezza è attualmente **XX%**.

# %%
for audio, label in mixed_test_ds:
    create_distribution_plot(tuned_improved_best_model, audio, label)
    break

# %% [markdown]
# ### Miglioramenti all'architettura del modello
# Procediamo quindi con la fase corrispettiva al notebook di riferimento.

# %%
def residual_block(x, filters, pooling=False):
    residual = x

    x = tf.keras.layers.SeparableConv2D(filters, 3, padding="same", use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    if pooling:
      x = tf.keras.layers.MaxPooling2D(pool_size=2, padding="same")(x)
      residual = tf.keras.layers.Conv2D(filters, 1, strides=2)(residual)
    elif filters != residual.shape[-1]:
      residual = tf.keras.layers.Conv2D(filters, 1)(residual)

    x = tf.keras.layers.add([x, residual])
    return x

# %%
def bp_basic_model():
    # input e pre processamento
    inputs = tf.keras.Input(shape=(124, 129, 1))
    
    x = residual_block(inputs, 32, pooling=True)
    x = residual_block(x, 64, pooling=True)
    x = residual_block(x, 128, pooling=True)
    x = residual_block(x, 256, pooling=True)
    x = residual_block(x, 256, pooling=False)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Livelli per la classificazione
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
bp_basic_model = bp_basic_model()
bp_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

# %%
bp_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/noise/rmsprop/bp_basic_model.keras", save_best_only=True, monitor="val_loss")]
bp_model_history = bp_basic_model.fit(mixed_train_ds, epochs=100, validation_data=mixed_val_ds, callbacks=bp_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 6s 21ms/step - loss: 3.4645 - accuracy: 0.0661 - val_loss: 3.3795 - val_accuracy: 0.0475
# Epoch 2/100
# 243/243 [==============================] - 5s 20ms/step - loss: 3.0574 - accuracy: 0.1340 - val_loss: 3.0665 - val_accuracy: 0.1412
# Epoch 3/100
# 243/243 [==============================] - 5s 20ms/step - loss: 2.7741 - accuracy: 0.2068 - val_loss: 3.2277 - val_accuracy: 0.1381
# Epoch 4/100
# 243/243 [==============================] - 5s 21ms/step - loss: 2.4771 - accuracy: 0.2906 - val_loss: 2.9723 - val_accuracy: 0.1971
# Epoch 5/100
# 243/243 [==============================] - 5s 20ms/step - loss: 2.2137 - accuracy: 0.3695 - val_loss: 3.1482 - val_accuracy: 0.2188
# Epoch 6/100
# 243/243 [==============================] - 5s 20ms/step - loss: 2.0014 - accuracy: 0.4241 - val_loss: 3.0780 - val_accuracy: 0.2346
# Epoch 7/100
# 243/243 [==============================] - 5s 20ms/step - loss: 1.8259 - accuracy: 0.4781 - val_loss: 2.8435 - val_accuracy: 0.2863
# Epoch 8/100
# 243/243 [==============================] - 5s 21ms/step - loss: 1.6753 - accuracy: 0.5129 - val_loss: 2.8112 - val_accuracy: 0.2963
# Epoch 9/100
# 243/243 [==============================] - 5s 21ms/step - loss: 1.5396 - accuracy: 0.5485 - val_loss: 2.2874 - val_accuracy: 0.3954
# Epoch 10/100
# 243/243 [==============================] - 5s 20ms/step - loss: 1.4338 - accuracy: 0.5863 - val_loss: 1.8703 - val_accuracy: 0.4792
# Epoch 11/100
# 243/243 [==============================] - 5s 20ms/step - loss: 1.3386 - accuracy: 0.6138 - val_loss: 2.1516 - val_accuracy: 0.4271
# Epoch 12/100
# 243/243 [==============================] - 5s 20ms/step - loss: 1.2527 - accuracy: 0.6304 - val_loss: 2.0413 - val_accuracy: 0.4595
# Epoch 13/100
# 243/243 [==============================] - 5s 20ms/step - loss: 1.1693 - accuracy: 0.6576 - val_loss: 1.4482 - val_accuracy: 0.5833
# Epoch 14/100
# 243/243 [==============================] - 5s 20ms/step - loss: 1.0829 - accuracy: 0.6849 - val_loss: 1.5136 - val_accuracy: 0.5598
# Epoch 15/100
# 243/243 [==============================] - 5s 20ms/step - loss: 1.0178 - accuracy: 0.7044 - val_loss: 1.5466 - val_accuracy: 0.5579
# Epoch 16/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.9672 - accuracy: 0.7174 - val_loss: 1.6975 - val_accuracy: 0.5289
# Epoch 17/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.9133 - accuracy: 0.7325 - val_loss: 1.7086 - val_accuracy: 0.5343
# Epoch 18/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.8572 - accuracy: 0.7460 - val_loss: 1.5522 - val_accuracy: 0.5660
# Epoch 19/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.8081 - accuracy: 0.7595 - val_loss: 1.4493 - val_accuracy: 0.5926
# Epoch 20/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.7611 - accuracy: 0.7795 - val_loss: 2.6707 - val_accuracy: 0.4298
# Epoch 21/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.7182 - accuracy: 0.7912 - val_loss: 1.6299 - val_accuracy: 0.5640
# Epoch 22/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.6848 - accuracy: 0.7987 - val_loss: 1.4205 - val_accuracy: 0.6076
# Epoch 23/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.6521 - accuracy: 0.8081 - val_loss: 1.6248 - val_accuracy: 0.5629
# Epoch 24/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.6241 - accuracy: 0.8216 - val_loss: 1.4151 - val_accuracy: 0.6092
# Epoch 25/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.5902 - accuracy: 0.8343 - val_loss: 1.3440 - val_accuracy: 0.6250
# Epoch 26/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.5514 - accuracy: 0.8411 - val_loss: 1.6964 - val_accuracy: 0.5718
# Epoch 27/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.5334 - accuracy: 0.8486 - val_loss: 1.3643 - val_accuracy: 0.6238
# Epoch 28/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.5186 - accuracy: 0.8519 - val_loss: 1.5255 - val_accuracy: 0.5961
# Epoch 29/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.4964 - accuracy: 0.8602 - val_loss: 1.4401 - val_accuracy: 0.6130
# Epoch 30/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.4683 - accuracy: 0.8640 - val_loss: 3.4514 - val_accuracy: 0.4039
# Epoch 31/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.4477 - accuracy: 0.8698 - val_loss: 1.4628 - val_accuracy: 0.6188
# Epoch 32/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.4275 - accuracy: 0.8776 - val_loss: 1.4725 - val_accuracy: 0.6389
# Epoch 33/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.4054 - accuracy: 0.8816 - val_loss: 1.6470 - val_accuracy: 0.5961
# Epoch 34/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.3935 - accuracy: 0.8889 - val_loss: 1.6101 - val_accuracy: 0.6092
# Epoch 35/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.3856 - accuracy: 0.8905 - val_loss: 2.2818 - val_accuracy: 0.5170
# Epoch 36/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.3643 - accuracy: 0.8969 - val_loss: 1.6467 - val_accuracy: 0.6150
# Epoch 37/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.3575 - accuracy: 0.9035 - val_loss: 1.8275 - val_accuracy: 0.5914
# Epoch 38/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.3362 - accuracy: 0.9054 - val_loss: 2.2414 - val_accuracy: 0.5559
# Epoch 39/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.3269 - accuracy: 0.9085 - val_loss: 1.8157 - val_accuracy: 0.6057
# Epoch 40/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.3292 - accuracy: 0.9108 - val_loss: 1.6031 - val_accuracy: 0.6389
# Epoch 41/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.3131 - accuracy: 0.9134 - val_loss: 1.7725 - val_accuracy: 0.6211
# Epoch 42/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.3162 - accuracy: 0.9130 - val_loss: 1.6629 - val_accuracy: 0.6208
# Epoch 43/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.3091 - accuracy: 0.9126 - val_loss: 1.8935 - val_accuracy: 0.5899
# Epoch 44/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.2831 - accuracy: 0.9240 - val_loss: 2.2921 - val_accuracy: 0.5698
# Epoch 45/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.2737 - accuracy: 0.9236 - val_loss: 1.8652 - val_accuracy: 0.6011
# Epoch 46/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2820 - accuracy: 0.9197 - val_loss: 2.0996 - val_accuracy: 0.5806
# Epoch 47/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2506 - accuracy: 0.9321 - val_loss: 2.3618 - val_accuracy: 0.5536
# Epoch 48/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.2496 - accuracy: 0.9304 - val_loss: 1.8886 - val_accuracy: 0.5883
# Epoch 49/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.2513 - accuracy: 0.9302 - val_loss: 1.8888 - val_accuracy: 0.5868
# Epoch 50/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2486 - accuracy: 0.9278 - val_loss: 2.2722 - val_accuracy: 0.5710
# Epoch 51/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2345 - accuracy: 0.9356 - val_loss: 2.4236 - val_accuracy: 0.5224
# Epoch 52/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2371 - accuracy: 0.9338 - val_loss: 2.0787 - val_accuracy: 0.5887
# Epoch 53/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2336 - accuracy: 0.9370 - val_loss: 1.8303 - val_accuracy: 0.6100
# Epoch 54/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2202 - accuracy: 0.9375 - val_loss: 3.8089 - val_accuracy: 0.4641
# Epoch 55/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2142 - accuracy: 0.9383 - val_loss: 2.5030 - val_accuracy: 0.5440
# Epoch 56/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2169 - accuracy: 0.9405 - val_loss: 2.6853 - val_accuracy: 0.5521
# Epoch 57/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2185 - accuracy: 0.9389 - val_loss: 3.1210 - val_accuracy: 0.4815
# Epoch 58/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2012 - accuracy: 0.9415 - val_loss: 1.9047 - val_accuracy: 0.6196
# Epoch 59/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2087 - accuracy: 0.9428 - val_loss: 2.3175 - val_accuracy: 0.5702
# Epoch 60/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1960 - accuracy: 0.9439 - val_loss: 2.2839 - val_accuracy: 0.5741
# Epoch 61/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1996 - accuracy: 0.9441 - val_loss: 2.2961 - val_accuracy: 0.5718
# Epoch 62/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1922 - accuracy: 0.9465 - val_loss: 2.8247 - val_accuracy: 0.5131
# Epoch 63/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1909 - accuracy: 0.9477 - val_loss: 2.3746 - val_accuracy: 0.5471
# Epoch 64/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1985 - accuracy: 0.9446 - val_loss: 2.0140 - val_accuracy: 0.5941
# Epoch 65/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1862 - accuracy: 0.9503 - val_loss: 2.6496 - val_accuracy: 0.5706
# Epoch 66/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1917 - accuracy: 0.9448 - val_loss: 2.9631 - val_accuracy: 0.5239
# Epoch 67/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1876 - accuracy: 0.9456 - val_loss: 2.8445 - val_accuracy: 0.5123
# Epoch 68/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1700 - accuracy: 0.9537 - val_loss: 2.3989 - val_accuracy: 0.5532
# Epoch 69/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1742 - accuracy: 0.9532 - val_loss: 2.0295 - val_accuracy: 0.6142
# Epoch 70/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1642 - accuracy: 0.9546 - val_loss: 2.3493 - val_accuracy: 0.5829
# Epoch 71/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1650 - accuracy: 0.9532 - val_loss: 2.2548 - val_accuracy: 0.5965
# Epoch 72/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1630 - accuracy: 0.9563 - val_loss: 2.1486 - val_accuracy: 0.6123
# Epoch 73/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1734 - accuracy: 0.9503 - val_loss: 2.4371 - val_accuracy: 0.5718
# Epoch 74/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1563 - accuracy: 0.9554 - val_loss: 2.7353 - val_accuracy: 0.5521
# Epoch 75/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1536 - accuracy: 0.9566 - val_loss: 2.4123 - val_accuracy: 0.5945
# Epoch 76/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1600 - accuracy: 0.9543 - val_loss: 2.4551 - val_accuracy: 0.5953
# Epoch 77/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1504 - accuracy: 0.9546 - val_loss: 2.4509 - val_accuracy: 0.5930
# Epoch 78/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1523 - accuracy: 0.9571 - val_loss: 2.3436 - val_accuracy: 0.5806
# Epoch 79/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1510 - accuracy: 0.9591 - val_loss: 2.2271 - val_accuracy: 0.5868
# Epoch 80/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1457 - accuracy: 0.9585 - val_loss: 2.8843 - val_accuracy: 0.5556
# Epoch 81/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1331 - accuracy: 0.9617 - val_loss: 2.8603 - val_accuracy: 0.5675
# Epoch 82/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1449 - accuracy: 0.9563 - val_loss: 3.1564 - val_accuracy: 0.5486
# Epoch 83/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1431 - accuracy: 0.9629 - val_loss: 1.8082 - val_accuracy: 0.6458
# Epoch 84/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1496 - accuracy: 0.9563 - val_loss: 2.2638 - val_accuracy: 0.6204
# Epoch 85/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1430 - accuracy: 0.9615 - val_loss: 2.9960 - val_accuracy: 0.5336
# Epoch 86/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1387 - accuracy: 0.9606 - val_loss: 2.8351 - val_accuracy: 0.5556
# Epoch 87/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1288 - accuracy: 0.9647 - val_loss: 2.6762 - val_accuracy: 0.5914
# Epoch 88/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1452 - accuracy: 0.9591 - val_loss: 2.0309 - val_accuracy: 0.6404
# Epoch 89/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1279 - accuracy: 0.9598 - val_loss: 3.4408 - val_accuracy: 0.5077
# Epoch 90/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1224 - accuracy: 0.9677 - val_loss: 3.7744 - val_accuracy: 0.5112
# Epoch 91/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1274 - accuracy: 0.9634 - val_loss: 2.5621 - val_accuracy: 0.5783
# Epoch 92/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1312 - accuracy: 0.9607 - val_loss: 1.8067 - val_accuracy: 0.6478
# Epoch 93/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1187 - accuracy: 0.9659 - val_loss: 2.2855 - val_accuracy: 0.6103
# Epoch 94/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1361 - accuracy: 0.9619 - val_loss: 2.5061 - val_accuracy: 0.5876
# Epoch 95/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1291 - accuracy: 0.9621 - val_loss: 3.1754 - val_accuracy: 0.5328
# Epoch 96/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1171 - accuracy: 0.9669 - val_loss: 2.1391 - val_accuracy: 0.6242
# Epoch 97/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1144 - accuracy: 0.9671 - val_loss: 2.5002 - val_accuracy: 0.5972
# Epoch 98/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1233 - accuracy: 0.9642 - val_loss: 2.2928 - val_accuracy: 0.6003
# Epoch 99/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1196 - accuracy: 0.9674 - val_loss: 1.9592 - val_accuracy: 0.6420
# Epoch 100/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1193 - accuracy: 0.9652 - val_loss: 2.3548 - val_accuracy: 0.6084

# %% [markdown]
# Salviamo nuovamente la history del modello in un file csv e convertiamo il miglior modello nel formato **.onnx**.

# %%
bp_model_history_df = convert_history_to_csv(bp_model_history)
bp_model_history_df.to_csv("model_histories/noise/rmsprop/bp_model_history.csv")

convert_model_to_onnx("bestmodels/noise/rmsprop/bp_basic_model.keras", (124, 129, 1))

# %%
create_train_val_plot(bp_model_history.history)

# %% [markdown]
# In questo caso il modello **HA raggiunto una fase di overfitting**, inoltre le prestazioni sono diminuite di parecchio sotto qualsiasi aspetto.

# %%
best_bp_basic_model = tf.keras.models.load_model("bestmodels/noise/rmsprop/bp_basic_model.keras")
test_loss, test_acc = best_bp_basic_model.evaluate(mixed_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 7ms/step - loss: 1.4095 - accuracy: 0.6284
# Accuratezza: 0.628

# %%
evaluate_onnx_model("bestmodels/noise/rmsprop/bp_basic_model.onnx", mixed_test_ds)
# Out:
# Accuratezza: 0.628

# %% [markdown]
# Abbiamo ottenuto un forte peggioramento per quanto riguarda l'accuratezza, ottenendo un **62.8%**.

# %%
for audio, label in mixed_test_ds:
    create_distribution_plot(best_bp_basic_model, audio, label)
    break

# %% [markdown]
# La decisione del modello in questo caso è completamente sbagliata, non si è avvicinato minimamente alla classe corretta.
