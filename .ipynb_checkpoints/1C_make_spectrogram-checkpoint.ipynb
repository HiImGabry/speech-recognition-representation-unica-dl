# %% [markdown]
# # Analisi di spettrogrammi audio
#
# In questo notebook viene eseguita un'analisi sugli spettrogrammi di alcuni audio. L'obiettivo è estrarre informazioni utili dagli spettrogrammi e rappresentarle graficamente.

# %% [markdown]
# ## Importazione delle librerie necessarie
# Si installano e importano le librerie necessarie per l'analisi e la visualizzazione dei dati.

# %%
import random
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importazione del dataset
# Importiamo anche il dataset dalla quale prenderemo gli audio. Questo passaggio l'abbiamo già visto nel notebook precedente dove abbiamo effettuato un'analisi esplorativa.

# %%
train_ds, validation_ds = tf.keras.utils.audio_dataset_from_directory(
    directory='../reduced_dataset/dataset/audio',
    validation_split=0.4, # stiamo mettendo da parte il 40% del dataset, che sarà suddiviso in validation set e test set
    shuffle=True,
    subset='both', # necessario se stiamo utilizzando validation_split (se no darebbe errore)
    seed=0 # necessario se stiamo utilizzando sia shuffle che validation_split (se no darebbe errore)
)

label_names = train_ds.class_names
# Out:
# Found 12933 files belonging to 30 classes.
# Using 7760 files for training.
# Using 5173 files for validation.

# %% [markdown]
# ## Funzioni per il processamento dei dati
# I dati a nostra disposizione sono dei **file .wav** perciò è necessario definire delle funzioni per convertirli in spettrogrammi.

# %% [markdown]
# La prima funzione definita è `squeeze()`, la quale prende come argomenti l'audio e le classi.
#
# Questa funzione serve per rimuovere l'ultimo asse dello shape dai nostri audio. Attualmente, lo shape dei dati, come abbiamo potuto analizzare nel notebook sulol'analisi esplorativa, è (32, 16000, 1), ma si può eliminare l'ultima dimensione poiché non necessaria. L'ultima dimensione non è necessaria perché gli audio che stiamo trattando sono di tipo **mono**. Specificando il parametro **axis=-1** nella funzione `tf.squeeze` la forma dell'audio viene trasformata in (32, 16000).
#
# Eseguiamo questa semplificazione sulla forma del dato poiché rende la fase di processamento dei dati più efficiente, soprattutto per quando andremo a utilizzare un modello.

# %%
def squeeze(audio, labels):
    audio = tf.squeeze(audio, axis=-1)
    return audio, labels

# %%
train_ds = train_ds.map(squeeze, tf.data.AUTOTUNE)
validation_ds = validation_ds.map(squeeze, tf.data.AUTOTUNE)

audio, label = next(iter(train_ds))
print(audio.shape)
print(label.shape)
# Out:
# (32, 16000)
# (32,)

# %% [markdown]
# Come è possibile notare, adesso la forma dell'audio è (32, 16000).

# %% [markdown]
# ### Conversione dataset
# Definiamo altre due funzioni: `get_spectrogram` e `get_spectrogram_dataset`. Quest'ultime usate insieme convertono il nostro dataset di audio in un dataset di spettrogrammi. La prima funzione `get_spectrogram` converte il singolo audio in spettrogramma attraverso la **short-time Fourier Transform**.
#
# Viene utilizzata la **short-time Fourier Transform** (`tf.signal.stft`) invece della **trasformata di Fourier** (`tf.signal.fft`) perché quest'ultima perde tutte le informazioni temporali. I parametri `frame_length` e `frame_step` hanno dei valori tali da produrre uno spettrogramma di grandezza quasi quadrata.
#
# La **short-time Fourier transform** produce una matrice di **numeri complessi** che rappresentano l'ampiezza e la fase. Noi rappresenteremo soltanto l'ampiezza dello spettrogramma grazie all'applicazione di `tf.abs`.

# %%
def get_spectrogram(waveform):
    # applichiamo la short-time Fourier transorm
    spectrogram = tf.signal.stft(waveform, frame_length=255, frame_step=128)
    spectrogram = tf.abs(spectrogram)
    
    return spectrogram[..., tf.newaxis]

# fonte: tutorial riconoscimento audio semplice di tensorflow: https://www.tensorflow.org/tutorials/audio/simple_audio?hl=it

# %% [markdown]
# La seconda funzione `get_spectrogram_dataset` richiama la prima funzione per ogni dato presente nel dataset.

# %%
def get_spectrogram_dataset(dataset):
    dataset = dataset.map(lambda x, y: (get_spectrogram(x), y), num_parallel_calls=tf.data.AUTOTUNE)
    
    return dataset

# %% [markdown]
# Infine definiamo la funzione `samplefy()`, che prende in input un dataset e una label. Questa funzione è necessaria per ricavare un audio, o nel nostro caso uno spettrogramma, appartenente a una specifica classe.

# %%
def samplefy(dataset, dir_label):
    for audio, label in dataset:
        label_np = label.numpy()
        
        for i in range(len(label_np)):
            if label_names[label_np[i]] == dir_label:
                spectrogram = np.squeeze(audio[i], axis=-1)
                spectrogram = np.log(spectrogram.T + np.finfo(float).eps)  # aggiungiamo una piccola costante per evitare problemi con log(0)
                return spectrogram, label_names[label_np[i]]

# %% [markdown]
# ## Visualizzazione spettrogrammi
# La funzione `plot_spectrograms` racchiude tutti i comandi utili per la visualizzazione dei dati. Quando chiamata, utilizza la funzione precedentemente creata per estrarre le informazioni di quattro diversi audio.

# %%
def plot_spectrograms(dataset):
    spectrogram1, label1 = samplefy(dataset, 'right')
    spectrogram2, label2 = samplefy(dataset, 'right')
    spectrogram3, label3 = samplefy(dataset, 'tree')
    spectrogram4, label4 = samplefy(dataset, 'tree')
    
    fig, ax = plt.subplots(2, 2, figsize=(12, 8)) # Creiamo subplot 2 x 2
    fig.tight_layout(pad=3.0)  # Aggiunge padding tra subplot
    
    # Primo spettrogramma
    im1 = ax[0, 0].imshow(spectrogram1, origin="lower")
    fig.colorbar(im1, ax=ax[0, 0], format='%+2.0f dB')
    ax[0, 0].set_title(f"Spettrogramma classe: {label1}")
    ax[0, 0].set_ylabel("Bande di frequenza", fontweight="semibold")
    ax[0, 0].set_xlabel("Segmenti temporali", fontweight="semibold")
    
    # Secondo spettrogramma
    im2 = ax[0, 1].imshow(spectrogram2, origin="lower")
    fig.colorbar(im2, ax=ax[0, 1], format='%+2.0f dB')
    ax[0, 1].set_title(f"Spettrogramma classe: {label2}")
    ax[0, 1].set_ylabel("Bande di frequenza", fontweight="semibold")
    ax[0, 1].set_xlabel("Segmenti temporali", fontweight="semibold")
    
    # Terzo spettrogramma
    im3 = ax[1, 0].imshow(spectrogram3, origin="lower")
    fig.colorbar(im3, ax=ax[1, 0], format='%+2.0f dB')
    ax[1, 0].set_title(f"Spettrogramma classe: {label3}")
    ax[1, 0].set_ylabel("Bande di frequenza", fontweight="semibold")
    ax[1, 0].set_xlabel("Segmenti temporali", fontweight="semibold")
    
    # Quarto spettrogramma
    im4 = ax[1, 1].imshow(spectrogram4, origin="lower")
    fig.colorbar(im4, ax=ax[1, 1], format='%+2.0f dB')
    ax[1, 1].set_title(f"Spettrogramma classe: {label4}")
    ax[1, 1].set_ylabel("Bande di frequenza", fontweight="semibold")
    ax[1, 1].set_xlabel("Segmenti temporali", fontweight="semibold")
    
    plt.show()

# %%
#diminuiamo la dimensione e otteniamo il dataset di spettrogrammi
train_ds = get_spectrogram_dataset(train_ds)

# %%
plot_spectrograms(train_ds)

# %% [markdown]
# Vengono rappresentati gli spettrogrammi di due etichette diverse. Si può notare, anche ad occhio, come comandi appartenenti ad una stessa etichette abbiano frequenze simili, mentre quelli di classi diverse presentano differenze significative.
