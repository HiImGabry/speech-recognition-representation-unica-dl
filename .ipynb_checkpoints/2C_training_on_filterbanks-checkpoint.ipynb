# %% [markdown]
# # Addestramento modello convolutivo
# Nel seguente notebook verranno addestrati i modelli presenti nel notebook [Modello convolutivo](Modello_convolutivo.ipynb), utilizzando come tipo di dati i **filterbanks** e gli **mfcc**. Ci aspettiamo di ottenere risultati differenti e sarà interessante analizzare le differenze.

# %%
import os
import time
import numpy as np
import pandas as pd
import tensorflow as tf
import scipy.fftpack as scipy
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# per il modello con estensione .onnx
import onnxruntime as rt
import tf2onnx
import onnx

# %% [markdown]
# ## Classe per la conversione del dataset
# Vista la quantità di opzioni disponibili, si è scelto di creare una classe. Essa contiene il metodo `convert` in grado di trasformare il dataset di audio in spettrogrammi, filterbanks, o mfcc in base all'argomento dato in input. Gli altri metodi presenti al suo interno sono già stati spiegati e ne abbiamo visto l'utilizzo nei precedenti notebook.

# %%
class DatasetConverter:
    def __init__(self, dataset):
        self.dataset = dataset

    def convert(self, option):
        available_options = ['spettrogrammi', 'filterbanks', 'mfcc']
        
        if option == available_options[0]:
            return self.get_spectrogram_dataset()
        elif option == available_options[1]:
            return self.get_filterbanks_dataset()
        elif option == available_options[2]:
            return self.get_mfcc_dataset()
        else:
            raise ValueError(f"Opzione non disponibile: inserire una delle seguenti opzioni: {available_options}")
    
    # INIZIO SPETTROGRAMMI
    def squeeze(self, audio, labels):
        audio = tf.squeeze(audio, axis=-1)
        return audio, labels
    
    def get_spectrogram(self, waveform):
    # applichiamo la short-time Fourier transorm
        spectrogram = tf.signal.stft(waveform, frame_length=255, frame_step=128)
        spectrogram = tf.abs(spectrogram)
        
        return spectrogram[..., tf.newaxis]
    
    def get_spectrogram_dataset(self):
        # squeeze
        self.dataset = self.dataset.map(self.squeeze, tf.data.AUTOTUNE)
        self.dataset = self.dataset.map(lambda x, y: (self.get_spectrogram(x), y), num_parallel_calls=tf.data.AUTOTUNE)
        
        return self.dataset

    # FINE SPETTROGRAMMI

    def convert_to_numpy(self, dataset):
        audio_data = []
        labels = []
    
        dataset = dataset.unbatch()
        
        for audio, label in dataset:
            audio_data.append(audio.numpy())  # Assuming audio is a tensor, convert to numpy array
            labels.append(label.numpy())      # Assuming label is a tensor, convert to numpy array
        
        audio_data = np.array(audio_data)
        labels = np.array(labels)
        
        return audio_data, labels
    
    # INIZIO FILTERBANKS
    def makeHamming(self, M):
        R = (( M - 1 ) / 2 , M / 2)[M % 2 == 0]
        w = (np.hamming(M), np.hamming(M + 1))[M % 2 == 0]
        if M % 2 != 0:
            w[0] = w[0]/2
            w[M-1] = w[M-1]/2
        else:
            w = w[:M]
    
        return w

    def hztomel(self, hz):
        return (2595 * np.log10(1 + hz / 700))

    def meltohz(self, mel):
        return (700 * (10**(mel / 2595) - 1))

    def compute_filterbanks(self, audios_np, pre_emphasis=0.97, sample_rate=16000, frame_size=0.025, frame_stride=0.01, NFFT=512, nfilt=40):
        filterbanks_np = []
        
        for samples in audios_np:
            emphasized_audio = np.append(samples[0], samples[1:] - pre_emphasis * samples[:-1])
            audio_length = len(emphasized_audio)
    
            frame_length, frame_step = int(frame_size * sample_rate), int(frame_stride * sample_rate)
    
            num_frames = int(np.ceil(float(np.abs(audio_length - frame_length)) / frame_step))
    
            pad_audio_length = num_frames * frame_step + frame_length
            z = np.zeros((pad_audio_length - audio_length))
            pad_audio = np.append(emphasized_audio, z)
    
            indices = np.tile(np.arange(0, frame_length), (num_frames, 1)) + np.tile(np.arange(0, num_frames * frame_step, frame_step), (frame_length, 1)).T
            frames = pad_audio[indices.astype(np.int32, copy=False)]
    
            # Usiamo la funzione di Hamming
            hamming_window = self.makeHamming(frame_length)
    
            mag_frames = np.absolute(np.fft.rfft(frames, NFFT))  # Magnitudo della FFT
            pow_frames = ((1.0 / NFFT) * ((mag_frames) ** 2))
    
            # convertiamo hz in mel
            low_freq_mel = self.hztomel(0)
            high_freq_mel = self.hztomel(sample_rate / 2)
    
            mel_points = np.linspace(low_freq_mel, high_freq_mel, nfilt + 2)
            hz_points = self.meltohz(mel_points) 
    
            bin = np.floor((NFFT + 1) * hz_points / sample_rate)
    
            fbank = np.zeros((nfilt, int(np.floor(NFFT / 2 + 1))))
    
            for m in range(1, nfilt + 1):
                f_m_minus = int(bin[m - 1])
                f_m = int(bin[m])
                f_m_plus = int(bin[m + 1])
    
                for k in range(f_m_minus, f_m):
                    fbank[m - 1, k] = (k - bin[m - 1]) / (bin[m] - bin[m - 1])
                for k in range(f_m, f_m_plus):
                    fbank[m - 1, k] = (bin[m + 1] - k) / (bin[m + 1] - bin[m])
    
            # in questo momento invece calcoliamo i filter banks per i segmenti di audio, utilizzando i filtri triangolari appena creati
            filter_banks = np.dot(pow_frames, fbank.T)
            filter_banks = np.where(filter_banks == 0, np.finfo(float).eps, filter_banks)
            filter_banks = 20 * np.log10(filter_banks)
    
            filterbanks_np.append(filter_banks)
        
        return np.array(filterbanks_np)
    
    def get_filterbanks_dataset(self): 
        audios, labels = self.convert_to_numpy(self.dataset)

        filterbanks = self.compute_filterbanks(audios)
        filterbanks = np.expand_dims(filterbanks, axis=-1)

        self.dataset = tf.data.Dataset.from_tensor_slices((filterbanks, labels))
        self.dataset = self.dataset.batch(32)
        
        return self.dataset
    # FINE FILTERBANKS

    # INIZIO MFCC
    def compute_mfcc(self, filter_banks, num_ceps=12, cep_lifter=22):
        mfcc_np = []
        
        for f in filter_banks:
            mfcc = scipy.dct(f, type=2, axis=1, norm='ortho')[:, 1 : (num_ceps + 1)]

            (nframes, ncoeff) = mfcc.shape
            n = np.arange(ncoeff)
            
            lift = 1 + (cep_lifter / 2) * np.sin(np.pi * n / cep_lifter)
            mfcc *= lift

            mfcc_np.append(mfcc)
        
        return np.array(mfcc_np)
    
    
    def get_mfcc_dataset(self):
        audios, labels = self.convert_to_numpy(self.dataset)

        filterbanks = self.compute_filterbanks(audios)
        mfcc = self.compute_mfcc(filterbanks)
        
        mfcc = np.expand_dims(mfcc, axis=-1)
        
        self.dataset = tf.data.Dataset.from_tensor_slices((mfcc, labels))
        self.dataset = self.dataset.batch(32)
        
        return self.dataset
    
    # FINE MFCC

# %% [markdown]
# ## Importazione funzioni ulteriori
# In aggiunta alla classe per la conversione del dataset, ci serviremo delle seguenti funzioni:
# - `convert_history_to_csv` - salva l'history dell'addestramento in un csv
# - `convert_model_to_onnx` - converte il miglior modello **.keras** in **.onnx**
# - `create_train_val_plot` - visualizza l'andamento dell'accuratezza e della perdita durante l'addestramento
# - `evaluate_onnx_model` - valuta il modello sui dati di test con il modello **.onnx**
# - `create_distribution_plot` - visualizza la distribuzione di accuratezza delle classi su un'immagine casuale
#
# Anch'esse sono già state viste, perciò non ci soffermeremo troppo su di esse.

# %%
def convert_history_to_csv(model_history):
    # converto la history del dataframe in un dataframe pandas
    model_history_df = pd.DataFrame(model_history.history)
    # cambio il nome dell'indice e lo imposto a partire da 1
    model_history_df.index = range(1, len(model_history_df) + 1)
    model_history_df.index.name = "epochs"

    return model_history_df

def convert_model_to_onnx(model_path, input_shape):
    model = tf.keras.models.load_model(model_path)

    onnx_path = model_path.split(".")[:-1] + ["onnx"]
    onnx_path = ".".join(onnx_path)
    
    input_signature = [tf.TensorSpec((None, *input_shape), tf.float32, name="input")]
    onnx_model, _ = tf2onnx.convert.from_keras(model, input_signature=input_signature)

    onnx.save(onnx_model, onnx_path)

def create_train_val_plot(history, overfit=True):
    # definisco numero epoche
    epochs = range(1, len(history['accuracy']) + 1)

    # Accuracy
    accuracy = history['accuracy']
    val_accuracy = history['val_accuracy']

    fig_acc, ax_acc = plt.subplots()

    # linea di base
    ax_acc.plot(epochs, [0.5 for x in range(len(epochs))], color="lightgray", linestyle="--", label="Base")
    # linee di accuratezza
    ax_acc.plot(epochs, accuracy, color="slategray", label="Accuratezza in addestramento")
    ax_acc.plot(epochs, val_accuracy, color="indianred", label="Accuratezza in validazione")
    # miglior accuratezza validazione
    ax_acc.axhline(y=max(val_accuracy), c='indianred', alpha=0.7, linestyle='--')
    ax_acc.text(len(epochs) * 1.07, max(val_accuracy), round(max(val_accuracy), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_acc.spines["right"].set_visible(False)
    ax_acc.spines["top"].set_visible(False)
    ax_acc.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_acc.set_title("Accuratezza in addestramento e validazione")
    ax_acc.set_xlabel("Epoche")
    ax_acc.set_ylabel("Accuratezza (%)")
    ax_acc.legend()

    # Loss
    loss = history['loss']
    val_loss = history['val_loss']

    fig_loss, ax_loss = plt.subplots()

    # linee di loss
    ax_loss.plot(epochs, loss, color="slategray", label="Perdita in addestramento")
    ax_loss.plot(epochs, val_loss, color="indianred", label="Perdita in validazione")
    # miglior loss validazione
    ax_loss.axhline(y=min(val_loss), c='indianred', alpha=0.7, linestyle='--')
    ax_loss.text(len(epochs) * 1.07, min(val_loss), round(min(val_loss), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_loss.spines["right"].set_visible(False)
    ax_loss.spines["top"].set_visible(False)
    ax_loss.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_loss.set_title("Perdita in addestramento e validazione")
    ax_loss.set_xlabel("Epoche")
    ax_loss.set_ylabel("Perdita")

    handles, _ = ax_loss.get_legend_handles_labels()

    if overfit:
        # area overfit
        rect = mpatches.Rectangle((np.argmin(val_loss) + 1, 0), width=100 - np.argmin(val_loss), height=max(max(loss), max(val_loss)), color='lightcoral', alpha=0.3)
        ax_loss.add_patch(rect)
        # patch overfit per legenda
        overfit = mpatches.Patch(color='indianred', alpha=0.3, label='Area overfit')
        handles, _ = ax_loss.get_legend_handles_labels()
        handles.append(overfit)

    # legenda
    ax_loss.legend(handles=handles)

    plt.show()

def evaluate_onnx_model(path_model_onnx, test_ds):
    # il fatto che sia suddiviso in batch mi crea problemi, perciò lo risolvo togliendoli
    test_ds = test_ds.unbatch()
    
    # carico il modello utilizzando il file onnx
    m = rt.InferenceSession(path_model_onnx)
    
    # trasformo il dataset in array numpy
    spectrogram_np = np.array([spectrogram.numpy() for spectrogram, _ in test_ds], dtype=np.float32)
    labels_np = np.array([label.numpy() for _, label in test_ds])
    
    # eseguo le predizione del modello
    pred_onnx = m.run(None, {'input': spectrogram_np})
    # ottengo la predizione corretta
    predictions = np.argmax(pred_onnx[0], axis=1)
    # computo la accuratezza
    accuracy = np.mean(predictions == labels_np)
    # stampo l'accuratezza
    print(f"Accuratezza: {accuracy:.3f}")

def create_distribution_plot(model, audio, label):
    prediction = model(audio) # otteniamo la predizione del modello sull'audio preso in input

    random_audio_index = np.random.randint(0, len(prediction) - 1) # abbiamo notato che mostravamo sempre la classe no, magari così cambia un po' le classi che mostriamo

    softmax_pred = tf.nn.softmax(prediction[random_audio_index]) # dobbiamo applicare nuovamente la softmax in modo tale da avere dei dati leggibili
    pred_label = np.argmax(softmax_pred) # ci salviamo l'indice della label predetta dal nostro modello, quella con la probabilità più alta

    colors = ['indianred'] * len(label_names) # creiamo un vettore di lunghezza 30 (la quantità delle nostre label) colorate di rosso

    if pred_label == label[random_audio_index].numpy(): # se la label che abbiamo predetto è corretta, allora la coloriamo di verde
        colors[pred_label] = 'seagreen'
    else: # se la label che abbiamo predetto è sbagliata, allora coloriamo di verde la corretta e di gialla la predetta
        colors[pred_label] = 'khaki'
        colors[label[random_audio_index].numpy()] = 'seagreen'

    plt.figure(figsize=(12, 4))

    plt.bar(label_names, softmax_pred.numpy(), color=colors)
    plt.xticks(rotation=45)

    # dichiariamo i colori della legenda
    other_values_patch = mpatches.Patch(color='indianred', label='Altre classi')
    pred_value_patch = mpatches.Patch(color='khaki', label='Classe predetta')
    correct_value_patch = mpatches.Patch(color='green', label='Classe corretta')

    # disegniamo la legenda con i colori necessari
    if pred_label == label[random_audio_index].numpy(): # se abbiamo predetto correttamente la label, non è necessario mostrare il colore giallo (non è presente nel plot)
        plt.legend(handles=[other_values_patch, correct_value_patch])
    else:
        plt.legend(handles=[other_values_patch, pred_value_patch, correct_value_patch])

    plt.show()

# %% [markdown]
# Importiamo il dataset e lo dividiamo in set di allenamento e set di validazione. Successivamente salviamo la lista delle etichette disponibili.

# %%
train_ds, validation_ds = tf.keras.utils.audio_dataset_from_directory(
    directory='../reduced_dataset/dataset/audio',
    validation_split=0.4, # stiamo mettendo da parte il 40% del dataset, che sarà suddiviso in validation set e test set
    shuffle=True,
    subset='both', # necessario se stiamo utilizzando validation_split (se no darebbe errore)
    seed=0 # necessario se stiamo utilizzando sia shuffle che validation_split (se no darebbe errore)
)

label_names = train_ds.class_names
# Out:
# Found 12933 files belonging to 30 classes.
# Using 7760 files for training.
# Using 5173 files for validation.

# %% [markdown]
# ## Addestramento modello convolutivo base (filterbanks)
# L'addestramento delle reti convolutive sugli spettrogrammi sono già state effettuate, perciò di seguito ci focalizzeremo sui filterbank.

# %% [markdown]
# Si parte chiamando la classe **DatasetConvert** e passandole in input il set di allenamento. Di seguito, con il metodo **convert**, scegliamo di mutare gli audio in filterbanks.
#
# Ripetiamo gli stessi passaggi anche per il set di validazione. Quest'ultimo viene ulteriormente diviso per creare il set di test.

# %%
fb_train_ds = DatasetConverter(train_ds)
fb_train_ds = fb_train_ds.convert('filterbanks')

fb_validation_ds = DatasetConverter(validation_ds)
fb_validation_ds = fb_validation_ds.convert('filterbanks')

fb_val_ds = fb_validation_ds.take(fb_validation_ds.cardinality() // 2)
fb_test_ds = fb_validation_ds.skip(fb_validation_ds.cardinality() // 2)

# %% [markdown]
# Ora che abbiamo convertito con successo il dataset in filterbank, possiamo creare il modello, identico a quello usato per gli spettrogrammi, e procedere all'addestramento utilizzando l'ottimizzatore **rmsprop**.

# %%
def get_basic_model(input_shape):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=input_shape, name="inputs")
    x = tf.keras.layers.Normalization(name="normalizzazione")(inputs)

    # Blocco di apprendimento delle caratteristiche
    conv2D_1 = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same", name="conv2D_1")(x)
    MaxPooling2D_1 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_1")(conv2D_1)
    conv2D_2 = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same", name="conv2D_2")(MaxPooling2D_1)
    MaxPooling2D_2 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_2")(conv2D_2)
    conv2D_3 = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same", name="conv2D_3")(MaxPooling2D_2)
    MaxPooling2D_3 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_3")(conv2D_3)
    conv2D_4 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_4")(MaxPooling2D_3)
    MaxPooling2D_4 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_4")(conv2D_4)
    conv2D_5 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_5")(MaxPooling2D_4)

    # Blocco di classificazione
    Flatten = tf.keras.layers.Flatten(name="Flatten")(conv2D_5)
    outputs = tf.keras.layers.Dense(30, activation="softmax", name="dense_output")(Flatten)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
for audio, label in fb_train_ds:
    basic_model = get_basic_model(audio.shape[1:])
    break
    
basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

basic_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inputs (InputLayer)         [(None, 98, 40, 1)]       0
#
#  normalizzazione (Normalizat  (None, 98, 40, 1)        3
#  ion)
#
#  conv2D_1 (Conv2D)           (None, 98, 40, 32)        320
#
#  MaxPooling2D_1 (MaxPooling2  (None, 49, 20, 32)       0
#  D)
#
#  conv2D_2 (Conv2D)           (None, 49, 20, 64)        18496
#
#  MaxPooling2D_2 (MaxPooling2  (None, 24, 10, 64)       0
#  D)
#
#  conv2D_3 (Conv2D)           (None, 24, 10, 128)       73856
#
#  MaxPooling2D_3 (MaxPooling2  (None, 12, 5, 128)       0
#  D)
#
#  conv2D_4 (Conv2D)           (None, 12, 5, 256)        295168
#
#  MaxPooling2D_4 (MaxPooling2  (None, 6, 2, 256)        0
#  D)
#
#  conv2D_5 (Conv2D)           (None, 6, 2, 256)         590080
#
#  Flatten (Flatten)           (None, 3072)              0
#
#  dense_output (Dense)        (None, 30)                92190
#
# =================================================================
# Total params: 1,070,113
# Trainable params: 1,070,110
# Non-trainable params: 3
# _________________________________________________________________

# %% [markdown]
# Essendo l'input shape di **98 x 40**, anche il numero di parametri sarà minore rispetto al modello addestrato sugli spettrogrammi, passando da circa **1.4 milioni di parametri** a poco meno di **1.1 milioni di parametri**.

# %%
basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/filterbanks/basic_model_fb.keras", save_best_only=True, monitor="val_loss")]
basic_model_history = basic_model.fit(fb_train_ds, epochs=30, batch_size=32, validation_data=fb_val_ds, callbacks=basic_model_callbacks)
# Out:
# Epoch 1/30
# 243/243 [==============================] - 5s 6ms/step - loss: 3.4511 - accuracy: 0.1384 - val_loss: 2.1295 - val_accuracy: 0.3804
# Epoch 2/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.3277 - accuracy: 0.6159 - val_loss: 1.1025 - val_accuracy: 0.6948
# Epoch 3/30
# 243/243 [==============================] - 1s 6ms/step - loss: 0.6295 - accuracy: 0.8080 - val_loss: 0.6315 - val_accuracy: 0.8264
# Epoch 4/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3865 - accuracy: 0.8813 - val_loss: 0.6485 - val_accuracy: 0.8306
# Epoch 5/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2696 - accuracy: 0.9209 - val_loss: 0.7174 - val_accuracy: 0.8445
# Epoch 6/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2208 - accuracy: 0.9338 - val_loss: 0.8309 - val_accuracy: 0.8353
# Epoch 7/30
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1804 - accuracy: 0.9468 - val_loss: 0.9592 - val_accuracy: 0.8519
# Epoch 8/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1862 - accuracy: 0.9500 - val_loss: 0.6331 - val_accuracy: 0.8661
# Epoch 9/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1550 - accuracy: 0.9589 - val_loss: 0.8265 - val_accuracy: 0.8592
# Epoch 10/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1595 - accuracy: 0.9607 - val_loss: 1.6859 - val_accuracy: 0.8310
# Epoch 11/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1537 - accuracy: 0.9634 - val_loss: 0.9097 - val_accuracy: 0.8627
# Epoch 12/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1512 - accuracy: 0.9631 - val_loss: 1.2916 - val_accuracy: 0.8603
# Epoch 13/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1409 - accuracy: 0.9662 - val_loss: 1.3256 - val_accuracy: 0.8623
# Epoch 14/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1273 - accuracy: 0.9697 - val_loss: 1.1136 - val_accuracy: 0.8823
# Epoch 15/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1050 - accuracy: 0.9767 - val_loss: 1.3010 - val_accuracy: 0.8831
# Epoch 16/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1532 - accuracy: 0.9698 - val_loss: 1.1151 - val_accuracy: 0.8692
# Epoch 17/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1262 - accuracy: 0.9709 - val_loss: 1.1044 - val_accuracy: 0.8981
# Epoch 18/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1291 - accuracy: 0.9731 - val_loss: 1.7160 - val_accuracy: 0.8889
# Epoch 19/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1532 - accuracy: 0.9740 - val_loss: 1.5422 - val_accuracy: 0.8700
# Epoch 20/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1462 - accuracy: 0.9767 - val_loss: 1.3024 - val_accuracy: 0.8893
# Epoch 21/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1449 - accuracy: 0.9738 - val_loss: 1.4030 - val_accuracy: 0.8954
# Epoch 22/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1132 - accuracy: 0.9790 - val_loss: 1.3325 - val_accuracy: 0.8924
# Epoch 23/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1281 - accuracy: 0.9787 - val_loss: 1.5964 - val_accuracy: 0.8700
# Epoch 24/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1142 - accuracy: 0.9807 - val_loss: 1.7021 - val_accuracy: 0.8746
# Epoch 25/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1051 - accuracy: 0.9843 - val_loss: 2.8970 - val_accuracy: 0.8804
# Epoch 26/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1520 - accuracy: 0.9777 - val_loss: 2.0895 - val_accuracy: 0.8819
# Epoch 27/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1219 - accuracy: 0.9796 - val_loss: 2.1710 - val_accuracy: 0.8789
# Epoch 28/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0801 - accuracy: 0.9844 - val_loss: 2.6054 - val_accuracy: 0.8835
# Epoch 29/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1710 - accuracy: 0.9790 - val_loss: 1.8278 - val_accuracy: 0.8877
# Epoch 30/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1189 - accuracy: 0.9838 - val_loss: 1.8990 - val_accuracy: 0.8885

# %% [markdown]
# Salviamo i dati della cronologia del modello in un file csv e convertiamo il miglior modello nell'estensione **.onnx**.

# %%
basic_model_history_df = convert_history_to_csv(basic_model_history)
basic_model_history_df.to_csv("model_histories/rmsprop/filterbanks/basic_model_history_fb.csv")

convert_model_to_onnx("bestmodels/rmsprop/filterbanks/basic_model_fb.keras", (98, 40, 1))

# %% [markdown]
# Analizziamo l'andamento dell'accuratezza e della perdita durante l'addestramento.

# %%
create_train_val_plot(basic_model_history.history)

# %% [markdown]
# Dal grafico si evince che il modello entra in overfitting poco dopo la quinta epoca, raggiungendo comunque ottimi risultati per quanto riguarda l'accuratezza del validation set, con **90** punti percentile.
#
# La rete, inoltre, sembra essere lievemente migliore del modello addestrato sugli spettrogrammi, ma comparazioni più approffondite saranno affrontate su un notebook dedicato.

# %% [markdown]
# Verifichiamo l'accuratezza della migliore versione del modello di base.

# %%
best_basic_model = tf.keras.models.load_model("bestmodels/rmsprop/filterbanks/basic_model_fb.keras")
test_loss, test_acc = best_basic_model.evaluate(fb_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 6ms/step - loss: 0.6628 - accuracy: 0.8241
# Accuratezza: 0.824

# %%
evaluate_onnx_model("bestmodels/rmsprop/filterbanks/basic_model_fb.onnx", fb_test_ds)
# Out:
# Accuratezza: 0.824

# %% [markdown]
# Abbiamo ottenuto un'**accuratezza** del **82.4%**! Attualmente abbiamo riscontrato un miglioramento utilizzando i filter banks. Visualizziamo la distribuzione di accuratezza delle classi.

# %%
for audio, label in fb_test_ds: # prendiamo un audio a caso del test e creiamo la distribuzione
    create_distribution_plot(best_basic_model, audio, label)
    break

# %% [markdown]
# In questo specifico caso il modello ha **sbagliato totalmente** la classe predetta.

# %% [markdown]
# ### Convolutivo base risoluzione dell'overfitting
# In questa parte implementiamo il secondo modello presente nel notebook di riferimento, ovvero quello riguardante il paragrafo **risoluzione dell'overfitting**, dove viene aggiunto uno strato di dropout.

# %% [markdown]
# Come fatto prima, si procede con la creazione e l'addestramento del modello con l'ottimizzatore **rmsprop**.

# %%
def get_improved_basic_model(input_shape):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=input_shape)
    x = tf.keras.layers.Normalization()(inputs)

    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
for audio, label in fb_train_ds:
    improved_basic_model = get_improved_basic_model(audio.shape[1:])
    break

improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

# %%
improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/filterbanks/improved_basic_model_fb.keras", save_best_only=True, monitor="val_loss")]
improved_history = improved_basic_model.fit(fb_train_ds, epochs=100, validation_data=fb_val_ds, callbacks=improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] -
100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2614 - accuracy: 0.9816 - val_loss: 3.2280 - val_accuracy: 0.9167
# Epoch 93/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1853 - accuracy: 0.9848 - val_loss: 3.4647 - val_accuracy: 0.9155
# Epoch 94/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2718 - accuracy: 0.9839 - val_loss: 2.9622 - val_accuracy: 0.9144
# Epoch 95/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1985 - accuracy: 0.9840 - val_loss: 2.6096 - val_accuracy: 0.9252
# Epoch 96/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2129 - accuracy: 0.9831 - val_loss: 3.6436 - val_accuracy: 0.9159
# Epoch 97/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.2535 - accuracy: 0.9832 - val_loss: 4.3599 - val_accuracy: 0.9020
# Epoch 98/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.2005 - accuracy: 0.9826 - val_loss: 2.8122 - val_accuracy: 0.9136
# Epoch 99/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2193 - accuracy: 0.9826 - val_loss: 3.6588 - val_accuracy: 0.9055
# Epoch 100/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.2493 - accuracy: 0.9838 - val_loss: 4.9044 - val_accuracy: 0.9144

# %% [markdown]
# Seguiamo lo stesso ordine di prima per le operazione post-addestramento.

# %%
improved_history_df = convert_history_to_csv(improved_history)
improved_history_df.to_csv("model_histories/rmsprop/filterbanks/improved_history_fb.csv")

convert_model_to_onnx("bestmodels/rmsprop/filterbanks/improved_basic_model_fb.keras", (98, 40, 1))

# %%
create_train_val_plot(improved_history.history)

# %% [markdown]
# I risultati sono decisamente positivi. Siamo riusciti a ritardare il sovradattamento, arrivando a livelli di perdita molto più bassi rispetto al precedente. Inoltre, l'accuratezza nel set di valutazione è salita del **3%**.

# %%
improved_best_model = tf.keras.models.load_model("bestmodels/rmsprop/filterbanks/improved_basic_model_fb.keras")
test_loss, test_acc = improved_best_model.evaluate(fb_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5419 - accuracy: 0.8807
# Accuratezza: 0.881

# %%
evaluate_onnx_model("bestmodels/rmsprop/filterbanks/improved_basic_model_fb.onnx", fb_test_ds)
# Out:
# Accuratezza: 0.881

# %% [markdown]
# L'aumento di prestazioni vengono rispecchiate nel test set, dove si giunge a un'accuratezza di **88.1%**, con un notevole migliramento rispetto al precedente.

# %%
for audio, label in fb_test_ds:
    create_distribution_plot(improved_best_model, audio, label)
    break

# %% [markdown]
# ### Fine tuning
# In questa sezione effettuiamo il fine tuning nello stesso modo del notebook di riferimento.

# %%
def get_improved_basic_model_tuning(start_filters):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(98, 40, 1))
    x = tf.keras.layers.Normalization()(inputs)

    if not isinstance(start_filters, int):
        raise Exception("start_filters must be type integer")

    filters = [start_filters * (2 ** i) for i in range(4)]
    
    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=filters[0], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[1], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[2], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[3], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[3], kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

def tuner(filters, learning_rates, max_epochs, train_dataset, validation_dataset):
    start_time = time.time()

    counter = 1
    
    if not isinstance(filters, list):
        raise Exception("parameter filters must be type list")

    if not isinstance(learning_rates, list):
        raise Exception("parameter learning_rates must be type list")

    callbacks = [tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5)]

    best_learning_rate = 0 
    best_filters = 0
    best_val_accuracy = 0

    best_model = 0
    
    for f in filters:
        for lr in learning_rates:
            print(f"\nAddestrando con filtri {[f * (2 ** i) for i in range(4)]} e tasso di apprendimento {lr}")
            
            model = get_improved_basic_model_tuning(start_filters=f)
            model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.RMSprop(learning_rate=lr), metrics=["accuracy"])
            model_history = model.fit(train_dataset, epochs=max_epochs, validation_data=validation_dataset, callbacks=callbacks)

            model_history_df = convert_history_to_csv(model_history)

            model_history_df[["filters"]] = f
            model_history_df[["learning_rate"]] = lr
            
            path = "model_tuning/rmsprop/filterbanks/model_" + str(counter) + ".csv"
            model_history_df.to_csv(path)
            
            if best_val_accuracy < model_history_df.iloc[-1]["val_accuracy"]:
                best_val_accuracy = model_history_df.iloc[-1]["val_accuracy"]
                best_filters = f
                best_learning_rate = lr
                epoch = len(model_history_df)

            del model

            counter += 1

    total_time = time.time() - start_time
    minutes, seconds = divmod(total_time, 60)
    print(f"\nTempo totale trascorso: {int(minutes)} minuti e {int(seconds)} secondi")
    # print(f"Il miglior modello ha un filtro di partenza pari a {best_filters}, un learning rate pari a {best_learning_rate} con un'accuracy pari a {best_val_accuracy:.3f}")

    return best_filters, best_learning_rate

# %%
best_filter, best_learning_rate = tuner([16, 32, 64], [1e-3, 1e-4, 1e-5], 30, fb_train_ds, fb_val_ds)
# Out:
# Addestrando con filtri [16, 32, 64, 128] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 2s 5ms/step - loss: 3.5414 - accuracy: 0.0418 - val_loss: 3.2106 - val_accuracy: 0.1053
# Epoch 2/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.6416 - accuracy: 0.2308 - val_loss: 1.8054 - val_accuracy: 0.4579
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.6029 - accuracy: 0.5249 - val_loss: 1.0922 - val_accuracy: 0.6798
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.0073 - accuracy: 0.6959 - val_loss: 0.8301 - val_accuracy: 0.7573
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7267 - accuracy: 0.7774 - val_loss: 0.6812 - val_accuracy: 0.8040
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5502 - accuracy: 0.8304 - val_loss: 0.6403 - val_accuracy: 0.8241
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4597 - accuracy: 0.8628 - val_loss: 0.5434 - val_accuracy: 0.8534
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3722 - accuracy: 0.8844 - val_loss: 0.6724 - val_accuracy: 0.8218
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3202 - accuracy: 0.9017 - val_loss: 0.5691 - val_accuracy: 0.8654
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2950 - accuracy: 0.9131 - val_loss: 1.1839 - val_accuracy: 0.7658
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2758 - accuracy: 0.9166 - val_loss: 0.5266 - val_accuracy: 0.8650
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2483 - accuracy: 0.9265 - val_loss: 0.7763 - val_accuracy: 0.8252
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2414 - accuracy: 0.9327 - val_loss: 0.5339 - val_accuracy: 0.8904
# Epoch 14/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2038 - accuracy: 0.9387 - val_loss: 0.5979 - val_accuracy: 0.8846
# Epoch 15/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2155 - accuracy: 0.9349 - val_loss: 0.6824 - val_accuracy: 0.8627
# Epoch 16/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2025 - accuracy: 0.9390 - val_loss: 0.5542 - val_accuracy: 0.8881
#
# Addestrando con filtri [16, 32, 64, 128] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 1s 4ms/step - loss: 4.2347 - accuracy: 0.0366 - val_loss: 3.3760 - val_accuracy: 0.0544
# Epoch 2/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3810 - accuracy: 0.0510 - val_loss: 3.3275 - val_accuracy: 0.0490
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2956 - accuracy: 0.0793 - val_loss: 3.1692 - val_accuracy: 0.0818
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.0927 - accuracy: 0.1268 - val_loss: 2.8913 - val_accuracy: 0.1512
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.8550 - accuracy: 0.1838 - val_loss: 2.6172 - val_accuracy: 0.2296
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.6083 - accuracy: 0.2486 - val_loss: 2.3229 - val_accuracy: 0.3383
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.3676 - accuracy: 0.3162 - val_loss: 2.0558 - val_accuracy: 0.4217
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2
30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.9706 - accuracy: 0.1774 - val_loss: 2.8240 - val_accuracy: 0.2377
# Epoch 6/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.8328 - accuracy: 0.2134 - val_loss: 2.6727 - val_accuracy: 0.2832
# Epoch 7/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.6905 - accuracy: 0.2497 - val_loss: 2.5347 - val_accuracy: 0.3048
# Epoch 8/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.5452 - accuracy: 0.2889 - val_loss: 2.3792 - val_accuracy: 0.3584
# Epoch 9/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.4086 - accuracy: 0.3188 - val_loss: 2.2483 - val_accuracy: 0.3981
# Epoch 10/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.2816 - accuracy: 0.3567 - val_loss: 2.1387 - val_accuracy: 0.4225
# Epoch 11/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.1659 - accuracy: 0.3910 - val_loss: 2.0283 - val_accuracy: 0.4549
# Epoch 12/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.0456 - accuracy: 0.4210 - val_loss: 1.8983 - val_accuracy: 0.4923
# Epoch 13/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.9416 - accuracy: 0.4496 - val_loss: 1.8125 - val_accuracy: 0.5085
# Epoch 14/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.8397 - accuracy: 0.4771 - val_loss: 1.7134 - val_accuracy: 0.5374
# Epoch 15/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.7432 - accuracy: 0.5070 - val_loss: 1.6229 - val_accuracy: 0.5617
# Epoch 16/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.6478 - accuracy: 0.5317 - val_loss: 1.5347 - val_accuracy: 0.5880
# Epoch 17/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.5649 - accuracy: 0.5595 - val_loss: 1.4711 - val_accuracy: 0.6111
# Epoch 18/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.4760 - accuracy: 0.5798 - val_loss: 1.4117 - val_accuracy: 0.6177
# Epoch 19/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.3905 - accuracy: 0.6081 - val_loss: 1.3168 - val_accuracy: 0.6478
# Epoch 20/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.3187 - accuracy: 0.6210 - val_loss: 1.2662 - val_accuracy: 0.6566
# Epoch 21/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.2585 - accuracy: 0.6465 - val_loss: 1.2343 - val_accuracy: 0.6694
# Epoch 22/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.1779 - accuracy: 0.6700 - val_loss: 1.1469 - val_accuracy: 0.6852
# Epoch 23/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.1289 - accuracy: 0.6813 - val_loss: 1.0991 - val_accuracy: 0.7002
# Epoch 24/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.0647 - accuracy: 0.6957 - val_loss: 1.0818 - val_accuracy: 0.7018
# Epoch 25/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.0098 - accuracy: 0.7099 - val_loss: 1.0458 - val_accuracy: 0.7149
# Epoch 26/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.9583 - accuracy: 0.7222 - val_loss: 0.9933 - val_accuracy: 0.7269
# Epoch 27/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.9230 - accuracy: 0.7320 - val_loss: 0.9734 - val_accuracy: 0.7338
# Epoch 28/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.8597 - accuracy: 0.7559 - val_loss: 0.9397 - val_accuracy: 0.7342
# Epoch 29/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.8244 - accuracy: 0.7625 - val_loss: 0.9131 - val_accuracy: 0.7411
# Epoch 30/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.7905 - accuracy: 0.7744 - val_loss: 0.8749 - val_accuracy: 0.7627
#
# Tempo totale trascorso: 4 minuti e 32 secondi

# %% [markdown]
# Il tempo necessario per la ricerca dei migliori iperparametri è stata di 4 minuti e 32 secondi.
#
# Visualizziamo l'accuratezza e la perdita di tutti i modelli che il tuner ha addestato.

# %%
def plot_models(path, reverse=False, show="accuracy", overfit=True):
    n_models = len(os.listdir(path))
    # creo il subplot a seconda di quanti modelli dispongo
    best_pair = None
    min_diff = float("inf")
    
    for idx_model in range(1, int(np.sqrt(n_models)) + 1):
        if n_models % idx_model == 0:
            diff = abs(idx_model - n_models // idx_model)

            if diff < min_diff:
                min_diff = diff
                best_pair = (idx_model, n_models // idx_model)

    if reverse:
        rows = best_pair[1]
        cols = best_pair[0]
    else:
        rows = best_pair[0]
        cols = best_pair[1]
    
    fig, axes = plt.subplots(rows, cols, figsize=(14, 10))
    
    for index, model in enumerate(os.listdir(path)):
        row = index // cols
        col = index % cols
    
        ax = axes[row][col]
        
        newpath = path + "/" + model
        df = pd.read_csv(newpath)

        value1 = df[show].values
        value2 = df["val_" + show].values
        
        ax.plot(range(1, len(value1) + 1), value1, color="slategray", label="Addestramento")
        ax.plot(range(1, len(value2) + 1), value2, color="indianred", label="Validazione")

        if (row in range(rows)) and col == 0:
            ax.set_ylabel("Accuratezza (%)" if show == "accuracy" else "Perdita", fontweight="semibold", fontsize=10)

        if (col in range(cols)) and row == 2:
            ax.set_xlabel("Epoche", fontweight="semibold", fontsize=10)

        ax.set_title("Filtro " + str(df["filters"][0]) + " & lr " + str(df["learning_rate"][0]), fontsize=12)
            
        ax.set_ylim(0)
        ax.set_xlim(0)

        ax.spines["left"].set_visible(False)
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)

        ax.grid(True, color="gainsboro", alpha=0.3, linestyle="--")

        handles, _ = ax.get_legend_handles_labels()
        
        if overfit and show == "loss":
            # area overfit
            
            rect = mpatches.Rectangle((np.argmin(value2) + 1, 0), width=len(value1) - np.argmin(value2), height=max(max(value1), max(value2)), color='lightcoral', alpha=0.3)
            ax.add_patch(rect)
            # patch overfit per legenda
            overfit = mpatches.Patch(color='lightcoral', alpha=0.3, label='Area overfit')
           
            handles.append(overfit)

        ax.legend(handles=handles)

    plt.subplots_adjust(wspace=0.3, hspace=0.3)
    plt.show()

# %%
plot_models(path="model_tuning/rmsprop/filterbanks", show="accuracy")
plot_models(path="model_tuning/rmsprop/filterbanks", show="loss")

# %% [markdown]
# Dai grafici emerge che la combinazione più performante è composta da **64 filtri di partenza** e un **tasso di apprendimento di 1e-5**, poiché ritarda maggiormente l'overfitting. Altre combinazioni, come **32 filtri di partenza** e un **tasso di apprendimento di 1e-5**, mostrano buone prestazioni per la perdita ma l'accuratezza non è delle migliori.
#
# Procediamo quindi con l'addestramento del modello con **64 filtri di partenza** e un **tasso di apprendimento di 1e-5**. Come di consueto, salviamo i risultati in un file `keras` e la cronologia (history) in un file `csv`. Infine, convertiamo il file in formato `onnx`.

# %%
for audio, label in fb_train_ds:
    tuned_improved_basic_model = get_improved_basic_model_tuning(64)
    break

tuned_improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-5), metrics=["accuracy"])

# %%
tuned_improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/filterbanks/tuned_improved_basic_model_fb.keras", save_best_only=True, monitor="val_loss")]
tuned_improved_history = tuned_improved_basic_model.fit(fb_train_ds, epochs=100, validation_data=fb_val_ds, callbacks=tuned_improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] -
100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0981 - accuracy: 0.9723 - val_loss: 0.6344 - val_accuracy: 0.8472
# Epoch 87/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0942 - accuracy: 0.9746 - val_loss: 0.6540 - val_accuracy: 0.8383
# Epoch 88/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0942 - accuracy: 0.9731 - val_loss: 0.6455 - val_accuracy: 0.8414
# Epoch 89/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0932 - accuracy: 0.9726 - val_loss: 0.6223 - val_accuracy: 0.8538
# Epoch 90/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0920 - accuracy: 0.9732 - val_loss: 0.6134 - val_accuracy: 0.8515
# Epoch 91/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0833 - accuracy: 0.9767 - val_loss: 0.6112 - val_accuracy: 0.8538
# Epoch 92/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0804 - accuracy: 0.9762 - val_loss: 0.6404 - val_accuracy: 0.8511
# Epoch 93/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0872 - accuracy: 0.9742 - val_loss: 0.6134 - val_accuracy: 0.8538
# Epoch 94/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0737 - accuracy: 0.9813 - val_loss: 0.6323 - val_accuracy: 0.8492
# Epoch 95/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0776 - accuracy: 0.9781 - val_loss: 0.6295 - val_accuracy: 0.8542
# Epoch 96/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0749 - accuracy: 0.9795 - val_loss: 0.6161 - val_accuracy: 0.8580
# Epoch 97/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0738 - accuracy: 0.9780 - val_loss: 0.6459 - val_accuracy: 0.8507
# Epoch 98/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0721 - accuracy: 0.9803 - val_loss: 0.6568 - val_accuracy: 0.8434
# Epoch 99/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0718 - accuracy: 0.9804 - val_loss: 0.6370 - val_accuracy: 0.8526
# Epoch 100/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0646 - accuracy: 0.9822 - val_loss: 0.6132 - val_accuracy: 0.8522

# %%
tuned_improved_history_df = convert_history_to_csv(tuned_improved_history)
tuned_improved_history_df.to_csv("model_histories/rmsprop/filterbanks/tuned_improved_history_fb.csv")

convert_model_to_onnx("bestmodels/rmsprop/filterbanks/tuned_improved_basic_model_fb.keras", (98, 40, 1))

# %%
create_train_val_plot(tuned_improved_history.history)

# %% [markdown]
# In questo caso il modello non è ancora andato in overfitting, perciò magari avremmo potuto addestrarlo per qualche epoca in più. L'accuratezza in addestramento e validazione sono basse rispetto ai modelli precedenti, dovuto molto probabilmente dalla quantità limitata di epoche.

# %%
tuned_improved_best_model = tf.keras.models.load_model("bestmodels/rmsprop/filterbanks/tuned_improved_basic_model_fb.keras")
test_loss, test_acc = tuned_improved_best_model.evaluate(fb_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 4ms/step - loss: 0.6094 - accuracy: 0.8462
# Accuratezza: 0.846

# %%
evaluate_onnx_model("bestmodels/rmsprop/filterbanks/tuned_improved_basic_model_fb.onnx", fb_test_ds)
# Out:
# Accuratezza: 0.846

# %% [markdown]
# Come ci aspettavamo dall'andamento dell'accuratezza, il modello ha registrato delle prestazioni inferiori rispetto a prima ma senza andare in overfitting. L'accuratezza corrisponde a **80.7%**.

# %%
for audio, label in fb_test_ds:
    create_distribution_plot(tuned_improved_best_model, audio, label)
    break

# %% [markdown]
# Un fattore molto positivo riguarda la distinzione corretta di parole molto simili, come in questo caso **three** e **tree**.

# %% [markdown]
# ### Miglioramenti all'architettura del modello convolutivo
# In questa ultima fase riguardante i filterbanks andremo ad addestrare il modello corrispondente alla sezione **miglioramenti all'architettura del modello** del notebook di riferimento.

# %% [markdown]
# Si procede con la creazione dell'architettura composta da blocchi residuali, il suo addestramento e la dimostrazione grafica dell'andamento.

# %%
def residual_block(x, filters, pooling=False):
    residual = x

    x = tf.keras.layers.SeparableConv2D(filters, 3, padding="same", use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    if pooling:
      x = tf.keras.layers.MaxPooling2D(pool_size=2, padding="same")(x)
      residual = tf.keras.layers.Conv2D(filters, 1, strides=2)(residual)
    elif filters != residual.shape[-1]:
      residual = tf.keras.layers.Conv2D(filters, 1)(residual)

    x = tf.keras.layers.add([x, residual])
    return x

def bp_basic_model(input_shape):
    # input e pre processamento
    inputs = tf.keras.Input(shape=input_shape)
    
    x = residual_block(inputs, 32, pooling=True)
    x = residual_block(x, 64, pooling=True)
    x = residual_block(x, 128, pooling=True)
    x = residual_block(x, 256, pooling=True)
    x = residual_block(x, 256, pooling=False)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Livelli per la classificazione
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
for audio, label in fb_train_ds:
    bp_basic_model = bp_basic_model(audio.shape[1:])
    break

bp_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

bp_basic_model.summary()
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_11 (InputLayer)          [(None, 98, 40, 1)]  0           []
#
#  separable_conv2d (SeparableCon  (None, 98, 40, 32)  41          ['input_11[0][0]']
#  v2D)
#
#  batch_normalization (BatchNorm  (None, 98, 40, 32)  128         ['separable_conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 98, 40, 32)   0           ['batch_normalization[0][0]']
#
#  max_pooling2d_40 (MaxPooling2D  (None, 49, 20, 32)  0           ['activation[0][0]']
#  )
#
#  conv2d_50 (Conv2D)             (None, 49, 20, 32)   64          ['input_11[0][0]']
#
#  add (Add)                      (None, 49, 20, 32)   0           ['max_pooling2d_40[0][0]',
#                                                                   'conv2d_50[0][0]']
#
#  separable_conv2d_1 (SeparableC  (None, 49, 20, 64)  2336        ['add[0][0]']
#  onv2D)
#
#  batch_normalization_1 (BatchNo  (None, 49, 20, 64)  256         ['separable_conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 49, 20, 64)   0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d_41 (MaxPooling2D  (None, 25, 10, 64)  0           ['activation_1[0][0]']
#  )
#
#  conv2d_51 (Conv2D)             (None, 25, 10, 64)   2112        ['add[0][0]']
#
#  add_1 (Add)                    (None, 25, 10, 64)   0           ['max_pooling2d_41[0][0]',
#                                                                   'conv2d_51[0][0]']
#
#  separable_conv2d_2 (SeparableC  (None, 25, 10, 128)  8768       ['add_1[0][0]']
#  onv2D)
#
#  batch_normalization_2 (BatchNo  (None, 25, 10, 128)  512        ['separable_conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 25, 10, 128)  0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_42 (MaxPooling2D  (None, 13, 5, 128)  0           ['activation_2[0][0]']
#  )
#
#  conv2d_52 (Conv2D)             (None, 13, 5, 128)   8320        ['add_1[0][0]']
#
#  add_2 (Add)                    (None, 13, 5, 128)   0           ['max_pooling2d_42[0][0]',
#                                                                   'conv2d_52[0][0]']
#
#  separable_conv2d_3 (SeparableC  (None, 13, 5, 256)  33920       ['add_2[0][0]']
#  onv2D)
#
#  batch_normalization_3 (BatchNo  (None, 13, 5, 256)  1024        ['separable_conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 13, 5, 256)   0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_43 (MaxPooling2D  (None, 7, 3, 256)   0           ['activation_3[0][0]']
#  )
#
#  conv2d_53 (Conv2D)             (None, 7, 3, 256)    33024       ['add_2[0][0]']
#
#  add_3 (Add)                    (None, 7, 3, 256)    0           ['max_pooling2d_43[0][0]',
#                                                                   'conv2d_53[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 7, 3, 256)   67840       ['add_3[0][0]']
#  onv2D)
#
#  batch_normalization_4 (BatchNo  (None, 7, 3, 256)   1024        ['separable_conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 7, 3, 256)    0           ['batch_normalization_4[0][0]']
#
#  add_4 (Add)                    (None, 7, 3, 256)    0           ['activation_4[0][0]',
#                                                                   'add_3[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['add_4[0][0]']
#  alAveragePooling2D)
#
#  dropout_10 (Dropout)           (None, 256)          0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_10 (Dense)               (None, 30)           7710        ['dropout_10[0][0]']
#
# ==================================================================================================
# Total params: 167,079
# Trainable params: 165,607
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %% [markdown]
# Il numero di parametri in questo caso non è cambiato rispetto al notebook di riferimento.

# %%
bp_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/filterbanks/bp_basic_model_fb.keras", save_best_only=True, monitor="val_loss")]
bp_model_history = bp_basic_model.fit(fb_train_ds, epochs=100, validation_data=fb_val_ds, callbacks=bp_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 4s 10ms/step - loss: 7.0607 - accuracy: 0.0487 - val_loss: 3.4785 - val_accuracy: 0.0617
# Epoch 2/100
# 243/243 [==============================] - 2s 9ms/step - loss: 3.2431 - accuracy: 0.1325 - val_loss: 3.6481 - val_accuracy: 0.0779
# Epoch 3/100
# 243/243 [==============================] - 2s 9ms/step - loss: 2.3871 - accuracy: 0.3014 - val_loss: 2.4184 - val_accuracy: 0.2739
# Epoch 4/100
# 243/243 [==============================] - 2s 9ms/step - loss: 1.7276 - accuracy: 0.4969 - val_loss: 3.2791 - val_accuracy: 0.2022
# Epoch 5/100
# 243/243 [==============================] - 2s 8ms/step - loss: 1.2593 - accuracy: 0.6396 - val_loss: 2.9883 - val_accuracy: 0.3291
# Epoch 6/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.9798 - accuracy: 0.7214 - val_loss: 2.2278 - val_accuracy: 0.4452
# Epoch 7/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.7992 - accuracy: 0.7711 - val_loss: 1.4033 - val_accuracy: 0.6107
# Epoch 8/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.6805 - accuracy: 0.8080 - val_loss: 1.7026 - val_accuracy: 0.5201
# Epoch 9/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.5774 - accuracy: 0.8354 - val_loss: 3.0051 - val_accuracy: 0.3665
# Epoch 10/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.5172 - accuracy: 0.8508 - val_loss: 1.4146 - val_accuracy: 0.6069
# Epoch 11/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.4579 - accuracy: 0.8656 - val_loss: 1.1004 - val_accuracy: 0.6929
# Epoch 12/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.4091 - accuracy: 0.8861 - val_loss: 1.6874 - val_accuracy: 0.5583
# Epoch 13/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.3722 - accuracy: 0.8968 - val_loss: 1.4545 - val_accuracy: 0.6173
# Epoch 14/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.3373 - accuracy: 0.9037 - val_loss: 0.7510 - val_accuracy: 0.7863
# Epoch 15/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.3054 - accuracy: 0.9133 - val_loss: 0.7925 - val_accuracy: 0.7944
# Epoch 16/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.2796 - accuracy: 0.9197 - val_loss: 1.0604 - val_accuracy: 0.7153
# Epoch 17/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.2546 - accuracy: 0.9276 - val_loss: 0.7080 - val_accuracy: 0.7986
# Epoch 18/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.2256 - accuracy: 0.9366 - val_loss: 0.7075 - val_accuracy: 0.8005
# Epoch 19/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0
100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0301 - accuracy: 0.9912 - val_loss: 0.9710 - val_accuracy: 0.8441
# Epoch 81/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0261 - accuracy: 0.9927 - val_loss: 0.7355 - val_accuracy: 0.8557
# Epoch 82/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0262 - accuracy: 0.9912 - val_loss: 1.9423 - val_accuracy: 0.7249
# Epoch 83/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0209 - accuracy: 0.9932 - val_loss: 0.8616 - val_accuracy: 0.8534
# Epoch 84/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0258 - accuracy: 0.9914 - val_loss: 0.9006 - val_accuracy: 0.8492
# Epoch 85/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0294 - accuracy: 0.9912 - val_loss: 0.7731 - val_accuracy: 0.8638
# Epoch 86/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0248 - accuracy: 0.9933 - val_loss: 0.9726 - val_accuracy: 0.8391
# Epoch 87/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.0282 - accuracy: 0.9897 - val_loss: 1.4646 - val_accuracy: 0.7816
# Epoch 88/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0258 - accuracy: 0.9924 - val_loss: 0.7365 - val_accuracy: 0.8708
# Epoch 89/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0201 - accuracy: 0.9941 - val_loss: 1.0922 - val_accuracy: 0.8310
# Epoch 90/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0276 - accuracy: 0.9911 - val_loss: 0.8972 - val_accuracy: 0.8264
# Epoch 91/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0252 - accuracy: 0.9927 - val_loss: 0.9495 - val_accuracy: 0.8387
# Epoch 92/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0229 - accuracy: 0.9924 - val_loss: 1.2678 - val_accuracy: 0.8148
# Epoch 93/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0186 - accuracy: 0.9942 - val_loss: 0.8755 - val_accuracy: 0.8534
# Epoch 94/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0252 - accuracy: 0.9918 - val_loss: 1.8770 - val_accuracy: 0.7404
# Epoch 95/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0237 - accuracy: 0.9925 - val_loss: 0.9624 - val_accuracy: 0.8499
# Epoch 96/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0232 - accuracy: 0.9921 - val_loss: 1.3552 - val_accuracy: 0.8021
# Epoch 97/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0208 - accuracy: 0.9939 - val_loss: 0.9099 - val_accuracy: 0.8592
# Epoch 98/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0184 - accuracy: 0.9948 - val_loss: 0.8692 - val_accuracy: 0.8607
# Epoch 99/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0214 - accuracy: 0.9925 - val_loss: 0.9058 - val_accuracy: 0.8538
# Epoch 100/100
# 243/243 [==============================] - 2s 10ms/step - loss: 0.0195 - accuracy: 0.9942 - val_loss: 1.0628 - val_accuracy: 0.8337

# %%
bp_model_history_df = convert_history_to_csv(bp_model_history)
bp_model_history_df.to_csv("model_histories/rmsprop/filterbanks/bp_model_history_fb.csv")

convert_model_to_onnx("bestmodels/rmsprop/filterbanks/bp_basic_model_fb.keras", (98, 40, 1))

# %%
create_train_val_plot(bp_model_history.history, overfit=False)

# %% [markdown]
# In questo caso il modello ha perfomato peggio rispetto al corrispettivo. Il valore minimo di loss è maggiore, mentre il valore massimo di accuratezza è inferiore.

# %%
best_bp_basic_model = tf.keras.models.load_model("bestmodels/rmsprop/filterbanks/bp_basic_model_fb.keras")
test_loss, test_acc = best_bp_basic_model.evaluate(fb_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 4ms/step - loss: 0.6076 - accuracy: 0.8710
# Accuratezza: 0.871

# %%
evaluate_onnx_model("bestmodels/rmsprop/filterbanks/bp_basic_model_fb.onnx", fb_test_ds)
# Out:
# Accuratezza: 0.871

# %% [markdown]
# L'accuratezza è diminuita, siamo a quota **87.1%**.

# %%
for audio, label in fb_test_ds:
    create_distribution_plot(best_bp_basic_model, audio, label)
    break

# %% [markdown]
# ## Addestramento modello convolutivo base (mfcc)
# L'ultimo argomento che trattiamo nel notebook riguarda l'uso degli mfcc come dati in input ai modelli.

# %% [markdown]
# Procediamo nello stesso modo fatto sopra, quindi trasformiamo i dati con la nostra classe e otteniamo i set di train, validation e test.

# %%
mfcc_train_ds = DatasetConverter(train_ds)
mfcc_train_ds = mfcc_train_ds.convert('mfcc')

mfcc_validation_ds = DatasetConverter(validation_ds)
mfcc_validation_ds = mfcc_validation_ds.convert('mfcc')

mfcc_val_ds = mfcc_validation_ds.take(mfcc_validation_ds.cardinality() // 2)
mfcc_test_ds = mfcc_validation_ds.skip(mfcc_validation_ds.cardinality() // 2)

# %% [markdown]
# Considerata la grandezza ridotta della matrice degli mfcc, dobbiamo apportare una leggera modifica al modello convolutivo di base, applicando il **padding** nel livello `MaxPooling2D_4`.

# %%
def get_basic_model(input_shape):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=input_shape, name="inputs")
    x = tf.keras.layers.Normalization(name="normalizzazione")(inputs)

    # Blocco di apprendimento delle caratteristiche
    conv2D_1 = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same", name="conv2D_1")(x)
    MaxPooling2D_1 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_1")(conv2D_1)
    conv2D_2 = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same", name="conv2D_2")(MaxPooling2D_1)
    MaxPooling2D_2 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_2")(conv2D_2)
    conv2D_3 = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same", name="conv2D_3")(MaxPooling2D_2)
    MaxPooling2D_3 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_3")(conv2D_3)
    conv2D_4 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_4")(MaxPooling2D_3)
    MaxPooling2D_4 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_4", padding="same")(conv2D_4)
    conv2D_5 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_5")(MaxPooling2D_4)

    # Blocco di classificazione
    Flatten = tf.keras.layers.Flatten(name="Flatten")(conv2D_5)
    outputs = tf.keras.layers.Dense(30, activation="softmax", name="dense_output")(Flatten)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
for audio, label in mfcc_train_ds:
    basic_model = get_basic_model(audio.shape[1:])
    break
    
basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

basic_model.summary()
# Out:
# Model: "model_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inputs (InputLayer)         [(None, 98, 12, 1)]       0
#
#  normalizzazione (Normalizat  (None, 98, 12, 1)        3
#  ion)
#
#  conv2D_1 (Conv2D)           (None, 98, 12, 32)        320
#
#  MaxPooling2D_1 (MaxPooling2  (None, 49, 6, 32)        0
#  D)
#
#  conv2D_2 (Conv2D)           (None, 49, 6, 64)         18496
#
#  MaxPooling2D_2 (MaxPooling2  (None, 24, 3, 64)        0
#  D)
#
#  conv2D_3 (Conv2D)           (None, 24, 3, 128)        73856
#
#  MaxPooling2D_3 (MaxPooling2  (None, 12, 1, 128)       0
#  D)
#
#  conv2D_4 (Conv2D)           (None, 12, 1, 256)        295168
#
#  MaxPooling2D_4 (MaxPooling2  (None, 6, 1, 256)        0
#  D)
#
#  conv2D_5 (Conv2D)           (None, 6, 1, 256)         590080
#
#  Flatten (Flatten)           (None, 1536)              0
#
#  dense_output (Dense)        (None, 30)                46110
#
# =================================================================
# Total params: 1,024,033
# Trainable params: 1,024,030
# Non-trainable params: 3
# _________________________________________________________________

# %% [markdown]
# Anche in questo caso notiamo una **diminuzione dei parametri di circa 50.000**, dovuto alla differenza di grandezza della matrice.

# %%
basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop
convert_model_to_onnx("bestmodels/rmsprop/mfcc/basic_model_mfcc.keras", (98, 12, 1))

# %% [markdown]
# Visualizziamo l'andamento dell'accurateza e della perdita durante l'addestramento.

# %%
create_train_val_plot(basic_model_history.history)

# %% [markdown]
# Il modello di base addestrato sugli mfcc non ha performato bene quanto quello con i filterbanks. Raggiunge molto presto un adattamento ai dati e si nota un degradamento dell'accuratezza di **7 punti percentile**, con un aumento importante nel valore della perdita.

# %% [markdown]
# Verifichiamo l'accuratezza della migliore versione del modello di base.

# %%
best_basic_model = tf.keras.models.load_model("bestmodels/rmsprop/mfcc/basic_model_mfcc.keras")
test_loss, test_acc = best_basic_model.evaluate(mfcc_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 2ms/step - loss: 0.8599 - accuracy: 0.7966
# Accuratezza: 0.797

# %%
evaluate_onnx_model("bestmodels/rmsprop/mfcc/basic_model_mfcc.onnx", mfcc_test_ds)
# Out:
# Accuratezza: 0.797

# %% [markdown]
# Abbiamo ottenuto un'**accuratezza** del **76.5%**. Vediamo come si evolve con i prossimi modelli.

# %%
for audio, label in mfcc_test_ds: # prendiamo un audio a caso del test e creiamo la distribuzione
    create_distribution_plot(best_basic_model, audio, label)
    break

# %% [markdown]
# ### Convolutivo base risoluzione dell'overfitting
# In questa parte andremo a utilizzare il secondo modello presente nel notebook di riferimento, perciò il modello riguardante il paragrafo **risoluzione dell'overfitting**. Anche in questo caso, a causa della grandezza ridotta della matrice, è necessario applicare la stessa modifica allo stesso livello di MaxPooling.

# %%
def get_improved_basic_model(input_shape):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=input_shape)
    x = tf.keras.layers.Normalization()(inputs)

    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2, padding="same")(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
for audio, label in mfcc_train_ds:
    improved_basic_model = get_improved_basic_model(audio.shape[1:])
    break

improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

# %%
improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/mfcc/improved_basic_model_mfcc.keras", save_best_only=True, monitor="val_loss")]
improved_history = improved_basic_model.fit(mfcc_train_ds, epochs=100, validation_data=mfcc_val_ds, callbacks=improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 2s 6ms/step - loss: 3.0837 - accuracy: 0.1589 - val_loss: 2.2398 - val_accuracy: 0.3422
# Epoch 2/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.7118 - accuracy: 0.5064 - val_loss: 1.1682 - val_accuracy: 0.6663
# Epoch 3/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.0807 - accuracy: 0.6772 - val_loss: 1.0632 - val_accuracy: 0.7238
# Epoch 4/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7731 - accuracy: 0.7729 - val_loss: 1.0648 - val_accuracy: 0.7365
# Epoch 5/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6091 - accuracy: 0.8189 - val_loss: 0.8795 - val_accuracy: 0.7978
# Epoch 6/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5289 - accuracy: 0.8436 - val_loss: 0.8508 - val_accuracy: 0.8106
# Epoch 7/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4405 - accuracy: 0.8741 - val_loss: 1.0210 - val_accuracy: 0.7951
# Epoch 8/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4035 - accuracy: 0.8852 - val_loss: 0.9374 - val_accuracy: 0.8248
# Epoch 9/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3908 - accuracy: 0.8941 - val_loss: 0.9887 - val_accuracy: 0.8140
# Epoch 10/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3548 - accuracy: 0.8976 - val_loss: 0.9451 - val_accuracy: 0.8353
# Epoch 11/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3625 - accuracy: 0.9040 - val_loss: 0.8982 - val_accuracy: 0.8326
# Epoch 12/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3485 - accuracy: 0.9072 - val_loss: 1.0403 - val_accuracy: 0.8472
# Epoch 13/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3657 - accuracy: 0.9130 - val_loss: 1.6992 - val_accuracy: 0.7670
# Epoch 14/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.
100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8222 - accuracy: 0.9427 - val_loss: 5.9564 - val_accuracy: 0.8507
# Epoch 76/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7841 - accuracy: 0.9429 - val_loss: 4.7326 - val_accuracy: 0.8681
# Epoch 77/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8412 - accuracy: 0.9460 - val_loss: 5.5506 - val_accuracy: 0.8488
# Epoch 78/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6790 - accuracy: 0.9447 - val_loss: 4.2418 - val_accuracy: 0.8364
# Epoch 79/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7944 - accuracy: 0.9457 - val_loss: 4.5688 - val_accuracy: 0.8542
# Epoch 80/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8475 - accuracy: 0.9481 - val_loss: 5.2260 - val_accuracy: 0.8646
# Epoch 81/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6785 - accuracy: 0.9513 - val_loss: 4.7346 - val_accuracy: 0.8611
# Epoch 82/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7896 - accuracy: 0.9476 - val_loss: 6.2935 - val_accuracy: 0.8731
# Epoch 83/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.9768 - accuracy: 0.9405 - val_loss: 4.3399 - val_accuracy: 0.8364
# Epoch 84/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8216 - accuracy: 0.9383 - val_loss: 5.2765 - val_accuracy: 0.8515
# Epoch 85/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8785 - accuracy: 0.9424 - val_loss: 5.6102 - val_accuracy: 0.8449
# Epoch 86/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8743 - accuracy: 0.9445 - val_loss: 6.3765 - val_accuracy: 0.8488
# Epoch 87/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.8646 - accuracy: 0.9451 - val_loss: 3.6007 - val_accuracy: 0.8380
# Epoch 88/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7718 - accuracy: 0.9500 - val_loss: 6.1724 - val_accuracy: 0.8727
# Epoch 89/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7114 - accuracy: 0.9468 - val_loss: 5.0016 - val_accuracy: 0.8468
# Epoch 90/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7848 - accuracy: 0.9508 - val_loss: 5.5960 - val_accuracy: 0.8569
# Epoch 91/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.9460 - accuracy: 0.9500 - val_loss: 5.7400 - val_accuracy: 0.8596
# Epoch 92/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8485 - accuracy: 0.9490 - val_loss: 7.9179 - val_accuracy: 0.8661
# Epoch 93/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8874 - accuracy: 0.9594 - val_loss: 6.2682 - val_accuracy: 0.8669
# Epoch 94/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.0076 - accuracy: 0.9521 - val_loss: 7.5523 - val_accuracy: 0.8688
# Epoch 95/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8788 - accuracy: 0.9527 - val_loss: 4.7684 - val_accuracy: 0.8391
# Epoch 96/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.9549 - accuracy: 0.9527 - val_loss: 6.6842 - val_accuracy: 0.8511
# Epoch 97/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.9439 - accuracy: 0.9459 - val_loss: 6.3789 - val_accuracy: 0.8642
# Epoch 98/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.9715 - accuracy: 0.9528 - val_loss: 6.3384 - val_accuracy: 0.8569
# Epoch 99/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8940 - accuracy: 0.9595 - val_loss: 8.9593 - val_accuracy: 0.8634
# Epoch 100/100
# 243/243 [==============================] - 1s 5ms/step - loss: 1.0605 - accuracy: 0.9523 - val_loss: 7.7908 - val_accuracy: 0.8650

# %%
improved_history_df = convert_history_to_csv(improved_history)
improved_history_df.to_csv("model_histories/rmsprop/mfcc/improved_history_mfcc.csv")

convert_model_to_onnx("bestmodels/rmsprop/mfcc/improved_basic_model_mfcc.keras", (98, 12, 1))

# %%
create_train_val_plot(improved_history.history)

# %% [markdown]
# In questo caso abbiamo ottenuto dei miglioramenti nella gestione dell'overfitting, un aumento del valore massimo di accuratezza e un livello di perdita minimo inferiore.

# %%
improved_best_model = tf.keras.models.load_model("bestmodels/rmsprop/mfcc/improved_basic_model_mfcc.keras")
test_loss, test_acc = improved_best_model.evaluate(mfcc_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 2ms/step - loss: 0.7900 - accuracy: 0.8140
# Accuratezza: 0.814

# %%
evaluate_onnx_model("bestmodels/rmsprop/mfcc/improved_basic_model_mfcc.onnx", mfcc_test_ds)
# Out:
# Accuratezza: 0.814

# %% [markdown]
# Questi cambiamenti hanno portato ad ottenere un'accuratezza pari a **81.8%** nei dati di test! Un significativo aumento confrontando i precedenti.

# %%
for audio, label in mfcc_test_ds:
    create_distribution_plot(improved_best_model, audio, label)
    break

# %% [markdown]
# ### Fine tuning
# In questa sezione effettuiamo il fine tuning anche per il dataset mfcc. Ovviamente anche in questo caso adattiamo il modello ai mfcc.

# %%
def get_improved_basic_model_tuning(start_filters):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(98, 12, 1))
    x = tf.keras.layers.Normalization()(inputs)

    if not isinstance(start_filters, int):
        raise Exception("start_filters must be type integer")

    filters = [start_filters * (2 ** i) for i in range(4)]
    
    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=filters[0], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[1], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[2], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[3], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2, padding="same")(x)
    x = tf.keras.layers.Conv2D(filters=filters[3], kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

def tuner(filters, learning_rates, max_epochs, train_dataset, validation_dataset):
    start_time = time.time()

    counter = 1
    
    if not isinstance(filters, list):
        raise Exception("parameter filters must be type list")

    if not isinstance(learning_rates, list):
        raise Exception("parameter learning_rates must be type list")

    callbacks = [tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5)]

    best_learning_rate = 0 
    best_filters = 0
    best_val_accuracy = 0

    best_model = 0
    
    for f in filters:
        for lr in learning_rates:
            print(f"\nAddestrando con filtri {[f * (2 ** i) for i in range(4)]} e tasso di apprendimento {lr}")
            
            model = get_improved_basic_model_tuning(start_filters=f)
            model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.RMSprop(learning_rate=lr), metrics=["accuracy"])
            model_history = model.fit(train_dataset, epochs=max_epochs, validation_data=validation_dataset, callbacks=callbacks)

            model_history_df = convert_history_to_csv(model_history)

            model_history_df[["filters"]] = f
            model_history_df[["learning_rate"]] = lr
            
            path = "model_tuning/rmsprop/mfcc/model_" + str(counter) + ".csv"
            model_history_df.to_csv(path)
            
            if best_val_accuracy < model_history_df.iloc[-1]["val_accuracy"]:
                best_val_accuracy = model_history_df.iloc[-1]["val_accuracy"]
                best_filters = f
                best_learning_rate = lr
                epoch = len(model_history_df)

            del model

            counter += 1

    total_time = time.time() - start_time
    minutes, seconds = divmod(total_time, 60)
    print(f"\nTempo totale trascorso: {int(minutes)} minuti e {int(seconds)} secondi")
    # print(f"Il miglior modello ha un filtro di partenza pari a {best_filters}, un learning rate pari a {best_learning_rate} con un'accuracy pari a {best_val_accuracy:.3f}")

    return best_filters, best_learning_rate

# %%
best_filter, best_learning_rate = tuner([16, 32, 64], [1e-3, 1e-4, 1e-5], 30, mfcc_train_ds, mfcc_val_ds)
# Out:
# Addestrando con filtri [16, 32, 64, 128] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 2s 5ms/step - loss: 3.3120 - accuracy: 0.0869 - val_loss: 2.6410 - val_accuracy: 0.2400
# Epoch 2/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.2640 - accuracy: 0.3407 - val_loss: 1.6722 - val_accuracy: 0.5123
# Epoch 3/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.5575 - accuracy: 0.5430 - val_loss: 1.2272 - val_accuracy: 0.6605
# Epoch 4/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.1328 - accuracy: 0.6678 - val_loss: 1.2542 - val_accuracy: 0.6597
# Epoch 5/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.
30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.8548 - accuracy: 0.4637 - val_loss: 1.8639 - val_accuracy: 0.4896
# Epoch 13/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.7731 - accuracy: 0.4802 - val_loss: 1.7883 - val_accuracy: 0.5077
# Epoch 14/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.6640 - accuracy: 0.5210 - val_loss: 1.7494 - val_accuracy: 0.5147
# Epoch 15/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.6174 - accuracy: 0.5317 - val_loss: 1.6867 - val_accuracy: 0.5293
# Epoch 16/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.5582 - accuracy: 0.5521 - val_loss: 1.6335 - val_accuracy: 0.5536
# Epoch 17/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.4877 - accuracy: 0.5682 - val_loss: 1.5921 - val_accuracy: 0.5671
# Epoch 18/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.4314 - accuracy: 0.5807 - val_loss: 1.5578 - val_accuracy: 0.5656
# Epoch 19/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.3752 - accuracy: 0.6085 - val_loss: 1.5254 - val_accuracy: 0.5791
# Epoch 20/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.3297 - accuracy: 0.6131 - val_loss: 1.4788 - val_accuracy: 0.5953
# Epoch 21/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.2727 - accuracy: 0.6273 - val_loss: 1.4487 - val_accuracy: 0.6030
# Epoch 22/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.2062 - accuracy: 0.6487 - val_loss: 1.4266 - val_accuracy: 0.6088
# Epoch 23/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.1777 - accuracy: 0.6593 - val_loss: 1.4007 - val_accuracy: 0.6146
# Epoch 24/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.1258 - accuracy: 0.6780 - val_loss: 1.3715 - val_accuracy: 0.6292
# Epoch 25/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.0802 - accuracy: 0.6856 - val_loss: 1.3472 - val_accuracy: 0.6366
# Epoch 26/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.0438 - accuracy: 0.6916 - val_loss: 1.3229 - val_accuracy: 0.6316
# Epoch 27/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.9909 - accuracy: 0.7113 - val_loss: 1.3028 - val_accuracy: 0.6427
# Epoch 28/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.9574 - accuracy: 0.7198 - val_loss: 1.2632 - val_accuracy: 0.6551
# Epoch 29/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.9302 - accuracy: 0.7277 - val_loss: 1.2338 - val_accuracy: 0.6663
# Epoch 30/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8968 - accuracy: 0.7376 - val_loss: 1.2325 - val_accuracy: 0.6628
#
# Tempo totale trascorso: 3 minuti e 47 secondi

# %% [markdown]
# Il tempo necessario per la ricerca dei migliori iperparametri è stata di quasi 4 minuti.
#
# Visualizziamo l'accuratezza e la perdita di tutti i modelli che il tuner ha addestato.

# %%
plot_models(path="model_tuning/rmsprop/mfcc", show="accuracy")
plot_models(path="model_tuning/rmsprop/mfcc", show="loss")

# %% [markdown]
# Dai grafici emerge che la combinazione più performante è composta da **32 filtri di partenza** e un **tasso di apprendimento di 0.0001**, poiché ritarda maggiormente l'overfitting. Altre combinazioni, come **64 filtri di partenza** e un **tasso di apprendimento di 0.0001**, mostrano buone prestazioni ma anche un inizio di overfitting, evidenziato dallo distaccamento tra la perdita di addestramento e quella di validazione.
#
# Procediamo quindi con l'addestramento del modello con **32 filtri di partenza** e un **tasso di apprendimento di 0.0001**. Come di consueto, salviamo i risultati in un file `keras` e la cronologia (history) in un file `csv`. Infine, convertiamo il file in formato `onnx`.

# %%
for audio, label in mfcc_train_ds:
    tuned_improved_basic_model = get_improved_basic_model(audio.shape[1:])
    break

tuned_improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-5), metrics=["accuracy"])

# %%
tuned_improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/mfcc/tuned_improved_basic_model_mfcc.keras", save_best_only=True, monitor="val_loss")]
tuned_improved_history = tuned_improved_basic_model.fit(mfcc_train_ds, epochs=100, validation_data=mfcc_val_ds, callbacks=tuned_improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] -
100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6878 - accuracy: 0.7974 - val_loss: 1.1379 - val_accuracy: 0.6790
# Epoch 92/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6883 - accuracy: 0.7911 - val_loss: 1.1276 - val_accuracy: 0.6836
# Epoch 93/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6797 - accuracy: 0.7938 - val_loss: 1.1161 - val_accuracy: 0.6821
# Epoch 94/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6499 - accuracy: 0.8019 - val_loss: 1.1149 - val_accuracy: 0.6821
# Epoch 95/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6515 - accuracy: 0.8064 - val_loss: 1.1203 - val_accuracy: 0.6790
# Epoch 96/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6245 - accuracy: 0.8119 - val_loss: 1.1074 - val_accuracy: 0.6856
# Epoch 97/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6250 - accuracy: 0.8161 - val_loss: 1.1121 - val_accuracy: 0.6867
# Epoch 98/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6168 - accuracy: 0.8130 - val_loss: 1.0969 - val_accuracy: 0.6879
# Epoch 99/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6079 - accuracy: 0.8134 - val_loss: 1.0974 - val_accuracy: 0.6871
# Epoch 100/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5964 - accuracy: 0.8198 - val_loss: 1.0924 - val_accuracy: 0.6925

# %%
tuned_improved_history_df = convert_history_to_csv(tuned_improved_history)
tuned_improved_history_df.to_csv("model_histories/rmsprop/mfcc/tuned_improved_history_mfcc.csv")

convert_model_to_onnx("bestmodels/rmsprop/mfcc/tuned_improved_basic_model_mfcc.keras", (98, 12, 1))

# %%
create_train_val_plot(tuned_improved_history.history)

# %% [markdown]
# Anche in questo caso la rete non ha raggiunto l'overfitting, nonostante ci fosse vicina, perciò avremmo potuto addestrarlo per un numero di epoche maggiore.
#
# D'altro canto le prestazioni non sono delle migliori. L'accuratezza maggiore raggiunge con difficoltà il **70%**. Probabilmente avremmo dovuto utilizzare un'altro **tasso di apprendimento**.

# %%
tuned_improved_best_model = tf.keras.models.load_model("bestmodels/rmsprop/mfcc/tuned_improved_basic_model_mfcc.keras")
test_loss, test_acc = tuned_improved_best_model.evaluate(mfcc_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 3ms/step - loss: 1.1486 - accuracy: 0.6807
# Accuratezza: 0.681

# %%
evaluate_onnx_model("bestmodels/rmsprop/mfcc/tuned_improved_basic_model_mfcc.onnx", mfcc_test_ds)
# Out:
# Accuratezza: 0.681

# %% [markdown]
# Di fatto l'accuratezza raggiuta nel set non raggiunge neppure la soglia del **70%**.

# %%
for audio, label in mfcc_test_ds:
    create_distribution_plot(tuned_improved_best_model, audio, label)
    break

# %% [markdown]
# Come prima è riuscito a predire correttamente la classe three, con dell'incertezza verso tree. Accettabile vista la somiglianza tra le parole.

# %% [markdown]
# ### Miglioramenti all'architettura del modello convolutivo
# In questa ultima fase riguardante gli mfcc andremo ad addestrare il modello corrispondente alla sezione **miglioramenti all'architettura del modello** del notebook di riferimento.
#
# In questo caso non è necessario implementare cambiamenti all'architettura del modello.

# %%
def residual_block(x, filters, pooling=False):
    residual = x

    x = tf.keras.layers.SeparableConv2D(filters, 3, padding="same", use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    if pooling:
      x = tf.keras.layers.MaxPooling2D(pool_size=2, padding="same")(x)
      residual = tf.keras.layers.Conv2D(filters, 1, strides=2)(residual)
    elif filters != residual.shape[-1]:
      residual = tf.keras.layers.Conv2D(filters, 1)(residual)

    x = tf.keras.layers.add([x, residual])
    return x

def bp_basic_model(input_shape):
    # input e pre processamento
    inputs = tf.keras.Input(shape=input_shape)
    
    x = residual_block(inputs, 32, pooling=True)
    x = residual_block(x, 64, pooling=True)
    x = residual_block(x, 128, pooling=True)
    x = residual_block(x, 256, pooling=True)
    x = residual_block(x, 256, pooling=False)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Livelli per la classificazione
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
for audio, label in mfcc_train_ds:
    bp_basic_model = bp_basic_model(audio.shape[1:])
    break

bp_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

bp_basic_model.summary()
# Out:
# Model: "model_23"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_22 (InputLayer)          [(None, 98, 12, 1)]  0           []
#
#  separable_conv2d_5 (SeparableC  (None, 98, 12, 32)  41          ['input_22[0][0]']
#  onv2D)
#
#  batch_normalization_5 (BatchNo  (None, 98, 12, 32)  128         ['separable_conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 98, 12, 32)   0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_84 (MaxPooling2D  (None, 49, 6, 32)   0           ['activation_5[0][0]']
#  )
#
#  conv2d_104 (Conv2D)            (None, 49, 6, 32)    64          ['input_22[0][0]']
#
#  add_5 (Add)                    (None, 49, 6, 32)    0           ['max_pooling2d_84[0][0]',
#                                                                   'conv2d_104[0][0]']
#
#  separable_conv2d_6 (SeparableC  (None, 49, 6, 64)   2336        ['add_5[0][0]']
#  onv2D)
#
#  batch_normalization_6 (BatchNo  (None, 49, 6, 64)   256         ['separable_conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 49, 6, 64)    0           ['batch_normalization_6[0][0]']
#
#  max_pooling2d_85 (MaxPooling2D  (None, 25, 3, 64)   0           ['activation_6[0][0]']
#  )
#
#  conv2d_105 (Conv2D)            (None, 25, 3, 64)    2112        ['add_5[0][0]']
#
#  add_6 (Add)                    (None, 25, 3, 64)    0           ['max_pooling2d_85[0][0]',
#                                                                   'conv2d_105[0][0]']
#
#  separable_conv2d_7 (SeparableC  (None, 25, 3, 128)  8768        ['add_6[0][0]']
#  onv2D)
#
#  batch_normalization_7 (BatchNo  (None, 25, 3, 128)  512         ['separable_conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 25, 3, 128)   0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_86 (MaxPooling2D  (None, 13, 2, 128)  0           ['activation_7[0][0]']
#  )
#
#  conv2d_106 (Conv2D)            (None, 13, 2, 128)   8320        ['add_6[0][0]']
#
#  add_7 (Add)                    (None, 13, 2, 128)   0           ['max_pooling2d_86[0][0]',
#                                                                   'conv2d_106[0][0]']
#
#  separable_conv2d_8 (SeparableC  (None, 13, 2, 256)  33920       ['add_7[0][0]']
#  onv2D)
#
#  batch_normalization_8 (BatchNo  (None, 13, 2, 256)  1024        ['separable_conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 13, 2, 256)   0           ['batch_normalization_8[0][0]']
#
#  max_pooling2d_87 (MaxPooling2D  (None, 7, 1, 256)   0           ['activation_8[0][0]']
#  )
#
#  conv2d_107 (Conv2D)            (None, 7, 1, 256)    33024       ['add_7[0][0]']
#
#  add_8 (Add)                    (None, 7, 1, 256)    0           ['max_pooling2d_87[0][0]',
#                                                                   'conv2d_107[0][0]']
#
#  separable_conv2d_9 (SeparableC  (None, 7, 1, 256)   67840       ['add_8[0][0]']
#  onv2D)
#
#  batch_normalization_9 (BatchNo  (None, 7, 1, 256)   1024        ['separable_conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 7, 1, 256)    0           ['batch_normalization_9[0][0]']
#
#  add_9 (Add)                    (None, 7, 1, 256)    0           ['activation_9[0][0]',
#                                                                   'add_8[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 256)         0           ['add_9[0][0]']
#  obalAveragePooling2D)
#
#  dropout_21 (Dropout)           (None, 256)          0           ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_21 (Dense)               (None, 30)           7710        ['dropout_21[0][0]']
#
# ==================================================================================================
# Total params: 167,079
# Trainable params: 165,607
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %% [markdown]
# Il numero di parametri, come per i filterbank, è rimasto invariato.

# %%
bp_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/mfcc/bp_basic_model_mfcc.keras", save_best_only=True, monitor="val_loss")]
bp_model_history = bp_basic_model.fit(mfcc_train_ds, epochs=100, validation_data=mfcc_val_ds, callbacks=bp_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 3s 10ms/step - loss: 4.4417 - accuracy: 0.0927 - val_loss: 3.1504 - val_accuracy: 0.1061
# Epoch 2/100
# 243/243 [==============================] - 2s 9ms/step - loss: 2.8713 - accuracy: 0.1990 - val_loss: 2.5233 - val_accuracy: 0.3071
# Epoch 3/100
# 243/243 [==============================] - 2s 9ms/step - loss: 2.2811 - accuracy: 0.3474 - val_loss: 2.2130 - val_accuracy: 0.3681
# Epoch 4/100
# 243/243 [==============================] - 2s 9ms/step - loss: 1.8566 - accuracy: 0.4696 - val_loss: 1.6735 - val_accuracy: 0.5154
# Epoch 5/100
# 243/243 [==============================] - 2s 8ms/step - loss: 1.5121 - accuracy: 0.5711 - val_loss: 1.5013 - val_accuracy: 0.5640
# Epoch 6/100
# 243/243 [==============================] - 2s 6ms/step - loss: 1.2820 - accuracy: 0.6296 - val_loss: 1.4790 - val_accuracy: 0.5683
# Epoch 7/100
# 243/243 [==============================] - 2s 8ms/step - loss: 1.1281 - accuracy: 0.6769 - val_loss: 1.3235 - val_accuracy: 0.6250
# Epoch 8/100
# 243/243 [==============================] - 2s 8ms/step - loss: 1.0054 - accuracy: 0.7075 - val_loss: 1.0813 - val_accuracy: 0.6875
# Epoch 9/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.8914 - accuracy: 0.7437 - val_loss: 1.0849 - val_accuracy: 0.6829
# Epoch 10/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.8013 - accuracy: 0.7584 - val_loss: 0.9883 - val_accuracy: 0.7226
# Epoch 11/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.7276 - accuracy: 0.7857 - val_loss: 1.1247 - val_accuracy: 0.6674
# Epoch 12/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.6535 - accuracy: 0.8080 - val_loss: 1.0764 - val_accuracy: 0.6956
# Epoch 13/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.5976 - accuracy: 0.8278 - val_loss: 0.8300 - val_accuracy: 0.7604
# Epoch 14/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.5464 - accuracy: 0.8370 - val_loss: 0.9145 - val_accuracy: 0.7531
# Epoch 15/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.4964 - accuracy: 0.8519 - val_loss: 0.9611 - val_accuracy: 0.7361
# Epoch 16/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.4612 - accuracy: 0.8651 - val_loss: 0.8062 - val_accuracy: 0.7801
# Epoch 17/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.4196 - accuracy: 0.8754 - val_loss: 0.8151 - val_accuracy: 0.7693
# Epoch 18/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.3814 - accuracy: 0.8890 - val_loss: 0.8040 - val_accuracy: 0.7836
# Epoch 19/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.3601 - accuracy: 0.8939 - val_loss: 0.9957 - val_accuracy: 0.7284
# Epoch 20/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.3232 - accuracy: 0.9040 - val_loss: 0.7573 - val_accuracy: 0.7897
# Epoch 21/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.
100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0394 - accuracy: 0.9867 - val_loss: 1.0117 - val_accuracy: 0.8287
# Epoch 83/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0379 - accuracy: 0.9874 - val_loss: 0.7929 - val_accuracy: 0.8607
# Epoch 84/100
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0397 - accuracy: 0.9872 - val_loss: 0.9076 - val_accuracy: 0.8414
# Epoch 85/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0432 - accuracy: 0.9863 - val_loss: 1.0021 - val_accuracy: 0.8291
# Epoch 86/100
# 243/243 [==============================] - 2s 8ms/step - loss: 0.0363 - accuracy: 0.9879 - val_loss: 1.0606 - val_accuracy: 0.8306
# Epoch 87/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0374 - accuracy: 0.9876 - val_loss: 0.9883 - val_accuracy: 0.8302
# Epoch 88/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0387 - accuracy: 0.9865 - val_loss: 0.8934 - val_accuracy: 0.8329
# Epoch 89/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0356 - accuracy: 0.9866 - val_loss: 1.1468 - val_accuracy: 0.8094
# Epoch 90/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0416 - accuracy: 0.9858 - val_loss: 1.0183 - val_accuracy: 0.8360
# Epoch 91/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0370 - accuracy: 0.9879 - val_loss: 0.8380 - val_accuracy: 0.8519
# Epoch 92/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0421 - accuracy: 0.9865 - val_loss: 0.9078 - val_accuracy: 0.8468
# Epoch 93/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0339 - accuracy: 0.9889 - val_loss: 1.2356 - val_accuracy: 0.8090
# Epoch 94/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0368 - accuracy: 0.9879 - val_loss: 0.9878 - val_accuracy: 0.8333
# Epoch 95/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0338 - accuracy: 0.9885 - val_loss: 1.0276 - val_accuracy: 0.8399
# Epoch 96/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0409 - accuracy: 0.9861 - val_loss: 0.9585 - val_accuracy: 0.8368
# Epoch 97/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0336 - accuracy: 0.9885 - val_loss: 1.0378 - val_accuracy: 0.8356
# Epoch 98/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0328 - accuracy: 0.9898 - val_loss: 1.0029 - val_accuracy: 0.8422
# Epoch 99/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0422 - accuracy: 0.9871 - val_loss: 1.0825 - val_accuracy: 0.8302
# Epoch 100/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0337 - accuracy: 0.9872 - val_loss: 1.1387 - val_accuracy: 0.8210

# %%
bp_model_history_df = convert_history_to_csv(bp_model_history)
bp_model_history_df.to_csv("model_histories/rmsprop/mfcc/bp_model_history_mfcc.csv")

convert_model_to_onnx("bestmodels/rmsprop/mfcc/bp_basic_model_mfcc.keras", (98, 12, 1))

# %%
create_train_val_plot(bp_model_history.history, overfit=False)

# %% [markdown]
# In questo caso il modello è sotto certi aspetti leggermente migliorato rispetto a prima, ma continua ad avere delle prestazioni peggiori rispetto agli spettrogrammi e filterbanks.

# %%
best_bp_basic_model = tf.keras.models.load_model("bestmodels/rmsprop/mfcc/bp_basic_model_mfcc.keras")
test_loss, test_acc = best_bp_basic_model.evaluate(mfcc_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 2ms/step - loss: 0.7952 - accuracy: 0.7962
# Accuratezza: 0.796

# %%
evaluate_onnx_model("bestmodels/rmsprop/mfcc/bp_basic_model_mfcc.onnx", mfcc_test_ds)
# Out:
# Accuratezza: 0.796

# %% [markdown]
# Abbiamo ottenuto un'accuratezza del **82.1%**. A conferma di quanto detto prima, il modello risulta migliore.

# %%
for audio, label in mfcc_test_ds:
    create_distribution_plot(best_bp_basic_model, audio, label)
    break

# %% [markdown]
# La decisione del modello in questo caso è nuovamente molto chiara.
