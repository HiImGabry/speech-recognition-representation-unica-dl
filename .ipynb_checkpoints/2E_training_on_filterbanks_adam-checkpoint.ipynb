# %% [markdown]
# # Addestramento modello convolutivo
# Nel seguente notebook verranno addestrati i modelli presenti nel notebook [Modello convolutivo](Modello_convolutivo.ipynb), utilizzando come tipo di dati i **filterbanks** e gli **mfcc**. Ci aspettiamo di ottenere risultati differenti e sarà interessante analizzare le differenze.

# %%
import os
import time
import numpy as np
import pandas as pd
import tensorflow as tf
import scipy.fftpack as scipy
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# per il modello con estensione .onnx
import onnxruntime as rt
import tf2onnx
import onnx

# %% [markdown]
# ## Classe per la conversione del dataset
# Vista la quantità di opzioni disponibili, si è scelto di creare una classe. Essa contiene il metodo `convert` in grado di trasformare il dataset di audio in spettrogrammi, filterbanks, o mfcc in base all'argomento dato in input. Gli altri metodi presenti al suo interno sono già stati spiegati e ne abbiamo visto l'utilizzo nei precedenti notebook.

# %%
class DatasetConverter:
    def __init__(self, dataset):
        self.dataset = dataset

    def convert(self, option):
        available_options = ['spettrogrammi', 'filterbanks', 'mfcc']
        
        if option == available_options[0]:
            return self.get_spectrogram_dataset()
        elif option == available_options[1]:
            return self.get_filterbanks_dataset()
        elif option == available_options[2]:
            return self.get_mfcc_dataset()
        else:
            raise ValueError(f"Opzione non disponibile: inserire una delle seguenti opzioni: {available_options}")
    
    # INIZIO SPETTROGRAMMI
    def squeeze(self, audio, labels):
        audio = tf.squeeze(audio, axis=-1)
        return audio, labels
    
    def get_spectrogram(self, waveform):
    # applichiamo la short-time Fourier transorm
        spectrogram = tf.signal.stft(waveform, frame_length=255, frame_step=128)
        spectrogram = tf.abs(spectrogram)
        
        return spectrogram[..., tf.newaxis]
    
    def get_spectrogram_dataset(self):
        # squeeze
        self.dataset = self.dataset.map(self.squeeze, tf.data.AUTOTUNE)
        self.dataset = self.dataset.map(lambda x, y: (self.get_spectrogram(x), y), num_parallel_calls=tf.data.AUTOTUNE)
        
        return self.dataset

    # FINE SPETTROGRAMMI

    def convert_to_numpy(self, dataset):
        audio_data = []
        labels = []
    
        dataset = dataset.unbatch()
        
        for audio, label in dataset:
            audio_data.append(audio.numpy())  # Assuming audio is a tensor, convert to numpy array
            labels.append(label.numpy())      # Assuming label is a tensor, convert to numpy array
        
        audio_data = np.array(audio_data)
        labels = np.array(labels)
        
        return audio_data, labels
    
    # INIZIO FILTERBANKS
    def makeHamming(self, M):
        R = (( M - 1 ) / 2 , M / 2)[M % 2 == 0]
        w = (np.hamming(M), np.hamming(M + 1))[M % 2 == 0]
        if M % 2 != 0:
            w[0] = w[0]/2
            w[M-1] = w[M-1]/2
        else:
            w = w[:M]
    
        return w

    def hztomel(self, hz):
        return (2595 * np.log10(1 + hz / 700))

    def meltohz(self, mel):
        return (700 * (10**(mel / 2595) - 1))

    def compute_filterbanks(self, audios_np, pre_emphasis=0.97, sample_rate=16000, frame_size=0.025, frame_stride=0.01, NFFT=512, nfilt=40):
        filterbanks_np = []
        
        for samples in audios_np:
            emphasized_audio = np.append(samples[0], samples[1:] - pre_emphasis * samples[:-1])
            audio_length = len(emphasized_audio)
    
            frame_length, frame_step = int(frame_size * sample_rate), int(frame_stride * sample_rate)
    
            num_frames = int(np.ceil(float(np.abs(audio_length - frame_length)) / frame_step))
    
            pad_audio_length = num_frames * frame_step + frame_length
            z = np.zeros((pad_audio_length - audio_length))
            pad_audio = np.append(emphasized_audio, z)
    
            indices = np.tile(np.arange(0, frame_length), (num_frames, 1)) + np.tile(np.arange(0, num_frames * frame_step, frame_step), (frame_length, 1)).T
            frames = pad_audio[indices.astype(np.int32, copy=False)]
    
            # Usiamo la funzione di Hamming
            hamming_window = self.makeHamming(frame_length)
    
            mag_frames = np.absolute(np.fft.rfft(frames, NFFT))  # Magnitudo della FFT
            pow_frames = ((1.0 / NFFT) * ((mag_frames) ** 2))
    
            # convertiamo hz in mel
            low_freq_mel = self.hztomel(0)
            high_freq_mel = self.hztomel(sample_rate / 2)
    
            mel_points = np.linspace(low_freq_mel, high_freq_mel, nfilt + 2)
            hz_points = self.meltohz(mel_points) 
    
            bin = np.floor((NFFT + 1) * hz_points / sample_rate)
    
            fbank = np.zeros((nfilt, int(np.floor(NFFT / 2 + 1))))
    
            for m in range(1, nfilt + 1):
                f_m_minus = int(bin[m - 1])
                f_m = int(bin[m])
                f_m_plus = int(bin[m + 1])
    
                for k in range(f_m_minus, f_m):
                    fbank[m - 1, k] = (k - bin[m - 1]) / (bin[m] - bin[m - 1])
                for k in range(f_m, f_m_plus):
                    fbank[m - 1, k] = (bin[m + 1] - k) / (bin[m + 1] - bin[m])
    
            # in questo momento invece calcoliamo i filter banks per i segmenti di audio, utilizzando i filtri triangolari appena creati
            filter_banks = np.dot(pow_frames, fbank.T)
            filter_banks = np.where(filter_banks == 0, np.finfo(float).eps, filter_banks)
            filter_banks = 20 * np.log10(filter_banks)
    
            filterbanks_np.append(filter_banks)
        
        return np.array(filterbanks_np)
    
    def get_filterbanks_dataset(self): 
        audios, labels = self.convert_to_numpy(self.dataset)

        filterbanks = self.compute_filterbanks(audios)
        filterbanks = np.expand_dims(filterbanks, axis=-1)

        self.dataset = tf.data.Dataset.from_tensor_slices((filterbanks, labels))
        self.dataset = self.dataset.batch(32)
        
        return self.dataset
    # FINE FILTERBANKS

    # INIZIO MFCC
    def compute_mfcc(self, filter_banks, num_ceps=12, cep_lifter=22):
        mfcc_np = []
        
        for f in filter_banks:
            mfcc = scipy.dct(f, type=2, axis=1, norm='ortho')[:, 1 : (num_ceps + 1)]

            (nframes, ncoeff) = mfcc.shape
            n = np.arange(ncoeff)
            
            lift = 1 + (cep_lifter / 2) * np.sin(np.pi * n / cep_lifter)
            mfcc *= lift

            mfcc_np.append(mfcc)
        
        return np.array(mfcc_np)
    
    
    def get_mfcc_dataset(self):
        audios, labels = self.convert_to_numpy(self.dataset)

        filterbanks = self.compute_filterbanks(audios)
        mfcc = self.compute_mfcc(filterbanks)
        
        mfcc = np.expand_dims(mfcc, axis=-1)
        
        self.dataset = tf.data.Dataset.from_tensor_slices((mfcc, labels))
        self.dataset = self.dataset.batch(32)
        
        return self.dataset
    
    # FINE MFCC

# %% [markdown]
# ## Importazione funzioni ulteriori
# In aggiunta alla classe per la conversione del dataset, ci serviremo delle seguenti funzioni:
# - `convert_history_to_csv` - salva l'history dell'addestramento in un csv
# - `convert_model_to_onnx` - converte il miglior modello **.keras** in **.onnx**
# - `create_train_val_plot` - visualizza l'andamento dell'accuratezza e della perdita durante l'addestramento
# - `evaluate_onnx_model` - valuta il modello sui dati di test con il modello **.onnx**
# - `create_distribution_plot` - visualizza la distribuzione di accuratezza delle classi su un'immagine casuale
#
# Anch'esse sono già state viste, perciò non ci soffermeremo troppo su di esse.

# %%
def convert_history_to_csv(model_history):
    # converto la history del dataframe in un dataframe pandas
    model_history_df = pd.DataFrame(model_history.history)
    # cambio il nome dell'indice e lo imposto a partire da 1
    model_history_df.index = range(1, len(model_history_df) + 1)
    model_history_df.index.name = "epochs"

    return model_history_df

def convert_model_to_onnx(model_path, input_shape):
    model = tf.keras.models.load_model(model_path)

    onnx_path = model_path.split(".")[:-1] + ["onnx"]
    onnx_path = ".".join(onnx_path)
    
    input_signature = [tf.TensorSpec((None, *input_shape), tf.float32, name="input")]
    onnx_model, _ = tf2onnx.convert.from_keras(model, input_signature=input_signature)

    onnx.save(onnx_model, onnx_path)

def create_train_val_plot(history, overfit=True):
    # definisco numero epoche
    epochs = range(1, len(history['accuracy']) + 1)

    # Accuracy
    accuracy = history['accuracy']
    val_accuracy = history['val_accuracy']

    fig_acc, ax_acc = plt.subplots()

    # linea di base
    ax_acc.plot(epochs, [0.5 for x in range(len(epochs))], color="lightgray", linestyle="--", label="Base")
    # linee di accuratezza
    ax_acc.plot(epochs, accuracy, color="slategray", label="Accuratezza in addestramento")
    ax_acc.plot(epochs, val_accuracy, color="indianred", label="Accuratezza in validazione")
    # miglior accuratezza validazione
    ax_acc.axhline(y=max(val_accuracy), c='indianred', alpha=0.7, linestyle='--')
    ax_acc.text(len(epochs) * 1.07, max(val_accuracy), round(max(val_accuracy), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_acc.spines["right"].set_visible(False)
    ax_acc.spines["top"].set_visible(False)
    ax_acc.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_acc.set_title("Accuratezza in addestramento e validazione")
    ax_acc.set_xlabel("Epoche")
    ax_acc.set_ylabel("Accuratezza (%)")
    ax_acc.legend()

    # Loss
    loss = history['loss']
    val_loss = history['val_loss']

    fig_loss, ax_loss = plt.subplots()

    # linee di loss
    ax_loss.plot(epochs, loss, color="slategray", label="Perdita in addestramento")
    ax_loss.plot(epochs, val_loss, color="indianred", label="Perdita in validazione")
    # miglior loss validazione
    ax_loss.axhline(y=min(val_loss), c='indianred', alpha=0.7, linestyle='--')
    ax_loss.text(len(epochs) * 1.07, min(val_loss), round(min(val_loss), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_loss.spines["right"].set_visible(False)
    ax_loss.spines["top"].set_visible(False)
    ax_loss.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_loss.set_title("Perdita in addestramento e validazione")
    ax_loss.set_xlabel("Epoche")
    ax_loss.set_ylabel("Perdita")

    handles, _ = ax_loss.get_legend_handles_labels()

    if overfit:
        # area overfit
        rect = mpatches.Rectangle((np.argmin(val_loss) + 1, 0), width=100 - np.argmin(val_loss), height=max(max(loss), max(val_loss)), color='lightcoral', alpha=0.3)
        ax_loss.add_patch(rect)
        # patch overfit per legenda
        overfit = mpatches.Patch(color='indianred', alpha=0.3, label='Area overfit')
        handles, _ = ax_loss.get_legend_handles_labels()
        handles.append(overfit)

    # legenda
    ax_loss.legend(handles=handles)

    plt.show()

def evaluate_onnx_model(path_model_onnx, test_ds):
    # il fatto che sia suddiviso in batch mi crea problemi, perciò lo risolvo togliendoli
    test_ds = test_ds.unbatch()
    
    # carico il modello utilizzando il file onnx
    m = rt.InferenceSession(path_model_onnx)
    
    # trasformo il dataset in array numpy
    spectrogram_np = np.array([spectrogram.numpy() for spectrogram, _ in test_ds], dtype=np.float32)
    labels_np = np.array([label.numpy() for _, label in test_ds])
    
    # eseguo le predizione del modello
    pred_onnx = m.run(None, {'input': spectrogram_np})
    # ottengo la predizione corretta
    predictions = np.argmax(pred_onnx[0], axis=1)
    # computo la accuratezza
    accuracy = np.mean(predictions == labels_np)
    # stampo l'accuratezza
    print(f"Accuratezza: {accuracy:.3f}")

def create_distribution_plot(model, audio, label):
    prediction = model(audio) # otteniamo la predizione del modello sull'audio preso in input

    random_audio_index = np.random.randint(0, len(prediction) - 1) # abbiamo notato che mostravamo sempre la classe no, magari così cambia un po' le classi che mostriamo

    softmax_pred = tf.nn.softmax(prediction[random_audio_index]) # dobbiamo applicare nuovamente la softmax in modo tale da avere dei dati leggibili
    pred_label = np.argmax(softmax_pred) # ci salviamo l'indice della label predetta dal nostro modello, quella con la probabilità più alta

    colors = ['indianred'] * len(label_names) # creiamo un vettore di lunghezza 30 (la quantità delle nostre label) colorate di rosso

    if pred_label == label[random_audio_index].numpy(): # se la label che abbiamo predetto è corretta, allora la coloriamo di verde
        colors[pred_label] = 'seagreen'
    else: # se la label che abbiamo predetto è sbagliata, allora coloriamo di verde la corretta e di gialla la predetta
        colors[pred_label] = 'khaki'
        colors[label[random_audio_index].numpy()] = 'seagreen'

    plt.figure(figsize=(12, 4))

    plt.bar(label_names, softmax_pred.numpy(), color=colors)
    plt.xticks(rotation=45)

    # dichiariamo i colori della legenda
    other_values_patch = mpatches.Patch(color='indianred', label='Altre classi')
    pred_value_patch = mpatches.Patch(color='khaki', label='Classe predetta')
    correct_value_patch = mpatches.Patch(color='green', label='Classe corretta')

    # disegniamo la legenda con i colori necessari
    if pred_label == label[random_audio_index].numpy(): # se abbiamo predetto correttamente la label, non è necessario mostrare il colore giallo (non è presente nel plot)
        plt.legend(handles=[other_values_patch, correct_value_patch])
    else:
        plt.legend(handles=[other_values_patch, pred_value_patch, correct_value_patch])

    plt.show()

# %% [markdown]
# Importiamo il dataset e lo dividiamo in set di allenamento e set di validazione. Successivamente salviamo la lista delle etichette disponibili.

# %%
train_ds, validation_ds = tf.keras.utils.audio_dataset_from_directory(
    directory='../reduced_dataset/dataset/audio',
    validation_split=0.4, # stiamo mettendo da parte il 40% del dataset, che sarà suddiviso in validation set e test set
    shuffle=True,
    subset='both', # necessario se stiamo utilizzando validation_split (se no darebbe errore)
    seed=0 # necessario se stiamo utilizzando sia shuffle che validation_split (se no darebbe errore)
)

label_names = train_ds.class_names
# Out:
# Found 12933 files belonging to 30 classes.
# Using 7760 files for training.
# Using 5173 files for validation.

# %% [markdown]
# ## Addestramento modello convolutivo base (filterbanks)
# L'addestramento delle reti convolutive sugli spettrogrammi sono già state effettuate, perciò di seguito ci focalizzeremo sui filterbank.

# %% [markdown]
# Si parte chiamando la classe **DatasetConvert** e passandole in input il set di allenamento. Di seguito, con il metodo **convert**, scegliamo di mutare gli audio in filterbanks.
#
# Ripetiamo gli stessi passaggi anche per il set di validazione. Quest'ultimo viene ulteriormente diviso per creare il set di test.

# %%
fb_train_ds = DatasetConverter(train_ds)
fb_train_ds = fb_train_ds.convert('filterbanks')

fb_validation_ds = DatasetConverter(validation_ds)
fb_validation_ds = fb_validation_ds.convert('filterbanks')

fb_val_ds = fb_validation_ds.take(fb_validation_ds.cardinality() // 2)
fb_test_ds = fb_validation_ds.skip(fb_validation_ds.cardinality() // 2)

# %% [markdown]
# Ora che abbiamo convertito con successo il dataset in filterbank, possiamo creare il modello, identico a quello usato per gli spettrogrammi, e procedere all'addestramento utilizzando l'ottimizzatore **adam**.

# %%
def get_basic_model(input_shape):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=input_shape, name="inputs")
    x = tf.keras.layers.Normalization(name="normalizzazione")(inputs)

    # Blocco di apprendimento delle caratteristiche
    conv2D_1 = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same", name="conv2D_1")(x)
    MaxPooling2D_1 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_1")(conv2D_1)
    conv2D_2 = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same", name="conv2D_2")(MaxPooling2D_1)
    MaxPooling2D_2 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_2")(conv2D_2)
    conv2D_3 = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same", name="conv2D_3")(MaxPooling2D_2)
    MaxPooling2D_3 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_3")(conv2D_3)
    conv2D_4 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_4")(MaxPooling2D_3)
    MaxPooling2D_4 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_4")(conv2D_4)
    conv2D_5 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_5")(MaxPooling2D_4)

    # Blocco di classificazione
    Flatten = tf.keras.layers.Flatten(name="Flatten")(conv2D_5)
    outputs = tf.keras.layers.Dense(30, activation="softmax", name="dense_output")(Flatten)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
for audio, label in fb_train_ds:
    basic_model = get_basic_model(audio.shape[1:])
    break
    
basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

basic_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inputs (InputLayer)         [(None, 98, 40, 1)]       0
#
#  normalizzazione (Normalizat  (None, 98, 40, 1)        3
#  ion)
#
#  conv2D_1 (Conv2D)           (None, 98, 40, 32)        320
#
#  MaxPooling2D_1 (MaxPooling2  (None, 49, 20, 32)       0
#  D)
#
#  conv2D_2 (Conv2D)           (None, 49, 20, 64)        18496
#
#  MaxPooling2D_2 (MaxPooling2  (None, 24, 10, 64)       0
#  D)
#
#  conv2D_3 (Conv2D)           (None, 24, 10, 128)       73856
#
#  MaxPooling2D_3 (MaxPooling2  (None, 12, 5, 128)       0
#  D)
#
#  conv2D_4 (Conv2D)           (None, 12, 5, 256)        295168
#
#  MaxPooling2D_4 (MaxPooling2  (None, 6, 2, 256)        0
#  D)
#
#  conv2D_5 (Conv2D)           (None, 6, 2, 256)         590080
#
#  Flatten (Flatten)           (None, 3072)              0
#
#  dense_output (Dense)        (None, 30)                92190
#
# =================================================================
# Total params: 1,070,113
# Trainable params: 1,070,110
# Non-trainable params: 3
# _________________________________________________________________

# %% [markdown]
# Essendo l'input shape di **98 x 40**, anche il numero di parametri sarà minore rispetto al modello addestrato sugli spettrogrammi, passando da circa **1.4 milioni di parametri** a poco meno di **1.1 milioni di parametri**.

# %%
basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/adam/filterbanks/basic_model_fb.keras", save_best_only=True, monitor="val_loss")]
basic_model_history = basic_model.fit(fb_train_ds, epochs=30, batch_size=32, validation_data=fb_val_ds, callbacks=basic_model_callbacks)
# Out:
# Epoch 1/30
# 243/243 [==============================] - 4s 5ms/step - loss: 3.5037 - accuracy: 0.0473 - val_loss: 3.0265 - val_accuracy: 0.1358
# Epoch 2/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.2719 - accuracy: 0.3336 - val_loss: 1.4362 - val_accuracy: 0.5764
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.9508 - accuracy: 0.7156 - val_loss: 0.8326 - val_accuracy: 0.7623
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5266 - accuracy: 0.8396 - val_loss: 0.6443 - val_accuracy: 0.8237
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3551 - accuracy: 0.8887 - val_loss: 0.5942 - val_accuracy: 0.8326
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2684 - accuracy: 0.9159 - val_loss: 0.6635 - val_accuracy: 0.8387
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2082 - accuracy: 0.9344 - val_loss: 0.8211 - val_accuracy: 0.8129
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1787 - accuracy: 0.9445 - val_loss: 0.7967 - val_accuracy: 0.8310
# Epoch 9/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1409 - accuracy: 0.9558 - val_loss: 0.7905 - val_accuracy: 0.8445
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1291 - accuracy: 0.9612 - val_loss: 0.7777 - val_accuracy: 0.8542
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1172 - accuracy: 0.9648 - val_loss: 0.7843 - val_accuracy: 0.8445
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0979 - accuracy: 0.9677 - val_loss: 0.8269 - val_accuracy: 0.8488
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1084 - accuracy: 0.9655 - val_loss: 0.9371 - val_accuracy: 0.8314
# Epoch 14/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0774 - accuracy: 0.9753 - val_loss: 0.8094 - val_accuracy: 0.8661
# Epoch 15/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0882 - accuracy: 0.9713 - val_loss: 0.9185 - val_accuracy: 0.8549
# Epoch 16/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1021 - accuracy: 0.9698 - val_loss: 0.8635 - val_accuracy: 0.8654
# Epoch 17/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1186 - accuracy: 0.9679 - val_loss: 0.7381 - val_accuracy: 0.8623
# Epoch 18/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0865 - accuracy: 0.9741 - val_loss: 0.8481 - val_accuracy: 0.8607
# Epoch 19/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0972 - accuracy: 0.9736 - val_loss: 0.9353 - val_accuracy: 0.8519
# Epoch 20/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0795 - accuracy: 0.9789 - val_loss: 0.7513 - val_accuracy: 0.8669
# Epoch 21/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0466 - accuracy: 0.9870 - val_loss: 0.8277 - val_accuracy: 0.8839
# Epoch 22/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0569 - accuracy: 0.9820 - val_loss: 0.8841 - val_accuracy: 0.8850
# Epoch 23/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0552 - accuracy: 0.9847 - val_loss: 1.1097 - val_accuracy: 0.8592
# Epoch 24/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0982 - accuracy: 0.9745 - val_loss: 0.9564 - val_accuracy: 0.8627
# Epoch 25/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0538 - accuracy: 0.9851 - val_loss: 0.8434 - val_accuracy: 0.8750
# Epoch 26/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0817 - accuracy: 0.9747 - val_loss: 1.1929 - val_accuracy: 0.8345
# Epoch 27/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1175 - accuracy: 0.9679 - val_loss: 1.0164 - val_accuracy: 0.8526
# Epoch 28/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0617 - accuracy: 0.9836 - val_loss: 0.9343 - val_accuracy: 0.8800
# Epoch 29/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0518 - accuracy: 0.9843 - val_loss: 1.0110 - val_accuracy: 0.8665
# Epoch 30/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0474 - accuracy: 0.9872 - val_loss: 0.9482 - val_accuracy: 0.8765

# %% [markdown]
# Salviamo i dati della cronologia del modello in un file csv e convertiamo il miglior modello nell'estensione **.onnx**.

# %%
basic_model_history_df = convert_history_to_csv(basic_model_history)
basic_model_history_df.to_csv("model_histories/adam/filterbanks/basic_model_history_fb.csv")

convert_model_to_onnx("bestmodels/adam/filterbanks/basic_model_fb.keras", (98, 40, 1))

# %% [markdown]
# Analizziamo l'andamento dell'accuratezza e della perdita durante l'addestramento.

# %%
create_train_val_plot(basic_model_history.history)

# %% [markdown]
# Dal grafico si evince che il modello entra in overfitting poco dopo la quinta epoca, raggiungendo comunque ottimi risultati per quanto riguarda l'accuratezza del validation set, con **90** punti percentile.
#
# La rete, inoltre, sembra essere lievemente migliore del modello addestrato sugli spettrogrammi, ma comparazioni più approffondite saranno affrontate su un notebook dedicato.

# %% [markdown]
# Verifichiamo l'accuratezza della migliore versione del modello di base.

# %%
best_basic_model = tf.keras.models.load_model("bestmodels/adam/filterbanks/basic_model_fb.keras")
test_loss, test_acc = best_basic_model.evaluate(fb_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 3ms/step - loss: 0.6196 - accuracy: 0.8315
# Accuratezza: 0.831

# %%
evaluate_onnx_model("bestmodels/adam/filterbanks/basic_model_fb.onnx", fb_test_ds)
# Out:
# Accuratezza: 0.831

# %% [markdown]
# Abbiamo ottenuto un'**accuratezza** del **83.1%**! Attualmente abbiamo riscontrato un miglioramento utilizzando i filter banks. Visualizziamo la distribuzione di accuratezza delle classi.

# %%
for audio, label in fb_test_ds: # prendiamo un audio a caso del test e creiamo la distribuzione
    create_distribution_plot(best_basic_model, audio, label)
    break

# %% [markdown]
# In questo specifico caso il modello ha **sbagliato totalmente** la classe predetta.

# %% [markdown]
# ### Convolutivo base risoluzione dell'overfitting
# In questa parte implementiamo il secondo modello presente nel notebook di riferimento, ovvero quello riguardante il paragrafo **risoluzione dell'overfitting**, dove viene aggiunto uno strato di dropout.

# %% [markdown]
# Come fatto prima, si procede con la creazione e l'addestramento del modello con l'ottimizzatore **adam**.

# %%
def get_improved_basic_model(input_shape):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=input_shape)
    x = tf.keras.layers.Normalization()(inputs)

    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
for audio, label in fb_train_ds:
    improved_basic_model = get_improved_basic_model(audio.shape[1:])
    break

improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/adam/filterbanks/improved_basic_model_fb.keras", save_best_only=True, monitor="val_loss")]
improved_history = improved_basic_model.fit(fb_train_ds, epochs=100, validation_data=fb_val_ds, callbacks=improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 2s 5ms/step - loss: 3.5181 - accuracy: 0.0352 - val_loss: 3.3916 - val_accuracy: 0.0378
# Epoch 2/100
# 243/243 [==============================] - 1s 4ms/step - loss: 2.9408 - accuracy: 0.1513 - val_loss: 2.1856 - val_accuracy: 0.3711
# Epoch 3/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.7818 - accuracy: 0.4737 - val_loss: 1.2614 - val_accuracy: 0.6223
# Epoch 4/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.0810 - accuracy: 0.6732 - val_loss: 0.9097 - val_accuracy: 0.7342
# Epoch 5/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7935 - accuracy: 0.7561 - val_loss: 0.7938 - val_accuracy: 0.7697
# Epoch 6/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6354 - accuracy: 0.8084 - val_loss: 0.7585 - val_accuracy: 0.7785
# Epoch 7/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5101 - accuracy: 0.8399 - val_loss: 0.6767 - val_accuracy: 0.8079
# Epoch 8/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4468 - accuracy: 0.8603 - val_loss: 0.5696 - val_accuracy: 0.8376
# Epoch 9/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3776 - accuracy: 0.8799 - val_loss: 0.5746 - val_accuracy: 0.8461
# Epoch 10/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3199 - accuracy: 0.9000 - val_loss: 0.7399 - val_accuracy: 0.8148
# Epoch 11/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2984 - accuracy: 0.9048 - val_loss: 0.5282 - val_accuracy: 0.8584
# Epoch 12/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2734 - accuracy: 0.9126 - val_loss: 0.5966 - val_accuracy: 0.8457
# Epoch 13/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2288 - accuracy: 0.9277 - val_loss: 0.5597 - val_accuracy: 0.8700
# Epoch 14/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2388 - accuracy: 0.9222 - val_loss: 0.6944 - val_accuracy: 0.8430
# Epoch 15/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2030 - accuracy: 0.9341 - val_loss: 0.7059 - val_accuracy: 0.8519
# Epoch 16/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2341 - accuracy: 0.9265 - val_loss: 0.6675 - val_accuracy: 0.8526
# Epoch 17/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1844 - accuracy: 0.9421 - val_loss: 0.6582 - val_accuracy: 0.8607
# Epoch 18/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1778 - accuracy: 0.9424 - val_loss: 0.8008 - val_accuracy: 0.8360
# Epoch 19/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1713 - accuracy: 0.9469 - val_loss: 0.6353 - val_accuracy: 0.8638
# Epoch 20/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1652 - accuracy: 0.9486 - val_loss: 0.9754 - val_accuracy: 0.8063
# Epoch 21/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1818 - accuracy: 0.9441 - val_loss: 0.6813 - val_accuracy: 0.8542
# Epoch 22/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1346 - accuracy: 0.9576 - val_loss: 0.6308 - val_accuracy: 0.8719
# Epoch 23/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1580 - accuracy: 0.9509 - val_loss: 0.8566 - val_accuracy: 0.8399
# Epoch 24/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1417 - accuracy: 0.9548 - val_loss: 0.6386 - val_accuracy: 0.8816
# Epoch 25/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1643 - accuracy: 0.9486 - val_loss: 0.6190 - val_accuracy: 0.8630
# Epoch 26/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1630 - accuracy: 0.9503 - val_loss: 0.6443 - val_accuracy: 0.8765
# Epoch 27/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1265 - accuracy: 0.9608 - val_loss: 0.7260 - val_accuracy: 0.8669
# Epoch 28/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1503 - accuracy: 0.9541 - val_loss: 0.6889 - val_accuracy: 0.8711
# Epoch 29/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1432 - accuracy: 0.9567 - val_loss: 0.6406 - val_accuracy: 0.8765
# Epoch 30/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1083 - accuracy: 0.9668 - val_loss: 0.6474 - val_accuracy: 0.8812
# Epoch 31/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1150 - accuracy: 0.9652 - val_loss: 0.8365 - val_accuracy: 0.8580
# Epoch 32/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1125 - accuracy: 0.9659 - val_loss: 0.6904 - val_accuracy: 0.8715
# Epoch 33/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1242 - accuracy: 0.9631 - val_loss: 0.6887 - val_accuracy: 0.8762
# Epoch 34/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1005 - accuracy: 0.9696 - val_loss: 0.7392 - val_accuracy: 0.8735
# Epoch 35/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1550 - accuracy: 0.9546 - val_loss: 0.7671 - val_accuracy: 0.8719
# Epoch 36/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1145 - accuracy: 0.9644 - val_loss: 0.7176 - val_accuracy: 0.8657
# Epoch 37/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1159 - accuracy: 0.9665 - val_loss: 0.6418 - val_accuracy: 0.8870
# Epoch 38/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1578 - accuracy: 0.9540 - val_loss: 0.7139 - val_accuracy: 0.8727
# Epoch 39/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0847 - accuracy: 0.9724 - val_loss: 0.5986 - val_accuracy: 0.8927
# Epoch 40/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1236 - accuracy: 0.9670 - val_loss: 0.6701 - val_accuracy: 0.8781
# Epoch 41/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0827 - accuracy: 0.9756 - val_loss: 0.6901 - val_accuracy: 0.8742
# Epoch 42/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1025 - accuracy: 0.9683 - val_loss: 0.6984 - val_accuracy: 0.8846
# Epoch 43/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1198 - accuracy: 0.9673 - val_loss: 0.6950 - val_accuracy: 0.8762
# Epoch 44/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0978 - accuracy: 0.9723 - val_loss: 0.8414 - val_accuracy: 0.8843
# Epoch 45/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1098 - accuracy: 0.9689 - val_loss: 0.7450 - val_accuracy: 0.8873
# Epoch 46/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1271 - accuracy: 0.9653 - val_loss: 0.7036 - val_accuracy: 0.8843
# Epoch 47/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0804 - accuracy: 0.9777 - val_loss: 0.7236 - val_accuracy: 0.8827
# Epoch 48/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1074 - accuracy: 0.9720 - val_loss: 0.8163 - val_accuracy: 0.8808
# Epoch 49/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0895 - accuracy: 0.9728 - val_loss: 0.7595 - val_accuracy: 0.8781
# Epoch 50/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1386 - accuracy: 0.9639 - val_loss: 0.9263 - val_accuracy: 0.8638
# Epoch 51/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1664 - accuracy: 0.9548 - val_loss: 0.9216 - val_accuracy: 0.8457
# Epoch 52/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0937 - accuracy: 0.9745 - val_loss: 0.7421 - val_accuracy: 0.8846
# Epoch 53/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0751 - accuracy: 0.9790 - val_loss: 0.8962 - val_accuracy: 0.8711
# Epoch 54/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1095 - accuracy: 0.9715 - val_loss: 0.7205 - val_accuracy: 0.8885
# Epoch 55/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0877 - accuracy: 0.9728 - val_loss: 0.7423 - val_accuracy: 0.8893
# Epoch 56/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0904 - accuracy: 0.9767 - val_loss: 0.7513 - val_accuracy: 0.8873
# Epoch 57/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1162 - accuracy: 0.9673 - val_loss: 0.8043 - val_accuracy: 0.8854
# Epoch 58/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0848 - accuracy: 0.9776 - val_loss: 0.7067 - val_accuracy: 0.8943
# Epoch 59/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1213 - accuracy: 0.9678 - val_loss: 0.7368 - val_accuracy: 0.8831
# Epoch 60/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1094 - accuracy: 0.9706 - val_loss: 0.7953 - val_accuracy: 0.8978
# Epoch 61/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0964 - accuracy: 0.9764 - val_loss: 0.7646 - val_accuracy: 0.8900
# Epoch 62/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1074 - accuracy: 0.9738 - val_loss: 0.7941 - val_accuracy: 0.8800
# Epoch 63/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1061 - accuracy: 0.9736 - val_loss: 0.7168 - val_accuracy: 0.8916
# Epoch 64/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0803 - accuracy: 0.9751 - val_loss: 0.8012 - val_accuracy: 0.8831
# Epoch 65/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1105 - accuracy: 0.9729 - val_loss: 0.8045 - val_accuracy: 0.8754
# Epoch 66/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0928 - accuracy: 0.9749 - val_loss: 0.7421 - val_accuracy: 0.8858
# Epoch 67/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0755 - accuracy: 0.9786 - val_loss: 0.9528 - val_accuracy: 0.8711
# Epoch 68/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1140 - accuracy: 0.9723 - val_loss: 0.8261 - val_accuracy: 0.8823
# Epoch 69/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1002 - accuracy: 0.9729 - val_loss: 0.9532 - val_accuracy: 0.8796
# Epoch 70/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0756 - accuracy: 0.9793 - val_loss: 0.9969 - val_accuracy: 0.8692
# Epoch 71/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1174 - accuracy: 0.9706 - val_loss: 0.8962 - val_accuracy: 0.8673
# Epoch 72/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1090 - accuracy: 0.9756 - val_loss: 0.9282 - val_accuracy: 0.8831
# Epoch 73/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0901 - accuracy: 0.9763 - val_loss: 0.8738 - val_accuracy: 0.8854
# Epoch 74/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0874 - accuracy: 0.9759 - val_loss: 0.8615 - val_accuracy: 0.8908
# Epoch 75/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1116 - accuracy: 0.9741 - val_loss: 0.9291 - val_accuracy: 0.8897
# Epoch 76/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0974 - accuracy: 0.9740 - val_loss: 0.9359 - val_accuracy: 0.8989
# Epoch 77/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1027 - accuracy: 0.9754 - val_loss: 0.9015 - val_accuracy: 0.8927
# Epoch 78/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0649 - accuracy: 0.9832 - val_loss: 1.1292 - val_accuracy: 0.8827
# Epoch 79/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1131 - accuracy: 0.9747 - val_loss: 0.9535 - val_accuracy: 0.8846
# Epoch 80/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1657 - accuracy: 0.9669 - val_loss: 1.0106 - val_accuracy: 0.8846
# Epoch 81/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1161 - accuracy: 0.9737 - val_loss: 0.9463 - val_accuracy: 0.8796
# Epoch 82/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0649 - accuracy: 0.9814 - val_loss: 0.9750 - val_accuracy: 0.8943
# Epoch 83/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0838 - accuracy: 0.9789 - val_loss: 0.8415 - val_accuracy: 0.8947
# Epoch 84/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0776 - accuracy: 0.9816 - val_loss: 1.0912 - val_accuracy: 0.8789
# Epoch 85/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0922 - accuracy: 0.9774 - val_loss: 0.9775 - val_accuracy: 0.8889
# Epoch 86/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0903 - accuracy: 0.9794 - val_loss: 1.0827 - val_accuracy: 0.8731
# Epoch 87/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9763 - val_loss: 0.8039 - val_accuracy: 0.8943
# Epoch 88/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0630 - accuracy: 0.9825 - val_loss: 1.1320 - val_accuracy: 0.8765
# Epoch 89/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1124 - accuracy: 0.9724 - val_loss: 1.0645 - val_accuracy: 0.8908
# Epoch 90/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0920 - accuracy: 0.9782 - val_loss: 1.1782 - val_accuracy: 0.8769
# Epoch 91/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0884 - accuracy: 0.9790 - val_loss: 1.0950 - val_accuracy: 0.8931
# Epoch 92/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1448 - accuracy: 0.9714 - val_loss: 1.0176 - val_accuracy: 0.8738
# Epoch 93/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1295 - accuracy: 0.9746 - val_loss: 1.2624 - val_accuracy: 0.8526
# Epoch 94/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1127 - accuracy: 0.9720 - val_loss: 0.8856 - val_accuracy: 0.8947
# Epoch 95/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0897 - accuracy: 0.9774 - val_loss: 1.0986 - val_accuracy: 0.8931
# Epoch 96/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1063 - accuracy: 0.9780 - val_loss: 1.0256 - val_accuracy: 0.8947
# Epoch 97/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0860 - accuracy: 0.9808 - val_loss: 1.0038 - val_accuracy: 0.8870
# Epoch 98/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0778 - accuracy: 0.9812 - val_loss: 0.9293 - val_accuracy: 0.8827
# Epoch 99/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0926 - accuracy: 0.9773 - val_loss: 0.9649 - val_accuracy: 0.8993
# Epoch 100/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0932 - accuracy: 0.9821 - val_loss: 1.2732 - val_accuracy: 0.8796

# %% [markdown]
# Seguiamo lo stesso ordine di prima per le operazione post-addestramento.

# %%
improved_history_df = convert_history_to_csv(improved_history)
improved_history_df.to_csv("model_histories/adam/filterbanks/improved_history_fb.csv")

convert_model_to_onnx("bestmodels/adam/filterbanks/improved_basic_model_fb.keras", (98, 40, 1))

# %%
create_train_val_plot(improved_history.history)

# %% [markdown]
# I risultati sono decisamente positivi. Siamo riusciti a ritardare il sovradattamento, arrivando a livelli di perdita molto più bassi rispetto al precedente. Inoltre, l'accuratezza nel set di valutazione è salita del **3%**.

# %%
improved_best_model = tf.keras.models.load_model("bestmodels/adam/filterbanks/improved_basic_model_fb.keras")
test_loss, test_acc = improved_best_model.evaluate(fb_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5805 - accuracy: 0.8427
# Accuratezza: 0.843

# %%
evaluate_onnx_model("bestmodels/adam/filterbanks/improved_basic_model_fb.onnx", fb_test_ds)
# Out:
# Accuratezza: 0.843

# %% [markdown]
# L'aumento di prestazioni vengono rispecchiate nel test set, dove si giunge a un'accuratezza di **88.1%**, con un notevole migliramento rispetto al precedente.

# %%
for audio, label in fb_test_ds:
    create_distribution_plot(improved_best_model, audio, label)
    break

# %% [markdown]
# ### Fine tuning
# In questa sezione effettuiamo il fine tuning nello stesso modo del notebook di riferimento.

# %%
def get_improved_basic_model_tuning(start_filters):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(98, 40, 1))
    x = tf.keras.layers.Normalization()(inputs)

    if not isinstance(start_filters, int):
        raise Exception("start_filters must be type integer")

    filters = [start_filters * (2 ** i) for i in range(4)]
    
    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=filters[0], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[1], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[2], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[3], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[3], kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

def tuner(filters, learning_rates, max_epochs, train_dataset, validation_dataset):
    start_time = time.time()

    counter = 1
    
    if not isinstance(filters, list):
        raise Exception("parameter filters must be type list")

    if not isinstance(learning_rates, list):
        raise Exception("parameter learning_rates must be type list")

    callbacks = [tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5)]

    best_learning_rate = 0 
    best_filters = 0
    best_val_accuracy = 0

    best_model = 0
    
    for f in filters:
        for lr in learning_rates:
            print(f"\nAddestrando con filtri {[f * (2 ** i) for i in range(4)]} e tasso di apprendimento {lr}")
            
            model = get_improved_basic_model_tuning(start_filters=f)
            model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=lr), metrics=["accuracy"])
            model_history = model.fit(train_dataset, epochs=max_epochs, validation_data=validation_dataset, callbacks=callbacks)

            model_history_df = convert_history_to_csv(model_history)

            model_history_df[["filters"]] = f
            model_history_df[["learning_rate"]] = lr
            
            path = "model_tuning/adam/filterbanks/model_" + str(counter) + ".csv"
            model_history_df.to_csv(path)
            
            if best_val_accuracy < model_history_df.iloc[-1]["val_accuracy"]:
                best_val_accuracy = model_history_df.iloc[-1]["val_accuracy"]
                best_filters = f
                best_learning_rate = lr
                epoch = len(model_history_df)

            del model

            counter += 1

    total_time = time.time() - start_time
    minutes, seconds = divmod(total_time, 60)
    print(f"\nTempo totale trascorso: {int(minutes)} minuti e {int(seconds)} secondi")
    # print(f"Il miglior modello ha un filtro di partenza pari a {best_filters}, un learning rate pari a {best_learning_rate} con un'accuracy pari a {best_val_accuracy:.3f}")

    return best_filters, best_learning_rate

# %%
best_filter, best_learning_rate = tuner([16, 32, 64], [1e-3, 1e-4, 1e-5], 30, fb_train_ds, fb_val_ds)
# Out:
# Addestrando con filtri [16, 32, 64, 128] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 2s 5ms/step - loss: 3.4830 - accuracy: 0.0424 - val_loss: 3.1691 - val_accuracy: 0.0891
# Epoch 2/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.5946 - accuracy: 0.2396 - val_loss: 1.6885 - val_accuracy: 0.4988
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.4477 - accuracy: 0.5646 - val_loss: 0.9748 - val_accuracy: 0.7041
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8958 - accuracy: 0.7280 - val_loss: 0.6655 - val_accuracy: 0.7955
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6444 - accuracy: 0.8054 - val_loss: 0.5934 - val_accuracy: 0.8210
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4902 - accuracy: 0.8448 - val_loss: 0.5352 - val_accuracy: 0.8472
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4071 - accuracy: 0.8701 - val_loss: 0.5464 - val_accuracy: 0.8519
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3641 - accuracy: 0.8849 - val_loss: 0.4625 - val_accuracy: 0.8785
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3055 - accuracy: 0.9015 - val_loss: 0.4928 - val_accuracy: 0.8777
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2508 - accuracy: 0.9186 - val_loss: 0.5407 - val_accuracy: 0.8711
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2447 - accuracy: 0.9268 - val_loss: 0.4973 - val_accuracy: 0.8758
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2202 - accuracy: 0.9303 - val_loss: 0.5634 - val_accuracy: 0.8580
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1944 - accuracy: 0.9392 - val_loss: 0.4761 - val_accuracy: 0.8877
#
# Addestrando con filtri [16, 32, 64, 128] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.6548 - accuracy: 0.0434 - val_loss: 3.3640 - val_accuracy: 0.0513
# Epoch 2/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3463 - accuracy: 0.0649 - val_loss: 3.2945 - val_accuracy: 0.1030
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1851 - accuracy: 0.1095 - val_loss: 2.9213 - val_accuracy: 0.1944
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.7898 - accuracy: 0.2044 - val_loss: 2.5015 - val_accuracy: 0.2820
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.3917 - accuracy: 0.3098 - val_loss: 2.1543 - val_accuracy: 0.3816
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.0893 - accuracy: 0.3857 - val_loss: 1.7981 - val_accuracy: 0.5054
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.7887 - accuracy: 0.4749 - val_loss: 1.5048 - val_accuracy: 0.5930
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.5378 - accuracy: 0.5518 - val_loss: 1.3017 - val_accuracy: 0.6343
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.3205 - accuracy: 0.6117 - val_loss: 1.1275 - val_accuracy: 0.6948
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.1388 - accuracy: 0.6630 - val_loss: 0.9780 - val_accuracy: 0.7269
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.0053 - accuracy: 0.6974 - val_loss: 0.9173 - val_accuracy: 0.7427
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8947 - accuracy: 0.7253 - val_loss: 0.8264 - val_accuracy: 0.7674
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7978 - accuracy: 0.7581 - val_loss: 0.7920 - val_accuracy: 0.7701
# Epoch 14/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7265 - accuracy: 0.7826 - val_loss: 0.7157 - val_accuracy: 0.7967
# Epoch 15/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.6589 - accuracy: 0.7972 - val_loss: 0.7174 - val_accuracy: 0.7905
# Epoch 16/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.5922 - accuracy: 0.8189 - val_loss: 0.6494 - val_accuracy: 0.8102
# Epoch 17/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.5351 - accuracy: 0.8345 - val_loss: 0.6342 - val_accuracy: 0.8140
# Epoch 18/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.5016 - accuracy: 0.8454 - val_loss: 0.5985 - val_accuracy: 0.8225
# Epoch 19/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4638 - accuracy: 0.8570 - val_loss: 0.5820 - val_accuracy: 0.8318
# Epoch 20/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.4238 - accuracy: 0.8673 - val_loss: 0.5719 - val_accuracy: 0.8329
# Epoch 21/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.3939 - accuracy: 0.8780 - val_loss: 0.5477 - val_accuracy: 0.8345
# Epoch 22/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.3639 - accuracy: 0.8853 - val_loss: 0.5451 - val_accuracy: 0.8399
# Epoch 23/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.3294 - accuracy: 0.8996 - val_loss: 0.5436 - val_accuracy: 0.8395
# Epoch 24/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.3083 - accuracy: 0.9040 - val_loss: 0.4916 - val_accuracy: 0.8569
# Epoch 25/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.2918 - accuracy: 0.9106 - val_loss: 0.4955 - val_accuracy: 0.8573
# Epoch 26/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.2656 - accuracy: 0.9151 - val_loss: 0.4974 - val_accuracy: 0.8565
# Epoch 27/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.2609 - accuracy: 0.9180 - val_loss: 0.5030 - val_accuracy: 0.8619
# Epoch 28/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.2251 - accuracy: 0.9276 - val_loss: 0.4989 - val_accuracy: 0.8623
# Epoch 29/30
# 243/243 [==============================] - 1s 3ms/step - loss: 0.2284 - accuracy: 0.9271 - val_loss: 0.5058 - val_accuracy: 0.8619
#
# Addestrando con filtri [16, 32, 64, 128] e tasso di apprendimento 1e-05
# Epoch 1/30
# 243/243 [==============================] - 1s 4ms/step - loss: 11.7955 - accuracy: 0.0366 - val_loss: 3.7112 - val_accuracy: 0.0316
# Epoch 2/30
# 243/243 [==============================] - 1s 3ms/step - loss: 4.4500 - accuracy: 0.0356 - val_loss: 3.4550 - val_accuracy: 0.0386
# Epoch 3/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.6256 - accuracy: 0.0369 - val_loss: 3.3975 - val_accuracy: 0.0463
# Epoch 4/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.4562 - accuracy: 0.0486 - val_loss: 3.3802 - val_accuracy: 0.0613
# Epoch 5/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.4106 - accuracy: 0.0504 - val_loss: 3.3686 - val_accuracy: 0.0625
# Epoch 6/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.3881 - accuracy: 0.0508 - val_loss: 3.3600 - val_accuracy: 0.0714
# Epoch 7/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.3754 - accuracy: 0.0610 - val_loss: 3.3543 - val_accuracy: 0.0752
# Epoch 8/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.3658 - accuracy: 0.0585 - val_loss: 3.3467 - val_accuracy: 0.0791
# Epoch 9/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.3536 - accuracy: 0.0607 - val_loss: 3.3379 - val_accuracy: 0.0748
# Epoch 10/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.3475 - accuracy: 0.0741 - val_loss: 3.3261 - val_accuracy: 0.0887
# Epoch 11/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.3423 - accuracy: 0.0705 - val_loss: 3.3193 - val_accuracy: 0.0910
# Epoch 12/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.3288 - accuracy: 0.0754 - val_loss: 3.3063 - val_accuracy: 0.0880
# Epoch 13/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.3216 - accuracy: 0.0768 - val_loss: 3.3018 - val_accuracy: 0.0949
# Epoch 14/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.3090 - accuracy: 0.0782 - val_loss: 3.2887 - val_accuracy: 0.0957
# Epoch 15/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.3017 - accuracy: 0.0825 - val_loss: 3.2715 - val_accuracy: 0.1034
# Epoch 16/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.2810 - accuracy: 0.0890 - val_loss: 3.2587 - val_accuracy: 0.1007
# Epoch 17/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.2809 - accuracy: 0.0869 - val_loss: 3.2456 - val_accuracy: 0.1127
# Epoch 18/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.2566 - accuracy: 0.0885 - val_loss: 3.2250 - val_accuracy: 0.1227
# Epoch 19/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.2378 - accuracy: 0.1000 - val_loss: 3.2001 - val_accuracy: 0.1304
# Epoch 20/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.2214 - accuracy: 0.1054 - val_loss: 3.1839 - val_accuracy: 0.1265
# Epoch 21/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.2100 - accuracy: 0.1017 - val_loss: 3.1618 - val_accuracy: 0.1427
# Epoch 22/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.1841 - accuracy: 0.1183 - val_loss: 3.1382 - val_accuracy: 0.1431
# Epoch 23/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.1652 - accuracy: 0.1227 - val_loss: 3.1090 - val_accuracy: 0.1562
# Epoch 24/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.1447 - accuracy: 0.1191 - val_loss: 3.0842 - val_accuracy: 0.1659
# Epoch 25/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.1179 - accuracy: 0.1282 - val_loss: 3.0554 - val_accuracy: 0.1728
# Epoch 26/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.0991 - accuracy: 0.1378 - val_loss: 3.0253 - val_accuracy: 0.1941
# Epoch 27/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.0636 - accuracy: 0.1457 - val_loss: 2.9860 - val_accuracy: 0.2022
# Epoch 28/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.0361 - accuracy: 0.1552 - val_loss: 2.9528 - val_accuracy: 0.2014
# Epoch 29/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.0048 - accuracy: 0.1546 - val_loss: 2.9234 - val_accuracy: 0.2207
# Epoch 30/30
# 243/243 [==============================] - 1s 3ms/step - loss: 2.9851 - accuracy: 0.1576 - val_loss: 2.8868 - val_accuracy: 0.2191
#
# Addestrando con filtri [32, 64, 128, 256] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.4900 - accuracy: 0.0603 - val_loss: 2.8958 - val_accuracy: 0.1655
# Epoch 2/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.1914 - accuracy: 0.3470 - val_loss: 1.3082 - val_accuracy: 0.6111
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.1620 - accuracy: 0.6474 - val_loss: 0.8108 - val_accuracy: 0.7566
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7347 - accuracy: 0.7805 - val_loss: 0.6078 - val_accuracy: 0.8183
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5369 - accuracy: 0.8354 - val_loss: 0.6137 - val_accuracy: 0.8302
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4612 - accuracy: 0.8568 - val_loss: 0.5795 - val_accuracy: 0.8345
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3688 - accuracy: 0.8856 - val_loss: 0.5533 - val_accuracy: 0.8445
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3365 - accuracy: 0.8919 - val_loss: 0.5199 - val_accuracy: 0.8615
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2644 - accuracy: 0.9144 - val_loss: 0.5401 - val_accuracy: 0.8642
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2487 - accuracy: 0.9215 - val_loss: 0.5794 - val_accuracy: 0.8596
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2568 - accuracy: 0.9213 - val_loss: 0.5885 - val_accuracy: 0.8461
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2046 - accuracy: 0.9365 - val_loss: 0.4778 - val_accuracy: 0.8823
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1872 - accuracy: 0.9418 - val_loss: 0.6089 - val_accuracy: 0.8611
# Epoch 14/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1754 - accuracy: 0.9456 - val_loss: 0.5757 - val_accuracy: 0.8592
# Epoch 15/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1926 - accuracy: 0.9432 - val_loss: 0.6317 - val_accuracy: 0.8607
# Epoch 16/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1629 - accuracy: 0.9490 - val_loss: 0.6010 - val_accuracy: 0.8796
# Epoch 17/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1649 - accuracy: 0.9503 - val_loss: 0.6006 - val_accuracy: 0.8507
#
# Addestrando con filtri [32, 64, 128, 256] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 1s 5ms/step - loss: 3.5376 - accuracy: 0.0455 - val_loss: 3.3398 - val_accuracy: 0.0583
# Epoch 2/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1559 - accuracy: 0.1093 - val_loss: 2.6958 - val_accuracy: 0.2265
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.4842 - accuracy: 0.2780 - val_loss: 2.0277 - val_accuracy: 0.4363
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.9096 - accuracy: 0.4344 - val_loss: 1.6067 - val_accuracy: 0.5556
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.4368 - accuracy: 0.5813 - val_loss: 1.1824 - val_accuracy: 0.6771
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.0690 - accuracy: 0.6853 - val_loss: 0.9201 - val_accuracy: 0.7419
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8370 - accuracy: 0.7490 - val_loss: 0.7525 - val_accuracy: 0.7905
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6768 - accuracy: 0.7970 - val_loss: 0.6679 - val_accuracy: 0.8106
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5593 - accuracy: 0.8303 - val_loss: 0.6214 - val_accuracy: 0.8225
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4724 - accuracy: 0.8555 - val_loss: 0.6077 - val_accuracy: 0.8279
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3963 - accuracy: 0.8760 - val_loss: 0.5555 - val_accuracy: 0.8407
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3416 - accuracy: 0.8933 - val_loss: 0.5256 - val_accuracy: 0.8414
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3010 - accuracy: 0.9080 - val_loss: 0.5094 - val_accuracy: 0.8507
# Epoch 14/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2507 - accuracy: 0.9204 - val_loss: 0.5595 - val_accuracy: 0.8457
# Epoch 15/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2318 - accuracy: 0.9293 - val_loss: 0.5013 - val_accuracy: 0.8584
# Epoch 16/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2031 - accuracy: 0.9353 - val_loss: 0.5548 - val_accuracy: 0.8492
# Epoch 17/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1787 - accuracy: 0.9442 - val_loss: 0.5165 - val_accuracy: 0.8607
# Epoch 18/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1539 - accuracy: 0.9512 - val_loss: 0.5083 - val_accuracy: 0.8588
# Epoch 19/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1395 - accuracy: 0.9562 - val_loss: 0.5225 - val_accuracy: 0.8684
# Epoch 20/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1269 - accuracy: 0.9602 - val_loss: 0.5025 - val_accuracy: 0.8661
#
# Addestrando con filtri [32, 64, 128, 256] e tasso di apprendimento 1e-05
# Epoch 1/30
# 243/243 [==============================] - 1s 4ms/step - loss: 4.6889 - accuracy: 0.0365 - val_loss: 3.3962 - val_accuracy: 0.0432
# Epoch 2/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.4867 - accuracy: 0.0457 - val_loss: 3.3430 - val_accuracy: 0.0652
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3754 - accuracy: 0.0603 - val_loss: 3.3111 - val_accuracy: 0.0802
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3212 - accuracy: 0.0751 - val_loss: 3.2709 - val_accuracy: 0.1127
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2784 - accuracy: 0.0885 - val_loss: 3.2393 - val_accuracy: 0.1231
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2455 - accuracy: 0.1041 - val_loss: 3.1880 - val_accuracy: 0.1420
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1822 - accuracy: 0.1251 - val_loss: 3.1243 - val_accuracy: 0.1674
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1215 - accuracy: 0.1437 - val_loss: 3.0522 - val_accuracy: 0.1898
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.0486 - accuracy: 0.1496 - val_loss: 2.9662 - val_accuracy: 0.2060
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.9754 - accuracy: 0.1735 - val_loss: 2.8863 - val_accuracy: 0.2269
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.8748 - accuracy: 0.2061 - val_loss: 2.7788 - val_accuracy: 0.2604
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.7889 - accuracy: 0.2195 - val_loss: 2.6672 - val_accuracy: 0.2890
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.6869 - accuracy: 0.2476 - val_loss: 2.5726 - val_accuracy: 0.3225
# Epoch 14/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.6066 - accuracy: 0.2679 - val_loss: 2.4828 - val_accuracy: 0.3368
# Epoch 15/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.5218 - accuracy: 0.2866 - val_loss: 2.3975 - val_accuracy: 0.3715
# Epoch 16/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.4274 - accuracy: 0.3085 - val_loss: 2.3063 - val_accuracy: 0.3927
# Epoch 17/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.3783 - accuracy: 0.3204 - val_loss: 2.2266 - val_accuracy: 0.4140
# Epoch 18/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.2914 - accuracy: 0.3464 - val_loss: 2.1638 - val_accuracy: 0.4390
# Epoch 19/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.2085 - accuracy: 0.3706 - val_loss: 2.0894 - val_accuracy: 0.4599
# Epoch 20/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.1295 - accuracy: 0.3919 - val_loss: 2.0180 - val_accuracy: 0.4788
# Epoch 21/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.0823 - accuracy: 0.4071 - val_loss: 1.9603 - val_accuracy: 0.4834
# Epoch 22/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.0197 - accuracy: 0.4220 - val_loss: 1.9058 - val_accuracy: 0.5031
# Epoch 23/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.9616 - accuracy: 0.4344 - val_loss: 1.8333 - val_accuracy: 0.5285
# Epoch 24/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.9019 - accuracy: 0.4494 - val_loss: 1.7725 - val_accuracy: 0.5394
# Epoch 25/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.8500 - accuracy: 0.4701 - val_loss: 1.7338 - val_accuracy: 0.5544
# Epoch 26/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.8008 - accuracy: 0.4863 - val_loss: 1.6912 - val_accuracy: 0.5625
# Epoch 27/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.7412 - accuracy: 0.5031 - val_loss: 1.6336 - val_accuracy: 0.5783
# Epoch 28/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.6905 - accuracy: 0.5219 - val_loss: 1.5853 - val_accuracy: 0.5910
# Epoch 29/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.6490 - accuracy: 0.5262 - val_loss: 1.5434 - val_accuracy: 0.6069
# Epoch 30/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.6067 - accuracy: 0.5421 - val_loss: 1.4988 - val_accuracy: 0.6169
#
# Addestrando con filtri [64, 128, 256, 512] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.5800 - accuracy: 0.0397 - val_loss: 3.3143 - val_accuracy: 0.0602
# Epoch 2/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.6662 - accuracy: 0.2287 - val_loss: 1.9299 - val_accuracy: 0.4259
# Epoch 3/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.5671 - accuracy: 0.5265 - val_loss: 1.2813 - val_accuracy: 0.6138
# Epoch 4/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.0859 - accuracy: 0.6715 - val_loss: 1.0249 - val_accuracy: 0.6906
# Epoch 5/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.8256 - accuracy: 0.7535 - val_loss: 0.8329 - val_accuracy: 0.7577
# Epoch 6/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.6574 - accuracy: 0.7968 - val_loss: 0.9377 - val_accuracy: 0.7361
# Epoch 7/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.5529 - accuracy: 0.8264 - val_loss: 0.8815 - val_accuracy: 0.7566
# Epoch 8/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.4649 - accuracy: 0.8521 - val_loss: 0.8707 - val_accuracy: 0.7785
# Epoch 9/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.3880 - accuracy: 0.8790 - val_loss: 0.8672 - val_accuracy: 0.7762
# Epoch 10/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.3793 - accuracy: 0.8784 - val_loss: 0.8574 - val_accuracy: 0.7917
#
# Addestrando con filtri [64, 128, 256, 512] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.4745 - accuracy: 0.0505 - val_loss: 3.2298 - val_accuracy: 0.1049
# Epoch 2/30
# 243/243 [==============================] - 2s 6ms/step - loss: 2.6465 - accuracy: 0.2393 - val_loss: 1.9155 - val_accuracy: 0.4576
# Epoch 3/30
# 243/243 [==============================] - 2s 6ms/step - loss: 1.6391 - accuracy: 0.5260 - val_loss: 1.1621 - val_accuracy: 0.6736
# Epoch 4/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.9900 - accuracy: 0.7080 - val_loss: 0.7701 - val_accuracy: 0.7766
# Epoch 5/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.6620 - accuracy: 0.8037 - val_loss: 0.6464 - val_accuracy: 0.8106
# Epoch 6/30
# 243/243 [==============================] - 2s 6ms/step - loss: 0.4966 - accuracy: 0.8501 - val_loss: 0.5762 - val_accuracy: 0.8272
# Epoch 7/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.3667 - accuracy: 0.8851 - val_loss: 0.5595 - val_accuracy: 0.8414
# Epoch 8/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.3069 - accuracy: 0.9066 - val_loss: 0.5252 - val_accuracy: 0.8495
# Epoch 9/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.2437 - accuracy: 0.9209 - val_loss: 0.5077 - val_accuracy: 0.8611
# Epoch 10/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1963 - accuracy: 0.9398 - val_loss: 0.5480 - val_accuracy: 0.8519
# Epoch 11/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1581 - accuracy: 0.9517 - val_loss: 0.4814 - val_accuracy: 0.8735
# Epoch 12/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1339 - accuracy: 0.9599 - val_loss: 0.4908 - val_accuracy: 0.8684
# Epoch 13/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1078 - accuracy: 0.9688 - val_loss: 0.4660 - val_accuracy: 0.8816
# Epoch 14/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.1061 - accuracy: 0.9671 - val_loss: 0.5052 - val_accuracy: 0.8781
# Epoch 15/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0890 - accuracy: 0.9735 - val_loss: 0.4984 - val_accuracy: 0.8835
# Epoch 16/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0800 - accuracy: 0.9763 - val_loss: 0.5152 - val_accuracy: 0.8819
# Epoch 17/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0698 - accuracy: 0.9807 - val_loss: 0.4479 - val_accuracy: 0.8908
# Epoch 18/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0524 - accuracy: 0.9836 - val_loss: 0.5026 - val_accuracy: 0.8846
# Epoch 19/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0608 - accuracy: 0.9823 - val_loss: 0.4654 - val_accuracy: 0.8877
# Epoch 20/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0683 - accuracy: 0.9796 - val_loss: 0.5773 - val_accuracy: 0.8792
# Epoch 21/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0590 - accuracy: 0.9817 - val_loss: 0.5779 - val_accuracy: 0.8746
# Epoch 22/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0573 - accuracy: 0.9829 - val_loss: 0.6027 - val_accuracy: 0.8769
#
# Addestrando con filtri [64, 128, 256, 512] e tasso di apprendimento 1e-05
# Epoch 1/30
# 243/243 [==============================] - 2s 7ms/step - loss: 4.3121 - accuracy: 0.0428 - val_loss: 3.3350 - val_accuracy: 0.0525
# Epoch 2/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.3722 - accuracy: 0.0688 - val_loss: 3.2699 - val_accuracy: 0.0941
# Epoch 3/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.2773 - accuracy: 0.0852 - val_loss: 3.1866 - val_accuracy: 0.1196
# Epoch 4/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.1887 - accuracy: 0.1169 - val_loss: 3.1019 - val_accuracy: 0.1543
# Epoch 5/30
# 243/243 [==============================] - 2s 7ms/step - loss: 3.0860 - accuracy: 0.1497 - val_loss: 2.9581 - val_accuracy: 0.1968
# Epoch 6/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.9445 - accuracy: 0.1784 - val_loss: 2.8020 - val_accuracy: 0.2454
# Epoch 7/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.7908 - accuracy: 0.2289 - val_loss: 2.6224 - val_accuracy: 0.2963
# Epoch 8/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.6188 - accuracy: 0.2740 - val_loss: 2.4661 - val_accuracy: 0.3345
# Epoch 9/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.4582 - accuracy: 0.3063 - val_loss: 2.2776 - val_accuracy: 0.3900
# Epoch 10/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.2995 - accuracy: 0.3552 - val_loss: 2.1335 - val_accuracy: 0.4387
# Epoch 11/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.1535 - accuracy: 0.3884 - val_loss: 1.9820 - val_accuracy: 0.4769
# Epoch 12/30
# 243/243 [==============================] - 2s 7ms/step - loss: 2.0039 - accuracy: 0.4263 - val_loss: 1.8435 - val_accuracy: 0.5231
# Epoch 13/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.8789 - accuracy: 0.4612 - val_loss: 1.7383 - val_accuracy: 0.5428
# Epoch 14/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.7612 - accuracy: 0.5014 - val_loss: 1.6258 - val_accuracy: 0.5795
# Epoch 15/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.6443 - accuracy: 0.5287 - val_loss: 1.5295 - val_accuracy: 0.6011
# Epoch 16/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.5269 - accuracy: 0.5688 - val_loss: 1.4323 - val_accuracy: 0.6231
# Epoch 17/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.4448 - accuracy: 0.5905 - val_loss: 1.3642 - val_accuracy: 0.6412
# Epoch 18/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.3533 - accuracy: 0.6166 - val_loss: 1.2909 - val_accuracy: 0.6582
# Epoch 19/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.2721 - accuracy: 0.6369 - val_loss: 1.2189 - val_accuracy: 0.6759
# Epoch 20/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.1869 - accuracy: 0.6602 - val_loss: 1.1465 - val_accuracy: 0.6952
# Epoch 21/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.1045 - accuracy: 0.6796 - val_loss: 1.0971 - val_accuracy: 0.7049
# Epoch 22/30
# 243/243 [==============================] - 2s 7ms/step - loss: 1.0439 - accuracy: 0.7039 - val_loss: 1.0453 - val_accuracy: 0.7137
# Epoch 23/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.9773 - accuracy: 0.7162 - val_loss: 1.0132 - val_accuracy: 0.7284
# Epoch 24/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.9411 - accuracy: 0.7285 - val_loss: 0.9635 - val_accuracy: 0.7458
# Epoch 25/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.8827 - accuracy: 0.7465 - val_loss: 0.9331 - val_accuracy: 0.7458
# Epoch 26/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.8284 - accuracy: 0.7585 - val_loss: 0.9110 - val_accuracy: 0.7519
# Epoch 27/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.7971 - accuracy: 0.7742 - val_loss: 0.8690 - val_accuracy: 0.7654
# Epoch 28/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.7484 - accuracy: 0.7818 - val_loss: 0.8453 - val_accuracy: 0.7654
# Epoch 29/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.7144 - accuracy: 0.7946 - val_loss: 0.8358 - val_accuracy: 0.7712
# Epoch 30/30
# 243/243 [==============================] - 2s 7ms/step - loss: 0.6783 - accuracy: 0.8048 - val_loss: 0.8106 - val_accuracy: 0.7758
#
# Tempo totale trascorso: 3 minuti e 47 secondi

# %% [markdown]
# Il tempo necessario per la ricerca dei migliori iperparametri è stata di 4 minuti e 32 secondi.
#
# Visualizziamo l'accuratezza e la perdita di tutti i modelli che il tuner ha addestato.

# %%
def plot_models(path, reverse=False, show="accuracy", overfit=True):
    n_models = len(os.listdir(path))
    # creo il subplot a seconda di quanti modelli dispongo
    best_pair = None
    min_diff = float("inf")
    
    for idx_model in range(1, int(np.sqrt(n_models)) + 1):
        if n_models % idx_model == 0:
            diff = abs(idx_model - n_models // idx_model)

            if diff < min_diff:
                min_diff = diff
                best_pair = (idx_model, n_models // idx_model)

    if reverse:
        rows = best_pair[1]
        cols = best_pair[0]
    else:
        rows = best_pair[0]
        cols = best_pair[1]
    
    fig, axes = plt.subplots(rows, cols, figsize=(14, 10))
    
    for index, model in enumerate(os.listdir(path)):
        row = index // cols
        col = index % cols
    
        ax = axes[row][col]
        
        newpath = path + "/" + model
        df = pd.read_csv(newpath)

        value1 = df[show].values
        value2 = df["val_" + show].values
        
        ax.plot(range(1, len(value1) + 1), value1, color="slategray", label="Addestramento")
        ax.plot(range(1, len(value2) + 1), value2, color="indianred", label="Validazione")

        if (row in range(rows)) and col == 0:
            ax.set_ylabel("Accuratezza (%)" if show == "accuracy" else "Perdita", fontweight="semibold", fontsize=10)

        if (col in range(cols)) and row == 2:
            ax.set_xlabel("Epoche", fontweight="semibold", fontsize=10)

        ax.set_title("Filtro " + str(df["filters"][0]) + " & lr " + str(df["learning_rate"][0]), fontsize=12)
            
        ax.set_ylim(0)
        ax.set_xlim(0)

        ax.spines["left"].set_visible(False)
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)

        ax.grid(True, color="gainsboro", alpha=0.3, linestyle="--")

        handles, _ = ax.get_legend_handles_labels()
        
        if overfit and show == "loss":
            # area overfit
            
            rect = mpatches.Rectangle((np.argmin(value2) + 1, 0), width=len(value1) - np.argmin(value2), height=max(max(value1), max(value2)), color='lightcoral', alpha=0.3)
            ax.add_patch(rect)
            # patch overfit per legenda
            overfit = mpatches.Patch(color='lightcoral', alpha=0.3, label='Area overfit')
           
            handles.append(overfit)

        ax.legend(handles=handles)

    plt.subplots_adjust(wspace=0.3, hspace=0.3)
    plt.show()

# %%
plot_models(path="model_tuning/adam/filterbanks", show="accuracy")
plot_models(path="model_tuning/adam/filterbanks", show="loss")

# %% [markdown]
# Dai grafici emerge che la combinazione più performante è composta da **32 filtri di partenza** e un **tasso di apprendimento di 0.0001**, poiché ritarda maggiormente l'overfitting. Altre combinazioni, come **64 filtri di partenza** e un **tasso di apprendimento di 0.0001**, mostrano buone prestazioni ma anche un inizio di overfitting, evidenziato dallo distaccamento tra la perdita di addestramento e quella di validazione.
#
# Procediamo quindi con l'addestramento del modello con **32 filtri di partenza** e un **tasso di apprendimento di 0.0001**. Come di consueto, salviamo i risultati in un file `keras` e la cronologia (history) in un file `csv`. Infine, convertiamo il file in formato `onnx`.

# %% [markdown]
# # DA RIFARE

# %%
for audio, label in fb_train_ds:
    tuned_improved_basic_model = get_improved_basic_model(audio.shape[1:])
    break

tuned_improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5), metrics=["accuracy"])

# %%
tuned_improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/adam/filterbanks/tuned_improved_basic_model_fb.keras", save_best_only=True, monitor="val_loss")]
tuned_improved_history = tuned_improved_basic_model.fit(fb_train_ds, epochs=100, validation_data=fb_val_ds, callbacks=tuned_improved_basic_model_callbacks)

# %%
tuned_improved_history_df = convert_history_to_csv(tuned_improved_history)
tuned_improved_history_df.to_csv("model_histories/adam/filterbanks/tuned_improved_history_fb.csv")

convert_model_to_onnx("bestmodels/adam/filterbanks/tuned_improved_basic_model_fb.keras", (98, 40, 1))

# %%
create_train_val_plot(tuned_improved_history.history)

# %% [markdown]
# In questo caso il modello non è ancora andato in overfitting, perciò magari avremmo potuto addestrarlo per qualche epoca in più. L'accuratezza in addestramento e validazione sono basse rispetto ai modelli precedenti, dovuto molto probabilmente dalla quantità limitata di epoche.

# %%
tuned_improved_best_model = tf.keras.models.load_model("bestmodels/adam/filterbanks/tuned_improved_basic_model_fb.keras")
test_loss, test_acc = tuned_improved_best_model.evaluate(fb_test_ds)
print(f"Accuratezza: {test_acc:.3f}")

# %%
evaluate_onnx_model("bestmodels/adam/filterbanks/tuned_improved_basic_model_fb.onnx", fb_test_ds)

# %% [markdown]
# Come ci aspettavamo dall'andamento dell'accuratezza, il modello ha registrato delle prestazioni inferiori rispetto a prima ma senza andare in overfitting. L'accuratezza corrisponde a **80.7%**.

# %%
for audio, label in fb_test_ds:
    create_distribution_plot(tuned_improved_best_model, audio, label)
    break

# %% [markdown]
# Un fattore molto positivo riguarda la distinzione corretta di parole molto simili, come in questo caso **three** e **tree**.

# %% [markdown]
# ### Miglioramenti all'architettura del modello convolutivo
# In questa ultima fase riguardante i filterbanks andremo ad addestrare il modello corrispondente alla sezione **miglioramenti all'architettura del modello** del notebook di riferimento.

# %% [markdown]
# Si procede con la creazione dell'architettura composta da blocchi residuali, il suo addestramento e la dimostrazione grafica dell'andamento.

# %%
def residual_block(x, filters, pooling=False):
    residual = x

    x = tf.keras.layers.SeparableConv2D(filters, 3, padding="same", use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    if pooling:
      x = tf.keras.layers.MaxPooling2D(pool_size=2, padding="same")(x)
      residual = tf.keras.layers.Conv2D(filters, 1, strides=2)(residual)
    elif filters != residual.shape[-1]:
      residual = tf.keras.layers.Conv2D(filters, 1)(residual)

    x = tf.keras.layers.add([x, residual])
    return x

def bp_basic_model(input_shape):
    # input e pre processamento
    inputs = tf.keras.Input(shape=input_shape)
    
    x = residual_block(inputs, 32, pooling=True)
    x = residual_block(x, 64, pooling=True)
    x = residual_block(x, 128, pooling=True)
    x = residual_block(x, 256, pooling=True)
    x = residual_block(x, 256, pooling=False)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Livelli per la classificazione
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
for audio, label in fb_train_ds:
    bp_basic_model = bp_basic_model(audio.shape[1:])
    break

bp_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

bp_basic_model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_12 (InputLayer)          [(None, 98, 40, 1)]  0           []
#
#  separable_conv2d (SeparableCon  (None, 98, 40, 32)  41          ['input_12[0][0]']
#  v2D)
#
#  batch_normalization (BatchNorm  (None, 98, 40, 32)  128         ['separable_conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 98, 40, 32)   0           ['batch_normalization[0][0]']
#
#  max_pooling2d_44 (MaxPooling2D  (None, 49, 20, 32)  0           ['activation[0][0]']
#  )
#
#  conv2d_55 (Conv2D)             (None, 49, 20, 32)   64          ['input_12[0][0]']
#
#  add (Add)                      (None, 49, 20, 32)   0           ['max_pooling2d_44[0][0]',
#                                                                   'conv2d_55[0][0]']
#
#  separable_conv2d_1 (SeparableC  (None, 49, 20, 64)  2336        ['add[0][0]']
#  onv2D)
#
#  batch_normalization_1 (BatchNo  (None, 49, 20, 64)  256         ['separable_conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 49, 20, 64)   0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d_45 (MaxPooling2D  (None, 25, 10, 64)  0           ['activation_1[0][0]']
#  )
#
#  conv2d_56 (Conv2D)             (None, 25, 10, 64)   2112        ['add[0][0]']
#
#  add_1 (Add)                    (None, 25, 10, 64)   0           ['max_pooling2d_45[0][0]',
#                                                                   'conv2d_56[0][0]']
#
#  separable_conv2d_2 (SeparableC  (None, 25, 10, 128)  8768       ['add_1[0][0]']
#  onv2D)
#
#  batch_normalization_2 (BatchNo  (None, 25, 10, 128)  512        ['separable_conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 25, 10, 128)  0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_46 (MaxPooling2D  (None, 13, 5, 128)  0           ['activation_2[0][0]']
#  )
#
#  conv2d_57 (Conv2D)             (None, 13, 5, 128)   8320        ['add_1[0][0]']
#
#  add_2 (Add)                    (None, 13, 5, 128)   0           ['max_pooling2d_46[0][0]',
#                                                                   'conv2d_57[0][0]']
#
#  separable_conv2d_3 (SeparableC  (None, 13, 5, 256)  33920       ['add_2[0][0]']
#  onv2D)
#
#  batch_normalization_3 (BatchNo  (None, 13, 5, 256)  1024        ['separable_conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 13, 5, 256)   0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_47 (MaxPooling2D  (None, 7, 3, 256)   0           ['activation_3[0][0]']
#  )
#
#  conv2d_58 (Conv2D)             (None, 7, 3, 256)    33024       ['add_2[0][0]']
#
#  add_3 (Add)                    (None, 7, 3, 256)    0           ['max_pooling2d_47[0][0]',
#                                                                   'conv2d_58[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 7, 3, 256)   67840       ['add_3[0][0]']
#  onv2D)
#
#  batch_normalization_4 (BatchNo  (None, 7, 3, 256)   1024        ['separable_conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 7, 3, 256)    0           ['batch_normalization_4[0][0]']
#
#  add_4 (Add)                    (None, 7, 3, 256)    0           ['activation_4[0][0]',
#                                                                   'add_3[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['add_4[0][0]']
#  alAveragePooling2D)
#
#  dropout_11 (Dropout)           (None, 256)          0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_11 (Dense)               (None, 30)           7710        ['dropout_11[0][0]']
#
# ==================================================================================================
# Total params: 167,079
# Trainable params: 165,607
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %% [markdown]
# Il numero di parametri in questo caso non è cambiato rispetto al notebook di riferimento.

# %%
bp_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/adam/filterbanks/bp_basic_model_fb.keras", save_best_only=True, monitor="val_loss")]
bp_model_history = bp_basic_model.fit(fb_train_ds, epochs=100, validation_data=fb_val_ds, callbacks=bp_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 2s 7ms/step - loss: 6.1164 - accuracy: 0.0485 - val_loss: 3.7170 - val_accuracy: 0.0721
# Epoch 2/100
# 243/243 [==============================] - 2s 7ms/step - loss: 3.1992 - accuracy: 0.1370 - val_loss: 3.2251 - val_accuracy: 0.1728
# Epoch 3/100
# 243/243 [==============================] - 2s 6ms/step - loss: 2.4655 - accuracy: 0.2910 - val_loss: 4.3767 - val_accuracy: 0.1262
# Epoch 4/100
# 243/243 [==============================] - 2s 6ms/step - loss: 1.8704 - accuracy: 0.4588 - val_loss: 2.6420 - val_accuracy: 0.3268
# Epoch 5/100
# 243/243 [==============================] - 2s 6ms/step - loss: 1.4261 - accuracy: 0.5919 - val_loss: 2.4731 - val_accuracy: 0.3939
# Epoch 6/100
# 243/243 [==============================] - 2s 6ms/step - loss: 1.1164 - accuracy: 0.6869 - val_loss: 1.6946 - val_accuracy: 0.4850
# Epoch 7/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.9251 - accuracy: 0.7357 - val_loss: 1.4567 - val_accuracy: 0.5745
# Epoch 8/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.7692 - accuracy: 0.7839 - val_loss: 1.9190 - val_accuracy: 0.5216
# Epoch 9/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.6777 - accuracy: 0.8057 - val_loss: 1.6033 - val_accuracy: 0.5544
# Epoch 10/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.6015 - accuracy: 0.8298 - val_loss: 0.9773 - val_accuracy: 0.7052
# Epoch 11/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.5329 - accuracy: 0.8469 - val_loss: 1.0419 - val_accuracy: 0.7064
# Epoch 12/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.4968 - accuracy: 0.8630 - val_loss: 0.9908 - val_accuracy: 0.6944
# Epoch 13/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.4547 - accuracy: 0.8697 - val_loss: 1.6595 - val_accuracy: 0.5772
# Epoch 14/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.3817 - accuracy: 0.8918 - val_loss: 1.4567 - val_accuracy: 0.5922
# Epoch 15/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.3885 - accuracy: 0.8890 - val_loss: 1.3094 - val_accuracy: 0.6424
# Epoch 16/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.3421 - accuracy: 0.9032 - val_loss: 0.7303 - val_accuracy: 0.7928
# Epoch 17/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.2980 - accuracy: 0.9151 - val_loss: 0.7627 - val_accuracy: 0.7975
# Epoch 18/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.2943 - accuracy: 0.9165 - val_loss: 0.8251 - val_accuracy: 0.7681
# Epoch 19/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.2905 - accuracy: 0.9138 - val_loss: 0.8265 - val_accuracy: 0.7758
# Epoch 20/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.2383 - accuracy: 0.9302 - val_loss: 1.1101 - val_accuracy: 0.7326
# Epoch 21/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.2365 - accuracy: 0.9293 - val_loss: 1.3451 - val_accuracy: 0.6771
# Epoch 22/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.2144 - accuracy: 0.9372 - val_loss: 0.6991 - val_accuracy: 0.8187
# Epoch 23/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.1995 - accuracy: 0.9447 - val_loss: 1.1926 - val_accuracy: 0.7002
# Epoch 24/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.1992 - accuracy: 0.9406 - val_loss: 0.7113 - val_accuracy: 0.8140
# Epoch 25/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.1768 - accuracy: 0.9473 - val_loss: 2.4830 - val_accuracy: 0.5401
# Epoch 26/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1611 - accuracy: 0.9535 - val_loss: 1.9203 - val_accuracy: 0.6019
# Epoch 27/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1762 - accuracy: 0.9497 - val_loss: 1.1842 - val_accuracy: 0.7083
# Epoch 28/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1623 - accuracy: 0.9503 - val_loss: 5.1434 - val_accuracy: 0.4070
# Epoch 29/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1591 - accuracy: 0.9559 - val_loss: 2.0585 - val_accuracy: 0.6227
# Epoch 30/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1678 - accuracy: 0.9519 - val_loss: 1.1304 - val_accuracy: 0.7164
# Epoch 31/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1243 - accuracy: 0.9649 - val_loss: 2.0346 - val_accuracy: 0.6319
# Epoch 32/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1407 - accuracy: 0.9586 - val_loss: 2.4398 - val_accuracy: 0.6223
# Epoch 33/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1160 - accuracy: 0.9660 - val_loss: 1.5771 - val_accuracy: 0.6686
# Epoch 34/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1320 - accuracy: 0.9601 - val_loss: 3.7022 - val_accuracy: 0.4996
# Epoch 35/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.1127 - accuracy: 0.9689 - val_loss: 0.6678 - val_accuracy: 0.8318
# Epoch 36/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0990 - accuracy: 0.9719 - val_loss: 1.9858 - val_accuracy: 0.6443
# Epoch 37/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1236 - accuracy: 0.9617 - val_loss: 5.3622 - val_accuracy: 0.3954
# Epoch 38/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.1174 - accuracy: 0.9647 - val_loss: 2.2653 - val_accuracy: 0.6100
# Epoch 39/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0918 - accuracy: 0.9726 - val_loss: 1.5420 - val_accuracy: 0.6979
# Epoch 40/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.1038 - accuracy: 0.9715 - val_loss: 0.7460 - val_accuracy: 0.8322
# Epoch 41/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0931 - accuracy: 0.9722 - val_loss: 1.2298 - val_accuracy: 0.7407
# Epoch 42/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0855 - accuracy: 0.9768 - val_loss: 1.2816 - val_accuracy: 0.7566
# Epoch 43/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0812 - accuracy: 0.9741 - val_loss: 1.7066 - val_accuracy: 0.7195
# Epoch 44/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0890 - accuracy: 0.9727 - val_loss: 1.7366 - val_accuracy: 0.6736
# Epoch 45/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0835 - accuracy: 0.9751 - val_loss: 0.8381 - val_accuracy: 0.8214
# Epoch 46/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0905 - accuracy: 0.9720 - val_loss: 1.8402 - val_accuracy: 0.6562
# Epoch 47/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0728 - accuracy: 0.9795 - val_loss: 1.9563 - val_accuracy: 0.6871
# Epoch 48/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0781 - accuracy: 0.9772 - val_loss: 1.0687 - val_accuracy: 0.7840
# Epoch 49/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0645 - accuracy: 0.9818 - val_loss: 1.2224 - val_accuracy: 0.7616
# Epoch 50/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0720 - accuracy: 0.9780 - val_loss: 1.7260 - val_accuracy: 0.7022
# Epoch 51/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0801 - accuracy: 0.9744 - val_loss: 1.6422 - val_accuracy: 0.7508
# Epoch 52/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0743 - accuracy: 0.9762 - val_loss: 0.9826 - val_accuracy: 0.8144
# Epoch 53/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0483 - accuracy: 0.9862 - val_loss: 1.3085 - val_accuracy: 0.7724
# Epoch 54/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0535 - accuracy: 0.9844 - val_loss: 1.8743 - val_accuracy: 0.6971
# Epoch 55/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0601 - accuracy: 0.9818 - val_loss: 0.9874 - val_accuracy: 0.8137
# Epoch 56/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0607 - accuracy: 0.9808 - val_loss: 1.3507 - val_accuracy: 0.7608
# Epoch 57/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0515 - accuracy: 0.9852 - val_loss: 0.9173 - val_accuracy: 0.8245
# Epoch 58/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0707 - accuracy: 0.9774 - val_loss: 1.0280 - val_accuracy: 0.8040
# Epoch 59/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0736 - accuracy: 0.9776 - val_loss: 2.4543 - val_accuracy: 0.6412
# Epoch 60/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0586 - accuracy: 0.9818 - val_loss: 0.9422 - val_accuracy: 0.8214
# Epoch 61/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0439 - accuracy: 0.9876 - val_loss: 0.6328 - val_accuracy: 0.8596
# Epoch 62/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0521 - accuracy: 0.9841 - val_loss: 0.8656 - val_accuracy: 0.8268
# Epoch 63/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0495 - accuracy: 0.9845 - val_loss: 1.9844 - val_accuracy: 0.6705
# Epoch 64/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0558 - accuracy: 0.9830 - val_loss: 0.8127 - val_accuracy: 0.8356
# Epoch 65/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0537 - accuracy: 0.9831 - val_loss: 1.6803 - val_accuracy: 0.7338
# Epoch 66/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0572 - accuracy: 0.9825 - val_loss: 1.0413 - val_accuracy: 0.8129
# Epoch 67/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0723 - accuracy: 0.9777 - val_loss: 0.8328 - val_accuracy: 0.8310
# Epoch 68/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0638 - accuracy: 0.9794 - val_loss: 1.5665 - val_accuracy: 0.7461
# Epoch 69/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0400 - accuracy: 0.9898 - val_loss: 0.6499 - val_accuracy: 0.8615
# Epoch 70/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0401 - accuracy: 0.9881 - val_loss: 1.8222 - val_accuracy: 0.7284
# Epoch 71/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0358 - accuracy: 0.9892 - val_loss: 1.0229 - val_accuracy: 0.8121
# Epoch 72/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0500 - accuracy: 0.9851 - val_loss: 0.7780 - val_accuracy: 0.8438
# Epoch 73/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0352 - accuracy: 0.9897 - val_loss: 0.7445 - val_accuracy: 0.8588
# Epoch 74/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0482 - accuracy: 0.9844 - val_loss: 1.0968 - val_accuracy: 0.7917
# Epoch 75/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0371 - accuracy: 0.9885 - val_loss: 1.3508 - val_accuracy: 0.7843
# Epoch 76/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0394 - accuracy: 0.9890 - val_loss: 1.3697 - val_accuracy: 0.7701
# Epoch 77/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0618 - accuracy: 0.9803 - val_loss: 0.8976 - val_accuracy: 0.8137
# Epoch 78/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0625 - accuracy: 0.9826 - val_loss: 0.7513 - val_accuracy: 0.8576
# Epoch 79/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0224 - accuracy: 0.9945 - val_loss: 0.4709 - val_accuracy: 0.8966
# Epoch 80/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0274 - accuracy: 0.9905 - val_loss: 1.3355 - val_accuracy: 0.8009
# Epoch 81/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0336 - accuracy: 0.9898 - val_loss: 0.8625 - val_accuracy: 0.8283
# Epoch 82/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0674 - accuracy: 0.9790 - val_loss: 1.2537 - val_accuracy: 0.7847
# Epoch 83/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0559 - accuracy: 0.9817 - val_loss: 1.4247 - val_accuracy: 0.7878
# Epoch 84/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0481 - accuracy: 0.9839 - val_loss: 0.8018 - val_accuracy: 0.8453
# Epoch 85/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0419 - accuracy: 0.9860 - val_loss: 2.5859 - val_accuracy: 0.6586
# Epoch 86/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0529 - accuracy: 0.9845 - val_loss: 0.8902 - val_accuracy: 0.8465
# Epoch 87/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0243 - accuracy: 0.9934 - val_loss: 0.9098 - val_accuracy: 0.8372
# Epoch 88/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0254 - accuracy: 0.9912 - val_loss: 0.8561 - val_accuracy: 0.8449
# Epoch 89/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0230 - accuracy: 0.9923 - val_loss: 1.2566 - val_accuracy: 0.7774
# Epoch 90/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0503 - accuracy: 0.9836 - val_loss: 1.7727 - val_accuracy: 0.7539
# Epoch 91/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0490 - accuracy: 0.9840 - val_loss: 0.7867 - val_accuracy: 0.8441
# Epoch 92/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0330 - accuracy: 0.9889 - val_loss: 0.7848 - val_accuracy: 0.8522
# Epoch 93/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0298 - accuracy: 0.9902 - val_loss: 3.4632 - val_accuracy: 0.5880
# Epoch 94/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0427 - accuracy: 0.9858 - val_loss: 1.1020 - val_accuracy: 0.8260
# Epoch 95/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0383 - accuracy: 0.9896 - val_loss: 0.9770 - val_accuracy: 0.8360
# Epoch 96/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0251 - accuracy: 0.9924 - val_loss: 0.6282 - val_accuracy: 0.8731
# Epoch 97/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.0170 - accuracy: 0.9946 - val_loss: 1.7929 - val_accuracy: 0.7384
# Epoch 98/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0317 - accuracy: 0.9899 - val_loss: 1.2124 - val_accuracy: 0.8025
# Epoch 99/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0542 - accuracy: 0.9831 - val_loss: 1.5923 - val_accuracy: 0.7677
# Epoch 100/100
# 243/243 [==============================] - 2s 7ms/step - loss: 0.0375 - accuracy: 0.9876 - val_loss: 0.9501 - val_accuracy: 0.8372

# %%
bp_model_history_df = convert_history_to_csv(bp_model_history)
bp_model_history_df.to_csv("model_histories/adam/filterbanks/bp_model_history_fb.csv")

convert_model_to_onnx("bestmodels/adam/filterbanks/bp_basic_model_fb.keras", (98, 40, 1))

# %%
create_train_val_plot(bp_model_history.history, overfit=False)

# %% [markdown]
# In questo caso il modello ha perfomato peggio rispetto al corrispettivo. Il valore minimo di loss è maggiore, mentre il valore massimo di accuratezza è inferiore.

# %%
best_bp_basic_model = tf.keras.models.load_model("bestmodels/adam/filterbanks/bp_basic_model_fb.keras")
test_loss, test_acc = best_bp_basic_model.evaluate(fb_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 3ms/step - loss: 0.5312 - accuracy: 0.8811
# Accuratezza: 0.881

# %%
evaluate_onnx_model("bestmodels/adam/filterbanks/bp_basic_model_fb.onnx", fb_test_ds)
# Out:
# Accuratezza: 0.881

# %% [markdown]
# L'accuratezza è diminuita, siamo a quota **87.1%**.

# %%
for audio, label in fb_test_ds:
    create_distribution_plot(best_bp_basic_model, audio, label)
    break

# %% [markdown]
# ## Addestramento modello convolutivo base (mfcc)
# L'ultimo argomento che trattiamo nel notebook riguarda l'uso degli mfcc come dati in input ai modelli.

# %% [markdown]
# Procediamo nello stesso modo fatto sopra, quindi trasformiamo i dati con la nostra classe e otteniamo i set di train, validation e test.

# %%
mfcc_train_ds = DatasetConverter(train_ds)
mfcc_train_ds = mfcc_train_ds.convert('mfcc')

mfcc_validation_ds = DatasetConverter(validation_ds)
mfcc_validation_ds = mfcc_validation_ds.convert('mfcc')

mfcc_val_ds = mfcc_validation_ds.take(mfcc_validation_ds.cardinality() // 2)
mfcc_test_ds = mfcc_validation_ds.skip(mfcc_validation_ds.cardinality() // 2)

# %% [markdown]
# Considerata la grandezza ridotta della matrice degli mfcc, dobbiamo apportare una leggera modifica al modello convolutivo di base, applicando il **padding** nel livello `MaxPooling2D_4`.

# %%
def get_basic_model(input_shape):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=input_shape, name="inputs")
    x = tf.keras.layers.Normalization(name="normalizzazione")(inputs)

    # Blocco di apprendimento delle caratteristiche
    conv2D_1 = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same", name="conv2D_1")(x)
    MaxPooling2D_1 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_1")(conv2D_1)
    conv2D_2 = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same", name="conv2D_2")(MaxPooling2D_1)
    MaxPooling2D_2 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_2")(conv2D_2)
    conv2D_3 = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same", name="conv2D_3")(MaxPooling2D_2)
    MaxPooling2D_3 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_3")(conv2D_3)
    conv2D_4 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_4")(MaxPooling2D_3)
    MaxPooling2D_4 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_4", padding="same")(conv2D_4)
    conv2D_5 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_5")(MaxPooling2D_4)

    # Blocco di classificazione
    Flatten = tf.keras.layers.Flatten(name="Flatten")(conv2D_5)
    outputs = tf.keras.layers.Dense(30, activation="softmax", name="dense_output")(Flatten)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
for audio, label in mfcc_train_ds:
    basic_model = get_basic_model(audio.shape[1:])
    break
    
basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

basic_model.summary()
# Out:
# Model: "model_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inputs (InputLayer)         [(None, 98, 12, 1)]       0
#
#  normalizzazione (Normalizat  (None, 98, 12, 1)        3
#  ion)
#
#  conv2D_1 (Conv2D)           (None, 98, 12, 32)        320
#
#  MaxPooling2D_1 (MaxPooling2  (None, 49, 6, 32)        0
#  D)
#
#  conv2D_2 (Conv2D)           (None, 49, 6, 64)         18496
#
#  MaxPooling2D_2 (MaxPooling2  (None, 24, 3, 64)        0
#  D)
#
#  conv2D_3 (Conv2D)           (None, 24, 3, 128)        73856
#
#  MaxPooling2D_3 (MaxPooling2  (None, 12, 1, 128)       0
#  D)
#
#  conv2D_4 (Conv2D)           (None, 12, 1, 256)        295168
#
#  MaxPooling2D_4 (MaxPooling2  (None, 6, 1, 256)        0
#  D)
#
#  conv2D_5 (Conv2D)           (None, 6, 1, 256)         590080
#
#  Flatten (Flatten)           (None, 1536)              0
#
#  dense_output (Dense)        (None, 30)                46110
#
# =================================================================
# Total params: 1,024,033
# Trainable params: 1,024,030
# Non-trainable params: 3
# _________________________________________________________________

# %% [markdown]
# Anche in questo caso notiamo una **diminuzione dei parametri di circa 50.000**, dovuto alla differenza di grandezza della matrice.

# %%
basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/adam/mfcc/basic_model_mfcc.keras", save_best_only=True, monitor="val_loss")]
basic_model_history = basic_model.fit(mfcc_train_ds, epochs=30, batch_size=32, validation_data=mfcc_val_ds, callbacks=basic_model_callbacks)
# Out:
# Epoch 1/30
# 243/243 [==============================] - 2s 5ms/step - loss: 2.6135 - accuracy: 0.2563 - val_loss: 1.7426 - val_accuracy: 0.4742
# Epoch 2/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.2529 - accuracy: 0.6271 - val_loss: 1.1297 - val_accuracy: 0.6794
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7710 - accuracy: 0.7584 - val_loss: 0.9880 - val_accuracy: 0.7361
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5638 - accuracy: 0.8260 - val_loss: 0.9281 - val_accuracy: 0.7461
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4174 - accuracy: 0.8657 - val_loss: 0.9654 - val_accuracy: 0.7809
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3547 - accuracy: 0.8847 - val_loss: 1.2372 - val_accuracy: 0.7296
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3039 - accuracy: 0.9019 - val_loss: 0.9813 - val_accuracy: 0.7863
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2504 - accuracy: 0.9202 - val_loss: 1.0177 - val_accuracy: 0.7863
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2286 - accuracy: 0.9300 - val_loss: 1.0822 - val_accuracy: 0.7870
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1886 - accuracy: 0.9405 - val_loss: 1.1798 - val_accuracy: 0.7940
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2019 - accuracy: 0.9407 - val_loss: 1.0996 - val_accuracy: 0.7867
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2216 - accuracy: 0.9343 - val_loss: 1.3095 - val_accuracy: 0.7820
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1819 - accuracy: 0.9476 - val_loss: 1.1929 - val_accuracy: 0.7921
# Epoch 14/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1369 - accuracy: 0.9598 - val_loss: 1.2595 - val_accuracy: 0.7932
# Epoch 15/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1222 - accuracy: 0.9611 - val_loss: 1.2110 - val_accuracy: 0.8094
# Epoch 16/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1549 - accuracy: 0.9584 - val_loss: 1.2400 - val_accuracy: 0.8083
# Epoch 17/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1382 - accuracy: 0.9626 - val_loss: 1.4856 - val_accuracy: 0.7951
# Epoch 18/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1304 - accuracy: 0.9666 - val_loss: 1.4609 - val_accuracy: 0.7932
# Epoch 19/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1765 - accuracy: 0.9521 - val_loss: 1.5693 - val_accuracy: 0.7793
# Epoch 20/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1483 - accuracy: 0.9581 - val_loss: 1.4019 - val_accuracy: 0.8071
# Epoch 21/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1083 - accuracy: 0.9684 - val_loss: 1.5168 - val_accuracy: 0.7901
# Epoch 22/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1609 - accuracy: 0.9579 - val_loss: 1.2471 - val_accuracy: 0.8110
# Epoch 23/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0926 - accuracy: 0.9727 - val_loss: 1.7864 - val_accuracy: 0.8021
# Epoch 24/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1204 - accuracy: 0.9714 - val_loss: 1.4660 - val_accuracy: 0.8202
# Epoch 25/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1740 - accuracy: 0.9563 - val_loss: 2.2956 - val_accuracy: 0.7731
# Epoch 26/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2302 - accuracy: 0.9482 - val_loss: 1.4151 - val_accuracy: 0.7874
# Epoch 27/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0942 - accuracy: 0.9741 - val_loss: 1.4545 - val_accuracy: 0.8179
# Epoch 28/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1136 - accuracy: 0.9718 - val_loss: 1.6600 - val_accuracy: 0.8036
# Epoch 29/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1411 - accuracy: 0.9668 - val_loss: 1.6923 - val_accuracy: 0.7940
# Epoch 30/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1445 - accuracy: 0.9659 - val_loss: 1.7310 - val_accuracy: 0.8029

# %% [markdown]
# Salviamo i dati della history del modello in un file **csv** e convertiamo il miglior modello nell'estensione **.onnx**.

# %%
basic_model_history_df = convert_history_to_csv(basic_model_history)
basic_model_history_df.to_csv("model_histories/adam/mfcc/basic_model_history_mfcc.csv")

convert_model_to_onnx("bestmodels/adam/mfcc/basic_model_mfcc.keras", (98, 12, 1))

# %% [markdown]
# Visualizziamo l'andamento dell'accurateza e della perdita durante l'addestramento.

# %%
create_train_val_plot(basic_model_history.history)

# %% [markdown]
# Il modello di base addestrato sugli mfcc non ha performato bene quanto quello con i filterbanks. Raggiunge molto presto un adattamento ai dati e si nota un degradamento dell'accuratezza di **7 punti percentile**, con un aumento importante nel valore della perdita.

# %% [markdown]
# Verifichiamo l'accuratezza della migliore versione del modello di base.

# %%
best_basic_model = tf.keras.models.load_model("bestmodels/adam/mfcc/basic_model_mfcc.keras")
test_loss, test_acc = best_basic_model.evaluate(mfcc_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 3ms/step - loss: 0.9698 - accuracy: 0.7423
# Accuratezza: 0.742

# %%
evaluate_onnx_model("bestmodels/adam/mfcc/basic_model_mfcc.onnx", mfcc_test_ds)
# Out:
# Accuratezza: 0.742

# %% [markdown]
# Abbiamo ottenuto un'**accuratezza** del **76.5%**. Vediamo come si evolve con i prossimi modelli.

# %%
for audio, label in mfcc_test_ds: # prendiamo un audio a caso del test e creiamo la distribuzione
    create_distribution_plot(best_basic_model, audio, label)
    break

# %% [markdown]
# ### Convolutivo base risoluzione dell'overfitting
# In questa parte andremo a utilizzare il secondo modello presente nel notebook di riferimento, perciò il modello riguardante il paragrafo **risoluzione dell'overfitting**. Anche in questo caso, a causa della grandezza ridotta della matrice, è necessario applicare la stessa modifica allo stesso livello di MaxPooling.

# %%
def get_improved_basic_model(input_shape):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=input_shape)
    x = tf.keras.layers.Normalization()(inputs)

    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2, padding="same")(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
for audio, label in mfcc_train_ds:
    improved_basic_model = get_improved_basic_model(audio.shape[1:])
    break

improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/adam/mfcc/improved_basic_model_mfcc.keras", save_best_only=True, monitor="val_loss")]
improved_history = improved_basic_model.fit(mfcc_train_ds, epochs=100, validation_data=mfcc_val_ds, callbacks=improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 1s 5ms/step - loss: 3.1102 - accuracy: 0.1439 - val_loss: 2.2810 - val_accuracy: 0.3453
# Epoch 2/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.9995 - accuracy: 0.4135 - val_loss: 1.5807 - val_accuracy: 0.5324
# Epoch 3/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.3554 - accuracy: 0.5957 - val_loss: 1.2272 - val_accuracy: 0.6451
# Epoch 4/100
# 243/243 [==============================] - 1s 4ms/step - loss: 1.0046 - accuracy: 0.7022 - val_loss: 1.0565 - val_accuracy: 0.7083
# Epoch 5/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7765 - accuracy: 0.7608 - val_loss: 0.8503 - val_accuracy: 0.7631
# Epoch 6/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6287 - accuracy: 0.8081 - val_loss: 0.7814 - val_accuracy: 0.7959
# Epoch 7/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5502 - accuracy: 0.8273 - val_loss: 0.7872 - val_accuracy: 0.7959
# Epoch 8/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4789 - accuracy: 0.8501 - val_loss: 0.7590 - val_accuracy: 0.7971
# Epoch 9/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4273 - accuracy: 0.8651 - val_loss: 0.8048 - val_accuracy: 0.8005
# Epoch 10/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3839 - accuracy: 0.8764 - val_loss: 0.8847 - val_accuracy: 0.7951
# Epoch 11/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3757 - accuracy: 0.8854 - val_loss: 0.7870 - val_accuracy: 0.8133
# Epoch 12/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3164 - accuracy: 0.9012 - val_loss: 0.8244 - val_accuracy: 0.8071
# Epoch 13/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2846 - accuracy: 0.9116 - val_loss: 0.8701 - val_accuracy: 0.8032
# Epoch 14/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2919 - accuracy: 0.9079 - val_loss: 0.7761 - val_accuracy: 0.8191
# Epoch 15/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3055 - accuracy: 0.9080 - val_loss: 0.9315 - val_accuracy: 0.8086
# Epoch 16/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2769 - accuracy: 0.9161 - val_loss: 0.9733 - val_accuracy: 0.8133
# Epoch 17/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2764 - accuracy: 0.9209 - val_loss: 0.8790 - val_accuracy: 0.8144
# Epoch 18/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2112 - accuracy: 0.9336 - val_loss: 0.9291 - val_accuracy: 0.8272
# Epoch 19/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2316 - accuracy: 0.9326 - val_loss: 0.9757 - val_accuracy: 0.8299
# Epoch 20/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2335 - accuracy: 0.9318 - val_loss: 1.0297 - val_accuracy: 0.8248
# Epoch 21/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2701 - accuracy: 0.9228 - val_loss: 0.9112 - val_accuracy: 0.8337
# Epoch 22/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2147 - accuracy: 0.9393 - val_loss: 1.0120 - val_accuracy: 0.8183
# Epoch 23/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2349 - accuracy: 0.9348 - val_loss: 1.0938 - val_accuracy: 0.8279
# Epoch 24/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2020 - accuracy: 0.9428 - val_loss: 1.1351 - val_accuracy: 0.8129
# Epoch 25/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2418 - accuracy: 0.9341 - val_loss: 1.1566 - val_accuracy: 0.8140
# Epoch 26/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2007 - accuracy: 0.9433 - val_loss: 1.1458 - val_accuracy: 0.8264
# Epoch 27/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2027 - accuracy: 0.9450 - val_loss: 1.1487 - val_accuracy: 0.8272
# Epoch 28/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2169 - accuracy: 0.9436 - val_loss: 1.0810 - val_accuracy: 0.8326
# Epoch 29/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2320 - accuracy: 0.9366 - val_loss: 1.4847 - val_accuracy: 0.7878
# Epoch 30/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2748 - accuracy: 0.9294 - val_loss: 1.1692 - val_accuracy: 0.8279
# Epoch 31/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2170 - accuracy: 0.9429 - val_loss: 1.3544 - val_accuracy: 0.8299
# Epoch 32/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2114 - accuracy: 0.9483 - val_loss: 1.2380 - val_accuracy: 0.8360
# Epoch 33/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1904 - accuracy: 0.9527 - val_loss: 1.1762 - val_accuracy: 0.8164
# Epoch 34/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1629 - accuracy: 0.9546 - val_loss: 1.2600 - val_accuracy: 0.8372
# Epoch 35/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1960 - accuracy: 0.9499 - val_loss: 1.2639 - val_accuracy: 0.8187
# Epoch 36/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1893 - accuracy: 0.9519 - val_loss: 1.3839 - val_accuracy: 0.8210
# Epoch 37/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2080 - accuracy: 0.9461 - val_loss: 1.2469 - val_accuracy: 0.8345
# Epoch 38/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1602 - accuracy: 0.9558 - val_loss: 1.4441 - val_accuracy: 0.8299
# Epoch 39/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2527 - accuracy: 0.9432 - val_loss: 1.3303 - val_accuracy: 0.8210
# Epoch 40/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2011 - accuracy: 0.9522 - val_loss: 1.5223 - val_accuracy: 0.8237
# Epoch 41/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2159 - accuracy: 0.9510 - val_loss: 1.3306 - val_accuracy: 0.8241
# Epoch 42/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1910 - accuracy: 0.9550 - val_loss: 1.5274 - val_accuracy: 0.8179
# Epoch 43/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1979 - accuracy: 0.9546 - val_loss: 1.5513 - val_accuracy: 0.8349
# Epoch 44/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2391 - accuracy: 0.9466 - val_loss: 1.6286 - val_accuracy: 0.8245
# Epoch 45/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1981 - accuracy: 0.9534 - val_loss: 1.3712 - val_accuracy: 0.8372
# Epoch 46/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2526 - accuracy: 0.9463 - val_loss: 1.6766 - val_accuracy: 0.8094
# Epoch 47/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2180 - accuracy: 0.9528 - val_loss: 1.5269 - val_accuracy: 0.8333
# Epoch 48/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2446 - accuracy: 0.9465 - val_loss: 1.3976 - val_accuracy: 0.8291
# Epoch 49/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1873 - accuracy: 0.9589 - val_loss: 1.4701 - val_accuracy: 0.8356
# Epoch 50/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1725 - accuracy: 0.9633 - val_loss: 1.4878 - val_accuracy: 0.8337
# Epoch 51/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1615 - accuracy: 0.9652 - val_loss: 1.5283 - val_accuracy: 0.8349
# Epoch 52/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2249 - accuracy: 0.9521 - val_loss: 2.2049 - val_accuracy: 0.7967
# Epoch 53/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2332 - accuracy: 0.9512 - val_loss: 1.7348 - val_accuracy: 0.8241
# Epoch 54/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2959 - accuracy: 0.9418 - val_loss: 1.6231 - val_accuracy: 0.8241
# Epoch 55/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1874 - accuracy: 0.9634 - val_loss: 1.6686 - val_accuracy: 0.8445
# Epoch 56/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1918 - accuracy: 0.9624 - val_loss: 1.6811 - val_accuracy: 0.8395
# Epoch 57/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2449 - accuracy: 0.9539 - val_loss: 1.8636 - val_accuracy: 0.8252
# Epoch 58/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2258 - accuracy: 0.9535 - val_loss: 1.5820 - val_accuracy: 0.8391
# Epoch 59/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1858 - accuracy: 0.9610 - val_loss: 1.5972 - val_accuracy: 0.8341
# Epoch 60/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2560 - accuracy: 0.9521 - val_loss: 1.6984 - val_accuracy: 0.8252
# Epoch 61/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2223 - accuracy: 0.9558 - val_loss: 1.6986 - val_accuracy: 0.8414
# Epoch 62/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2182 - accuracy: 0.9561 - val_loss: 1.6415 - val_accuracy: 0.8345
# Epoch 63/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2245 - accuracy: 0.9579 - val_loss: 1.8533 - val_accuracy: 0.8422
# Epoch 64/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2300 - accuracy: 0.9549 - val_loss: 1.7261 - val_accuracy: 0.8310
# Epoch 65/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1916 - accuracy: 0.9660 - val_loss: 2.2434 - val_accuracy: 0.8187
# Epoch 66/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2494 - accuracy: 0.9527 - val_loss: 1.8782 - val_accuracy: 0.8322
# Epoch 67/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2942 - accuracy: 0.9512 - val_loss: 1.8212 - val_accuracy: 0.8133
# Epoch 68/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2472 - accuracy: 0.9566 - val_loss: 1.9776 - val_accuracy: 0.8310
# Epoch 69/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1983 - accuracy: 0.9640 - val_loss: 1.9557 - val_accuracy: 0.8356
# Epoch 70/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2197 - accuracy: 0.9626 - val_loss: 2.2623 - val_accuracy: 0.8164
# Epoch 71/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2116 - accuracy: 0.9617 - val_loss: 1.8426 - val_accuracy: 0.8353
# Epoch 72/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2415 - accuracy: 0.9595 - val_loss: 1.8917 - val_accuracy: 0.8345
# Epoch 73/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2359 - accuracy: 0.9595 - val_loss: 1.9942 - val_accuracy: 0.8368
# Epoch 74/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2760 - accuracy: 0.9562 - val_loss: 2.0051 - val_accuracy: 0.8191
# Epoch 75/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3002 - accuracy: 0.9523 - val_loss: 2.0961 - val_accuracy: 0.8345
# Epoch 76/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2358 - accuracy: 0.9585 - val_loss: 2.5190 - val_accuracy: 0.8125
# Epoch 77/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2673 - accuracy: 0.9579 - val_loss: 2.0505 - val_accuracy: 0.8248
# Epoch 78/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1679 - accuracy: 0.9704 - val_loss: 1.8489 - val_accuracy: 0.8476
# Epoch 79/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2429 - accuracy: 0.9626 - val_loss: 2.2407 - val_accuracy: 0.8380
# Epoch 80/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2819 - accuracy: 0.9580 - val_loss: 2.1906 - val_accuracy: 0.8353
# Epoch 81/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2417 - accuracy: 0.9646 - val_loss: 2.1165 - val_accuracy: 0.8318
# Epoch 82/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2567 - accuracy: 0.9601 - val_loss: 2.3490 - val_accuracy: 0.8310
# Epoch 83/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3057 - accuracy: 0.9548 - val_loss: 2.2366 - val_accuracy: 0.8302
# Epoch 84/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2486 - accuracy: 0.9646 - val_loss: 2.3324 - val_accuracy: 0.8291
# Epoch 85/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2169 - accuracy: 0.9653 - val_loss: 2.3517 - val_accuracy: 0.8364
# Epoch 86/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2344 - accuracy: 0.9626 - val_loss: 2.4465 - val_accuracy: 0.8503
# Epoch 87/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2335 - accuracy: 0.9639 - val_loss: 2.5850 - val_accuracy: 0.8268
# Epoch 88/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3336 - accuracy: 0.9577 - val_loss: 2.3022 - val_accuracy: 0.8329
# Epoch 89/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2210 - accuracy: 0.9651 - val_loss: 2.5656 - val_accuracy: 0.8395
# Epoch 90/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2870 - accuracy: 0.9589 - val_loss: 2.5230 - val_accuracy: 0.8368
# Epoch 91/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3259 - accuracy: 0.9561 - val_loss: 2.5218 - val_accuracy: 0.8310
# Epoch 92/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3531 - accuracy: 0.9535 - val_loss: 2.3079 - val_accuracy: 0.8380
# Epoch 93/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2664 - accuracy: 0.9615 - val_loss: 2.3808 - val_accuracy: 0.8395
# Epoch 94/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1781 - accuracy: 0.9722 - val_loss: 2.6095 - val_accuracy: 0.8457
# Epoch 95/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2992 - accuracy: 0.9624 - val_loss: 3.1021 - val_accuracy: 0.8299
# Epoch 96/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3798 - accuracy: 0.9528 - val_loss: 2.4406 - val_accuracy: 0.8322
# Epoch 97/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2657 - accuracy: 0.9649 - val_loss: 2.6603 - val_accuracy: 0.8353
# Epoch 98/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4609 - accuracy: 0.9490 - val_loss: 2.6439 - val_accuracy: 0.8125
# Epoch 99/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3310 - accuracy: 0.9555 - val_loss: 2.5909 - val_accuracy: 0.8310
# Epoch 100/100
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2527 - accuracy: 0.9662 - val_loss: 3.2786 - val_accuracy: 0.8399

# %%
improved_history_df = convert_history_to_csv(improved_history)
improved_history_df.to_csv("model_histories/adam/mfcc/improved_history_mfcc.csv")

convert_model_to_onnx("bestmodels/adam/mfcc/improved_basic_model_mfcc.keras", (98, 12, 1))

# %%
create_train_val_plot(improved_history.history)

# %% [markdown]
# In questo caso abbiamo ottenuto dei miglioramenti nella gestione dell'overfitting, un aumento del valore massimo di accuratezza e un livello di perdita minimo inferiore.

# %%
improved_best_model = tf.keras.models.load_model("bestmodels/adam/mfcc/improved_basic_model_mfcc.keras")
test_loss, test_acc = improved_best_model.evaluate(mfcc_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 2ms/step - loss: 0.8770 - accuracy: 0.7795
# Accuratezza: 0.780

# %%
evaluate_onnx_model("bestmodels/adam/mfcc/improved_basic_model_mfcc.onnx", mfcc_test_ds)
# Out:
# Accuratezza: 0.780

# %% [markdown]
# Questi cambiamenti hanno portato ad ottenere un'accuratezza pari a **81.8%** nei dati di test! Un significativo aumento confrontando i precedenti.

# %%
for audio, label in mfcc_test_ds:
    create_distribution_plot(improved_best_model, audio, label)
    break

# %% [markdown]
# ### Fine tuning
# In questa sezione effettuiamo il fine tuning anche per il dataset mfcc. Ovviamente anche in questo caso adattiamo il modello ai mfcc.

# %%
def get_improved_basic_model_tuning(start_filters):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(98, 12, 1))
    x = tf.keras.layers.Normalization()(inputs)

    if not isinstance(start_filters, int):
        raise Exception("start_filters must be type integer")

    filters = [start_filters * (2 ** i) for i in range(4)]
    
    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=filters[0], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[1], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[2], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[3], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2, padding="same")(x)
    x = tf.keras.layers.Conv2D(filters=filters[3], kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

def tuner(filters, learning_rates, max_epochs, train_dataset, validation_dataset):
    start_time = time.time()

    counter = 1
    
    if not isinstance(filters, list):
        raise Exception("parameter filters must be type list")

    if not isinstance(learning_rates, list):
        raise Exception("parameter learning_rates must be type list")

    callbacks = [tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5)]

    best_learning_rate = 0 
    best_filters = 0
    best_val_accuracy = 0

    best_model = 0
    
    for f in filters:
        for lr in learning_rates:
            print(f"\nAddestrando con filtri {[f * (2 ** i) for i in range(4)]} e tasso di apprendimento {lr}")
            
            model = get_improved_basic_model_tuning(start_filters=f)
            model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=lr), metrics=["accuracy"])
            model_history = model.fit(train_dataset, epochs=max_epochs, validation_data=validation_dataset, callbacks=callbacks)

            model_history_df = convert_history_to_csv(model_history)

            model_history_df[["filters"]] = f
            model_history_df[["learning_rate"]] = lr
            
            path = "model_tuning/adam/mfcc/model_" + str(counter) + ".csv"
            model_history_df.to_csv(path)
            
            if best_val_accuracy < model_history_df.iloc[-1]["val_accuracy"]:
                best_val_accuracy = model_history_df.iloc[-1]["val_accuracy"]
                best_filters = f
                best_learning_rate = lr
                epoch = len(model_history_df)

            del model

            counter += 1

    total_time = time.time() - start_time
    minutes, seconds = divmod(total_time, 60)
    print(f"\nTempo totale trascorso: {int(minutes)} minuti e {int(seconds)} secondi")
    # print(f"Il miglior modello ha un filtro di partenza pari a {best_filters}, un learning rate pari a {best_learning_rate} con un'accuracy pari a {best_val_accuracy:.3f}")

    return best_filters, best_learning_rate

# %%
best_filter, best_learning_rate = tuner([16, 32, 64], [1e-3, 1e-4, 1e-5], 30, mfcc_train_ds, mfcc_val_ds)
# Out:
# Addestrando con filtri [16, 32, 64, 128] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 2s 5ms/step - loss: 3.3021 - accuracy: 0.0976 - val_loss: 2.6690 - val_accuracy: 0.2334
# Epoch 2/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.4428 - accuracy: 0.2786 - val_loss: 2.0881 - val_accuracy: 0.4066
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.8799 - accuracy: 0.4411 - val_loss: 1.4760 - val_accuracy: 0.5783
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.4202 - accuracy: 0.5827 - val_loss: 1.1627 - val_accuracy: 0.6655
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.0805 - accuracy: 0.6728 - val_loss: 1.0023 - val_accuracy: 0.7137
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8777 - accuracy: 0.7332 - val_loss: 0.8585 - val_accuracy: 0.7485
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7388 - accuracy: 0.7768 - val_loss: 0.8058 - val_accuracy: 0.7604
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6276 - accuracy: 0.8046 - val_loss: 0.7158 - val_accuracy: 0.7944
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5559 - accuracy: 0.8291 - val_loss: 0.7443 - val_accuracy: 0.7936
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4952 - accuracy: 0.8438 - val_loss: 0.7356 - val_accuracy: 0.7982
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4510 - accuracy: 0.8577 - val_loss: 0.7395 - val_accuracy: 0.7994
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4201 - accuracy: 0.8702 - val_loss: 0.7601 - val_accuracy: 0.8002
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3790 - accuracy: 0.8823 - val_loss: 0.7250 - val_accuracy: 0.8237
#
# Addestrando con filtri [16, 32, 64, 128] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 1s 4ms/step - loss: 4.1424 - accuracy: 0.0416 - val_loss: 3.3837 - val_accuracy: 0.0529
# Epoch 2/30
# 243/243 [==============================] - 1s 3ms/step - loss: 3.3744 - accuracy: 0.0579 - val_loss: 3.3279 - val_accuracy: 0.0640
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3039 - accuracy: 0.0803 - val_loss: 3.2277 - val_accuracy: 0.0992
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1616 - accuracy: 0.1124 - val_loss: 2.9864 - val_accuracy: 0.1705
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.9575 - accuracy: 0.1607 - val_loss: 2.7270 - val_accuracy: 0.2330
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.7428 - accuracy: 0.2143 - val_loss: 2.5243 - val_accuracy: 0.2928
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.5349 - accuracy: 0.2659 - val_loss: 2.3123 - val_accuracy: 0.3553
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.3549 - accuracy: 0.3164 - val_loss: 2.1399 - val_accuracy: 0.3943
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.1870 - accuracy: 0.3599 - val_loss: 1.9879 - val_accuracy: 0.4387
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.0464 - accuracy: 0.3959 - val_loss: 1.8889 - val_accuracy: 0.4711
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.9384 - accuracy: 0.4331 - val_loss: 1.7591 - val_accuracy: 0.5046
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.7976 - accuracy: 0.4691 - val_loss: 1.6661 - val_accuracy: 0.5293
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.6668 - accuracy: 0.5008 - val_loss: 1.5884 - val_accuracy: 0.5513
# Epoch 14/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.5706 - accuracy: 0.5335 - val_loss: 1.4845 - val_accuracy: 0.5814
# Epoch 15/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.4616 - accuracy: 0.5635 - val_loss: 1.4550 - val_accuracy: 0.5849
# Epoch 16/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.3882 - accuracy: 0.5844 - val_loss: 1.3657 - val_accuracy: 0.6204
# Epoch 17/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.2940 - accuracy: 0.6071 - val_loss: 1.3212 - val_accuracy: 0.6254
# Epoch 18/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.2131 - accuracy: 0.6326 - val_loss: 1.2930 - val_accuracy: 0.6277
# Epoch 19/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.1330 - accuracy: 0.6625 - val_loss: 1.2426 - val_accuracy: 0.6516
# Epoch 20/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.0688 - accuracy: 0.6772 - val_loss: 1.1912 - val_accuracy: 0.6570
# Epoch 21/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.9991 - accuracy: 0.6951 - val_loss: 1.1297 - val_accuracy: 0.6829
# Epoch 22/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.9492 - accuracy: 0.7129 - val_loss: 1.1155 - val_accuracy: 0.6844
# Epoch 23/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8978 - accuracy: 0.7268 - val_loss: 1.1064 - val_accuracy: 0.6871
# Epoch 24/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.8310 - accuracy: 0.7430 - val_loss: 1.0706 - val_accuracy: 0.7002
# Epoch 25/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7960 - accuracy: 0.7528 - val_loss: 1.0908 - val_accuracy: 0.6890
# Epoch 26/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7547 - accuracy: 0.7659 - val_loss: 1.0464 - val_accuracy: 0.7018
# Epoch 27/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7145 - accuracy: 0.7754 - val_loss: 1.0376 - val_accuracy: 0.7041
# Epoch 28/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6641 - accuracy: 0.7902 - val_loss: 0.9809 - val_accuracy: 0.7303
# Epoch 29/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6377 - accuracy: 0.8001 - val_loss: 1.0269 - val_accuracy: 0.7164
# Epoch 30/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6102 - accuracy: 0.8079 - val_loss: 0.9884 - val_accuracy: 0.7180
#
# Addestrando con filtri [16, 32, 64, 128] e tasso di apprendimento 1e-05
# Epoch 1/30
# 243/243 [==============================] - 1s 4ms/step - loss: 5.1761 - accuracy: 0.0389 - val_loss: 3.5368 - val_accuracy: 0.0378
# Epoch 2/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.6663 - accuracy: 0.0407 - val_loss: 3.4279 - val_accuracy: 0.0455
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.4756 - accuracy: 0.0457 - val_loss: 3.3993 - val_accuracy: 0.0463
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.4317 - accuracy: 0.0433 - val_loss: 3.3877 - val_accuracy: 0.0494
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.4030 - accuracy: 0.0499 - val_loss: 3.3811 - val_accuracy: 0.0529
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3859 - accuracy: 0.0548 - val_loss: 3.3729 - val_accuracy: 0.0498
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3743 - accuracy: 0.0567 - val_loss: 3.3658 - val_accuracy: 0.0540
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3553 - accuracy: 0.0584 - val_loss: 3.3565 - val_accuracy: 0.0602
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3529 - accuracy: 0.0608 - val_loss: 3.3460 - val_accuracy: 0.0667
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3380 - accuracy: 0.0639 - val_loss: 3.3343 - val_accuracy: 0.0698
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3196 - accuracy: 0.0738 - val_loss: 3.3191 - val_accuracy: 0.0764
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3070 - accuracy: 0.0751 - val_loss: 3.3040 - val_accuracy: 0.0826
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2945 - accuracy: 0.0756 - val_loss: 3.2863 - val_accuracy: 0.0849
# Epoch 14/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2716 - accuracy: 0.0874 - val_loss: 3.2632 - val_accuracy: 0.0980
# Epoch 15/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2534 - accuracy: 0.0938 - val_loss: 3.2404 - val_accuracy: 0.0995
# Epoch 16/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2342 - accuracy: 0.0941 - val_loss: 3.2190 - val_accuracy: 0.1030
# Epoch 17/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2078 - accuracy: 0.1010 - val_loss: 3.1850 - val_accuracy: 0.1231
# Epoch 18/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1829 - accuracy: 0.1061 - val_loss: 3.1548 - val_accuracy: 0.1273
# Epoch 19/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1443 - accuracy: 0.1197 - val_loss: 3.1219 - val_accuracy: 0.1366
# Epoch 20/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1177 - accuracy: 0.1280 - val_loss: 3.0876 - val_accuracy: 0.1485
# Epoch 21/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.0923 - accuracy: 0.1286 - val_loss: 3.0540 - val_accuracy: 0.1539
# Epoch 22/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.0664 - accuracy: 0.1402 - val_loss: 3.0212 - val_accuracy: 0.1644
# Epoch 23/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.0362 - accuracy: 0.1478 - val_loss: 2.9809 - val_accuracy: 0.1736
# Epoch 24/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.0035 - accuracy: 0.1568 - val_loss: 2.9507 - val_accuracy: 0.1817
# Epoch 25/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.9732 - accuracy: 0.1646 - val_loss: 2.9208 - val_accuracy: 0.1956
# Epoch 26/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.9520 - accuracy: 0.1638 - val_loss: 2.8892 - val_accuracy: 0.2033
# Epoch 27/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.9109 - accuracy: 0.1732 - val_loss: 2.8557 - val_accuracy: 0.2099
# Epoch 28/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.8823 - accuracy: 0.1879 - val_loss: 2.8230 - val_accuracy: 0.2180
# Epoch 29/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.8433 - accuracy: 0.1874 - val_loss: 2.7891 - val_accuracy: 0.2234
# Epoch 30/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.8288 - accuracy: 0.1952 - val_loss: 2.7652 - val_accuracy: 0.2323
#
# Addestrando con filtri [32, 64, 128, 256] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1736 - accuracy: 0.1119 - val_loss: 2.2960 - val_accuracy: 0.3110
# Epoch 2/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.9656 - accuracy: 0.4195 - val_loss: 1.4558 - val_accuracy: 0.5814
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.2840 - accuracy: 0.6149 - val_loss: 1.0748 - val_accuracy: 0.6964
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.9583 - accuracy: 0.7125 - val_loss: 0.9143 - val_accuracy: 0.7400
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7326 - accuracy: 0.7799 - val_loss: 0.7614 - val_accuracy: 0.7867
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5846 - accuracy: 0.8187 - val_loss: 0.7623 - val_accuracy: 0.7955
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5088 - accuracy: 0.8369 - val_loss: 0.7539 - val_accuracy: 0.8044
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4685 - accuracy: 0.8527 - val_loss: 0.6971 - val_accuracy: 0.8194
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3751 - accuracy: 0.8822 - val_loss: 0.7435 - val_accuracy: 0.8202
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3894 - accuracy: 0.8756 - val_loss: 0.7360 - val_accuracy: 0.8175
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3470 - accuracy: 0.8943 - val_loss: 0.7578 - val_accuracy: 0.8333
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2728 - accuracy: 0.9134 - val_loss: 0.8364 - val_accuracy: 0.8306
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3027 - accuracy: 0.9106 - val_loss: 0.7858 - val_accuracy: 0.8326
#
# Addestrando con filtri [32, 64, 128, 256] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.5322 - accuracy: 0.0686 - val_loss: 3.0939 - val_accuracy: 0.1157
# Epoch 2/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.9610 - accuracy: 0.1562 - val_loss: 2.6061 - val_accuracy: 0.2812
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.4983 - accuracy: 0.2729 - val_loss: 2.1665 - val_accuracy: 0.4082
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.0813 - accuracy: 0.3906 - val_loss: 1.8046 - val_accuracy: 0.4927
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.7479 - accuracy: 0.4794 - val_loss: 1.5799 - val_accuracy: 0.5583
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.4704 - accuracy: 0.5595 - val_loss: 1.3947 - val_accuracy: 0.6111
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.2590 - accuracy: 0.6165 - val_loss: 1.2261 - val_accuracy: 0.6593
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.0720 - accuracy: 0.6768 - val_loss: 1.1269 - val_accuracy: 0.6748
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.9222 - accuracy: 0.7187 - val_loss: 1.0370 - val_accuracy: 0.7025
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.7907 - accuracy: 0.7563 - val_loss: 1.0073 - val_accuracy: 0.7153
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6908 - accuracy: 0.7875 - val_loss: 0.9363 - val_accuracy: 0.7369
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.6094 - accuracy: 0.8126 - val_loss: 0.9232 - val_accuracy: 0.7427
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.5353 - accuracy: 0.8385 - val_loss: 0.8745 - val_accuracy: 0.7488
# Epoch 14/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4594 - accuracy: 0.8589 - val_loss: 0.8662 - val_accuracy: 0.7604
# Epoch 15/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.4048 - accuracy: 0.8738 - val_loss: 0.8491 - val_accuracy: 0.7670
# Epoch 16/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3576 - accuracy: 0.8883 - val_loss: 0.8486 - val_accuracy: 0.7623
# Epoch 17/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.3158 - accuracy: 0.8996 - val_loss: 0.8489 - val_accuracy: 0.7693
# Epoch 18/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2787 - accuracy: 0.9122 - val_loss: 0.8806 - val_accuracy: 0.7596
# Epoch 19/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2497 - accuracy: 0.9219 - val_loss: 0.8624 - val_accuracy: 0.7677
# Epoch 20/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2249 - accuracy: 0.9304 - val_loss: 0.8895 - val_accuracy: 0.7620
# Epoch 21/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.2061 - accuracy: 0.9370 - val_loss: 0.8315 - val_accuracy: 0.7847
# Epoch 22/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1796 - accuracy: 0.9450 - val_loss: 0.8400 - val_accuracy: 0.7886
# Epoch 23/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1642 - accuracy: 0.9488 - val_loss: 0.8816 - val_accuracy: 0.7770
# Epoch 24/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1565 - accuracy: 0.9504 - val_loss: 0.8400 - val_accuracy: 0.7905
# Epoch 25/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1367 - accuracy: 0.9586 - val_loss: 0.8474 - val_accuracy: 0.7905
# Epoch 26/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1251 - accuracy: 0.9631 - val_loss: 0.8180 - val_accuracy: 0.8032
# Epoch 27/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1132 - accuracy: 0.9653 - val_loss: 0.8314 - val_accuracy: 0.8013
# Epoch 28/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1128 - accuracy: 0.9646 - val_loss: 0.8283 - val_accuracy: 0.8009
# Epoch 29/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.1004 - accuracy: 0.9707 - val_loss: 0.8724 - val_accuracy: 0.8013
# Epoch 30/30
# 243/243 [==============================] - 1s 4ms/step - loss: 0.0965 - accuracy: 0.9701 - val_loss: 0.8397 - val_accuracy: 0.8052
#
# Addestrando con filtri [32, 64, 128, 256] e tasso di apprendimento 1e-05
# Epoch 1/30
# 243/243 [==============================] - 1s 4ms/step - loss: 5.5603 - accuracy: 0.0365 - val_loss: 3.4570 - val_accuracy: 0.0552
# Epoch 2/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.6029 - accuracy: 0.0452 - val_loss: 3.3652 - val_accuracy: 0.0656
# Epoch 3/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.4206 - accuracy: 0.0564 - val_loss: 3.3280 - val_accuracy: 0.0721
# Epoch 4/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3572 - accuracy: 0.0664 - val_loss: 3.2966 - val_accuracy: 0.0864
# Epoch 5/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.3124 - accuracy: 0.0754 - val_loss: 3.2514 - val_accuracy: 0.1061
# Epoch 6/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.2579 - accuracy: 0.0945 - val_loss: 3.2010 - val_accuracy: 0.1150
# Epoch 7/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1931 - accuracy: 0.1097 - val_loss: 3.1321 - val_accuracy: 0.1412
# Epoch 8/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.1360 - accuracy: 0.1245 - val_loss: 3.0547 - val_accuracy: 0.1671
# Epoch 9/30
# 243/243 [==============================] - 1s 4ms/step - loss: 3.0593 - accuracy: 0.1429 - val_loss: 2.9777 - val_accuracy: 0.1833
# Epoch 10/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.9792 - accuracy: 0.1599 - val_loss: 2.8879 - val_accuracy: 0.2052
# Epoch 11/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.9175 - accuracy: 0.1729 - val_loss: 2.8176 - val_accuracy: 0.2261
# Epoch 12/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.8349 - accuracy: 0.2017 - val_loss: 2.7457 - val_accuracy: 0.2461
# Epoch 13/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.7779 - accuracy: 0.2113 - val_loss: 2.6672 - val_accuracy: 0.2635
# Epoch 14/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.7080 - accuracy: 0.2312 - val_loss: 2.6040 - val_accuracy: 0.2778
# Epoch 15/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.6271 - accuracy: 0.2508 - val_loss: 2.5325 - val_accuracy: 0.2971
# Epoch 16/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.5757 - accuracy: 0.2666 - val_loss: 2.4781 - val_accuracy: 0.3140
# Epoch 17/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.5206 - accuracy: 0.2825 - val_loss: 2.4322 - val_accuracy: 0.3198
# Epoch 18/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.4744 - accuracy: 0.2875 - val_loss: 2.3827 - val_accuracy: 0.3407
# Epoch 19/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.4151 - accuracy: 0.3088 - val_loss: 2.3257 - val_accuracy: 0.3495
# Epoch 20/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.3592 - accuracy: 0.3182 - val_loss: 2.2834 - val_accuracy: 0.3623
# Epoch 21/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.3114 - accuracy: 0.3351 - val_loss: 2.2395 - val_accuracy: 0.3773
# Epoch 22/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.2506 - accuracy: 0.3474 - val_loss: 2.1953 - val_accuracy: 0.3881
# Epoch 23/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.2196 - accuracy: 0.3611 - val_loss: 2.1574 - val_accuracy: 0.3939
# Epoch 24/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.1702 - accuracy: 0.3695 - val_loss: 2.1252 - val_accuracy: 0.4090
# Epoch 25/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.1233 - accuracy: 0.3843 - val_loss: 2.0748 - val_accuracy: 0.4240
# Epoch 26/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.0998 - accuracy: 0.3889 - val_loss: 2.0510 - val_accuracy: 0.4294
# Epoch 27/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.0565 - accuracy: 0.4015 - val_loss: 2.0186 - val_accuracy: 0.4433
# Epoch 28/30
# 243/243 [==============================] - 1s 4ms/step - loss: 2.0115 - accuracy: 0.4161 - val_loss: 1.9807 - val_accuracy: 0.4518
# Epoch 29/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.9502 - accuracy: 0.4313 - val_loss: 1.9515 - val_accuracy: 0.4595
# Epoch 30/30
# 243/243 [==============================] - 1s 4ms/step - loss: 1.9153 - accuracy: 0.4463 - val_loss: 1.9163 - val_accuracy: 0.4676
#
# Addestrando con filtri [64, 128, 256, 512] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 2s 5ms/step - loss: 2.9884 - accuracy: 0.1710 - val_loss: 2.1100 - val_accuracy: 0.3719
# Epoch 2/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.6605 - accuracy: 0.5110 - val_loss: 1.3644 - val_accuracy: 0.5992
# Epoch 3/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.0780 - accuracy: 0.6794 - val_loss: 1.0886 - val_accuracy: 0.6914
# Epoch 4/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.7837 - accuracy: 0.7625 - val_loss: 0.8929 - val_accuracy: 0.7492
# Epoch 5/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6318 - accuracy: 0.8093 - val_loss: 0.7751 - val_accuracy: 0.7855
# Epoch 6/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.5283 - accuracy: 0.8358 - val_loss: 0.8820 - val_accuracy: 0.7778
# Epoch 7/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4482 - accuracy: 0.8639 - val_loss: 0.8361 - val_accuracy: 0.7832
# Epoch 8/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4035 - accuracy: 0.8780 - val_loss: 0.7919 - val_accuracy: 0.8013
# Epoch 9/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3909 - accuracy: 0.8822 - val_loss: 0.9731 - val_accuracy: 0.7785
# Epoch 10/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3651 - accuracy: 0.8890 - val_loss: 0.9823 - val_accuracy: 0.7840
#
# Addestrando con filtri [64, 128, 256, 512] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 1s 5ms/step - loss: 3.2697 - accuracy: 0.1160 - val_loss: 2.5799 - val_accuracy: 0.2770
# Epoch 2/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.3060 - accuracy: 0.3332 - val_loss: 1.9440 - val_accuracy: 0.4433
# Epoch 3/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.7561 - accuracy: 0.4952 - val_loss: 1.5655 - val_accuracy: 0.5417
# Epoch 4/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.3510 - accuracy: 0.6035 - val_loss: 1.2041 - val_accuracy: 0.6640
# Epoch 5/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.0211 - accuracy: 0.6999 - val_loss: 1.0174 - val_accuracy: 0.7060
# Epoch 6/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8094 - accuracy: 0.7586 - val_loss: 0.9300 - val_accuracy: 0.7323
# Epoch 7/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.6158 - accuracy: 0.8139 - val_loss: 0.8563 - val_accuracy: 0.7631
# Epoch 8/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.4879 - accuracy: 0.8524 - val_loss: 0.8103 - val_accuracy: 0.7739
# Epoch 9/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3875 - accuracy: 0.8807 - val_loss: 0.8669 - val_accuracy: 0.7577
# Epoch 10/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.3104 - accuracy: 0.9039 - val_loss: 0.7769 - val_accuracy: 0.7847
# Epoch 11/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2567 - accuracy: 0.9186 - val_loss: 0.7785 - val_accuracy: 0.7897
# Epoch 12/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.2048 - accuracy: 0.9343 - val_loss: 0.7822 - val_accuracy: 0.7982
# Epoch 13/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1750 - accuracy: 0.9470 - val_loss: 0.8941 - val_accuracy: 0.7747
# Epoch 14/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1391 - accuracy: 0.9568 - val_loss: 0.7856 - val_accuracy: 0.8083
# Epoch 15/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.1225 - accuracy: 0.9615 - val_loss: 0.8387 - val_accuracy: 0.8036
#
# Addestrando con filtri [64, 128, 256, 512] e tasso di apprendimento 1e-05
# Epoch 1/30
# 243/243 [==============================] - 1s 5ms/step - loss: 4.2353 - accuracy: 0.0496 - val_loss: 3.2828 - val_accuracy: 0.0802
# Epoch 2/30
# 243/243 [==============================] - 1s 5ms/step - loss: 3.3294 - accuracy: 0.0799 - val_loss: 3.1427 - val_accuracy: 0.1397
# Epoch 3/30
# 243/243 [==============================] - 1s 5ms/step - loss: 3.1450 - accuracy: 0.1258 - val_loss: 2.9741 - val_accuracy: 0.1917
# Epoch 4/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.9524 - accuracy: 0.1727 - val_loss: 2.7874 - val_accuracy: 0.2465
# Epoch 5/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.7634 - accuracy: 0.2223 - val_loss: 2.6119 - val_accuracy: 0.2905
# Epoch 6/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.6147 - accuracy: 0.2554 - val_loss: 2.4745 - val_accuracy: 0.3302
# Epoch 7/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.4701 - accuracy: 0.2901 - val_loss: 2.3506 - val_accuracy: 0.3492
# Epoch 8/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.3283 - accuracy: 0.3348 - val_loss: 2.2383 - val_accuracy: 0.3765
# Epoch 9/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.2047 - accuracy: 0.3606 - val_loss: 2.1199 - val_accuracy: 0.4120
# Epoch 10/30
# 243/243 [==============================] - 1s 5ms/step - loss: 2.0990 - accuracy: 0.3943 - val_loss: 2.0514 - val_accuracy: 0.4317
# Epoch 11/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.9934 - accuracy: 0.4205 - val_loss: 1.9654 - val_accuracy: 0.4657
# Epoch 12/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.9028 - accuracy: 0.4436 - val_loss: 1.8941 - val_accuracy: 0.4765
# Epoch 13/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.8180 - accuracy: 0.4731 - val_loss: 1.8245 - val_accuracy: 0.4965
# Epoch 14/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.7286 - accuracy: 0.4952 - val_loss: 1.7750 - val_accuracy: 0.5093
# Epoch 15/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.6657 - accuracy: 0.5178 - val_loss: 1.7036 - val_accuracy: 0.5301
# Epoch 16/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.5785 - accuracy: 0.5477 - val_loss: 1.6708 - val_accuracy: 0.5370
# Epoch 17/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.4988 - accuracy: 0.5693 - val_loss: 1.6180 - val_accuracy: 0.5536
# Epoch 18/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.4455 - accuracy: 0.5796 - val_loss: 1.5742 - val_accuracy: 0.5718
# Epoch 19/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.3746 - accuracy: 0.6012 - val_loss: 1.5372 - val_accuracy: 0.5799
# Epoch 20/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.3207 - accuracy: 0.6174 - val_loss: 1.4947 - val_accuracy: 0.5853
# Epoch 21/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.2586 - accuracy: 0.6397 - val_loss: 1.4664 - val_accuracy: 0.5957
# Epoch 22/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.2197 - accuracy: 0.6485 - val_loss: 1.4309 - val_accuracy: 0.6011
# Epoch 23/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.1538 - accuracy: 0.6727 - val_loss: 1.4023 - val_accuracy: 0.6130
# Epoch 24/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.1141 - accuracy: 0.6821 - val_loss: 1.3721 - val_accuracy: 0.6200
# Epoch 25/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.0616 - accuracy: 0.6889 - val_loss: 1.3423 - val_accuracy: 0.6292
# Epoch 26/30
# 243/243 [==============================] - 1s 5ms/step - loss: 1.0214 - accuracy: 0.7040 - val_loss: 1.3157 - val_accuracy: 0.6373
# Epoch 27/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.9815 - accuracy: 0.7195 - val_loss: 1.2902 - val_accuracy: 0.6435
# Epoch 28/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.9289 - accuracy: 0.7314 - val_loss: 1.2672 - val_accuracy: 0.6424
# Epoch 29/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8925 - accuracy: 0.7457 - val_loss: 1.2527 - val_accuracy: 0.6516
# Epoch 30/30
# 243/243 [==============================] - 1s 5ms/step - loss: 0.8546 - accuracy: 0.7546 - val_loss: 1.2258 - val_accuracy: 0.6601
#
# Tempo totale trascorso: 3 minuti e 26 secondi

# %% [markdown]
# Il tempo necessario per la ricerca dei migliori iperparametri è stata di quasi 4 minuti.
#
# Visualizziamo l'accuratezza e la perdita di tutti i modelli che il tuner ha addestato.

# %%
plot_models(path="model_tuning/adam/mfcc", show="accuracy")
plot_models(path="model_tuning/adam/mfcc", show="loss")

# %% [markdown]
# Dai grafici emerge che la combinazione più performante è composta da **32 filtri di partenza** e un **tasso di apprendimento di 0.0001**, poiché ritarda maggiormente l'overfitting. Altre combinazioni, come **64 filtri di partenza** e un **tasso di apprendimento di 0.0001**, mostrano buone prestazioni ma anche un inizio di overfitting, evidenziato dallo distaccamento tra la perdita di addestramento e quella di validazione.
#
# Procediamo quindi con l'addestramento del modello con **32 filtri di partenza** e un **tasso di apprendimento di 0.0001**. Come di consueto, salviamo i risultati in un file `keras` e la cronologia (history) in un file `csv`. Infine, convertiamo il file in formato `onnx`.

# %% [markdown]
# # DA RIFARE

# %%
for audio, label in mfcc_train_ds:
    tuned_improved_basic_model = get_improved_basic_model(audio.shape[1:])
    break

tuned_improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5), metrics=["accuracy"])

# %%
tuned_improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/adam/mfcc/tuned_improved_basic_model_mfcc.keras", save_best_only=True, monitor="val_loss")]
tuned_improved_history = tuned_improved_basic_model.fit(mfcc_train_ds, epochs=100, validation_data=mfcc_val_ds, callbacks=tuned_improved_basic_model_callbacks)

# %%
tuned_improved_history_df = convert_history_to_csv(tuned_improved_history)
tuned_improved_history_df.to_csv("model_histories/adam/mfcc/tuned_improved_history_mfcc.csv")

convert_model_to_onnx("bestmodels/adam/mfcc/tuned_improved_basic_model_mfcc.keras", (98, 12, 1))

# %%
create_train_val_plot(tuned_improved_history.history)

# %% [markdown]
# Anche in questo caso la rete non ha raggiunto l'overfitting, nonostante ci fosse vicina, perciò avremmo potuto addestrarlo per un numero di epoche maggiore.
#
# D'altro canto le prestazioni non sono delle migliori. L'accuratezza maggiore raggiunge con difficoltà il **70%**. Probabilmente avremmo dovuto utilizzare un'altro **tasso di apprendimento**.

# %%
tuned_improved_best_model = tf.keras.models.load_model("bestmodels/adam/mfcc/tuned_improved_basic_model_mfcc.keras")
test_loss, test_acc = tuned_improved_best_model.evaluate(mfcc_test_ds)
print(f"Accuratezza: {test_acc:.3f}")

# %%
evaluate_onnx_model("bestmodels/adam/mfcc/tuned_improved_basic_model_mfcc.onnx", mfcc_test_ds)

# %% [markdown]
# Di fatto l'accuratezza raggiuta nel set non raggiunge neppure la soglia del **70%**.

# %%
for audio, label in mfcc_test_ds:
    create_distribution_plot(tuned_improved_best_model, audio, label)
    break

# %% [markdown]
# Come prima è riuscito a predire correttamente la classe three, con dell'incertezza verso tree. Accettabile vista la somiglianza tra le parole.

# %% [markdown]
# ### Miglioramenti all'architettura del modello convolutivo
# In questa ultima fase riguardante gli mfcc andremo ad addestrare il modello corrispondente alla sezione **miglioramenti all'architettura del modello** del notebook di riferimento.
#
# In questo caso non è necessario implementare cambiamenti all'architettura del modello.

# %%
def residual_block(x, filters, pooling=False):
    residual = x

    x = tf.keras.layers.SeparableConv2D(filters, 3, padding="same", use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    if pooling:
      x = tf.keras.layers.MaxPooling2D(pool_size=2, padding="same")(x)
      residual = tf.keras.layers.Conv2D(filters, 1, strides=2)(residual)
    elif filters != residual.shape[-1]:
      residual = tf.keras.layers.Conv2D(filters, 1)(residual)

    x = tf.keras.layers.add([x, residual])
    return x

def bp_basic_model(input_shape):
    # input e pre processamento
    inputs = tf.keras.Input(shape=input_shape)
    
    x = residual_block(inputs, 32, pooling=True)
    x = residual_block(x, 64, pooling=True)
    x = residual_block(x, 128, pooling=True)
    x = residual_block(x, 256, pooling=True)
    x = residual_block(x, 256, pooling=False)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Livelli per la classificazione
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
for audio, label in mfcc_train_ds:
    bp_basic_model = bp_basic_model(audio.shape[1:])
    break

bp_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

bp_basic_model.summary()
# Out:
# Model: "model_24"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_23 (InputLayer)          [(None, 98, 12, 1)]  0           []
#
#  separable_conv2d_5 (SeparableC  (None, 98, 12, 32)  41          ['input_23[0][0]']
#  onv2D)
#
#  batch_normalization_5 (BatchNo  (None, 98, 12, 32)  128         ['separable_conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 98, 12, 32)   0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_88 (MaxPooling2D  (None, 49, 6, 32)   0           ['activation_5[0][0]']
#  )
#
#  conv2d_109 (Conv2D)            (None, 49, 6, 32)    64          ['input_23[0][0]']
#
#  add_5 (Add)                    (None, 49, 6, 32)    0           ['max_pooling2d_88[0][0]',
#                                                                   'conv2d_109[0][0]']
#
#  separable_conv2d_6 (SeparableC  (None, 49, 6, 64)   2336        ['add_5[0][0]']
#  onv2D)
#
#  batch_normalization_6 (BatchNo  (None, 49, 6, 64)   256         ['separable_conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 49, 6, 64)    0           ['batch_normalization_6[0][0]']
#
#  max_pooling2d_89 (MaxPooling2D  (None, 25, 3, 64)   0           ['activation_6[0][0]']
#  )
#
#  conv2d_110 (Conv2D)            (None, 25, 3, 64)    2112        ['add_5[0][0]']
#
#  add_6 (Add)                    (None, 25, 3, 64)    0           ['max_pooling2d_89[0][0]',
#                                                                   'conv2d_110[0][0]']
#
#  separable_conv2d_7 (SeparableC  (None, 25, 3, 128)  8768        ['add_6[0][0]']
#  onv2D)
#
#  batch_normalization_7 (BatchNo  (None, 25, 3, 128)  512         ['separable_conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 25, 3, 128)   0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_90 (MaxPooling2D  (None, 13, 2, 128)  0           ['activation_7[0][0]']
#  )
#
#  conv2d_111 (Conv2D)            (None, 13, 2, 128)   8320        ['add_6[0][0]']
#
#  add_7 (Add)                    (None, 13, 2, 128)   0           ['max_pooling2d_90[0][0]',
#                                                                   'conv2d_111[0][0]']
#
#  separable_conv2d_8 (SeparableC  (None, 13, 2, 256)  33920       ['add_7[0][0]']
#  onv2D)
#
#  batch_normalization_8 (BatchNo  (None, 13, 2, 256)  1024        ['separable_conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 13, 2, 256)   0           ['batch_normalization_8[0][0]']
#
#  max_pooling2d_91 (MaxPooling2D  (None, 7, 1, 256)   0           ['activation_8[0][0]']
#  )
#
#  conv2d_112 (Conv2D)            (None, 7, 1, 256)    33024       ['add_7[0][0]']
#
#  add_8 (Add)                    (None, 7, 1, 256)    0           ['max_pooling2d_91[0][0]',
#                                                                   'conv2d_112[0][0]']
#
#  separable_conv2d_9 (SeparableC  (None, 7, 1, 256)   67840       ['add_8[0][0]']
#  onv2D)
#
#  batch_normalization_9 (BatchNo  (None, 7, 1, 256)   1024        ['separable_conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 7, 1, 256)    0           ['batch_normalization_9[0][0]']
#
#  add_9 (Add)                    (None, 7, 1, 256)    0           ['activation_9[0][0]',
#                                                                   'add_8[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 256)         0           ['add_9[0][0]']
#  obalAveragePooling2D)
#
#  dropout_22 (Dropout)           (None, 256)          0           ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_22 (Dense)               (None, 30)           7710        ['dropout_22[0][0]']
#
# ==================================================================================================
# Total params: 167,079
# Trainable params: 165,607
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %% [markdown]
# Il numero di parametri, come per i filterbank, è rimasto invariato.

# %%
bp_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/adam/mfcc/bp_basic_model_mfcc.keras", save_best_only=True, monitor="val_loss")]
bp_model_history = bp_basic_model.fit(mfcc_train_ds, epochs=100, validation_data=mfcc_val_ds, callbacks=bp_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 2s 6ms/step - loss: 4.5408 - accuracy: 0.0923 - val_loss: 3.0772 - val_accuracy: 0.1354
# Epoch 2/100
# 243/243 [==============================] - 2s 7ms/step - loss: 2.8980 - accuracy: 0.2005 - val_loss: 2.7331 - val_accuracy: 0.2218
# Epoch 3/100
# 243/243 [==============================] - 1s 6ms/step - loss: 2.3977 - accuracy: 0.3082 - val_loss: 2.1998 - val_accuracy: 0.3800
# Epoch 4/100
# 243/243 [==============================] - 1s 6ms/step - loss: 1.9341 - accuracy: 0.4460 - val_loss: 1.7020 - val_accuracy: 0.5367
# Epoch 5/100
# 243/243 [==============================] - 1s 6ms/step - loss: 1.5957 - accuracy: 0.5494 - val_loss: 1.4625 - val_accuracy: 0.5976
# Epoch 6/100
# 243/243 [==============================] - 1s 6ms/step - loss: 1.3182 - accuracy: 0.6233 - val_loss: 1.2721 - val_accuracy: 0.6331
# Epoch 7/100
# 243/243 [==============================] - 1s 6ms/step - loss: 1.1427 - accuracy: 0.6756 - val_loss: 1.1907 - val_accuracy: 0.6597
# Epoch 8/100
# 243/243 [==============================] - 1s 6ms/step - loss: 1.0115 - accuracy: 0.7111 - val_loss: 1.0829 - val_accuracy: 0.6944
# Epoch 9/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.9050 - accuracy: 0.7387 - val_loss: 0.9369 - val_accuracy: 0.7365
# Epoch 10/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.8221 - accuracy: 0.7602 - val_loss: 0.9282 - val_accuracy: 0.7326
# Epoch 11/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.7669 - accuracy: 0.7776 - val_loss: 0.8411 - val_accuracy: 0.7542
# Epoch 12/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.7125 - accuracy: 0.7923 - val_loss: 0.9433 - val_accuracy: 0.7234
# Epoch 13/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.6585 - accuracy: 0.8055 - val_loss: 0.7701 - val_accuracy: 0.7812
# Epoch 14/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.5928 - accuracy: 0.8262 - val_loss: 0.8944 - val_accuracy: 0.7407
# Epoch 15/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.5487 - accuracy: 0.8402 - val_loss: 0.7169 - val_accuracy: 0.7863
# Epoch 16/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.5031 - accuracy: 0.8526 - val_loss: 0.8021 - val_accuracy: 0.7739
# Epoch 17/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.4513 - accuracy: 0.8686 - val_loss: 0.7489 - val_accuracy: 0.7801
# Epoch 18/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.4309 - accuracy: 0.8720 - val_loss: 0.7438 - val_accuracy: 0.7870
# Epoch 19/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.3974 - accuracy: 0.8808 - val_loss: 0.8139 - val_accuracy: 0.7820
# Epoch 20/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.3757 - accuracy: 0.8844 - val_loss: 0.7654 - val_accuracy: 0.7890
# Epoch 21/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.3444 - accuracy: 0.8955 - val_loss: 0.7516 - val_accuracy: 0.7948
# Epoch 22/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.3179 - accuracy: 0.8995 - val_loss: 0.9059 - val_accuracy: 0.7608
# Epoch 23/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.2987 - accuracy: 0.9112 - val_loss: 0.7584 - val_accuracy: 0.8005
# Epoch 24/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.2856 - accuracy: 0.9120 - val_loss: 0.9857 - val_accuracy: 0.7566
# Epoch 25/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.2657 - accuracy: 0.9189 - val_loss: 0.8526 - val_accuracy: 0.7843
# Epoch 26/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.2460 - accuracy: 0.9216 - val_loss: 0.7392 - val_accuracy: 0.8002
# Epoch 27/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.2247 - accuracy: 0.9305 - val_loss: 0.9341 - val_accuracy: 0.7774
# Epoch 28/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.2129 - accuracy: 0.9352 - val_loss: 0.7560 - val_accuracy: 0.8063
# Epoch 29/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1931 - accuracy: 0.9388 - val_loss: 0.8955 - val_accuracy: 0.7967
# Epoch 30/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.2027 - accuracy: 0.9360 - val_loss: 0.8838 - val_accuracy: 0.7859
# Epoch 31/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1731 - accuracy: 0.9460 - val_loss: 0.7746 - val_accuracy: 0.8194
# Epoch 32/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1726 - accuracy: 0.9457 - val_loss: 0.7166 - val_accuracy: 0.8283
# Epoch 33/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1664 - accuracy: 0.9485 - val_loss: 0.7180 - val_accuracy: 0.8287
# Epoch 34/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1382 - accuracy: 0.9573 - val_loss: 0.8493 - val_accuracy: 0.7944
# Epoch 35/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1448 - accuracy: 0.9519 - val_loss: 0.7521 - val_accuracy: 0.8148
# Epoch 36/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1232 - accuracy: 0.9621 - val_loss: 0.7727 - val_accuracy: 0.8167
# Epoch 37/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.1254 - accuracy: 0.9603 - val_loss: 0.7062 - val_accuracy: 0.8310
# Epoch 38/100
# 243/243 [==============================] - 2s 6ms/step - loss: 0.1204 - accuracy: 0.9612 - val_loss: 0.7550 - val_accuracy: 0.8214
# Epoch 39/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1152 - accuracy: 0.9631 - val_loss: 0.7225 - val_accuracy: 0.8275
# Epoch 40/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1144 - accuracy: 0.9631 - val_loss: 0.7672 - val_accuracy: 0.8241
# Epoch 41/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0998 - accuracy: 0.9693 - val_loss: 0.8016 - val_accuracy: 0.8164
# Epoch 42/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1041 - accuracy: 0.9675 - val_loss: 0.7374 - val_accuracy: 0.8283
# Epoch 43/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1260 - accuracy: 0.9593 - val_loss: 1.2796 - val_accuracy: 0.7508
# Epoch 44/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0844 - accuracy: 0.9755 - val_loss: 0.7619 - val_accuracy: 0.8268
# Epoch 45/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0760 - accuracy: 0.9745 - val_loss: 0.6989 - val_accuracy: 0.8414
# Epoch 46/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0818 - accuracy: 0.9746 - val_loss: 0.8195 - val_accuracy: 0.8279
# Epoch 47/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0748 - accuracy: 0.9771 - val_loss: 0.9711 - val_accuracy: 0.8113
# Epoch 48/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.1027 - accuracy: 0.9674 - val_loss: 0.8816 - val_accuracy: 0.8206
# Epoch 49/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0942 - accuracy: 0.9679 - val_loss: 0.8197 - val_accuracy: 0.8291
# Epoch 50/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0736 - accuracy: 0.9759 - val_loss: 0.9618 - val_accuracy: 0.8121
# Epoch 51/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0781 - accuracy: 0.9744 - val_loss: 0.8563 - val_accuracy: 0.8275
# Epoch 52/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0907 - accuracy: 0.9698 - val_loss: 1.0054 - val_accuracy: 0.8094
# Epoch 53/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0863 - accuracy: 0.9711 - val_loss: 1.0000 - val_accuracy: 0.8005
# Epoch 54/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0782 - accuracy: 0.9742 - val_loss: 0.9623 - val_accuracy: 0.8009
# Epoch 55/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0653 - accuracy: 0.9791 - val_loss: 0.8511 - val_accuracy: 0.8225
# Epoch 56/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0649 - accuracy: 0.9777 - val_loss: 0.8408 - val_accuracy: 0.8302
# Epoch 57/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0596 - accuracy: 0.9826 - val_loss: 1.0427 - val_accuracy: 0.8063
# Epoch 58/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0818 - accuracy: 0.9723 - val_loss: 1.2756 - val_accuracy: 0.7608
# Epoch 59/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0988 - accuracy: 0.9682 - val_loss: 0.9951 - val_accuracy: 0.8067
# Epoch 60/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0519 - accuracy: 0.9826 - val_loss: 0.8095 - val_accuracy: 0.8360
# Epoch 61/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0458 - accuracy: 0.9857 - val_loss: 0.8785 - val_accuracy: 0.8380
# Epoch 62/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0667 - accuracy: 0.9772 - val_loss: 0.9156 - val_accuracy: 0.8256
# Epoch 63/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0632 - accuracy: 0.9790 - val_loss: 0.8821 - val_accuracy: 0.8314
# Epoch 64/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0823 - accuracy: 0.9736 - val_loss: 1.0210 - val_accuracy: 0.8102
# Epoch 65/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0748 - accuracy: 0.9750 - val_loss: 0.8194 - val_accuracy: 0.8356
# Epoch 66/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0814 - accuracy: 0.9735 - val_loss: 0.8341 - val_accuracy: 0.8410
# Epoch 67/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0546 - accuracy: 0.9826 - val_loss: 0.8399 - val_accuracy: 0.8391
# Epoch 68/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0461 - accuracy: 0.9851 - val_loss: 0.7822 - val_accuracy: 0.8484
# Epoch 69/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0602 - accuracy: 0.9799 - val_loss: 0.8693 - val_accuracy: 0.8283
# Epoch 70/100
# 243/243 [==============================] - 1s 5ms/step - loss: 0.0700 - accuracy: 0.9780 - val_loss: 0.8597 - val_accuracy: 0.8426
# Epoch 71/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0530 - accuracy: 0.9841 - val_loss: 0.7568 - val_accuracy: 0.8576
# Epoch 72/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0518 - accuracy: 0.9848 - val_loss: 0.7827 - val_accuracy: 0.8468
# Epoch 73/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0546 - accuracy: 0.9814 - val_loss: 1.2753 - val_accuracy: 0.7955
# Epoch 74/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0725 - accuracy: 0.9767 - val_loss: 1.0136 - val_accuracy: 0.8129
# Epoch 75/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0430 - accuracy: 0.9866 - val_loss: 1.1012 - val_accuracy: 0.8164
# Epoch 76/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0638 - accuracy: 0.9803 - val_loss: 0.9285 - val_accuracy: 0.8333
# Epoch 77/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0667 - accuracy: 0.9785 - val_loss: 0.8410 - val_accuracy: 0.8383
# Epoch 78/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0570 - accuracy: 0.9813 - val_loss: 0.9159 - val_accuracy: 0.8356
# Epoch 79/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0548 - accuracy: 0.9829 - val_loss: 0.9567 - val_accuracy: 0.8275
# Epoch 80/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0690 - accuracy: 0.9773 - val_loss: 0.9781 - val_accuracy: 0.8237
# Epoch 81/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0549 - accuracy: 0.9820 - val_loss: 0.9272 - val_accuracy: 0.8426
# Epoch 82/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0607 - accuracy: 0.9794 - val_loss: 0.8763 - val_accuracy: 0.8395
# Epoch 83/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0378 - accuracy: 0.9879 - val_loss: 0.9165 - val_accuracy: 0.8376
# Epoch 84/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0627 - accuracy: 0.9786 - val_loss: 0.8287 - val_accuracy: 0.8526
# Epoch 85/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0420 - accuracy: 0.9869 - val_loss: 0.7837 - val_accuracy: 0.8546
# Epoch 86/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0440 - accuracy: 0.9854 - val_loss: 0.9405 - val_accuracy: 0.8422
# Epoch 87/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0602 - accuracy: 0.9799 - val_loss: 0.9196 - val_accuracy: 0.8256
# Epoch 88/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0500 - accuracy: 0.9836 - val_loss: 0.8698 - val_accuracy: 0.8430
# Epoch 89/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0466 - accuracy: 0.9845 - val_loss: 0.8201 - val_accuracy: 0.8603
# Epoch 90/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0520 - accuracy: 0.9827 - val_loss: 0.7886 - val_accuracy: 0.8638
# Epoch 91/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0249 - accuracy: 0.9916 - val_loss: 0.8573 - val_accuracy: 0.8399
# Epoch 92/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0285 - accuracy: 0.9902 - val_loss: 0.8803 - val_accuracy: 0.8438
# Epoch 93/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0519 - accuracy: 0.9812 - val_loss: 0.9122 - val_accuracy: 0.8364
# Epoch 94/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0648 - accuracy: 0.9790 - val_loss: 0.8703 - val_accuracy: 0.8461
# Epoch 95/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0482 - accuracy: 0.9853 - val_loss: 0.8714 - val_accuracy: 0.8302
# Epoch 96/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0485 - accuracy: 0.9835 - val_loss: 1.0899 - val_accuracy: 0.8179
# Epoch 97/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0706 - accuracy: 0.9789 - val_loss: 1.1503 - val_accuracy: 0.8287
# Epoch 98/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0583 - accuracy: 0.9821 - val_loss: 0.8753 - val_accuracy: 0.8484
# Epoch 99/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0389 - accuracy: 0.9870 - val_loss: 0.8957 - val_accuracy: 0.8418
# Epoch 100/100
# 243/243 [==============================] - 1s 6ms/step - loss: 0.0242 - accuracy: 0.9919 - val_loss: 0.7644 - val_accuracy: 0.8534

# %%
bp_model_history_df = convert_history_to_csv(bp_model_history)
bp_model_history_df.to_csv("model_histories/adam/mfcc/bp_model_history_mfcc.csv")

convert_model_to_onnx("bestmodels/adam/mfcc/bp_basic_model_mfcc.keras", (98, 12, 1))

# %%
create_train_val_plot(bp_model_history.history, overfit=False)

# %% [markdown]
# In questo caso il modello è sotto certi aspetti leggermente migliorato rispetto a prima, ma continua ad avere delle prestazioni peggiori rispetto agli spettrogrammi e filterbanks.

# %%
best_bp_basic_model = tf.keras.models.load_model("bestmodels/adam/mfcc/bp_basic_model_mfcc.keras")
test_loss, test_acc = best_bp_basic_model.evaluate(mfcc_test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 0s 2ms/step - loss: 0.7438 - accuracy: 0.8307
# Accuratezza: 0.831

# %%
evaluate_onnx_model("bestmodels/adam/mfcc/bp_basic_model_mfcc.onnx", mfcc_test_ds)
# Out:
# Accuratezza: 0.831

# %% [markdown]
# Abbiamo ottenuto un'accuratezza del **82.1%**. A conferma di quanto detto prima, il modello risulta migliore.

# %%
for audio, label in mfcc_test_ds:
    create_distribution_plot(best_bp_basic_model, audio, label)
    break

# %% [markdown]
# La decisione del modello in questo caso è nuovamente molto chiara.
