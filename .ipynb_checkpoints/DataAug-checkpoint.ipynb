# %%
import tensorflow as tf
import numpy as np
import librosa
from IPython.display import Audio
import matplotlib.pyplot as plt
import random

# %%
train_ds, validation_ds = tf.keras.utils.audio_dataset_from_directory(
    directory='../reduced_dataset/dataset/audio',
    validation_split=0.4, # stiamo mettendo da parte il 40% del dataset, che sarà suddiviso in validation set e test set
    shuffle=True,
    subset='both', # necessario se stiamo utilizzando validation_split (se no darebbe errore)
    seed=0 # necessario se stiamo utilizzando sia shuffle che validation_split (se no darebbe errore)
)

noise_ds = tf.keras.utils.audio_dataset_from_directory(
    directory='../noise_dataset',
    validation_split=0.4, # stiamo mettendo da parte il 40% del dataset, che sarà suddiviso in validation set e test set
    shuffle=True,
    subset='both', # necessario se stiamo utilizzando validation_split (se no darebbe errore)
    seed=0 # necessario se stiamo utilizzando sia shuffle che validation_split (se no darebbe errore)
)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dataset = tf.keras.utils.audio_dataset_from_directory(directory='../DL_PROJECT/reduced_dataset/train/audio')
#       2 noise = tf.keras.utils.audio_dataset_from_directory(directory='../DL_PROJECT/noise_dataset', batch_size=1)
#
# File ~/miniconda3/envs/DL/lib/python3.10/site-packages/keras/src/utils/audio_dataset.py:199, in audio_dataset_from_directory(directory, labels, label_mode, class_names, batch_size, sampling_rate, output_sequence_length, ragged, shuffle, seed, validation_split, subset, follow_links)
#     196 if seed is None:
#     197     seed = np.random.randint(1e6)
# --> 199 file_paths, labels, class_names = dataset_utils.index_directory(
#     200     directory,
#     201     labels,
#     202     formats=ALLOWED_FORMATS,
#     203     class_names=class_names,
#     204     shuffle=shuffle,
#     205     seed=seed,
#     206     follow_links=follow_links,
#     207 )
#     209 if label_mode == "binary" and len(class_names) != 2:
#     210     raise ValueError(
#     211         'When passing `label_mode="binary"`, there must be exactly 2 '
#     212         f"class_names. Received: class_names={class_names}"
#     213     )
#
# File ~/miniconda3/envs/DL/lib/python3.10/site-packages/keras/src/utils/dataset_utils.py:542, in index_directory(directory, labels, formats, class_names, shuffle, seed, follow_links)
#     540 else:
#     541     subdirs = []
# --> 542     for subdir in sorted(tf.io.gfile.listdir(directory)):
#     543         if tf.io.gfile.isdir(tf.io.gfile.join(directory, subdir)):
#     544             if not subdir.startswith("."):
#
# File ~/miniconda3/envs/DL/lib/python3.10/site-packages/tensorflow/python/lib/io/file_io.py:768, in list_directory_v2(path)
#     753 """Returns a list of entries contained within a directory.
#     754
#     755 The list is in arbitrary order. It does not contain the special entries "."
#    (...)
#     765   errors.NotFoundError if directory doesn't exist
#     766 """
#     767 if not is_directory(path):
# --> 768   raise errors.NotFoundError(
#     769       node_def=None,
#     770       op=None,
#     771       message="Could not find directory {}".format(path))
#     773 # Convert each element to string, since the return values of the
#     774 # vector of string should be interpreted as strings, not bytes.
#     775 return [
#     776     compat.as_str_any(filename)
#     777     for filename in _pywrap_file_io.GetChildren(compat.path_to_bytes(path))
#     778 ]
#
# NotFoundError: Could not find directory ../DL_PROJECT/reduced_dataset/train/audio

# %%
for n, label in noise:
    print(np.shape(n))
    break
# Out:
# (1, 518400, 1)

# %%
new_n = []

# iteriamo nel dataset con gli audio rumorosi
for n, label  in noise:
    # tagliamo l'audio ad un secondo e lo appendiamo a una lista 
    n = tf.reshape(n, [-1])[600:16600]
    new_n.append(n.numpy()) # convertiamo in array per poterli modificare
    
test_audio = new_n[0].astype(np.float32)
print(np.shape(new_n))
display(Audio(test_audio, rate=16000))
# Out:
# (10, 16000)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Plot the waveform
plt.figure(figsize=(14, 5))
plt.plot(test_audio, color="indianred")
plt.title('Segnale audio di rumore')
plt.ylabel('Ampiezza')
plt.xlabel('Frame #')
plt.grid(True, color="gainsboro", linestyle="--", alpha=0.5)
plt.show()

# %%
mixed_dataset = []

for audio, label in dataset:
    
    audio = audio.numpy()[0]  # convertiamo in array
    
    # Scegliamo in modo randomico un audio dalla lista 00000000000ri
    noise_sample = random.choice(new_n)000
    mixed_audio = audio + noise_sample*0.005 # mo00ltiplichiamo per un valore costante molto piccoli cosi da ridurre il volume del rumore e far sentire meglio l'audio del comando
    
    # appendiamo alla lista mixed dataset
    mixed_dataset.append((mixed_audio, label))
    
# trasformiamo la lista mixed_dataset in un dataset da poter passare ai modelli
mixed_dataset = tf.data.Dataset.from_tensor_slices(mixed_dataset)
