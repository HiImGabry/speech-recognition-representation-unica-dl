# %% [markdown]
# # Modello convolutivo di base
# Lo scopo di questo notebook è creare un **modello convolutivo di base** con un'architettura semplice. In seguito, sarà interessante confrontare i risultati di questo primo modello con i risultati ottenuti da modelli più complessi, o pre addestrati.

# %% [markdown]
# Come al solito, si procede con l'importazione delle librerie utilizzate e la creazione dei set di allenamento e validazione.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd
import numpy as np
import os
import time
# per il modello con estensione .onnx
import onnxruntime as rt
import tf2onnx
import onnx

# %%
train_ds, validation_ds = tf.keras.utils.audio_dataset_from_directory(
    directory='../reduced_dataset/dataset/audio',
    validation_split=0.4, # stiamo mettendo da parte il 40% del dataset, che sarà suddiviso in validation set e test set
    shuffle=True,
    subset='both', # necessario se stiamo utilizzando validation_split (se no darebbe errore)
    seed=0 # necessario se stiamo utilizzando sia shuffle che validation_split (se no darebbe errore)
)

label_names = train_ds.class_names
# Out:
# Found 12933 files belonging to 30 classes.
# Using 7760 files for training.
# Using 5173 files for validation.

# %% [markdown]
# ## Funzioni per processamento dei dati

# %% [markdown]
# La prima funzione che ci tornerà utile è `squeeze(audio, labels)`, della quale abbiamo già visto l'implementazione e parlato del suo utilizzo nel notebook dove trattiamo gli spettrogrammi.

# %%
def squeeze(audio, labels):
    audio = tf.squeeze(audio, axis=-1)
    return audio, labels

# fonte: funzione presa dal seguente link: https://www.geeksforgeeks.org/audio-recognition-in-tensorflow/

# %%
train_ds = train_ds.map(squeeze, tf.data.AUTOTUNE)
validation_ds = validation_ds.map(squeeze, tf.data.AUTOTUNE)

audio, label = next(iter(train_ds))
print(audio.shape)
print(label.shape)
# Out:
# (32, 16000)
# (32,)

# %% [markdown]
# Una volta eseguito questa semplificazione, a partire dai tensori degli audio, creeremo gli spettrogrammi che sarannò presi come input dal modello convolutivo.

# %% [markdown]
# ## Conversione e suddivisione dataset
# Per la conversione del dataset utilizziamo due funzioni che abbiamo già definito nel notebook dove trattiamo gli spettrogrammi.

# %%
def get_spectrogram(waveform):
    spectrogram = tf.signal.stft(waveform, frame_length=255, frame_step=128)
    spectrogram = tf.abs(spectrogram)

    return spectrogram[..., tf.newaxis]

# fonte: tutorial riconoscimento audio semplice di tensorflow: https://www.tensorflow.org/tutorials/audio/simple_audio?hl=it

# %%
def get_spectrogram_dataset(dataset):
    dataset = dataset.map(lambda x, y: (get_spectrogram(x), y), num_parallel_calls=tf.data.AUTOTUNE)

    return dataset

# %% [markdown]
# Definite le due funzioni possiamo procedere a ottenere il nostro **training set**, **validation set**, e **test set** di spettrogrammi. La suddivisione di dati ricordo essere rispettivamente 60%, 20%, 20%.

# %%
train_ds = get_spectrogram_dataset(train_ds)
validation_ds = get_spectrogram_dataset(validation_ds)

val_ds = validation_ds.take(validation_ds.cardinality() // 2) # ho cambiato nome del validation_ds in modo tale da non creare problemi con l'istruzione seguente
test_ds = validation_ds.skip(validation_ds.cardinality() // 2)

# %%
print("Numero di audio training set:", len(train_ds) * 32)
print("Numero di audio validation set:", len(val_ds) * 32)
print("Numero di audio test set:", len(test_ds) * 32)
# Out:
# Numero di audio training set: 7776
# Numero di audio validation set: 2592
# Numero di audio test set: 2592

# %%
for audio, label in train_ds:
    print("Shape (forma) spettrogrammi:", audio.shape)

    spectrogram = np.squeeze(audio[0], axis=-1)
    spectrogram = np.log(spectrogram.T + np.finfo(float).eps)

    plt.imshow(spectrogram.T)
    plt.colorbar(format='%+2.0f dB') # barra laterale dei dB

    plt.title(f"Classe: {label_names[label[0].numpy()]}")
    break
# Out:
# Shape (forma) spettrogrammi: (32, 124, 129, 1)

# %% [markdown]
# La grandezza degli spettrogrammi, quindi delle immagini ottenute, è di **124x129**.

# %% [markdown]
# ## Creazione modello di base

# %% [markdown]
# Come modello implementiamo una rete neurale convolutiva. Questo modello ha un'architettura semplice e servirà da benchmark per i modelli futuri.
#
# La rete prende in ingresso tensori di forma **altezza x larghezza x canali**, rispettivamente di **124, 129, 1**. Per farla lavorare meglio normalizziamo i dati con la funzione `tf.keras.layers.Normalization()`. Questo livello sposta e ridimensiona gli input in una distribuzione centrata su 0 e con deviazione standard 1.

# %% [markdown]
# L'architettura del modello è suddivisa in **due blocchi** principali: un blocco per l'apprendimento delle caratteristiche e un blocco per la classificazione.
#
# Il **blocco di apprendimento delle caratteristiche** ha un'architettura formata da una serie di livelli convolutivi alternati a livelli di max pooling. Per ciascun livello convolutivo viene anche applicata la funzione di attivazione **ReLu** per applicare non linearità. Il blocco termina con un livello convolutivo di **256 filtri**, che corrispondono alla stessa quantità di filtri applicati dal livello convolutivo precedente.
#
# Terminato il blocco di apprendimento delle caratteristiche, è presente il **blocco di classificazione**, formato da un **livello di Flatten**, necessario per trasformare i dati in un vettore unidimensionali, e un **livello Dense**, necessario per la predizione della classe di appartenenza del dato. Quest'ultimo livello Dense ha **30 unità**, che corrispondono alle 30 classi del nostro task di classificazione multiclasse. La funzione di attivazione applicata dal livello Dense è la **softmax**, ideale per i task di classificazione multiclasse.
#
# La funzione **softmax**, a differenza della funzione **sigmoid** ci fornisce una distribuzione di probabilità sulle classi possibili (questa distribuzione saremo in grado di visualizzarla durante la valutazione del modello).

# %%
def get_basic_model():
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(124, 129, 1), name="inputs")
    x = tf.keras.layers.Normalization(name="normalizzazione")(inputs)

    # Blocco di apprendimento delle caratteristiche
    conv2D_1 = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same", name="conv2D_1")(x)
    MaxPooling2D_1 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_1")(conv2D_1)
    conv2D_2 = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same", name="conv2D_2")(MaxPooling2D_1)
    MaxPooling2D_2 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_2")(conv2D_2)
    conv2D_3 = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same", name="conv2D_3")(MaxPooling2D_2)
    MaxPooling2D_3 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_3")(conv2D_3)
    conv2D_4 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_4")(MaxPooling2D_3)
    MaxPooling2D_4 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_4")(conv2D_4)
    conv2D_5 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_5")(MaxPooling2D_4)

    # Blocco di classificazione
    Flatten = tf.keras.layers.Flatten(name="Flatten")(conv2D_5)
    outputs = tf.keras.layers.Dense(30, activation="softmax", name="dense_output")(Flatten)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# Nella prossima cella di codice dichiariamo l'**ottimizzatore** da utilizzare (adam), le **metriche** di cui tenere traccia (accuratezza), e la funzione di perdita da utilizzare per il calcolo del gradiente. Nel nostro caso la **funzione di perdita** corrisponde alla `sparse_categorical_crossentropy`, una variante della `categorical_crossentropy`.
#
# La **sparse categorical crossentropy** viene utilizzata quando le classi sono rappresentate come interi, proprio come nel nostro caso.

# %%
basic_model = get_basic_model()
basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

basic_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inputs (InputLayer)         [(None, 124, 129, 1)]     0
#
#  normalizzazione (Normalizat  (None, 124, 129, 1)      3
#  ion)
#
#  conv2D_1 (Conv2D)           (None, 124, 129, 32)      320
#
#  MaxPooling2D_1 (MaxPooling2  (None, 62, 64, 32)       0
#  D)
#
#  conv2D_2 (Conv2D)           (None, 62, 64, 64)        18496
#
#  MaxPooling2D_2 (MaxPooling2  (None, 31, 32, 64)       0
#  D)
#
#  conv2D_3 (Conv2D)           (None, 31, 32, 128)       73856
#
#  MaxPooling2D_3 (MaxPooling2  (None, 15, 16, 128)      0
#  D)
#
#  conv2D_4 (Conv2D)           (None, 15, 16, 256)       295168
#
#  MaxPooling2D_4 (MaxPooling2  (None, 7, 8, 256)        0
#  D)
#
#  conv2D_5 (Conv2D)           (None, 7, 8, 256)         590080
#
#  Flatten (Flatten)           (None, 14336)             0
#
#  dense_output (Dense)        (None, 30)                430110
#
# =================================================================
# Total params: 1,408,033
# Trainable params: 1,408,030
# Non-trainable params: 3
# _________________________________________________________________

# %% [markdown]
# Il modello ha un totale di circa **1.4 milioni di parametri**, bilanciando complessità e capacità di apprendimento.

# %%
basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/adam/spectrogram/basic_model.keras", save_best_only=True, monitor="val_loss")]
basic_model_history = basic_model.fit(train_ds, epochs=30, validation_data=val_ds, callbacks=basic_model_callbacks)
# Out:
# Epoch 1/30
# 243/243 [==============================] - 6s 13ms/step - loss: 2.3189 - accuracy: 0.3536 - val_loss: 1.2957 - val_accuracy: 0.6300
# Epoch 2/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.9515 - accuracy: 0.7286 - val_loss: 0.8146 - val_accuracy: 0.7639
# Epoch 3/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.5059 - accuracy: 0.8524 - val_loss: 0.7488 - val_accuracy: 0.7986
# Epoch 4/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.3377 - accuracy: 0.8951 - val_loss: 0.8083 - val_accuracy: 0.8333
# Epoch 5/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2301 - accuracy: 0.9278 - val_loss: 0.8504 - val_accuracy: 0.8148
# Epoch 6/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1703 - accuracy: 0.9482 - val_loss: 0.9617 - val_accuracy: 0.8322
# Epoch 7/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1545 - accuracy: 0.9521 - val_loss: 0.8248 - val_accuracy: 0.8410
# Epoch 8/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1249 - accuracy: 0.9637 - val_loss: 0.7750 - val_accuracy: 0.8457
# Epoch 9/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1090 - accuracy: 0.9679 - val_loss: 0.7610 - val_accuracy: 0.8484
# Epoch 10/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0743 - accuracy: 0.9803 - val_loss: 1.1967 - val_accuracy: 0.7994
# Epoch 11/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0870 - accuracy: 0.9745 - val_loss: 1.3235 - val_accuracy: 0.8256
# Epoch 12/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1195 - accuracy: 0.9661 - val_loss: 0.8643 - val_accuracy: 0.8210
# Epoch 13/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0646 - accuracy: 0.9827 - val_loss: 0.8941 - val_accuracy: 0.8403
# Epoch 14/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0989 - accuracy: 0.9729 - val_loss: 1.0301 - val_accuracy: 0.8364
# Epoch 15/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0682 - accuracy: 0.9816 - val_loss: 1.1169 - val_accuracy: 0.8495
# Epoch 16/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.0605 - accuracy: 0.9847 - val_loss: 1.3812 - val_accuracy: 0.8302
# Epoch 17/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0652 - accuracy: 0.9822 - val_loss: 1.5635 - val_accuracy: 0.8360
# Epoch 18/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0657 - accuracy: 0.9827 - val_loss: 1.0673 - val_accuracy: 0.8530
# Epoch 19/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0256 - accuracy: 0.9928 - val_loss: 1.0912 - val_accuracy: 0.8708
# Epoch 20/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0557 - accuracy: 0.9869 - val_loss: 1.1390 - val_accuracy: 0.8241
# Epoch 21/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0656 - accuracy: 0.9820 - val_loss: 1.2521 - val_accuracy: 0.8233
# Epoch 22/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0688 - accuracy: 0.9813 - val_loss: 0.9974 - val_accuracy: 0.8387
# Epoch 23/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0598 - accuracy: 0.9840 - val_loss: 1.2142 - val_accuracy: 0.8337
# Epoch 24/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0229 - accuracy: 0.9933 - val_loss: 1.1978 - val_accuracy: 0.8557
# Epoch 25/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0460 - accuracy: 0.9884 - val_loss: 1.2978 - val_accuracy: 0.8029
# Epoch 26/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0638 - accuracy: 0.9840 - val_loss: 1.1954 - val_accuracy: 0.8283
# Epoch 27/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0588 - accuracy: 0.9861 - val_loss: 1.3456 - val_accuracy: 0.8410
# Epoch 28/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0404 - accuracy: 0.9905 - val_loss: 1.1585 - val_accuracy: 0.8588
# Epoch 29/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0419 - accuracy: 0.9890 - val_loss: 1.1850 - val_accuracy: 0.8218
# Epoch 30/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0366 - accuracy: 0.9906 - val_loss: 1.2548 - val_accuracy: 0.8465

# %% [markdown]
# Alleniamo il modello per 30 epoche e visualizziamo le **curve di addestramento** e **validazione**.
#
# In modo tale da poter accedere ai dati del modello più facilmente in futuro trasformiamo la cronologia del modello in un dataframe pandas. Questo facilità anche al visualizzazione dei dati salvati per un caso futuro.

# %%
def convert_history_to_csv(model_history):
    # converto la history del dataframe in un dataframe pandas
    model_history_df = pd.DataFrame(model_history.history)
    # cambio il nome dell'indice e lo imposto a partire da 1
    model_history_df.index = range(1, len(model_history_df) + 1)
    model_history_df.index.name = "epochs"

    return model_history_df

# %% [markdown]
# Salviamo i dati della history del modello in un file csv.

# %%
basic_model_history_df = convert_history_to_csv(basic_model_history)
basic_model_history_df.to_csv("model_histories/adam/spectrogram/basic_model_history.csv")

# %% [markdown]
# Salviamo il miglior modello come file csv nella directory `model_histories/adam/spectrogram/` con il nome `basic_model_history`. Inoltre, per prevenire errori di salvataggio casuati da versioni differenti di python o dei pacchetti, procediamo con la conversione del file in formato standard `.onnx`.

# %% [markdown]
# Per eseguire la conversione utilizzeremo le librerie **tf2onnx** e **onnx**, importate precedentemente.

# %%
def convert_model_to_onnx(model_path, input_shape):
    model = tf.keras.models.load_model(model_path)

    onnx_path = model_path.split(".")[:-1] + ["onnx"]
    onnx_path = ".".join(onnx_path)
    
    input_signature = [tf.TensorSpec((None, *input_shape), tf.float32, name="input")]
    onnx_model, _ = tf2onnx.convert.from_keras(model, input_signature=input_signature)

    onnx.save(onnx_model, onnx_path)

# %%
convert_model_to_onnx("bestmodels/adam/spectrogram/basic_model.keras", (124, 129, 1))

# %% [markdown]
# Utilizziamo la funzione `create_train_val_plot` per mostrare l'andamento dell'accurateza e della perdita durante l'addestramento.

# %%
def create_train_val_plot(history, overfit=True):
    # definisco numero epoche
    epochs = range(1, len(history['accuracy']) + 1)

    # Accuracy
    accuracy = history['accuracy']
    val_accuracy = history['val_accuracy']

    fig_acc, ax_acc = plt.subplots()

    # linea di base
    ax_acc.plot(epochs, [0.5 for x in range(len(epochs))], color="lightgray", linestyle="--", label="Base")
    # linee di accuratezza
    ax_acc.plot(epochs, accuracy, color="slategray", label="Accuratezza in addestramento")
    ax_acc.plot(epochs, val_accuracy, color="indianred", label="Accuratezza in validazione")
    # miglior accuratezza validazione
    ax_acc.axhline(y=max(val_accuracy), c='indianred', alpha=0.7, linestyle='--')
    ax_acc.text(len(epochs) * 1.07, max(val_accuracy), round(max(val_accuracy), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_acc.spines["right"].set_visible(False)
    ax_acc.spines["top"].set_visible(False)
    ax_acc.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_acc.set_title("Accuratezza in addestramento e validazione")
    ax_acc.set_xlabel("Epoche")
    ax_acc.set_ylabel("Accuratezza (%)")
    ax_acc.legend()

    # Loss
    loss = history['loss']
    val_loss = history['val_loss']

    fig_loss, ax_loss = plt.subplots()

    # linee di loss
    ax_loss.plot(epochs, loss, color="slategray", label="Perdita in addestramento")
    ax_loss.plot(epochs, val_loss, color="indianred", label="Perdita in validazione")
    # miglior loss validazione
    ax_loss.axhline(y=min(val_loss), c='indianred', alpha=0.7, linestyle='--')
    ax_loss.text(len(epochs) * 1.07, min(val_loss), round(min(val_loss), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_loss.spines["right"].set_visible(False)
    ax_loss.spines["top"].set_visible(False)
    ax_loss.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_loss.set_title("Perdita in addestramento e validazione")
    ax_loss.set_xlabel("Epoche")
    ax_loss.set_ylabel("Perdita")

    handles, _ = ax_loss.get_legend_handles_labels()

    if overfit:
        # area overfit
        rect = mpatches.Rectangle((np.argmin(val_loss) + 1, 0), width=100 - np.argmin(val_loss), height=max(max(loss), max(val_loss)), color='lightcoral', alpha=0.3)
        ax_loss.add_patch(rect)
        # patch overfit per legenda
        overfit = mpatches.Patch(color='indianred', alpha=0.3, label='Area overfit')
        handles, _ = ax_loss.get_legend_handles_labels()
        handles.append(overfit)

    # legenda
    ax_loss.legend(handles=handles)

    plt.show()

# %%
create_train_val_plot(basic_model_history.history)

# %% [markdown]
# Questi grafici mostrano come il nostro modello sia andato immediatamente in overfitting. L'accuratezza dell'addestramento aumenta col tempo e raggiunge quasi il **100%**, mentre l'accuratezza della validazione si attesta sull'**85%** con un **picco del 87%**. La **perdita nel set di addestramento** continua a diminuire dopo la **quinta epoca**, mentre la **perdita nel set di validazione** aumenta.

# %% [markdown]
# Possiamo verificare l'accuratezza della migliore versione del nostro modello di base ricaricando il file **basic_model.keras**

# %%
best_basic_model = tf.keras.models.load_model("bestmodels/adam/spectrogram/basic_model.keras")
test_loss, test_acc = best_basic_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 6ms/step - loss: 0.7877 - accuracy: 0.7885
# Accuratezza: 0.788

# %% [markdown]
# Oppure possiamo verificarla con il file **basic_model.onnx**

# %%
def evaluate_onnx_model(path_model_onnx, test_ds):
    # il fatto che sia suddiviso in batch mi crea problemi, perciò lo risolvo togliendoli
    test_ds = test_ds.unbatch()
    
    # carico il modello utilizzando il file onnx
    m = rt.InferenceSession(path_model_onnx)
    
    # trasformo il dataset in array numpy
    spectrogram_np = np.array([spectrogram.numpy() for spectrogram, _ in test_ds])
    labels_np = np.array([label.numpy() for _, label in test_ds])
    
    # eseguo le predizione del modello
    pred_onnx = m.run(None, {'input': spectrogram_np})
    # ottengo la predizione corretta
    predictions = np.argmax(pred_onnx[0], axis=1)
    # computo la accuratezza
    accuracy = np.mean(predictions == labels_np)
    # stampo l'accuratezza
    print(f"Accuratezza: {accuracy:.3f}")

# %%
evaluate_onnx_model("bestmodels/adam/spectrogram/basic_model.onnx", test_ds)
# Out:
# Accuratezza: 0.788

# %% [markdown]
# Abbiamo ottenuto un'**accuratezza** del **78.8%**! Lo riteniamo un ottimo risultato considerato il task non banale.

# %% [markdown]
# Come ultimo, creiamo una funzione utile a visualizzare graficamente la distribuzione di accuratezza delle classi su un'immagine casuale, per capire come ha lavorato il modello. Nel caso il modello non predica correttamente, la **classe corretta** verrà sempre evidenziata di **verde**, mentre la **classe predetta** verrà evidenziata di **giallo**.

# %%
def create_distribution_plot(model, audio, label):
    prediction = model(audio) # otteniamo la predizione del modello sull'audio preso in input

    random_audio_index = np.random.randint(0, len(prediction) - 1) # abbiamo notato che mostravamo sempre la classe no, magari così cambia un po' le classi che mostriamo

    softmax_pred = tf.nn.softmax(prediction[random_audio_index]) # dobbiamo applicare nuovamente la softmax in modo tale da avere dei dati leggibili
    pred_label = np.argmax(softmax_pred) # ci salviamo l'indice della label predetta dal nostro modello, quella con la probabilità più alta

    colors = ['indianred'] * len(label_names) # creiamo un vettore di lunghezza 30 (la quantità delle nostre label) colorate di rosso

    if pred_label == label[random_audio_index].numpy(): # se la label che abbiamo predetto è corretta, allora la coloriamo di verde
        colors[pred_label] = 'seagreen'
    else: # se la label che abbiamo predetto è sbagliata, allora coloriamo di verde la corretta e di gialla la predetta
        colors[pred_label] = 'khaki'
        colors[label[random_audio_index].numpy()] = 'seagreen'

    plt.figure(figsize=(12, 4))

    plt.bar(label_names, softmax_pred.numpy(), color=colors)
    plt.xticks(rotation=45)

    # dichiariamo i colori della legenda
    other_values_patch = mpatches.Patch(color='indianred', label='Altre classi')
    pred_value_patch = mpatches.Patch(color='khaki', label='Classe predetta')
    correct_value_patch = mpatches.Patch(color='green', label='Classe corretta')

    # disegniamo al legenda con i colori necessari
    if pred_label == label[random_audio_index].numpy(): # se abbiamo predetto correttamente la label, non è necessario mostrare il colore giallo (non è presente nel plot)
        plt.legend(handles=[other_values_patch, correct_value_patch])
    else:
        plt.legend(handles=[other_values_patch, pred_value_patch, correct_value_patch])

    plt.show()

# %%
for audio, label in test_ds: # prendiamo un audio a caso del test e creiamo la distribuzione
    create_distribution_plot(best_basic_model, audio, label)
    break

# %% [markdown]
# Possiamo notare dalla distribuzione che il modello in questo caso ha predetto correttamente la **classe cat**.

# %% [markdown]
# ## Risoluzione dell'overfitting
# Abbiamo capito che il modello è andato immediatamente in **overfitting**, e lo possiamo notare dalla loss di validazione che inizia a salire dalla quinta epoca in poi. L'obbiettivo principale in questo momento è evitare che vada in overfitting troppo velocemente, applicando le tecniche viste a lezione.

# %% [markdown]
# Attualmente per ridurre l'overfitting applichiamo **un livello di Dropout**. Il livello di dropout imposta **randomicamente** delle attivazioni a 0, perciò stiamo disattivando qualche neurone. Nello specifico stiamo **azzerando** un certo numero di caratteristiche di uscita dello strato Dense. L'idea dietro questa tecnica è quella di mettere in difficoltà il modello.

# %%
def get_improved_basic_model():
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(124, 129, 1))
    x = tf.keras.layers.Normalization()(inputs)

    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
improved_basic_model = get_improved_basic_model()
improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/adam/spectrogram/improved_basic_model.keras", save_best_only=True, monitor="val_loss")]
improved_history = improved_basic_model.fit(train_ds, epochs=100, validation_data=val_ds, callbacks=improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 3s 11ms/step - loss: 2.5563 - accuracy: 0.2763 - val_loss: 1.5039 - val_accuracy: 0.5702
# Epoch 2/100
# 243/243 [==============================] - 3s 11ms/step - loss: 1.2336 - accuracy: 0.6473 - val_loss: 0.9743 - val_accuracy: 0.7369
# Epoch 3/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.7404 - accuracy: 0.7835 - val_loss: 0.7043 - val_accuracy: 0.7955
# Epoch 4/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0
100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0424 - accuracy: 0.9903 - val_loss: 1.4660 - val_accuracy: 0.8927
# Epoch 98/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0799 - accuracy: 0.9851 - val_loss: 1.1818 - val_accuracy: 0.8908
# Epoch 99/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0267 - accuracy: 0.9923 - val_loss: 1.2229 - val_accuracy: 0.8870
# Epoch 100/100
# 243/243 [==============================] - 5s 18ms/step - loss: 0.0431 - accuracy: 0.9910 - val_loss: 1.1179 - val_accuracy: 0.8858

# %% [markdown]
# Salviamo come prima la history del modello in un file csv.

# %%
improved_history_df = convert_history_to_csv(improved_history)
improved_history_df.to_csv("model_histories/adam/spectrogram/improved_history.csv")

# %% [markdown]
# Salviamo nuovamente il miglior modello anche nel formato **.onnx**.

# %%
convert_model_to_onnx("bestmodels/adam/spectrogram/improved_basic_model.keras", (124, 129, 1))

# %%
create_train_val_plot(improved_history.history)

# %% [markdown]
# Alleniamo il modello per 100 epoche e visualizziamo le **curve di addestramento** e **validazione**.
#
# L'obbiettivo di ridurre **l'overfitting è stato comunque raggiunto**, dato che il modello andato in overfitting leggermente dopo, circa **all'epoca 10**, ma dobbiamo sicuramente applicare qualche altra tecnica per migliorarlo ulteriormente.

# %%
improved_best_model = tf.keras.models.load_model("bestmodels/adam/spectrogram/improved_basic_model.keras")
test_loss, test_acc = improved_best_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 7ms/step - loss: 0.6549 - accuracy: 0.8555
# Accuratezza: 0.855

# %% [markdown]
# Verifichiamola anche con il modello **.onnx**

# %%
evaluate_onnx_model("bestmodels/adam/spectrogram/improved_basic_model.onnx", test_ds)
# Out:
# Accuratezza: 0.855

# %% [markdown]
# Abbiamo ottenuto un buon miglioramento dell'accuratezza, attualmente siamo a quota **85.5%**!

# %%
for audio, label in test_ds:
    create_distribution_plot(improved_best_model, audio, label)
    break

# %% [markdown]
# In questo caso il modello NON è stato in grado di predirre la classe corretta **bed**.

# %% [markdown]
# ### Fine tuning
#
# Gli **iperparametri** sono le variabili che governano il processo di addestramento e la topologia di un modello. Queste rimangono costanti durante l'allenamento e influenzano direttamente le prestazioni.

# %% [markdown]
# Per scegliere un insieme ottimale di iperparametri, abbiamo sviluppato una funzione `tuner`, alla quale passiamo come argomenti una lista di filtri, una lista di tassi di apprendimento, un totale massimo di epoche ed i set di dati su cui si vuole fare l'allenamento.
#
# Questa funzione implementa un **ipermodello**, il quale viene addestrato con varie combinazioni di filtri e tassi di apprendimento, salva i risultati in un file csv e resitituisce le corrispondenze migliori. Queste informazioni sono utili sia per determinare la struttura ottimale del modello da implementare, sia per identificare le combinazioni utilizzate nei modelli precedenti, a fronte del fatto che fino ad ora abbiamo sempre usato dei tassi di apprendimento dinamici.
#
# Per usare questa funzione dobbiamo prima definire un **ipermodello**, ovvero l'architettura del modello su cui vogliamo eseguire i test per trovare gli iperparametri più consoni. Esso è implementato attraverso la funzione `get_improved_basic_model_tuning`, che iterando una lista di filtri adatta le dimensioni degli output degli strati convolutivi.

# %%
def get_improved_basic_model_tuning(start_filters):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(124, 129, 1))
    x = tf.keras.layers.Normalization()(inputs)

    if not isinstance(start_filters, int):
        raise Exception("start_filters must be type integer")

    filters = [start_filters * (2 ** i) for i in range(4)]
    
    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=filters[0], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[1], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[2], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[3], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[3], kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# Più nello specifico, la funzione tuner utilizza una callback di tipo EarlyStopping che monitora la perdita sul set di validazione con una pazienza di 5. Questo significa che il modello viene interrotto se la perdita di validazione non diminuisce entro 5 epoche dalla sua minima.
#
# Questa implementazione è utile per risparmiare tempo con i modelli che cessano di migliorare precocemente le loro prestazioni.

# %%
def tuner(filters, learning_rates, max_epochs, train_dataset, validation_dataset):
    start_time = time.time()

    counter = 1
    
    if not isinstance(filters, list):
        raise Exception("parameter filters must be type list")

    if not isinstance(learning_rates, list):
        raise Exception("parameter learning_rates must be type list")

    callbacks = [tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5)]

    best_learning_rate = 0 
    best_filters = 0
    best_val_accuracy = 0

    best_model = 0
    
    for f in filters:
        for lr in learning_rates:
            print(f"\nAddestramndo con filtri {[f * (2 ** i) for i in range(4)]} e tasso di apprendimento {lr}")
            
            model = get_improved_basic_model_tuning(start_filters=f)
            model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=lr), metrics=["accuracy"])
            model_history = model.fit(train_dataset, epochs=max_epochs, validation_data=validation_dataset, callbacks=callbacks)

            model_history_df = convert_history_to_csv(model_history)

            model_history_df[["filters"]] = f
            model_history_df[["learning_rate"]] = lr
            
            path = "model_tuning/adam/spectrogram/model_" + str(counter) + ".csv"
            model_history_df.to_csv(path)
            
            if best_val_accuracy < model_history_df.iloc[-1]["val_accuracy"]:
                best_val_accuracy = model_history_df.iloc[-1]["val_accuracy"]
                best_filters = f
                best_learning_rate = lr
                epoch = len(model_history_df)

            del model

            counter += 1

    total_time = time.time() - start_time
    minutes, seconds = divmod(total_time, 60)
    print(f"\nTempo totale trascorso: {int(minutes)} minuti e {int(seconds)} secondi")
    # print(f"Il miglior modello ha un filtro di partenza pari a {best_filters}, un learning rate pari a {best_learning_rate} con un'accuracy pari a {best_val_accuracy:.3f}")

    return best_filters, best_learning_rate

# %%
best_filter, best_learning_rate = tuner([16, 32, 64], [1e-3, 1e-4, 1e-5], 30, train_ds, val_ds)
# Out:
# Addestramndo con filtri [16, 32, 64, 128] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 3s 9ms/step - loss: 2.5956 - accuracy: 0.2670 - val_loss: 1.6665 - val_accuracy: 0.5312
# Epoch 2/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.3577 - accuracy: 0.6119 - val_loss: 1.0664 - val_accuracy: 0.7052
# Epoch 3/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.8976 - accuracy: 0.7423 - val_loss: 0.8873 - val_accuracy: 0.7735
# Epoch 4/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.6369 - accuracy: 0.8164 - val_loss: 0.7055 - val_accuracy: 0.7967
# Epoch 5/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.4768 - accuracy: 0.8555 - val_loss: 0.6460 - val_accuracy: 0.8329
# Epoch 6/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.3767 - accuracy: 0.8856 - val_loss: 0.6764 - val_accuracy: 0.8387
# Epoch 7/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.3407 - accuracy: 0.8925 - val_loss: 0.6630 - val_accuracy: 0.8295
# Epoch 8/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.2674 - accuracy: 0.9168 - val_loss: 0.6483 - val_accuracy: 0.8410
# Epoch 9/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.2339 - accuracy: 0.9293 - val_loss: 0.9322 - val_accuracy: 0.8380
# Epoch 10/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.
30
# 243/243 [==============================] - 6s 23ms/step - loss: 0.8481 - accuracy: 0.7897 - val_loss: 1.2529 - val_accuracy: 0.7461
#
# Tempo totale trascorso: 10 minuti e 24 secondi

# %% [markdown]
# Il tempo necessario per la ricerca dei migliori iperparametri è stata di quasi 10 minuti.

# %% [markdown]
# Grazie alla funzione `plot_models`, possiamo visualizzare l'accuratezza e la perdita di tutti i modelli che il tuner ha addestrato. Questa funzione adatta automaticamente il grafico al numero di modelli addestrati (in questo caso 9).

# %%
def plot_models(path, reverse=False, show="accuracy", overfit=True):
    n_models = len(os.listdir(path))
    # creo il subplot a seconda di quanti modelli dispongo
    best_pair = None
    min_diff = float("inf")
    
    for idx_model in range(1, int(np.sqrt(n_models)) + 1):
        if n_models % idx_model == 0:
            diff = abs(idx_model - n_models // idx_model)

            if diff < min_diff:
                min_diff = diff
                best_pair = (idx_model, n_models // idx_model)

    if reverse:
        rows = best_pair[1]
        cols = best_pair[0]
    else:
        rows = best_pair[0]
        cols = best_pair[1]
    
    fig, axes = plt.subplots(rows, cols, figsize=(14, 10))
    
    for index, model in enumerate(os.listdir(path)):
        row = index // cols
        col = index % cols
    
        ax = axes[row][col]
        
        newpath = path + "/" + model
        df = pd.read_csv(newpath)

        value1 = df[show].values
        value2 = df["val_" + show].values
        
        ax.plot(range(1, len(value1) + 1), value1, color="slategray", label="Addestramento")
        ax.plot(range(1, len(value2) + 1), value2, color="indianred", label="Validazione")

        if (row in range(rows)) and col == 0:
            ax.set_ylabel("Accuratezza (%)" if show == "accuracy" else "Perdita", fontweight="semibold", fontsize=10)

        if (col in range(cols)) and row == 2:
            ax.set_xlabel("Epoche", fontweight="semibold", fontsize=10)

        ax.set_title("Filtro " + str(df["filters"][0]) + " & lr " + str(df["learning_rate"][0]), fontsize=12)
            
        ax.set_ylim(0)
        ax.set_xlim(0)

        ax.spines["left"].set_visible(False)
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)

        ax.grid(True, color="gainsboro", alpha=0.3, linestyle="--")

        handles, _ = ax.get_legend_handles_labels()
        
        if overfit and show == "loss":
            # area overfit
            
            rect = mpatches.Rectangle((np.argmin(value2) + 1, 0), width=len(value1) - np.argmin(value2), height=max(max(value1), max(value2)), color='lightcoral', alpha=0.3)
            ax.add_patch(rect)
            # patch overfit per legenda
            overfit = mpatches.Patch(color='lightcoral', alpha=0.3, label='Area overfit')
           
            handles.append(overfit)

        ax.legend(handles=handles)

    plt.subplots_adjust(wspace=0.3, hspace=0.3)
    plt.show()

# %%
plot_models(path="model_tuning/adam/spectrogram", show="accuracy")
plot_models(path="model_tuning/adam/spectrogram", show="loss")

# %% [markdown]
# Dai grafici emerge che la combinazione più performante è composta da **32 filtri di partenza** e un **tasso di apprendimento di 1e-5**, poiché ritarda maggiormente l'overfitting. Altre combinazioni, come **64 filtri di partenza** e un **tasso di apprendimento di 1e-5**, mostrano buone prestazioni ma anche un inizio di overfitting, evidenziato dallo distaccamento tra la perdita di addestramento e quella di validazione.
#
# Procediamo quindi con l'addestramento del modello con **32 filtri di partenza** e un **tasso di apprendimento di 1e-5**. Come di consueto, salviamo i risultati in un file `keras` e la cronologia (history) in un file `csv`. Infine, convertiamo il file in formato `onnx`.

# %%
tuned_improved_basic_model = get_improved_basic_model()
tuned_improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5), metrics=["accuracy"])

# %%
tuned_improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/adam/spectrogram/tuned_improved_basic_model.keras", save_best_only=True, monitor="val_loss")]
tuned_improved_history = tuned_improved_basic_model.fit(train_ds, epochs=100, validation_data=val_ds, callbacks=tuned_improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] -
100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.4355 - accuracy: 0.8790 - val_loss: 1.1447 - val_accuracy: 0.7870
# Epoch 91/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.4469 - accuracy: 0.8795 - val_loss: 1.1515 - val_accuracy: 0.7847
# Epoch 92/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.4402 - accuracy: 0.8793 - val_loss: 1.1521 - val_accuracy: 0.7855
# Epoch 93/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.4315 - accuracy: 0.8834 - val_loss: 1.1785 - val_accuracy: 0.7840
# Epoch 94/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.4137 - accuracy: 0.8856 - val_loss: 1.1742 - val_accuracy: 0.7917
# Epoch 95/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.4248 - accuracy: 0.8861 - val_loss: 1.1800 - val_accuracy: 0.7897
# Epoch 96/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.4150 - accuracy: 0.8862 - val_loss: 1.1644 - val_accuracy: 0.7878
# Epoch 97/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.4082 - accuracy: 0.8885 - val_loss: 1.1545 - val_accuracy: 0.7951
# Epoch 98/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.3945 - accuracy: 0.8924 - val_loss: 1.1628 - val_accuracy: 0.7897
# Epoch 99/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.3982 - accuracy: 0.8907 - val_loss: 1.1719 - val_accuracy: 0.7924
# Epoch 100/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.3934 - accuracy: 0.8921 - val_loss: 1.1996 - val_accuracy: 0.7886

# %%
tuned_improved_history_df = convert_history_to_csv(tuned_improved_history)
tuned_improved_history_df.to_csv("model_histories/adam/spectrogram/tuned_improved_history.csv")

# %%
convert_model_to_onnx("bestmodels/adam/spectrogram/tuned_improved_basic_model.keras", (124, 129, 1))

# %%
create_train_val_plot(tuned_improved_history.history)

# %%
tuned_improved_best_model = tf.keras.models.load_model("bestmodels/adam/spectrogram/tuned_improved_basic_model.keras")
test_loss, test_acc = tuned_improved_best_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 4ms/step - loss: 1.2145 - accuracy: 0.7691
# Accuratezza: 0.769

# %%
evaluate_onnx_model("bestmodels/adam/spectrogram/tuned_improved_basic_model.onnx", test_ds)
# Out:
# Accuratezza: 0.769

# %% [markdown]
# Il modello ha registrato un insignificante miglioramento rispetto a prima, tuttavia è stato osservato un leggero ritardo nell'insorgere dell'overfitting. Inoltre, la perdita non è peggiorata tanto quanto in precedenza con l'avanzare delle epoche. L'accuratezza è attualmente **76.9%**.

# %%
for audio, label in test_ds:
    create_distribution_plot(tuned_improved_best_model, audio, label)
    break

# %% [markdown]
# ## Miglioramenti all'architettura del modello
#
# Durante il corso abbiamo visto anche delle best practice architetturali che possono aiutare a ottenere maggiori prestazioni col modello. Il nostro scopo è provare le tecniche viste e studiate durante il corso e capire come reagiscono al task.

# %% [markdown]
# Le tre tecniche che andremo ad applicare sono:
# - blocchi residuali
# - normalizzazione dei batch
# - convoluzioni separabili

# %% [markdown]
# ### Blocchi residuali
# I blocchi residuali sono un'applicazione efficace quando riscontriamo il problema dei **gradienti che svaniscono**. Non sono una tecnica strettamente legata ai modelli convolutivi, ma sono una best practice generale che viene applicare nella maggior parte delle architetture.
#
# I **gradienti che vaniscono** sono causati dalle **catene di funzioni troppo lunghe**, che nel nostro caso non sono altro che **una sequenza di livelli convolutivi**. Per ogni livello convolutivo **una certa quantità di rumore** viene introdotta, finché essa non arriva a **sopraffare** le informazioni sul gradiente.
#
# Se le informazioni sul gradiente sono sopraffatte la **backpropagation smette di funzionare**, e quindi il nostro **modello non impara**.

# %% [markdown]
# L'**idea basilare** dietro ai blocchi residuali è quella di **salvare l'informazione** contenuta nell'input precedente al livello convolutivo, e **sommarla all'output** dello stesso livello convolutivo.

# %% [markdown]
# Per applicare i blocchi residuali abbiamo implementato la funzione `residual_block(x, filters, pooling=False)` vista a lezione. La funzione è stata adattata al modello da noi implementato, e utilizza le altre due best practice citate precedentemente.

# %%
def residual_block(x, filters, pooling=False):
    residual = x

    x = tf.keras.layers.SeparableConv2D(filters, 3, padding="same", use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    if pooling:
      x = tf.keras.layers.MaxPooling2D(pool_size=2, padding="same")(x)
      residual = tf.keras.layers.Conv2D(filters, 1, strides=2)(residual)
    elif filters != residual.shape[-1]:
      residual = tf.keras.layers.Conv2D(filters, 1)(residual)

    x = tf.keras.layers.add([x, residual])
    return x

# %% [markdown]
# ### Normalizzazione dei batch e convoluzioni separabili
# La **normalizzazione dei batch** è un concetto che abbiamo già affrontato nel notebook, infatti il suo scopo rimane quello di rendere i dati **più simili tra loro** centrandoli sullo zero, e ciò aiuta la **propagazione del gradiente**. Questa normalizzazione, a differenza della precedente, è in grado di normalizzare i dati in modo adattivo anche quando la media e la varianza cambiano durante l'addestramento.

# %% [markdown]
# Le **convoluzione separabili** invece sono un **sostituto** ai livelli convolutivi utilizzati fino ad adesso, e offrono un modello con maggiori prestazioni e meno parametri.

# %%
def bp_basic_model():
    # input e pre processamento
    inputs = tf.keras.Input(shape=(124, 129, 1))
    
    x = residual_block(inputs, 32, pooling=True)
    x = residual_block(x, 64, pooling=True)
    x = residual_block(x, 128, pooling=True)
    x = residual_block(x, 256, pooling=True)
    x = residual_block(x, 256, pooling=False)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Livelli per la classificazione
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
bp_basic_model = bp_basic_model()
bp_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

bp_basic_model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_12 (InputLayer)          [(None, 124, 129, 1  0           []
#                                 )]
#
#  separable_conv2d (SeparableCon  (None, 124, 129, 32  41         ['input_12[0][0]']
#  v2D)                           )
#
#  batch_normalization (BatchNorm  (None, 124, 129, 32  128        ['separable_conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 124, 129, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d_44 (MaxPooling2D  (None, 62, 65, 32)  0           ['activation[0][0]']
#  )
#
#  conv2d_55 (Conv2D)             (None, 62, 65, 32)   64          ['input_12[0][0]']
#
#  add (Add)                      (None, 62, 65, 32)   0           ['max_pooling2d_44[0][0]',
#                                                                   'conv2d_55[0][0]']
#
#  separable_conv2d_1 (SeparableC  (None, 62, 65, 64)  2336        ['add[0][0]']
#  onv2D)
#
#  batch_normalization_1 (BatchNo  (None, 62, 65, 64)  256         ['separable_conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 62, 65, 64)   0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d_45 (MaxPooling2D  (None, 31, 33, 64)  0           ['activation_1[0][0]']
#  )
#
#  conv2d_56 (Conv2D)             (None, 31, 33, 64)   2112        ['add[0][0]']
#
#  add_1 (Add)                    (None, 31, 33, 64)   0           ['max_pooling2d_45[0][0]',
#                                                                   'conv2d_56[0][0]']
#
#  separable_conv2d_2 (SeparableC  (None, 31, 33, 128)  8768       ['add_1[0][0]']
#  onv2D)
#
#  batch_normalization_2 (BatchNo  (None, 31, 33, 128)  512        ['separable_conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 31, 33, 128)  0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_46 (MaxPooling2D  (None, 16, 17, 128)  0          ['activation_2[0][0]']
#  )
#
#  conv2d_57 (Conv2D)             (None, 16, 17, 128)  8320        ['add_1[0][0]']
#
#  add_2 (Add)                    (None, 16, 17, 128)  0           ['max_pooling2d_46[0][0]',
#                                                                   'conv2d_57[0][0]']
#
#  separable_conv2d_3 (SeparableC  (None, 16, 17, 256)  33920      ['add_2[0][0]']
#  onv2D)
#
#  batch_normalization_3 (BatchNo  (None, 16, 17, 256)  1024       ['separable_conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 16, 17, 256)  0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_47 (MaxPooling2D  (None, 8, 9, 256)   0           ['activation_3[0][0]']
#  )
#
#  conv2d_58 (Conv2D)             (None, 8, 9, 256)    33024       ['add_2[0][0]']
#
#  add_3 (Add)                    (None, 8, 9, 256)    0           ['max_pooling2d_47[0][0]',
#                                                                   'conv2d_58[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 8, 9, 256)   67840       ['add_3[0][0]']
#  onv2D)
#
#  batch_normalization_4 (BatchNo  (None, 8, 9, 256)   1024        ['separable_conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 8, 9, 256)    0           ['batch_normalization_4[0][0]']
#
#  add_4 (Add)                    (None, 8, 9, 256)    0           ['activation_4[0][0]',
#                                                                   'add_3[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['add_4[0][0]']
#  alAveragePooling2D)
#
#  dropout_11 (Dropout)           (None, 256)          0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_11 (Dense)               (None, 30)           7710        ['dropout_11[0][0]']
#
# ==================================================================================================
# Total params: 167,079
# Trainable params: 165,607
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %% [markdown]
# Le best practice, insieme al `tf.keras.layers.GlobalAveragePooling2D()` applicato al posto del Flatten, hanno formato un modello con circa **160000 parametri addestrabili** (circa il 12% del modello precedente).

# %%
bp_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/adam/spectrogram/bp_basic_model.keras", save_best_only=True, monitor="val_loss")]
bp_model_history = bp_basic_model.fit(train_ds, epochs=100, validation_data=val_ds, callbacks=bp_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 6s 23ms/step - loss: 3.2093 - accuracy: 0.1178 - val_loss: 3.3977 - val_accuracy: 0.0401
# Epoch 2/100
# 243/243 [==============================] - 5s 22ms/step - loss: 2.6248 - accuracy: 0.2634 - val_loss: 2.7321 - val_accuracy: 0.2234
# Epoch 3/100
# 243/243 [==============================] - 5s 21ms/step - loss: 2.1292 - accuracy: 0.4113 - val_loss: 2.0222 - val_accuracy: 0.4279
# Epoch 4/100
# 243/243 [==============================] - 5s 22ms/step - loss: 1.5991 - accuracy: 0.5800 - val_loss: 1.4719 - val_accuracy: 0.5702
# Epoch 5/100
# 243/243 [==============================] - 5s 22ms/step - loss: 1.2511 - accuracy: 0.6716 - val_loss: 1.2178 - val_accuracy: 0.6435
# Epoch 6/100
# 243/243 [==============================] - 6s 23ms/step - loss: 0.9853 - accuracy: 0.7461 - val_loss: 1.0186 - val_accuracy: 0.7126
# Epoch 7/100
# 243/243 [==============================] - 6s 22ms/step - loss: 0.8249 - accuracy: 0.7827 - val_loss: 0.9996 - val_accuracy: 0.6998
# Epoch 8/100
# 243/243 [==============================] - 6s 22ms/step - loss: 0.7153 - accuracy: 0.8093 - val_loss: 0.9269 - val_accuracy: 0.7276
# Epoch 9/100
# 243/243 [==============================] - 6s 22ms/step - loss: 0.6176 - accuracy: 0.8393 - val_loss: 0.7993 - val_accuracy: 0.7774
# Epoch 10/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.5697 - accuracy: 0.8523 - val_loss: 0.7383 - val_accuracy: 0.7994
# Epoch 11/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.5007 - accuracy: 0.8606 - val_loss: 0.8688 - val_accuracy: 0.7523
# Epoch 12/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.4460 - accuracy: 0.8754 - val_loss: 0.6428 - val_accuracy: 0.8260
# Epoch 13/100
# 243/243 [==============================] - 6s 22ms/step - loss: 0.4196 - accuracy: 0.8869 - val_loss: 0.5787 - val_accuracy: 0.8438
# Epoch 14/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.3721 - accuracy: 0.9006 - val_loss: 0.7858 - val_accuracy: 0.7677
# Epoch 15/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.3566 - accuracy: 0.9028 - val_loss: 0.6177 - val_accuracy: 0.8206
# Epoch 16/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.3195 - accuracy: 0.9152 - val_loss: 0.6163 - val_accuracy: 0.8275
# Epoch 17/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.3288 - accuracy: 0.9098 - val_loss: 0.5892 - val_accuracy: 0.8299
# Epoch 18/100
# 243/243 [==============================] - 6s 23ms/step - loss: 0.3029 - accuracy: 0.9138 - val_loss: 0.5413 - val_accuracy: 0.8546
# Epoch 19/100
# 243/243 [==============================] - 6s 22ms/step - loss: 0.2951 - accuracy: 0.9179 - val_loss: 0.7308 - val_accuracy: 0.8017
# Epoch 20/100
# 243/243 [==============================] - 6s 23ms/step - loss: 0.2967 - accuracy: 0.9175 - val_loss: 0.6895 - val_accuracy: 0.8179
# Epoch 21/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.2756 - accuracy: 0.9238 - val_loss: 0.5622 - val_accuracy: 0.8441
# Epoch 22/100
# 243/243 [==============================] - 6s 22ms/step - loss: 0.2414 - accuracy: 0.9356 - val_loss: 0.7092 - val_accuracy: 0.8117
# Epoch 23/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.2400 - accuracy: 0.9336 - val_loss: 0.6470 - val_accuracy: 0.8295
# Epoch 24/100
# 243/243 [==============================] - 6s 23ms/step - loss: 0
100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1357 - accuracy: 0.9640 - val_loss: 0.5232 - val_accuracy: 0.8738
# Epoch 55/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1142 - accuracy: 0.9683 - val_loss: 0.5027 - val_accuracy: 0.8762
# Epoch 56/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.0924 - accuracy: 0.9753 - val_loss: 0.5415 - val_accuracy: 0.8708
# Epoch 57/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.0957 - accuracy: 0.9749 - val_loss: 0.6429 - val_accuracy: 0.8507
# Epoch 58/100
# 243/243 [==============================] - 6s 23ms/step - loss: 0.1155 - accuracy: 0.9670 - val_loss: 0.5971 - val_accuracy: 0.8488
# Epoch 59/100
# 243/243 [==============================] - 6s 23ms/step - loss: 0.1100 - accuracy: 0.9700 - val_loss: 0.8924 - val_accuracy: 0.8167
# Epoch 60/100
# 243/243 [==============================] - 6s 23ms/step - loss: 0.1289 - accuracy: 0.9621 - val_loss: 0.6334 - val_accuracy: 0.8480
# Epoch 61/100
# 243/243 [==============================] - 6s 23ms/step - loss: 0.1014 - accuracy: 0.9723 - val_loss: 0.6941 - val_accuracy: 0.8356
# Epoch 62/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1207 - accuracy: 0.9637 - val_loss: 0.5153 - val_accuracy: 0.8708
# Epoch 63/100
# 243/243 [==============================] - 6s 23ms/step - loss: 0.0971 - accuracy: 0.9756 - val_loss: 0.6275 - val_accuracy: 0.8573
# Epoch 64/100
# 243/243 [==============================] - 6s 23ms/step - loss: 0.1040 - accuracy: 0.9728 - val_loss: 0.5263 - val_accuracy: 0.8758
# Epoch 65/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.0912 - accuracy: 0.9744 - val_loss: 1.5371 - val_accuracy: 0.7330
# Epoch 66/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.0958 - accuracy: 0.9728 - val_loss: 0.4550 - val_accuracy: 0.8916
# Epoch 67/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0911 - accuracy: 0.9763 - val_loss: 0.8405 - val_accuracy: 0.8272
# Epoch 68/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0895 - accuracy: 0.9754 - val_loss: 1.4368 - val_accuracy: 0.7299
# Epoch 69/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1343 - accuracy: 0.9599 - val_loss: 0.8895 - val_accuracy: 0.8083
# Epoch 70/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1415 - accuracy: 0.9616 - val_loss: 0.5871 - val_accuracy: 0.8634
# Epoch 71/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1020 - accuracy: 0.9722 - val_loss: 0.4787 - val_accuracy: 0.8823
# Epoch 72/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0714 - accuracy: 0.9816 - val_loss: 0.4739 - val_accuracy: 0.8816
# Epoch 73/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0741 - accuracy: 0.9802 - val_loss: 0.6038 - val_accuracy: 0.8627
# Epoch 74/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.0784 - accuracy: 0.9782 - val_loss: 0.5017 - val_accuracy: 0.8858
# Epoch 75/100
# 243/243 [==============================] - 6s 23ms/step - loss: 0.0811 - accuracy: 0.9784 - val_loss: 1.0022 - val_accuracy: 0.8036
# Epoch 76/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1261 - accuracy: 0.9656 - val_loss: 0.6412 - val_accuracy: 0.8615
# Epoch 77/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1016 - accuracy: 0.9722 - val_loss: 0.5729 - val_accuracy: 0.8731
# Epoch 78/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1013 - accuracy: 0.9722 - val_loss: 0.7262 - val_accuracy: 0.8461
# Epoch 79/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.0855 - accuracy: 0.9772 - val_loss: 0.4099 - val_accuracy: 0.9016
# Epoch 80/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.0833 - accuracy: 0.9780 - val_loss: 0.6265 - val_accuracy: 0.8688
# Epoch 81/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0954 - accuracy: 0.9720 - val_loss: 0.5416 - val_accuracy: 0.8812
# Epoch 82/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1078 - accuracy: 0.9724 - val_loss: 0.4715 - val_accuracy: 0.8881
# Epoch 83/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.0734 - accuracy: 0.9781 - val_loss: 0.5524 - val_accuracy: 0.8754
# Epoch 84/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.0815 - accuracy: 0.9781 - val_loss: 0.5254 - val_accuracy: 0.8792
# Epoch 85/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0708 - accuracy: 0.9808 - val_loss: 0.6388 - val_accuracy: 0.8692
# Epoch 86/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0803 - accuracy: 0.9790 - val_loss: 0.7308 - val_accuracy: 0.8465
# Epoch 87/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0962 - accuracy: 0.9738 - val_loss: 0.8848 - val_accuracy: 0.8218
# Epoch 88/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1309 - accuracy: 0.9638 - val_loss: 0.5641 - val_accuracy: 0.8638
# Epoch 89/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.0823 - accuracy: 0.9765 - val_loss: 0.4623 - val_accuracy: 0.8916
# Epoch 90/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.0620 - accuracy: 0.9835 - val_loss: 0.6855 - val_accuracy: 0.8507
# Epoch 91/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.0601 - accuracy: 0.9856 - val_loss: 0.5160 - val_accuracy: 0.8916
# Epoch 92/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.0627 - accuracy: 0.9838 - val_loss: 1.0136 - val_accuracy: 0.8376
# Epoch 93/100
# 243/243 [==============================] - 5s 22ms/step - loss: 0.0828 - accuracy: 0.9769 - val_loss: 0.6069 - val_accuracy: 0.8723
# Epoch 94/100
# 243/243 [==============================] - 6s 24ms/step - loss: 0.0779 - accuracy: 0.9777 - val_loss: 0.4829 - val_accuracy: 0.8935
# Epoch 95/100
# 243/243 [==============================] - 6s 23ms/step - loss: 0.0823 - accuracy: 0.9767 - val_loss: 0.5890 - val_accuracy: 0.8765
# Epoch 96/100
# 243/243 [==============================] - 6s 23ms/step - loss: 0.1021 - accuracy: 0.9713 - val_loss: 1.0183 - val_accuracy: 0.7998
# Epoch 97/100
# 243/243 [==============================] - 6s 24ms/step - loss: 0.0810 - accuracy: 0.9781 - val_loss: 0.7171 - val_accuracy: 0.8534
# Epoch 98/100
# 243/243 [==============================] - 6s 23ms/step - loss: 0.0857 - accuracy: 0.9759 - val_loss: 0.7921 - val_accuracy: 0.8407
# Epoch 99/100
# 243/243 [==============================] - 6s 23ms/step - loss: 0.0768 - accuracy: 0.9787 - val_loss: 0.4899 - val_accuracy: 0.8893
# Epoch 100/100
# 243/243 [==============================] - 6s 24ms/step - loss: 0.0562 - accuracy: 0.9852 - val_loss: 0.4880 - val_accuracy: 0.8943

# %% [markdown]
# Salviamo nuovamente la history del modello in un file csv.

# %%
bp_model_history_df = convert_history_to_csv(bp_model_history)
bp_model_history_df.to_csv("model_histories/adam/spectrogram/bp_model_history.csv")

# %% [markdown]
# Convertiamo anche il miglior modello nel formato **.onnx**.

# %%
convert_model_to_onnx("bestmodels/adam/spectrogram/bp_basic_model.keras", (124, 129, 1))

# %%
create_train_val_plot(bp_model_history.history, overfit=False)

# %% [markdown]
# Possiamo notare che il modello **NON ha raggiunto una vera fase di overfitting**, ma la validazione non ha mostrato un incremento sostanziale all'aumentare delle epoche (probabilmente dovuto dalle tecniche di overfitting non totalmente implementate). La **loss della validazione** stava continuando a scendere, e allo stesso tempo **l'accuratezza della validazione era crescente**.

# %%
best_bp_basic_model = tf.keras.models.load_model("bestmodels/adam/spectrogram/bp_basic_model.keras")
test_loss, test_acc = best_bp_basic_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 5ms/step - loss: 0.4494 - accuracy: 0.8966
# Accuratezza: 0.897

# %% [markdown]
# Verifichiamola anche con il modello **.onnx**.

# %%
evaluate_onnx_model("bestmodels/adam/spectrogram/bp_basic_model.onnx", test_ds)
# Out:
# Accuratezza: 0.897

# %% [markdown]
# Abbiamo ottenuto un notevole miglioramento per quanto riguarda l'accuratezza, ottenendo un **89.7%**. Questo risultato non è male, considerando che il modello ha poco meno del **12% dei parametri** rispetto al precedente.

# %%
for audio, label in test_ds:
    create_distribution_plot(best_bp_basic_model, audio, label)
    break

# %% [markdown]
# La decisione del modello in questo caso è nuovamente molto chiara.
