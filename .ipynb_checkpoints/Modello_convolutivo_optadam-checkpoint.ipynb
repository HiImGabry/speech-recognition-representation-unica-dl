# %% [markdown]
# # Modello convolutivo di base
# Lo scopo di questo notebook è creare un **modello convolutivo di base** con un'architettura semplice. In seguito, sarà interessante confrontare i risultati di questo primo modello con i risultati ottenuti da modelli più complessi, o pre addestrati.

# %% [markdown]
# Come al solito, si procede con l'importazione delle librerie utilizzate e la creazione dei set di allenamento e validazione.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import os

# %%
train_ds, validation_ds = tf.keras.utils.audio_dataset_from_directory(
    directory='../reduced_dataset/dataset/audio',
    validation_split=0.4, # stiamo mettendo da parte il 40% del dataset, che sarà suddiviso in validation set e test set
    shuffle=True,
    subset='both', # necessario se stiamo utilizzando validation_split (se no darebbe errore)
    seed=0 # necessario se stiamo utilizzando sia shuffle che validation_split (se no darebbe errore)
)

label_names = train_ds.class_names
# Out:
# Found 12933 files belonging to 30 classes.
# Using 7760 files for training.
# Using 5173 files for validation.

# %%
for audios, labels in train_ds:
    print("Forma (shape) audio:", audios.shape)
    print("Forma (shape) classi:", labels.shape)
    break
# Out:
# Forma (shape) audio: (32, 16000, 1)
# Forma (shape) classi: (32,)

# %% [markdown]
# Lo shape dell'audio è di (32, 16000, 1), indicando che ogni file è contenuto in un batch di 32 tensori unidimensionali di lunghezza 16000. Inoltre, lo shape delle classi è anch'esso 32. Questo perché la funzione `tf.keras.utils.audio_dataset_from_directory(directory)` ha il parametro `batch_size` impostato a 32 di default, non avendolo specificato la dimensione è rimasta tale.

# %% [markdown]
# ## Funzioni per processamento dei dati

# %% [markdown]
# Il prossimo step è definire la funzione `squeeze(audio, labels)`, la quale prende come argomenti l'audio e le classi.
#
# Questa funzione serve per rimuovere l'ultimo asse dello shape dai nostri audio. Attualmente, lo shape dei dati è (32, 16000, 1), ma si può eliminare l'ultima dimensione poiché non necessaria. Specificando il parametro **axis=-1** nella funzione `tf.squeeze` la forma dell'audio viene trasformata in (32, 16000).
#
# Eseguiamo questa semplificazione sulla forma del dato poiché rende la fase di processamento dei dati più efficiente.

# %%
def squeeze(audio, labels):
    audio = tf.squeeze(audio, axis=-1)
    return audio, labels

# fonte: funzione presa dal seguente link: https://www.geeksforgeeks.org/audio-recognition-in-tensorflow/

# %%
train_ds = train_ds.map(squeeze, tf.data.AUTOTUNE)
validation_ds = validation_ds.map(squeeze, tf.data.AUTOTUNE)

audio, label = next(iter(train_ds))
print(audio.shape)
print(label.shape)
# Out:
# (32, 16000)
# (32,)

# %% [markdown]
# Una volta eseguito questa semplificazione, a partire dai tensori degli audio, creeremo gli spettrogrammi che sarannò presi come input dal modello convolutivo.

# %% [markdown]
# ## Conversione e suddivisione dataset
# Andremo ad utilizzare due funzioni: `get_spectrogram` e `get_spectrogram_dataset`. Queste due funzioni usate insieme convertono il nostro dataset di audio in un dataset di spettrogrammi. La prima funzione `get_spectrogram` converte il singolo audio in spettrogramma mentre la seconda funzione `get_spectrogram_dataset` richiama la prima funzione per ogni dato presente nel dataset.

# %%
def get_spectrogram(waveform):
    spectrogram = tf.signal.stft(waveform, frame_length=255, frame_step=128)
    spectrogram = tf.abs(spectrogram)

    return spectrogram[..., tf.newaxis]

# fonte: funzione presa dal seguente link: https://www.geeksforgeeks.org/audio-recognition-in-tensorflow/

# %%
def get_spectrogram_dataset(dataset):
    dataset = dataset.map(lambda x, y: (get_spectrogram(x), y), num_parallel_calls=tf.data.AUTOTUNE)

    return dataset

# fonte: funzione presa dal seguente link: https://www.geeksforgeeks.org/audio-recognition-in-tensorflow/

# %% [markdown]
# Definite le due funzioni possiamo procedere a ottenere il nostro **training set**, **validation set**, e **test set** di spettrogrammi. La suddivisione di dati ricordo essere rispettivamente 60%, 20%, 20%.

# %%
train_ds = get_spectrogram_dataset(train_ds)
validation_ds = get_spectrogram_dataset(validation_ds)

val_ds = validation_ds.take(validation_ds.cardinality() // 2) # ho cambiato nome del validation_ds in modo tale da non creare problemi con l'istruzione seguente
test_ds = validation_ds.skip(validation_ds.cardinality() // 2)

# %%
print("Numero di audio training set:", len(train_ds) * 32)
print("Numero di audio validation set:", len(val_ds) * 32)
print("Numero di audio test set:", len(test_ds) * 32)
# Out:
# Numero di audio training set: 7776
# Numero di audio validation set: 2592
# Numero di audio test set: 2592

# %%
for audio, label in train_ds:
    print("Shape (forma) spettrogrammi:", audio.shape)

    spectrogram = np.squeeze(audio[0])
    spectrogram = np.log(spectrogram.T)

    plt.imshow(spectrogram.T)
    plt.colorbar(format='%+2.0f dB') # barra laterale dei dB

    plt.title(f"Classe: {label_names[label[0].numpy()]}")
    break
# Out:
# Shape (forma) spettrogrammi: (32, 124, 129, 1)

# %% [markdown]
# La grandezza degli spettrogrammi, quindi delle immagini ottenute, è di **124x129**.

# %% [markdown]
# ## Creazione modello di base

# %% [markdown]
# Come modello implementiamo una rete neurale convolutiva. Questo modello ha un'architettura semplice e servirà da benchmark per i modelli futuri.
#
# La rete prende in ingresso tensori di forma **altezza x larghezza x canali**, rispettivamente di **124, 129, 1**. Per farlo lavorare meglio, rendiamo le immagini di dimensione quadrata e normalizziamo i dati con la funzione `tf.keras.layers.Normalization()`.

# %% [markdown]
# L'architettura del modello è suddivisa in **due blocchi** principali: un blocco per l'apprendimento delle caratteristiche e un blocco per la classificazione.
#
# Il **blocco di apprendimento delle caratteristiche** ha un'architettura formata da una serie di livelli convolutivi alternati a livelli di max pooling. Per ciascun livello convolutivo viene anche applicata la funzione di attivazione **ReLu** per applicare non linearità. Il blocco termina con un livello convolutivo di **256 filtri**, che corrispondono alla stessa quantità di filtri applicati dal livello convolutivo precedente.
#
# Terminato il blocco di apprendimento delle caratteristiche, è presente il **blocco di classificazione**, formato da un **livello di Flatten**, necessario per trasformare i dati in un vettore unidimensionali, e un **livello Dense**, necessario per la predizione della classe di appartenenza del dato. Quest'ultimo livello Dense ha **30 unità**, che corrispondono alle 30 classi del nostro task di classificazione multiclasse. La funzione di attivazione applicata dal livello Dense è la **softmax**, ideale per i task di classificazione multiclasse.
#
# La funzione **softmax**, a differenza della funzione **sigmoid** ci fornisce una distribuzione di probabilità sulle classi possibili (questa distribuzione saremo in grado di visualizzarla durante la valutazione del modello).

# %%
def get_basic_model():
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(124, 129, 1))
    x = tf.keras.layers.Resizing(120, 120)(inputs)
    x = tf.keras.layers.Normalization()(x)

    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# Nella prossima cella di codice dichiariamo l'**ottimizzatore** da utilizzare (rmsprop), le **metriche** di cui tenere traccia (accuratezza), e la funzione di perdita da utilizzare per il calcolo del gradiente. Nel nostro caso la **funzione di perdita** corrisponde alla `sparse_categorical_crossentropy`, una variante della `categorical_crossentropy`.
#
# La **sparse categorical crossentropy** viene utilizzata quando le classi sono rappresentate come interi, proprio come nel nostro caso.

# %%
basic_model = get_basic_model()
basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

basic_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 124, 129, 1)]     0
#
#  resizing (Resizing)         (None, 120, 120, 1)       0
#
#  normalization (Normalizati  (None, 120, 120, 1)       3
#  on)
#
#  conv2d (Conv2D)             (None, 118, 118, 32)      320
#
#  max_pooling2d (MaxPooling2  (None, 59, 59, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 57, 57, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 28, 28, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 26, 26, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 13, 13, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 256)       295168
#
#  max_pooling2d_3 (MaxPoolin  (None, 5, 5, 256)         0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 3, 3, 256)         590080
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 30)                69150
#
# =================================================================
# Total params: 1047073 (3.99 MB)
# Trainable params: 1047070 (3.99 MB)
# Non-trainable params: 3 (16.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Il modello ha un totale di circa **1 milione di parametri**, bilanciando complessità e capacità di apprendimento.

# %%
basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/basic_model.keras", save_best_only=True, monitor="val_loss")]
basic_model_history = basic_model.fit(train_ds, epochs=30, validation_data=val_ds, callbacks=basic_model_callbacks)
# Out:
# Epoch 1/30
# 243/243 [==============================] - 9s 15ms/step - loss: 2.7245 - accuracy: 0.2245 - val_loss: 2.0794 - val_accuracy: 0.4005
# Epoch 2/30
# 243/243 [==============================] - 3s 12ms/step - loss: 1.4579 - accuracy: 0.5853 - val_loss: 1.1499 - val_accuracy: 0.6759
# Epoch 3/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.8683 - accuracy: 0.7517 - val_loss: 0.8855 - val_accuracy: 0.7504
# Epoch 4/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.5672 - accuracy: 0.8320 - val_loss: 0.9130 - val_accuracy: 0.7647
# Epoch 5/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.4216 - accuracy: 0.8785 - val_loss: 0.8239 - val_accuracy: 0.7924
# Epoch 6/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.3428 - accuracy: 0.8961 - val_loss: 0.8663 - val_accuracy: 0.7990
# Epoch 7/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2598 - accuracy: 0.9216 - val_loss: 1.0177 - val_accuracy: 0.8044
# Epoch 8/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2364 - accuracy: 0.9309 - val_loss: 0.9127 - val_accuracy: 0.8156
# Epoch 9/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2015 - accuracy: 0.9410 - val_loss: 0.9198 - val_accuracy: 0.8140
# Epoch 10/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1682 - accuracy: 0.9518 - val_loss: 1.0110 - val_accuracy: 0.8260
# Epoch 11/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1858 - accuracy: 0.9452 - val_loss: 0.9847 - val_accuracy: 0.7990
# Epoch 12/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1314 - accuracy: 0.9610 - val_loss: 1.0739 - val_accuracy: 0.8005
# Epoch 13/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1521 - accuracy: 0.9584 - val_loss: 1.3021 - val_accuracy: 0.7319
# Epoch 14/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1312 - accuracy: 0.9615 - val_loss: 1.1759 - val_accuracy: 0.8202
# Epoch 15/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1211 - accuracy: 0.9660 - val_loss: 1.3014 - val_accuracy: 0.7886
# Epoch 16/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0818 - accuracy: 0.9771 - val_loss: 1.1680 - val_accuracy: 0.8164
# Epoch 17/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0991 - accuracy: 0.9738 - val_loss: 1.0050 - val_accuracy: 0.8202
# Epoch 18/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1118 - accuracy: 0.9702 - val_loss: 1.3309 - val_accuracy: 0.8152
# Epoch 19/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1086 - accuracy: 0.9711 - val_loss: 1.2259 - val_accuracy: 0.7924
# Epoch 20/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1618 - accuracy: 0.9582 - val_loss: 1.1065 - val_accuracy: 0.8225
# Epoch 21/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0678 - accuracy: 0.9831 - val_loss: 1.0111 - val_accuracy: 0.8410
# Epoch 22/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0469 - accuracy: 0.9879 - val_loss: 1.2715 - val_accuracy: 0.8283
# Epoch 23/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0545 - accuracy: 0.9851 - val_loss: 1.4149 - val_accuracy: 0.8237
# Epoch 24/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0684 - accuracy: 0.9813 - val_loss: 1.5685 - val_accuracy: 0.8094
# Epoch 25/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0968 - accuracy: 0.9732 - val_loss: 1.1944 - val_accuracy: 0.8017
# Epoch 26/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0610 - accuracy: 0.9821 - val_loss: 1.3467 - val_accuracy: 0.8291
# Epoch 27/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0857 - accuracy: 0.9771 - val_loss: 1.2633 - val_accuracy: 0.8245
# Epoch 28/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0691 - accuracy: 0.9816 - val_loss: 1.2819 - val_accuracy: 0.8302
# Epoch 29/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0482 - accuracy: 0.9866 - val_loss: 1.3126 - val_accuracy: 0.8241
# Epoch 30/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0640 - accuracy: 0.9841 - val_loss: 1.5956 - val_accuracy: 0.8106

# %% [markdown]
# Alleniamo il modello per 30 epoche e visualizziamo le **curve di addestramento** e **validazione**.

# %%
def create_train_val_plot(history, overfit=True):
    # definisco numero epoche
    epochs = range(1, len(history['accuracy']) + 1)

    # Accuracy
    accuracy = history['accuracy']
    val_accuracy = history['val_accuracy']

    fig_acc, ax_acc = plt.subplots()

    # linea di base
    ax_acc.plot(epochs, [0.5 for x in range(len(epochs))], color="lightgray", linestyle="--", label="Base")
    # linee di accuratezza
    ax_acc.plot(epochs, accuracy, color="slategray", label="Accuratezza in addestramento")
    ax_acc.plot(epochs, val_accuracy, color="indianred", label="Accuratezza in validazione")
    # miglior accuratezza validazione
    ax_acc.axhline(y=max(val_accuracy), c='indianred', alpha=0.7, linestyle='--')
    ax_acc.text(len(epochs) * 1.07, max(val_accuracy), round(max(val_accuracy), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_acc.spines["right"].set_visible(False)
    ax_acc.spines["top"].set_visible(False)
    ax_acc.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_acc.set_title("Accuratezza in addestramento e validazione")
    ax_acc.set_xlabel("Epoche")
    ax_acc.set_ylabel("Accuratezza (%)")
    ax_acc.legend()

    # Loss
    loss = history['loss']
    val_loss = history['val_loss']

    fig_loss, ax_loss = plt.subplots()

    # linee di loss
    ax_loss.plot(epochs, loss, color="slategray", label="Perdita in addestramento")
    ax_loss.plot(epochs, val_loss, color="indianred", label="Perdita in validazione")
    # miglior loss validazione
    ax_loss.axhline(y=min(val_loss), c='indianred', alpha=0.7, linestyle='--')
    ax_loss.text(len(epochs) * 1.07, min(val_loss), round(min(val_loss), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_loss.spines["right"].set_visible(False)
    ax_loss.spines["top"].set_visible(False)
    ax_loss.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_loss.set_title("Perdita in addestramento e validazione")
    ax_loss.set_xlabel("Epoche")
    ax_loss.set_ylabel("Perdita")

    handles, _ = ax_loss.get_legend_handles_labels()

    if overfit:
        # area overfit
        rect = mpatches.Rectangle((np.argmin(val_loss) + 1, 0), width=100 - np.argmin(val_loss), height=max(max(loss), max(val_loss)), color='lightcoral', alpha=0.3)
        ax_loss.add_patch(rect)
        # patch overfit per legenda
        overfit = mpatches.Patch(color='indianred', alpha=0.3, label='Area overfit')
        handles, _ = ax_loss.get_legend_handles_labels()
        handles.append(overfit)

    # legenda
    ax_loss.legend(handles=handles)

    plt.show()

# %%
create_train_val_plot(basic_model_history.history)

# %% [markdown]
# Questi grafici mostrano come il nostro modello sia andato immediatamente in overfitting. L'accuratezza dell'addestramento aumenta col tempo e raggiunge quasi il **100%**, mentre l'accuratezza della validazione si attesta sull'**80%** con un **picco del 86%**. Inoltre, la **perdita nel set di addestramento** continua a diminuire mentre la **perdita nel set di validazione** aumenta.

# %% [markdown]
# Possiamo verificare l'accuratezza della migliore versione del nostro modello di base ricaricando il file **basic_model.keras**.

# %%
best_basic_model = tf.keras.models.load_model("bestmodels/basic_model.keras")
test_loss, test_acc = best_basic_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 8ms/step - loss: 0.8920 - accuracy: 0.7861
# Accuratezza: 0.786

# %% [markdown]
# Abbiamo ottenuto un'**accuratezza** del **82%**! La complessità di questo task è legata fortemente alla **quantità di classi** e alla **dimensione limitata del dataset**. Considerato ciò, il risultato ottenuto non è male.

# %% [markdown]
# Infine, creiamo una funzione utile a visualizzare graficamente la distribuzione di accuratezza delle classi su un'immagine casuale, per capire come ha lavorato il modello. Nel caso il modello non predica correttamente, la **classe corretta** verrà sempre evidenziata di **verde** mentre la **classe predetta** verrà evidenziata di **giallo**.

# %%
def create_distribution_plot(model, audio, label):
    prediction = model(audio) # otteniamo la predizione del modello sull'audio preso in input
    softmax_pred = tf.nn.softmax(prediction[0]) # dobbiamo applicare nuovamente la softmax in modo tale da avere dei dati leggibili
    pred_label = np.argmax(softmax_pred) # ci salviamo l'indice della label predetta dal nostro modello, quella con la probabilità più alta

    colors = ['indianred'] * len(label_names) # creiamo un vettore di lunghezza 30 (la quantità delle nostre label) colorate di rosso

    if pred_label == label[0].numpy(): # se la label che abbiamo predetto è corretta, allora la coloriamo di verde
        colors[pred_label] = 'seagreen'
    else: # se la label che abbiamo predetto è sbagliata, allora coloriamo di verde la corretta e di gialla la predetta
        colors[pred_label] = 'khaki'
        colors[label[0].numpy()] = 'seagreen'

    plt.figure(figsize=(12, 4))

    plt.bar(label_names, softmax_pred.numpy(), color=colors)
    plt.xticks(rotation=45)

    # dichiariamo i colori della legenda
    other_values_patch = mpatches.Patch(color='indianred', label='Altre classi')
    pred_value_patch = mpatches.Patch(color='khaki', label='Classe predetta')
    correct_value_patch = mpatches.Patch(color='green', label='Classe corretta')

    # disegniamo al legenda con i colori necessari
    if pred_label == label[0].numpy(): # se abbiamo predetto correttamente la label, non è necessario mostrare il colore giallo (non è presente nel plot)
        plt.legend(handles=[other_values_patch, correct_value_patch])
    else:
        plt.legend(handles=[other_values_patch, pred_value_patch, correct_value_patch])

    plt.show()

# %%
for audio, label in test_ds: # prendiamo un audio a caso del test e creiamo la distribuzione
    create_distribution_plot(best_basic_model, audio, label)
    break

# %% [markdown]
# Possiamo notare dalla distribuzione che il modello in questo caso ha predetto correttamente la **classe no**. Inoltre possiamo notare che la **classe go** ha qualche punto percentuale in più delle altre, il che ha senso essendo una parola molto simile (ergo uno spettrogramma simile).

# %% [markdown]
# L'overfitting è probabilmente fortemente causato dal fatto che il nostro dataset contiene un numero insufficente di campioni, rendendolo non in grado di generalizzare su dati nuovi. Per migliorare la capacità di generalizzare del modello andremo a creare dei dati artificali con le tecniche di data agumentation.

# %% [markdown]
# ### Risoluzione dell'overfitting
# Abbiamo capito che il modello è andato immediatamente in **overfitting**, e lo possiamo notare dalla loss di validazione che inizia a salire dalla quinta epoca in poi. L'obbiettivo principale in questo momento è evitare che vada in overfitting troppo velocemente, applicando le tecniche viste a lezione.

# %% [markdown]
# Utilizzeremo la tecnica della **data augmentation** per risolvere la grandezza ridotta del dataset, e inoltre applicheremo un **livello di Dropout** al **blocco di classificazione**.

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.1)
    # tf.keras.layers.RandomZoom(0.2) # -> non ci stava dando risultati e aumentava il tempo di training
    # tf.keras.layers.RandomTranslation(height_factor=5/124, width_factor=0)
    # tf.keras.layers.RandomTranslation(height_factor=0, width_factor=5/129)
    # questi ultimi due layer non ci stavano dando risultati e aumentava di molto il tempo di training
    # l'idea era quella di traslare le immagini di 5 pixel per la X e 5 pixel per la Y
])

# %%
def get_improved_basic_model():
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(124, 129, 1))
    # x = data_augmentation(inputs)
    x = tf.keras.layers.Resizing(120, 120)(inputs)
    x = tf.keras.layers.Normalization()(x)

    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
improved_basic_model = get_improved_basic_model()
improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/improved_basic_model.keras", save_best_only=True, monitor="val_loss")]
improved_history = improved_basic_model.fit(train_ds, epochs=100, validation_data=val_ds, callbacks=improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 6s 13ms/step - loss: 2.8935 - accuracy: 0.1746 - val_loss: 2.2927 - val_accuracy: 0.3519
# Epoch 2/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.8606 - accuracy: 0.4601 - val_loss: 1.4061 - val_accuracy: 0.5926
# Epoch 3/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.2135 - accuracy: 0.6452 - val_loss: 0.9799 - val_accuracy: 0.7137
# Epoch 4/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.8721 - accuracy: 0.7360 - val_loss: 0.8388 - val_accuracy: 0.7569
# Epoch 5/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.6725 - accuracy: 0.8014 - val_loss: 0.7726 - val_accuracy: 0.7870
# Epoch 6/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.5336 - accuracy: 0.8380 - val_loss: 0.6876 - val_accuracy: 0.8152
# Epoch 7/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4470 - accuracy: 0.8662 - val_loss: 0.6270 - val_accuracy: 0.8356
# Epoch 8/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.3769 - accuracy: 0.8826 - val_loss: 0.6317 - val_accuracy: 0.8383
# Epoch 9/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.3200 - accuracy: 0.9037 - val_loss: 0.6790 - val_accuracy: 0.8399
# Epoch 10/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2862 - accuracy: 0.9113 - val_loss: 0.7019 - val_accuracy: 0.8252
# Epoch 11/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2700 - accuracy: 0.9168 - val_loss: 0.7075 - val_accuracy: 0.8229
# Epoch 12/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2459 - accuracy: 0.9273 - val_loss: 0.5537 - val_accuracy: 0.8580
# Epoch 13/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2116 - accuracy: 0.9379 - val_loss: 0.7192 - val_accuracy: 0.8457
# Epoch 14/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2139 - accuracy: 0.9339 - val_loss: 0.6613 - val_accuracy: 0.8449
# Epoch 15/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1829 - accuracy: 0.9472 - val_loss: 0.6574 - val_accuracy: 0.8484
# Epoch 16/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1866 - accuracy: 0.9445 - val_loss: 0.7929 - val_accuracy: 0.8333
# Epoch 17/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1918 - accuracy: 0.9454 - val_loss: 0.5545 - val_accuracy: 0.8642
# Epoch 18/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1530 - accuracy: 0.9539 - val_loss: 0.6846 - val_accuracy: 0.8573
# Epoch 19/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1379 - accuracy: 0.9612 - val_loss: 0.6633 - val_accuracy: 0.8499
# Epoch 20/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1514 - accuracy: 0.9537 - val_loss: 0.7217 - val_accuracy: 0.8515
# Epoch 21/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1407 - accuracy: 0.9580 - val_loss: 0.7575 - val_accuracy: 0.8507
# Epoch 22/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1407 - accuracy: 0.9588 - val_loss: 0.6428 - val_accuracy: 0.8684
# Epoch 23/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1214 - accuracy: 0.9651 - val_loss: 0.8842 - val_accuracy: 0.8561
# Epoch 24/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1247 - accuracy: 0.9630 - val_loss: 0.8093 - val_accuracy: 0.8580
# Epoch 25/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1300 - accuracy: 0.9612 - val_loss: 0.6849 - val_accuracy: 0.8661
# Epoch 26/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1099 - accuracy: 0.9692 - val_loss: 0.8076 - val_accuracy: 0.8607
# Epoch 27/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1218 - accuracy: 0.9677 - val_loss: 0.7093 - val_accuracy: 0.8665
# Epoch 28/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1065 - accuracy: 0.9698 - val_loss: 0.7057 - val_accuracy: 0.8769
# Epoch 29/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0882 - accuracy: 0.9759 - val_loss: 0.9119 - val_accuracy: 0.8677
# Epoch 30/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1048 - accuracy: 0.9683 - val_loss: 0.5953 - val_accuracy: 0.8839
# Epoch 31/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1129 - accuracy: 0.9669 - val_loss: 0.8175 - val_accuracy: 0.8480
# Epoch 32/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1154 - accuracy: 0.9662 - val_loss: 0.8268 - val_accuracy: 0.8615
# Epoch 33/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1308 - accuracy: 0.9665 - val_loss: 0.6710 - val_accuracy: 0.8615
# Epoch 34/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1032 - accuracy: 0.9716 - val_loss: 0.6720 - val_accuracy: 0.8735
# Epoch 35/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0842 - accuracy: 0.9756 - val_loss: 0.6797 - val_accuracy: 0.8738
# Epoch 36/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1124 - accuracy: 0.9695 - val_loss: 0.8161 - val_accuracy: 0.8569
# Epoch 37/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1116 - accuracy: 0.9706 - val_loss: 0.9619 - val_accuracy: 0.8573
# Epoch 38/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0953 - accuracy: 0.9745 - val_loss: 0.7824 - val_accuracy: 0.8746
# Epoch 39/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0930 - accuracy: 0.9751 - val_loss: 0.6559 - val_accuracy: 0.8785
# Epoch 40/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0926 - accuracy: 0.9765 - val_loss: 0.6835 - val_accuracy: 0.8719
# Epoch 41/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0777 - accuracy: 0.9798 - val_loss: 0.7180 - val_accuracy: 0.8781
# Epoch 42/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0512 - accuracy: 0.9862 - val_loss: 0.8044 - val_accuracy: 0.8765
# Epoch 43/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0786 - accuracy: 0.9785 - val_loss: 0.8159 - val_accuracy: 0.8765
# Epoch 44/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1099 - accuracy: 0.9710 - val_loss: 0.8163 - val_accuracy: 0.8561
# Epoch 45/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0962 - accuracy: 0.9726 - val_loss: 0.8993 - val_accuracy: 0.8669
# Epoch 46/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0849 - accuracy: 0.9764 - val_loss: 0.7596 - val_accuracy: 0.8719
# Epoch 47/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0858 - accuracy: 0.9760 - val_loss: 0.8353 - val_accuracy: 0.8681
# Epoch 48/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0831 - accuracy: 0.9755 - val_loss: 0.6968 - val_accuracy: 0.8823
# Epoch 49/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0596 - accuracy: 0.9841 - val_loss: 0.7663 - val_accuracy: 0.8816
# Epoch 50/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0738 - accuracy: 0.9798 - val_loss: 0.7234 - val_accuracy: 0.8738
# Epoch 51/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0801 - accuracy: 0.9771 - val_loss: 0.9810 - val_accuracy: 0.8677
# Epoch 52/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1095 - accuracy: 0.9715 - val_loss: 0.8832 - val_accuracy: 0.8711
# Epoch 53/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0774 - accuracy: 0.9800 - val_loss: 0.8325 - val_accuracy: 0.8723
# Epoch 54/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0766 - accuracy: 0.9805 - val_loss: 0.9733 - val_accuracy: 0.8827
# Epoch 55/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0653 - accuracy: 0.9814 - val_loss: 0.8134 - val_accuracy: 0.8719
# Epoch 56/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0602 - accuracy: 0.9841 - val_loss: 0.8495 - val_accuracy: 0.8866
# Epoch 57/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0668 - accuracy: 0.9834 - val_loss: 0.8469 - val_accuracy: 0.8812
# Epoch 58/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0806 - accuracy: 0.9789 - val_loss: 0.8253 - val_accuracy: 0.8827
# Epoch 59/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1107 - accuracy: 0.9710 - val_loss: 0.9740 - val_accuracy: 0.8715
# Epoch 60/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0811 - accuracy: 0.9804 - val_loss: 0.9292 - val_accuracy: 0.8681
# Epoch 61/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0783 - accuracy: 0.9787 - val_loss: 0.9577 - val_accuracy: 0.8765
# Epoch 62/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0774 - accuracy: 0.9803 - val_loss: 0.7635 - val_accuracy: 0.8762
# Epoch 63/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0719 - accuracy: 0.9812 - val_loss: 0.9107 - val_accuracy: 0.8530
# Epoch 64/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0639 - accuracy: 0.9838 - val_loss: 0.8831 - val_accuracy: 0.8708
# Epoch 65/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0655 - accuracy: 0.9813 - val_loss: 0.7759 - val_accuracy: 0.8812
# Epoch 66/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0599 - accuracy: 0.9843 - val_loss: 0.8522 - val_accuracy: 0.8538
# Epoch 67/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0657 - accuracy: 0.9825 - val_loss: 1.0009 - val_accuracy: 0.8681
# Epoch 68/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0776 - accuracy: 0.9803 - val_loss: 0.7858 - val_accuracy: 0.8885
# Epoch 69/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0598 - accuracy: 0.9843 - val_loss: 0.8758 - val_accuracy: 0.8877
# Epoch 70/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0797 - accuracy: 0.9793 - val_loss: 0.8476 - val_accuracy: 0.8796
# Epoch 71/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0619 - accuracy: 0.9858 - val_loss: 0.8140 - val_accuracy: 0.8812
# Epoch 72/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0749 - accuracy: 0.9813 - val_loss: 0.9449 - val_accuracy: 0.8800
# Epoch 73/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0602 - accuracy: 0.9860 - val_loss: 0.9258 - val_accuracy: 0.8812
# Epoch 74/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0670 - accuracy: 0.9832 - val_loss: 0.8637 - val_accuracy: 0.8858
# Epoch 75/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0784 - accuracy: 0.9814 - val_loss: 1.0063 - val_accuracy: 0.8796
# Epoch 76/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0905 - accuracy: 0.9776 - val_loss: 0.8182 - val_accuracy: 0.8692
# Epoch 77/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0538 - accuracy: 0.9867 - val_loss: 0.9327 - val_accuracy: 0.8804
# Epoch 78/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0608 - accuracy: 0.9843 - val_loss: 0.8717 - val_accuracy: 0.8846
# Epoch 79/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0699 - accuracy: 0.9831 - val_loss: 0.9997 - val_accuracy: 0.8696
# Epoch 80/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0631 - accuracy: 0.9856 - val_loss: 1.0139 - val_accuracy: 0.8700
# Epoch 81/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0656 - accuracy: 0.9811 - val_loss: 0.9741 - val_accuracy: 0.8835
# Epoch 82/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0528 - accuracy: 0.9866 - val_loss: 1.0507 - val_accuracy: 0.8665
# Epoch 83/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0758 - accuracy: 0.9826 - val_loss: 1.0289 - val_accuracy: 0.8719
# Epoch 84/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0437 - accuracy: 0.9888 - val_loss: 1.1093 - val_accuracy: 0.8762
# Epoch 85/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0544 - accuracy: 0.9866 - val_loss: 1.0487 - val_accuracy: 0.8742
# Epoch 86/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0526 - accuracy: 0.9869 - val_loss: 0.9436 - val_accuracy: 0.8819
# Epoch 87/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0410 - accuracy: 0.9892 - val_loss: 0.8515 - val_accuracy: 0.8796
# Epoch 88/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0536 - accuracy: 0.9857 - val_loss: 0.9333 - val_accuracy: 0.8858
# Epoch 89/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0749 - accuracy: 0.9820 - val_loss: 0.8980 - val_accuracy: 0.8808
# Epoch 90/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0693 - accuracy: 0.9836 - val_loss: 1.0368 - val_accuracy: 0.8573
# Epoch 91/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0558 - accuracy: 0.9862 - val_loss: 0.8863 - val_accuracy: 0.8789
# Epoch 92/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0558 - accuracy: 0.9856 - val_loss: 1.1376 - val_accuracy: 0.8738
# Epoch 93/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0505 - accuracy: 0.9871 - val_loss: 0.9051 - val_accuracy: 0.8893
# Epoch 94/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0755 - accuracy: 0.9851 - val_loss: 1.0245 - val_accuracy: 0.8727
# Epoch 95/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0506 - accuracy: 0.9866 - val_loss: 1.0500 - val_accuracy: 0.8715
# Epoch 96/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0786 - accuracy: 0.9835 - val_loss: 1.1034 - val_accuracy: 0.8700
# Epoch 97/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0789 - accuracy: 0.9813 - val_loss: 1.1948 - val_accuracy: 0.8704
# Epoch 98/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0668 - accuracy: 0.9845 - val_loss: 1.1647 - val_accuracy: 0.8704
# Epoch 99/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0721 - accuracy: 0.9825 - val_loss: 1.1103 - val_accuracy: 0.8684
# Epoch 100/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0474 - accuracy: 0.9871 - val_loss: 1.1510 - val_accuracy: 0.8765

# %%
create_train_val_plot(improved_history.history)

# %% [markdown]
# Alleniamo il modello per 100 epoche (dobbiamo dargli più tempo per apprendere, 30 epoche non sarebbero bastate) e visualizziamo le **curve di addestramento** e **validazione**.
#
# L'obbiettivo di ridurre **l'overfitting è stato comunque raggiunto**, dato che il modello ha iniziato ad andare in overfitting verso **l'epoca 30**.

# %%
improved_best_model = tf.keras.models.load_model("bestmodels/improved_basic_model.keras")
test_loss, test_acc = improved_best_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 5ms/step - loss: 0.6036 - accuracy: 0.8512
# Accuratezza: 0.851

# %% [markdown]
# In questo caso non abbiamo ottenuto alcun tipo di miglioramento a livello di prestazioni, anzi è peggiorato!

# %%
for audio, label in test_ds:
    create_distribution_plot(improved_best_model, audio, label)
    break

# %% [markdown]
# In questo caso il modello era molto più indeciso di prima. Il modello aveva intuito potesse essere un audio con **classe no** ma era convinto fosse invece la **classe go**.

# %% [markdown]
# ## Miglioramenti all'architettura del modello
#
# Durante il corso abbiamo visto anche delle best practice architetturali che possono aiutare a ottenere maggiori prestazioni col modello. Il nostro scopo è provare le tecniche viste e studiate durante il corso e capire come reagiscono al task.

# %% [markdown]
# Le tre tecniche che andremo ad applicare sono:
# - blocchi residuali
# - normalizzazione dei batch
# - convoluzioni separabili

# %% [markdown]
# ### Blocchi residuali
# I blocchi residuali sono un'applicazione efficace quando riscontriamo il problema dei **gradienti che svaniscono**. Non sono una tecnica strettamente legata ai modelli convolutivi, ma sono una best practice generale che viene applicare nella maggior parte delle architetture.
#
# I **gradienti che vaniscono** sono causati dalle **catene di funzioni troppo lunghe**, che nel nostro caso non sono altro che **una sequenza di livelli convolutivi**. Per ogni livello convolutivo **una certa quantità di rumore** viene introdotta, finché essa non arriva a **sopraffare** le informazioni sul gradiente.
#
# Se le informazioni sul gradiente sono sopraffatte la **backpropagation smette di funzionare**, e quindi il nostro **modello non impara**.

# %% [markdown]
# L'**idea basilare** dietro ai blocchi residuali è quella di **salvare l'informazione** contenuta nell'input precedente al livello convolutivo, e **sommarla all'output** dello stesso livello convolutivo.

# %% [markdown]
# Per applicare i blocchi residuali abbiamo implementato la funzione `residual_block(x, filters, pooling=False)` vista a lezione. La funzione è ovviamente adattata al modello da noi implementato, e utilizza le altre due best practice citate precedentemente.

# %%
def residual_block(x, filters, pooling=False):
    residual = x

    x = tf.keras.layers.SeparableConv2D(filters, 3, padding="same", use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    if pooling:
      x = tf.keras.layers.MaxPooling2D(pool_size=2, padding="same")(x)
      residual = tf.keras.layers.Conv2D(filters, 1, strides=2)(residual)
    elif filters != residual.shape[-1]:
      residual = tf.keras.layers.Conv2D(filters, 1)(residual)

    x = tf.keras.layers.add([x, residual])
    return x

# %% [markdown]
# ### Normalizzazione dei batch e convoluzioni separabili
# La **normalizzazione dei batch** è un concetto che abbiamo già affrontato nel notebook, infatti il suo scopo rimane quello di rendere i dati **più simili tra loro** centrandoli sullo zero, e ciò aiuta la **propagazione del gradiente**. Questa normalizzazione, a differenza della precedente, è in grado di normalizzare i dati in modo adattivo anche quando la media e la varianza cambiano durante l'addestramento.

# %% [markdown]
# Le **convoluzione separabili** invece sono un **sostituto** ai livelli convolutivi utilizzati fino ad adesso, e offrono un modello con maggiori prestazioni e meno parametri.

# %%
def bp_basic_model():
    # input e pre processamento
    inputs = tf.keras.Input(shape=(124, 129, 1))
    # x = data_augmentation(inputs)
    x = tf.keras.layers.Resizing(120, 120)(inputs)

    x = residual_block(x, 32, pooling=True)
    x = residual_block(x, 64, pooling=True)
    x = residual_block(x, 128, pooling=True)
    x = residual_block(x, 256, pooling=True)
    x = residual_block(x, 256, pooling=False)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Livelli per la classificazione
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
bp_basic_model = bp_basic_model()
bp_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

bp_basic_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 124, 129, 1)]        0         []
#
#  resizing (Resizing)         (None, 120, 120, 1)          0         ['input_1[0][0]']
#
#  separable_conv2d (Separabl  (None, 120, 120, 32)         41        ['resizing[0][0]']
#  eConv2D)
#
#  batch_normalization (Batch  (None, 120, 120, 32)         128       ['separable_conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 120, 120, 32)         0         ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 60, 60, 32)           0         ['activation[0][0]']
#  D)
#
#  conv2d (Conv2D)             (None, 60, 60, 32)           64        ['resizing[0][0]']
#
#  add (Add)                   (None, 60, 60, 32)           0         ['max_pooling2d[0][0]',
#                                                                      'conv2d[0][0]']
#
#  separable_conv2d_1 (Separa  (None, 60, 60, 64)           2336      ['add[0][0]']
#  bleConv2D)
#
#  batch_normalization_1 (Bat  (None, 60, 60, 64)           256       ['separable_conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 60, 60, 64)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 30, 30, 64)           0         ['activation_1[0][0]']
#  g2D)
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 64)           2112      ['add[0][0]']
#
#  add_1 (Add)                 (None, 30, 30, 64)           0         ['max_pooling2d_1[0][0]',
#                                                                      'conv2d_1[0][0]']
#
#  separable_conv2d_2 (Separa  (None, 30, 30, 128)          8768      ['add_1[0][0]']
#  bleConv2D)
#
#  batch_normalization_2 (Bat  (None, 30, 30, 128)          512       ['separable_conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 30, 30, 128)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 15, 15, 128)          0         ['activation_2[0][0]']
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 128)          8320      ['add_1[0][0]']
#
#  add_2 (Add)                 (None, 15, 15, 128)          0         ['max_pooling2d_2[0][0]',
#                                                                      'conv2d_2[0][0]']
#
#  separable_conv2d_3 (Separa  (None, 15, 15, 256)          33920     ['add_2[0][0]']
#  bleConv2D)
#
#  batch_normalization_3 (Bat  (None, 15, 15, 256)          1024      ['separable_conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 15, 15, 256)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling2d_3 (MaxPoolin  (None, 8, 8, 256)            0         ['activation_3[0][0]']
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 256)            33024     ['add_2[0][0]']
#
#  add_3 (Add)                 (None, 8, 8, 256)            0         ['max_pooling2d_3[0][0]',
#                                                                      'conv2d_3[0][0]']
#
#  separable_conv2d_4 (Separa  (None, 8, 8, 256)            67840     ['add_3[0][0]']
#  bleConv2D)
#
#  batch_normalization_4 (Bat  (None, 8, 8, 256)            1024      ['separable_conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 8, 8, 256)            0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  add_4 (Add)                 (None, 8, 8, 256)            0         ['activation_4[0][0]',
#                                                                      'add_3[0][0]']
#
#  global_average_pooling2d (  (None, 256)                  0         ['add_4[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 256)                  0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 30)                   7710      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 167079 (652.65 KB)
# Trainable params: 165607 (646.90 KB)
# Non-trainable params: 1472 (5.75 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# Le best practice, insieme al `tf.keras.layers.GlobalAveragePooling2D()` applicato al posto del Flatten, hanno formato un modello con circa **160000 parametri addestrabili** (circa il 16% del modello precedente).

# %%
bp_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/bp_basic_model.keras", save_best_only=True, monitor="val_loss")]
bp_model_history = bp_basic_model.fit(train_ds, epochs=100, validation_data=val_ds, callbacks=bp_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 13s 24ms/step - loss: 3.2378 - accuracy: 0.1179 - val_loss: 3.3756 - val_accuracy: 0.0494
# Epoch 2/100
# 243/243 [==============================] - 4s 18ms/step - loss: 2.6439 - accuracy: 0.2548 - val_loss: 2.7566 - val_accuracy: 0.1894
# Epoch 3/100
# 243/243 [==============================] - 4s 18ms/step - loss: 2.1343 - accuracy: 0.4160 - val_loss: 2.1654 - val_accuracy: 0.3453
# Epoch 4/100
# 243/243 [==============================] - 4s 18ms/step - loss: 1.6222 - accuracy: 0.5597 - val_loss: 1.3254 - val_accuracy: 0.6624
# Epoch 5/100
# 243/243 [==============================] - 4s 18ms/step - loss: 1.2388 - accuracy: 0.6723 - val_loss: 1.2860 - val_accuracy: 0.6289
# Epoch 6/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.9851 - accuracy: 0.7427 - val_loss: 0.9526 - val_accuracy: 0.7431
# Epoch 7/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.8322 - accuracy: 0.7777 - val_loss: 0.8365 - val_accuracy: 0.7793
# Epoch 8/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.6994 - accuracy: 0.8106 - val_loss: 0.7651 - val_accuracy: 0.7878
# Epoch 9/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.6037 - accuracy: 0.8401 - val_loss: 0.7498 - val_accuracy: 0.7867
# Epoch 10/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.5565 - accuracy: 0.8466 - val_loss: 0.8364 - val_accuracy: 0.7689
# Epoch 11/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.4940 - accuracy: 0.8643 - val_loss: 0.7865 - val_accuracy: 0.7670
# Epoch 12/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.4430 - accuracy: 0.8767 - val_loss: 0.7605 - val_accuracy: 0.7762
# Epoch 13/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.4121 - accuracy: 0.8848 - val_loss: 0.6590 - val_accuracy: 0.8148
# Epoch 14/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.3832 - accuracy: 0.8964 - val_loss: 1.4139 - val_accuracy: 0.6655
# Epoch 15/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.3708 - accuracy: 0.8963 - val_loss: 0.7098 - val_accuracy: 0.8021
# Epoch 16/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.3200 - accuracy: 0.9115 - val_loss: 0.5456 - val_accuracy: 0.8526
# Epoch 17/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.3175 - accuracy: 0.9093 - val_loss: 0.5449 - val_accuracy: 0.8519
# Epoch 18/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.2760 - accuracy: 0.9218 - val_loss: 0.6664 - val_accuracy: 0.8156
# Epoch 19/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.2775 - accuracy: 0.9246 - val_loss: 0.5244 - val_accuracy: 0.8522
# Epoch 20/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.2670 - accuracy: 0.9278 - val_loss: 0.8161 - val_accuracy: 0.7959
# Epoch 21/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.2876 - accuracy: 0.9193 - val_loss: 0.5414 - val_accuracy: 0.8519
# Epoch 22/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.2342 - accuracy: 0.9357 - val_loss: 0.5735 - val_accuracy: 0.8453
# Epoch 23/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.2192 - accuracy: 0.9384 - val_loss: 0.5459 - val_accuracy: 0.8488
# Epoch 24/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.2085 - accuracy: 0.9430 - val_loss: 0.5743 - val_accuracy: 0.8476
# Epoch 25/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.2087 - accuracy: 0.9392 - val_loss: 1.0929 - val_accuracy: 0.7735
# Epoch 26/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.2162 - accuracy: 0.9427 - val_loss: 0.6218 - val_accuracy: 0.8360
# Epoch 27/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1772 - accuracy: 0.9521 - val_loss: 0.6447 - val_accuracy: 0.8333
# Epoch 28/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1933 - accuracy: 0.9461 - val_loss: 0.7761 - val_accuracy: 0.8152
# Epoch 29/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1810 - accuracy: 0.9495 - val_loss: 0.8647 - val_accuracy: 0.7886
# Epoch 30/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1940 - accuracy: 0.9441 - val_loss: 0.5774 - val_accuracy: 0.8561
# Epoch 31/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1836 - accuracy: 0.9483 - val_loss: 0.6015 - val_accuracy: 0.8453
# Epoch 32/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1731 - accuracy: 0.9522 - val_loss: 0.6839 - val_accuracy: 0.8395
# Epoch 33/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1571 - accuracy: 0.9572 - val_loss: 0.6029 - val_accuracy: 0.8476
# Epoch 34/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1456 - accuracy: 0.9591 - val_loss: 0.5736 - val_accuracy: 0.8600
# Epoch 35/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1628 - accuracy: 0.9573 - val_loss: 0.8692 - val_accuracy: 0.7847
# Epoch 36/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1568 - accuracy: 0.9545 - val_loss: 1.3300 - val_accuracy: 0.7242
# Epoch 37/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1636 - accuracy: 0.9552 - val_loss: 0.6754 - val_accuracy: 0.8395
# Epoch 38/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1591 - accuracy: 0.9561 - val_loss: 0.6372 - val_accuracy: 0.8492
# Epoch 39/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1313 - accuracy: 0.9646 - val_loss: 0.4528 - val_accuracy: 0.8823
# Epoch 40/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1274 - accuracy: 0.9657 - val_loss: 1.0642 - val_accuracy: 0.7566
# Epoch 41/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1472 - accuracy: 0.9589 - val_loss: 0.6584 - val_accuracy: 0.8349
# Epoch 42/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1678 - accuracy: 0.9518 - val_loss: 0.5819 - val_accuracy: 0.8638
# Epoch 43/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1268 - accuracy: 0.9647 - val_loss: 0.7618 - val_accuracy: 0.8399
# Epoch 44/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1211 - accuracy: 0.9678 - val_loss: 0.6671 - val_accuracy: 0.8383
# Epoch 45/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1186 - accuracy: 0.9664 - val_loss: 1.0952 - val_accuracy: 0.7643
# Epoch 46/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1142 - accuracy: 0.9689 - val_loss: 0.7056 - val_accuracy: 0.8515
# Epoch 47/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1255 - accuracy: 0.9669 - val_loss: 0.7319 - val_accuracy: 0.8326
# Epoch 48/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1256 - accuracy: 0.9668 - val_loss: 0.7003 - val_accuracy: 0.8438
# Epoch 49/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1553 - accuracy: 0.9546 - val_loss: 0.5215 - val_accuracy: 0.8792
# Epoch 50/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1006 - accuracy: 0.9732 - val_loss: 0.5035 - val_accuracy: 0.8812
# Epoch 51/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1007 - accuracy: 0.9738 - val_loss: 0.5546 - val_accuracy: 0.8669
# Epoch 52/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1197 - accuracy: 0.9679 - val_loss: 0.9860 - val_accuracy: 0.7940
# Epoch 53/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1284 - accuracy: 0.9635 - val_loss: 0.5856 - val_accuracy: 0.8615
# Epoch 54/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1139 - accuracy: 0.9706 - val_loss: 0.6347 - val_accuracy: 0.8657
# Epoch 55/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1218 - accuracy: 0.9646 - val_loss: 0.5690 - val_accuracy: 0.8646
# Epoch 56/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1411 - accuracy: 0.9624 - val_loss: 0.6282 - val_accuracy: 0.8430
# Epoch 57/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1058 - accuracy: 0.9702 - val_loss: 0.4872 - val_accuracy: 0.8731
# Epoch 58/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0911 - accuracy: 0.9754 - val_loss: 0.4586 - val_accuracy: 0.8920
# Epoch 59/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0923 - accuracy: 0.9755 - val_loss: 0.7269 - val_accuracy: 0.8453
# Epoch 60/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1189 - accuracy: 0.9677 - val_loss: 0.7185 - val_accuracy: 0.8441
# Epoch 61/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1045 - accuracy: 0.9720 - val_loss: 0.6322 - val_accuracy: 0.8673
# Epoch 62/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1304 - accuracy: 0.9634 - val_loss: 0.5351 - val_accuracy: 0.8781
# Epoch 63/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0832 - accuracy: 0.9784 - val_loss: 0.4260 - val_accuracy: 0.9062
# Epoch 64/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0709 - accuracy: 0.9826 - val_loss: 0.4804 - val_accuracy: 0.8885
# Epoch 65/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0765 - accuracy: 0.9784 - val_loss: 0.6600 - val_accuracy: 0.8592
# Epoch 66/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1420 - accuracy: 0.9595 - val_loss: 0.6728 - val_accuracy: 0.8476
# Epoch 67/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1022 - accuracy: 0.9707 - val_loss: 0.5916 - val_accuracy: 0.8692
# Epoch 68/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0978 - accuracy: 0.9723 - val_loss: 0.4360 - val_accuracy: 0.8997
# Epoch 69/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0773 - accuracy: 0.9791 - val_loss: 0.6560 - val_accuracy: 0.8561
# Epoch 70/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0769 - accuracy: 0.9791 - val_loss: 0.5829 - val_accuracy: 0.8665
# Epoch 71/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1055 - accuracy: 0.9710 - val_loss: 0.5333 - val_accuracy: 0.8804
# Epoch 72/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1025 - accuracy: 0.9707 - val_loss: 0.6890 - val_accuracy: 0.8565
# Epoch 73/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0956 - accuracy: 0.9729 - val_loss: 0.7680 - val_accuracy: 0.8430
# Epoch 74/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0993 - accuracy: 0.9719 - val_loss: 0.5382 - val_accuracy: 0.8781
# Epoch 75/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0791 - accuracy: 0.9777 - val_loss: 0.4735 - val_accuracy: 0.8935
# Epoch 76/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0772 - accuracy: 0.9812 - val_loss: 0.5490 - val_accuracy: 0.8823
# Epoch 77/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0830 - accuracy: 0.9771 - val_loss: 0.7557 - val_accuracy: 0.8410
# Epoch 78/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0812 - accuracy: 0.9777 - val_loss: 0.4958 - val_accuracy: 0.8789
# Epoch 79/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0871 - accuracy: 0.9767 - val_loss: 0.8208 - val_accuracy: 0.8484
# Epoch 80/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0941 - accuracy: 0.9727 - val_loss: 0.6087 - val_accuracy: 0.8727
# Epoch 81/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1031 - accuracy: 0.9723 - val_loss: 0.5009 - val_accuracy: 0.8819
# Epoch 82/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0875 - accuracy: 0.9763 - val_loss: 0.4810 - val_accuracy: 0.8885
# Epoch 83/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0750 - accuracy: 0.9790 - val_loss: 0.5340 - val_accuracy: 0.8773
# Epoch 84/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0756 - accuracy: 0.9798 - val_loss: 0.4444 - val_accuracy: 0.9028
# Epoch 85/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0615 - accuracy: 0.9838 - val_loss: 0.4890 - val_accuracy: 0.8981
# Epoch 86/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0629 - accuracy: 0.9836 - val_loss: 0.8197 - val_accuracy: 0.8368
# Epoch 87/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0600 - accuracy: 0.9839 - val_loss: 0.5390 - val_accuracy: 0.8850
# Epoch 88/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1250 - accuracy: 0.9639 - val_loss: 0.7271 - val_accuracy: 0.8565
# Epoch 89/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0849 - accuracy: 0.9768 - val_loss: 0.6650 - val_accuracy: 0.8650
# Epoch 90/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0902 - accuracy: 0.9746 - val_loss: 0.8360 - val_accuracy: 0.8368
# Epoch 91/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0910 - accuracy: 0.9727 - val_loss: 0.6042 - val_accuracy: 0.8765
# Epoch 92/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0651 - accuracy: 0.9827 - val_loss: 0.4824 - val_accuracy: 0.9001
# Epoch 93/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1126 - accuracy: 0.9692 - val_loss: 0.6261 - val_accuracy: 0.8546
# Epoch 94/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0885 - accuracy: 0.9763 - val_loss: 0.4124 - val_accuracy: 0.8962
# Epoch 95/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0556 - accuracy: 0.9847 - val_loss: 0.5668 - val_accuracy: 0.8816
# Epoch 96/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0627 - accuracy: 0.9831 - val_loss: 0.6426 - val_accuracy: 0.8600
# Epoch 97/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0668 - accuracy: 0.9826 - val_loss: 1.1595 - val_accuracy: 0.8059
# Epoch 98/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1071 - accuracy: 0.9697 - val_loss: 2.0845 - val_accuracy: 0.7029
# Epoch 99/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0757 - accuracy: 0.9795 - val_loss: 0.4289 - val_accuracy: 0.9047
# Epoch 100/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0516 - accuracy: 0.9861 - val_loss: 0.4720 - val_accuracy: 0.8989

# %%
create_train_val_plot(bp_model_history.history, overfit=False)

# %% [markdown]
# Possiamo notare che il modello **NON ha raggiunto l'overfitting**, infatti probabilmente 100 epoche di addestramento erano troppo poche. La **loss della validazione** stava continuando a scendere, e allo stesso tempo **l'accuratezza della validazione era crescente**.

# %%
best_bp_basic_model = tf.keras.models.load_model("bestmodels/bp_basic_model.keras")
test_loss, test_acc = best_bp_basic_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 2s 8ms/step - loss: 0.4379 - accuracy: 0.8989
# Accuratezza: 0.899

# %% [markdown]
# Non abbiamo ottenuto miglioramenti a livello di prestazioni rispetto al primo modello presentato, però ci siamo avvicinati molto con il **16% dei parametri**

# %%
for audio, label in test_ds:
    create_distribution_plot(best_bp_basic_model, audio, label)
    break

# %% [markdown]
# La decisione del modello in questo caso è nuovamente molto chiara.
