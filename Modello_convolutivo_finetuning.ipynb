# %% [markdown]
# # Modello convolutivo di base
# Lo scopo di questo notebook è creare un **modello convolutivo di base** con un'architettura semplice. In seguito, sarà interessante confrontare i risultati di questo primo modello con i risultati ottenuti da modelli più complessi, o pre addestrati.

# %% [markdown]
# Come al solito, si procede con l'importazione delle librerie utilizzate e la creazione dei set di allenamento e validazione.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd
import numpy as np
# per il modello con estensione .onnx
import onnxruntime as rt
import tf2onnx
import onnx

# %%
train_ds, validation_ds = tf.keras.utils.audio_dataset_from_directory(
    directory='../reduced_dataset/dataset/audio',
    validation_split=0.4, # stiamo mettendo da parte il 40% del dataset, che sarà suddiviso in validation set e test set
    shuffle=True,
    subset='both', # necessario se stiamo utilizzando validation_split (se no darebbe errore)
    seed=0 # necessario se stiamo utilizzando sia shuffle che validation_split (se no darebbe errore)
)

label_names = train_ds.class_names
# Out:
# Found 12933 files belonging to 30 classes.
# Using 7760 files for training.
# Using 5173 files for validation.

# %% [markdown]
# ## Funzioni per processamento dei dati

# %% [markdown]
# La prima funzione che ci tornerà utile è `squeeze(audio, labels)`, della quale abbiamo già visto l'implementazione e parlato del suo utilizzo nel notebook dove trattiamo gli spettrogrammi.

# %%
def squeeze(audio, labels):
    audio = tf.squeeze(audio, axis=-1)
    return audio, labels

# fonte: funzione presa dal seguente link: https://www.geeksforgeeks.org/audio-recognition-in-tensorflow/

# %%
train_ds = train_ds.map(squeeze, tf.data.AUTOTUNE)
validation_ds = validation_ds.map(squeeze, tf.data.AUTOTUNE)

audio, label = next(iter(train_ds))
print(audio.shape)
print(label.shape)
# Out:
# (32, 16000)
# (32,)

# %% [markdown]
# Una volta eseguito questa semplificazione, a partire dai tensori degli audio, creeremo gli spettrogrammi che sarannò presi come input dal modello convolutivo.

# %% [markdown]
# ## Conversione e suddivisione dataset
# Per la conversione del dataset utilizziamo due funzioni che abbiamo già definito nel notebook dove trattiamo gli spettrogrammi.

# %%
def get_spectrogram(waveform):
    spectrogram = tf.signal.stft(waveform, frame_length=255, frame_step=128)
    spectrogram = tf.abs(spectrogram)

    return spectrogram[..., tf.newaxis]

# fonte: funzione presa dal seguente link: https://www.geeksforgeeks.org/audio-recognition-in-tensorflow/

# %%
def get_spectrogram_dataset(dataset):
    dataset = dataset.map(lambda x, y: (get_spectrogram(x), y), num_parallel_calls=tf.data.AUTOTUNE)

    return dataset

# fonte: funzione presa dal seguente link: https://www.geeksforgeeks.org/audio-recognition-in-tensorflow/

# %% [markdown]
# Definite le due funzioni possiamo procedere a ottenere il nostro **training set**, **validation set**, e **test set** di spettrogrammi. La suddivisione di dati ricordo essere rispettivamente 60%, 20%, 20%.

# %%
train_ds = get_spectrogram_dataset(train_ds)
validation_ds = get_spectrogram_dataset(validation_ds)

val_ds = validation_ds.take(validation_ds.cardinality() // 2) # ho cambiato nome del validation_ds in modo tale da non creare problemi con l'istruzione seguente
test_ds = validation_ds.skip(validation_ds.cardinality() // 2)

# %%
print("Numero di audio training set:", len(train_ds) * 32)
print("Numero di audio validation set:", len(val_ds) * 32)
print("Numero di audio test set:", len(test_ds) * 32)
# Out:
# Numero di audio training set: 7776
# Numero di audio validation set: 2592
# Numero di audio test set: 2592

# %%
for audio, label in train_ds:
    print("Shape (forma) spettrogrammi:", audio.shape)

    spectrogram = np.squeeze(audio[0], axis=-1)
    spectrogram = np.log(spectrogram.T + np.finfo(float).eps)

    plt.imshow(spectrogram.T)
    plt.colorbar(format='%+2.0f dB') # barra laterale dei dB

    plt.title(f"Classe: {label_names[label[0].numpy()]}")
    break
# Out:
# Shape (forma) spettrogrammi: (32, 124, 129, 1)

# %% [markdown]
# La grandezza degli spettrogrammi, quindi delle immagini ottenute, è di **124x129**.

# %% [markdown]
# ## Creazione modello di base

# %% [markdown]
# Come modello implementiamo una rete neurale convolutiva. Questo modello ha un'architettura semplice e servirà da benchmark per i modelli futuri.
#
# La rete prende in ingresso tensori di forma **altezza x larghezza x canali**, rispettivamente di **124, 129, 1**. Per farla lavorare meglio normalizziamo i dati con la funzione `tf.keras.layers.Normalization()`. Questo livello sposta e ridimensiona gli input in una distribuzione centrata su 0 e con deviazione standard 1.

# %% [markdown]
# L'architettura del modello è suddivisa in **due blocchi** principali: un blocco per l'apprendimento delle caratteristiche e un blocco per la classificazione.
#
# Il **blocco di apprendimento delle caratteristiche** ha un'architettura formata da una serie di livelli convolutivi alternati a livelli di max pooling. Per ciascun livello convolutivo viene anche applicata la funzione di attivazione **ReLu** per applicare non linearità. Il blocco termina con un livello convolutivo di **256 filtri**, che corrispondono alla stessa quantità di filtri applicati dal livello convolutivo precedente.
#
# Terminato il blocco di apprendimento delle caratteristiche, è presente il **blocco di classificazione**, formato da un **livello di Flatten**, necessario per trasformare i dati in un vettore unidimensionali, e un **livello Dense**, necessario per la predizione della classe di appartenenza del dato. Quest'ultimo livello Dense ha **30 unità**, che corrispondono alle 30 classi del nostro task di classificazione multiclasse. La funzione di attivazione applicata dal livello Dense è la **softmax**, ideale per i task di classificazione multiclasse.
#
# La funzione **softmax**, a differenza della funzione **sigmoid** ci fornisce una distribuzione di probabilità sulle classi possibili (questa distribuzione saremo in grado di visualizzarla durante la valutazione del modello).

# %%
def get_basic_model():
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(124, 129, 1), name="inputs")
    x = tf.keras.layers.Normalization(name="normalizzazione")(inputs)

    # Blocco di apprendimento delle caratteristiche
    conv2D_1 = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same", name="conv2D_1")(x)
    MaxPooling2D_1 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_1")(conv2D_1)
    conv2D_2 = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same", name="conv2D_2")(MaxPooling2D_1)
    MaxPooling2D_2 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_2")(conv2D_2)
    conv2D_3 = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same", name="conv2D_3")(MaxPooling2D_2)
    MaxPooling2D_3 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_3")(conv2D_3)
    conv2D_4 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_4")(MaxPooling2D_3)
    MaxPooling2D_4 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_4")(conv2D_4)
    conv2D_5 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_5")(MaxPooling2D_4)

    # Blocco di classificazione
    Flatten = tf.keras.layers.Flatten(name="Flatten")(conv2D_5)
    outputs = tf.keras.layers.Dense(30, activation="softmax", name="dense_output")(Flatten)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# Nella prossima cella di codice dichiariamo l'**ottimizzatore** da utilizzare (rmsprop), le **metriche** di cui tenere traccia (accuratezza), e la funzione di perdita da utilizzare per il calcolo del gradiente. Nel nostro caso la **funzione di perdita** corrisponde alla `sparse_categorical_crossentropy`, una variante della `categorical_crossentropy`.
#
# La **sparse categorical crossentropy** viene utilizzata quando le classi sono rappresentate come interi, proprio come nel nostro caso.

# %%
basic_model = get_basic_model()
basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

basic_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inputs (InputLayer)         [(None, 124, 129, 1)]     0
#
#  normalizzazione (Normalizat  (None, 124, 129, 1)      3
#  ion)
#
#  conv2D_1 (Conv2D)           (None, 124, 129, 32)      320
#
#  MaxPooling2D_1 (MaxPooling2  (None, 62, 64, 32)       0
#  D)
#
#  conv2D_2 (Conv2D)           (None, 62, 64, 64)        18496
#
#  MaxPooling2D_2 (MaxPooling2  (None, 31, 32, 64)       0
#  D)
#
#  conv2D_3 (Conv2D)           (None, 31, 32, 128)       73856
#
#  MaxPooling2D_3 (MaxPooling2  (None, 15, 16, 128)      0
#  D)
#
#  conv2D_4 (Conv2D)           (None, 15, 16, 256)       295168
#
#  MaxPooling2D_4 (MaxPooling2  (None, 7, 8, 256)        0
#  D)
#
#  conv2D_5 (Conv2D)           (None, 7, 8, 256)         590080
#
#  Flatten (Flatten)           (None, 14336)             0
#
#  dense_output (Dense)        (None, 30)                430110
#
# =================================================================
# Total params: 1,408,033
# Trainable params: 1,408,030
# Non-trainable params: 3
# _________________________________________________________________

# %% [markdown]
# Il modello ha un totale di circa **1.4 milioni di parametri**, bilanciando complessità e capacità di apprendimento.

# %%
basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/basic_model.keras", save_best_only=True, monitor="val_loss")]
basic_model_history = basic_model.fit(train_ds, epochs=30, validation_data=val_ds, callbacks=basic_model_callbacks)
# Out:
# Epoch 1/30
# 243/243 [==============================] - 12s 14ms/step - loss: 2.3542 - accuracy: 0.3479 - val_loss: 1.3114 - val_accuracy: 0.6289
# Epoch 2/30
# 243/243 [==============================] - 3s 14ms/step - loss: 0.9984 - accuracy: 0.7168 - val_loss: 0.8832 - val_accuracy: 0.7535
# Epoch 3/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5506 - accuracy: 0.8451 - val_loss: 0.8191 - val_accuracy: 0.8110
# Epoch 4/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.3475 - accuracy: 0.9003 - val_loss: 0.6532 - val_accuracy: 0.8468
# Epoch 5/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.2454 - accuracy: 0.9278 - val_loss: 0.8342 - val_accuracy: 0.8611
# Epoch 6/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1838 - accuracy: 0.9474 - val_loss: 0.6575 - val_accuracy: 0.8596
# Epoch 7/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1421 - accuracy: 0.9598 - val_loss: 0.8594 - val_accuracy: 0.8576
# Epoch 8/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1231 - accuracy: 0.9675 - val_loss: 0.9365 - val_accuracy: 0.8484
# Epoch 9/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1060 - accuracy: 0.9709 - val_loss: 1.0061 - val_accuracy: 0.8657
# Epoch 10/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0993 - accuracy: 0.9760 - val_loss: 1.1748 - val_accuracy: 0.8727
# Epoch 11/30
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0951 - accuracy: 0.9762 - val_loss: 2.1593 - val_accuracy: 0.8233
# Epoch 12/30
# 243/243 [==============================] - 4s 16ms/step - loss: 0.0853 - accuracy: 0.9776 - val_loss: 1.6197 - val_accuracy: 0.8441
# Epoch 13/30
# 243/243 [==============================] - 4s 16ms/step - loss: 0.0983 - accuracy: 0.9786 - val_loss: 1.1821 - val_accuracy: 0.8762
# Epoch 14/30
# 243/243 [==============================] - 4s 15ms/step - loss: 0.0830 - accuracy: 0.9814 - val_loss: 1.2945 - val_accuracy: 0.8719
# Epoch 15/30
# 243/243 [==============================] - 4s 15ms/step - loss: 0.0802 - accuracy: 0.9817 - val_loss: 1.3587 - val_accuracy: 0.8580
# Epoch 16/30
# 243/243 [==============================] - 4s 15ms/step - loss: 0.0805 - accuracy: 0.9809 - val_loss: 2.9628 - val_accuracy: 0.8040
# Epoch 17/30
# 243/243 [==============================] - 4s 15ms/step - loss: 0.0878 - accuracy: 0.9843 - val_loss: 1.6271 - val_accuracy: 0.8650
# Epoch 18/30
# 243/243 [==============================] - 12s 50ms/step - loss: 0.0673 - accuracy: 0.9849 - val_loss: 1.9709 - val_accuracy: 0.8673
# Epoch 19/30
# 243/243 [==============================] - 24s 100ms/step - loss: 0.0867 - accuracy: 0.9830 - val_loss: 1.6486 - val_accuracy: 0.8561
# Epoch 20/30
# 243/243 [==============================] - 7s 28ms/step - loss: 0.0756 - accuracy: 0.9856 - val_loss: 2.2808 - val_accuracy: 0.8684
# Epoch 21/30
# 243/243 [==============================] - 6s 26ms/step - loss: 0.0826 - accuracy: 0.9862 - val_loss: 2.2490 - val_accuracy: 0.8607
# Epoch 22/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.0820 - accuracy: 0.9860 - val_loss: 4.3830 - val_accuracy: 0.8125
# Epoch 23/30
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0713 - accuracy: 0.9860 - val_loss: 2.4103 - val_accuracy: 0.8661
# Epoch 24/30
# 243/243 [==============================] - 7s 28ms/step - loss: 0.0774 - accuracy: 0.9852 - val_loss: 2.7718 - val_accuracy: 0.8650
# Epoch 25/30
# 243/243 [==============================] - 6s 25ms/step - loss: 0.0736 - accuracy: 0.9854 - val_loss: 2.6691 - val_accuracy: 0.8484
# Epoch 26/30
# 243/243 [==============================] - 8s 30ms/step - loss: 0.0791 - accuracy: 0.9887 - val_loss: 2.5190 - val_accuracy: 0.8684
# Epoch 27/30
# 243/243 [==============================] - 7s 30ms/step - loss: 0.0702 - accuracy: 0.9881 - val_loss: 3.9527 - val_accuracy: 0.8387
# Epoch 28/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0896 - accuracy: 0.9876 - val_loss: 2.9657 - val_accuracy: 0.8677
# Epoch 29/30
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1169 - accuracy: 0.9869 - val_loss: 2.5224 - val_accuracy: 0.8569
# Epoch 30/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0798 - accuracy: 0.9884 - val_loss: 3.1474 - val_accuracy: 0.8615

# %% [markdown]
# Alleniamo il modello per 30 epoche e visualizziamo le **curve di addestramento** e **validazione**.
#
# In modo tale da poter accedere ai dati del modello più facilmente in futuro trasformiamo la history del modello in un dataframe pandas. Questo facilità anche al visualizzazione dei dati salvati per un caso futuro.

# %%
def convert_history_to_csv(model_history):
    # converto la history del dataframe in un dataframe pandas
    model_history_df = pd.DataFrame(model_history.history)
    # cambio il nome dell'indice e lo imposto a partire da 1
    model_history_df.index = range(1, len(model_history_df) + 1)
    model_history_df.index.name = "epochs"

    return model_history_df

# %% [markdown]
# Salviamo i dati della history del modello in un file csv.

# %%
basic_model_history_df = convert_history_to_csv(basic_model_history)
basic_model_history_df.to_csv("model_histories/rmsprop/basic_model_history.csv")

# %% [markdown]
# Salviamo il miglior modello nella seguente directory `bestmodels/rmsprop/` con il nome `basic_model.keras`. L'estensione keras potrebbe crearci problemi di corruzioni se utilizziamo versioni differenti di pacchetti o python, perciò lo convertiamo nello standard onnx.

# %% [markdown]
# Per convertirlo nello standard onnx procediamo a utilizzare le librerie **tf2onnx** e **onnx**, importate precedentemente.

# %%
def convert_model_to_onnx(model_path, input_shape):
    model = tf.keras.models.load_model(model_path)

    onnx_path = model_path.split(".")[:-1] + ["onnx"]
    onnx_path = ".".join(onnx_path)
    
    input_signature = [tf.TensorSpec((None, *input_shape), tf.float32, name="input")]
    onnx_model, _ = tf2onnx.convert.from_keras(model, input_signature=input_signature)

    onnx.save(onnx_model, onnx_path)

# %%
convert_model_to_onnx("bestmodels/rmsprop/basic_model.keras", (124, 129, 1))

# %%
def create_train_val_plot(history, overfit=True):
    # definisco numero epoche
    epochs = range(1, len(history['accuracy']) + 1)

    # Accuracy
    accuracy = history['accuracy']
    val_accuracy = history['val_accuracy']

    fig_acc, ax_acc = plt.subplots()

    # linea di base
    ax_acc.plot(epochs, [0.5 for x in range(len(epochs))], color="lightgray", linestyle="--", label="Base")
    # linee di accuratezza
    ax_acc.plot(epochs, accuracy, color="slategray", label="Accuratezza in addestramento")
    ax_acc.plot(epochs, val_accuracy, color="indianred", label="Accuratezza in validazione")
    # miglior accuratezza validazione
    ax_acc.axhline(y=max(val_accuracy), c='indianred', alpha=0.7, linestyle='--')
    ax_acc.text(len(epochs) * 1.07, max(val_accuracy), round(max(val_accuracy), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_acc.spines["right"].set_visible(False)
    ax_acc.spines["top"].set_visible(False)
    ax_acc.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_acc.set_title("Accuratezza in addestramento e validazione")
    ax_acc.set_xlabel("Epoche")
    ax_acc.set_ylabel("Accuratezza (%)")
    ax_acc.legend()

    # Loss
    loss = history['loss']
    val_loss = history['val_loss']

    fig_loss, ax_loss = plt.subplots()

    # linee di loss
    ax_loss.plot(epochs, loss, color="slategray", label="Perdita in addestramento")
    ax_loss.plot(epochs, val_loss, color="indianred", label="Perdita in validazione")
    # miglior loss validazione
    ax_loss.axhline(y=min(val_loss), c='indianred', alpha=0.7, linestyle='--')
    ax_loss.text(len(epochs) * 1.07, min(val_loss), round(min(val_loss), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_loss.spines["right"].set_visible(False)
    ax_loss.spines["top"].set_visible(False)
    ax_loss.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_loss.set_title("Perdita in addestramento e validazione")
    ax_loss.set_xlabel("Epoche")
    ax_loss.set_ylabel("Perdita")

    handles, _ = ax_loss.get_legend_handles_labels()

    if overfit:
        # area overfit
        rect = mpatches.Rectangle((np.argmin(val_loss) + 1, 0), width=100 - np.argmin(val_loss), height=max(max(loss), max(val_loss)), color='lightcoral', alpha=0.3)
        ax_loss.add_patch(rect)
        # patch overfit per legenda
        overfit = mpatches.Patch(color='indianred', alpha=0.3, label='Area overfit')
        handles, _ = ax_loss.get_legend_handles_labels()
        handles.append(overfit)

    # legenda
    ax_loss.legend(handles=handles)

    plt.show()

# %%
create_train_val_plot(basic_model_history.history)

# %% [markdown]
# Questi grafici mostrano come il nostro modello sia andato immediatamente in overfitting. L'accuratezza dell'addestramento aumenta col tempo e raggiunge quasi il **100%**, mentre l'accuratezza della validazione si attesta sull'**85%** con un **picco del 88%**. La **perdita nel set di addestramento** continua a diminuire dopo la **quinta epoca**, mentre la **perdita nel set di validazione** aumenta.

# %% [markdown]
# Possiamo verificare l'accuratezza della migliore versione del nostro modello di base ricaricando il file **basic_model.keras**

# %%
best_basic_model = tf.keras.models.load_model("bestmodels/rmsprop/basic_model.keras")
test_loss, test_acc = best_basic_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 8ms/step - loss: 0.7476 - accuracy: 0.8268
# Accuratezza: 0.827

# %% [markdown]
# Oppure possiamo verificarla con il file **basic_model.onnx**

# %%
def evaluate_onnx_model(path_model_onnx, test_ds):
    # il fatto che sia suddiviso in batch mi crea problemi, perciò lo risolvo togliendoli
    test_ds = test_ds.unbatch()
    
    # carico il modello utilizzando il file onnx
    m = rt.InferenceSession(path_model_onnx)
    
    # trasformo il dataset in array numpy
    spectrogram_np = np.array([spectrogram.numpy() for spectrogram, _ in test_ds])
    labels_np = np.array([label.numpy() for _, label in test_ds])
    
    # eseguo le predizione del modello
    pred_onnx = m.run(None, {'input': spectrogram_np})
    # ottengo la predizione corretta
    predictions = np.argmax(pred_onnx[0], axis=1)
    # computo la accuratezza
    accuracy = np.mean(predictions == labels_np)
    # stampo l'accuratezza
    print(f"Accuratezza: {accuracy:.3f}")

# %%
evaluate_onnx_model("bestmodels/rmsprop/basic_model.onnx", test_ds)
# Out:
# Accuratezza: 0.827

# %% [markdown]
# Abbiamo ottenuto un'**accuratezza** del **84.3%**! Lo riteniamo un ottimo risultato considerato il task non banale.

# %% [markdown]
# Infine, creiamo una funzione utile a visualizzare graficamente la distribuzione di accuratezza delle classi su un'immagine casuale, per capire come ha lavorato il modello. Nel caso il modello non predica correttamente, la **classe corretta** verrà sempre evidenziata di **verde**, mentre la **classe predetta** verrà evidenziata di **giallo**.

# %%
def create_distribution_plot(model, audio, label):
    prediction = model(audio) # otteniamo la predizione del modello sull'audio preso in input

    random_audio_index = np.random.randint(0, len(prediction) - 1) # abbiamo notato che mostravamo sempre la classe no, magari così cambia un po' le classi che mostriamo

    softmax_pred = tf.nn.softmax(prediction[random_audio_index]) # dobbiamo applicare nuovamente la softmax in modo tale da avere dei dati leggibili
    pred_label = np.argmax(softmax_pred) # ci salviamo l'indice della label predetta dal nostro modello, quella con la probabilità più alta

    colors = ['indianred'] * len(label_names) # creiamo un vettore di lunghezza 30 (la quantità delle nostre label) colorate di rosso

    if pred_label == label[random_audio_index].numpy(): # se la label che abbiamo predetto è corretta, allora la coloriamo di verde
        colors[pred_label] = 'seagreen'
    else: # se la label che abbiamo predetto è sbagliata, allora coloriamo di verde la corretta e di gialla la predetta
        colors[pred_label] = 'khaki'
        colors[label[random_audio_index].numpy()] = 'seagreen'

    plt.figure(figsize=(12, 4))

    plt.bar(label_names, softmax_pred.numpy(), color=colors)
    plt.xticks(rotation=45)

    # dichiariamo i colori della legenda
    other_values_patch = mpatches.Patch(color='indianred', label='Altre classi')
    pred_value_patch = mpatches.Patch(color='khaki', label='Classe predetta')
    correct_value_patch = mpatches.Patch(color='green', label='Classe corretta')

    # disegniamo al legenda con i colori necessari
    if pred_label == label[random_audio_index].numpy(): # se abbiamo predetto correttamente la label, non è necessario mostrare il colore giallo (non è presente nel plot)
        plt.legend(handles=[other_values_patch, correct_value_patch])
    else:
        plt.legend(handles=[other_values_patch, pred_value_patch, correct_value_patch])

    plt.show()

# %%
for audio, label in test_ds: # prendiamo un audio a caso del test e creiamo la distribuzione
    create_distribution_plot(best_basic_model, audio, label)
    break

# %% [markdown]
# Possiamo notare dalla distribuzione che il modello in questo caso ha predetto erroneamente la **classe up**. Da un modello così basilare possiamo aspettarci qualche errore.

# %% [markdown]
# ### Risoluzione dell'overfitting
# Abbiamo capito che il modello è andato immediatamente in **overfitting**, e lo possiamo notare dalla loss di validazione che inizia a salire dalla quinta epoca in poi. L'obbiettivo principale in questo momento è evitare che vada in overfitting troppo velocemente, applicando le tecniche viste a lezione.

# %% [markdown]
# Attualmente per ridurre l'overfitting applichiamo **un livello di Dropout**. Il livello di dropout imposta **randomicamente** delle attivazioni a 0, perciò stiamo disattivando qualche neurone. Nello specifico stiamo **azzerando** un certo numero di caratteristiche di uscita dello strato Dense. L'idea dietro questa tecnica è quella di mettere in difficoltà il modello.

# %%
def get_improved_basic_model_tuning(start_filters):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(124, 129, 1))
    x = tf.keras.layers.Normalization()(inputs)

    if not isinstance(start_filters, int):
        raise Exception("start_filters must be type integer")

    filters = [start_filters * (2 ** i) for i in range(4)]
    
    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=filters[0], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[1], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[2], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[3], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[3], kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
def tuner(filters, learning_rates, max_epochs, train_dataset, validation_dataset):
    start_time = time.time()

    counter = 1
    
    if not isinstance(filters, list):
        raise Exception("parameter filters must be type list")

    if not isinstance(learning_rates, list):
        raise Exception("parameter learning_rates must be type list")

    callbacks = [tf.keras.callbacks.EarlyStopping(monitor="val_accuracy", patience=5)]

    best_learning_rate = 0 
    best_filters = 0
    best_val_accuracy = 0
    
    for f in filters:
        for lr in learning_rates:
            print(f"\nTraining for filters={[f * (2 ** i) for i in range(4)]} and learning_rate={lr}")
            
            model = get_improved_basic_model_tuning(start_filters=f)
            model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.RMSprop(learning_rate=lr), metrics=["accuracy"])
            model_history = model.fit(train_dataset, epochs=max_epochs, validation_data=validation_dataset, callbacks=callbacks)

            model_history_df = convert_history_to_csv(model_history)

            model_history_df[["filters"]] = f
            model_history_df[["learning_rate"]] = lr
            
            path = "model_tuning/histories/model_" + str(counter) + ".csv"
            model_history_df.to_csv(path)
            
            if best_val_accuracy < model_history_df.iloc[-1]["val_accuracy"]:
                best_val_accuracy = model_history_df.iloc[-1]["val_accuracy"]
                best_filters = f
                best_learning_rate = lr
                epoch = len(model_history_df)

            del model

            counter += 1

    total_time = time.time() - start_time
    minutes, seconds = divmod(total_time, 60)
    print(f"Tempo totale: {int(minutes)} minuti e {seconds:.2f} secondi")
    print(f"Il miglior modello ha un filtro di partenza pari a {best_filters}, un learning rate pari a {best_learning_rate} con un'accuracy pari a {best_val_accuracy:.3f}")

    return best_filters, best_learning_rate

# %%
best_filter, best_learning_rate = tuner([16, 32, 64], [1e-2, 1e-3, 1e-4], 30, train_ds, val_ds)
# Out:
# Training for filters=[16, 32, 64, 128] and learning_rate=0.01
# Epoch 1/30
# 243/243 [==============================] - 3s 10ms/step - loss: 4.4084 - accuracy: 0.0362 - val_loss: 3.3933 - val_accuracy: 0.0285
# Epoch 2/30
# 243/243 [==============================] - 2s 9ms/step - loss: 3.4391 - accuracy: 0.0365 - val_loss: 3.3950 - val_accuracy: 0.0347
# Epoch 3/30
# 243/243 [==============================] - 2s 8ms/step - loss: 3.3978 - accuracy: 0.0363 - val_loss: 3.3944 - val_accuracy: 0.0285
# Epoch 4/30
# 243/243 [==============================] - 2s 9ms/step - loss: 3.3938 - accuracy: 0.0361 - val_loss: 3.3938 - val_accuracy: 0.0343
# Epoch 5/30
# 243/243 [==============================] - 2s 9ms/step - loss: 3.3935 - accuracy: 0.0371 - val_loss: 3.3939 - val_accuracy: 0.0285
# Epoch 6/30
# 243/243 [==============================] - 2s 10ms/step - loss: 3.3937 - accuracy: 0.0358 - val_loss: 3.3942 - val_accuracy: 0.0343
# Epoch 7/30
# 243/243 [==============================] - 2s 9ms/step - loss: 3.3937 - accuracy: 0.0360 - val_loss: 3.3941 - val_accuracy: 0.0343
#
# Training for filters=[16, 32, 64, 128] and learning_rate=0.001
# Epoch 1/30
# 243/243 [==============================] - 3s 11ms/step - loss: 2.6124 - accuracy: 0.2718 - val_loss: 1.8014 - val_accuracy: 0.4823
# Epoch 2/30
# 243/243 [==============================] - 3s 11ms/step - loss: 1.4504 - accuracy: 0.5941 - val_loss: 1.1476 - val_accuracy: 0.6875
# Epoch 3/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.9171 - accuracy: 0.7383 - val_loss: 0.8040 - val_accuracy: 0.7824
# Epoch 4/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.6437 - accuracy: 0.8155 - val_loss: 0.7634 - val_accuracy: 0.7909
# Epoch 5/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.4953 - accuracy: 0.8528 - val_loss: 0.7737 - val_accuracy: 0.7828
# Epoch 6/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.3987 - accuracy: 0.8823 - val_loss: 0.5258 - val_accuracy: 0.8453
# Epoch 7/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.3243 - accuracy: 0.9043 - val_loss: 0.7606 - val_accuracy: 0.8492
# Epoch 8/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2685 - accuracy: 0.9183 - val_loss: 0.5082 - val_accuracy: 0.8688
# Epoch 9/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.2356 - accuracy: 0.9289 - val_loss: 0.7438 - val_accuracy: 0.8407
# Epoch 10/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.2040 - accuracy: 0.9375 - val_loss: 0.6388 - val_accuracy: 0.8646
# Epoch 11/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1768 - accuracy: 0.9473 - val_loss: 0.6545 - val_accuracy: 0.8727
# Epoch 12/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.1737 - accuracy: 0.9488 - val_loss: 0.7385 - val_accuracy: 0.8665
# Epoch 13/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.1460 - accuracy: 0.9557 - val_loss: 0.6749 - val_accuracy: 0.8696
# Epoch 14/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1453 - accuracy: 0.9558 - val_loss: 0.5242 - val_accuracy: 0.8750
# Epoch 15/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.1257 - accuracy: 0.9622 - val_loss: 0.7731 - val_accuracy: 0.8804
# Epoch 16/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1338 - accuracy: 0.9610 - val_loss: 0.9100 - val_accuracy: 0.8634
# Epoch 17/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1215 - accuracy: 0.9656 - val_loss: 0.7061 - val_accuracy: 0.8812
# Epoch 18/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.1212 - accuracy: 0.9617 - val_loss: 0.6677 - val_accuracy: 0.8816
# Epoch 19/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1049 - accuracy: 0.9702 - val_loss: 0.8758 - val_accuracy: 0.8638
# Epoch 20/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.1043 - accuracy: 0.9695 - val_loss: 0.7633 - val_accuracy: 0.8823
# Epoch 21/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.0995 - accuracy: 0.9719 - val_loss: 0.8158 - val_accuracy: 0.8862
# Epoch 22/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1088 - accuracy: 0.9686 - val_loss: 0.8523 - val_accuracy: 0.8738
# Epoch 23/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1018 - accuracy: 0.9707 - val_loss: 0.9173 - val_accuracy: 0.8738
# Epoch 24/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1086 - accuracy: 0.9706 - val_loss: 0.8892 - val_accuracy: 0.8773
# Epoch 25/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0959 - accuracy: 0.9737 - val_loss: 0.6853 - val_accuracy: 0.8912
# Epoch 26/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0988 - accuracy: 0.9753 - val_loss: 0.8513 - val_accuracy: 0.8858
# Epoch 27/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1064 - accuracy: 0.9718 - val_loss: 0.8672 - val_accuracy: 0.8850
# Epoch 28/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0983 - accuracy: 0.9741 - val_loss: 0.8673 - val_accuracy: 0.8681
# Epoch 29/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0925 - accuracy: 0.9753 - val_loss: 1.4191 - val_accuracy: 0.8688
# Epoch 30/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1020 - accuracy: 0.9738 - val_loss: 1.1200 - val_accuracy: 0.8870
#
# Training for filters=[16, 32, 64, 128] and learning_rate=0.0001
# Epoch 1/30
# 243/243 [==============================] - 3s 10ms/step - loss: 3.2475 - accuracy: 0.1094 - val_loss: 2.9325 - val_accuracy: 0.2446
# Epoch 2/30
# 243/243 [==============================] - 3s 11ms/step - loss: 2.8174 - accuracy: 0.2392 - val_loss: 2.5835 - val_accuracy: 0.3530
# Epoch 3/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.5328 - accuracy: 0.3286 - val_loss: 2.3365 - val_accuracy: 0.4082
# Epoch 4/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.2780 - accuracy: 0.4021 - val_loss: 2.1070 - val_accuracy: 0.4641
# Epoch 5/30
# 243/243 [==============================] - 3s 10ms/step - loss: 2.0444 - accuracy: 0.4612 - val_loss: 1.9470 - val_accuracy: 0.5046
# Epoch 6/30
# 243/243 [==============================] - 2s 9ms/step - loss: 1.8451 - accuracy: 0.5216 - val_loss: 1.7845 - val_accuracy: 0.5343
# Epoch 7/30
# 243/243 [==============================] - 2s 9ms/step - loss: 1.6663 - accuracy: 0.5584 - val_loss: 1.6147 - val_accuracy: 0.6042
# Epoch 8/30
# 243/243 [==============================] - 2s 9ms/step - loss: 1.5145 - accuracy: 0.6073 - val_loss: 1.4985 - val_accuracy: 0.6285
# Epoch 9/30
# 243/243 [==============================] - 3s 11ms/step - loss: 1.3665 - accuracy: 0.6479 - val_loss: 1.3688 - val_accuracy: 0.6682
# Epoch 10/30
# 243/243 [==============================] - 3s 11ms/step - loss: 1.2371 - accuracy: 0.6790 - val_loss: 1.3078 - val_accuracy: 0.6755
# Epoch 11/30
# 243/243 [==============================] - 3s 11ms/step - loss: 1.1195 - accuracy: 0.7035 - val_loss: 1.1860 - val_accuracy: 0.7184
# Epoch 12/30
# 243/243 [==============================] - 3s 11ms/step - loss: 1.0278 - accuracy: 0.7296 - val_loss: 1.1615 - val_accuracy: 0.7149
# Epoch 13/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.9450 - accuracy: 0.7491 - val_loss: 1.0786 - val_accuracy: 0.7388
# Epoch 14/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.8761 - accuracy: 0.7661 - val_loss: 1.0452 - val_accuracy: 0.7554
# Epoch 15/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.8210 - accuracy: 0.7834 - val_loss: 1.0256 - val_accuracy: 0.7635
# Epoch 16/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.7775 - accuracy: 0.7898 - val_loss: 1.0106 - val_accuracy: 0.7523
# Epoch 17/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.7172 - accuracy: 0.8063 - val_loss: 0.9786 - val_accuracy: 0.7627
# Epoch 18/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.6739 - accuracy: 0.8219 - val_loss: 0.9304 - val_accuracy: 0.7797
# Epoch 19/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.6360 - accuracy: 0.8299 - val_loss: 0.9750 - val_accuracy: 0.7724
# Epoch 20/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.6038 - accuracy: 0.8339 - val_loss: 0.8599 - val_accuracy: 0.7870
# Epoch 21/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.5658 - accuracy: 0.8409 - val_loss: 1.0025 - val_accuracy: 0.7677
# Epoch 22/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.5337 - accuracy: 0.8545 - val_loss: 0.8647 - val_accuracy: 0.7990
# Epoch 23/30
# 243/243 [==============================] - 2s 10ms/step - loss: 0.4992 - accuracy: 0.8619 - val_loss: 0.8507 - val_accuracy: 0.7948
# Epoch 24/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.4740 - accuracy: 0.8701 - val_loss: 0.8633 - val_accuracy: 0.8032
# Epoch 25/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.4582 - accuracy: 0.8687 - val_loss: 0.8399 - val_accuracy: 0.7990
# Epoch 26/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.4353 - accuracy: 0.8796 - val_loss: 0.8234 - val_accuracy: 0.8175
# Epoch 27/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.4071 - accuracy: 0.8839 - val_loss: 0.8150 - val_accuracy: 0.8137
# Epoch 28/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.3965 - accuracy: 0.8867 - val_loss: 0.9412 - val_accuracy: 0.7901
# Epoch 29/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.3751 - accuracy: 0.8937 - val_loss: 0.8803 - val_accuracy: 0.8140
# Epoch 30/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.3454 - accuracy: 0.9012 - val_loss: 0.8730 - val_accuracy: 0.8160
#
# Training for filters=[32, 64, 128, 256] and learning_rate=0.01
# Epoch 1/30
# 243/243 [==============================] - 4s 14ms/step - loss: 147.7192 - accuracy: 0.0384 - val_loss: 10.7879 - val_accuracy: 0.0343
# Epoch 2/30
# 243/243 [==============================] - 4s 15ms/step - loss: 3.4239 - accuracy: 0.0370 - val_loss: 3.3943 - val_accuracy: 0.0343
# Epoch 3/30
# 243/243 [==============================] - 3s 13ms/step - loss: 3.3936 - accuracy: 0.0380 - val_loss: 3.3939 - val_accuracy: 0.0285
# Epoch 4/30
# 243/243 [==============================] - 3s 13ms/step - loss: 3.3935 - accuracy: 0.0370 - val_loss: 3.3941 - val_accuracy: 0.0285
# Epoch 5/30
# 243/243 [==============================] - 5s 20ms/step - loss: 3.3936 - accuracy: 0.0352 - val_loss: 3.3944 - val_accuracy: 0.0285
# Epoch 6/30
# 243/243 [==============================] - 4s 16ms/step - loss: 3.3934 - accuracy: 0.0352 - val_loss: 3.3938 - val_accuracy: 0.0343
#
# Training for filters=[32, 64, 128, 256] and learning_rate=0.001
# Epoch 1/30
# 243/243 [==============================] - 4s 14ms/step - loss: 2.5472 - accuracy: 0.2921 - val_loss: 1.5509 - val_accuracy: 0.5621
# Epoch 2/30
# 243/243 [==============================] - 3s 14ms/step - loss: 1.1630 - accuracy: 0.6714 - val_loss: 0.9794 - val_accuracy: 0.7531
# Epoch 3/30
# 243/243 [==============================] - 4s 15ms/step - loss: 0.6871 - accuracy: 0.8052 - val_loss: 0.6964 - val_accuracy: 0.8187
# Epoch 4/30
# 243/243 [==============================] - 4s 15ms/step - loss: 0.4764 - accuracy: 0.8617 - val_loss: 0.9875 - val_accuracy: 0.7724
# Epoch 5/30
# 243/243 [==============================] - 5s 20ms/step - loss: 0.3710 - accuracy: 0.8938 - val_loss: 0.5254 - val_accuracy: 0.8704
# Epoch 6/30
# 243/243 [==============================] - 4s 16ms/step - loss: 0.2689 - accuracy: 0.9187 - val_loss: 0.5641 - val_accuracy: 0.8546
# Epoch 7/30
# 243/243 [==============================] - 3s 14ms/step - loss: 0.2292 - accuracy: 0.9294 - val_loss: 0.6899 - val_accuracy: 0.8619
# Epoch 8/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1907 - accuracy: 0.9436 - val_loss: 0.5836 - val_accuracy: 0.8858
# Epoch 9/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1721 - accuracy: 0.9509 - val_loss: 0.8630 - val_accuracy: 0.8789
# Epoch 10/30
# 243/243 [==============================] - 4s 15ms/step - loss: 0.1690 - accuracy: 0.9541 - val_loss: 0.7901 - val_accuracy: 0.8434
# Epoch 11/30
# 243/243 [==============================] - 4s 16ms/step - loss: 0.1505 - accuracy: 0.9571 - val_loss: 0.7051 - val_accuracy: 0.8870
# Epoch 12/30
# 243/243 [==============================] - 6s 23ms/step - loss: 0.1413 - accuracy: 0.9634 - val_loss: 1.0358 - val_accuracy: 0.8769
# Epoch 13/30
# 243/243 [==============================] - 3s 14ms/step - loss: 0.1379 - accuracy: 0.9633 - val_loss: 0.8870 - val_accuracy: 0.8696
# Epoch 14/30
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1372 - accuracy: 0.9630 - val_loss: 1.1504 - val_accuracy: 0.8492
# Epoch 15/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1211 - accuracy: 0.9678 - val_loss: 0.9197 - val_accuracy: 0.8765
# Epoch 16/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1322 - accuracy: 0.9673 - val_loss: 0.8236 - val_accuracy: 0.8889
# Epoch 17/30
# 243/243 [==============================] - 3s 14ms/step - loss: 0.1065 - accuracy: 0.9698 - val_loss: 1.1566 - val_accuracy: 0.8827
# Epoch 18/30
# 243/243 [==============================] - 3s 14ms/step - loss: 0.1134 - accuracy: 0.9733 - val_loss: 0.9214 - val_accuracy: 0.8661
# Epoch 19/30
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1190 - accuracy: 0.9707 - val_loss: 1.0692 - val_accuracy: 0.8758
# Epoch 20/30
# 243/243 [==============================] - 4s 15ms/step - loss: 0.1082 - accuracy: 0.9740 - val_loss: 1.3522 - val_accuracy: 0.8654
# Epoch 21/30
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0984 - accuracy: 0.9759 - val_loss: 1.1985 - val_accuracy: 0.8854
#
# Training for filters=[32, 64, 128, 256] and learning_rate=0.0001
# Epoch 1/30
# 243/243 [==============================] - 4s 15ms/step - loss: 3.0955 - accuracy: 0.1555 - val_loss: 2.6775 - val_accuracy: 0.3191
# Epoch 2/30
# 243/243 [==============================] - 4s 15ms/step - loss: 2.5360 - accuracy: 0.3196 - val_loss: 2.2438 - val_accuracy: 0.4302
# Epoch 3/30
# 243/243 [==============================] - 3s 14ms/step - loss: 2.1290 - accuracy: 0.4460 - val_loss: 2.0297 - val_accuracy: 0.4842
# Epoch 4/30
# 243/243 [==============================] - 4s 18ms/step - loss: 1.7886 - accuracy: 0.5428 - val_loss: 1.6765 - val_accuracy: 0.5802
# Epoch 5/30
# 243/243 [==============================] - 6s 25ms/step - loss: 1.4897 - accuracy: 0.6170 - val_loss: 1.3841 - val_accuracy: 0.6609
# Epoch 6/30
# 243/243 [==============================] - 4s 17ms/step - loss: 1.2485 - accuracy: 0.6765 - val_loss: 1.2406 - val_accuracy: 0.6825
# Epoch 7/30
# 243/243 [==============================] - 4s 15ms/step - loss: 1.0653 - accuracy: 0.7271 - val_loss: 1.2332 - val_accuracy: 0.6844
# Epoch 8/30
# 243/243 [==============================] - 4s 17ms/step - loss: 0.9216 - accuracy: 0.7606 - val_loss: 1.0543 - val_accuracy: 0.7373
# Epoch 9/30
# 243/243 [==============================] - 6s 22ms/step - loss: 0.8118 - accuracy: 0.7865 - val_loss: 0.9371 - val_accuracy: 0.7685
# Epoch 10/30
# 243/243 [==============================] - 4s 15ms/step - loss: 0.7161 - accuracy: 0.8122 - val_loss: 0.9822 - val_accuracy: 0.7523
# Epoch 11/30
# 243/243 [==============================] - 4s 15ms/step - loss: 0.6263 - accuracy: 0.8274 - val_loss: 0.9472 - val_accuracy: 0.7870
# Epoch 12/30
# 243/243 [==============================] - 4s 16ms/step - loss: 0.5651 - accuracy: 0.8482 - val_loss: 0.7843 - val_accuracy: 0.8002
# Epoch 13/30
# 243/243 [==============================] - 4s 15ms/step - loss: 0.5104 - accuracy: 0.8575 - val_loss: 0.9760 - val_accuracy: 0.7523
# Epoch 14/30
# 243/243 [==============================] - 4s 15ms/step - loss: 0.4587 - accuracy: 0.8713 - val_loss: 0.7239 - val_accuracy: 0.8287
# Epoch 15/30
# 243/243 [==============================] - 4s 15ms/step - loss: 0.4134 - accuracy: 0.8869 - val_loss: 0.7879 - val_accuracy: 0.8152
# Epoch 16/30
# 243/243 [==============================] - 4s 15ms/step - loss: 0.3780 - accuracy: 0.8932 - val_loss: 0.9663 - val_accuracy: 0.7870
# Epoch 17/30
# 243/243 [==============================] - 4s 17ms/step - loss: 0.3446 - accuracy: 0.9026 - val_loss: 0.8685 - val_accuracy: 0.8179
# Epoch 18/30
# 243/243 [==============================] - 5s 19ms/step - loss: 0.3157 - accuracy: 0.9106 - val_loss: 0.9431 - val_accuracy: 0.8164
# Epoch 19/30
# 243/243 [==============================] - 4s 16ms/step - loss: 0.2926 - accuracy: 0.9165 - val_loss: 0.7341 - val_accuracy: 0.8353
# Epoch 20/30
# 243/243 [==============================] - 6s 26ms/step - loss: 0.2716 - accuracy: 0.9195 - val_loss: 0.6801 - val_accuracy: 0.8387
# Epoch 21/30
# 243/243 [==============================] - 6s 23ms/step - loss: 0.2490 - accuracy: 0.9286 - val_loss: 0.8133 - val_accuracy: 0.8326
# Epoch 22/30
# 243/243 [==============================] - 6s 24ms/step - loss: 0.2246 - accuracy: 0.9349 - val_loss: 0.8545 - val_accuracy: 0.8426
# Epoch 23/30
# 243/243 [==============================] - 6s 22ms/step - loss: 0.2103 - accuracy: 0.9381 - val_loss: 0.8975 - val_accuracy: 0.8241
# Epoch 24/30
# 243/243 [==============================] - 5s 19ms/step - loss: 0.2000 - accuracy: 0.9392 - val_loss: 0.6993 - val_accuracy: 0.8418
# Epoch 25/30
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1878 - accuracy: 0.9447 - val_loss: 1.0620 - val_accuracy: 0.8434
# Epoch 26/30
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1730 - accuracy: 0.9476 - val_loss: 0.7873 - val_accuracy: 0.8542
# Epoch 27/30
# 243/243 [==============================] - 6s 25ms/step - loss: 0.1579 - accuracy: 0.9521 - val_loss: 0.9608 - val_accuracy: 0.8341
# Epoch 28/30
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1552 - accuracy: 0.9537 - val_loss: 0.7442 - val_accuracy: 0.8569
# Epoch 29/30
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1482 - accuracy: 0.9555 - val_loss: 1.2746 - val_accuracy: 0.7959
# Epoch 30/30
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1376 - accuracy: 0.9598 - val_loss: 0.7838 - val_accuracy: 0.8611
#
# Training for filters=[64, 128, 256, 512] and learning_rate=0.01
# Epoch 1/30
# 243/243 [==============================] - 7s 28ms/step - loss: 5169.2275 - accuracy: 0.0325 - val_loss: 3.3945 - val_accuracy: 0.0343
# Epoch 2/30
# 243/243 [==============================] - 7s 27ms/step - loss: 3.5432 - accuracy: 0.0367 - val_loss: 3.3951 - val_accuracy: 0.0343
# Epoch 3/30
# 243/243 [==============================] - 11s 44ms/step - loss: 3.4730 - accuracy: 0.0361 - val_loss: 3.3937 - val_accuracy: 0.0285
# Epoch 4/30
# 243/243 [==============================] - 16s 63ms/step - loss: 3.3938 - accuracy: 0.0362 - val_loss: 3.3943 - val_accuracy: 0.0285
# Epoch 5/30
# 243/243 [==============================] - 17s 68ms/step - loss: 3.4447 - accuracy: 0.0367 - val_loss: 3.3939 - val_accuracy: 0.0285
# Epoch 6/30
# 243/243 [==============================] - 17s 69ms/step - loss: 3.3937 - accuracy: 0.0363 - val_loss: 3.3949 - val_accuracy: 0.0285
#
# Training for filters=[64, 128, 256, 512] and learning_rate=0.001
# Epoch 1/30
# 243/243 [==============================] - 16s 63ms/step - loss: 2.6277 - accuracy: 0.3008 - val_loss: 1.4022 - val_accuracy: 0.5976
# Epoch 2/30
# 243/243 [==============================] - 17s 71ms/step - loss: 1.1219 - accuracy: 0.6782 - val_loss: 1.3427 - val_accuracy: 0.6651
# Epoch 3/30
# 243/243 [==============================] - 18s 75ms/step - loss: 0.6407 - accuracy: 0.8178 - val_loss: 0.8011 - val_accuracy: 0.8110
# Epoch 4/30
# 243/243 [==============================] - 17s 68ms/step - loss: 0.4410 - accuracy: 0.8723 - val_loss: 0.5199 - val_accuracy: 0.8711
# Epoch 5/30
# 243/243 [==============================] - 14s 57ms/step - loss: 0.3187 - accuracy: 0.9059 - val_loss: 0.8543 - val_accuracy: 0.8310
# Epoch 6/30
# 243/243 [==============================] - 16s 66ms/step - loss: 0.2538 - accuracy: 0.9265 - val_loss: 0.6475 - val_accuracy: 0.8677
# Epoch 7/30
# 243/243 [==============================] - 16s 64ms/step - loss: 0.2144 - accuracy: 0.9392 - val_loss: 0.6373 - val_accuracy: 0.8781
# Epoch 8/30
# 243/243 [==============================] - 15s 61ms/step - loss: 0.1943 - accuracy: 0.9478 - val_loss: 0.7118 - val_accuracy: 0.8727
# Epoch 9/30
# 243/243 [==============================] - 17s 71ms/step - loss: 0.1638 - accuracy: 0.9553 - val_loss: 0.7394 - val_accuracy: 0.8715
# Epoch 10/30
# 243/243 [==============================] - 16s 66ms/step - loss: 0.1612 - accuracy: 0.9564 - val_loss: 0.7391 - val_accuracy: 0.8762
# Epoch 11/30
# 243/243 [==============================] - 17s 69ms/step - loss: 0.1521 - accuracy: 0.9621 - val_loss: 0.6656 - val_accuracy: 0.8758
# Epoch 12/30
# 243/243 [==============================] - 15s 60ms/step - loss: 0.1527 - accuracy: 0.9616 - val_loss: 1.3131 - val_accuracy: 0.8322
#
# Training for filters=[64, 128, 256, 512] and learning_rate=0.0001
# Epoch 1/30
# 243/243 [==============================] - 17s 67ms/step - loss: 2.9583 - accuracy: 0.1947 - val_loss: 2.6018 - val_accuracy: 0.2782
# Epoch 2/30
# 243/243 [==============================] - 15s 62ms/step - loss: 2.1728 - accuracy: 0.4214 - val_loss: 1.9210 - val_accuracy: 0.4958
# Epoch 3/30
# 243/243 [==============================] - 12s 49ms/step - loss: 1.5958 - accuracy: 0.5759 - val_loss: 1.4990 - val_accuracy: 0.5934
# Epoch 4/30
# 243/243 [==============================] - 11s 45ms/step - loss: 1.1688 - accuracy: 0.6957 - val_loss: 1.1044 - val_accuracy: 0.7242
# Epoch 5/30
# 243/243 [==============================] - 12s 50ms/step - loss: 0.9009 - accuracy: 0.7606 - val_loss: 0.9295 - val_accuracy: 0.7608
# Epoch 6/30
# 243/243 [==============================] - 11s 45ms/step - loss: 0.7288 - accuracy: 0.8030 - val_loss: 0.8213 - val_accuracy: 0.7816
# Epoch 7/30
# 243/243 [==============================] - 9s 35ms/step - loss: 0.5786 - accuracy: 0.8375 - val_loss: 0.7660 - val_accuracy: 0.7921
# Epoch 8/30
# 243/243 [==============================] - 8s 34ms/step - loss: 0.4960 - accuracy: 0.8633 - val_loss: 0.6848 - val_accuracy: 0.8326
# Epoch 9/30
# 243/243 [==============================] - 13s 54ms/step - loss: 0.4081 - accuracy: 0.8823 - val_loss: 0.7507 - val_accuracy: 0.8287
# Epoch 10/30
# 243/243 [==============================] - 10s 42ms/step - loss: 0.3437 - accuracy: 0.9012 - val_loss: 0.6361 - val_accuracy: 0.8542
# Epoch 11/30
# 243/243 [==============================] - 8s 34ms/step - loss: 0.2965 - accuracy: 0.9166 - val_loss: 0.7126 - val_accuracy: 0.8302
# Epoch 12/30
# 243/243 [==============================] - 18s 75ms/step - loss: 0.2592 - accuracy: 0.9258 - val_loss: 0.6610 - val_accuracy: 0.8461
# Epoch 13/30
# 243/243 [==============================] - 9s 35ms/step - loss: 0.2226 - accuracy: 0.9345 - val_loss: 0.6761 - val_accuracy: 0.8449
# Epoch 14/30
# 243/243 [==============================] - 17s 68ms/step - loss: 0.1917 - accuracy: 0.9434 - val_loss: 0.6284 - val_accuracy: 0.8588
# Epoch 15/30
# 243/243 [==============================] - 9s 36ms/step - loss: 0.1826 - accuracy: 0.9468 - val_loss: 0.7284 - val_accuracy: 0.8630
# Epoch 16/30
# 243/243 [==============================] - 9s 36ms/step - loss: 0.1543 - accuracy: 0.9541 - val_loss: 0.9420 - val_accuracy: 0.8329
# Epoch 17/30
# 243/243 [==============================] - 15s 60ms/step - loss: 0.1383 - accuracy: 0.9602 - val_loss: 0.7362 - val_accuracy: 0.8623
# Epoch 18/30
# 243/243 [==============================] - 8s 35ms/step - loss: 0.1290 - accuracy: 0.9628 - val_loss: 0.7385 - val_accuracy: 0.8700
# Epoch 19/30
# 243/243 [==============================] - 12s 50ms/step - loss: 0.1112 - accuracy: 0.9673 - val_loss: 0.7428 - val_accuracy: 0.8580
# Epoch 20/30
# 243/243 [==============================] - 15s 60ms/step - loss: 0.1090 - accuracy: 0.9700 - val_loss: 0.9579 - val_accuracy: 0.8607
# Epoch 21/30
# 243/243 [==============================] - 9s 39ms/step - loss: 0.1016 - accuracy: 0.9704 - val_loss: 0.6730 - val_accuracy: 0.8727
# Epoch 22/30
# 243/243 [==============================] - 10s 39ms/step - loss: 0.0961 - accuracy: 0.9707 - val_loss: 0.7180 - val_accuracy: 0.8777
# Epoch 23/30
# 243/243 [==============================] - 9s 38ms/step - loss: 0.0821 - accuracy: 0.9772 - val_loss: 0.9983 - val_accuracy: 0.8549
# Epoch 24/30
# 243/243 [==============================] - 10s 40ms/step - loss: 0.0922 - accuracy: 0.9736 - val_loss: 0.7126 - val_accuracy: 0.8750
# Epoch 25/30
# 243/243 [==============================] - 9s 38ms/step - loss: 0.0704 - accuracy: 0.9798 - val_loss: 0.9739 - val_accuracy: 0.8619
# Epoch 26/30
# 243/243 [==============================] - 9s 37ms/step - loss: 0.0745 - accuracy: 0.9802 - val_loss: 0.8547 - val_accuracy: 0.8669
# Epoch 27/30
# 243/243 [==============================] - 9s 37ms/step - loss: 0.0703 - accuracy: 0.9793 - val_loss: 0.8706 - val_accuracy: 0.8654
# Tempo totale: 16 minuti e 23.88 secondi
# Il miglior modello ha un filtro di partenza pari a 16, un learning rate pari a 0.001 con un'accuracy pari a 0.887

# %%
os.listdir("model_tuning/histories")
# Out:
# ['model_1.csv',
#  'model_2.csv',
#  'model_3.csv',
#  'model_4.csv',
#  'model_5.csv',
#  'model_6.csv',
#  'model_7.csv',
#  'model_8.csv',
#  'model_9.csv']

# %%
p = "model_tuning/histories" + "/" + "model_1.csv"
prova = pd.read_csv(p)

# %%
prova["accuracy"].values
# Out:
# array([0.03621134, 0.03646907, 0.03634021, 0.03608247, 0.0371134 ,
#        0.03582474, 0.03595361])

# %%
fig, ax = plt.subplots()

path = "model_tuning/histories"

for model in os.listdir(path):
    newpath = path + "/" + model
    df = pd.read_csv(newpath)

    accuracy = df["val_loss"].values
    
    ax.plot(range(1, len(accuracy) + 1), accuracy, label=model)

    ax.legend()

plt.show()

# %%
improved_basic_model = get_improved_basic_model_tuning()
improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])
# Out:
# [16, 32, 64, 128]

# %%
improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/improved_basic_model.keras", save_best_only=True, monitor="val_loss")]
improved_history = improved_basic_model.fit(train_ds, epochs=100, validation_data=val_ds, callbacks=improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 3s 12ms/step - loss: 2.5861 - accuracy: 0.2848 - val_loss: 1.5696 - val_accuracy: 0.5455
# Epoch 2/100
# 243/243 [==============================] - 3s 11ms/step - loss: 1.1898 - accuracy: 0.6616 - val_loss: 0.9921 - val_accuracy: 0.7215
# Epoch 3/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.6851 - accuracy: 0.8032 - val_loss: 0.6516 - val_accuracy: 0.8086
# Epoch 4/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.4714 - accuracy: 0.8620 - val_loss: 0.5508 - val_accuracy: 0.8495
# Epoch 5/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.3538 - accuracy: 0.8929 - val_loss: 0.5613 - val_accuracy: 0.8657
# Epoch 6/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2878 - accuracy: 0.9131 - val_loss: 0.4973 - val_accuracy: 0.8839
# Epoch 7/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2190 - accuracy: 0.9321 - val_loss: 0.6339 - val_accuracy: 0.8781
# Epoch 8/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1929 - accuracy: 0.9448 - val_loss: 0.6299 - val_accuracy: 0.8673
# Epoch 9/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1667 - accuracy: 0.9512 - val_loss: 0.6322 - val_accuracy: 0.8777
# Epoch 10/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1541 - accuracy: 0.9552 - val_loss: 0.9205 - val_accuracy: 0.8600
# Epoch 11/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1436 - accuracy: 0.9602 - val_loss: 0.5761 - val_accuracy: 0.8870
# Epoch 12/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1306 - accuracy: 0.9620 - val_loss: 0.9209 - val_accuracy: 0.8804
# Epoch 13/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1322 - accuracy: 0.9669 - val_loss: 0.7716 - val_accuracy: 0.8881
# Epoch 14/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1258 - accuracy: 0.9698 - val_loss: 0.7145 - val_accuracy: 0.8924
# Epoch 15/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1153 - accuracy: 0.9689 - val_loss: 0.9372 - val_accuracy: 0.8715
# Epoch 16/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1143 - accuracy: 0.9718 - val_loss: 0.6953 - val_accuracy: 0.9028
# Epoch 17/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1138 - accuracy: 0.9716 - val_loss: 0.7670 - val_accuracy: 0.8931
# Epoch 18/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1171 - accuracy: 0.9731 - val_loss: 0.8904 - val_accuracy: 0.8808
# Epoch 19/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1131 - accuracy: 0.9732 - val_loss: 0.9712 - val_accuracy: 0.8924
# Epoch 20/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1038 - accuracy: 0.9750 - val_loss: 1.1812 - val_accuracy: 0.8881
# Epoch 21/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1206 - accuracy: 0.9723 - val_loss: 1.0808 - val_accuracy: 0.8916
# Epoch 22/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1189 - accuracy: 0.9744 - val_loss: 1.2287 - val_accuracy: 0.8800
# Epoch 23/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1050 - accuracy: 0.9764 - val_loss: 1.1633 - val_accuracy: 0.8924
# Epoch 24/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1092 - accuracy: 0.9774 - val_loss: 1.2365 - val_accuracy: 0.8862
# Epoch 25/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1051 - accuracy: 0.9784 - val_loss: 1.2756 - val_accuracy: 0.8681
# Epoch 26/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1066 - accuracy: 0.9762 - val_loss: 1.7216 - val_accuracy: 0.8804
# Epoch 27/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1227 - accuracy: 0.9771 - val_loss: 1.6266 - val_accuracy: 0.8762
# Epoch 28/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1297 - accuracy: 0.9767 - val_loss: 1.4878 - val_accuracy: 0.8769
# Epoch 29/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1228 - accuracy: 0.9754 - val_loss: 1.6878 - val_accuracy: 0.8800
# Epoch 30/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1107 - accuracy: 0.9790 - val_loss: 1.6400 - val_accuracy: 0.8681
# Epoch 31/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1268 - accuracy: 0.9774 - val_loss: 2.0666 - val_accuracy: 0.8866
# Epoch 32/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1418 - accuracy: 0.9772 - val_loss: 1.9076 - val_accuracy: 0.8943
# Epoch 33/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0986 - accuracy: 0.9791 - val_loss: 1.9743 - val_accuracy: 0.8881
# Epoch 34/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1097 - accuracy: 0.9830 - val_loss: 2.4543 - val_accuracy: 0.8754
# Epoch 35/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1316 - accuracy: 0.9807 - val_loss: 2.2372 - val_accuracy: 0.8711
# Epoch 36/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1165 - accuracy: 0.9808 - val_loss: 1.9908 - val_accuracy: 0.8800
# Epoch 37/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1226 - accuracy: 0.9809 - val_loss: 2.0323 - val_accuracy: 0.8831
# Epoch 38/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1159 - accuracy: 0.9830 - val_loss: 2.1724 - val_accuracy: 0.8777
# Epoch 39/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1311 - accuracy: 0.9812 - val_loss: 2.3624 - val_accuracy: 0.8862
# Epoch 40/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1425 - accuracy: 0.9811 - val_loss: 2.5838 - val_accuracy: 0.8781
# Epoch 41/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1308 - accuracy: 0.9820 - val_loss: 2.0386 - val_accuracy: 0.8816
# Epoch 42/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1446 - accuracy: 0.9800 - val_loss: 2.1136 - val_accuracy: 0.8696
# Epoch 43/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1326 - accuracy: 0.9835 - val_loss: 2.8116 - val_accuracy: 0.8688
# Epoch 44/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1133 - accuracy: 0.9853 - val_loss: 2.7223 - val_accuracy: 0.8819
# Epoch 45/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1274 - accuracy: 0.9841 - val_loss: 2.2522 - val_accuracy: 0.8951
# Epoch 46/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1350 - accuracy: 0.9839 - val_loss: 2.3332 - val_accuracy: 0.8908
# Epoch 47/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1641 - accuracy: 0.9814 - val_loss: 4.0725 - val_accuracy: 0.8619
# Epoch 48/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1230 - accuracy: 0.9834 - val_loss: 2.3440 - val_accuracy: 0.8858
# Epoch 49/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1216 - accuracy: 0.9839 - val_loss: 2.9808 - val_accuracy: 0.8777
# Epoch 50/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1306 - accuracy: 0.9853 - val_loss: 3.0682 - val_accuracy: 0.8870
# Epoch 51/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1389 - accuracy: 0.9840 - val_loss: 4.5850 - val_accuracy: 0.8673
# Epoch 52/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1787 - accuracy: 0.9832 - val_loss: 2.7310 - val_accuracy: 0.8854
# Epoch 53/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1345 - accuracy: 0.9816 - val_loss: 3.2976 - val_accuracy: 0.8549
# Epoch 54/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1504 - accuracy: 0.9809 - val_loss: 3.2677 - val_accuracy: 0.8769
# Epoch 55/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1465 - accuracy: 0.9840 - val_loss: 2.8314 - val_accuracy: 0.8854
# Epoch 56/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1290 - accuracy: 0.9851 - val_loss: 2.8084 - val_accuracy: 0.8858
# Epoch 57/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1282 - accuracy: 0.9857 - val_loss: 2.8686 - val_accuracy: 0.8877
# Epoch 58/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1417 - accuracy: 0.9854 - val_loss: 2.2272 - val_accuracy: 0.8773
# Epoch 59/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1283 - accuracy: 0.9861 - val_loss: 3.0013 - val_accuracy: 0.8696
# Epoch 60/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1330 - accuracy: 0.9834 - val_loss: 2.8332 - val_accuracy: 0.8823
# Epoch 61/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1505 - accuracy: 0.9831 - val_loss: 2.9528 - val_accuracy: 0.8835
# Epoch 62/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1276 - accuracy: 0.9851 - val_loss: 3.0818 - val_accuracy: 0.8843
# Epoch 63/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1359 - accuracy: 0.9852 - val_loss: 2.6940 - val_accuracy: 0.8885
# Epoch 64/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1357 - accuracy: 0.9836 - val_loss: 3.3413 - val_accuracy: 0.8916
# Epoch 65/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1302 - accuracy: 0.9863 - val_loss: 4.7256 - val_accuracy: 0.8669
# Epoch 66/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1346 - accuracy: 0.9852 - val_loss: 4.0923 - val_accuracy: 0.8800
# Epoch 67/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1167 - accuracy: 0.9878 - val_loss: 3.6277 - val_accuracy: 0.8958
# Epoch 68/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1542 - accuracy: 0.9853 - val_loss: 3.0875 - val_accuracy: 0.8796
# Epoch 69/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1698 - accuracy: 0.9856 - val_loss: 3.5563 - val_accuracy: 0.8808
# Epoch 70/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1819 - accuracy: 0.9851 - val_loss: 3.0166 - val_accuracy: 0.8789
# Epoch 71/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1436 - accuracy: 0.9834 - val_loss: 3.9524 - val_accuracy: 0.8765
# Epoch 72/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1295 - accuracy: 0.9874 - val_loss: 4.8274 - val_accuracy: 0.8708
# Epoch 73/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1617 - accuracy: 0.9854 - val_loss: 4.1096 - val_accuracy: 0.8850
# Epoch 74/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1321 - accuracy: 0.9883 - val_loss: 4.7064 - val_accuracy: 0.8904
# Epoch 75/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1519 - accuracy: 0.9871 - val_loss: 4.8632 - val_accuracy: 0.8939
# Epoch 76/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0945 - accuracy: 0.9907 - val_loss: 5.5453 - val_accuracy: 0.8700
# Epoch 77/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1418 - accuracy: 0.9870 - val_loss: 3.9148 - val_accuracy: 0.8920
# Epoch 78/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1457 - accuracy: 0.9881 - val_loss: 4.7272 - val_accuracy: 0.8792
# Epoch 79/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1897 - accuracy: 0.9854 - val_loss: 5.9512 - val_accuracy: 0.8796
# Epoch 80/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1745 - accuracy: 0.9872 - val_loss: 5.6979 - val_accuracy: 0.8924
# Epoch 81/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1681 - accuracy: 0.9879 - val_loss: 4.9959 - val_accuracy: 0.8943
# Epoch 82/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1654 - accuracy: 0.9881 - val_loss: 5.2570 - val_accuracy: 0.8889
# Epoch 83/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1784 - accuracy: 0.9887 - val_loss: 5.8782 - val_accuracy: 0.8862
# Epoch 84/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2259 - accuracy: 0.9869 - val_loss: 6.0586 - val_accuracy: 0.8862
# Epoch 85/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1608 - accuracy: 0.9889 - val_loss: 6.4216 - val_accuracy: 0.8850
# Epoch 86/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1809 - accuracy: 0.9878 - val_loss: 5.6495 - val_accuracy: 0.8816
# Epoch 87/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1915 - accuracy: 0.9876 - val_loss: 5.7174 - val_accuracy: 0.8827
# Epoch 88/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2339 - accuracy: 0.9876 - val_loss: 7.2812 - val_accuracy: 0.8819
# Epoch 89/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1432 - accuracy: 0.9893 - val_loss: 5.5333 - val_accuracy: 0.8846
# Epoch 90/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2263 - accuracy: 0.9893 - val_loss: 5.8058 - val_accuracy: 0.8758
# Epoch 91/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2110 - accuracy: 0.9892 - val_loss: 6.5709 - val_accuracy: 0.8924
# Epoch 92/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2133 - accuracy: 0.9889 - val_loss: 5.7071 - val_accuracy: 0.8835
# Epoch 93/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2721 - accuracy: 0.9866 - val_loss: 6.2356 - val_accuracy: 0.8873
# Epoch 94/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1987 - accuracy: 0.9902 - val_loss: 6.2105 - val_accuracy: 0.8954
# Epoch 95/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1873 - accuracy: 0.9888 - val_loss: 7.3473 - val_accuracy: 0.8939
# Epoch 96/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2073 - accuracy: 0.9885 - val_loss: 5.3384 - val_accuracy: 0.8943
# Epoch 97/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1938 - accuracy: 0.9884 - val_loss: 8.5132 - val_accuracy: 0.8908
# Epoch 98/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2169 - accuracy: 0.9899 - val_loss: 6.5812 - val_accuracy: 0.8846
# Epoch 99/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2110 - accuracy: 0.9890 - val_loss: 5.9545 - val_accuracy: 0.8954
# Epoch 100/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2168 - accuracy: 0.9869 - val_loss: 7.7531 - val_accuracy: 0.8877

# %% [markdown]
# Salviamo come prima la history del modello in un file csv.

# %%
improved_history_df = convert_history_to_csv(improved_history)
improved_history_df.to_csv("model_histories/rmsprop/improved_history.csv")

# %% [markdown]
# Salviamo nuovamente il miglior modello anche nel formato **.onnx**.

# %%
convert_model_to_onnx("bestmodels/rmsprop/improved_basic_model.keras", (124, 129, 1))

# %%
create_train_val_plot(improved_history.history)

# %% [markdown]
# Alleniamo il modello per 100 epoche e visualizziamo le **curve di addestramento** e **validazione**.
#
# L'obbiettivo di ridurre **l'overfitting è stato comunque raggiunto**, dato che il modello andato in overfitting leggermente dopo, circa **all'epoca 10**, ma dobbiamo sicuramente applicare qualche altra tecnica per migliorarlo ulteriormente.

# %%
improved_best_model = tf.keras.models.load_model("bestmodels/rmsprop/improved_basic_model.keras")
test_loss, test_acc = improved_best_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 7ms/step - loss: 0.5833 - accuracy: 0.8659
# Accuratezza: 0.866

# %% [markdown]
# Verifichiamola anche con il modello **.onnx**

# %%
evaluate_onnx_model("bestmodels/rmsprop/improved_basic_model.onnx", test_ds)
# Out:
# Accuratezza: 0.866

# %% [markdown]
# Abbiamo ottenuto un buon miglioramento dell'accuratezza, attualmente siamo a quota **86.6%**!.

# %%
for audio, label in test_ds:
    create_distribution_plot(improved_best_model, audio, label)
    break

# %% [markdown]
# In questo caso il modello è stato in grado di predirre la classe corretta **off**.

# %% [markdown]
# ## Miglioramenti all'architettura del modello
#
# Durante il corso abbiamo visto anche delle best practice architetturali che possono aiutare a ottenere maggiori prestazioni col modello. Il nostro scopo è provare le tecniche viste e studiate durante il corso e capire come reagiscono al task.

# %% [markdown]
# Le tre tecniche che andremo ad applicare sono:
# - blocchi residuali
# - normalizzazione dei batch
# - convoluzioni separabili

# %% [markdown]
# ### Blocchi residuali
# I blocchi residuali sono un'applicazione efficace quando riscontriamo il problema dei **gradienti che svaniscono**. Non sono una tecnica strettamente legata ai modelli convolutivi, ma sono una best practice generale che viene applicare nella maggior parte delle architetture.
#
# I **gradienti che vaniscono** sono causati dalle **catene di funzioni troppo lunghe**, che nel nostro caso non sono altro che **una sequenza di livelli convolutivi**. Per ogni livello convolutivo **una certa quantità di rumore** viene introdotta, finché essa non arriva a **sopraffare** le informazioni sul gradiente.
#
# Se le informazioni sul gradiente sono sopraffatte la **backpropagation smette di funzionare**, e quindi il nostro **modello non impara**.

# %% [markdown]
# L'**idea basilare** dietro ai blocchi residuali è quella di **salvare l'informazione** contenuta nell'input precedente al livello convolutivo, e **sommarla all'output** dello stesso livello convolutivo.

# %% [markdown]
# Per applicare i blocchi residuali abbiamo implementato la funzione `residual_block(x, filters, pooling=False)` vista a lezione. La funzione è stata adattata al modello da noi implementato, e utilizza le altre due best practice citate precedentemente.

# %%
def residual_block(x, filters, pooling=False):
    residual = x

    x = tf.keras.layers.SeparableConv2D(filters, 3, padding="same", use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    if pooling:
      x = tf.keras.layers.MaxPooling2D(pool_size=2, padding="same")(x)
      residual = tf.keras.layers.Conv2D(filters, 1, strides=2)(residual)
    elif filters != residual.shape[-1]:
      residual = tf.keras.layers.Conv2D(filters, 1)(residual)

    x = tf.keras.layers.add([x, residual])
    return x

# %% [markdown]
# ### Normalizzazione dei batch e convoluzioni separabili
# La **normalizzazione dei batch** è un concetto che abbiamo già affrontato nel notebook, infatti il suo scopo rimane quello di rendere i dati **più simili tra loro** centrandoli sullo zero, e ciò aiuta la **propagazione del gradiente**. Questa normalizzazione, a differenza della precedente, è in grado di normalizzare i dati in modo adattivo anche quando la media e la varianza cambiano durante l'addestramento.

# %% [markdown]
# Le **convoluzione separabili** invece sono un **sostituto** ai livelli convolutivi utilizzati fino ad adesso, e offrono un modello con maggiori prestazioni e meno parametri.

# %%
def bp_basic_model():
    # input e pre processamento
    inputs = tf.keras.Input(shape=(124, 129, 1))
    
    x = residual_block(x, 32, pooling=True)
    x = residual_block(x, 64, pooling=True)
    x = residual_block(x, 128, pooling=True)
    x = residual_block(x, 256, pooling=True)
    x = residual_block(x, 256, pooling=False)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Livelli per la classificazione
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
bp_basic_model = bp_basic_model()
bp_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

bp_basic_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 124, 129, 1  0           []
#                                 )]
#
#  resizing (Resizing)            (None, 120, 120, 1)  0           ['input_2[0][0]']
#
#  separable_conv2d (SeparableCon  (None, 120, 120, 32  41         ['resizing[0][0]']
#  v2D)                           )
#
#  batch_normalization (BatchNorm  (None, 120, 120, 32  128        ['separable_conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 120, 120, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 60, 60, 32)  0           ['activation[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 60, 60, 32)   64          ['resizing[0][0]']
#
#  add (Add)                      (None, 60, 60, 32)   0           ['max_pooling2d_4[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  separable_conv2d_1 (SeparableC  (None, 60, 60, 64)  2336        ['add[0][0]']
#  onv2D)
#
#  batch_normalization_1 (BatchNo  (None, 60, 60, 64)  256         ['separable_conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 60, 60, 64)   0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 30, 30, 64)  0           ['activation_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 30, 30, 64)   2112        ['add[0][0]']
#
#  add_1 (Add)                    (None, 30, 30, 64)   0           ['max_pooling2d_5[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  separable_conv2d_2 (SeparableC  (None, 30, 30, 128)  8768       ['add_1[0][0]']
#  onv2D)
#
#  batch_normalization_2 (BatchNo  (None, 30, 30, 128)  512        ['separable_conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 30, 30, 128)  0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 15, 15, 128)  0          ['activation_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 15, 15, 128)  8320        ['add_1[0][0]']
#
#  add_2 (Add)                    (None, 15, 15, 128)  0           ['max_pooling2d_6[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  separable_conv2d_3 (SeparableC  (None, 15, 15, 256)  33920      ['add_2[0][0]']
#  onv2D)
#
#  batch_normalization_3 (BatchNo  (None, 15, 15, 256)  1024       ['separable_conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 15, 15, 256)  0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 256)   0           ['activation_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 256)    33024       ['add_2[0][0]']
#
#  add_3 (Add)                    (None, 8, 8, 256)    0           ['max_pooling2d_7[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 8, 8, 256)   67840       ['add_3[0][0]']
#  onv2D)
#
#  batch_normalization_4 (BatchNo  (None, 8, 8, 256)   1024        ['separable_conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 8, 8, 256)    0           ['batch_normalization_4[0][0]']
#
#  add_4 (Add)                    (None, 8, 8, 256)    0           ['activation_4[0][0]',
#                                                                   'add_3[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['add_4[0][0]']
#  alAveragePooling2D)
#
#  dropout_1 (Dropout)            (None, 256)          0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 30)           7710        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 167,079
# Trainable params: 165,607
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %% [markdown]
# Le best practice, insieme al `tf.keras.layers.GlobalAveragePooling2D()` applicato al posto del Flatten, hanno formato un modello con circa **160000 parametri addestrabili** (circa il 12% del modello precedente).

# %%
bp_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/bp_basic_model.keras", save_best_only=True, monitor="val_loss")]
bp_model_history = bp_basic_model.fit(train_ds, epochs=100, validation_data=val_ds, callbacks=bp_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 6s 20ms/step - loss: 3.1785 - accuracy: 0.1238 - val_loss: 3.3366 - val_accuracy: 0.0448
# Epoch 2/100
# 243/243 [==============================] - 5s 20ms/step - loss: 2.5841 - accuracy: 0.2818 - val_loss: 2.5996 - val_accuracy: 0.2789
# Epoch 3/100
# 243/243 [==============================] - 5s 20ms/step - loss: 2.0666 - accuracy: 0.4420 - val_loss: 2.0380 - val_accuracy: 0.4267
# Epoch 4/100
# 243/243 [==============================] - 5s 21ms/step - loss: 1.5906 - accuracy: 0.5829 - val_loss: 1.4983 - val_accuracy: 0.5748
# Epoch 5/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.2430 - accuracy: 0.6784 - val_loss: 1.2060 - val_accuracy: 0.6582
# Epoch 6/100
# 243/243 [==============================] - 5s 20ms/step - loss: 1.0184 - accuracy: 0.7320 - val_loss: 0.9399 - val_accuracy: 0.7450
# Epoch 7/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.8531 - accuracy: 0.7736 - val_loss: 0.8273 - val_accuracy: 0.7708
# Epoch 8/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.7410 - accuracy: 0.8000 - val_loss: 0.9288 - val_accuracy: 0.7365
# Epoch 9/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.6513 - accuracy: 0.8246 - val_loss: 1.0477 - val_accuracy: 0.7060
# Epoch 10/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.5823 - accuracy: 0.8387 - val_loss: 1.2874 - val_accuracy: 0.6393
# Epoch 11/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.5338 - accuracy: 0.8528 - val_loss: 0.6799 - val_accuracy: 0.8106
# Epoch 12/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.4813 - accuracy: 0.8660 - val_loss: 0.7710 - val_accuracy: 0.7921
# Epoch 13/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.4483 - accuracy: 0.8759 - val_loss: 0.5196 - val_accuracy: 0.8565
# Epoch 14/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.4141 - accuracy: 0.8831 - val_loss: 0.9276 - val_accuracy: 0.7253
# Epoch 15/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.3784 - accuracy: 0.8981 - val_loss: 0.5549 - val_accuracy: 0.8488
# Epoch 16/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.3569 - accuracy: 0.8985 - val_loss: 0.5678 - val_accuracy: 0.8453
# Epoch 17/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.3304 - accuracy: 0.9079 - val_loss: 0.9470 - val_accuracy: 0.7681
# Epoch 18/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.3149 - accuracy: 0.9080 - val_loss: 0.6326 - val_accuracy: 0.8214
# Epoch 19/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.2958 - accuracy: 0.9173 - val_loss: 0.7257 - val_accuracy: 0.8017
# Epoch 20/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.2823 - accuracy: 0.9207 - val_loss: 0.8770 - val_accuracy: 0.7728
# Epoch 21/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.2702 - accuracy: 0.9246 - val_loss: 0.7097 - val_accuracy: 0.8191
# Epoch 22/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.2622 - accuracy: 0.9273 - val_loss: 0.8838 - val_accuracy: 0.8009
# Epoch 23/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.2581 - accuracy: 0.9291 - val_loss: 0.8428 - val_accuracy: 0.7836
# Epoch 24/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.2355 - accuracy: 0.9338 - val_loss: 0.5270 - val_accuracy: 0.8565
# Epoch 25/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.2285 - accuracy: 0.9383 - val_loss: 0.6190 - val_accuracy: 0.8414
# Epoch 26/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.2138 - accuracy: 0.9405 - val_loss: 0.5038 - val_accuracy: 0.8654
# Epoch 27/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.2074 - accuracy: 0.9427 - val_loss: 0.5747 - val_accuracy: 0.8468
# Epoch 28/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.2027 - accuracy: 0.9434 - val_loss: 0.8748 - val_accuracy: 0.7782
# Epoch 29/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1929 - accuracy: 0.9472 - val_loss: 0.9946 - val_accuracy: 0.7550
# Epoch 30/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1844 - accuracy: 0.9499 - val_loss: 0.7883 - val_accuracy: 0.7913
# Epoch 31/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1857 - accuracy: 0.9485 - val_loss: 0.8066 - val_accuracy: 0.7963
# Epoch 32/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1791 - accuracy: 0.9486 - val_loss: 0.6599 - val_accuracy: 0.8287
# Epoch 33/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1766 - accuracy: 0.9521 - val_loss: 0.7896 - val_accuracy: 0.8113
# Epoch 34/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1663 - accuracy: 0.9509 - val_loss: 1.1008 - val_accuracy: 0.7739
# Epoch 35/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1575 - accuracy: 0.9582 - val_loss: 0.6329 - val_accuracy: 0.8360
# Epoch 36/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1493 - accuracy: 0.9602 - val_loss: 0.5887 - val_accuracy: 0.8511
# Epoch 37/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1565 - accuracy: 0.9553 - val_loss: 1.2388 - val_accuracy: 0.7369
# Epoch 38/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1404 - accuracy: 0.9617 - val_loss: 0.5276 - val_accuracy: 0.8576
# Epoch 39/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1487 - accuracy: 0.9597 - val_loss: 0.5810 - val_accuracy: 0.8507
# Epoch 40/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1430 - accuracy: 0.9616 - val_loss: 0.5791 - val_accuracy: 0.8488
# Epoch 41/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1386 - accuracy: 0.9622 - val_loss: 0.7960 - val_accuracy: 0.8059
# Epoch 42/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1411 - accuracy: 0.9622 - val_loss: 0.5732 - val_accuracy: 0.8553
# Epoch 43/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1366 - accuracy: 0.9634 - val_loss: 0.7320 - val_accuracy: 0.8322
# Epoch 44/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1259 - accuracy: 0.9656 - val_loss: 0.5510 - val_accuracy: 0.8615
# Epoch 45/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1326 - accuracy: 0.9673 - val_loss: 0.4814 - val_accuracy: 0.8812
# Epoch 46/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1245 - accuracy: 0.9665 - val_loss: 0.5295 - val_accuracy: 0.8588
# Epoch 47/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1241 - accuracy: 0.9653 - val_loss: 0.5561 - val_accuracy: 0.8580
# Epoch 48/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1255 - accuracy: 0.9669 - val_loss: 0.6592 - val_accuracy: 0.8326
# Epoch 49/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1111 - accuracy: 0.9698 - val_loss: 1.1039 - val_accuracy: 0.7728
# Epoch 50/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1241 - accuracy: 0.9653 - val_loss: 0.5507 - val_accuracy: 0.8615
# Epoch 51/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1212 - accuracy: 0.9673 - val_loss: 0.7129 - val_accuracy: 0.8360
# Epoch 52/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1106 - accuracy: 0.9704 - val_loss: 0.6419 - val_accuracy: 0.8360
# Epoch 53/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1172 - accuracy: 0.9652 - val_loss: 0.6057 - val_accuracy: 0.8515
# Epoch 54/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1157 - accuracy: 0.9689 - val_loss: 0.7989 - val_accuracy: 0.8171
# Epoch 55/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1047 - accuracy: 0.9726 - val_loss: 0.5262 - val_accuracy: 0.8750
# Epoch 56/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1093 - accuracy: 0.9706 - val_loss: 0.5883 - val_accuracy: 0.8507
# Epoch 57/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1091 - accuracy: 0.9718 - val_loss: 0.5768 - val_accuracy: 0.8684
# Epoch 58/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1073 - accuracy: 0.9700 - val_loss: 0.5939 - val_accuracy: 0.8565
# Epoch 59/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1078 - accuracy: 0.9710 - val_loss: 0.6378 - val_accuracy: 0.8484
# Epoch 60/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1099 - accuracy: 0.9693 - val_loss: 0.5776 - val_accuracy: 0.8646
# Epoch 61/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1021 - accuracy: 0.9715 - val_loss: 0.5434 - val_accuracy: 0.8677
# Epoch 62/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0989 - accuracy: 0.9735 - val_loss: 0.5909 - val_accuracy: 0.8642
# Epoch 63/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0948 - accuracy: 0.9749 - val_loss: 0.4406 - val_accuracy: 0.8889
# Epoch 64/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0989 - accuracy: 0.9750 - val_loss: 0.6850 - val_accuracy: 0.8480
# Epoch 65/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0972 - accuracy: 0.9746 - val_loss: 0.6462 - val_accuracy: 0.8600
# Epoch 66/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0901 - accuracy: 0.9759 - val_loss: 0.4610 - val_accuracy: 0.8904
# Epoch 67/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0987 - accuracy: 0.9737 - val_loss: 0.6653 - val_accuracy: 0.8495
# Epoch 68/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0955 - accuracy: 0.9765 - val_loss: 0.6474 - val_accuracy: 0.8515
# Epoch 69/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0929 - accuracy: 0.9741 - val_loss: 0.6123 - val_accuracy: 0.8511
# Epoch 70/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0856 - accuracy: 0.9778 - val_loss: 0.4500 - val_accuracy: 0.8970
# Epoch 71/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0913 - accuracy: 0.9767 - val_loss: 0.6024 - val_accuracy: 0.8692
# Epoch 72/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0897 - accuracy: 0.9754 - val_loss: 0.8673 - val_accuracy: 0.8287
# Epoch 73/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0858 - accuracy: 0.9776 - val_loss: 0.7076 - val_accuracy: 0.8495
# Epoch 74/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0854 - accuracy: 0.9765 - val_loss: 0.5905 - val_accuracy: 0.8785
# Epoch 75/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0847 - accuracy: 0.9759 - val_loss: 0.4473 - val_accuracy: 0.8935
# Epoch 76/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0835 - accuracy: 0.9781 - val_loss: 0.7264 - val_accuracy: 0.8468
# Epoch 77/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0856 - accuracy: 0.9768 - val_loss: 0.6097 - val_accuracy: 0.8696
# Epoch 78/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0803 - accuracy: 0.9782 - val_loss: 0.7145 - val_accuracy: 0.8623
# Epoch 79/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0811 - accuracy: 0.9768 - val_loss: 0.8914 - val_accuracy: 0.8133
# Epoch 80/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0859 - accuracy: 0.9764 - val_loss: 0.5395 - val_accuracy: 0.8827
# Epoch 81/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0767 - accuracy: 0.9811 - val_loss: 0.7001 - val_accuracy: 0.8449
# Epoch 82/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0806 - accuracy: 0.9785 - val_loss: 0.7640 - val_accuracy: 0.8468
# Epoch 83/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0729 - accuracy: 0.9798 - val_loss: 0.5145 - val_accuracy: 0.8862
# Epoch 84/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0742 - accuracy: 0.9818 - val_loss: 0.4841 - val_accuracy: 0.8850
# Epoch 85/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0752 - accuracy: 0.9807 - val_loss: 0.8992 - val_accuracy: 0.8044
# Epoch 86/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0831 - accuracy: 0.9790 - val_loss: 0.6216 - val_accuracy: 0.8758
# Epoch 87/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0766 - accuracy: 0.9798 - val_loss: 0.4768 - val_accuracy: 0.8924
# Epoch 88/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0704 - accuracy: 0.9825 - val_loss: 0.5703 - val_accuracy: 0.8754
# Epoch 89/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0651 - accuracy: 0.9834 - val_loss: 0.8211 - val_accuracy: 0.8488
# Epoch 90/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0735 - accuracy: 0.9798 - val_loss: 0.8573 - val_accuracy: 0.8403
# Epoch 91/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0740 - accuracy: 0.9809 - val_loss: 0.9599 - val_accuracy: 0.8083
# Epoch 92/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0738 - accuracy: 0.9799 - val_loss: 0.6812 - val_accuracy: 0.8650
# Epoch 93/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0791 - accuracy: 0.9781 - val_loss: 0.6364 - val_accuracy: 0.8843
# Epoch 94/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0649 - accuracy: 0.9822 - val_loss: 0.4582 - val_accuracy: 0.9016
# Epoch 95/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0707 - accuracy: 0.9821 - val_loss: 0.6119 - val_accuracy: 0.8858
# Epoch 96/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0726 - accuracy: 0.9803 - val_loss: 0.6208 - val_accuracy: 0.8603
# Epoch 97/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0717 - accuracy: 0.9811 - val_loss: 0.7049 - val_accuracy: 0.8557
# Epoch 98/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0707 - accuracy: 0.9823 - val_loss: 0.5386 - val_accuracy: 0.8885
# Epoch 99/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0714 - accuracy: 0.9813 - val_loss: 0.5385 - val_accuracy: 0.8785
# Epoch 100/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0714 - accuracy: 0.9825 - val_loss: 0.4987 - val_accuracy: 0.8897

# %% [markdown]
# Salviamo nuoavmente la history del modello in un file csv.

# %%
bp_model_history_df = convert_history_to_csv(bp_model_history)
bp_model_history_df.to_csv("model_histories/rmsprop/bp_model_history.csv")

# %% [markdown]
# Convertiamo anche il miglior modello nel formato **.onnx**.

# %%
convert_model_to_onnx("bestmodels/rmsprop/bp_basic_model.keras", (124, 129, 1))

# %%
create_train_val_plot(bp_model_history.history, overfit=False)

# %% [markdown]
# Possiamo notare che il modello **NON ha raggiunto una vera fase di overfitting**, ma la validazione non ha mostrato un incremento sostanziale all'aumentare delle epoche (probabilmente dovuto dalle tecniche di overfitting non totalmente implementate). La **loss della validazione** stava continuando a scendere, e allo stesso tempo **l'accuratezza della validazione era crescente**.

# %%
best_bp_basic_model = tf.keras.models.load_model("bestmodels/rmsprop/bp_basic_model.keras")
test_loss, test_acc = best_bp_basic_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 6ms/step - loss: 0.5104 - accuracy: 0.8931
# Accuratezza: 0.893

# %% [markdown]
# Verifichiamola anche con il modello **.onnx**.

# %%
evaluate_onnx_model("bestmodels/rmsprop/bp_basic_model.onnx", test_ds)
# Out:
# Accuratezza: 0.893

# %% [markdown]
# Abbiamo nuovamente ottenuto dei miglioramenti sostanziali per quanto riguarda l'accuratezza, ottenendo un **89.3%**. Questo risultato è ottimo, considerando che il modello ha poco meno del **12% dei parametri** rispetto al precedente.

# %%
for audio, label in test_ds:
    create_distribution_plot(best_bp_basic_model, audio, label)
    break

# %% [markdown]
# La decisione del modello in questo caso è nuovamente molto chiara.
