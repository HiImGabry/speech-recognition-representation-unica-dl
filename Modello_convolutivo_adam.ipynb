# %% [markdown]
# # Modello convolutivo di base
# Lo scopo di questo notebook è creare un **modello convolutivo di base** con un'architettura semplice. In seguito, sarà interessante confrontare i risultati di questo primo modello con i risultati ottenuti da modelli più complessi, o pre addestrati.

# %% [markdown]
# Come al solito, si procede con l'importazione delle librerie utilizzate e la creazione dei set di allenamento e validazione.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd
import numpy as np
# per il modello con estensione .onnx
import onnxruntime as rt
import tf2onnx
import onnx

# %%
train_ds, validation_ds = tf.keras.utils.audio_dataset_from_directory(
    directory='../reduced_dataset/dataset/audio',
    validation_split=0.4, # stiamo mettendo da parte il 40% del dataset, che sarà suddiviso in validation set e test set
    shuffle=True,
    subset='both', # necessario se stiamo utilizzando validation_split (se no darebbe errore)
    seed=0 # necessario se stiamo utilizzando sia shuffle che validation_split (se no darebbe errore)
)

label_names = train_ds.class_names
# Out:
# Found 12933 files belonging to 30 classes.
# Using 7760 files for training.
# Using 5173 files for validation.

# %% [markdown]
# ## Funzioni per processamento dei dati

# %% [markdown]
# La prima funzione che ci tornerà utile è `squeeze(audio, labels)`, della quale abbiamo già visto l'implementazione e parlato del suo utilizzo nel notebook dove trattiamo gli spettrogrammi.

# %%
def squeeze(audio, labels):
    audio = tf.squeeze(audio, axis=-1)
    return audio, labels

# fonte: funzione presa dal seguente link: https://www.geeksforgeeks.org/audio-recognition-in-tensorflow/

# %%
train_ds = train_ds.map(squeeze, tf.data.AUTOTUNE)
validation_ds = validation_ds.map(squeeze, tf.data.AUTOTUNE)

audio, label = next(iter(train_ds))
print(audio.shape)
print(label.shape)
# Out:
# (32, 16000)
# (32,)

# %% [markdown]
# Una volta eseguito questa semplificazione, a partire dai tensori degli audio, creeremo gli spettrogrammi che sarannò presi come input dal modello convolutivo.

# %% [markdown]
# ## Conversione e suddivisione dataset
# Per la conversione del dataset utilizziamo due funzioni che abbiamo già definito nel notebook dove trattiamo gli spettrogrammi.

# %%
def get_spectrogram(waveform):
    spectrogram = tf.signal.stft(waveform, frame_length=255, frame_step=128)
    spectrogram = tf.abs(spectrogram)

    return spectrogram[..., tf.newaxis]

# fonte: funzione presa dal seguente link: https://www.geeksforgeeks.org/audio-recognition-in-tensorflow/

# %%
def get_spectrogram_dataset(dataset):
    dataset = dataset.map(lambda x, y: (get_spectrogram(x), y), num_parallel_calls=tf.data.AUTOTUNE)

    return dataset

# fonte: funzione presa dal seguente link: https://www.geeksforgeeks.org/audio-recognition-in-tensorflow/

# %% [markdown]
# Definite le due funzioni possiamo procedere a ottenere il nostro **training set**, **validation set**, e **test set** di spettrogrammi. La suddivisione di dati ricordo essere rispettivamente 60%, 20%, 20%.

# %%
train_ds = get_spectrogram_dataset(train_ds)
validation_ds = get_spectrogram_dataset(validation_ds)

val_ds = validation_ds.take(validation_ds.cardinality() // 2) # ho cambiato nome del validation_ds in modo tale da non creare problemi con l'istruzione seguente
test_ds = validation_ds.skip(validation_ds.cardinality() // 2)

# %%
print("Numero di audio training set:", len(train_ds) * 32)
print("Numero di audio validation set:", len(val_ds) * 32)
print("Numero di audio test set:", len(test_ds) * 32)
# Out:
# Numero di audio training set: 7776
# Numero di audio validation set: 2592
# Numero di audio test set: 2592

# %%
for audio, label in train_ds:
    print("Shape (forma) spettrogrammi:", audio.shape)

    spectrogram = np.squeeze(audio[0], axis=-1)
    spectrogram = np.log(spectrogram.T + np.finfo(float).eps)

    plt.imshow(spectrogram.T)
    plt.colorbar(format='%+2.0f dB') # barra laterale dei dB

    plt.title(f"Classe: {label_names[label[0].numpy()]}")
    break
# Out:
# Shape (forma) spettrogrammi: (32, 124, 129, 1)

# %% [markdown]
# La grandezza degli spettrogrammi, quindi delle immagini ottenute, è di **124x129**.

# %% [markdown]
# ## Creazione modello di base

# %% [markdown]
# Come modello implementiamo una rete neurale convolutiva. Questo modello ha un'architettura semplice e servirà da benchmark per i modelli futuri.
#
# La rete prende in ingresso tensori di forma **altezza x larghezza x canali**, rispettivamente di **124, 129, 1**. Per farlo lavorare meglio, rendiamo le immagini di dimensione quadrata e normalizziamo i dati con la funzione `tf.keras.layers.Normalization()`.

# %% [markdown]
# L'architettura del modello è suddivisa in **due blocchi** principali: un blocco per l'apprendimento delle caratteristiche e un blocco per la classificazione.
#
# Il **blocco di apprendimento delle caratteristiche** ha un'architettura formata da una serie di livelli convolutivi alternati a livelli di max pooling. Per ciascun livello convolutivo viene anche applicata la funzione di attivazione **ReLu** per applicare non linearità. Il blocco termina con un livello convolutivo di **256 filtri**, che corrispondono alla stessa quantità di filtri applicati dal livello convolutivo precedente.
#
# Terminato il blocco di apprendimento delle caratteristiche, è presente il **blocco di classificazione**, formato da un **livello di Flatten**, necessario per trasformare i dati in un vettore unidimensionali, e un **livello Dense**, necessario per la predizione della classe di appartenenza del dato. Quest'ultimo livello Dense ha **30 unità**, che corrispondono alle 30 classi del nostro task di classificazione multiclasse. La funzione di attivazione applicata dal livello Dense è la **softmax**, ideale per i task di classificazione multiclasse.
#
# La funzione **softmax**, a differenza della funzione **sigmoid** ci fornisce una distribuzione di probabilità sulle classi possibili (questa distribuzione saremo in grado di visualizzarla durante la valutazione del modello).

# %%
def get_basic_model():
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(124, 129, 1), name="inputs")
    x = tf.keras.layers.Normalization(name="normalizzazione")(inputs)

    # Blocco di apprendimento delle caratteristiche
    conv2D_1 = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same", name="conv2D_1")(x)
    MaxPooling2D_1 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_1")(conv2D_1)
    conv2D_2 = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same", name="conv2D_2")(MaxPooling2D_1)
    MaxPooling2D_2 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_2")(conv2D_2)
    conv2D_3 = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same", name="conv2D_3")(MaxPooling2D_2)
    MaxPooling2D_3 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_3")(conv2D_3)
    conv2D_4 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_4")(MaxPooling2D_3)
    MaxPooling2D_4 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_4")(conv2D_4)
    conv2D_5 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_5")(MaxPooling2D_4)

    # Blocco di classificazione
    Flatten = tf.keras.layers.Flatten(name="Flatten")(conv2D_5)
    outputs = tf.keras.layers.Dense(30, activation="softmax", name="dense_output")(Flatten)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# Nella prossima cella di codice dichiariamo l'**ottimizzatore** da utilizzare (rmsprop), le **metriche** di cui tenere traccia (accuratezza), e la funzione di perdita da utilizzare per il calcolo del gradiente. Nel nostro caso la **funzione di perdita** corrisponde alla `sparse_categorical_crossentropy`, una variante della `categorical_crossentropy`.
#
# La **sparse categorical crossentropy** viene utilizzata quando le classi sono rappresentate come interi, proprio come nel nostro caso.

# %%
basic_model = get_basic_model()
basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

basic_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inputs (InputLayer)         [(None, 124, 129, 1)]     0
#
#  normalizzazione (Normalizat  (None, 124, 129, 1)      3
#  ion)
#
#  conv2D_1 (Conv2D)           (None, 124, 129, 32)      320
#
#  MaxPooling2D_1 (MaxPooling2  (None, 62, 64, 32)       0
#  D)
#
#  conv2D_2 (Conv2D)           (None, 62, 64, 64)        18496
#
#  MaxPooling2D_2 (MaxPooling2  (None, 31, 32, 64)       0
#  D)
#
#  conv2D_3 (Conv2D)           (None, 31, 32, 128)       73856
#
#  MaxPooling2D_3 (MaxPooling2  (None, 15, 16, 128)      0
#  D)
#
#  conv2D_4 (Conv2D)           (None, 15, 16, 256)       295168
#
#  MaxPooling2D_4 (MaxPooling2  (None, 7, 8, 256)        0
#  D)
#
#  conv2D_5 (Conv2D)           (None, 7, 8, 256)         590080
#
#  Flatten (Flatten)           (None, 14336)             0
#
#  dense_output (Dense)        (None, 30)                430110
#
# =================================================================
# Total params: 1,408,033
# Trainable params: 1,408,030
# Non-trainable params: 3
# _________________________________________________________________

# %% [markdown]
# Il modello ha un totale di circa **1.4 milioni di parametri**, bilanciando complessità e capacità di apprendimento.

# %%
basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/basic_model_adam.keras", save_best_only=True, monitor="val_loss")]
basic_model_history = basic_model.fit(train_ds, epochs=30, validation_data=val_ds, callbacks=basic_model_callbacks)
# Out:
# Epoch 1/30
# 243/243 [==============================] - 6s 12ms/step - loss: 2.3773 - accuracy: 0.3329 - val_loss: 1.4018 - val_accuracy: 0.6019
# Epoch 2/30
# 243/243 [==============================] - 3s 11ms/step - loss: 1.0084 - accuracy: 0.7151 - val_loss: 0.8663 - val_accuracy: 0.7585
# Epoch 3/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.5503 - accuracy: 0.8445 - val_loss: 0.7416 - val_accuracy: 0.8144
# Epoch 4/30
# 243/243 [==============================] - 3s 10ms/step - loss: 0.3434 - accuracy: 0.8963 - val_loss: 0.7787 - val_accuracy: 0.8275
# Epoch 5/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2314 - accuracy: 0.9312 - val_loss: 0.8816 - val_accuracy: 0.8218
# Epoch 6/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1869 - accuracy: 0.9423 - val_loss: 1.0343 - val_accuracy: 0.8129
# Epoch 7/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1767 - accuracy: 0.9459 - val_loss: 0.9211 - val_accuracy: 0.8187
# Epoch 8/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1331 - accuracy: 0.9613 - val_loss: 0.8628 - val_accuracy: 0.8345
# Epoch 9/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1054 - accuracy: 0.9715 - val_loss: 1.0436 - val_accuracy: 0.8449
# Epoch 10/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1083 - accuracy: 0.9683 - val_loss: 1.0483 - val_accuracy: 0.8144
# Epoch 11/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0838 - accuracy: 0.9782 - val_loss: 1.1376 - val_accuracy: 0.8248
# Epoch 12/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0931 - accuracy: 0.9733 - val_loss: 1.0083 - val_accuracy: 0.8383
# Epoch 13/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0741 - accuracy: 0.9785 - val_loss: 1.0978 - val_accuracy: 0.8075
# Epoch 14/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0802 - accuracy: 0.9756 - val_loss: 0.9445 - val_accuracy: 0.8422
# Epoch 15/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0520 - accuracy: 0.9843 - val_loss: 0.9411 - val_accuracy: 0.8526
# Epoch 16/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0637 - accuracy: 0.9839 - val_loss: 1.1629 - val_accuracy: 0.8210
# Epoch 17/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0650 - accuracy: 0.9808 - val_loss: 1.3212 - val_accuracy: 0.8160
# Epoch 18/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0886 - accuracy: 0.9774 - val_loss: 1.1705 - val_accuracy: 0.8410
# Epoch 19/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0370 - accuracy: 0.9883 - val_loss: 1.1672 - val_accuracy: 0.8268
# Epoch 20/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0862 - accuracy: 0.9773 - val_loss: 0.9132 - val_accuracy: 0.8322
# Epoch 21/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0575 - accuracy: 0.9840 - val_loss: 0.9855 - val_accuracy: 0.8449
# Epoch 22/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0456 - accuracy: 0.9867 - val_loss: 1.1627 - val_accuracy: 0.8511
# Epoch 23/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0272 - accuracy: 0.9919 - val_loss: 1.2303 - val_accuracy: 0.8630
# Epoch 24/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0606 - accuracy: 0.9858 - val_loss: 1.4144 - val_accuracy: 0.7951
# Epoch 25/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0590 - accuracy: 0.9836 - val_loss: 1.1063 - val_accuracy: 0.8441
# Epoch 26/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0401 - accuracy: 0.9896 - val_loss: 1.2869 - val_accuracy: 0.8569
# Epoch 27/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0460 - accuracy: 0.9870 - val_loss: 1.0548 - val_accuracy: 0.8468
# Epoch 28/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0588 - accuracy: 0.9869 - val_loss: 1.1518 - val_accuracy: 0.8522
# Epoch 29/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0377 - accuracy: 0.9907 - val_loss: 1.1761 - val_accuracy: 0.8337
# Epoch 30/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0335 - accuracy: 0.9919 - val_loss: 1.1489 - val_accuracy: 0.8530

# %% [markdown]
# Alleniamo il modello per 30 epoche e visualizziamo le **curve di addestramento** e **validazione**.
#
# In modo tale da poter accedere ai dati del modello più facilmente in futuro trasformiamo la history del modello in un dataframe pandas. Questo facilità anche al visualizzazione dei dati salvati per un caso futuro.

# %%
def convert_history_to_csv(model_history):
    # converto la history del dataframe in un dataframe pandas
    model_history_df = pd.DataFrame(model_history.history)
    # cambio il nome dell'indice e lo imposto a partire da 1
    model_history_df.index = range(1, len(model_history_df) + 1)
    model_history_df.index.name = "epochs"

    return model_history_df

# %% [markdown]
# Salvo i dati della history del modello in un file csv.

# %%
basic_model_history_df = convert_history_to_csv(basic_model_history)
basic_model_history_df.to_csv("model_histories/rmsprop/basic_model_history_adam.csv")

# %% [markdown]
# Inoltre abbiamo salvato il miglior modello nellas seguente directory `bestmodels/rmsprop/` con il nome `basic_model.keras`. L'estensione keras potrebbe crearci problemi di corruzioni se utilizziamo versioni differenti di pacchetti o python, perciò lo convertiamo nello standard onnx.

# %% [markdown]
# Per convertirlo nello standard onnx procediamo a utilizzare le librerie **tf2onnx** e **onnx**, importate precedentemente.

# %%
def convert_model_to_onnx(model_path, input_shape):
    model = tf.keras.models.load_model(model_path)

    onnx_path = model_path.split(".")[:-1] + ["onnx"]
    onnx_path = ".".join(onnx_path)
    
    input_signature = [tf.TensorSpec((None, *input_shape), tf.float32, name="input")]
    onnx_model, _ = tf2onnx.convert.from_keras(model, input_signature=input_signature)

    onnx.save(onnx_model, onnx_path)

# %%
convert_model_to_onnx("bestmodels/rmsprop/basic_model_adam.keras", (124, 129, 1))

# %%
def create_train_val_plot(history, overfit=True):
    # definisco numero epoche
    epochs = range(1, len(history['accuracy']) + 1)

    # Accuracy
    accuracy = history['accuracy']
    val_accuracy = history['val_accuracy']

    fig_acc, ax_acc = plt.subplots()

    # linea di base
    ax_acc.plot(epochs, [0.5 for x in range(len(epochs))], color="lightgray", linestyle="--", label="Base")
    # linee di accuratezza
    ax_acc.plot(epochs, accuracy, color="slategray", label="Accuratezza in addestramento")
    ax_acc.plot(epochs, val_accuracy, color="indianred", label="Accuratezza in validazione")
    # miglior accuratezza validazione
    ax_acc.axhline(y=max(val_accuracy), c='indianred', alpha=0.7, linestyle='--')
    ax_acc.text(len(epochs) * 1.07, max(val_accuracy), round(max(val_accuracy), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_acc.spines["right"].set_visible(False)
    ax_acc.spines["top"].set_visible(False)
    ax_acc.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_acc.set_title("Accuratezza in addestramento e validazione")
    ax_acc.set_xlabel("Epoche")
    ax_acc.set_ylabel("Accuratezza (%)")
    ax_acc.legend()

    # Loss
    loss = history['loss']
    val_loss = history['val_loss']

    fig_loss, ax_loss = plt.subplots()

    # linee di loss
    ax_loss.plot(epochs, loss, color="slategray", label="Perdita in addestramento")
    ax_loss.plot(epochs, val_loss, color="indianred", label="Perdita in validazione")
    # miglior loss validazione
    ax_loss.axhline(y=min(val_loss), c='indianred', alpha=0.7, linestyle='--')
    ax_loss.text(len(epochs) * 1.07, min(val_loss), round(min(val_loss), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_loss.spines["right"].set_visible(False)
    ax_loss.spines["top"].set_visible(False)
    ax_loss.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_loss.set_title("Perdita in addestramento e validazione")
    ax_loss.set_xlabel("Epoche")
    ax_loss.set_ylabel("Perdita")

    handles, _ = ax_loss.get_legend_handles_labels()

    if overfit:
        # area overfit
        rect = mpatches.Rectangle((np.argmin(val_loss) + 1, 0), width=100 - np.argmin(val_loss), height=max(max(loss), max(val_loss)), color='lightcoral', alpha=0.3)
        ax_loss.add_patch(rect)
        # patch overfit per legenda
        overfit = mpatches.Patch(color='indianred', alpha=0.3, label='Area overfit')
        handles, _ = ax_loss.get_legend_handles_labels()
        handles.append(overfit)

    # legenda
    ax_loss.legend(handles=handles)

    plt.show()

# %%
create_train_val_plot(basic_model_history.history)

# %% [markdown]
# Questi grafici mostrano come il nostro modello sia andato immediatamente in overfitting. L'accuratezza dell'addestramento aumenta col tempo e raggiunge quasi il **100%**, mentre l'accuratezza della validazione si attesta sull'**85%** con un **picco del 86%**. Inoltre, la **perdita nel set di addestramento** continua a diminuire dopo la **quinta epoca** mentre la **perdita nel set di validazione** aumenta.

# %% [markdown]
# Possiamo verificare l'accuratezza della migliore versione del nostro modello di base ricaricando il file **basic_model.keras**

# %%
best_basic_model = tf.keras.models.load_model("bestmodels/rmsprop/basic_model_adam.keras")
test_loss, test_acc = best_basic_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 8ms/step - loss: 0.7771 - accuracy: 0.7947
# Accuratezza: 0.795

# %% [markdown]
# Oppure possiamo verificarla con il file **basic_model_adam.onnx**

# %%
def evaluate_onnx_model(path_model_onnx, test_ds):
    # il fatto che sia suddiviso in batch mi crea problemi, perciò lo risolvo togliendoli
    test_ds = test_ds.unbatch()
    
    # carico il modello utilizzando il file onnx
    m = rt.InferenceSession(path_model_onnx)
    
    # trasformo il dataset in array numpy
    spectrogram_np = np.array([spectrogram.numpy() for spectrogram, _ in test_ds])
    labels_np = np.array([label.numpy() for _, label in test_ds])
    
    # eseguo le predizione del modello
    pred_onnx = m.run(None, {'input': spectrogram_np})
    # ottengo la predizione corretta
    predictions = np.argmax(pred_onnx[0], axis=1)
    # computo la accuratezza
    accuracy = np.mean(predictions == labels_np)
    # stampo l'accuratezza
    print(f"Accuratezza: {accuracy:.3f}")

# %%
evaluate_onnx_model("bestmodels/rmsprop/basic_model_adam.onnx", test_ds)
# Out:
# Accuratezza: 0.795

# %% [markdown]
# Abbiamo ottenuto un'**accuratezza** del **79.5%**! Lo riteniamo un buon risultato considerato il task non banale.

# %% [markdown]
# Infine, creiamo una funzione utile a visualizzare graficamente la distribuzione di accuratezza delle classi su un'immagine casuale, per capire come ha lavorato il modello. Nel caso il modello non predica correttamente, la **classe corretta** verrà sempre evidenziata di **verde** mentre la **classe predetta** verrà evidenziata di **giallo**.

# %%
def create_distribution_plot(model, audio, label):
    prediction = model(audio) # otteniamo la predizione del modello sull'audio preso in input

    random_audio_index = np.random.randint(0, len(prediction) - 1) # abbiamo notato che mostravamo sempre la classe no, magari così cambia un po' le classi che mostriamo

    softmax_pred = tf.nn.softmax(prediction[random_audio_index]) # dobbiamo applicare nuovamente la softmax in modo tale da avere dei dati leggibili
    pred_label = np.argmax(softmax_pred) # ci salviamo l'indice della label predetta dal nostro modello, quella con la probabilità più alta

    colors = ['indianred'] * len(label_names) # creiamo un vettore di lunghezza 30 (la quantità delle nostre label) colorate di rosso

    if pred_label == label[random_audio_index].numpy(): # se la label che abbiamo predetto è corretta, allora la coloriamo di verde
        colors[pred_label] = 'seagreen'
    else: # se la label che abbiamo predetto è sbagliata, allora coloriamo di verde la corretta e di gialla la predetta
        colors[pred_label] = 'khaki'
        colors[label[random_audio_index].numpy()] = 'seagreen'

    plt.figure(figsize=(12, 4))

    plt.bar(label_names, softmax_pred.numpy(), color=colors)
    plt.xticks(rotation=45)

    # dichiariamo i colori della legenda
    other_values_patch = mpatches.Patch(color='indianred', label='Altre classi')
    pred_value_patch = mpatches.Patch(color='khaki', label='Classe predetta')
    correct_value_patch = mpatches.Patch(color='green', label='Classe corretta')

    # disegniamo al legenda con i colori necessari
    if pred_label == label[random_audio_index].numpy(): # se abbiamo predetto correttamente la label, non è necessario mostrare il colore giallo (non è presente nel plot)
        plt.legend(handles=[other_values_patch, correct_value_patch])
    else:
        plt.legend(handles=[other_values_patch, pred_value_patch, correct_value_patch])

    plt.show()

# %%
for audio, label in test_ds: # prendiamo un audio a caso del test e creiamo la distribuzione
    create_distribution_plot(best_basic_model, audio, label)
    break

# %% [markdown]
# Possiamo notare dalla distribuzione che il modello in questo caso ha predetto erroneamente la **classe eight**.

# %% [markdown]
# ### Risoluzione dell'overfitting
# Abbiamo capito che il modello è andato immediatamente in **overfitting**, e lo possiamo notare dalla loss di validazione che inizia a salire dalla quinta epoca in poi. L'obbiettivo principale in questo momento è evitare che vada in overfitting troppo velocemente, applicando le tecniche viste a lezione.

# %% [markdown]
# Attualmente per ridurre l'overfitting stiamo applicando **un livello di Dropout**. Il livello di dropout imposta **randomicamente** delle attivazioni a 0, perciò stiamo disattivando qualche neurone. Nello specifico stiamo **azzerando** un certo numero di caratteristiche di uscita dello strato Dense. L'idea dietro questa tecnica è quella di far sforzare maggiormente il modello.

# %%
def get_improved_basic_model():
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(124, 129, 1))
    x = tf.keras.layers.Normalization()(inputs)

    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
improved_basic_model = get_improved_basic_model()
improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/improved_basic_model_adam.keras", save_best_only=True, monitor="val_loss")]
improved_history = improved_basic_model.fit(train_ds, epochs=100, validation_data=val_ds, callbacks=improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 3s 11ms/step - loss: 2.5409 - accuracy: 0.2866 - val_loss: 1.4849 - val_accuracy: 0.5710
# Epoch 2/100
# 243/243 [==============================] - 3s 11ms/step - loss: 1.2401 - accuracy: 0.6425 - val_loss: 0.9614 - val_accuracy: 0.7257
# Epoch 3/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.7448 - accuracy: 0.7825 - val_loss: 0.7868 - val_accuracy: 0.7820
# Epoch 4/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.5218 - accuracy: 0.8468 - val_loss: 0.6959 - val_accuracy: 0.8086
# Epoch 5/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.3926 - accuracy: 0.8802 - val_loss: 0.6295 - val_accuracy: 0.8318
# Epoch 6/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2994 - accuracy: 0.9059 - val_loss: 0.6539 - val_accuracy: 0.8484
# Epoch 7/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2593 - accuracy: 0.9219 - val_loss: 0.7040 - val_accuracy: 0.8337
# Epoch 8/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2026 - accuracy: 0.9371 - val_loss: 0.7332 - val_accuracy: 0.8221
# Epoch 9/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1974 - accuracy: 0.9385 - val_loss: 0.6664 - val_accuracy: 0.8600
# Epoch 10/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1633 - accuracy: 0.9508 - val_loss: 0.7172 - val_accuracy: 0.8627
# Epoch 11/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1518 - accuracy: 0.9559 - val_loss: 0.6305 - val_accuracy: 0.8677
# Epoch 12/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1332 - accuracy: 0.9579 - val_loss: 0.8176 - val_accuracy: 0.8646
# Epoch 13/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1624 - accuracy: 0.9512 - val_loss: 0.6330 - val_accuracy: 0.8688
# Epoch 14/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1129 - accuracy: 0.9680 - val_loss: 0.6390 - val_accuracy: 0.8762
# Epoch 15/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1226 - accuracy: 0.9633 - val_loss: 0.6780 - val_accuracy: 0.8634
# Epoch 16/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1202 - accuracy: 0.9642 - val_loss: 0.5781 - val_accuracy: 0.8738
# Epoch 17/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0954 - accuracy: 0.9735 - val_loss: 0.7014 - val_accuracy: 0.8561
# Epoch 18/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1026 - accuracy: 0.9701 - val_loss: 0.8014 - val_accuracy: 0.8661
# Epoch 19/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0843 - accuracy: 0.9771 - val_loss: 0.8229 - val_accuracy: 0.8781
# Epoch 20/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0937 - accuracy: 0.9726 - val_loss: 0.8689 - val_accuracy: 0.8700
# Epoch 21/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0909 - accuracy: 0.9711 - val_loss: 0.9292 - val_accuracy: 0.8777
# Epoch 22/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1086 - accuracy: 0.9704 - val_loss: 0.7719 - val_accuracy: 0.8723
# Epoch 23/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0711 - accuracy: 0.9800 - val_loss: 0.9276 - val_accuracy: 0.8696
# Epoch 24/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0875 - accuracy: 0.9763 - val_loss: 0.8370 - val_accuracy: 0.8742
# Epoch 25/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0840 - accuracy: 0.9763 - val_loss: 0.6842 - val_accuracy: 0.8681
# Epoch 26/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0752 - accuracy: 0.9781 - val_loss: 0.7081 - val_accuracy: 0.8792
# Epoch 27/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0496 - accuracy: 0.9848 - val_loss: 0.6989 - val_accuracy: 0.8885
# Epoch 28/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0967 - accuracy: 0.9738 - val_loss: 0.8507 - val_accuracy: 0.8769
# Epoch 29/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0771 - accuracy: 0.9782 - val_loss: 0.8278 - val_accuracy: 0.8808
# Epoch 30/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0742 - accuracy: 0.9802 - val_loss: 0.7290 - val_accuracy: 0.8654
# Epoch 31/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0708 - accuracy: 0.9793 - val_loss: 0.9515 - val_accuracy: 0.8696
# Epoch 32/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0794 - accuracy: 0.9776 - val_loss: 0.9799 - val_accuracy: 0.8711
# Epoch 33/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0709 - accuracy: 0.9795 - val_loss: 0.8160 - val_accuracy: 0.8765
# Epoch 34/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0559 - accuracy: 0.9822 - val_loss: 0.8197 - val_accuracy: 0.8823
# Epoch 35/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0628 - accuracy: 0.9834 - val_loss: 0.9408 - val_accuracy: 0.8800
# Epoch 36/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0324 - accuracy: 0.9902 - val_loss: 0.8689 - val_accuracy: 0.8785
# Epoch 37/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0578 - accuracy: 0.9848 - val_loss: 0.8482 - val_accuracy: 0.8746
# Epoch 38/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0754 - accuracy: 0.9800 - val_loss: 0.8738 - val_accuracy: 0.8839
# Epoch 39/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0719 - accuracy: 0.9816 - val_loss: 0.7657 - val_accuracy: 0.8881
# Epoch 40/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0636 - accuracy: 0.9812 - val_loss: 0.9638 - val_accuracy: 0.8708
# Epoch 41/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0681 - accuracy: 0.9829 - val_loss: 0.8386 - val_accuracy: 0.8823
# Epoch 42/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0593 - accuracy: 0.9849 - val_loss: 0.8618 - val_accuracy: 0.8858
# Epoch 43/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0602 - accuracy: 0.9829 - val_loss: 0.7526 - val_accuracy: 0.8866
# Epoch 44/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0731 - accuracy: 0.9817 - val_loss: 0.7623 - val_accuracy: 0.8866
# Epoch 45/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0376 - accuracy: 0.9883 - val_loss: 0.9193 - val_accuracy: 0.8916
# Epoch 46/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0485 - accuracy: 0.9879 - val_loss: 0.7799 - val_accuracy: 0.8850
# Epoch 47/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0306 - accuracy: 0.9914 - val_loss: 0.8268 - val_accuracy: 0.8897
# Epoch 48/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0503 - accuracy: 0.9878 - val_loss: 0.7066 - val_accuracy: 0.8970
# Epoch 49/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0680 - accuracy: 0.9836 - val_loss: 0.8792 - val_accuracy: 0.8916
# Epoch 50/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0435 - accuracy: 0.9875 - val_loss: 0.9555 - val_accuracy: 0.8661
# Epoch 51/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0490 - accuracy: 0.9863 - val_loss: 0.9928 - val_accuracy: 0.8754
# Epoch 52/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1017 - accuracy: 0.9764 - val_loss: 1.0166 - val_accuracy: 0.8731
# Epoch 53/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0616 - accuracy: 0.9860 - val_loss: 0.7717 - val_accuracy: 0.8931
# Epoch 54/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0366 - accuracy: 0.9898 - val_loss: 0.9396 - val_accuracy: 0.8873
# Epoch 55/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0402 - accuracy: 0.9909 - val_loss: 0.8491 - val_accuracy: 0.8935
# Epoch 56/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0244 - accuracy: 0.9936 - val_loss: 0.9385 - val_accuracy: 0.8943
# Epoch 57/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0494 - accuracy: 0.9889 - val_loss: 0.9431 - val_accuracy: 0.8592
# Epoch 58/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0684 - accuracy: 0.9844 - val_loss: 0.9773 - val_accuracy: 0.8781
# Epoch 59/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0496 - accuracy: 0.9858 - val_loss: 1.3096 - val_accuracy: 0.8789
# Epoch 60/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0666 - accuracy: 0.9834 - val_loss: 1.0308 - val_accuracy: 0.8754
# Epoch 61/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0441 - accuracy: 0.9894 - val_loss: 1.0100 - val_accuracy: 0.8804
# Epoch 62/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0413 - accuracy: 0.9896 - val_loss: 1.0405 - val_accuracy: 0.8796
# Epoch 63/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0532 - accuracy: 0.9862 - val_loss: 1.1398 - val_accuracy: 0.8769
# Epoch 64/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0664 - accuracy: 0.9858 - val_loss: 1.0555 - val_accuracy: 0.8781
# Epoch 65/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0464 - accuracy: 0.9892 - val_loss: 0.8271 - val_accuracy: 0.8889
# Epoch 66/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0560 - accuracy: 0.9865 - val_loss: 0.8967 - val_accuracy: 0.8974
# Epoch 67/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0541 - accuracy: 0.9872 - val_loss: 0.9304 - val_accuracy: 0.8908
# Epoch 68/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0433 - accuracy: 0.9880 - val_loss: 0.9882 - val_accuracy: 0.8819
# Epoch 69/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0426 - accuracy: 0.9887 - val_loss: 1.0916 - val_accuracy: 0.8881
# Epoch 70/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0572 - accuracy: 0.9869 - val_loss: 1.1852 - val_accuracy: 0.8819
# Epoch 71/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0440 - accuracy: 0.9894 - val_loss: 1.0199 - val_accuracy: 0.8970
# Epoch 72/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0357 - accuracy: 0.9907 - val_loss: 1.3169 - val_accuracy: 0.8700
# Epoch 73/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0527 - accuracy: 0.9887 - val_loss: 1.4313 - val_accuracy: 0.8623
# Epoch 74/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0549 - accuracy: 0.9878 - val_loss: 1.1474 - val_accuracy: 0.8796
# Epoch 75/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0506 - accuracy: 0.9884 - val_loss: 1.1988 - val_accuracy: 0.8939
# Epoch 76/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0464 - accuracy: 0.9885 - val_loss: 1.1020 - val_accuracy: 0.8958
# Epoch 77/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0396 - accuracy: 0.9907 - val_loss: 0.9969 - val_accuracy: 0.8916
# Epoch 78/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0408 - accuracy: 0.9907 - val_loss: 1.1720 - val_accuracy: 0.8765
# Epoch 79/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0323 - accuracy: 0.9916 - val_loss: 1.0669 - val_accuracy: 0.8843
# Epoch 80/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0329 - accuracy: 0.9906 - val_loss: 1.1521 - val_accuracy: 0.8611
# Epoch 81/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0433 - accuracy: 0.9903 - val_loss: 1.1587 - val_accuracy: 0.8785
# Epoch 82/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0408 - accuracy: 0.9905 - val_loss: 1.4237 - val_accuracy: 0.8580
# Epoch 83/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0527 - accuracy: 0.9880 - val_loss: 1.2804 - val_accuracy: 0.8823
# Epoch 84/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0420 - accuracy: 0.9902 - val_loss: 1.1772 - val_accuracy: 0.8889
# Epoch 85/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0575 - accuracy: 0.9875 - val_loss: 1.3566 - val_accuracy: 0.8642
# Epoch 86/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0613 - accuracy: 0.9867 - val_loss: 1.1218 - val_accuracy: 0.8885
# Epoch 87/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0557 - accuracy: 0.9892 - val_loss: 1.1202 - val_accuracy: 0.8746
# Epoch 88/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0575 - accuracy: 0.9876 - val_loss: 1.3149 - val_accuracy: 0.8850
# Epoch 89/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0442 - accuracy: 0.9901 - val_loss: 1.4480 - val_accuracy: 0.8796
# Epoch 90/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0505 - accuracy: 0.9896 - val_loss: 1.2018 - val_accuracy: 0.8789
# Epoch 91/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0503 - accuracy: 0.9881 - val_loss: 1.0503 - val_accuracy: 0.8939
# Epoch 92/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0356 - accuracy: 0.9912 - val_loss: 1.1119 - val_accuracy: 0.8939
# Epoch 93/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0393 - accuracy: 0.9897 - val_loss: 1.1764 - val_accuracy: 0.8858
# Epoch 94/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.0527 - accuracy: 0.9887 - val_loss: 1.2341 - val_accuracy: 0.8927
# Epoch 95/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0359 - accuracy: 0.9918 - val_loss: 1.1710 - val_accuracy: 0.8951
# Epoch 96/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.0311 - accuracy: 0.9929 - val_loss: 1.2197 - val_accuracy: 0.8974
# Epoch 97/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0598 - accuracy: 0.9889 - val_loss: 1.2171 - val_accuracy: 0.8951
# Epoch 98/100
# 243/243 [==============================] - 3s 10ms/step - loss: 0.0380 - accuracy: 0.9899 - val_loss: 1.1015 - val_accuracy: 0.8997
# Epoch 99/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0333 - accuracy: 0.9925 - val_loss: 1.3496 - val_accuracy: 0.8981
# Epoch 100/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0365 - accuracy: 0.9915 - val_loss: 1.3000 - val_accuracy: 0.8870

# %% [markdown]
# Salviamo come prima la history del modello in un file csv.

# %%
improved_history_df = convert_history_to_csv(improved_history)
improved_history_df.to_csv("model_histories/rmsprop/improved_history_adam.csv")

# %% [markdown]
# Inoltre salviamo nuovamente il miglior modello anche nel formato **.onnx**.

# %%
convert_model_to_onnx("bestmodels/rmsprop/improved_basic_model_adam.keras", (124, 129, 1))

# %%
create_train_val_plot(improved_history.history)

# %% [markdown]
# Alleniamo il modello per 100 epoche e visualizziamo le **curve di addestramento** e **validazione**.
#
# L'obbiettivo di ridurre **l'overfitting è stato comunque raggiunto**, dato che il modello ha iniziato ad andare in overfitting leggermente dopo, quindi verso **l'epoca 10**, ma dobbiamo sicuramente applicare qualche altra tecnica per migliorarlo ulteriormente.

# %%
improved_best_model = tf.keras.models.load_model("bestmodels/rmsprop/improved_basic_model_adam.keras")
test_loss, test_acc = improved_best_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 4ms/step - loss: 0.6460 - accuracy: 0.8601
# Accuratezza: 0.860

# %% [markdown]
# Verifichiamola anche con il modello **.onnx**

# %%
evaluate_onnx_model("bestmodels/rmsprop/improved_basic_model_adam.onnx", test_ds)
# Out:
# Accuratezza: 0.860

# %% [markdown]
# Abbiamo ottenuto un notevole miglioramento dell'accuratezza, attualmente siamo a quota **86%**!.

# %%
for audio, label in test_ds:
    create_distribution_plot(improved_best_model, audio, label)
    break

# %% [markdown]
# In questo caso il modello è stato in grado di predirre la classe corretta **left**.

# %% [markdown]
# ## Miglioramenti all'architettura del modello
#
# Durante il corso abbiamo visto anche delle best practice architetturali che possono aiutare a ottenere maggiori prestazioni col modello. Il nostro scopo è provare le tecniche viste e studiate durante il corso e capire come reagiscono al task.

# %% [markdown]
# Le tre tecniche che andremo ad applicare sono:
# - blocchi residuali
# - normalizzazione dei batch
# - convoluzioni separabili

# %% [markdown]
# ### Blocchi residuali
# I blocchi residuali sono un'applicazione efficace quando riscontriamo il problema dei **gradienti che svaniscono**. Non sono una tecnica strettamente legata ai modelli convolutivi, ma sono una best practice generale che viene applicare nella maggior parte delle architetture.
#
# I **gradienti che vaniscono** sono causati dalle **catene di funzioni troppo lunghe**, che nel nostro caso non sono altro che **una sequenza di livelli convolutivi**. Per ogni livello convolutivo **una certa quantità di rumore** viene introdotta, finché essa non arriva a **sopraffare** le informazioni sul gradiente.
#
# Se le informazioni sul gradiente sono sopraffatte la **backpropagation smette di funzionare**, e quindi il nostro **modello non impara**.

# %% [markdown]
# L'**idea basilare** dietro ai blocchi residuali è quella di **salvare l'informazione** contenuta nell'input precedente al livello convolutivo, e **sommarla all'output** dello stesso livello convolutivo.

# %% [markdown]
# Per applicare i blocchi residuali abbiamo implementato la funzione `residual_block(x, filters, pooling=False)` vista a lezione. La funzione è ovviamente adattata al modello da noi implementato, e utilizza le altre due best practice citate precedentemente.

# %%
def residual_block(x, filters, pooling=False):
    residual = x

    x = tf.keras.layers.SeparableConv2D(filters, 3, padding="same", use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    if pooling:
      x = tf.keras.layers.MaxPooling2D(pool_size=2, padding="same")(x)
      residual = tf.keras.layers.Conv2D(filters, 1, strides=2)(residual)
    elif filters != residual.shape[-1]:
      residual = tf.keras.layers.Conv2D(filters, 1)(residual)

    x = tf.keras.layers.add([x, residual])
    return x

# %% [markdown]
# ### Normalizzazione dei batch e convoluzioni separabili
# La **normalizzazione dei batch** è un concetto che abbiamo già affrontato nel notebook, infatti il suo scopo rimane quello di rendere i dati **più simili tra loro** centrandoli sullo zero, e ciò aiuta la **propagazione del gradiente**. Questa normalizzazione, a differenza della precedente, è in grado di normalizzare i dati in modo adattivo anche quando la media e la varianza cambiano durante l'addestramento.

# %% [markdown]
# Le **convoluzione separabili** invece sono un **sostituto** ai livelli convolutivi utilizzati fino ad adesso, e offrono un modello con maggiori prestazioni e meno parametri.

# %%
def bp_basic_model():
    # input e pre processamento
    inputs = tf.keras.Input(shape=(124, 129, 1))
    # x = data_augmentation(inputs)
    x = tf.keras.layers.Resizing(120, 120)(inputs)

    x = residual_block(x, 32, pooling=True)
    x = residual_block(x, 64, pooling=True)
    x = residual_block(x, 128, pooling=True)
    x = residual_block(x, 256, pooling=True)
    x = residual_block(x, 256, pooling=False)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Livelli per la classificazione
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
bp_basic_model = bp_basic_model()
bp_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

bp_basic_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 124, 129, 1  0           []
#                                 )]
#
#  resizing (Resizing)            (None, 120, 120, 1)  0           ['input_2[0][0]']
#
#  separable_conv2d (SeparableCon  (None, 120, 120, 32  41         ['resizing[0][0]']
#  v2D)                           )
#
#  batch_normalization (BatchNorm  (None, 120, 120, 32  128        ['separable_conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 120, 120, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 60, 60, 32)  0           ['activation[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 60, 60, 32)   64          ['resizing[0][0]']
#
#  add (Add)                      (None, 60, 60, 32)   0           ['max_pooling2d_4[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  separable_conv2d_1 (SeparableC  (None, 60, 60, 64)  2336        ['add[0][0]']
#  onv2D)
#
#  batch_normalization_1 (BatchNo  (None, 60, 60, 64)  256         ['separable_conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 60, 60, 64)   0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 30, 30, 64)  0           ['activation_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 30, 30, 64)   2112        ['add[0][0]']
#
#  add_1 (Add)                    (None, 30, 30, 64)   0           ['max_pooling2d_5[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  separable_conv2d_2 (SeparableC  (None, 30, 30, 128)  8768       ['add_1[0][0]']
#  onv2D)
#
#  batch_normalization_2 (BatchNo  (None, 30, 30, 128)  512        ['separable_conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 30, 30, 128)  0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 15, 15, 128)  0          ['activation_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 15, 15, 128)  8320        ['add_1[0][0]']
#
#  add_2 (Add)                    (None, 15, 15, 128)  0           ['max_pooling2d_6[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  separable_conv2d_3 (SeparableC  (None, 15, 15, 256)  33920      ['add_2[0][0]']
#  onv2D)
#
#  batch_normalization_3 (BatchNo  (None, 15, 15, 256)  1024       ['separable_conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 15, 15, 256)  0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 256)   0           ['activation_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 256)    33024       ['add_2[0][0]']
#
#  add_3 (Add)                    (None, 8, 8, 256)    0           ['max_pooling2d_7[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 8, 8, 256)   67840       ['add_3[0][0]']
#  onv2D)
#
#  batch_normalization_4 (BatchNo  (None, 8, 8, 256)   1024        ['separable_conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 8, 8, 256)    0           ['batch_normalization_4[0][0]']
#
#  add_4 (Add)                    (None, 8, 8, 256)    0           ['activation_4[0][0]',
#                                                                   'add_3[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['add_4[0][0]']
#  alAveragePooling2D)
#
#  dropout_1 (Dropout)            (None, 256)          0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 30)           7710        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 167,079
# Trainable params: 165,607
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %% [markdown]
# Le best practice, insieme al `tf.keras.layers.GlobalAveragePooling2D()` applicato al posto del Flatten, hanno formato un modello con circa **160000 parametri addestrabili** (circa il XX% del modello precedente).

# %%
bp_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/rmsprop/bp_basic_model_adam.keras", save_best_only=True, monitor="val_loss")]
bp_model_history = bp_basic_model.fit(train_ds, epochs=100, validation_data=val_ds, callbacks=bp_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 5s 19ms/step - loss: 3.2492 - accuracy: 0.1144 - val_loss: 3.3584 - val_accuracy: 0.0394
# Epoch 2/100
# 243/243 [==============================] - 5s 18ms/step - loss: 2.6531 - accuracy: 0.2601 - val_loss: 2.8168 - val_accuracy: 0.1929
# Epoch 3/100
# 243/243 [==============================] - 4s 18ms/step - loss: 2.1057 - accuracy: 0.4189 - val_loss: 1.9855 - val_accuracy: 0.4429
# Epoch 4/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.6233 - accuracy: 0.5637 - val_loss: 1.5508 - val_accuracy: 0.5629
# Epoch 5/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.2408 - accuracy: 0.6711 - val_loss: 1.2475 - val_accuracy: 0.6508
# Epoch 6/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.0003 - accuracy: 0.7344 - val_loss: 1.1001 - val_accuracy: 0.6948
# Epoch 7/100
# 243/243 [==============================] - 5s 18ms/step - loss: 0.8434 - accuracy: 0.7733 - val_loss: 0.9455 - val_accuracy: 0.7419
# Epoch 8/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.6991 - accuracy: 0.8122 - val_loss: 1.0756 - val_accuracy: 0.7114
# Epoch 9/100
# 243/243 [==============================] - 5s 18ms/step - loss: 0.6395 - accuracy: 0.8250 - val_loss: 0.6509 - val_accuracy: 0.8245
# Epoch 10/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.5602 - accuracy: 0.8468 - val_loss: 0.6136 - val_accuracy: 0.8414
# Epoch 11/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.5113 - accuracy: 0.8595 - val_loss: 0.8342 - val_accuracy: 0.7527
# Epoch 12/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.4467 - accuracy: 0.8812 - val_loss: 0.7113 - val_accuracy: 0.8063
# Epoch 13/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.4247 - accuracy: 0.8838 - val_loss: 0.7096 - val_accuracy: 0.7840
# Epoch 14/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.3967 - accuracy: 0.8921 - val_loss: 0.5105 - val_accuracy: 0.8646
# Epoch 15/100
# 243/243 [==============================] - 5s 18ms/step - loss: 0.3577 - accuracy: 0.9005 - val_loss: 0.5213 - val_accuracy: 0.8507
# Epoch 16/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.3269 - accuracy: 0.9075 - val_loss: 0.5530 - val_accuracy: 0.8492
# Epoch 17/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.3209 - accuracy: 0.9125 - val_loss: 0.6319 - val_accuracy: 0.8291
# Epoch 18/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.3000 - accuracy: 0.9175 - val_loss: 0.6454 - val_accuracy: 0.8206
# Epoch 19/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.2939 - accuracy: 0.9206 - val_loss: 0.6677 - val_accuracy: 0.8194
# Epoch 20/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.2831 - accuracy: 0.9216 - val_loss: 0.5190 - val_accuracy: 0.8573
# Epoch 21/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.2458 - accuracy: 0.9321 - val_loss: 0.5803 - val_accuracy: 0.8380
# Epoch 22/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.2703 - accuracy: 0.9253 - val_loss: 0.7935 - val_accuracy: 0.7959
# Epoch 23/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.2542 - accuracy: 0.9299 - val_loss: 0.5344 - val_accuracy: 0.8495
# Epoch 24/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.2300 - accuracy: 0.9323 - val_loss: 0.7718 - val_accuracy: 0.8021
# Epoch 25/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.2263 - accuracy: 0.9343 - val_loss: 0.8861 - val_accuracy: 0.7677
# Epoch 26/100
# 243/243 [==============================] - 5s 18ms/step - loss: 0.2031 - accuracy: 0.9424 - val_loss: 0.7877 - val_accuracy: 0.7975
# Epoch 27/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.2291 - accuracy: 0.9375 - val_loss: 0.5781 - val_accuracy: 0.8391
# Epoch 28/100
# 243/243 [==============================] - 5s 18ms/step - loss: 0.1932 - accuracy: 0.9473 - val_loss: 0.7880 - val_accuracy: 0.7836
# Epoch 29/100
# 243/243 [==============================] - 5s 18ms/step - loss: 0.1837 - accuracy: 0.9506 - val_loss: 0.5405 - val_accuracy: 0.8607
# Epoch 30/100
# 243/243 [==============================] - 5s 18ms/step - loss: 0.1877 - accuracy: 0.9472 - val_loss: 0.7866 - val_accuracy: 0.8048
# Epoch 31/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1617 - accuracy: 0.9567 - val_loss: 0.7286 - val_accuracy: 0.8117
# Epoch 32/100
# 243/243 [==============================] - 5s 18ms/step - loss: 0.1651 - accuracy: 0.9554 - val_loss: 0.5699 - val_accuracy: 0.8511
# Epoch 33/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1806 - accuracy: 0.9494 - val_loss: 0.9083 - val_accuracy: 0.7851
# Epoch 34/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.2092 - accuracy: 0.9409 - val_loss: 0.6493 - val_accuracy: 0.8376
# Epoch 35/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1843 - accuracy: 0.9483 - val_loss: 0.5734 - val_accuracy: 0.8461
# Epoch 36/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1522 - accuracy: 0.9571 - val_loss: 0.6175 - val_accuracy: 0.8430
# Epoch 37/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1746 - accuracy: 0.9495 - val_loss: 0.5343 - val_accuracy: 0.8607
# Epoch 38/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1493 - accuracy: 0.9607 - val_loss: 0.6228 - val_accuracy: 0.8414
# Epoch 39/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1389 - accuracy: 0.9608 - val_loss: 0.6776 - val_accuracy: 0.8221
# Epoch 40/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1576 - accuracy: 0.9554 - val_loss: 0.7389 - val_accuracy: 0.8164
# Epoch 41/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1427 - accuracy: 0.9590 - val_loss: 0.6531 - val_accuracy: 0.8329
# Epoch 42/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1477 - accuracy: 0.9572 - val_loss: 0.7394 - val_accuracy: 0.8137
# Epoch 43/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1241 - accuracy: 0.9646 - val_loss: 0.5040 - val_accuracy: 0.8827
# Epoch 44/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1397 - accuracy: 0.9616 - val_loss: 0.8027 - val_accuracy: 0.8063
# Epoch 45/100
# 243/243 [==============================] - 5s 18ms/step - loss: 0.1317 - accuracy: 0.9655 - val_loss: 0.5723 - val_accuracy: 0.8503
# Epoch 46/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1286 - accuracy: 0.9660 - val_loss: 0.5633 - val_accuracy: 0.8511
# Epoch 47/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1468 - accuracy: 0.9576 - val_loss: 0.7622 - val_accuracy: 0.8156
# Epoch 48/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1149 - accuracy: 0.9695 - val_loss: 0.4367 - val_accuracy: 0.8916
# Epoch 49/100
# 243/243 [==============================] - 5s 18ms/step - loss: 0.1174 - accuracy: 0.9677 - val_loss: 0.8163 - val_accuracy: 0.8171
# Epoch 50/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1184 - accuracy: 0.9673 - val_loss: 0.7385 - val_accuracy: 0.8272
# Epoch 51/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1318 - accuracy: 0.9637 - val_loss: 0.4443 - val_accuracy: 0.8873
# Epoch 52/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1073 - accuracy: 0.9727 - val_loss: 1.0562 - val_accuracy: 0.7936
# Epoch 53/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.1624 - accuracy: 0.9540 - val_loss: 0.7634 - val_accuracy: 0.8256
# Epoch 54/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1411 - accuracy: 0.9622 - val_loss: 0.6594 - val_accuracy: 0.8480
# Epoch 55/100
# 243/243 [==============================] - 5s 18ms/step - loss: 0.1207 - accuracy: 0.9674 - val_loss: 0.4257 - val_accuracy: 0.9001
# Epoch 56/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0942 - accuracy: 0.9728 - val_loss: 0.7033 - val_accuracy: 0.8534
# Epoch 57/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0933 - accuracy: 0.9762 - val_loss: 0.5697 - val_accuracy: 0.8692
# Epoch 58/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1229 - accuracy: 0.9635 - val_loss: 0.8455 - val_accuracy: 0.8391
# Epoch 59/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1088 - accuracy: 0.9720 - val_loss: 0.6072 - val_accuracy: 0.8546
# Epoch 60/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1064 - accuracy: 0.9704 - val_loss: 0.5447 - val_accuracy: 0.8611
# Epoch 61/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1137 - accuracy: 0.9675 - val_loss: 0.7561 - val_accuracy: 0.8492
# Epoch 62/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1086 - accuracy: 0.9702 - val_loss: 0.7039 - val_accuracy: 0.8603
# Epoch 63/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1109 - accuracy: 0.9696 - val_loss: 0.5488 - val_accuracy: 0.8677
# Epoch 64/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0977 - accuracy: 0.9727 - val_loss: 0.6004 - val_accuracy: 0.8661
# Epoch 65/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0985 - accuracy: 0.9709 - val_loss: 0.6490 - val_accuracy: 0.8522
# Epoch 66/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0948 - accuracy: 0.9755 - val_loss: 0.6171 - val_accuracy: 0.8619
# Epoch 67/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1071 - accuracy: 0.9711 - val_loss: 0.8770 - val_accuracy: 0.8094
# Epoch 68/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1196 - accuracy: 0.9652 - val_loss: 0.9843 - val_accuracy: 0.7913
# Epoch 69/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0973 - accuracy: 0.9732 - val_loss: 0.5163 - val_accuracy: 0.8773
# Epoch 70/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0657 - accuracy: 0.9834 - val_loss: 0.4444 - val_accuracy: 0.8920
# Epoch 71/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0721 - accuracy: 0.9821 - val_loss: 1.0429 - val_accuracy: 0.8005
# Epoch 72/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1023 - accuracy: 0.9720 - val_loss: 0.5527 - val_accuracy: 0.8723
# Epoch 73/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1449 - accuracy: 0.9608 - val_loss: 0.7409 - val_accuracy: 0.8395
# Epoch 74/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1032 - accuracy: 0.9715 - val_loss: 0.4624 - val_accuracy: 0.8823
# Epoch 75/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0883 - accuracy: 0.9755 - val_loss: 0.7124 - val_accuracy: 0.8522
# Epoch 76/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0829 - accuracy: 0.9764 - val_loss: 0.7566 - val_accuracy: 0.8430
# Epoch 77/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0951 - accuracy: 0.9756 - val_loss: 0.4237 - val_accuracy: 0.8997
# Epoch 78/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0842 - accuracy: 0.9769 - val_loss: 0.7177 - val_accuracy: 0.8438
# Epoch 79/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1119 - accuracy: 0.9688 - val_loss: 0.5023 - val_accuracy: 0.8831
# Epoch 80/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1072 - accuracy: 0.9716 - val_loss: 1.3492 - val_accuracy: 0.7755
# Epoch 81/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0931 - accuracy: 0.9731 - val_loss: 0.6888 - val_accuracy: 0.8511
# Epoch 82/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0662 - accuracy: 0.9818 - val_loss: 0.5058 - val_accuracy: 0.8816
# Epoch 83/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0839 - accuracy: 0.9785 - val_loss: 0.5619 - val_accuracy: 0.8719
# Epoch 84/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1423 - accuracy: 0.9590 - val_loss: 0.9272 - val_accuracy: 0.8094
# Epoch 85/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1091 - accuracy: 0.9684 - val_loss: 0.8608 - val_accuracy: 0.8542
# Epoch 86/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0888 - accuracy: 0.9758 - val_loss: 0.4082 - val_accuracy: 0.9020
# Epoch 87/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0605 - accuracy: 0.9839 - val_loss: 0.4510 - val_accuracy: 0.9012
# Epoch 88/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0789 - accuracy: 0.9781 - val_loss: 0.5141 - val_accuracy: 0.8812
# Epoch 89/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0695 - accuracy: 0.9807 - val_loss: 0.5887 - val_accuracy: 0.8781
# Epoch 90/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0783 - accuracy: 0.9763 - val_loss: 0.5835 - val_accuracy: 0.8816
# Epoch 91/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.0771 - accuracy: 0.9786 - val_loss: 0.4066 - val_accuracy: 0.9047
# Epoch 92/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0689 - accuracy: 0.9808 - val_loss: 0.4919 - val_accuracy: 0.8958
# Epoch 93/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0601 - accuracy: 0.9832 - val_loss: 0.6007 - val_accuracy: 0.8808
# Epoch 94/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1067 - accuracy: 0.9702 - val_loss: 0.7898 - val_accuracy: 0.8534
# Epoch 95/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0980 - accuracy: 0.9709 - val_loss: 0.7667 - val_accuracy: 0.8391
# Epoch 96/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0855 - accuracy: 0.9760 - val_loss: 0.4222 - val_accuracy: 0.9055
# Epoch 97/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0761 - accuracy: 0.9793 - val_loss: 0.7705 - val_accuracy: 0.8476
# Epoch 98/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0741 - accuracy: 0.9799 - val_loss: 0.5752 - val_accuracy: 0.8723
# Epoch 99/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0732 - accuracy: 0.9780 - val_loss: 0.6443 - val_accuracy: 0.8596
# Epoch 100/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0624 - accuracy: 0.9834 - val_loss: 0.4585 - val_accuracy: 0.8981

# %% [markdown]
# Salviamo nuoavmente la history del modello in un file csv.

# %%
bp_model_history_df = convert_history_to_csv(bp_model_history)
bp_model_history_df.to_csv("model_histories/rmsprop/bp_model_history_adam.csv")

# %% [markdown]
# Convertiamo anche il miglior modello nel formato **.onnx**.

# %%
convert_model_to_onnx("bestmodels/rmsprop/bp_basic_model_adam.keras", (124, 129, 1))

# %%
create_train_val_plot(bp_model_history.history, overfit=False)

# %% [markdown]
# Possiamo notare che il modello **NON ha raggiunto una vera fase di overfitting**, ma la validazione non ha mostrato un incremento sostanziale all'aumentare delle epoche (probabilmente dovuto dalle tecniche di overfitting non totalmente implementate). La **loss della validazione** stava continuando a scendere, e allo stesso tempo **l'accuratezza della validazione era crescente**.

# %%
best_bp_basic_model = tf.keras.models.load_model("bestmodels/rmsprop/bp_basic_model_adam.keras")
test_loss, test_acc = best_bp_basic_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 7ms/step - loss: 0.4525 - accuracy: 0.9028
# Accuratezza: 0.903

# %% [markdown]
# Verifichiamola anche con il modello **.onnx**.

# %%
evaluate_onnx_model("bestmodels/rmsprop/bp_basic_model_adam.onnx", test_ds)
# Out:
# Accuratezza: 0.903

# %% [markdown]
# Abbiamo nuovamente ottenuto dei miglioramenti sostanziali per quanto riguarda l'accuratezza, ottenendo un **90.3%**. Questo risultato è ottimo, considerando che il modello ha poco più del **10% dei parametri** del precedente.

# %%
for audio, label in test_ds:
    create_distribution_plot(best_bp_basic_model, audio, label)
    break

# %% [markdown]
# La decisione del modello in questo caso è nuovamente chiara, con una leggera indecisione con la classe **tree**.
