# %% [markdown]
# # Modello convolutivo di base
# Lo scopo di questo notebook è creare un **modello convolutivo di base** con un'architettura semplice. In seguito, sarà interessante confrontare i risultati di questo primo modello con i risultati ottenuti da modelli più complessi, o pre addestrati.

# %% [markdown]
# Come al solito, si procede con l'importazione delle librerie utilizzate e la creazione dei set di allenamento e validazione.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd
import numpy as np
import os
import time
# per il modello con estensione .onnx
import onnxruntime as rt
import tf2onnx
import onnx

# %%
train_ds, validation_ds = tf.keras.utils.audio_dataset_from_directory(
    directory='../reduced_dataset/dataset/audio',
    validation_split=0.4, # stiamo mettendo da parte il 40% del dataset, che sarà suddiviso in validation set e test set
    shuffle=True,
    subset='both', # necessario se stiamo utilizzando validation_split (se no darebbe errore)
    seed=0 # necessario se stiamo utilizzando sia shuffle che validation_split (se no darebbe errore)
)

label_names = train_ds.class_names
# Out:
# Found 12933 files belonging to 30 classes.
# Using 7760 files for training.
# Using 5173 files for validation.

# %% [markdown]
# ## Funzioni per processamento dei dati

# %% [markdown]
# La prima funzione che ci tornerà utile è `squeeze(audio, labels)`, della quale abbiamo già visto l'implementazione e parlato del suo utilizzo nel notebook dove trattiamo gli spettrogrammi.

# %%
def squeeze(audio, labels):
    audio = tf.squeeze(audio, axis=-1)
    return audio, labels

# fonte: funzione presa dal seguente link: https://www.geeksforgeeks.org/audio-recognition-in-tensorflow/

# %%
train_ds = train_ds.map(squeeze, tf.data.AUTOTUNE)
validation_ds = validation_ds.map(squeeze, tf.data.AUTOTUNE)

audio, label = next(iter(train_ds))
print(audio.shape)
print(label.shape)
# Out:
# (32, 16000)
# (32,)

# %% [markdown]
# Una volta eseguito questa semplificazione, a partire dai tensori degli audio, creeremo gli spettrogrammi che sarannò presi come input dal modello convolutivo.

# %% [markdown]
# ## Conversione e suddivisione dataset
# Per la conversione del dataset utilizziamo due funzioni che abbiamo già definito nel notebook dove trattiamo gli spettrogrammi.

# %%
def get_spectrogram(waveform):
    spectrogram = tf.signal.stft(waveform, frame_length=255, frame_step=128)
    spectrogram = tf.abs(spectrogram)

    return spectrogram[..., tf.newaxis]

# fonte: tutorial riconoscimento audio semplice di tensorflow: https://www.tensorflow.org/tutorials/audio/simple_audio?hl=it

# %%
def get_spectrogram_dataset(dataset):
    dataset = dataset.map(lambda x, y: (get_spectrogram(x), y), num_parallel_calls=tf.data.AUTOTUNE)

    return dataset

# %% [markdown]
# Definite le due funzioni possiamo procedere a ottenere il nostro **training set**, **validation set**, e **test set** di spettrogrammi. La suddivisione di dati ricordo essere rispettivamente 60%, 20%, 20%.

# %%
train_ds = get_spectrogram_dataset(train_ds)
validation_ds = get_spectrogram_dataset(validation_ds)

val_ds = validation_ds.take(validation_ds.cardinality() // 2) # ho cambiato nome del validation_ds in modo tale da non creare problemi con l'istruzione seguente
test_ds = validation_ds.skip(validation_ds.cardinality() // 2)

# %%
print("Numero di audio training set:", len(train_ds) * 32)
print("Numero di audio validation set:", len(val_ds) * 32)
print("Numero di audio test set:", len(test_ds) * 32)
# Out:
# Numero di audio training set: 7776
# Numero di audio validation set: 2592
# Numero di audio test set: 2592

# %%
for audio, label in train_ds:
    print("Shape (forma) spettrogrammi:", audio.shape)

    spectrogram = np.squeeze(audio[0], axis=-1)
    spectrogram = np.log(spectrogram.T + np.finfo(float).eps)

    plt.imshow(spectrogram.T)
    plt.colorbar(format='%+2.0f dB') # barra laterale dei dB

    plt.title(f"Classe: {label_names[label[0].numpy()]}")
    break
# Out:
# Shape (forma) spettrogrammi: (32, 124, 129, 1)

# %% [markdown]
# La grandezza degli spettrogrammi, quindi delle immagini ottenute, è di **124x129**.

# %% [markdown]
# ## Creazione modello di base

# %% [markdown]
# Come modello implementiamo una rete neurale convolutiva. Questo modello ha un'architettura semplice e servirà da benchmark per i modelli futuri.
#
# La rete prende in ingresso tensori di forma **altezza x larghezza x canali**, rispettivamente di **124, 129, 1**. Per farla lavorare meglio normalizziamo i dati con la funzione `tf.keras.layers.Normalization()`. Questo livello sposta e ridimensiona gli input in una distribuzione centrata su 0 e con deviazione standard 1.

# %% [markdown]
# L'architettura del modello è suddivisa in **due blocchi** principali: un blocco per l'apprendimento delle caratteristiche e un blocco per la classificazione.
#
# Il **blocco di apprendimento delle caratteristiche** ha un'architettura formata da una serie di livelli convolutivi alternati a livelli di max pooling. Per ciascun livello convolutivo viene anche applicata la funzione di attivazione **ReLu** per applicare non linearità. Il blocco termina con un livello convolutivo di **256 filtri**, che corrispondono alla stessa quantità di filtri applicati dal livello convolutivo precedente.
#
# Terminato il blocco di apprendimento delle caratteristiche, è presente il **blocco di classificazione**, formato da un **livello di Flatten**, necessario per trasformare i dati in un vettore unidimensionali, e un **livello Dense**, necessario per la predizione della classe di appartenenza del dato. Quest'ultimo livello Dense ha **30 unità**, che corrispondono alle 30 classi del nostro task di classificazione multiclasse. La funzione di attivazione applicata dal livello Dense è la **softmax**, ideale per i task di classificazione multiclasse.
#
# La funzione **softmax**, a differenza della funzione **sigmoid** ci fornisce una distribuzione di probabilità sulle classi possibili (questa distribuzione saremo in grado di visualizzarla durante la valutazione del modello).

# %%
def get_basic_model():
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(124, 129, 1), name="inputs")
    x = tf.keras.layers.Normalization(name="normalizzazione")(inputs)

    # Blocco di apprendimento delle caratteristiche
    conv2D_1 = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same", name="conv2D_1")(x)
    MaxPooling2D_1 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_1")(conv2D_1)
    conv2D_2 = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same", name="conv2D_2")(MaxPooling2D_1)
    MaxPooling2D_2 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_2")(conv2D_2)
    conv2D_3 = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same", name="conv2D_3")(MaxPooling2D_2)
    MaxPooling2D_3 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_3")(conv2D_3)
    conv2D_4 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_4")(MaxPooling2D_3)
    MaxPooling2D_4 = tf.keras.layers.MaxPooling2D(pool_size=2, name="MaxPooling2D_4")(conv2D_4)
    conv2D_5 = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same", name="conv2D_5")(MaxPooling2D_4)

    # Blocco di classificazione
    Flatten = tf.keras.layers.Flatten(name="Flatten")(conv2D_5)
    outputs = tf.keras.layers.Dense(30, activation="softmax", name="dense_output")(Flatten)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# Nella prossima cella di codice dichiariamo l'**ottimizzatore** da utilizzare (adam), le **metriche** di cui tenere traccia (accuratezza), e la funzione di perdita da utilizzare per il calcolo del gradiente. Nel nostro caso la **funzione di perdita** corrisponde alla `sparse_categorical_crossentropy`, una variante della `categorical_crossentropy`.
#
# La **sparse categorical crossentropy** viene utilizzata quando le classi sono rappresentate come interi, proprio come nel nostro caso.

# %%
basic_model = get_basic_model()
basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

basic_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inputs (InputLayer)         [(None, 124, 129, 1)]     0
#
#  normalizzazione (Normalizat  (None, 124, 129, 1)      3
#  ion)
#
#  conv2D_1 (Conv2D)           (None, 124, 129, 32)      320
#
#  MaxPooling2D_1 (MaxPooling2  (None, 62, 64, 32)       0
#  D)
#
#  conv2D_2 (Conv2D)           (None, 62, 64, 64)        18496
#
#  MaxPooling2D_2 (MaxPooling2  (None, 31, 32, 64)       0
#  D)
#
#  conv2D_3 (Conv2D)           (None, 31, 32, 128)       73856
#
#  MaxPooling2D_3 (MaxPooling2  (None, 15, 16, 128)      0
#  D)
#
#  conv2D_4 (Conv2D)           (None, 15, 16, 256)       295168
#
#  MaxPooling2D_4 (MaxPooling2  (None, 7, 8, 256)        0
#  D)
#
#  conv2D_5 (Conv2D)           (None, 7, 8, 256)         590080
#
#  Flatten (Flatten)           (None, 14336)             0
#
#  dense_output (Dense)        (None, 30)                430110
#
# =================================================================
# Total params: 1,408,033
# Trainable params: 1,408,030
# Non-trainable params: 3
# _________________________________________________________________

# %% [markdown]
# Il modello ha un totale di circa **1.4 milioni di parametri**, bilanciando complessità e capacità di apprendimento.

# %%
basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/adam/basic_model.keras", save_best_only=True, monitor="val_loss")]
basic_model_history = basic_model.fit(train_ds, epochs=30, validation_data=val_ds, callbacks=basic_model_callbacks)
# Out:
# Epoch 1/30
# 243/243 [==============================] - 7s 12ms/step - loss: 2.2969 - accuracy: 0.3517 - val_loss: 1.3158 - val_accuracy: 0.6304
# Epoch 2/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.9455 - accuracy: 0.7357 - val_loss: 0.8504 - val_accuracy: 0.7623
# Epoch 3/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.5127 - accuracy: 0.8501 - val_loss: 0.6651 - val_accuracy: 0.8171
# Epoch 4/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.3268 - accuracy: 0.9021 - val_loss: 0.7272 - val_accuracy: 0.8268
# Epoch 5/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2075 - accuracy: 0.9363 - val_loss: 0.7408 - val_accuracy: 0.8302
# Epoch 6/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1808 - accuracy: 0.9446 - val_loss: 0.8516 - val_accuracy: 0.8275
# Epoch 7/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1480 - accuracy: 0.9527 - val_loss: 0.8881 - val_accuracy: 0.8345
# Epoch 8/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1286 - accuracy: 0.9613 - val_loss: 1.0095 - val_accuracy: 0.8052
# Epoch 9/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1362 - accuracy: 0.9610 - val_loss: 0.8692 - val_accuracy: 0.8426
# Epoch 10/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0873 - accuracy: 0.9756 - val_loss: 0.8822 - val_accuracy: 0.8476
# Epoch 11/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0963 - accuracy: 0.9763 - val_loss: 1.0366 - val_accuracy: 0.8322
# Epoch 12/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0725 - accuracy: 0.9796 - val_loss: 0.8724 - val_accuracy: 0.8526
# Epoch 13/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0625 - accuracy: 0.9827 - val_loss: 0.9897 - val_accuracy: 0.8519
# Epoch 14/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0943 - accuracy: 0.9733 - val_loss: 0.9883 - val_accuracy: 0.8302
# Epoch 15/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0810 - accuracy: 0.9773 - val_loss: 0.9203 - val_accuracy: 0.8449
# Epoch 16/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0584 - accuracy: 0.9839 - val_loss: 1.2211 - val_accuracy: 0.8268
# Epoch 17/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0558 - accuracy: 0.9849 - val_loss: 1.0698 - val_accuracy: 0.8434
# Epoch 18/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0785 - accuracy: 0.9794 - val_loss: 0.8241 - val_accuracy: 0.8268
# Epoch 19/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0454 - accuracy: 0.9884 - val_loss: 1.0872 - val_accuracy: 0.8430
# Epoch 20/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0674 - accuracy: 0.9814 - val_loss: 1.1453 - val_accuracy: 0.8233
# Epoch 21/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0651 - accuracy: 0.9823 - val_loss: 1.3223 - val_accuracy: 0.8125
# Epoch 22/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0568 - accuracy: 0.9838 - val_loss: 1.1604 - val_accuracy: 0.8260
# Epoch 23/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0447 - accuracy: 0.9874 - val_loss: 1.1581 - val_accuracy: 0.8565
# Epoch 24/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0254 - accuracy: 0.9937 - val_loss: 1.1446 - val_accuracy: 0.8657
# Epoch 25/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0260 - accuracy: 0.9930 - val_loss: 1.9742 - val_accuracy: 0.8268
# Epoch 26/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0569 - accuracy: 0.9844 - val_loss: 1.4788 - val_accuracy: 0.8279
# Epoch 27/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0622 - accuracy: 0.9820 - val_loss: 1.1599 - val_accuracy: 0.8565
# Epoch 28/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0444 - accuracy: 0.9887 - val_loss: 1.6230 - val_accuracy: 0.8372
# Epoch 29/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0778 - accuracy: 0.9813 - val_loss: 1.0774 - val_accuracy: 0.8407
# Epoch 30/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0214 - accuracy: 0.9932 - val_loss: 1.3252 - val_accuracy: 0.8422

# %% [markdown]
# Alleniamo il modello per 30 epoche e visualizziamo le **curve di addestramento** e **validazione**.
#
# In modo tale da poter accedere ai dati del modello più facilmente in futuro trasformiamo la cronologia del modello in un dataframe pandas. Questo facilità anche al visualizzazione dei dati salvati per un caso futuro.

# %%
def convert_history_to_csv(model_history):
    # converto la history del dataframe in un dataframe pandas
    model_history_df = pd.DataFrame(model_history.history)
    # cambio il nome dell'indice e lo imposto a partire da 1
    model_history_df.index = range(1, len(model_history_df) + 1)
    model_history_df.index.name = "epochs"

    return model_history_df

# %% [markdown]
# Salviamo i dati della history del modello in un file csv.

# %%
basic_model_history_df = convert_history_to_csv(basic_model_history)
basic_model_history_df.to_csv("model_histories/adam/basic_model_history.csv")

# %% [markdown]
# Salviamo il miglior modello come file csv nella directory `model_histories/adam/` con il nome `basic_model_history`. Inoltre, per prevenire errori di salvataggio casuati da versioni differenti di python o dei pacchetti, procediamo con la conversione del file in formato standard `.onnx`.

# %% [markdown]
# Per eseguire la conversione utilizzeremo le librerie **tf2onnx** e **onnx**, importate precedentemente.

# %%
def convert_model_to_onnx(model_path, input_shape):
    model = tf.keras.models.load_model(model_path)

    onnx_path = model_path.split(".")[:-1] + ["onnx"]
    onnx_path = ".".join(onnx_path)
    
    input_signature = [tf.TensorSpec((None, *input_shape), tf.float32, name="input")]
    onnx_model, _ = tf2onnx.convert.from_keras(model, input_signature=input_signature)

    onnx.save(onnx_model, onnx_path)

# %%
convert_model_to_onnx("bestmodels/adam/basic_model.keras", (124, 129, 1))

# %% [markdown]
# Utilizziamo la funzione `create_train_val_plot` per mostrare l'andamento dell'accurateza e della perdita durante l'addestramento.

# %%
def create_train_val_plot(history, overfit=True):
    # definisco numero epoche
    epochs = range(1, len(history['accuracy']) + 1)

    # Accuracy
    accuracy = history['accuracy']
    val_accuracy = history['val_accuracy']

    fig_acc, ax_acc = plt.subplots()

    # linea di base
    ax_acc.plot(epochs, [0.5 for x in range(len(epochs))], color="lightgray", linestyle="--", label="Base")
    # linee di accuratezza
    ax_acc.plot(epochs, accuracy, color="slategray", label="Accuratezza in addestramento")
    ax_acc.plot(epochs, val_accuracy, color="indianred", label="Accuratezza in validazione")
    # miglior accuratezza validazione
    ax_acc.axhline(y=max(val_accuracy), c='indianred', alpha=0.7, linestyle='--')
    ax_acc.text(len(epochs) * 1.07, max(val_accuracy), round(max(val_accuracy), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_acc.spines["right"].set_visible(False)
    ax_acc.spines["top"].set_visible(False)
    ax_acc.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_acc.set_title("Accuratezza in addestramento e validazione")
    ax_acc.set_xlabel("Epoche")
    ax_acc.set_ylabel("Accuratezza (%)")
    ax_acc.legend()

    # Loss
    loss = history['loss']
    val_loss = history['val_loss']

    fig_loss, ax_loss = plt.subplots()

    # linee di loss
    ax_loss.plot(epochs, loss, color="slategray", label="Perdita in addestramento")
    ax_loss.plot(epochs, val_loss, color="indianred", label="Perdita in validazione")
    # miglior loss validazione
    ax_loss.axhline(y=min(val_loss), c='indianred', alpha=0.7, linestyle='--')
    ax_loss.text(len(epochs) * 1.07, min(val_loss), round(min(val_loss), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_loss.spines["right"].set_visible(False)
    ax_loss.spines["top"].set_visible(False)
    ax_loss.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_loss.set_title("Perdita in addestramento e validazione")
    ax_loss.set_xlabel("Epoche")
    ax_loss.set_ylabel("Perdita")

    handles, _ = ax_loss.get_legend_handles_labels()

    if overfit:
        # area overfit
        rect = mpatches.Rectangle((np.argmin(val_loss) + 1, 0), width=100 - np.argmin(val_loss), height=max(max(loss), max(val_loss)), color='lightcoral', alpha=0.3)
        ax_loss.add_patch(rect)
        # patch overfit per legenda
        overfit = mpatches.Patch(color='indianred', alpha=0.3, label='Area overfit')
        handles, _ = ax_loss.get_legend_handles_labels()
        handles.append(overfit)

    # legenda
    ax_loss.legend(handles=handles)

    plt.show()

# %%
create_train_val_plot(basic_model_history.history)

# %% [markdown]
# Questi grafici mostrano come il nostro modello sia andato immediatamente in overfitting. L'accuratezza dell'addestramento aumenta col tempo e raggiunge quasi il **100%**, mentre l'accuratezza della validazione si attesta sull'**85%** con un **picco del 87%**. La **perdita nel set di addestramento** continua a diminuire dopo la **quinta epoca**, mentre la **perdita nel set di validazione** aumenta.

# %% [markdown]
# Possiamo verificare l'accuratezza della migliore versione del nostro modello di base ricaricando il file **basic_model.keras**

# %%
best_basic_model = tf.keras.models.load_model("bestmodels/adam/basic_model.keras")
test_loss, test_acc = best_basic_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 5ms/step - loss: 0.7615 - accuracy: 0.7931
# Accuratezza: 0.793

# %% [markdown]
# Oppure possiamo verificarla con il file **basic_model.onnx**

# %%
def evaluate_onnx_model(path_model_onnx, test_ds):
    # il fatto che sia suddiviso in batch mi crea problemi, perciò lo risolvo togliendoli
    test_ds = test_ds.unbatch()
    
    # carico il modello utilizzando il file onnx
    m = rt.InferenceSession(path_model_onnx)
    
    # trasformo il dataset in array numpy
    spectrogram_np = np.array([spectrogram.numpy() for spectrogram, _ in test_ds])
    labels_np = np.array([label.numpy() for _, label in test_ds])
    
    # eseguo le predizione del modello
    pred_onnx = m.run(None, {'input': spectrogram_np})
    # ottengo la predizione corretta
    predictions = np.argmax(pred_onnx[0], axis=1)
    # computo la accuratezza
    accuracy = np.mean(predictions == labels_np)
    # stampo l'accuratezza
    print(f"Accuratezza: {accuracy:.3f}")

# %%
evaluate_onnx_model("bestmodels/adam/basic_model.onnx", test_ds)
# Out:
# Accuratezza: 0.793

# %% [markdown]
# Abbiamo ottenuto un'**accuratezza** del **79.3%**! Lo riteniamo un ottimo risultato considerato il task non banale.

# %% [markdown]
# Come ultimo, creiamo una funzione utile a visualizzare graficamente la distribuzione di accuratezza delle classi su un'immagine casuale, per capire come ha lavorato il modello. Nel caso il modello non predica correttamente, la **classe corretta** verrà sempre evidenziata di **verde**, mentre la **classe predetta** verrà evidenziata di **giallo**.

# %%
def create_distribution_plot(model, audio, label):
    prediction = model(audio) # otteniamo la predizione del modello sull'audio preso in input

    random_audio_index = np.random.randint(0, len(prediction) - 1) # abbiamo notato che mostravamo sempre la classe no, magari così cambia un po' le classi che mostriamo

    softmax_pred = tf.nn.softmax(prediction[random_audio_index]) # dobbiamo applicare nuovamente la softmax in modo tale da avere dei dati leggibili
    pred_label = np.argmax(softmax_pred) # ci salviamo l'indice della label predetta dal nostro modello, quella con la probabilità più alta

    colors = ['indianred'] * len(label_names) # creiamo un vettore di lunghezza 30 (la quantità delle nostre label) colorate di rosso

    if pred_label == label[random_audio_index].numpy(): # se la label che abbiamo predetto è corretta, allora la coloriamo di verde
        colors[pred_label] = 'seagreen'
    else: # se la label che abbiamo predetto è sbagliata, allora coloriamo di verde la corretta e di gialla la predetta
        colors[pred_label] = 'khaki'
        colors[label[random_audio_index].numpy()] = 'seagreen'

    plt.figure(figsize=(12, 4))

    plt.bar(label_names, softmax_pred.numpy(), color=colors)
    plt.xticks(rotation=45)

    # dichiariamo i colori della legenda
    other_values_patch = mpatches.Patch(color='indianred', label='Altre classi')
    pred_value_patch = mpatches.Patch(color='khaki', label='Classe predetta')
    correct_value_patch = mpatches.Patch(color='green', label='Classe corretta')

    # disegniamo al legenda con i colori necessari
    if pred_label == label[random_audio_index].numpy(): # se abbiamo predetto correttamente la label, non è necessario mostrare il colore giallo (non è presente nel plot)
        plt.legend(handles=[other_values_patch, correct_value_patch])
    else:
        plt.legend(handles=[other_values_patch, pred_value_patch, correct_value_patch])

    plt.show()

# %%
for audio, label in test_ds: # prendiamo un audio a caso del test e creiamo la distribuzione
    create_distribution_plot(best_basic_model, audio, label)
    break

# %% [markdown]
# Possiamo notare dalla distribuzione che il modello in questo caso ha predetto correttamente la **classe no**.

# %% [markdown]
# ## Risoluzione dell'overfitting
# Abbiamo capito che il modello è andato immediatamente in **overfitting**, e lo possiamo notare dalla loss di validazione che inizia a salire dalla quinta epoca in poi. L'obbiettivo principale in questo momento è evitare che vada in overfitting troppo velocemente, applicando le tecniche viste a lezione.

# %% [markdown]
# Attualmente per ridurre l'overfitting applichiamo **un livello di Dropout**. Il livello di dropout imposta **randomicamente** delle attivazioni a 0, perciò stiamo disattivando qualche neurone. Nello specifico stiamo **azzerando** un certo numero di caratteristiche di uscita dello strato Dense. L'idea dietro questa tecnica è quella di mettere in difficoltà il modello.

# %%
def get_improved_basic_model():
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(124, 129, 1))
    x = tf.keras.layers.Normalization()(inputs)

    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
improved_basic_model = get_improved_basic_model()
improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/adam/improved_basic_model.keras", save_best_only=True, monitor="val_loss")]
improved_history = improved_basic_model.fit(train_ds, epochs=100, validation_data=val_ds, callbacks=improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 3s 12ms/step - loss: 2.5426 - accuracy: 0.2869 - val_loss: 1.5186 - val_accuracy: 0.5714
# Epoch 2/100
# 243/243 [==============================] - 3s 12ms/step - loss: 1.2227 - accuracy: 0.6497 - val_loss: 0.9130 - val_accuracy: 0.7380
# Epoch 3/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.7265 - accuracy: 0.7899 - val_loss: 0.6953 - val_accuracy: 0.7982
# Epoch 4/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.5084 - accuracy: 0.8468 - val_loss: 0.5641 - val_accuracy: 0.8476
# Epoch 5/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.3710 - accuracy: 0.8865 - val_loss: 0.5867 - val_accuracy: 0.8488
# Epoch 6/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2988 - accuracy: 0.9076 - val_loss: 0.6196 - val_accuracy: 0.8534
# Epoch 7/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2343 - accuracy: 0.9276 - val_loss: 0.6378 - val_accuracy: 0.8592
# Epoch 8/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2208 - accuracy: 0.9313 - val_loss: 0.6527 - val_accuracy: 0.8356
# Epoch 9/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1795 - accuracy: 0.9456 - val_loss: 0.6535 - val_accuracy: 0.8623
# Epoch 10/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1830 - accuracy: 0.9442 - val_loss: 0.6842 - val_accuracy: 0.8546
# Epoch 11/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1617 - accuracy: 0.9523 - val_loss: 0.6140 - val_accuracy: 0.8576
# Epoch 12/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1321 - accuracy: 0.9593 - val_loss: 0.6428 - val_accuracy: 0.8638
# Epoch 13/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1363 - accuracy: 0.9599 - val_loss: 0.5763 - val_accuracy: 0.8561
# Epoch 14/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1035 - accuracy: 0.9680 - val_loss: 0.6244 - val_accuracy: 0.8889
# Epoch 15/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1063 - accuracy: 0.9683 - val_loss: 0.6299 - val_accuracy: 0.8696
# Epoch 16/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1287 - accuracy: 0.9643 - val_loss: 0.5993 - val_accuracy: 0.8742
# Epoch 17/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1085 - accuracy: 0.9682 - val_loss: 0.7129 - val_accuracy: 0.8765
# Epoch 18/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1090 - accuracy: 0.9702 - val_loss: 0.7780 - val_accuracy: 0.8576
# Epoch 19/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0943 - accuracy: 0.9729 - val_loss: 0.7859 - val_accuracy: 0.8619
# Epoch 20/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0968 - accuracy: 0.9746 - val_loss: 0.7214 - val_accuracy: 0.8781
# Epoch 21/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0956 - accuracy: 0.9726 - val_loss: 0.7928 - val_accuracy: 0.8654
# Epoch 22/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0840 - accuracy: 0.9772 - val_loss: 0.8858 - val_accuracy: 0.8546
# Epoch 23/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0738 - accuracy: 0.9763 - val_loss: 0.6884 - val_accuracy: 0.8900
# Epoch 24/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0786 - accuracy: 0.9765 - val_loss: 0.8456 - val_accuracy: 0.8580
# Epoch 25/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0886 - accuracy: 0.9747 - val_loss: 0.7830 - val_accuracy: 0.8762
# Epoch 26/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0711 - accuracy: 0.9802 - val_loss: 0.8143 - val_accuracy: 0.8773
# Epoch 27/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0786 - accuracy: 0.9793 - val_loss: 0.6911 - val_accuracy: 0.8800
# Epoch 28/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0952 - accuracy: 0.9754 - val_loss: 0.7404 - val_accuracy: 0.8596
# Epoch 29/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0701 - accuracy: 0.9823 - val_loss: 0.8179 - val_accuracy: 0.8654
# Epoch 30/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0846 - accuracy: 0.9772 - val_loss: 0.7697 - val_accuracy: 0.8808
# Epoch 31/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0607 - accuracy: 0.9829 - val_loss: 0.7633 - val_accuracy: 0.8835
# Epoch 32/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0681 - accuracy: 0.9800 - val_loss: 0.7338 - val_accuracy: 0.8831
# Epoch 33/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1015 - accuracy: 0.9741 - val_loss: 0.9128 - val_accuracy: 0.8835
# Epoch 34/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0865 - accuracy: 0.9753 - val_loss: 0.7210 - val_accuracy: 0.8754
# Epoch 35/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0746 - accuracy: 0.9791 - val_loss: 0.7150 - val_accuracy: 0.8889
# Epoch 36/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0574 - accuracy: 0.9831 - val_loss: 0.9201 - val_accuracy: 0.8754
# Epoch 37/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0597 - accuracy: 0.9844 - val_loss: 0.8495 - val_accuracy: 0.8669
# Epoch 38/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0625 - accuracy: 0.9820 - val_loss: 0.8835 - val_accuracy: 0.8715
# Epoch 39/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0644 - accuracy: 0.9817 - val_loss: 0.8141 - val_accuracy: 0.8700
# Epoch 40/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0627 - accuracy: 0.9822 - val_loss: 0.8376 - val_accuracy: 0.8785
# Epoch 41/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0526 - accuracy: 0.9857 - val_loss: 0.9121 - val_accuracy: 0.8735
# Epoch 42/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0618 - accuracy: 0.9839 - val_loss: 0.7939 - val_accuracy: 0.8804
# Epoch 43/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0497 - accuracy: 0.9875 - val_loss: 0.7721 - val_accuracy: 0.8735
# Epoch 44/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0564 - accuracy: 0.9853 - val_loss: 0.8705 - val_accuracy: 0.8777
# Epoch 45/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0595 - accuracy: 0.9834 - val_loss: 1.0240 - val_accuracy: 0.8673
# Epoch 46/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0646 - accuracy: 0.9823 - val_loss: 0.9149 - val_accuracy: 0.8835
# Epoch 47/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0403 - accuracy: 0.9884 - val_loss: 0.7887 - val_accuracy: 0.8885
# Epoch 48/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0630 - accuracy: 0.9823 - val_loss: 0.8541 - val_accuracy: 0.8769
# Epoch 49/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0784 - accuracy: 0.9799 - val_loss: 0.9094 - val_accuracy: 0.8630
# Epoch 50/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0611 - accuracy: 0.9844 - val_loss: 0.9920 - val_accuracy: 0.8646
# Epoch 51/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0482 - accuracy: 0.9867 - val_loss: 1.0882 - val_accuracy: 0.8893
# Epoch 52/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0769 - accuracy: 0.9814 - val_loss: 0.8772 - val_accuracy: 0.8738
# Epoch 53/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0614 - accuracy: 0.9853 - val_loss: 0.8541 - val_accuracy: 0.8777
# Epoch 54/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0463 - accuracy: 0.9887 - val_loss: 0.8760 - val_accuracy: 0.8785
# Epoch 55/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0327 - accuracy: 0.9901 - val_loss: 1.0917 - val_accuracy: 0.8688
# Epoch 56/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0605 - accuracy: 0.9865 - val_loss: 0.8947 - val_accuracy: 0.8769
# Epoch 57/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0663 - accuracy: 0.9834 - val_loss: 0.8148 - val_accuracy: 0.8877
# Epoch 58/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0624 - accuracy: 0.9853 - val_loss: 0.8910 - val_accuracy: 0.8800
# Epoch 59/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0465 - accuracy: 0.9888 - val_loss: 0.8520 - val_accuracy: 0.8870
# Epoch 60/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0448 - accuracy: 0.9879 - val_loss: 1.0720 - val_accuracy: 0.8839
# Epoch 61/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0575 - accuracy: 0.9861 - val_loss: 1.1028 - val_accuracy: 0.8711
# Epoch 62/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0625 - accuracy: 0.9851 - val_loss: 0.7497 - val_accuracy: 0.8939
# Epoch 63/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0396 - accuracy: 0.9883 - val_loss: 0.9234 - val_accuracy: 0.8843
# Epoch 64/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0406 - accuracy: 0.9893 - val_loss: 0.9598 - val_accuracy: 0.8885
# Epoch 65/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0752 - accuracy: 0.9827 - val_loss: 1.0775 - val_accuracy: 0.8796
# Epoch 66/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0618 - accuracy: 0.9854 - val_loss: 1.1120 - val_accuracy: 0.8777
# Epoch 67/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0573 - accuracy: 0.9856 - val_loss: 1.0701 - val_accuracy: 0.8978
# Epoch 68/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0493 - accuracy: 0.9894 - val_loss: 1.0135 - val_accuracy: 0.8754
# Epoch 69/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0341 - accuracy: 0.9907 - val_loss: 1.0661 - val_accuracy: 0.8808
# Epoch 70/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0632 - accuracy: 0.9862 - val_loss: 1.1010 - val_accuracy: 0.8769
# Epoch 71/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0443 - accuracy: 0.9885 - val_loss: 1.0696 - val_accuracy: 0.8862
# Epoch 72/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0469 - accuracy: 0.9865 - val_loss: 1.0480 - val_accuracy: 0.8912
# Epoch 73/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0577 - accuracy: 0.9866 - val_loss: 1.1857 - val_accuracy: 0.8835
# Epoch 74/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0595 - accuracy: 0.9878 - val_loss: 1.0307 - val_accuracy: 0.8935
# Epoch 75/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0429 - accuracy: 0.9897 - val_loss: 1.1526 - val_accuracy: 0.8954
# Epoch 76/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0526 - accuracy: 0.9881 - val_loss: 0.9802 - val_accuracy: 0.8935
# Epoch 77/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0369 - accuracy: 0.9901 - val_loss: 1.2464 - val_accuracy: 0.8615
# Epoch 78/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0495 - accuracy: 0.9896 - val_loss: 0.9457 - val_accuracy: 0.8912
# Epoch 79/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0423 - accuracy: 0.9898 - val_loss: 1.1972 - val_accuracy: 0.8870
# Epoch 80/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0421 - accuracy: 0.9910 - val_loss: 1.1699 - val_accuracy: 0.8854
# Epoch 81/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0332 - accuracy: 0.9923 - val_loss: 1.2158 - val_accuracy: 0.8846
# Epoch 82/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0533 - accuracy: 0.9881 - val_loss: 1.3983 - val_accuracy: 0.8777
# Epoch 83/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0792 - accuracy: 0.9843 - val_loss: 1.2950 - val_accuracy: 0.8808
# Epoch 84/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0622 - accuracy: 0.9878 - val_loss: 1.0024 - val_accuracy: 0.8827
# Epoch 85/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0490 - accuracy: 0.9887 - val_loss: 1.1446 - val_accuracy: 0.8835
# Epoch 86/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0460 - accuracy: 0.9901 - val_loss: 1.2534 - val_accuracy: 0.8669
# Epoch 87/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0330 - accuracy: 0.9915 - val_loss: 1.1586 - val_accuracy: 0.8885
# Epoch 88/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0450 - accuracy: 0.9893 - val_loss: 1.4782 - val_accuracy: 0.8781
# Epoch 89/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0458 - accuracy: 0.9905 - val_loss: 1.3496 - val_accuracy: 0.8889
# Epoch 90/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0622 - accuracy: 0.9854 - val_loss: 1.2639 - val_accuracy: 0.8897
# Epoch 91/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0527 - accuracy: 0.9892 - val_loss: 1.3270 - val_accuracy: 0.8808
# Epoch 92/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0771 - accuracy: 0.9840 - val_loss: 1.4334 - val_accuracy: 0.8650
# Epoch 93/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0606 - accuracy: 0.9879 - val_loss: 1.2163 - val_accuracy: 0.8904
# Epoch 94/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0581 - accuracy: 0.9898 - val_loss: 1.0600 - val_accuracy: 0.8897
# Epoch 95/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0270 - accuracy: 0.9930 - val_loss: 1.1736 - val_accuracy: 0.8873
# Epoch 96/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0703 - accuracy: 0.9883 - val_loss: 1.1709 - val_accuracy: 0.8846
# Epoch 97/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0370 - accuracy: 0.9914 - val_loss: 1.0857 - val_accuracy: 0.8889
# Epoch 98/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0497 - accuracy: 0.9914 - val_loss: 1.7047 - val_accuracy: 0.8669
# Epoch 99/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0769 - accuracy: 0.9862 - val_loss: 1.3895 - val_accuracy: 0.8893
# Epoch 100/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0394 - accuracy: 0.9901 - val_loss: 1.6390 - val_accuracy: 0.8688

# %% [markdown]
# Salviamo come prima la history del modello in un file csv.

# %%
improved_history_df = convert_history_to_csv(improved_history)
improved_history_df.to_csv("model_histories/adam/improved_history.csv")

# %% [markdown]
# Salviamo nuovamente il miglior modello anche nel formato **.onnx**.

# %%
convert_model_to_onnx("bestmodels/adam/improved_basic_model.keras", (124, 129, 1))

# %%
create_train_val_plot(improved_history.history)

# %% [markdown]
# Alleniamo il modello per 100 epoche e visualizziamo le **curve di addestramento** e **validazione**.
#
# L'obbiettivo di ridurre **l'overfitting è stato comunque raggiunto**, dato che il modello andato in overfitting leggermente dopo, circa **all'epoca 10**, ma dobbiamo sicuramente applicare qualche altra tecnica per migliorarlo ulteriormente.

# %%
improved_best_model = tf.keras.models.load_model("bestmodels/adam/improved_basic_model.keras")
test_loss, test_acc = improved_best_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 6ms/step - loss: 0.6480 - accuracy: 0.8237
# Accuratezza: 0.824

# %% [markdown]
# Verifichiamola anche con il modello **.onnx**

# %%
evaluate_onnx_model("bestmodels/adam/improved_basic_model.onnx", test_ds)
# Out:
# Accuratezza: 0.824

# %% [markdown]
# Abbiamo ottenuto un buon miglioramento dell'accuratezza, attualmente siamo a quota **82.4%**!

# %%
for audio, label in test_ds:
    create_distribution_plot(improved_best_model, audio, label)
    break

# %% [markdown]
# In questo caso il modello è stato in grado di predirre la classe corretta **eight**.

# %% [markdown]
# ### Fine tuning
#
# Gli **iperparametri** sono le variabili che governano il processo di addestramento e la topologia di un modello. Queste rimangono costanti durante l'allenamento e influenzano direttamente le prestazioni.

# %% [markdown]
# Per scegliere un insieme ottimale di iperparametri, abbiamo sviluppato una funzione `tuner`, alla quale passiamo come argomenti una lista di filtri, una lista di tassi di apprendimento, un totale massimo di epoche ed i set di dati su cui si vuole fare l'allenamento.
#
# Questa funzione implementa un **ipermodello**, il quale viene addestrato con varie combinazioni di filtri e tassi di apprendimento, salva i risultati in un file csv e resitituisce le corrispondenze migliori. Queste informazioni sono utili sia per determinare la struttura ottimale del modello da implementare, sia per identificare le combinazioni utilizzate nei modelli precedenti, a fronte del fatto che fino ad ora abbiamo sempre usato dei tassi di apprendimento dinamici.
#
# Per usare questa funzione dobbiamo prima definire un **ipermodello**, ovvero l'architettura del modello su cui vogliamo eseguire i test per trovare gli iperparametri più consoni. Esso è implementato attraverso la funzione `get_improved_basic_model_tuning`, che iterando una lista di filtri adatta le dimensioni degli output degli strati convolutivi.

# %%
def get_improved_basic_model_tuning(start_filters):
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(124, 129, 1))
    x = tf.keras.layers.Normalization()(inputs)

    if not isinstance(start_filters, int):
        raise Exception("start_filters must be type integer")

    filters = [start_filters * (2 ** i) for i in range(4)]
    
    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=filters[0], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[1], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[2], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[3], kernel_size=3, activation="relu", padding="same")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=filters[3], kernel_size=3, activation="relu", padding="same")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# Più nello specifico, la funzione tuner utilizza una callback di tipo EarlyStopping che monitora la perdita sul set di validazione con una pazienza di 5. Questo significa che il modello viene interrotto se la perdita di validazione non diminuisce entro 5 epoche dalla sua minima.
#
# Questa implementazione è utile per risparmiare tempo con i modelli che cessano di migliorare precocemente le loro prestazioni.

# %%
def tuner(filters, learning_rates, max_epochs, train_dataset, validation_dataset):
    start_time = time.time()

    counter = 1
    
    if not isinstance(filters, list):
        raise Exception("parameter filters must be type list")

    if not isinstance(learning_rates, list):
        raise Exception("parameter learning_rates must be type list")

    callbacks = [tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5)]

    best_learning_rate = 0 
    best_filters = 0
    best_val_accuracy = 0

    best_model = 0
    
    for f in filters:
        for lr in learning_rates:
            print(f"\nAddestramndo con filtri {[f * (2 ** i) for i in range(4)]} e tasso di apprendimento {lr}")
            
            model = get_improved_basic_model_tuning(start_filters=f)
            model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=lr), metrics=["accuracy"])
            model_history = model.fit(train_dataset, epochs=max_epochs, validation_data=validation_dataset, callbacks=callbacks)

            model_history_df = convert_history_to_csv(model_history)

            model_history_df[["filters"]] = f
            model_history_df[["learning_rate"]] = lr
            
            path = "model_tuning/histories/adam/model_" + str(counter) + ".csv"
            model_history_df.to_csv(path)
            
            if best_val_accuracy < model_history_df.iloc[-1]["val_accuracy"]:
                best_val_accuracy = model_history_df.iloc[-1]["val_accuracy"]
                best_filters = f
                best_learning_rate = lr
                epoch = len(model_history_df)

            del model

            counter += 1

    total_time = time.time() - start_time
    minutes, seconds = divmod(total_time, 60)
    print(f"\nTempo totale trascorso: {int(minutes)} minuti e {int(seconds)} secondi")
    # print(f"Il miglior modello ha un filtro di partenza pari a {best_filters}, un learning rate pari a {best_learning_rate} con un'accuracy pari a {best_val_accuracy:.3f}")

    return best_filters, best_learning_rate

# %%
best_filter, best_learning_rate = tuner([16, 32, 64], [1e-3, 1e-4, 1e-5], 30, train_ds, val_ds)
# Out:
# Addestramndo con filtri [16, 32, 64, 128] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 3s 10ms/step - loss: 2.6109 - accuracy: 0.2687 - val_loss: 1.7698 - val_accuracy: 0.4911
# Epoch 2/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.3476 - accuracy: 0.6108 - val_loss: 1.1110 - val_accuracy: 0.6898
# Epoch 3/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.8460 - accuracy: 0.7581 - val_loss: 0.7509 - val_accuracy: 0.7886
# Epoch 4/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.5978 - accuracy: 0.8211 - val_loss: 0.7150 - val_accuracy: 0.8063
# Epoch 5/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.4355 - accuracy: 0.8655 - val_loss: 0.6387 - val_accuracy: 0.8341
# Epoch 6/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.3468 - accuracy: 0.8901 - val_loss: 0.6778 - val_accuracy: 0.8407
# Epoch 7/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.3021 - accuracy: 0.9063 - val_loss: 0.6611 - val_accuracy: 0.8264
# Epoch 8/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.2618 - accuracy: 0.9195 - val_loss: 0.6086 - val_accuracy: 0.8580
# Epoch 9/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.2198 - accuracy: 0.9314 - val_loss: 0.6008 - val_accuracy: 0.8623
# Epoch 10/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.1946 - accuracy: 0.9396 - val_loss: 0.6352 - val_accuracy: 0.8565
# Epoch 11/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.1647 - accuracy: 0.9486 - val_loss: 0.6736 - val_accuracy: 0.8634
# Epoch 12/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.1652 - accuracy: 0.9490 - val_loss: 0.6508 - val_accuracy: 0.8681
# Epoch 13/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.1602 - accuracy: 0.9512 - val_loss: 0.6211 - val_accuracy: 0.8711
# Epoch 14/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.1466 - accuracy: 0.9546 - val_loss: 0.5968 - val_accuracy: 0.8754
# Epoch 15/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.1322 - accuracy: 0.9593 - val_loss: 0.6251 - val_accuracy: 0.8804
# Epoch 16/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.1294 - accuracy: 0.9625 - val_loss: 0.7537 - val_accuracy: 0.8692
# Epoch 17/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.1383 - accuracy: 0.9599 - val_loss: 0.6177 - val_accuracy: 0.8708
# Epoch 18/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.1266 - accuracy: 0.9635 - val_loss: 0.6179 - val_accuracy: 0.8596
# Epoch 19/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.1069 - accuracy: 0.9683 - val_loss: 0.8264 - val_accuracy: 0.8580
#
# Addestramndo con filtri [16, 32, 64, 128] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 2s 8ms/step - loss: 3.2178 - accuracy: 0.1164 - val_loss: 2.8636 - val_accuracy: 0.2566
# Epoch 2/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.7167 - accuracy: 0.2677 - val_loss: 2.4274 - val_accuracy: 0.3927
# Epoch 3/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.3289 - accuracy: 0.3874 - val_loss: 2.0685 - val_accuracy: 0.4823
# Epoch 4/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.9917 - accuracy: 0.4716 - val_loss: 1.7995 - val_accuracy: 0.5621
# Epoch 5/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.7183 - accuracy: 0.5526 - val_loss: 1.5854 - val_accuracy: 0.6080
# Epoch 6/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.4924 - accuracy: 0.6099 - val_loss: 1.4096 - val_accuracy: 0.6516
# Epoch 7/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.2990 - accuracy: 0.6570 - val_loss: 1.2722 - val_accuracy: 0.6833
# Epoch 8/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.1572 - accuracy: 0.6912 - val_loss: 1.1522 - val_accuracy: 0.7149
# Epoch 9/30
# 243/243 [==============================] - 2s 8ms/step - loss: 1.0137 - accuracy: 0.7309 - val_loss: 1.0661 - val_accuracy: 0.7458
# Epoch 10/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.9133 - accuracy: 0.7573 - val_loss: 1.0404 - val_accuracy: 0.7539
# Epoch 11/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.8344 - accuracy: 0.7740 - val_loss: 0.9642 - val_accuracy: 0.7670
# Epoch 12/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.7477 - accuracy: 0.7927 - val_loss: 0.9200 - val_accuracy: 0.7797
# Epoch 13/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.6933 - accuracy: 0.8071 - val_loss: 0.8778 - val_accuracy: 0.7940
# Epoch 14/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.6381 - accuracy: 0.8254 - val_loss: 0.9067 - val_accuracy: 0.7878
# Epoch 15/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.5700 - accuracy: 0.8407 - val_loss: 0.8566 - val_accuracy: 0.8032
# Epoch 16/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.5431 - accuracy: 0.8512 - val_loss: 0.8349 - val_accuracy: 0.8167
# Epoch 17/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.4997 - accuracy: 0.8597 - val_loss: 0.8285 - val_accuracy: 0.8113
# Epoch 18/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.4733 - accuracy: 0.8678 - val_loss: 0.8175 - val_accuracy: 0.8179
# Epoch 19/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.4377 - accuracy: 0.8728 - val_loss: 0.7896 - val_accuracy: 0.8171
# Epoch 20/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.4071 - accuracy: 0.8808 - val_loss: 0.7825 - val_accuracy: 0.8210
# Epoch 21/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.3759 - accuracy: 0.8888 - val_loss: 0.7535 - val_accuracy: 0.8256
# Epoch 22/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.3525 - accuracy: 0.8991 - val_loss: 0.8117 - val_accuracy: 0.8245
# Epoch 23/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.3287 - accuracy: 0.9043 - val_loss: 0.7861 - val_accuracy: 0.8272
# Epoch 24/30
# 243/243 [==============================] - 2s 9ms/step - loss: 0.3276 - accuracy: 0.9067 - val_loss: 0.7674 - val_accuracy: 0.8306
# Epoch 25/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.3065 - accuracy: 0.9134 - val_loss: 0.8070 - val_accuracy: 0.8272
# Epoch 26/30
# 243/243 [==============================] - 2s 8ms/step - loss: 0.2838 - accuracy: 0.9162 - val_loss: 0.7846 - val_accuracy: 0.8329
#
# Addestramndo con filtri [16, 32, 64, 128] e tasso di apprendimento 1e-05
# Epoch 1/30
# 243/243 [==============================] - 2s 9ms/step - loss: 3.3989 - accuracy: 0.0375 - val_loss: 3.3856 - val_accuracy: 0.0532
# Epoch 2/30
# 243/243 [==============================] - 2s 9ms/step - loss: 3.3761 - accuracy: 0.0620 - val_loss: 3.3600 - val_accuracy: 0.0818
# Epoch 3/30
# 243/243 [==============================] - 2s 9ms/step - loss: 3.3397 - accuracy: 0.0875 - val_loss: 3.3097 - val_accuracy: 0.1061
# Epoch 4/30
# 243/243 [==============================] - 2s 9ms/step - loss: 3.2758 - accuracy: 0.1053 - val_loss: 3.2178 - val_accuracy: 0.1497
# Epoch 5/30
# 243/243 [==============================] - 2s 8ms/step - loss: 3.1764 - accuracy: 0.1338 - val_loss: 3.0951 - val_accuracy: 0.2052
# Epoch 6/30
# 243/243 [==============================] - 2s 9ms/step - loss: 3.0834 - accuracy: 0.1598 - val_loss: 2.9842 - val_accuracy: 0.2384
# Epoch 7/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.9967 - accuracy: 0.1890 - val_loss: 2.8961 - val_accuracy: 0.2604
# Epoch 8/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.9227 - accuracy: 0.2080 - val_loss: 2.8232 - val_accuracy: 0.2913
# Epoch 9/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.8698 - accuracy: 0.2210 - val_loss: 2.7677 - val_accuracy: 0.3048
# Epoch 10/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.8324 - accuracy: 0.2304 - val_loss: 2.7240 - val_accuracy: 0.3248
# Epoch 11/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.7869 - accuracy: 0.2473 - val_loss: 2.6786 - val_accuracy: 0.3468
# Epoch 12/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.7308 - accuracy: 0.2601 - val_loss: 2.6331 - val_accuracy: 0.3630
# Epoch 13/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.7113 - accuracy: 0.2644 - val_loss: 2.5993 - val_accuracy: 0.3715
# Epoch 14/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.6638 - accuracy: 0.2907 - val_loss: 2.5606 - val_accuracy: 0.3850
# Epoch 15/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.6158 - accuracy: 0.2947 - val_loss: 2.5206 - val_accuracy: 0.3962
# Epoch 16/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.5846 - accuracy: 0.3001 - val_loss: 2.4895 - val_accuracy: 0.4043
# Epoch 17/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.5463 - accuracy: 0.3238 - val_loss: 2.4531 - val_accuracy: 0.4120
# Epoch 18/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.5156 - accuracy: 0.3320 - val_loss: 2.4247 - val_accuracy: 0.4217
# Epoch 19/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.4850 - accuracy: 0.3320 - val_loss: 2.3954 - val_accuracy: 0.4255
# Epoch 20/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.4387 - accuracy: 0.3536 - val_loss: 2.3598 - val_accuracy: 0.4387
# Epoch 21/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.4170 - accuracy: 0.3580 - val_loss: 2.3304 - val_accuracy: 0.4425
# Epoch 22/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.3905 - accuracy: 0.3713 - val_loss: 2.3064 - val_accuracy: 0.4421
# Epoch 23/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.3413 - accuracy: 0.3754 - val_loss: 2.2724 - val_accuracy: 0.4495
# Epoch 24/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.3154 - accuracy: 0.3875 - val_loss: 2.2430 - val_accuracy: 0.4583
# Epoch 25/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.2918 - accuracy: 0.3920 - val_loss: 2.2116 - val_accuracy: 0.4699
# Epoch 26/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.2502 - accuracy: 0.4101 - val_loss: 2.1856 - val_accuracy: 0.4726
# Epoch 27/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.2212 - accuracy: 0.4153 - val_loss: 2.1587 - val_accuracy: 0.4784
# Epoch 28/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.1990 - accuracy: 0.4164 - val_loss: 2.1306 - val_accuracy: 0.4792
# Epoch 29/30
# 243/243 [==============================] - 2s 9ms/step - loss: 2.1732 - accuracy: 0.4357 - val_loss: 2.1064 - val_accuracy: 0.4888
# Epoch 30/30
# 243/243 [==============================] - 2s 8ms/step - loss: 2.1390 - accuracy: 0.4407 - val_loss: 2.0800 - val_accuracy: 0.4904
#
# Addestramndo con filtri [32, 64, 128, 256] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 3s 13ms/step - loss: 2.5966 - accuracy: 0.2661 - val_loss: 1.7008 - val_accuracy: 0.5150
# Epoch 2/30
# 243/243 [==============================] - 3s 12ms/step - loss: 1.2934 - accuracy: 0.6322 - val_loss: 0.9264 - val_accuracy: 0.7350
# Epoch 3/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.7450 - accuracy: 0.7818 - val_loss: 0.7234 - val_accuracy: 0.7921
# Epoch 4/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.5208 - accuracy: 0.8466 - val_loss: 0.6436 - val_accuracy: 0.8264
# Epoch 5/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.3967 - accuracy: 0.8781 - val_loss: 0.5713 - val_accuracy: 0.8441
# Epoch 6/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.3184 - accuracy: 0.9032 - val_loss: 0.6593 - val_accuracy: 0.8306
# Epoch 7/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2412 - accuracy: 0.9242 - val_loss: 0.6270 - val_accuracy: 0.8553
# Epoch 8/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2180 - accuracy: 0.9335 - val_loss: 0.5890 - val_accuracy: 0.8627
# Epoch 9/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1664 - accuracy: 0.9496 - val_loss: 0.5718 - val_accuracy: 0.8696
# Epoch 10/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1533 - accuracy: 0.9530 - val_loss: 0.6964 - val_accuracy: 0.8573
#
# Addestramndo con filtri [32, 64, 128, 256] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 3s 13ms/step - loss: 3.1011 - accuracy: 0.1479 - val_loss: 2.6230 - val_accuracy: 0.3356
# Epoch 2/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.4071 - accuracy: 0.3563 - val_loss: 2.0450 - val_accuracy: 0.4707
# Epoch 3/30
# 243/243 [==============================] - 3s 12ms/step - loss: 1.8679 - accuracy: 0.5068 - val_loss: 1.6177 - val_accuracy: 0.5868
# Epoch 4/30
# 243/243 [==============================] - 3s 12ms/step - loss: 1.4552 - accuracy: 0.6121 - val_loss: 1.3490 - val_accuracy: 0.6562
# Epoch 5/30
# 243/243 [==============================] - 3s 12ms/step - loss: 1.1721 - accuracy: 0.6857 - val_loss: 1.1541 - val_accuracy: 0.7118
# Epoch 6/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.9561 - accuracy: 0.7369 - val_loss: 1.0466 - val_accuracy: 0.7346
# Epoch 7/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.8002 - accuracy: 0.7786 - val_loss: 0.9753 - val_accuracy: 0.7542
# Epoch 8/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.6945 - accuracy: 0.8101 - val_loss: 0.9152 - val_accuracy: 0.7785
# Epoch 9/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.5762 - accuracy: 0.8361 - val_loss: 0.8443 - val_accuracy: 0.7936
# Epoch 10/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.5203 - accuracy: 0.8517 - val_loss: 0.8223 - val_accuracy: 0.8117
# Epoch 11/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.4515 - accuracy: 0.8693 - val_loss: 0.8698 - val_accuracy: 0.8002
# Epoch 12/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.4119 - accuracy: 0.8823 - val_loss: 0.8043 - val_accuracy: 0.8117
# Epoch 13/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.3589 - accuracy: 0.8972 - val_loss: 0.7647 - val_accuracy: 0.8364
# Epoch 14/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.3214 - accuracy: 0.9017 - val_loss: 0.7880 - val_accuracy: 0.8252
# Epoch 15/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2977 - accuracy: 0.9122 - val_loss: 0.7454 - val_accuracy: 0.8341
# Epoch 16/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2632 - accuracy: 0.9246 - val_loss: 0.7973 - val_accuracy: 0.8391
# Epoch 17/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2514 - accuracy: 0.9289 - val_loss: 0.7528 - val_accuracy: 0.8372
# Epoch 18/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2158 - accuracy: 0.9389 - val_loss: 0.7995 - val_accuracy: 0.8318
# Epoch 19/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1889 - accuracy: 0.9452 - val_loss: 0.7428 - val_accuracy: 0.8353
# Epoch 20/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1695 - accuracy: 0.9510 - val_loss: 0.7955 - val_accuracy: 0.8376
# Epoch 21/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1710 - accuracy: 0.9522 - val_loss: 0.8153 - val_accuracy: 0.8399
# Epoch 22/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1563 - accuracy: 0.9537 - val_loss: 0.8369 - val_accuracy: 0.8391
# Epoch 23/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1768 - accuracy: 0.9482 - val_loss: 0.7379 - val_accuracy: 0.8472
# Epoch 24/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1685 - accuracy: 0.9512 - val_loss: 0.7085 - val_accuracy: 0.8484
# Epoch 25/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1419 - accuracy: 0.9586 - val_loss: 0.8337 - val_accuracy: 0.8449
# Epoch 26/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1329 - accuracy: 0.9607 - val_loss: 0.8762 - val_accuracy: 0.8546
# Epoch 27/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1093 - accuracy: 0.9701 - val_loss: 0.8086 - val_accuracy: 0.8515
# Epoch 28/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1231 - accuracy: 0.9651 - val_loss: 0.8260 - val_accuracy: 0.8465
# Epoch 29/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1248 - accuracy: 0.9637 - val_loss: 0.7960 - val_accuracy: 0.8561
#
# Addestramndo con filtri [32, 64, 128, 256] e tasso di apprendimento 1e-05
# Epoch 1/30
# 243/243 [==============================] - 3s 12ms/step - loss: 3.3738 - accuracy: 0.0566 - val_loss: 3.3310 - val_accuracy: 0.1038
# Epoch 2/30
# 243/243 [==============================] - 3s 11ms/step - loss: 3.2855 - accuracy: 0.0961 - val_loss: 3.1924 - val_accuracy: 0.1617
# Epoch 3/30
# 243/243 [==============================] - 3s 12ms/step - loss: 3.1145 - accuracy: 0.1601 - val_loss: 2.9705 - val_accuracy: 0.2377
# Epoch 4/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.9507 - accuracy: 0.2008 - val_loss: 2.8102 - val_accuracy: 0.2963
# Epoch 5/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.8205 - accuracy: 0.2380 - val_loss: 2.6937 - val_accuracy: 0.3364
# Epoch 6/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.7320 - accuracy: 0.2693 - val_loss: 2.6128 - val_accuracy: 0.3654
# Epoch 7/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.6585 - accuracy: 0.2905 - val_loss: 2.5386 - val_accuracy: 0.3831
# Epoch 8/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.5648 - accuracy: 0.3175 - val_loss: 2.4600 - val_accuracy: 0.4097
# Epoch 9/30
# 243/243 [==============================] - 3s 12ms/step - loss: 2.4816 - accuracy: 0.3410 - val_loss: 2.3958 - val_accuracy: 0.4309
# Epoch 10/30
# 243/243 [==============================] - 3s 11ms/step - loss: 2.4103 - accuracy: 0.3673 - val_loss: 2.3216 - val_accuracy: 0.4541
# Epoch 11/30
# 243/243 [==============================] - 3s 11ms/step - loss: 2.3450 - accuracy: 0.3863 - val_loss: 2.2624 - val_accuracy: 0.4734
# Epoch 12/30
# 243/243 [==============================] - 3s 11ms/step - loss: 2.2727 - accuracy: 0.4073 - val_loss: 2.2059 - val_accuracy: 0.4788
# Epoch 13/30
# 243/243 [==============================] - 3s 11ms/step - loss: 2.2086 - accuracy: 0.4289 - val_loss: 2.1419 - val_accuracy: 0.4938
# Epoch 14/30
# 243/243 [==============================] - 3s 11ms/step - loss: 2.1267 - accuracy: 0.4473 - val_loss: 2.0903 - val_accuracy: 0.5112
# Epoch 15/30
# 243/243 [==============================] - 3s 11ms/step - loss: 2.0750 - accuracy: 0.4590 - val_loss: 2.0438 - val_accuracy: 0.5158
# Epoch 16/30
# 243/243 [==============================] - 3s 11ms/step - loss: 2.0258 - accuracy: 0.4747 - val_loss: 1.9932 - val_accuracy: 0.5382
# Epoch 17/30
# 243/243 [==============================] - 3s 11ms/step - loss: 1.9507 - accuracy: 0.5010 - val_loss: 1.9515 - val_accuracy: 0.5394
# Epoch 18/30
# 243/243 [==============================] - 3s 11ms/step - loss: 1.9088 - accuracy: 0.5062 - val_loss: 1.9116 - val_accuracy: 0.5529
# Epoch 19/30
# 243/243 [==============================] - 3s 11ms/step - loss: 1.8637 - accuracy: 0.5222 - val_loss: 1.8647 - val_accuracy: 0.5706
# Epoch 20/30
# 243/243 [==============================] - 3s 11ms/step - loss: 1.8111 - accuracy: 0.5437 - val_loss: 1.8140 - val_accuracy: 0.5849
# Epoch 21/30
# 243/243 [==============================] - 3s 11ms/step - loss: 1.7520 - accuracy: 0.5532 - val_loss: 1.7913 - val_accuracy: 0.5883
# Epoch 22/30
# 243/243 [==============================] - 3s 11ms/step - loss: 1.7220 - accuracy: 0.5616 - val_loss: 1.7570 - val_accuracy: 0.5907
# Epoch 23/30
# 243/243 [==============================] - 3s 11ms/step - loss: 1.6795 - accuracy: 0.5758 - val_loss: 1.7257 - val_accuracy: 0.5968
# Epoch 24/30
# 243/243 [==============================] - 3s 11ms/step - loss: 1.6255 - accuracy: 0.5862 - val_loss: 1.6891 - val_accuracy: 0.6046
# Epoch 25/30
# 243/243 [==============================] - 3s 11ms/step - loss: 1.5808 - accuracy: 0.5966 - val_loss: 1.6625 - val_accuracy: 0.6184
# Epoch 26/30
# 243/243 [==============================] - 3s 11ms/step - loss: 1.5480 - accuracy: 0.6054 - val_loss: 1.6387 - val_accuracy: 0.6142
# Epoch 27/30
# 243/243 [==============================] - 3s 11ms/step - loss: 1.4932 - accuracy: 0.6263 - val_loss: 1.6108 - val_accuracy: 0.6223
# Epoch 28/30
# 243/243 [==============================] - 3s 11ms/step - loss: 1.4746 - accuracy: 0.6308 - val_loss: 1.5933 - val_accuracy: 0.6246
# Epoch 29/30
# 243/243 [==============================] - 3s 11ms/step - loss: 1.4416 - accuracy: 0.6344 - val_loss: 1.5550 - val_accuracy: 0.6370
# Epoch 30/30
# 243/243 [==============================] - 3s 11ms/step - loss: 1.4034 - accuracy: 0.6390 - val_loss: 1.5214 - val_accuracy: 0.6443
#
# Addestramndo con filtri [64, 128, 256, 512] e tasso di apprendimento 0.001
# Epoch 1/30
# 243/243 [==============================] - 7s 24ms/step - loss: 2.4423 - accuracy: 0.3117 - val_loss: 1.3612 - val_accuracy: 0.6019
# Epoch 2/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.1107 - accuracy: 0.6780 - val_loss: 0.8597 - val_accuracy: 0.7469
# Epoch 3/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.6463 - accuracy: 0.8102 - val_loss: 0.6911 - val_accuracy: 0.8187
# Epoch 4/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.4342 - accuracy: 0.8684 - val_loss: 0.5981 - val_accuracy: 0.8461
# Epoch 5/30
# 243/243 [==============================] - 6s 23ms/step - loss: 0.3180 - accuracy: 0.8999 - val_loss: 0.6150 - val_accuracy: 0.8619
# Epoch 6/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.2783 - accuracy: 0.9137 - val_loss: 0.5834 - val_accuracy: 0.8511
# Epoch 7/30
# 243/243 [==============================] - 6s 24ms/step - loss: 0.2138 - accuracy: 0.9351 - val_loss: 0.6913 - val_accuracy: 0.8565
# Epoch 8/30
# 243/243 [==============================] - 6s 23ms/step - loss: 0.1858 - accuracy: 0.9415 - val_loss: 0.6413 - val_accuracy: 0.8484
# Epoch 9/30
# 243/243 [==============================] - 6s 23ms/step - loss: 0.1741 - accuracy: 0.9505 - val_loss: 0.6039 - val_accuracy: 0.8673
# Epoch 10/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1576 - accuracy: 0.9545 - val_loss: 0.6624 - val_accuracy: 0.8561
# Epoch 11/30
# 243/243 [==============================] - 7s 27ms/step - loss: 0.1425 - accuracy: 0.9586 - val_loss: 0.7587 - val_accuracy: 0.8519
#
# Addestramndo con filtri [64, 128, 256, 512] e tasso di apprendimento 0.0001
# Epoch 1/30
# 243/243 [==============================] - 10s 39ms/step - loss: 2.9545 - accuracy: 0.1948 - val_loss: 2.3865 - val_accuracy: 0.4051
# Epoch 2/30
# 243/243 [==============================] - 11s 43ms/step - loss: 2.0208 - accuracy: 0.4597 - val_loss: 1.6392 - val_accuracy: 0.5791
# Epoch 3/30
# 243/243 [==============================] - 10s 39ms/step - loss: 1.3520 - accuracy: 0.6321 - val_loss: 1.2146 - val_accuracy: 0.6748
# Epoch 4/30
# 243/243 [==============================] - 10s 41ms/step - loss: 0.9637 - accuracy: 0.7378 - val_loss: 1.0618 - val_accuracy: 0.7434
# Epoch 5/30
# 243/243 [==============================] - 10s 42ms/step - loss: 0.7284 - accuracy: 0.7941 - val_loss: 0.8684 - val_accuracy: 0.7855
# Epoch 6/30
# 243/243 [==============================] - 7s 29ms/step - loss: 0.5807 - accuracy: 0.8352 - val_loss: 0.8213 - val_accuracy: 0.7971
# Epoch 7/30
# 243/243 [==============================] - 6s 26ms/step - loss: 0.4566 - accuracy: 0.8637 - val_loss: 0.8268 - val_accuracy: 0.8110
# Epoch 8/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.3733 - accuracy: 0.8906 - val_loss: 0.7971 - val_accuracy: 0.8264
# Epoch 9/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.3268 - accuracy: 0.9035 - val_loss: 0.7275 - val_accuracy: 0.8364
# Epoch 10/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.2619 - accuracy: 0.9216 - val_loss: 0.7062 - val_accuracy: 0.8480
# Epoch 11/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.2262 - accuracy: 0.9340 - val_loss: 0.7933 - val_accuracy: 0.8248
# Epoch 12/30
# 243/243 [==============================] - 6s 23ms/step - loss: 0.1789 - accuracy: 0.9485 - val_loss: 0.7626 - val_accuracy: 0.8465
# Epoch 13/30
# 243/243 [==============================] - 5s 22ms/step - loss: 0.1659 - accuracy: 0.9522 - val_loss: 0.6646 - val_accuracy: 0.8530
# Epoch 14/30
# 243/243 [==============================] - 6s 22ms/step - loss: 0.1484 - accuracy: 0.9566 - val_loss: 0.8568 - val_accuracy: 0.8345
# Epoch 15/30
# 243/243 [==============================] - 6s 23ms/step - loss: 0.1519 - accuracy: 0.9552 - val_loss: 0.7712 - val_accuracy: 0.8418
# Epoch 16/30
# 243/243 [==============================] - 6s 25ms/step - loss: 0.1420 - accuracy: 0.9594 - val_loss: 0.7913 - val_accuracy: 0.8468
# Epoch 17/30
# 243/243 [==============================] - 6s 23ms/step - loss: 0.1284 - accuracy: 0.9633 - val_loss: 0.8312 - val_accuracy: 0.8511
# Epoch 18/30
# 243/243 [==============================] - 6s 22ms/step - loss: 0.1263 - accuracy: 0.9643 - val_loss: 0.8640 - val_accuracy: 0.8519
#
# Addestramndo con filtri [64, 128, 256, 512] e tasso di apprendimento 1e-05
# Epoch 1/30
# 243/243 [==============================] - 6s 24ms/step - loss: 3.3587 - accuracy: 0.0728 - val_loss: 3.2748 - val_accuracy: 0.1343
# Epoch 2/30
# 243/243 [==============================] - 5s 22ms/step - loss: 3.1295 - accuracy: 0.1540 - val_loss: 2.9160 - val_accuracy: 0.2558
# Epoch 3/30
# 243/243 [==============================] - 5s 22ms/step - loss: 2.8544 - accuracy: 0.2336 - val_loss: 2.7007 - val_accuracy: 0.3360
# Epoch 4/30
# 243/243 [==============================] - 5s 22ms/step - loss: 2.6987 - accuracy: 0.2867 - val_loss: 2.5562 - val_accuracy: 0.3862
# Epoch 5/30
# 243/243 [==============================] - 5s 22ms/step - loss: 2.5654 - accuracy: 0.3247 - val_loss: 2.4605 - val_accuracy: 0.4109
# Epoch 6/30
# 243/243 [==============================] - 6s 23ms/step - loss: 2.4241 - accuracy: 0.3691 - val_loss: 2.3440 - val_accuracy: 0.4429
# Epoch 7/30
# 243/243 [==============================] - 6s 23ms/step - loss: 2.3176 - accuracy: 0.3987 - val_loss: 2.2310 - val_accuracy: 0.4715
# Epoch 8/30
# 243/243 [==============================] - 6s 23ms/step - loss: 2.2127 - accuracy: 0.4330 - val_loss: 2.1444 - val_accuracy: 0.4977
# Epoch 9/30
# 243/243 [==============================] - 6s 23ms/step - loss: 2.0988 - accuracy: 0.4688 - val_loss: 2.0480 - val_accuracy: 0.5316
# Epoch 10/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.9942 - accuracy: 0.5039 - val_loss: 1.9692 - val_accuracy: 0.5548
# Epoch 11/30
# 243/243 [==============================] - 6s 23ms/step - loss: 1.8925 - accuracy: 0.5284 - val_loss: 1.8999 - val_accuracy: 0.5694
# Epoch 12/30
# 243/243 [==============================] - 6s 25ms/step - loss: 1.8065 - accuracy: 0.5531 - val_loss: 1.8130 - val_accuracy: 0.5965
# Epoch 13/30
# 243/243 [==============================] - 6s 23ms/step - loss: 1.7243 - accuracy: 0.5728 - val_loss: 1.7586 - val_accuracy: 0.6080
# Epoch 14/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.6328 - accuracy: 0.5973 - val_loss: 1.7092 - val_accuracy: 0.6215
# Epoch 15/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.5686 - accuracy: 0.6131 - val_loss: 1.6340 - val_accuracy: 0.6458
# Epoch 16/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.5078 - accuracy: 0.6302 - val_loss: 1.5954 - val_accuracy: 0.6528
# Epoch 17/30
# 243/243 [==============================] - 5s 22ms/step - loss: 1.4441 - accuracy: 0.6497 - val_loss: 1.5624 - val_accuracy: 0.6605
# Epoch 18/30
# 243/243 [==============================] - 6s 23ms/step - loss: 1.3702 - accuracy: 0.6616 - val_loss: 1.5049 - val_accuracy: 0.6736
# Epoch 19/30
# 243/243 [==============================] - 6s 26ms/step - loss: 1.3009 - accuracy: 0.6793 - val_loss: 1.4763 - val_accuracy: 0.6667
# Epoch 20/30
# 243/243 [==============================] - 7s 28ms/step - loss: 1.2532 - accuracy: 0.6905 - val_loss: 1.4395 - val_accuracy: 0.6856
# Epoch 21/30
# 243/243 [==============================] - 7s 28ms/step - loss: 1.1979 - accuracy: 0.7043 - val_loss: 1.3994 - val_accuracy: 0.6995
# Epoch 22/30
# 243/243 [==============================] - 6s 25ms/step - loss: 1.1734 - accuracy: 0.7088 - val_loss: 1.3841 - val_accuracy: 0.6998
# Epoch 23/30
# 243/243 [==============================] - 6s 23ms/step - loss: 1.1084 - accuracy: 0.7220 - val_loss: 1.3604 - val_accuracy: 0.7064
# Epoch 24/30
# 243/243 [==============================] - 6s 23ms/step - loss: 1.0629 - accuracy: 0.7406 - val_loss: 1.3274 - val_accuracy: 0.7141
# Epoch 25/30
# 243/243 [==============================] - 6s 24ms/step - loss: 1.0272 - accuracy: 0.7379 - val_loss: 1.2972 - val_accuracy: 0.7326
# Epoch 26/30
# 243/243 [==============================] - 7s 27ms/step - loss: 0.9908 - accuracy: 0.7482 - val_loss: 1.2873 - val_accuracy: 0.7222
# Epoch 27/30
# 243/243 [==============================] - 6s 24ms/step - loss: 0.9732 - accuracy: 0.7513 - val_loss: 1.2940 - val_accuracy: 0.7323
# Epoch 28/30
# 243/243 [==============================] - 7s 27ms/step - loss: 0.9362 - accuracy: 0.7653 - val_loss: 1.2590 - val_accuracy: 0.7238
# Epoch 29/30
# 243/243 [==============================] - 6s 25ms/step - loss: 0.8800 - accuracy: 0.7835 - val_loss: 1.2839 - val_accuracy: 0.7257
# Epoch 30/30
# 243/243 [==============================] - 6s 23ms/step - loss: 0.8638 - accuracy: 0.7863 - val_loss: 1.2553 - val_accuracy: 0.7438
#
# Tempo totale trascorso: 12 minuti e 7 secondi

# %% [markdown]
# Il tempo necessario per la ricerca dei migliori iperparametri è stata di quasi 13 minuti.

# %% [markdown]
# Grazie alla funzione `plot_models`, possiamo visualizzare l'accuratezza e la perdita di tutti i modelli che il tuner ha addestrato. Questa funzione adatta automaticamente il grafico al numero di modelli addestrati (in questo caso 9).

# %%
def plot_models(path, reverse=False, show="accuracy", overfit=True):
    n_models = len(os.listdir(path))
    # creo il subplot a seconda di quanti modelli dispongo
    best_pair = None
    min_diff = float("inf")
    
    for idx_model in range(1, int(np.sqrt(n_models)) + 1):
        if n_models % idx_model == 0:
            diff = abs(idx_model - n_models // idx_model)

            if diff < min_diff:
                min_diff = diff
                best_pair = (idx_model, n_models // idx_model)

    if reverse:
        rows = best_pair[1]
        cols = best_pair[0]
    else:
        rows = best_pair[0]
        cols = best_pair[1]
    
    fig, axes = plt.subplots(rows, cols, figsize=(14, 10))
    
    for index, model in enumerate(os.listdir(path)):
        row = index // cols
        col = index % cols
    
        ax = axes[row][col]
        
        newpath = path + "/" + model
        df = pd.read_csv(newpath)

        value1 = df[show].values
        value2 = df["val_" + show].values
        
        ax.plot(range(1, len(value1) + 1), value1, color="slategray", label="Addestramento")
        ax.plot(range(1, len(value2) + 1), value2, color="indianred", label="Validazione")

        if (row in range(rows)) and col == 0:
            ax.set_ylabel("Accuratezza (%)" if show == "accuracy" else "Perdita", fontweight="semibold", fontsize=10)

        if (col in range(cols)) and row == 2:
            ax.set_xlabel("Epoche", fontweight="semibold", fontsize=10)

        ax.set_title("Filtro " + str(df["filters"][0]) + " & lr " + str(df["learning_rate"][0]), fontsize=12)
            
        ax.set_ylim(0)
        ax.set_xlim(0)

        ax.spines["left"].set_visible(False)
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)

        ax.grid(True, color="gainsboro", alpha=0.3, linestyle="--")

        handles, _ = ax.get_legend_handles_labels()
        
        if overfit and show == "loss":
            # area overfit
            
            rect = mpatches.Rectangle((np.argmin(value2) + 1, 0), width=len(value1) - np.argmin(value2), height=max(max(value1), max(value2)), color='lightcoral', alpha=0.3)
            ax.add_patch(rect)
            # patch overfit per legenda
            overfit = mpatches.Patch(color='lightcoral', alpha=0.3, label='Area overfit')
           
            handles.append(overfit)

        ax.legend(handles=handles)

    plt.subplots_adjust(wspace=0.3, hspace=0.3)
    plt.show()

# %%
plot_models(path="model_tuning/histories/adam", show="accuracy")
plot_models(path="model_tuning/histories/adam", show="loss")

# %% [markdown]
# Dai grafici emerge che la combinazione più performante è composta da **32 filtri di partenza** e un **tasso di apprendimento di 1e-5**, poiché ritarda maggiormente l'overfitting. Altre combinazioni, come **64 filtri di partenza** e un **tasso di apprendimento di 1e-5**, mostrano buone prestazioni ma anche un inizio di overfitting, evidenziato dallo distaccamento tra la perdita di addestramento e quella di validazione.
#
# Procediamo quindi con l'addestramento del modello con **32 filtri di partenza** e un **tasso di apprendimento di 1e-5**. Come di consueto, salviamo i risultati in un file `keras` e la cronologia (history) in un file `csv`. Infine, convertiamo il file in formato `onnx`.

# %%
tuned_improved_basic_model = get_improved_basic_model()
tuned_improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), metrics=["accuracy"])

# %%
tuned_improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/adam/tuned_improved_basic_model.keras", save_best_only=True, monitor="val_loss")]
tuned_improved_history = tuned_improved_basic_model.fit(train_ds, epochs=100, validation_data=val_ds, callbacks=tuned_improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 3s 12ms/step - loss: 3.0861 - accuracy: 0.1530 - val_loss: 2.6583 - val_accuracy: 0.3133
# Epoch 2/100
# 243/243 [==============================] - 3s 12ms/step - loss: 2.4892 - accuracy: 0.3329 - val_loss: 2.1369 - val_accuracy: 0.4444
# Epoch 3/100
# 243/243 [==============================] - 3s 11ms/step - loss: 1.9503 - accuracy: 0.4803 - val_loss: 1.7200 - val_accuracy: 0.5559
# Epoch 4/100
# 243/243 [==============================] - 3s 12ms/step - loss: 1.5264 - accuracy: 0.5899 - val_loss: 1.3750 - val_accuracy: 0.6620
# Epoch 5/100
# 243/243 [==============================] - 3s 11ms/step - loss: 1.2153 - accuracy: 0.6700 - val_loss: 1.2122 - val_accuracy: 0.6964
# Epoch 6/100
# 243/243 [==============================] - 3s 11ms/step - loss: 1.0015 - accuracy: 0.7263 - val_loss: 1.0477 - val_accuracy: 0.7369
# Epoch 7/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.8410 - accuracy: 0.7674 - val_loss: 0.9548 - val_accuracy: 0.7627
# Epoch 8/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.6789 - accuracy: 0.8117 - val_loss: 0.8737 - val_accuracy: 0.7793
# Epoch 9/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.6196 - accuracy: 0.8237 - val_loss: 0.8365 - val_accuracy: 0.7955
# Epoch 10/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.5116 - accuracy: 0.8513 - val_loss: 0.8688 - val_accuracy: 0.7975
# Epoch 11/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.4510 - accuracy: 0.8706 - val_loss: 0.8179 - val_accuracy: 0.8075
# Epoch 12/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.4025 - accuracy: 0.8825 - val_loss: 0.7632 - val_accuracy: 0.8152
# Epoch 13/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.3657 - accuracy: 0.8896 - val_loss: 0.7654 - val_accuracy: 0.8179
# Epoch 14/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.3216 - accuracy: 0.9048 - val_loss: 0.7797 - val_accuracy: 0.8283
# Epoch 15/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2976 - accuracy: 0.9107 - val_loss: 0.7730 - val_accuracy: 0.8264
# Epoch 16/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2561 - accuracy: 0.9235 - val_loss: 0.7713 - val_accuracy: 0.8306
# Epoch 17/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2552 - accuracy: 0.9241 - val_loss: 0.8186 - val_accuracy: 0.8299
# Epoch 18/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2372 - accuracy: 0.9289 - val_loss: 0.7873 - val_accuracy: 0.8434
# Epoch 19/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.2040 - accuracy: 0.9394 - val_loss: 0.7403 - val_accuracy: 0.8399
# Epoch 20/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1896 - accuracy: 0.9421 - val_loss: 0.7270 - val_accuracy: 0.8430
# Epoch 21/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1787 - accuracy: 0.9496 - val_loss: 0.7919 - val_accuracy: 0.8376
# Epoch 22/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1583 - accuracy: 0.9508 - val_loss: 0.8136 - val_accuracy: 0.8503
# Epoch 23/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1603 - accuracy: 0.9521 - val_loss: 0.8393 - val_accuracy: 0.8426
# Epoch 24/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1552 - accuracy: 0.9510 - val_loss: 0.8420 - val_accuracy: 0.8561
# Epoch 25/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1409 - accuracy: 0.9585 - val_loss: 0.8058 - val_accuracy: 0.8480
# Epoch 26/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1405 - accuracy: 0.9573 - val_loss: 0.7955 - val_accuracy: 0.8476
# Epoch 27/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1155 - accuracy: 0.9688 - val_loss: 0.7995 - val_accuracy: 0.8615
# Epoch 28/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1195 - accuracy: 0.9637 - val_loss: 0.8221 - val_accuracy: 0.8519
# Epoch 29/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1142 - accuracy: 0.9677 - val_loss: 0.7338 - val_accuracy: 0.8534
# Epoch 30/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1132 - accuracy: 0.9668 - val_loss: 0.8690 - val_accuracy: 0.8445
# Epoch 31/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0984 - accuracy: 0.9701 - val_loss: 0.8820 - val_accuracy: 0.8546
# Epoch 32/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0970 - accuracy: 0.9714 - val_loss: 0.8727 - val_accuracy: 0.8596
# Epoch 33/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0860 - accuracy: 0.9771 - val_loss: 0.8356 - val_accuracy: 0.8588
# Epoch 34/100
# 243/243 [==============================] - 4s 15ms/step - loss: 0.1023 - accuracy: 0.9697 - val_loss: 0.8711 - val_accuracy: 0.8515
# Epoch 35/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1037 - accuracy: 0.9693 - val_loss: 0.8861 - val_accuracy: 0.8623
# Epoch 36/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0830 - accuracy: 0.9762 - val_loss: 0.8101 - val_accuracy: 0.8646
# Epoch 37/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0955 - accuracy: 0.9711 - val_loss: 0.8887 - val_accuracy: 0.8530
# Epoch 38/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0991 - accuracy: 0.9731 - val_loss: 1.2778 - val_accuracy: 0.8252
# Epoch 39/100
# 243/243 [==============================] - 4s 14ms/step - loss: 0.1002 - accuracy: 0.9715 - val_loss: 0.8926 - val_accuracy: 0.8522
# Epoch 40/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0799 - accuracy: 0.9782 - val_loss: 0.8823 - val_accuracy: 0.8611
# Epoch 41/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0702 - accuracy: 0.9785 - val_loss: 0.9403 - val_accuracy: 0.8530
# Epoch 42/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.0765 - accuracy: 0.9787 - val_loss: 0.8653 - val_accuracy: 0.8576
# Epoch 43/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0810 - accuracy: 0.9756 - val_loss: 0.8209 - val_accuracy: 0.8627
# Epoch 44/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0694 - accuracy: 0.9812 - val_loss: 0.8605 - val_accuracy: 0.8642
# Epoch 45/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0687 - accuracy: 0.9804 - val_loss: 0.9339 - val_accuracy: 0.8646
# Epoch 46/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0625 - accuracy: 0.9820 - val_loss: 0.9854 - val_accuracy: 0.8603
# Epoch 47/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0605 - accuracy: 0.9825 - val_loss: 1.1893 - val_accuracy: 0.8619
# Epoch 48/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0660 - accuracy: 0.9821 - val_loss: 0.8723 - val_accuracy: 0.8650
# Epoch 49/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0842 - accuracy: 0.9764 - val_loss: 1.0350 - val_accuracy: 0.8557
# Epoch 50/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0559 - accuracy: 0.9849 - val_loss: 1.0045 - val_accuracy: 0.8596
# Epoch 51/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0800 - accuracy: 0.9785 - val_loss: 0.9197 - val_accuracy: 0.8561
# Epoch 52/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0699 - accuracy: 0.9807 - val_loss: 0.8547 - val_accuracy: 0.8580
# Epoch 53/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0704 - accuracy: 0.9812 - val_loss: 1.0630 - val_accuracy: 0.8588
# Epoch 54/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0676 - accuracy: 0.9821 - val_loss: 0.9657 - val_accuracy: 0.8576
# Epoch 55/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0502 - accuracy: 0.9851 - val_loss: 0.9317 - val_accuracy: 0.8661
# Epoch 56/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0502 - accuracy: 0.9848 - val_loss: 1.1179 - val_accuracy: 0.8515
# Epoch 57/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0536 - accuracy: 0.9857 - val_loss: 1.1980 - val_accuracy: 0.8573
# Epoch 58/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0554 - accuracy: 0.9865 - val_loss: 0.9160 - val_accuracy: 0.8681
# Epoch 59/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0512 - accuracy: 0.9847 - val_loss: 0.8590 - val_accuracy: 0.8677
# Epoch 60/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0438 - accuracy: 0.9888 - val_loss: 0.8902 - val_accuracy: 0.8580
# Epoch 61/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0508 - accuracy: 0.9865 - val_loss: 1.1240 - val_accuracy: 0.8646
# Epoch 62/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0572 - accuracy: 0.9852 - val_loss: 0.9066 - val_accuracy: 0.8588
# Epoch 63/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0641 - accuracy: 0.9836 - val_loss: 0.8956 - val_accuracy: 0.8623
# Epoch 64/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0550 - accuracy: 0.9858 - val_loss: 0.9296 - val_accuracy: 0.8526
# Epoch 65/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0505 - accuracy: 0.9863 - val_loss: 0.8936 - val_accuracy: 0.8704
# Epoch 66/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0501 - accuracy: 0.9865 - val_loss: 0.8932 - val_accuracy: 0.8711
# Epoch 67/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0386 - accuracy: 0.9894 - val_loss: 0.8723 - val_accuracy: 0.8723
# Epoch 68/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0345 - accuracy: 0.9907 - val_loss: 0.9570 - val_accuracy: 0.8711
# Epoch 69/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0518 - accuracy: 0.9860 - val_loss: 0.9944 - val_accuracy: 0.8638
# Epoch 70/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0443 - accuracy: 0.9888 - val_loss: 1.0462 - val_accuracy: 0.8654
# Epoch 71/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0457 - accuracy: 0.9874 - val_loss: 1.0197 - val_accuracy: 0.8650
# Epoch 72/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0498 - accuracy: 0.9883 - val_loss: 0.9477 - val_accuracy: 0.8561
# Epoch 73/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0363 - accuracy: 0.9894 - val_loss: 1.2638 - val_accuracy: 0.8607
# Epoch 74/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0401 - accuracy: 0.9885 - val_loss: 0.8190 - val_accuracy: 0.8711
# Epoch 75/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0474 - accuracy: 0.9876 - val_loss: 1.1357 - val_accuracy: 0.8565
# Epoch 76/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0352 - accuracy: 0.9889 - val_loss: 1.1265 - val_accuracy: 0.8634
# Epoch 77/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0355 - accuracy: 0.9901 - val_loss: 0.9582 - val_accuracy: 0.8700
# Epoch 78/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0333 - accuracy: 0.9903 - val_loss: 1.2650 - val_accuracy: 0.8634
# Epoch 79/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0533 - accuracy: 0.9861 - val_loss: 0.9418 - val_accuracy: 0.8542
# Epoch 80/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0368 - accuracy: 0.9902 - val_loss: 1.0224 - val_accuracy: 0.8538
# Epoch 81/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0344 - accuracy: 0.9906 - val_loss: 1.0408 - val_accuracy: 0.8700
# Epoch 82/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0324 - accuracy: 0.9899 - val_loss: 1.1048 - val_accuracy: 0.8731
# Epoch 83/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0381 - accuracy: 0.9885 - val_loss: 0.9905 - val_accuracy: 0.8669
# Epoch 84/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0455 - accuracy: 0.9896 - val_loss: 1.0346 - val_accuracy: 0.8576
# Epoch 85/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0365 - accuracy: 0.9909 - val_loss: 1.1089 - val_accuracy: 0.8661
# Epoch 86/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0344 - accuracy: 0.9920 - val_loss: 0.9992 - val_accuracy: 0.8623
# Epoch 87/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0354 - accuracy: 0.9906 - val_loss: 1.0451 - val_accuracy: 0.8723
# Epoch 88/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0341 - accuracy: 0.9901 - val_loss: 1.0360 - val_accuracy: 0.8700
# Epoch 89/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0266 - accuracy: 0.9921 - val_loss: 1.1001 - val_accuracy: 0.8727
# Epoch 90/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.0404 - accuracy: 0.9889 - val_loss: 1.1052 - val_accuracy: 0.8669
# Epoch 91/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.0249 - accuracy: 0.9928 - val_loss: 1.1290 - val_accuracy: 0.8692
# Epoch 92/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0336 - accuracy: 0.9905 - val_loss: 1.0775 - val_accuracy: 0.8650
# Epoch 93/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0380 - accuracy: 0.9883 - val_loss: 1.4483 - val_accuracy: 0.8607
# Epoch 94/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.0432 - accuracy: 0.9894 - val_loss: 0.9970 - val_accuracy: 0.8488
# Epoch 95/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0387 - accuracy: 0.9903 - val_loss: 1.0398 - val_accuracy: 0.8630
# Epoch 96/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0312 - accuracy: 0.9934 - val_loss: 0.9460 - val_accuracy: 0.8677
# Epoch 97/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0300 - accuracy: 0.9912 - val_loss: 1.0231 - val_accuracy: 0.8627
# Epoch 98/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0378 - accuracy: 0.9903 - val_loss: 1.0055 - val_accuracy: 0.8754
# Epoch 99/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0265 - accuracy: 0.9925 - val_loss: 1.1915 - val_accuracy: 0.8650
# Epoch 100/100
# 243/243 [==============================] - 3s 11ms/step - loss: 0.0279 - accuracy: 0.9927 - val_loss: 1.0314 - val_accuracy: 0.8592

# %%
tuned_improved_history_df = convert_history_to_csv(tuned_improved_history)
tuned_improved_history_df.to_csv("model_histories/adam/tuned_improved_history.csv")

# %%
convert_model_to_onnx("bestmodels/adam/tuned_improved_basic_model.keras", (124, 129, 1))

# %%
create_train_val_plot(tuned_improved_history.history)

# %%
tuned_improved_best_model = tf.keras.models.load_model("bestmodels/adam/tuned_improved_basic_model.keras")
test_loss, test_acc = tuned_improved_best_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 6ms/step - loss: 0.8460 - accuracy: 0.8280
# Accuratezza: 0.828

# %%
evaluate_onnx_model("bestmodels/adam/tuned_improved_basic_model.onnx", test_ds)
# Out:
# Accuratezza: 0.828

# %% [markdown]
# Il modello ha registrato un insignificante miglioramento rispetto a prima, tuttavia è stato osservato un leggero ritardo nell'insorgere dell'overfitting. Inoltre, la perdita non è peggiorata tanto quanto in precedenza con l'avanzare delle epoche. L'accuratezza è attualmente **82.8%**.

# %%
for audio, label in test_ds:
    create_distribution_plot(tuned_improved_best_model, audio, label)
    break

# %% [markdown]
# ## Miglioramenti all'architettura del modello
#
# Durante il corso abbiamo visto anche delle best practice architetturali che possono aiutare a ottenere maggiori prestazioni col modello. Il nostro scopo è provare le tecniche viste e studiate durante il corso e capire come reagiscono al task.

# %% [markdown]
# Le tre tecniche che andremo ad applicare sono:
# - blocchi residuali
# - normalizzazione dei batch
# - convoluzioni separabili

# %% [markdown]
# ### Blocchi residuali
# I blocchi residuali sono un'applicazione efficace quando riscontriamo il problema dei **gradienti che svaniscono**. Non sono una tecnica strettamente legata ai modelli convolutivi, ma sono una best practice generale che viene applicare nella maggior parte delle architetture.
#
# I **gradienti che vaniscono** sono causati dalle **catene di funzioni troppo lunghe**, che nel nostro caso non sono altro che **una sequenza di livelli convolutivi**. Per ogni livello convolutivo **una certa quantità di rumore** viene introdotta, finché essa non arriva a **sopraffare** le informazioni sul gradiente.
#
# Se le informazioni sul gradiente sono sopraffatte la **backpropagation smette di funzionare**, e quindi il nostro **modello non impara**.

# %% [markdown]
# L'**idea basilare** dietro ai blocchi residuali è quella di **salvare l'informazione** contenuta nell'input precedente al livello convolutivo, e **sommarla all'output** dello stesso livello convolutivo.

# %% [markdown]
# Per applicare i blocchi residuali abbiamo implementato la funzione `residual_block(x, filters, pooling=False)` vista a lezione. La funzione è stata adattata al modello da noi implementato, e utilizza le altre due best practice citate precedentemente.

# %%
def residual_block(x, filters, pooling=False):
    residual = x

    x = tf.keras.layers.SeparableConv2D(filters, 3, padding="same", use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    if pooling:
      x = tf.keras.layers.MaxPooling2D(pool_size=2, padding="same")(x)
      residual = tf.keras.layers.Conv2D(filters, 1, strides=2)(residual)
    elif filters != residual.shape[-1]:
      residual = tf.keras.layers.Conv2D(filters, 1)(residual)

    x = tf.keras.layers.add([x, residual])
    return x

# %% [markdown]
# ### Normalizzazione dei batch e convoluzioni separabili
# La **normalizzazione dei batch** è un concetto che abbiamo già affrontato nel notebook, infatti il suo scopo rimane quello di rendere i dati **più simili tra loro** centrandoli sullo zero, e ciò aiuta la **propagazione del gradiente**. Questa normalizzazione, a differenza della precedente, è in grado di normalizzare i dati in modo adattivo anche quando la media e la varianza cambiano durante l'addestramento.

# %% [markdown]
# Le **convoluzione separabili** invece sono un **sostituto** ai livelli convolutivi utilizzati fino ad adesso, e offrono un modello con maggiori prestazioni e meno parametri.

# %%
def bp_basic_model():
    # input e pre processamento
    inputs = tf.keras.Input(shape=(124, 129, 1))
    
    x = residual_block(inputs, 32, pooling=True)
    x = residual_block(x, 64, pooling=True)
    x = residual_block(x, 128, pooling=True)
    x = residual_block(x, 256, pooling=True)
    x = residual_block(x, 256, pooling=False)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Livelli per la classificazione
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
bp_basic_model = bp_basic_model()
bp_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

bp_basic_model.summary()
# Out:
# Model: "model_14"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_14 (InputLayer)          [(None, 124, 129, 1  0           []
#                                 )]
#
#  separable_conv2d (SeparableCon  (None, 124, 129, 32  41         ['input_14[0][0]']
#  v2D)                           )
#
#  batch_normalization (BatchNorm  (None, 124, 129, 32  128        ['separable_conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 124, 129, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d_52 (MaxPooling2D  (None, 62, 65, 32)  0           ['activation[0][0]']
#  )
#
#  conv2d_65 (Conv2D)             (None, 62, 65, 32)   64          ['input_14[0][0]']
#
#  add (Add)                      (None, 62, 65, 32)   0           ['max_pooling2d_52[0][0]',
#                                                                   'conv2d_65[0][0]']
#
#  separable_conv2d_1 (SeparableC  (None, 62, 65, 64)  2336        ['add[0][0]']
#  onv2D)
#
#  batch_normalization_1 (BatchNo  (None, 62, 65, 64)  256         ['separable_conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 62, 65, 64)   0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d_53 (MaxPooling2D  (None, 31, 33, 64)  0           ['activation_1[0][0]']
#  )
#
#  conv2d_66 (Conv2D)             (None, 31, 33, 64)   2112        ['add[0][0]']
#
#  add_1 (Add)                    (None, 31, 33, 64)   0           ['max_pooling2d_53[0][0]',
#                                                                   'conv2d_66[0][0]']
#
#  separable_conv2d_2 (SeparableC  (None, 31, 33, 128)  8768       ['add_1[0][0]']
#  onv2D)
#
#  batch_normalization_2 (BatchNo  (None, 31, 33, 128)  512        ['separable_conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 31, 33, 128)  0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_54 (MaxPooling2D  (None, 16, 17, 128)  0          ['activation_2[0][0]']
#  )
#
#  conv2d_67 (Conv2D)             (None, 16, 17, 128)  8320        ['add_1[0][0]']
#
#  add_2 (Add)                    (None, 16, 17, 128)  0           ['max_pooling2d_54[0][0]',
#                                                                   'conv2d_67[0][0]']
#
#  separable_conv2d_3 (SeparableC  (None, 16, 17, 256)  33920      ['add_2[0][0]']
#  onv2D)
#
#  batch_normalization_3 (BatchNo  (None, 16, 17, 256)  1024       ['separable_conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 16, 17, 256)  0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_55 (MaxPooling2D  (None, 8, 9, 256)   0           ['activation_3[0][0]']
#  )
#
#  conv2d_68 (Conv2D)             (None, 8, 9, 256)    33024       ['add_2[0][0]']
#
#  add_3 (Add)                    (None, 8, 9, 256)    0           ['max_pooling2d_55[0][0]',
#                                                                   'conv2d_68[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 8, 9, 256)   67840       ['add_3[0][0]']
#  onv2D)
#
#  batch_normalization_4 (BatchNo  (None, 8, 9, 256)   1024        ['separable_conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 8, 9, 256)    0           ['batch_normalization_4[0][0]']
#
#  add_4 (Add)                    (None, 8, 9, 256)    0           ['activation_4[0][0]',
#                                                                   'add_3[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['add_4[0][0]']
#  alAveragePooling2D)
#
#  dropout_13 (Dropout)           (None, 256)          0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_13 (Dense)               (None, 30)           7710        ['dropout_13[0][0]']
#
# ==================================================================================================
# Total params: 167,079
# Trainable params: 165,607
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %% [markdown]
# Le best practice, insieme al `tf.keras.layers.GlobalAveragePooling2D()` applicato al posto del Flatten, hanno formato un modello con circa **160000 parametri addestrabili** (circa il 12% del modello precedente).

# %%
bp_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/adam/bp_basic_model.keras", save_best_only=True, monitor="val_loss")]
bp_model_history = bp_basic_model.fit(train_ds, epochs=100, validation_data=val_ds, callbacks=bp_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 6s 21ms/step - loss: 3.2837 - accuracy: 0.1023 - val_loss: 3.3420 - val_accuracy: 0.0359
# Epoch 2/100
# 243/243 [==============================] - 5s 20ms/step - loss: 2.7963 - accuracy: 0.2075 - val_loss: 2.8426 - val_accuracy: 0.2106
# Epoch 3/100
# 243/243 [==============================] - 5s 22ms/step - loss: 2.4545 - accuracy: 0.3130 - val_loss: 2.4352 - val_accuracy: 0.3044
# Epoch 4/100
# 243/243 [==============================] - 5s 21ms/step - loss: 2.0593 - accuracy: 0.4308 - val_loss: 2.2347 - val_accuracy: 0.3291
# Epoch 5/100
# 243/243 [==============================] - 5s 20ms/step - loss: 1.6259 - accuracy: 0.5638 - val_loss: 1.5140 - val_accuracy: 0.5455
# Epoch 6/100
# 243/243 [==============================] - 5s 20ms/step - loss: 1.2980 - accuracy: 0.6563 - val_loss: 1.5063 - val_accuracy: 0.5764
# Epoch 7/100
# 243/243 [==============================] - 5s 20ms/step - loss: 1.0657 - accuracy: 0.7166 - val_loss: 1.1147 - val_accuracy: 0.7095
# Epoch 8/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.8968 - accuracy: 0.7601 - val_loss: 1.0809 - val_accuracy: 0.6879
# Epoch 9/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.7774 - accuracy: 0.7889 - val_loss: 0.9461 - val_accuracy: 0.7272
# Epoch 10/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.6958 - accuracy: 0.8090 - val_loss: 0.7734 - val_accuracy: 0.7820
# Epoch 11/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.6206 - accuracy: 0.8352 - val_loss: 0.7097 - val_accuracy: 0.7986
# Epoch 12/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.5544 - accuracy: 0.8519 - val_loss: 0.8773 - val_accuracy: 0.7434
# Epoch 13/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.4992 - accuracy: 0.8634 - val_loss: 0.9227 - val_accuracy: 0.7253
# Epoch 14/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.4546 - accuracy: 0.8768 - val_loss: 0.7998 - val_accuracy: 0.7809
# Epoch 15/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.4169 - accuracy: 0.8878 - val_loss: 0.7029 - val_accuracy: 0.8125
# Epoch 16/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.3924 - accuracy: 0.8939 - val_loss: 0.7891 - val_accuracy: 0.7674
# Epoch 17/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.3914 - accuracy: 0.8948 - val_loss: 0.7534 - val_accuracy: 0.7967
# Epoch 18/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.3558 - accuracy: 0.8999 - val_loss: 0.6732 - val_accuracy: 0.8121
# Epoch 19/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.3389 - accuracy: 0.9075 - val_loss: 0.6430 - val_accuracy: 0.8191
# Epoch 20/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.3196 - accuracy: 0.9111 - val_loss: 1.2881 - val_accuracy: 0.6582
# Epoch 21/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2996 - accuracy: 0.9156 - val_loss: 0.6651 - val_accuracy: 0.8094
# Epoch 22/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.3012 - accuracy: 0.9161 - val_loss: 0.7815 - val_accuracy: 0.7990
# Epoch 23/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2812 - accuracy: 0.9238 - val_loss: 0.6913 - val_accuracy: 0.8183
# Epoch 24/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.2583 - accuracy: 0.9287 - val_loss: 0.6328 - val_accuracy: 0.8329
# Epoch 25/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2722 - accuracy: 0.9254 - val_loss: 1.0199 - val_accuracy: 0.7330
# Epoch 26/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2513 - accuracy: 0.9298 - val_loss: 0.6670 - val_accuracy: 0.8221
# Epoch 27/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2606 - accuracy: 0.9285 - val_loss: 0.7925 - val_accuracy: 0.8063
# Epoch 28/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2293 - accuracy: 0.9372 - val_loss: 0.7338 - val_accuracy: 0.8160
# Epoch 29/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.2212 - accuracy: 0.9411 - val_loss: 0.6002 - val_accuracy: 0.8399
# Epoch 30/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2112 - accuracy: 0.9420 - val_loss: 0.8283 - val_accuracy: 0.7847
# Epoch 31/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.2089 - accuracy: 0.9399 - val_loss: 0.5998 - val_accuracy: 0.8380
# Epoch 32/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1889 - accuracy: 0.9478 - val_loss: 0.8416 - val_accuracy: 0.7998
# Epoch 33/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2003 - accuracy: 0.9437 - val_loss: 0.9551 - val_accuracy: 0.7731
# Epoch 34/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.2128 - accuracy: 0.9409 - val_loss: 0.7211 - val_accuracy: 0.8237
# Epoch 35/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1814 - accuracy: 0.9512 - val_loss: 0.7862 - val_accuracy: 0.8098
# Epoch 36/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1825 - accuracy: 0.9518 - val_loss: 0.8105 - val_accuracy: 0.8202
# Epoch 37/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1656 - accuracy: 0.9552 - val_loss: 0.6230 - val_accuracy: 0.8434
# Epoch 38/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1640 - accuracy: 0.9537 - val_loss: 0.6901 - val_accuracy: 0.8233
# Epoch 39/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1712 - accuracy: 0.9503 - val_loss: 0.7740 - val_accuracy: 0.8125
# Epoch 40/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1817 - accuracy: 0.9518 - val_loss: 0.7451 - val_accuracy: 0.8218
# Epoch 41/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1418 - accuracy: 0.9604 - val_loss: 0.7844 - val_accuracy: 0.8322
# Epoch 42/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1429 - accuracy: 0.9615 - val_loss: 0.6525 - val_accuracy: 0.8495
# Epoch 43/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1602 - accuracy: 0.9537 - val_loss: 1.1871 - val_accuracy: 0.7477
# Epoch 44/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1803 - accuracy: 0.9523 - val_loss: 0.7683 - val_accuracy: 0.8021
# Epoch 45/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1567 - accuracy: 0.9579 - val_loss: 0.7993 - val_accuracy: 0.8048
# Epoch 46/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1394 - accuracy: 0.9640 - val_loss: 0.5392 - val_accuracy: 0.8715
# Epoch 47/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1158 - accuracy: 0.9701 - val_loss: 0.6173 - val_accuracy: 0.8576
# Epoch 48/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1663 - accuracy: 0.9528 - val_loss: 2.0075 - val_accuracy: 0.6327
# Epoch 49/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1439 - accuracy: 0.9606 - val_loss: 0.6742 - val_accuracy: 0.8426
# Epoch 50/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1435 - accuracy: 0.9601 - val_loss: 0.6843 - val_accuracy: 0.8407
# Epoch 51/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1579 - accuracy: 0.9570 - val_loss: 0.5922 - val_accuracy: 0.8603
# Epoch 52/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1530 - accuracy: 0.9572 - val_loss: 0.6974 - val_accuracy: 0.8522
# Epoch 53/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1286 - accuracy: 0.9652 - val_loss: 0.6854 - val_accuracy: 0.8391
# Epoch 54/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1183 - accuracy: 0.9701 - val_loss: 0.7691 - val_accuracy: 0.8403
# Epoch 55/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1220 - accuracy: 0.9666 - val_loss: 0.7270 - val_accuracy: 0.8468
# Epoch 56/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1228 - accuracy: 0.9666 - val_loss: 1.1487 - val_accuracy: 0.7735
# Epoch 57/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1518 - accuracy: 0.9586 - val_loss: 0.6579 - val_accuracy: 0.8484
# Epoch 58/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1170 - accuracy: 0.9689 - val_loss: 0.7827 - val_accuracy: 0.8248
# Epoch 59/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1147 - accuracy: 0.9689 - val_loss: 0.6189 - val_accuracy: 0.8596
# Epoch 60/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1205 - accuracy: 0.9670 - val_loss: 1.0017 - val_accuracy: 0.7882
# Epoch 61/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1308 - accuracy: 0.9648 - val_loss: 0.8202 - val_accuracy: 0.8345
# Epoch 62/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1115 - accuracy: 0.9715 - val_loss: 0.6974 - val_accuracy: 0.8472
# Epoch 63/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1143 - accuracy: 0.9683 - val_loss: 0.6171 - val_accuracy: 0.8561
# Epoch 64/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0942 - accuracy: 0.9765 - val_loss: 0.5501 - val_accuracy: 0.8688
# Epoch 65/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.0948 - accuracy: 0.9762 - val_loss: 0.7261 - val_accuracy: 0.8422
# Epoch 66/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1435 - accuracy: 0.9628 - val_loss: 1.1061 - val_accuracy: 0.7870
# Epoch 67/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1267 - accuracy: 0.9647 - val_loss: 0.9769 - val_accuracy: 0.8113
# Epoch 68/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.0933 - accuracy: 0.9749 - val_loss: 0.5632 - val_accuracy: 0.8781
# Epoch 69/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.0839 - accuracy: 0.9773 - val_loss: 0.7662 - val_accuracy: 0.8218
# Epoch 70/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0931 - accuracy: 0.9747 - val_loss: 0.7395 - val_accuracy: 0.8461
# Epoch 71/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1146 - accuracy: 0.9679 - val_loss: 0.6737 - val_accuracy: 0.8507
# Epoch 72/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0929 - accuracy: 0.9751 - val_loss: 0.5207 - val_accuracy: 0.8823
# Epoch 73/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.0972 - accuracy: 0.9744 - val_loss: 0.8998 - val_accuracy: 0.8179
# Epoch 74/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1195 - accuracy: 0.9664 - val_loss: 0.7909 - val_accuracy: 0.8326
# Epoch 75/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1159 - accuracy: 0.9661 - val_loss: 0.9402 - val_accuracy: 0.7975
# Epoch 76/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.0850 - accuracy: 0.9786 - val_loss: 0.5990 - val_accuracy: 0.8785
# Epoch 77/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1031 - accuracy: 0.9714 - val_loss: 0.8470 - val_accuracy: 0.8410
# Epoch 78/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1038 - accuracy: 0.9720 - val_loss: 0.7779 - val_accuracy: 0.8403
# Epoch 79/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0932 - accuracy: 0.9765 - val_loss: 1.2361 - val_accuracy: 0.7720
# Epoch 80/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0703 - accuracy: 0.9829 - val_loss: 0.4990 - val_accuracy: 0.8827
# Epoch 81/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.0708 - accuracy: 0.9834 - val_loss: 0.6736 - val_accuracy: 0.8580
# Epoch 82/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1313 - accuracy: 0.9634 - val_loss: 0.7232 - val_accuracy: 0.8476
# Epoch 83/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0824 - accuracy: 0.9785 - val_loss: 0.5798 - val_accuracy: 0.8777
# Epoch 84/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1303 - accuracy: 0.9638 - val_loss: 1.6985 - val_accuracy: 0.7045
# Epoch 85/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1237 - accuracy: 0.9653 - val_loss: 0.6239 - val_accuracy: 0.8623
# Epoch 86/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.0857 - accuracy: 0.9764 - val_loss: 0.5643 - val_accuracy: 0.8819
# Epoch 87/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.0912 - accuracy: 0.9753 - val_loss: 0.8036 - val_accuracy: 0.8376
# Epoch 88/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0746 - accuracy: 0.9794 - val_loss: 0.4986 - val_accuracy: 0.8804
# Epoch 89/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.0674 - accuracy: 0.9825 - val_loss: 0.8625 - val_accuracy: 0.8326
# Epoch 90/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0749 - accuracy: 0.9809 - val_loss: 0.7045 - val_accuracy: 0.8472
# Epoch 91/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1008 - accuracy: 0.9735 - val_loss: 1.1144 - val_accuracy: 0.8036
# Epoch 92/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.1238 - accuracy: 0.9644 - val_loss: 0.7453 - val_accuracy: 0.8546
# Epoch 93/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0844 - accuracy: 0.9778 - val_loss: 0.4964 - val_accuracy: 0.8873
# Epoch 94/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0882 - accuracy: 0.9763 - val_loss: 0.6056 - val_accuracy: 0.8650
# Epoch 95/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0673 - accuracy: 0.9844 - val_loss: 0.6856 - val_accuracy: 0.8654
# Epoch 96/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.1233 - accuracy: 0.9652 - val_loss: 0.7844 - val_accuracy: 0.8287
# Epoch 97/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0772 - accuracy: 0.9790 - val_loss: 0.6710 - val_accuracy: 0.8600
# Epoch 98/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0841 - accuracy: 0.9771 - val_loss: 1.1143 - val_accuracy: 0.7855
# Epoch 99/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0880 - accuracy: 0.9754 - val_loss: 1.2887 - val_accuracy: 0.7890
# Epoch 100/100
# 243/243 [==============================] - 5s 21ms/step - loss: 0.0725 - accuracy: 0.9812 - val_loss: 0.5787 - val_accuracy: 0.8711

# %% [markdown]
# Salviamo nuovamente la history del modello in un file csv.

# %%
bp_model_history_df = convert_history_to_csv(bp_model_history)
bp_model_history_df.to_csv("model_histories/adam/bp_model_history.csv")

# %% [markdown]
# Convertiamo anche il miglior modello nel formato **.onnx**.

# %%
convert_model_to_onnx("bestmodels/adam/bp_basic_model.keras", (124, 129, 1))

# %%
create_train_val_plot(bp_model_history.history, overfit=False)

# %% [markdown]
# Possiamo notare che il modello **NON ha raggiunto una vera fase di overfitting**, ma la validazione non ha mostrato un incremento sostanziale all'aumentare delle epoche (probabilmente dovuto dalle tecniche di overfitting non totalmente implementate). La **loss della validazione** stava continuando a scendere, e allo stesso tempo **l'accuratezza della validazione era crescente**.

# %%
best_bp_basic_model = tf.keras.models.load_model("bestmodels/adam/bp_basic_model.keras")
test_loss, test_acc = best_bp_basic_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 7ms/step - loss: 0.5258 - accuracy: 0.8814
# Accuratezza: 0.881

# %% [markdown]
# Verifichiamola anche con il modello **.onnx**.

# %%
evaluate_onnx_model("bestmodels/adam/bp_basic_model.onnx", test_ds)
# Out:
# Accuratezza: 0.881

# %% [markdown]
# Abbiamo ottenuto un notevole miglioramento per quanto riguarda l'accuratezza, ottenendo un **88.1%**. Questo risultato non è male, considerando che il modello ha poco meno del **12% dei parametri** rispetto al precedente.

# %%
for audio, label in test_ds:
    create_distribution_plot(best_bp_basic_model, audio, label)
    break

# %% [markdown]
# La decisione del modello in questo caso è nuovamente molto chiara.
