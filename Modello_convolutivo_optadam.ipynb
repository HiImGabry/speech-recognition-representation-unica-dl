# %% [markdown]
# # Modello convolutivo di base
# Lo scopo di questo notebook è creare un **modello convolutivo di base** con un'architettura semplice. In seguito, sarà interessante confrontare i risultati di questo primo modello con i risultati ottenuti da modelli più complessi, o pre addestrati.

# %% [markdown]
# Come al solito, si procede con l'importazione delle librerie utilizzate e la creazione dei set di allenamento e validazione.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import os

# %%
train_ds, validation_ds = tf.keras.utils.audio_dataset_from_directory(
    directory='../reduced_dataset/dataset/audio',
    validation_split=0.4, # stiamo mettendo da parte il 40% del dataset, che sarà suddiviso in validation set e test set
    shuffle=True,
    subset='both', # necessario se stiamo utilizzando validation_split (se no darebbe errore)
    seed=0 # necessario se stiamo utilizzando sia shuffle che validation_split (se no darebbe errore)
)

label_names = train_ds.class_names
# Out:
# Found 12933 files belonging to 30 classes.
# Using 7760 files for training.
# Using 5173 files for validation.

# %%
for audios, labels in train_ds:
    print("Forma (shape) audio:", audios.shape)
    print("Forma (shape) classi:", labels.shape)
    break
# Out:
# Forma (shape) audio: (32, 16000, 1)
# Forma (shape) classi: (32,)

# %% [markdown]
# Lo shape dell'audio è di (32, 16000, 1), indicando che ogni file è contenuto in un batch di 32 tensori unidimensionali di lunghezza 16000. Inoltre, lo shape delle classi è anch'esso 32. Questo perché la funzione `tf.keras.utils.audio_dataset_from_directory(directory)` ha il parametro `batch_size` impostato a 32 di default, non avendolo specificato la dimensione è rimasta tale.

# %% [markdown]
# ## Funzioni per processamento dei dati

# %% [markdown]
# Il prossimo step è definire la funzione `squeeze(audio, labels)`, la quale prende come argomenti l'audio e le classi.
#
# Questa funzione serve per rimuovere l'ultimo asse dello shape dai nostri audio. Attualmente, lo shape dei dati è (32, 16000, 1), ma si può eliminare l'ultima dimensione poiché non necessaria. Specificando il parametro **axis=-1** nella funzione `tf.squeeze` la forma dell'audio viene trasformata in (32, 16000).
#
# Eseguiamo questa semplificazione sulla forma del dato poiché rende la fase di processamento dei dati più efficiente.

# %%
def squeeze(audio, labels):
    audio = tf.squeeze(audio, axis=-1)
    return audio, labels

# fonte: funzione presa dal seguente link: https://www.geeksforgeeks.org/audio-recognition-in-tensorflow/

# %%
train_ds = train_ds.map(squeeze, tf.data.AUTOTUNE)
validation_ds = validation_ds.map(squeeze, tf.data.AUTOTUNE)

audio, label = next(iter(train_ds))
print(audio.shape)
print(label.shape)
# Out:
# (32, 16000)
# (32,)

# %% [markdown]
# Una volta eseguito questa semplificazione, a partire dai tensori degli audio, creeremo gli spettrogrammi che sarannò presi come input dal modello convolutivo.

# %% [markdown]
# ## Conversione e suddivisione dataset
# Andremo ad utilizzare due funzioni: `get_spectrogram` e `get_spectrogram_dataset`. Queste due funzioni usate insieme convertono il nostro dataset di audio in un dataset di spettrogrammi. La prima funzione `get_spectrogram` converte il singolo audio in spettrogramma mentre la seconda funzione `get_spectrogram_dataset` richiama la prima funzione per ogni dato presente nel dataset.

# %%
def get_spectrogram(waveform):
    spectrogram = tf.signal.stft(waveform, frame_length=255, frame_step=128)
    spectrogram = tf.abs(spectrogram)

    return spectrogram[..., tf.newaxis]

# fonte: funzione presa dal seguente link: https://www.geeksforgeeks.org/audio-recognition-in-tensorflow/

# %%
def get_spectrogram_dataset(dataset):
    dataset = dataset.map(lambda x, y: (get_spectrogram(x), y), num_parallel_calls=tf.data.AUTOTUNE)

    return dataset

# fonte: funzione presa dal seguente link: https://www.geeksforgeeks.org/audio-recognition-in-tensorflow/

# %% [markdown]
# Definite le due funzioni possiamo procedere a ottenere il nostro **training set**, **validation set**, e **test set** di spettrogrammi. La suddivisione di dati ricordo essere rispettivamente 60%, 20%, 20%.

# %%
train_ds = get_spectrogram_dataset(train_ds)
validation_ds = get_spectrogram_dataset(validation_ds)

val_ds = validation_ds.take(validation_ds.cardinality() // 2) # ho cambiato nome del validation_ds in modo tale da non creare problemi con l'istruzione seguente
test_ds = validation_ds.skip(validation_ds.cardinality() // 2)

# %%
print("Numero di audio training set:", len(train_ds) * 32)
print("Numero di audio validation set:", len(val_ds) * 32)
print("Numero di audio test set:", len(test_ds) * 32)
# Out:
# Numero di audio training set: 7776
# Numero di audio validation set: 2592
# Numero di audio test set: 2592

# %%
for audio, label in train_ds:
    print("Shape (forma) spettrogrammi:", audio.shape)

    spectrogram = np.squeeze(audio[0])
    spectrogram = np.log(spectrogram.T)

    plt.imshow(spectrogram.T)
    plt.colorbar(format='%+2.0f dB') # barra laterale dei dB

    plt.title(f"Classe: {label_names[label[0].numpy()]}")
    break
# Out:
# Shape (forma) spettrogrammi: (32, 124, 129, 1)

# %% [markdown]
# La grandezza degli spettrogrammi, quindi delle immagini ottenute, è di **124x129**.

# %% [markdown]
# ## Creazione modello di base

# %% [markdown]
# Come modello implementiamo una rete neurale convolutiva. Questo modello ha un'architettura semplice e servirà da benchmark per i modelli futuri.
#
# La rete prende in ingresso tensori di forma **altezza x larghezza x canali**, rispettivamente di **124, 129, 1**. Per farlo lavorare meglio, rendiamo le immagini di dimensione quadrata e normalizziamo i dati con la funzione `tf.keras.layers.Normalization()`.

# %% [markdown]
# L'architettura del modello è suddivisa in **due blocchi** principali: un blocco per l'apprendimento delle caratteristiche e un blocco per la classificazione.
#
# Il **blocco di apprendimento delle caratteristiche** ha un'architettura formata da una serie di livelli convolutivi alternati a livelli di max pooling. Per ciascun livello convolutivo viene anche applicata la funzione di attivazione **ReLu** per applicare non linearità. Il blocco termina con un livello convolutivo di **256 filtri**, che corrispondono alla stessa quantità di filtri applicati dal livello convolutivo precedente.
#
# Terminato il blocco di apprendimento delle caratteristiche, è presente il **blocco di classificazione**, formato da un **livello di Flatten**, necessario per trasformare i dati in un vettore unidimensionali, e un **livello Dense**, necessario per la predizione della classe di appartenenza del dato. Quest'ultimo livello Dense ha **30 unità**, che corrispondono alle 30 classi del nostro task di classificazione multiclasse. La funzione di attivazione applicata dal livello Dense è la **softmax**, ideale per i task di classificazione multiclasse.
#
# La funzione **softmax**, a differenza della funzione **sigmoid** ci fornisce una distribuzione di probabilità sulle classi possibili (questa distribuzione saremo in grado di visualizzarla durante la valutazione del modello).

# %%
def get_basic_model():
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(124, 129, 1))
    x = tf.keras.layers.Resizing(120, 120)(inputs)
    x = tf.keras.layers.Normalization()(x)

    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# Nella prossima cella di codice dichiariamo l'**ottimizzatore** da utilizzare (rmsprop), le **metriche** di cui tenere traccia (accuratezza), e la funzione di perdita da utilizzare per il calcolo del gradiente. Nel nostro caso la **funzione di perdita** corrisponde alla `sparse_categorical_crossentropy`, una variante della `categorical_crossentropy`.
#
# La **sparse categorical crossentropy** viene utilizzata quando le classi sono rappresentate come interi, proprio come nel nostro caso.

# %%
basic_model = get_basic_model()
basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

basic_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 124, 129, 1)]     0
#
#  resizing (Resizing)         (None, 120, 120, 1)       0
#
#  normalization (Normalizati  (None, 120, 120, 1)       3
#  on)
#
#  conv2d (Conv2D)             (None, 118, 118, 32)      320
#
#  max_pooling2d (MaxPooling2  (None, 59, 59, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 57, 57, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 28, 28, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 26, 26, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 13, 13, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 256)       295168
#
#  max_pooling2d_3 (MaxPoolin  (None, 5, 5, 256)         0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 3, 3, 256)         590080
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 30)                69150
#
# =================================================================
# Total params: 1047073 (3.99 MB)
# Trainable params: 1047070 (3.99 MB)
# Non-trainable params: 3 (16.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Il modello ha un totale di circa **1 milione di parametri**, bilanciando complessità e capacità di apprendimento.

# %%
basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/basic_model.keras", save_best_only=True, monitor="val_loss")]
basic_model_history = basic_model.fit(train_ds, epochs=30, validation_data=val_ds, callbacks=basic_model_callbacks)
# Out:
# Epoch 1/30
# 243/243 [==============================] - 9s 16ms/step - loss: 2.7447 - accuracy: 0.2236 - val_loss: 1.9970 - val_accuracy: 0.4171
# Epoch 2/30
# 243/243 [==============================] - 3s 12ms/step - loss: 1.4653 - accuracy: 0.5747 - val_loss: 1.2752 - val_accuracy: 0.6389
# Epoch 3/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.9057 - accuracy: 0.7339 - val_loss: 0.9799 - val_accuracy: 0.7303
# Epoch 4/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.6140 - accuracy: 0.8213 - val_loss: 0.8875 - val_accuracy: 0.7708
# Epoch 5/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.4299 - accuracy: 0.8709 - val_loss: 0.8810 - val_accuracy: 0.7913
# Epoch 6/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.3482 - accuracy: 0.8952 - val_loss: 1.0677 - val_accuracy: 0.7454
# Epoch 7/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2966 - accuracy: 0.9095 - val_loss: 1.1138 - val_accuracy: 0.7944
# Epoch 8/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2242 - accuracy: 0.9314 - val_loss: 0.9188 - val_accuracy: 0.7909
# Epoch 9/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2130 - accuracy: 0.9388 - val_loss: 1.0463 - val_accuracy: 0.8005
# Epoch 10/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1765 - accuracy: 0.9460 - val_loss: 1.0442 - val_accuracy: 0.8002
# Epoch 11/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1505 - accuracy: 0.9559 - val_loss: 1.0801 - val_accuracy: 0.8056
# Epoch 12/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1244 - accuracy: 0.9664 - val_loss: 1.0406 - val_accuracy: 0.8206
# Epoch 13/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1105 - accuracy: 0.9678 - val_loss: 0.9941 - val_accuracy: 0.8113
# Epoch 14/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1273 - accuracy: 0.9644 - val_loss: 1.1400 - val_accuracy: 0.8052
# Epoch 15/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1205 - accuracy: 0.9668 - val_loss: 1.2701 - val_accuracy: 0.8225
# Epoch 16/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1138 - accuracy: 0.9711 - val_loss: 1.1306 - val_accuracy: 0.8171
# Epoch 17/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1187 - accuracy: 0.9695 - val_loss: 1.1534 - val_accuracy: 0.8210
# Epoch 18/30
# 243/243 [==============================] - 3s 11ms/step - loss: 0.1044 - accuracy: 0.9728 - val_loss: 1.1505 - val_accuracy: 0.8191
# Epoch 19/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1135 - accuracy: 0.9713 - val_loss: 1.1909 - val_accuracy: 0.8063
# Epoch 20/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0844 - accuracy: 0.9777 - val_loss: 1.3077 - val_accuracy: 0.8102
# Epoch 21/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0886 - accuracy: 0.9755 - val_loss: 1.0713 - val_accuracy: 0.8059
# Epoch 22/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0667 - accuracy: 0.9832 - val_loss: 1.1887 - val_accuracy: 0.8287
# Epoch 23/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0419 - accuracy: 0.9885 - val_loss: 1.3927 - val_accuracy: 0.8241
# Epoch 24/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0609 - accuracy: 0.9839 - val_loss: 1.3926 - val_accuracy: 0.7978
# Epoch 25/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0753 - accuracy: 0.9812 - val_loss: 1.3388 - val_accuracy: 0.7847
# Epoch 26/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1022 - accuracy: 0.9728 - val_loss: 1.4856 - val_accuracy: 0.8175
# Epoch 27/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0629 - accuracy: 0.9847 - val_loss: 1.1533 - val_accuracy: 0.8368
# Epoch 28/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0654 - accuracy: 0.9845 - val_loss: 1.2666 - val_accuracy: 0.8210
# Epoch 29/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0469 - accuracy: 0.9887 - val_loss: 1.2062 - val_accuracy: 0.8326
# Epoch 30/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0377 - accuracy: 0.9893 - val_loss: 1.6303 - val_accuracy: 0.8129

# %% [markdown]
# Alleniamo il modello per 30 epoche e visualizziamo le **curve di addestramento** e **validazione**.

# %%
def create_train_val_plot(history, overfit=True):
    # definisco numero epoche
    epochs = range(1, len(history['accuracy']) + 1)

    # Accuracy
    accuracy = history['accuracy']
    val_accuracy = history['val_accuracy']

    fig_acc, ax_acc = plt.subplots()

    # linea di base
    ax_acc.plot(epochs, [0.5 for x in range(len(epochs))], color="lightgray", linestyle="--", label="Base")
    # linee di accuratezza
    ax_acc.plot(epochs, accuracy, color="slategray", label="Accuratezza in addestramento")
    ax_acc.plot(epochs, val_accuracy, color="indianred", label="Accuratezza in validazione")
    # miglior accuratezza validazione
    ax_acc.axhline(y=max(val_accuracy), c='indianred', alpha=0.7, linestyle='--')
    ax_acc.text(len(epochs) * 1.07, max(val_accuracy), round(max(val_accuracy), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_acc.spines["right"].set_visible(False)
    ax_acc.spines["top"].set_visible(False)
    ax_acc.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_acc.set_title("Accuratezza in addestramento e validazione")
    ax_acc.set_xlabel("Epoche")
    ax_acc.set_ylabel("Accuratezza (%)")
    ax_acc.legend()

    # Loss
    loss = history['loss']
    val_loss = history['val_loss']

    fig_loss, ax_loss = plt.subplots()

    # linee di loss
    ax_loss.plot(epochs, loss, color="slategray", label="Perdita in addestramento")
    ax_loss.plot(epochs, val_loss, color="indianred", label="Perdita in validazione")
    # miglior loss validazione
    ax_loss.axhline(y=min(val_loss), c='indianred', alpha=0.7, linestyle='--')
    ax_loss.text(len(epochs) * 1.07, min(val_loss), round(min(val_loss), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_loss.spines["right"].set_visible(False)
    ax_loss.spines["top"].set_visible(False)
    ax_loss.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_loss.set_title("Perdita in addestramento e validazione")
    ax_loss.set_xlabel("Epoche")
    ax_loss.set_ylabel("Perdita")

    handles, _ = ax_loss.get_legend_handles_labels()

    if overfit:
        # area overfit
        rect = mpatches.Rectangle((np.argmin(val_loss) + 1, 0), width=100 - np.argmin(val_loss), height=max(max(loss), max(val_loss)), color='lightcoral', alpha=0.3)
        ax_loss.add_patch(rect)
        # patch overfit per legenda
        overfit = mpatches.Patch(color='indianred', alpha=0.3, label='Area overfit')
        handles, _ = ax_loss.get_legend_handles_labels()
        handles.append(overfit)

    # legenda
    ax_loss.legend(handles=handles)

    plt.show()

# %%
create_train_val_plot(basic_model_history.history)

# %% [markdown]
# Questi grafici mostrano come il nostro modello sia andato immediatamente in overfitting. L'accuratezza dell'addestramento aumenta col tempo e raggiunge quasi il **100%**, mentre l'accuratezza della validazione si attesta sull'**80%** con un **picco del 86%**. Inoltre, la **perdita nel set di addestramento** continua a diminuire mentre la **perdita nel set di validazione** aumenta.

# %% [markdown]
# Possiamo verificare l'accuratezza della migliore versione del nostro modello di base ricaricando il file **basic_model.keras**.

# %%
best_basic_model = tf.keras.models.load_model("bestmodels/basic_model.keras")
test_loss, test_acc = best_basic_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 8ms/step - loss: 0.9321 - accuracy: 0.7811
# Accuratezza: 0.781

# %% [markdown]
# Abbiamo ottenuto un'**accuratezza** del **82%**! La complessità di questo task è legata fortemente alla **quantità di classi** e alla **dimensione limitata del dataset**. Considerato ciò, il risultato ottenuto non è male.

# %% [markdown]
# Infine, creiamo una funzione utile a visualizzare graficamente la distribuzione di accuratezza delle classi su un'immagine casuale, per capire come ha lavorato il modello. Nel caso il modello non predica correttamente, la **classe corretta** verrà sempre evidenziata di **verde** mentre la **classe predetta** verrà evidenziata di **giallo**.

# %%
def create_distribution_plot(model, audio, label):
    prediction = model(audio) # otteniamo la predizione del modello sull'audio preso in input
    softmax_pred = tf.nn.softmax(prediction[0]) # dobbiamo applicare nuovamente la softmax in modo tale da avere dei dati leggibili
    pred_label = np.argmax(softmax_pred) # ci salviamo l'indice della label predetta dal nostro modello, quella con la probabilità più alta

    colors = ['indianred'] * len(label_names) # creiamo un vettore di lunghezza 30 (la quantità delle nostre label) colorate di rosso

    if pred_label == label[0].numpy(): # se la label che abbiamo predetto è corretta, allora la coloriamo di verde
        colors[pred_label] = 'seagreen'
    else: # se la label che abbiamo predetto è sbagliata, allora coloriamo di verde la corretta e di gialla la predetta
        colors[pred_label] = 'khaki'
        colors[label[0].numpy()] = 'seagreen'

    plt.figure(figsize=(12, 4))

    plt.bar(label_names, softmax_pred.numpy(), color=colors)
    plt.xticks(rotation=45)

    # dichiariamo i colori della legenda
    other_values_patch = mpatches.Patch(color='indianred', label='Altre classi')
    pred_value_patch = mpatches.Patch(color='khaki', label='Classe predetta')
    correct_value_patch = mpatches.Patch(color='green', label='Classe corretta')

    # disegniamo al legenda con i colori necessari
    if pred_label == label[0].numpy(): # se abbiamo predetto correttamente la label, non è necessario mostrare il colore giallo (non è presente nel plot)
        plt.legend(handles=[other_values_patch, correct_value_patch])
    else:
        plt.legend(handles=[other_values_patch, pred_value_patch, correct_value_patch])

    plt.show()

# %%
for audio, label in test_ds: # prendiamo un audio a caso del test e creiamo la distribuzione
    create_distribution_plot(best_basic_model, audio, label)
    break

# %% [markdown]
# Possiamo notare dalla distribuzione che il modello in questo caso ha predetto correttamente la **classe no**. Inoltre possiamo notare che la **classe go** ha qualche punto percentuale in più delle altre, il che ha senso essendo una parola molto simile (ergo uno spettrogramma simile).

# %% [markdown]
# L'overfitting è probabilmente fortemente causato dal fatto che il nostro dataset contiene un numero insufficente di campioni, rendendolo non in grado di generalizzare su dati nuovi. Per migliorare la capacità di generalizzare del modello andremo a creare dei dati artificali con le tecniche di data agumentation.

# %% [markdown]
# ### Risoluzione dell'overfitting
# Abbiamo capito che il modello è andato immediatamente in **overfitting**, e lo possiamo notare dalla loss di validazione che inizia a salire dalla quinta epoca in poi. L'obbiettivo principale in questo momento è evitare che vada in overfitting troppo velocemente, applicando le tecniche viste a lezione.

# %% [markdown]
# Utilizzeremo la tecnica della **data augmentation** per risolvere la grandezza ridotta del dataset, e inoltre applicheremo un **livello di Dropout** al **blocco di classificazione**.

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.1)
    # tf.keras.layers.RandomZoom(0.2) # -> non ci stava dando risultati e aumentava il tempo di training
    # tf.keras.layers.RandomTranslation(height_factor=5/124, width_factor=0)
    # tf.keras.layers.RandomTranslation(height_factor=0, width_factor=5/129)
    # questi ultimi due layer non ci stavano dando risultati e aumentava di molto il tempo di training
    # l'idea era quella di traslare le immagini di 5 pixel per la X e 5 pixel per la Y
])

# %%
def get_improved_basic_model():
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(124, 129, 1))
    x = data_augmentation(inputs)
    x = tf.keras.layers.Resizing(120, 120)(x)
    x = tf.keras.layers.Normalization()(x)

    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
improved_basic_model = get_improved_basic_model()
improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/improved_basic_model.keras", save_best_only=True, monitor="val_loss")]
improved_history = improved_basic_model.fit(train_ds, epochs=100, validation_data=val_ds, callbacks=improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 7s 14ms/step - loss: 3.3168 - accuracy: 0.0651 - val_loss: 3.0180 - val_accuracy: 0.1404
# Epoch 2/100
# 243/243 [==============================] - 4s 14ms/step - loss: 3.0388 - accuracy: 0.1340 - val_loss: 2.9189 - val_accuracy: 0.1867
# Epoch 3/100
# 243/243 [==============================] - 4s 15ms/step - loss: 2.7670 - accuracy: 0.2082 - val_loss: 2.3785 - val_accuracy: 0.3102
# Epoch 4/100
# 243/243 [==============================] - 3s 14ms/step - loss: 2.5177 - accuracy: 0.2755 - val_loss: 2.0439 - val_accuracy: 0.4163
# Epoch 5/100
# 243/243 [==============================] - 3s 14ms/step - loss: 2.2448 - accuracy: 0.3518 - val_loss: 1.7384 - val_accuracy: 0.5008
# Epoch 6/100
# 243/243 [==============================] - 4s 14ms/step - loss: 2.0212 - accuracy: 0.4192 - val_loss: 1.5114 - val_accuracy: 0.5590
# Epoch 7/100
# 243/243 [==============================] - 3s 14ms/step - loss: 1.8526 - accuracy: 0.4593 - val_loss: 1.4779 - val_accuracy: 0.5745
# Epoch 8/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.7224 - accuracy: 0.4954 - val_loss: 1.2607 - val_accuracy: 0.6393
# Epoch 9/100
# 243/243 [==============================] - 3s 14ms/step - loss: 1.6026 - accuracy: 0.5360 - val_loss: 1.1665 - val_accuracy: 0.6609
# Epoch 10/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.5228 - accuracy: 0.5472 - val_loss: 1.1716 - val_accuracy: 0.6628
# Epoch 11/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.4155 - accuracy: 0.5856 - val_loss: 1.0784 - val_accuracy: 0.6856
# Epoch 12/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.3379 - accuracy: 0.6129 - val_loss: 1.0945 - val_accuracy: 0.6825
# Epoch 13/100
# 243/243 [==============================] - 3s 14ms/step - loss: 1.3027 - accuracy: 0.6160 - val_loss: 0.9703 - val_accuracy: 0.7114
# Epoch 14/100
# 243/243 [==============================] - 3s 14ms/step - loss: 1.2260 - accuracy: 0.6352 - val_loss: 1.0585 - val_accuracy: 0.6883
# Epoch 15/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.1935 - accuracy: 0.6436 - val_loss: 0.9435 - val_accuracy: 0.7230
# Epoch 16/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.1333 - accuracy: 0.6590 - val_loss: 1.0293 - val_accuracy: 0.6975
# Epoch 17/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.1038 - accuracy: 0.6691 - val_loss: 0.8999 - val_accuracy: 0.7392
# Epoch 18/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.0595 - accuracy: 0.6832 - val_loss: 0.9163 - val_accuracy: 0.7307
# Epoch 19/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.0606 - accuracy: 0.6787 - val_loss: 0.9076 - val_accuracy: 0.7296
# Epoch 20/100
# 243/243 [==============================] - 3s 14ms/step - loss: 1.0145 - accuracy: 0.6956 - val_loss: 0.8243 - val_accuracy: 0.7643
# Epoch 21/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.9773 - accuracy: 0.7073 - val_loss: 0.8802 - val_accuracy: 0.7527
# Epoch 22/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.9491 - accuracy: 0.7134 - val_loss: 0.8601 - val_accuracy: 0.7477
# Epoch 23/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.9041 - accuracy: 0.7287 - val_loss: 0.8121 - val_accuracy: 0.7704
# Epoch 24/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.9113 - accuracy: 0.7263 - val_loss: 0.8174 - val_accuracy: 0.7708
# Epoch 25/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.8898 - accuracy: 0.7305 - val_loss: 0.8243 - val_accuracy: 0.7728
# Epoch 26/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.8849 - accuracy: 0.7360 - val_loss: 0.7887 - val_accuracy: 0.7728
# Epoch 27/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.8431 - accuracy: 0.7454 - val_loss: 0.8114 - val_accuracy: 0.7643
# Epoch 28/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.8303 - accuracy: 0.7441 - val_loss: 0.8522 - val_accuracy: 0.7674
# Epoch 29/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.8365 - accuracy: 0.7464 - val_loss: 0.8213 - val_accuracy: 0.7650
# Epoch 30/100
# 243/243 [==============================] - 4s 14ms/step - loss: 0.7940 - accuracy: 0.7620 - val_loss: 0.7356 - val_accuracy: 0.7836
# Epoch 31/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.7905 - accuracy: 0.7635 - val_loss: 0.7756 - val_accuracy: 0.7801
# Epoch 32/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.7782 - accuracy: 0.7628 - val_loss: 0.8074 - val_accuracy: 0.7643
# Epoch 33/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.7465 - accuracy: 0.7698 - val_loss: 0.7724 - val_accuracy: 0.7824
# Epoch 34/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.7208 - accuracy: 0.7771 - val_loss: 0.8589 - val_accuracy: 0.7762
# Epoch 35/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.7478 - accuracy: 0.7754 - val_loss: 0.7908 - val_accuracy: 0.7921
# Epoch 36/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.7279 - accuracy: 0.7812 - val_loss: 0.7576 - val_accuracy: 0.7894
# Epoch 37/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.7280 - accuracy: 0.7780 - val_loss: 0.7406 - val_accuracy: 0.7917
# Epoch 38/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.6887 - accuracy: 0.7887 - val_loss: 0.8064 - val_accuracy: 0.7805
# Epoch 39/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.6807 - accuracy: 0.7905 - val_loss: 0.7701 - val_accuracy: 0.7874
# Epoch 40/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.6597 - accuracy: 0.7921 - val_loss: 0.7937 - val_accuracy: 0.7793
# Epoch 41/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.6955 - accuracy: 0.7918 - val_loss: 0.7633 - val_accuracy: 0.7789
# Epoch 42/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.6517 - accuracy: 0.8054 - val_loss: 0.7522 - val_accuracy: 0.7959
# Epoch 43/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.6543 - accuracy: 0.8034 - val_loss: 0.7192 - val_accuracy: 0.8044
# Epoch 44/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.6475 - accuracy: 0.7985 - val_loss: 0.7587 - val_accuracy: 0.8032
# Epoch 45/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.6168 - accuracy: 0.8049 - val_loss: 0.8079 - val_accuracy: 0.7851
# Epoch 46/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.6138 - accuracy: 0.8070 - val_loss: 0.7158 - val_accuracy: 0.8017
# Epoch 47/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.6188 - accuracy: 0.8119 - val_loss: 0.8077 - val_accuracy: 0.7855
# Epoch 48/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.6042 - accuracy: 0.8147 - val_loss: 0.7668 - val_accuracy: 0.7963
# Epoch 49/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.6092 - accuracy: 0.8129 - val_loss: 0.7083 - val_accuracy: 0.8025
# Epoch 50/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.6019 - accuracy: 0.8171 - val_loss: 0.7363 - val_accuracy: 0.8017
# Epoch 51/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5893 - accuracy: 0.8184 - val_loss: 0.7962 - val_accuracy: 0.7805
# Epoch 52/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5767 - accuracy: 0.8227 - val_loss: 0.8181 - val_accuracy: 0.7820
# Epoch 53/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5887 - accuracy: 0.8197 - val_loss: 0.7654 - val_accuracy: 0.7990
# Epoch 54/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5783 - accuracy: 0.8202 - val_loss: 0.7189 - val_accuracy: 0.8094
# Epoch 55/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5657 - accuracy: 0.8235 - val_loss: 0.8526 - val_accuracy: 0.7836
# Epoch 56/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5634 - accuracy: 0.8250 - val_loss: 0.7699 - val_accuracy: 0.7921
# Epoch 57/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5217 - accuracy: 0.8372 - val_loss: 0.7834 - val_accuracy: 0.7963
# Epoch 58/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5443 - accuracy: 0.8353 - val_loss: 0.7747 - val_accuracy: 0.7963
# Epoch 59/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5219 - accuracy: 0.8410 - val_loss: 0.8175 - val_accuracy: 0.7998
# Epoch 60/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5421 - accuracy: 0.8322 - val_loss: 0.7769 - val_accuracy: 0.7963
# Epoch 61/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5267 - accuracy: 0.8362 - val_loss: 0.8641 - val_accuracy: 0.7801
# Epoch 62/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5004 - accuracy: 0.8432 - val_loss: 0.8113 - val_accuracy: 0.8121
# Epoch 63/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5057 - accuracy: 0.8436 - val_loss: 0.8242 - val_accuracy: 0.8009
# Epoch 64/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5066 - accuracy: 0.8436 - val_loss: 0.8464 - val_accuracy: 0.7901
# Epoch 65/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5103 - accuracy: 0.8437 - val_loss: 0.7853 - val_accuracy: 0.8075
# Epoch 66/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5079 - accuracy: 0.8441 - val_loss: 0.8093 - val_accuracy: 0.8005
# Epoch 67/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5070 - accuracy: 0.8427 - val_loss: 0.7828 - val_accuracy: 0.7932
# Epoch 68/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4893 - accuracy: 0.8501 - val_loss: 0.7669 - val_accuracy: 0.8048
# Epoch 69/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4970 - accuracy: 0.8448 - val_loss: 0.7606 - val_accuracy: 0.8036
# Epoch 70/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.4868 - accuracy: 0.8430 - val_loss: 0.7864 - val_accuracy: 0.8013
# Epoch 71/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4860 - accuracy: 0.8492 - val_loss: 1.0023 - val_accuracy: 0.7870
# Epoch 72/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4743 - accuracy: 0.8540 - val_loss: 0.8222 - val_accuracy: 0.8005
# Epoch 73/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4859 - accuracy: 0.8519 - val_loss: 0.7458 - val_accuracy: 0.8202
# Epoch 74/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4586 - accuracy: 0.8589 - val_loss: 0.8280 - val_accuracy: 0.7897
# Epoch 75/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.5027 - accuracy: 0.8459 - val_loss: 0.8344 - val_accuracy: 0.7874
# Epoch 76/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4622 - accuracy: 0.8562 - val_loss: 0.7607 - val_accuracy: 0.7990
# Epoch 77/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4682 - accuracy: 0.8585 - val_loss: 0.7469 - val_accuracy: 0.8075
# Epoch 78/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.4490 - accuracy: 0.8631 - val_loss: 0.8210 - val_accuracy: 0.7986
# Epoch 79/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4616 - accuracy: 0.8576 - val_loss: 0.8347 - val_accuracy: 0.7959
# Epoch 80/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.4516 - accuracy: 0.8552 - val_loss: 0.7925 - val_accuracy: 0.8044
# Epoch 81/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.4354 - accuracy: 0.8670 - val_loss: 0.7748 - val_accuracy: 0.8017
# Epoch 82/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4420 - accuracy: 0.8571 - val_loss: 0.8271 - val_accuracy: 0.8059
# Epoch 83/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4130 - accuracy: 0.8719 - val_loss: 0.8875 - val_accuracy: 0.7967
# Epoch 84/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4477 - accuracy: 0.8653 - val_loss: 0.7988 - val_accuracy: 0.8040
# Epoch 85/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4664 - accuracy: 0.8550 - val_loss: 0.8588 - val_accuracy: 0.7978
# Epoch 86/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4303 - accuracy: 0.8669 - val_loss: 0.8130 - val_accuracy: 0.7940
# Epoch 87/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4279 - accuracy: 0.8697 - val_loss: 0.7870 - val_accuracy: 0.8048
# Epoch 88/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4273 - accuracy: 0.8662 - val_loss: 0.7889 - val_accuracy: 0.8125
# Epoch 89/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4054 - accuracy: 0.8759 - val_loss: 0.7711 - val_accuracy: 0.8071
# Epoch 90/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4416 - accuracy: 0.8640 - val_loss: 0.8761 - val_accuracy: 0.7901
# Epoch 91/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4439 - accuracy: 0.8651 - val_loss: 0.8136 - val_accuracy: 0.8048
# Epoch 92/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4158 - accuracy: 0.8710 - val_loss: 0.8105 - val_accuracy: 0.8032
# Epoch 93/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4045 - accuracy: 0.8729 - val_loss: 0.8670 - val_accuracy: 0.7998
# Epoch 94/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4274 - accuracy: 0.8661 - val_loss: 0.8264 - val_accuracy: 0.7886
# Epoch 95/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4357 - accuracy: 0.8643 - val_loss: 0.9016 - val_accuracy: 0.7990
# Epoch 96/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4112 - accuracy: 0.8702 - val_loss: 0.8635 - val_accuracy: 0.7986
# Epoch 97/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.3959 - accuracy: 0.8800 - val_loss: 0.8102 - val_accuracy: 0.7967
# Epoch 98/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.3998 - accuracy: 0.8785 - val_loss: 0.8891 - val_accuracy: 0.7901
# Epoch 99/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.3959 - accuracy: 0.8803 - val_loss: 0.8046 - val_accuracy: 0.8025
# Epoch 100/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.3936 - accuracy: 0.8805 - val_loss: 0.8543 - val_accuracy: 0.7998

# %%
create_train_val_plot(improved_history.history)

# %% [markdown]
# Alleniamo il modello per 100 epoche (dobbiamo dargli più tempo per apprendere, 30 epoche non sarebbero bastate) e visualizziamo le **curve di addestramento** e **validazione**.
#
# L'obbiettivo di ridurre **l'overfitting è stato comunque raggiunto**, dato che il modello ha iniziato ad andare in overfitting verso **l'epoca 30**.

# %%
improved_best_model = tf.keras.models.load_model("bestmodels/improved_basic_model.keras")
test_loss, test_acc = improved_best_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 6ms/step - loss: 0.7446 - accuracy: 0.7888
# Accuratezza: 0.789

# %% [markdown]
# In questo caso non abbiamo ottenuto alcun tipo di miglioramento a livello di prestazioni, anzi è peggiorato!

# %%
for audio, label in test_ds:
    create_distribution_plot(improved_best_model, audio, label)
    break

# %% [markdown]
# In questo caso il modello era molto più indeciso di prima. Il modello aveva intuito potesse essere un audio con **classe no** ma era convinto fosse invece la **classe go**.

# %% [markdown]
# ## Miglioramenti all'architettura del modello
#
# Durante il corso abbiamo visto anche delle best practice architetturali che possono aiutare a ottenere maggiori prestazioni col modello. Il nostro scopo è provare le tecniche viste e studiate durante il corso e capire come reagiscono al task.

# %% [markdown]
# Le tre tecniche che andremo ad applicare sono:
# - blocchi residuali
# - normalizzazione dei batch
# - convoluzioni separabili

# %% [markdown]
# ### Blocchi residuali
# I blocchi residuali sono un'applicazione efficace quando riscontriamo il problema dei **gradienti che svaniscono**. Non sono una tecnica strettamente legata ai modelli convolutivi, ma sono una best practice generale che viene applicare nella maggior parte delle architetture.
#
# I **gradienti che vaniscono** sono causati dalle **catene di funzioni troppo lunghe**, che nel nostro caso non sono altro che **una sequenza di livelli convolutivi**. Per ogni livello convolutivo **una certa quantità di rumore** viene introdotta, finché essa non arriva a **sopraffare** le informazioni sul gradiente.
#
# Se le informazioni sul gradiente sono sopraffatte la **backpropagation smette di funzionare**, e quindi il nostro **modello non impara**.

# %% [markdown]
# L'**idea basilare** dietro ai blocchi residuali è quella di **salvare l'informazione** contenuta nell'input precedente al livello convolutivo, e **sommarla all'output** dello stesso livello convolutivo.

# %% [markdown]
# Per applicare i blocchi residuali abbiamo implementato la funzione `residual_block(x, filters, pooling=False)` vista a lezione. La funzione è ovviamente adattata al modello da noi implementato, e utilizza le altre due best practice citate precedentemente.

# %%
def residual_block(x, filters, pooling=False):
    residual = x

    x = tf.keras.layers.SeparableConv2D(filters, 3, padding="same", use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    if pooling:
      x = tf.keras.layers.MaxPooling2D(pool_size=2, padding="same")(x)
      residual = tf.keras.layers.Conv2D(filters, 1, strides=2)(residual)
    elif filters != residual.shape[-1]:
      residual = tf.keras.layers.Conv2D(filters, 1)(residual)

    x = tf.keras.layers.add([x, residual])
    return x

# %% [markdown]
# ### Normalizzazione dei batch e convoluzioni separabili
# La **normalizzazione dei batch** è un concetto che abbiamo già affrontato nel notebook, infatti il suo scopo rimane quello di rendere i dati **più simili tra loro** centrandoli sullo zero, e ciò aiuta la **propagazione del gradiente**. Questa normalizzazione, a differenza della precedente, è in grado di normalizzare i dati in modo adattivo anche quando la media e la varianza cambiano durante l'addestramento.

# %% [markdown]
# Le **convoluzione separabili** invece sono un **sostituto** ai livelli convolutivi utilizzati fino ad adesso, e offrono un modello con maggiori prestazioni e meno parametri.

# %%
def bp_basic_model():
    # input e pre processamento
    inputs = tf.keras.Input(shape=(124, 129, 1))
    x = data_augmentation(inputs)
    x = tf.keras.layers.Resizing(120, 120)(x)

    x = residual_block(x, 32, pooling=True)
    x = residual_block(x, 64, pooling=True)
    x = residual_block(x, 128, pooling=True)
    x = residual_block(x, 256, pooling=True)
    x = residual_block(x, 256, pooling=False)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Livelli per la classificazione
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
bp_basic_model = bp_basic_model()
bp_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

bp_basic_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 124, 129, 1)]        0         []
#
#  sequential (Sequential)     (None, None, 129, 1)         0         ['input_3[0][0]']
#
#  resizing_2 (Resizing)       (None, 120, 120, 1)          0         ['sequential[1][0]']
#
#  separable_conv2d (Separabl  (None, 120, 120, 32)         41        ['resizing_2[0][0]']
#  eConv2D)
#
#  batch_normalization (Batch  (None, 120, 120, 32)         128       ['separable_conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 120, 120, 32)         0         ['batch_normalization[0][0]']
#
#  max_pooling2d_8 (MaxPoolin  (None, 60, 60, 32)           0         ['activation[0][0]']
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 60, 60, 32)           64        ['resizing_2[0][0]']
#
#  add (Add)                   (None, 60, 60, 32)           0         ['max_pooling2d_8[0][0]',
#                                                                      'conv2d_10[0][0]']
#
#  separable_conv2d_1 (Separa  (None, 60, 60, 64)           2336      ['add[0][0]']
#  bleConv2D)
#
#  batch_normalization_1 (Bat  (None, 60, 60, 64)           256       ['separable_conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 60, 60, 64)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d_9 (MaxPoolin  (None, 30, 30, 64)           0         ['activation_1[0][0]']
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 30, 30, 64)           2112      ['add[0][0]']
#
#  add_1 (Add)                 (None, 30, 30, 64)           0         ['max_pooling2d_9[0][0]',
#                                                                      'conv2d_11[0][0]']
#
#  separable_conv2d_2 (Separa  (None, 30, 30, 128)          8768      ['add_1[0][0]']
#  bleConv2D)
#
#  batch_normalization_2 (Bat  (None, 30, 30, 128)          512       ['separable_conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 30, 30, 128)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d_10 (MaxPooli  (None, 15, 15, 128)          0         ['activation_2[0][0]']
#  ng2D)
#
#  conv2d_12 (Conv2D)          (None, 15, 15, 128)          8320      ['add_1[0][0]']
#
#  add_2 (Add)                 (None, 15, 15, 128)          0         ['max_pooling2d_10[0][0]',
#                                                                      'conv2d_12[0][0]']
#
#  separable_conv2d_3 (Separa  (None, 15, 15, 256)          33920     ['add_2[0][0]']
#  bleConv2D)
#
#  batch_normalization_3 (Bat  (None, 15, 15, 256)          1024      ['separable_conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 15, 15, 256)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling2d_11 (MaxPooli  (None, 8, 8, 256)            0         ['activation_3[0][0]']
#  ng2D)
#
#  conv2d_13 (Conv2D)          (None, 8, 8, 256)            33024     ['add_2[0][0]']
#
#  add_3 (Add)                 (None, 8, 8, 256)            0         ['max_pooling2d_11[0][0]',
#                                                                      'conv2d_13[0][0]']
#
#  separable_conv2d_4 (Separa  (None, 8, 8, 256)            67840     ['add_3[0][0]']
#  bleConv2D)
#
#  batch_normalization_4 (Bat  (None, 8, 8, 256)            1024      ['separable_conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 8, 8, 256)            0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  add_4 (Add)                 (None, 8, 8, 256)            0         ['activation_4[0][0]',
#                                                                      'add_3[0][0]']
#
#  global_average_pooling2d (  (None, 256)                  0         ['add_4[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 256)                  0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense_2 (Dense)             (None, 30)                   7710      ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 167079 (652.65 KB)
# Trainable params: 165607 (646.90 KB)
# Non-trainable params: 1472 (5.75 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# Le best practice, insieme al `tf.keras.layers.GlobalAveragePooling2D()` applicato al posto del Flatten, hanno formato un modello con circa **160000 parametri addestrabili** (circa il 16% del modello precedente).

# %%
bp_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/bp_basic_model.keras", save_best_only=True, monitor="val_loss")]
bp_model_history = bp_basic_model.fit(train_ds, epochs=100, validation_data=val_ds, callbacks=bp_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 12s 25ms/step - loss: 3.4883 - accuracy: 0.0543 - val_loss: 3.3974 - val_accuracy: 0.0347
# Epoch 2/100
# 243/243 [==============================] - 5s 19ms/step - loss: 3.2296 - accuracy: 0.0997 - val_loss: 3.1143 - val_accuracy: 0.1277
# Epoch 3/100
# 243/243 [==============================] - 5s 19ms/step - loss: 3.0938 - accuracy: 0.1284 - val_loss: 2.9371 - val_accuracy: 0.1690
# Epoch 4/100
# 243/243 [==============================] - 5s 19ms/step - loss: 3.0038 - accuracy: 0.1539 - val_loss: 3.0639 - val_accuracy: 0.1250
# Epoch 5/100
# 243/243 [==============================] - 5s 19ms/step - loss: 2.9092 - accuracy: 0.1738 - val_loss: 2.7159 - val_accuracy: 0.2423
# Epoch 6/100
# 243/243 [==============================] - 5s 19ms/step - loss: 2.8019 - accuracy: 0.2010 - val_loss: 2.6679 - val_accuracy: 0.2512
# Epoch 7/100
# 243/243 [==============================] - 5s 19ms/step - loss: 2.6877 - accuracy: 0.2295 - val_loss: 2.5744 - val_accuracy: 0.2789
# Epoch 8/100
# 243/243 [==============================] - 5s 19ms/step - loss: 2.5752 - accuracy: 0.2732 - val_loss: 2.3444 - val_accuracy: 0.3291
# Epoch 9/100
# 243/243 [==============================] - 5s 19ms/step - loss: 2.4677 - accuracy: 0.2929 - val_loss: 2.9052 - val_accuracy: 0.2064
# Epoch 10/100
# 243/243 [==============================] - 5s 19ms/step - loss: 2.3717 - accuracy: 0.3182 - val_loss: 2.0703 - val_accuracy: 0.4255
# Epoch 11/100
# 243/243 [==============================] - 5s 19ms/step - loss: 2.2360 - accuracy: 0.3633 - val_loss: 2.0036 - val_accuracy: 0.4086
# Epoch 12/100
# 243/243 [==============================] - 5s 19ms/step - loss: 2.1432 - accuracy: 0.3897 - val_loss: 1.8638 - val_accuracy: 0.4387
# Epoch 13/100
# 243/243 [==============================] - 5s 19ms/step - loss: 2.0603 - accuracy: 0.4138 - val_loss: 2.0089 - val_accuracy: 0.4329
# Epoch 14/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.9718 - accuracy: 0.4302 - val_loss: 2.1935 - val_accuracy: 0.3835
# Epoch 15/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.9087 - accuracy: 0.4594 - val_loss: 1.8439 - val_accuracy: 0.4672
# Epoch 16/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.8164 - accuracy: 0.4798 - val_loss: 1.9436 - val_accuracy: 0.4336
# Epoch 17/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.7618 - accuracy: 0.4894 - val_loss: 1.4244 - val_accuracy: 0.5880
# Epoch 18/100
# 243/243 [==============================] - 5s 18ms/step - loss: 1.7224 - accuracy: 0.5143 - val_loss: 1.7168 - val_accuracy: 0.5220
# Epoch 19/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.6745 - accuracy: 0.5229 - val_loss: 1.8382 - val_accuracy: 0.4807
# Epoch 20/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.6233 - accuracy: 0.5293 - val_loss: 1.4381 - val_accuracy: 0.5698
# Epoch 21/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.5837 - accuracy: 0.5509 - val_loss: 1.2718 - val_accuracy: 0.6296
# Epoch 22/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.5708 - accuracy: 0.5478 - val_loss: 1.4726 - val_accuracy: 0.5644
# Epoch 23/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.5047 - accuracy: 0.5733 - val_loss: 1.2174 - val_accuracy: 0.6462
# Epoch 24/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.4806 - accuracy: 0.5800 - val_loss: 1.3681 - val_accuracy: 0.6088
# Epoch 25/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.4606 - accuracy: 0.5796 - val_loss: 1.4062 - val_accuracy: 0.5787
# Epoch 26/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.4075 - accuracy: 0.5942 - val_loss: 1.6063 - val_accuracy: 0.5513
# Epoch 27/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.3821 - accuracy: 0.6035 - val_loss: 1.3631 - val_accuracy: 0.6096
# Epoch 28/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.3698 - accuracy: 0.6055 - val_loss: 1.1712 - val_accuracy: 0.6632
# Epoch 29/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.3376 - accuracy: 0.6138 - val_loss: 1.1100 - val_accuracy: 0.6728
# Epoch 30/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.3176 - accuracy: 0.6202 - val_loss: 1.4725 - val_accuracy: 0.5556
# Epoch 31/100
# 243/243 [==============================] - 5s 18ms/step - loss: 1.2968 - accuracy: 0.6171 - val_loss: 1.1286 - val_accuracy: 0.6605
# Epoch 32/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.2850 - accuracy: 0.6278 - val_loss: 1.1507 - val_accuracy: 0.6601
# Epoch 33/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.2549 - accuracy: 0.6340 - val_loss: 1.0872 - val_accuracy: 0.6775
# Epoch 34/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.2572 - accuracy: 0.6376 - val_loss: 1.5650 - val_accuracy: 0.5891
# Epoch 35/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.2091 - accuracy: 0.6388 - val_loss: 1.1696 - val_accuracy: 0.6586
# Epoch 36/100
# 243/243 [==============================] - 5s 18ms/step - loss: 1.2163 - accuracy: 0.6487 - val_loss: 1.2013 - val_accuracy: 0.6501
# Epoch 37/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.1722 - accuracy: 0.6594 - val_loss: 1.2591 - val_accuracy: 0.6412
# Epoch 38/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.1566 - accuracy: 0.6648 - val_loss: 1.0089 - val_accuracy: 0.7118
# Epoch 39/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.1470 - accuracy: 0.6674 - val_loss: 1.0952 - val_accuracy: 0.6786
# Epoch 40/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.1349 - accuracy: 0.6764 - val_loss: 1.3992 - val_accuracy: 0.5872
# Epoch 41/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.1084 - accuracy: 0.6772 - val_loss: 1.3118 - val_accuracy: 0.6258
# Epoch 42/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.1168 - accuracy: 0.6787 - val_loss: 1.3969 - val_accuracy: 0.6215
# Epoch 43/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.0912 - accuracy: 0.6844 - val_loss: 1.4486 - val_accuracy: 0.5930
# Epoch 44/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.0986 - accuracy: 0.6830 - val_loss: 1.4910 - val_accuracy: 0.5822
# Epoch 45/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.0765 - accuracy: 0.6901 - val_loss: 1.5190 - val_accuracy: 0.5787
# Epoch 46/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.0550 - accuracy: 0.6939 - val_loss: 1.2496 - val_accuracy: 0.6624
# Epoch 47/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.0284 - accuracy: 0.6976 - val_loss: 1.3078 - val_accuracy: 0.6030
# Epoch 48/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.0510 - accuracy: 0.6959 - val_loss: 1.6215 - val_accuracy: 0.5876
# Epoch 49/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.0395 - accuracy: 0.7019 - val_loss: 1.1117 - val_accuracy: 0.6763
# Epoch 50/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.0310 - accuracy: 0.6945 - val_loss: 1.0872 - val_accuracy: 0.6871
# Epoch 51/100
# 243/243 [==============================] - 5s 19ms/step - loss: 1.0379 - accuracy: 0.6947 - val_loss: 1.2982 - val_accuracy: 0.6277
# Epoch 52/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.9883 - accuracy: 0.7144 - val_loss: 1.0335 - val_accuracy: 0.7037
# Epoch 53/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.9960 - accuracy: 0.7177 - val_loss: 1.5014 - val_accuracy: 0.5833
# Epoch 54/100
# 243/243 [==============================] - 5s 18ms/step - loss: 0.9824 - accuracy: 0.7142 - val_loss: 1.1166 - val_accuracy: 0.6836
# Epoch 55/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.9816 - accuracy: 0.7128 - val_loss: 1.5865 - val_accuracy: 0.5583
# Epoch 56/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.9705 - accuracy: 0.7224 - val_loss: 1.3100 - val_accuracy: 0.6327
# Epoch 57/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.9477 - accuracy: 0.7242 - val_loss: 0.9571 - val_accuracy: 0.7292
# Epoch 58/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.9652 - accuracy: 0.7213 - val_loss: 1.1523 - val_accuracy: 0.6667
# Epoch 59/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.9535 - accuracy: 0.7201 - val_loss: 1.1253 - val_accuracy: 0.6910
# Epoch 60/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.9339 - accuracy: 0.7284 - val_loss: 0.9044 - val_accuracy: 0.7411
# Epoch 61/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.9419 - accuracy: 0.7298 - val_loss: 1.1149 - val_accuracy: 0.6798
# Epoch 62/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.9162 - accuracy: 0.7327 - val_loss: 1.7424 - val_accuracy: 0.5509
# Epoch 63/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.9233 - accuracy: 0.7302 - val_loss: 1.2400 - val_accuracy: 0.6308
# Epoch 64/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.9194 - accuracy: 0.7345 - val_loss: 1.1744 - val_accuracy: 0.6779
# Epoch 65/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.8787 - accuracy: 0.7445 - val_loss: 1.0689 - val_accuracy: 0.6941
# Epoch 66/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.8982 - accuracy: 0.7347 - val_loss: 1.0450 - val_accuracy: 0.7002
# Epoch 67/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.8852 - accuracy: 0.7427 - val_loss: 1.2517 - val_accuracy: 0.6659
# Epoch 68/100
# 243/243 [==============================] - 5s 20ms/step - loss: 0.8881 - accuracy: 0.7424 - val_loss: 0.8165 - val_accuracy: 0.7643
# Epoch 69/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.8657 - accuracy: 0.7494 - val_loss: 1.2869 - val_accuracy: 0.6424
# Epoch 70/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.8686 - accuracy: 0.7412 - val_loss: 0.9417 - val_accuracy: 0.7296
# Epoch 71/100
# 243/243 [==============================] - 5s 18ms/step - loss: 0.8618 - accuracy: 0.7488 - val_loss: 1.0743 - val_accuracy: 0.6836
# Epoch 72/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.8739 - accuracy: 0.7470 - val_loss: 1.2723 - val_accuracy: 0.6508
# Epoch 73/100
# 243/243 [==============================] - 5s 18ms/step - loss: 0.8561 - accuracy: 0.7441 - val_loss: 1.0455 - val_accuracy: 0.6991
# Epoch 74/100
# 243/243 [==============================] - 5s 18ms/step - loss: 0.8399 - accuracy: 0.7463 - val_loss: 0.9044 - val_accuracy: 0.7261
# Epoch 75/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.8148 - accuracy: 0.7598 - val_loss: 1.2782 - val_accuracy: 0.6543
# Epoch 76/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.8340 - accuracy: 0.7616 - val_loss: 0.8604 - val_accuracy: 0.7519
# Epoch 77/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.8057 - accuracy: 0.7657 - val_loss: 0.9312 - val_accuracy: 0.7400
# Epoch 78/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.8381 - accuracy: 0.7549 - val_loss: 0.9237 - val_accuracy: 0.7357
# Epoch 79/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.8057 - accuracy: 0.7608 - val_loss: 0.9293 - val_accuracy: 0.7357
# Epoch 80/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.8145 - accuracy: 0.7546 - val_loss: 1.1776 - val_accuracy: 0.6640
# Epoch 81/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.8091 - accuracy: 0.7608 - val_loss: 1.5156 - val_accuracy: 0.5934
# Epoch 82/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.8022 - accuracy: 0.7571 - val_loss: 2.4167 - val_accuracy: 0.4765
# Epoch 83/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.8075 - accuracy: 0.7640 - val_loss: 0.9210 - val_accuracy: 0.7357
# Epoch 84/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.7700 - accuracy: 0.7689 - val_loss: 0.8834 - val_accuracy: 0.7400
# Epoch 85/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.7856 - accuracy: 0.7642 - val_loss: 1.0856 - val_accuracy: 0.6883
# Epoch 86/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.7799 - accuracy: 0.7680 - val_loss: 1.2225 - val_accuracy: 0.6713
# Epoch 87/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.7701 - accuracy: 0.7711 - val_loss: 1.2288 - val_accuracy: 0.7002
# Epoch 88/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.7588 - accuracy: 0.7751 - val_loss: 0.8700 - val_accuracy: 0.7562
# Epoch 89/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.7683 - accuracy: 0.7765 - val_loss: 1.4315 - val_accuracy: 0.6393
# Epoch 90/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.7704 - accuracy: 0.7716 - val_loss: 2.2233 - val_accuracy: 0.5220
# Epoch 91/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.7664 - accuracy: 0.7742 - val_loss: 0.8805 - val_accuracy: 0.7562
# Epoch 92/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.7549 - accuracy: 0.7765 - val_loss: 1.3284 - val_accuracy: 0.6354
# Epoch 93/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.7429 - accuracy: 0.7802 - val_loss: 1.4991 - val_accuracy: 0.6292
# Epoch 94/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.7432 - accuracy: 0.7776 - val_loss: 0.9239 - val_accuracy: 0.7330
# Epoch 95/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.7496 - accuracy: 0.7844 - val_loss: 1.6942 - val_accuracy: 0.6096
# Epoch 96/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.7436 - accuracy: 0.7838 - val_loss: 1.9305 - val_accuracy: 0.5610
# Epoch 97/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.7255 - accuracy: 0.7871 - val_loss: 0.9417 - val_accuracy: 0.7353
# Epoch 98/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.7330 - accuracy: 0.7818 - val_loss: 0.8707 - val_accuracy: 0.7473
# Epoch 99/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.7322 - accuracy: 0.7821 - val_loss: 1.0491 - val_accuracy: 0.7126
# Epoch 100/100
# 243/243 [==============================] - 5s 19ms/step - loss: 0.7238 - accuracy: 0.7899 - val_loss: 1.3106 - val_accuracy: 0.6431

# %%
create_train_val_plot(bp_model_history.history, overfit=False)

# %% [markdown]
# Possiamo notare che il modello **NON ha raggiunto l'overfitting**, infatti probabilmente 100 epoche di addestramento erano troppo poche. La **loss della validazione** stava continuando a scendere, e allo stesso tempo **l'accuratezza della validazione era crescente**.

# %%
best_bp_basic_model = tf.keras.models.load_model("bestmodels/bp_basic_model.keras")
test_loss, test_acc = best_bp_basic_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 8ms/step - loss: 0.7903 - accuracy: 0.7741
# Accuratezza: 0.774

# %% [markdown]
# Non abbiamo ottenuto miglioramenti a livello di prestazioni rispetto al primo modello presentato, però ci siamo avvicinati molto con il **16% dei parametri**

# %%
for audio, label in test_ds:
    create_distribution_plot(best_bp_basic_model, audio, label)
    break

# %% [markdown]
# La decisione del modello in questo caso è nuovamente molto chiara.
