# %% [markdown]
# # Modello convolutivo di base
# Lo scopo di questo notebook è creare un **modello convolutivo di base** con un'architettura semplice. In seguito, sarà interessante confrontare i risultati di questo primo modello con i risultati ottenuti da modelli più complessi, o pre addestrati.

# %% [markdown]
# Come al solito, si procede con l'importazione delle librerie utilizzate e la creazione dei set di allenamento e validazione.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import os

# %%
train_ds, validation_ds = tf.keras.utils.audio_dataset_from_directory(
    directory='../reduced_dataset/dataset/audio',
    validation_split=0.4, # stiamo mettendo da parte il 40% del dataset, che sarà suddiviso in validation set e test set
    shuffle=True,
    subset='both', # necessario se stiamo utilizzando validation_split (se no darebbe errore)
    seed=0 # necessario se stiamo utilizzando sia shuffle che validation_split (se no darebbe errore)
)

label_names = train_ds.class_names
# Out:
# Found 12933 files belonging to 30 classes.
# Using 7760 files for training.
# Using 5173 files for validation.

# %%
for audios, labels in train_ds:
    print("Forma (shape) audio:", audios.shape)
    print("Forma (shape) classi:", labels.shape)
    break
# Out:
# Forma (shape) audio: (32, 16000, 1)
# Forma (shape) classi: (32,)

# %% [markdown]
# Lo shape dell'audio è di (32, 16000, 1), indicando che ogni file è contenuto in un batch di 32 tensori unidimensionali di lunghezza 16000. Inoltre, lo shape delle classi è anch'esso 32. Questo perché la funzione `tf.keras.utils.audio_dataset_from_directory(directory)` ha il parametro `batch_size` impostato a 32 di default, non avendolo specificato la dimensione è rimasta tale.

# %% [markdown]
# ## Funzioni per processamento dei dati

# %% [markdown]
# Il prossimo step è definire la funzione `squeeze(audio, labels)`, la quale prende come argomenti l'audio e le classi.
#
# Questa funzione serve per rimuovere l'ultimo asse dello shape dai nostri audio. Attualmente, lo shape dei dati è (32, 16000, 1), ma si può eliminare l'ultima dimensione poiché non necessaria. Specificando il parametro **axis=-1** nella funzione `tf.squeeze` la forma dell'audio viene trasformata in (32, 16000).
#
# Eseguiamo questa semplificazione sulla forma del dato poiché rende la fase di processamento dei dati più efficiente.

# %%
def squeeze(audio, labels):
    audio = tf.squeeze(audio, axis=-1)
    return audio, labels

# fonte: funzione presa dal seguente link: https://www.geeksforgeeks.org/audio-recognition-in-tensorflow/

# %%
train_ds = train_ds.map(squeeze, tf.data.AUTOTUNE)
validation_ds = validation_ds.map(squeeze, tf.data.AUTOTUNE)

audio, label = next(iter(train_ds))
print(audio.shape)
print(label.shape)
# Out:
# (32, 16000)
# (32,)

# %% [markdown]
# Una volta eseguito questa semplificazione, a partire dai tensori degli audio, creeremo gli spettrogrammi che sarannò presi come input dal modello convolutivo.

# %% [markdown]
# ## Conversione e suddivisione dataset
# Andremo ad utilizzare due funzioni: `get_spectrogram` e `get_spectrogram_dataset`. Queste due funzioni usate insieme convertono il nostro dataset di audio in un dataset di spettrogrammi. La prima funzione `get_spectrogram` converte il singolo audio in spettrogramma mentre la seconda funzione `get_spectrogram_dataset` richiama la prima funzione per ogni dato presente nel dataset.

# %%
def get_spectrogram(waveform):
    spectrogram = tf.signal.stft(waveform, frame_length=255, frame_step=128)
    spectrogram = tf.abs(spectrogram)

    return spectrogram[..., tf.newaxis]

# fonte: funzione presa dal seguente link: https://www.geeksforgeeks.org/audio-recognition-in-tensorflow/

# %%
def get_spectrogram_dataset(dataset):
    dataset = dataset.map(lambda x, y: (get_spectrogram(x), y), num_parallel_calls=tf.data.AUTOTUNE)

    return dataset

# fonte: funzione presa dal seguente link: https://www.geeksforgeeks.org/audio-recognition-in-tensorflow/

# %% [markdown]
# Definite le due funzioni possiamo procedere a ottenere il nostro **training set**, **validation set**, e **test set** di spettrogrammi. La suddivisione di dati ricordo essere rispettivamente 60%, 20%, 20%.

# %%
train_ds = get_spectrogram_dataset(train_ds)
validation_ds = get_spectrogram_dataset(validation_ds)

val_ds = validation_ds.take(validation_ds.cardinality() // 2) # ho cambiato nome del validation_ds in modo tale da non creare problemi con l'istruzione seguente
test_ds = validation_ds.skip(validation_ds.cardinality() // 2)

# %%
print("Numero di audio training set:", len(train_ds) * 32)
print("Numero di audio validation set:", len(val_ds) * 32)
print("Numero di audio test set:", len(test_ds) * 32)
# Out:
# Numero di audio training set: 7776
# Numero di audio validation set: 2592
# Numero di audio test set: 2592

# %%
for audio, label in train_ds:
    print("Shape (forma) spettrogrammi:", audio.shape)

    spectrogram = np.squeeze(audio[0])
    spectrogram = np.log(spectrogram.T)

    plt.imshow(spectrogram.T)
    plt.colorbar(format='%+2.0f dB') # barra laterale dei dB

    plt.title(f"Classe: {label_names[label[0].numpy()]}")
    break
# Out:
# Shape (forma) spettrogrammi: (32, 124, 129, 1)

# %% [markdown]
# La grandezza degli spettrogrammi, quindi delle immagini ottenute, è di **124x129**.

# %% [markdown]
# ## Creazione modello di base

# %% [markdown]
# Come modello implementiamo una rete neurale convolutiva. Questo modello ha un'architettura semplice e servirà da benchmark per i modelli futuri.
#
# La rete prende in ingresso tensori di forma **altezza x larghezza x canali**, rispettivamente di **124, 129, 1**. Per farlo lavorare meglio, rendiamo le immagini di dimensione quadrata e normalizziamo i dati con la funzione `tf.keras.layers.Normalization()`.

# %% [markdown]
# L'architettura del modello è suddivisa in **due blocchi** principali: un blocco per l'apprendimento delle caratteristiche e un blocco per la classificazione.
#
# Il **blocco di apprendimento delle caratteristiche** ha un'architettura formata da una serie di livelli convolutivi alternati a livelli di max pooling. Per ciascun livello convolutivo viene anche applicata la funzione di attivazione **ReLu** per applicare non linearità. Il blocco termina con un livello convolutivo di **256 filtri**, che corrispondono alla stessa quantità di filtri applicati dal livello convolutivo precedente.
#
# Terminato il blocco di apprendimento delle caratteristiche, è presente il **blocco di classificazione**, formato da un **livello di Flatten**, necessario per trasformare i dati in un vettore unidimensionali, e un **livello Dense**, necessario per la predizione della classe di appartenenza del dato. Quest'ultimo livello Dense ha **30 unità**, che corrispondono alle 30 classi del nostro task di classificazione multiclasse. La funzione di attivazione applicata dal livello Dense è la **softmax**, ideale per i task di classificazione multiclasse.
#
# La funzione **softmax**, a differenza della funzione **sigmoid** ci fornisce una distribuzione di probabilità sulle classi possibili (questa distribuzione saremo in grado di visualizzarla durante la valutazione del modello).

# %%
def get_basic_model():
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(124, 129, 1))
    x = tf.keras.layers.Resizing(120, 120)(inputs)
    x = tf.keras.layers.Normalization()(x)

    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# Nella prossima cella di codice dichiariamo l'**ottimizzatore** da utilizzare (rmsprop), le **metriche** di cui tenere traccia (accuratezza), e la funzione di perdita da utilizzare per il calcolo del gradiente. Nel nostro caso la **funzione di perdita** corrisponde alla `sparse_categorical_crossentropy`, una variante della `categorical_crossentropy`.
#
# La **sparse categorical crossentropy** viene utilizzata quando le classi sono rappresentate come interi, proprio come nel nostro caso.

# %%
basic_model = get_basic_model()
basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

basic_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 124, 129, 1)]     0
#
#  resizing (Resizing)         (None, 120, 120, 1)       0
#
#  normalization (Normalizati  (None, 120, 120, 1)       3
#  on)
#
#  conv2d (Conv2D)             (None, 118, 118, 32)      320
#
#  max_pooling2d (MaxPooling2  (None, 59, 59, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 57, 57, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 28, 28, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 26, 26, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 13, 13, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 256)       295168
#
#  max_pooling2d_3 (MaxPoolin  (None, 5, 5, 256)         0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 3, 3, 256)         590080
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 30)                69150
#
# =================================================================
# Total params: 1047073 (3.99 MB)
# Trainable params: 1047070 (3.99 MB)
# Non-trainable params: 3 (16.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Il modello ha un totale di circa **1 milione di parametri**, bilanciando complessità e capacità di apprendimento.

# %%
basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/adam/basic_model.keras", save_best_only=True, monitor="val_loss")]
basic_model_history = basic_model.fit(train_ds, epochs=30, validation_data=val_ds, callbacks=basic_model_callbacks)
# Out:
# Epoch 1/30
# 243/243 [==============================] - 9s 16ms/step - loss: 2.6931 - accuracy: 0.2392 - val_loss: 1.9301 - val_accuracy: 0.4433
# Epoch 2/30
# 243/243 [==============================] - 3s 13ms/step - loss: 1.4148 - accuracy: 0.5957 - val_loss: 1.2304 - val_accuracy: 0.6674
# Epoch 3/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.8714 - accuracy: 0.7478 - val_loss: 0.9003 - val_accuracy: 0.7454
# Epoch 4/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5703 - accuracy: 0.8322 - val_loss: 0.8742 - val_accuracy: 0.7716
# Epoch 5/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4253 - accuracy: 0.8732 - val_loss: 0.8102 - val_accuracy: 0.8063
# Epoch 6/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.3318 - accuracy: 0.8985 - val_loss: 0.8419 - val_accuracy: 0.8083
# Epoch 7/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2560 - accuracy: 0.9254 - val_loss: 0.8431 - val_accuracy: 0.8040
# Epoch 8/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2131 - accuracy: 0.9363 - val_loss: 1.1479 - val_accuracy: 0.7843
# Epoch 9/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2264 - accuracy: 0.9354 - val_loss: 0.9864 - val_accuracy: 0.8268
# Epoch 10/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1742 - accuracy: 0.9472 - val_loss: 0.9505 - val_accuracy: 0.8214
# Epoch 11/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1798 - accuracy: 0.9495 - val_loss: 1.1472 - val_accuracy: 0.8075
# Epoch 12/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1501 - accuracy: 0.9586 - val_loss: 0.9770 - val_accuracy: 0.8268
# Epoch 13/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1200 - accuracy: 0.9668 - val_loss: 1.0857 - val_accuracy: 0.8056
# Epoch 14/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1229 - accuracy: 0.9673 - val_loss: 1.1425 - val_accuracy: 0.8202
# Epoch 15/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1092 - accuracy: 0.9705 - val_loss: 0.9879 - val_accuracy: 0.8287
# Epoch 16/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1014 - accuracy: 0.9727 - val_loss: 0.9532 - val_accuracy: 0.8194
# Epoch 17/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0702 - accuracy: 0.9804 - val_loss: 1.1797 - val_accuracy: 0.8090
# Epoch 18/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0993 - accuracy: 0.9716 - val_loss: 1.1600 - val_accuracy: 0.8221
# Epoch 19/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1460 - accuracy: 0.9652 - val_loss: 1.0423 - val_accuracy: 0.7890
# Epoch 20/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1098 - accuracy: 0.9713 - val_loss: 0.9868 - val_accuracy: 0.8387
# Epoch 21/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0587 - accuracy: 0.9861 - val_loss: 1.0428 - val_accuracy: 0.8137
# Epoch 22/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0739 - accuracy: 0.9802 - val_loss: 1.0435 - val_accuracy: 0.8260
# Epoch 23/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0957 - accuracy: 0.9760 - val_loss: 1.2953 - val_accuracy: 0.8148
# Epoch 24/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0807 - accuracy: 0.9786 - val_loss: 1.4190 - val_accuracy: 0.8110
# Epoch 25/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1053 - accuracy: 0.9732 - val_loss: 1.1457 - val_accuracy: 0.8287
# Epoch 26/30
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0832 - accuracy: 0.9789 - val_loss: 1.2974 - val_accuracy: 0.8221
# Epoch 27/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0914 - accuracy: 0.9778 - val_loss: 1.0710 - val_accuracy: 0.8272
# Epoch 28/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0812 - accuracy: 0.9787 - val_loss: 1.2991 - val_accuracy: 0.8268
# Epoch 29/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0845 - accuracy: 0.9782 - val_loss: 1.2672 - val_accuracy: 0.8198
# Epoch 30/30
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0683 - accuracy: 0.9821 - val_loss: 1.0445 - val_accuracy: 0.8241

# %% [markdown]
# Alleniamo il modello per 30 epoche e visualizziamo le **curve di addestramento** e **validazione**.

# %%
def create_train_val_plot(history, overfit=True):
    # definisco numero epoche
    epochs = range(1, len(history['accuracy']) + 1)

    # Accuracy
    accuracy = history['accuracy']
    val_accuracy = history['val_accuracy']

    fig_acc, ax_acc = plt.subplots()

    # linea di base
    ax_acc.plot(epochs, [0.5 for x in range(len(epochs))], color="lightgray", linestyle="--", label="Base")
    # linee di accuratezza
    ax_acc.plot(epochs, accuracy, color="slategray", label="Accuratezza in addestramento")
    ax_acc.plot(epochs, val_accuracy, color="indianred", label="Accuratezza in validazione")
    # miglior accuratezza validazione
    ax_acc.axhline(y=max(val_accuracy), c='indianred', alpha=0.7, linestyle='--')
    ax_acc.text(len(epochs) * 1.07, max(val_accuracy), round(max(val_accuracy), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_acc.spines["right"].set_visible(False)
    ax_acc.spines["top"].set_visible(False)
    ax_acc.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_acc.set_title("Accuratezza in addestramento e validazione")
    ax_acc.set_xlabel("Epoche")
    ax_acc.set_ylabel("Accuratezza (%)")
    ax_acc.legend()

    # Loss
    loss = history['loss']
    val_loss = history['val_loss']

    fig_loss, ax_loss = plt.subplots()

    # linee di loss
    ax_loss.plot(epochs, loss, color="slategray", label="Perdita in addestramento")
    ax_loss.plot(epochs, val_loss, color="indianred", label="Perdita in validazione")
    # miglior loss validazione
    ax_loss.axhline(y=min(val_loss), c='indianred', alpha=0.7, linestyle='--')
    ax_loss.text(len(epochs) * 1.07, min(val_loss), round(min(val_loss), 2), fontsize=9, fontweight="bold", horizontalalignment="left", verticalalignment="center")
    # nascondo limiti plot
    ax_loss.spines["right"].set_visible(False)
    ax_loss.spines["top"].set_visible(False)
    ax_loss.spines["left"].set_visible(False)
    # definizione label e titolo + legenda
    ax_loss.set_title("Perdita in addestramento e validazione")
    ax_loss.set_xlabel("Epoche")
    ax_loss.set_ylabel("Perdita")

    handles, _ = ax_loss.get_legend_handles_labels()

    if overfit:
        # area overfit
        rect = mpatches.Rectangle((np.argmin(val_loss) + 1, 0), width=100 - np.argmin(val_loss), height=max(max(loss), max(val_loss)), color='lightcoral', alpha=0.3)
        ax_loss.add_patch(rect)
        # patch overfit per legenda
        overfit = mpatches.Patch(color='indianred', alpha=0.3, label='Area overfit')
        handles, _ = ax_loss.get_legend_handles_labels()
        handles.append(overfit)

    # legenda
    ax_loss.legend(handles=handles)

    plt.show()

# %%
create_train_val_plot(basic_model_history.history)

# %% [markdown]
# Questi grafici mostrano come il nostro modello sia andato immediatamente in overfitting. L'accuratezza dell'addestramento aumenta col tempo e raggiunge quasi il **100%**, mentre l'accuratezza della validazione si attesta sull'**80%** con un **picco del 86%**. Inoltre, la **perdita nel set di addestramento** continua a diminuire mentre la **perdita nel set di validazione** aumenta.

# %% [markdown]
# Possiamo verificare l'accuratezza della migliore versione del nostro modello di base ricaricando il file **basic_model.keras**.

# %%
best_basic_model = tf.keras.models.load_model("bestmodels/adam/basic_model.keras")
test_loss, test_acc = best_basic_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 8ms/step - loss: 0.8372 - accuracy: 0.7877
# Accuratezza: 0.788

# %% [markdown]
# Abbiamo ottenuto un'**accuratezza** del **82%**! La complessità di questo task è legata fortemente alla **quantità di classi** e alla **dimensione limitata del dataset**. Considerato ciò, il risultato ottenuto non è male.

# %% [markdown]
# Infine, creiamo una funzione utile a visualizzare graficamente la distribuzione di accuratezza delle classi su un'immagine casuale, per capire come ha lavorato il modello. Nel caso il modello non predica correttamente, la **classe corretta** verrà sempre evidenziata di **verde** mentre la **classe predetta** verrà evidenziata di **giallo**.

# %%
def create_distribution_plot(model, audio, label):
    prediction = model(audio) # otteniamo la predizione del modello sull'audio preso in input
    softmax_pred = tf.nn.softmax(prediction[0]) # dobbiamo applicare nuovamente la softmax in modo tale da avere dei dati leggibili
    pred_label = np.argmax(softmax_pred) # ci salviamo l'indice della label predetta dal nostro modello, quella con la probabilità più alta

    colors = ['indianred'] * len(label_names) # creiamo un vettore di lunghezza 30 (la quantità delle nostre label) colorate di rosso

    if pred_label == label[0].numpy(): # se la label che abbiamo predetto è corretta, allora la coloriamo di verde
        colors[pred_label] = 'seagreen'
    else: # se la label che abbiamo predetto è sbagliata, allora coloriamo di verde la corretta e di gialla la predetta
        colors[pred_label] = 'khaki'
        colors[label[0].numpy()] = 'seagreen'

    plt.figure(figsize=(12, 4))

    plt.bar(label_names, softmax_pred.numpy(), color=colors)
    plt.xticks(rotation=45)

    # dichiariamo i colori della legenda
    other_values_patch = mpatches.Patch(color='indianred', label='Altre classi')
    pred_value_patch = mpatches.Patch(color='khaki', label='Classe predetta')
    correct_value_patch = mpatches.Patch(color='green', label='Classe corretta')

    # disegniamo al legenda con i colori necessari
    if pred_label == label[0].numpy(): # se abbiamo predetto correttamente la label, non è necessario mostrare il colore giallo (non è presente nel plot)
        plt.legend(handles=[other_values_patch, correct_value_patch])
    else:
        plt.legend(handles=[other_values_patch, pred_value_patch, correct_value_patch])

    plt.show()

# %%
for audio, label in test_ds: # prendiamo un audio a caso del test e creiamo la distribuzione
    create_distribution_plot(best_basic_model, audio, label)
    break

# %% [markdown]
# Possiamo notare dalla distribuzione che il modello in questo caso ha predetto correttamente la **classe no**. Inoltre possiamo notare che la **classe go** ha qualche punto percentuale in più delle altre, il che ha senso essendo una parola molto simile (ergo uno spettrogramma simile).

# %% [markdown]
# L'overfitting è probabilmente fortemente causato dal fatto che il nostro dataset contiene un numero insufficente di campioni, rendendolo non in grado di generalizzare su dati nuovi. Per migliorare la capacità di generalizzare del modello andremo a creare dei dati artificali con le tecniche di data agumentation.

# %% [markdown]
# ### Risoluzione dell'overfitting
# Abbiamo capito che il modello è andato immediatamente in **overfitting**, e lo possiamo notare dalla loss di validazione che inizia a salire dalla quinta epoca in poi. L'obbiettivo principale in questo momento è evitare che vada in overfitting troppo velocemente, applicando le tecniche viste a lezione.

# %% [markdown]
# Utilizzeremo la tecnica della **data augmentation** per risolvere la grandezza ridotta del dataset, e inoltre applicheremo un **livello di Dropout** al **blocco di classificazione**.

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.1)
    # tf.keras.layers.RandomZoom(0.2) # -> non ci stava dando risultati e aumentava il tempo di training
    # tf.keras.layers.RandomTranslation(height_factor=5/124, width_factor=0)
    # tf.keras.layers.RandomTranslation(height_factor=0, width_factor=5/129)
    # questi ultimi due layer non ci stavano dando risultati e aumentava di molto il tempo di training
    # l'idea era quella di traslare le immagini di 5 pixel per la X e 5 pixel per la Y
])

# %%
def get_improved_basic_model():
    # Dichiariamo lo shape dell'input, ridimensioniamo le immagini, e normalizziamo
    inputs = tf.keras.Input(shape=(124, 129, 1))
    # x = data_augmentation(inputs)
    x = tf.keras.layers.Resizing(120, 120)(inputs)
    x = tf.keras.layers.Normalization()(x)

    # Blocco di apprendimento delle caratteristiche
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
    x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)

    # Blocco di classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
improved_basic_model = get_improved_basic_model()
improved_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
improved_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/adam/improved_basic_model.keras", save_best_only=True, monitor="val_loss")]
improved_history = improved_basic_model.fit(train_ds, epochs=100, validation_data=val_ds, callbacks=improved_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 6s 13ms/step - loss: 2.9180 - accuracy: 0.1728 - val_loss: 2.3068 - val_accuracy: 0.3569
# Epoch 2/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.8846 - accuracy: 0.4570 - val_loss: 1.3730 - val_accuracy: 0.5999
# Epoch 3/100
# 243/243 [==============================] - 3s 13ms/step - loss: 1.2323 - accuracy: 0.6363 - val_loss: 1.0471 - val_accuracy: 0.6879
# Epoch 4/100
# 243/243 [==============================] - 3s 14ms/step - loss: 0.8942 - accuracy: 0.7340 - val_loss: 0.8726 - val_accuracy: 0.7369
# Epoch 5/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.6958 - accuracy: 0.7920 - val_loss: 0.8058 - val_accuracy: 0.7770
# Epoch 6/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.5491 - accuracy: 0.8353 - val_loss: 0.7821 - val_accuracy: 0.8059
# Epoch 7/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4822 - accuracy: 0.8584 - val_loss: 0.7468 - val_accuracy: 0.8117
# Epoch 8/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.4113 - accuracy: 0.8758 - val_loss: 0.7317 - val_accuracy: 0.8233
# Epoch 9/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.3425 - accuracy: 0.8923 - val_loss: 0.7166 - val_accuracy: 0.8167
# Epoch 10/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.3069 - accuracy: 0.9064 - val_loss: 0.6973 - val_accuracy: 0.8410
# Epoch 11/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.2662 - accuracy: 0.9184 - val_loss: 0.6460 - val_accuracy: 0.8364
# Epoch 12/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.2295 - accuracy: 0.9314 - val_loss: 0.6932 - val_accuracy: 0.8395
# Epoch 13/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2184 - accuracy: 0.9321 - val_loss: 0.8820 - val_accuracy: 0.8310
# Epoch 14/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.2263 - accuracy: 0.9309 - val_loss: 0.7697 - val_accuracy: 0.8353
# Epoch 15/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1969 - accuracy: 0.9415 - val_loss: 0.7106 - val_accuracy: 0.8387
# Epoch 16/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1973 - accuracy: 0.9419 - val_loss: 0.7987 - val_accuracy: 0.8356
# Epoch 17/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1792 - accuracy: 0.9419 - val_loss: 0.7192 - val_accuracy: 0.8372
# Epoch 18/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1672 - accuracy: 0.9506 - val_loss: 0.7933 - val_accuracy: 0.8453
# Epoch 19/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1593 - accuracy: 0.9561 - val_loss: 0.6497 - val_accuracy: 0.8511
# Epoch 20/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1597 - accuracy: 0.9531 - val_loss: 0.7617 - val_accuracy: 0.8457
# Epoch 21/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1533 - accuracy: 0.9543 - val_loss: 0.7410 - val_accuracy: 0.8383
# Epoch 22/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1154 - accuracy: 0.9674 - val_loss: 0.8287 - val_accuracy: 0.8561
# Epoch 23/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1312 - accuracy: 0.9633 - val_loss: 0.6678 - val_accuracy: 0.8573
# Epoch 24/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1283 - accuracy: 0.9619 - val_loss: 0.8105 - val_accuracy: 0.8549
# Epoch 25/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1094 - accuracy: 0.9682 - val_loss: 0.8138 - val_accuracy: 0.8515
# Epoch 26/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1217 - accuracy: 0.9647 - val_loss: 0.8822 - val_accuracy: 0.8557
# Epoch 27/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1348 - accuracy: 0.9620 - val_loss: 0.6750 - val_accuracy: 0.8638
# Epoch 28/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1349 - accuracy: 0.9635 - val_loss: 0.7952 - val_accuracy: 0.8534
# Epoch 29/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1185 - accuracy: 0.9670 - val_loss: 0.7876 - val_accuracy: 0.8534
# Epoch 30/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0931 - accuracy: 0.9719 - val_loss: 0.7551 - val_accuracy: 0.8611
# Epoch 31/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0968 - accuracy: 0.9724 - val_loss: 0.9752 - val_accuracy: 0.8403
# Epoch 32/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1004 - accuracy: 0.9729 - val_loss: 0.8308 - val_accuracy: 0.8553
# Epoch 33/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0940 - accuracy: 0.9735 - val_loss: 0.8493 - val_accuracy: 0.8611
# Epoch 34/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.1003 - accuracy: 0.9736 - val_loss: 1.0261 - val_accuracy: 0.8480
# Epoch 35/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0911 - accuracy: 0.9738 - val_loss: 0.8416 - val_accuracy: 0.8681
# Epoch 36/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1038 - accuracy: 0.9716 - val_loss: 0.9791 - val_accuracy: 0.8461
# Epoch 37/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1175 - accuracy: 0.9689 - val_loss: 0.8719 - val_accuracy: 0.8600
# Epoch 38/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0740 - accuracy: 0.9804 - val_loss: 0.9184 - val_accuracy: 0.8592
# Epoch 39/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0900 - accuracy: 0.9746 - val_loss: 0.9328 - val_accuracy: 0.8472
# Epoch 40/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0954 - accuracy: 0.9765 - val_loss: 0.8463 - val_accuracy: 0.8465
# Epoch 41/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1072 - accuracy: 0.9706 - val_loss: 0.7729 - val_accuracy: 0.8638
# Epoch 42/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0842 - accuracy: 0.9759 - val_loss: 0.9608 - val_accuracy: 0.8522
# Epoch 43/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0669 - accuracy: 0.9820 - val_loss: 0.9073 - val_accuracy: 0.8511
# Epoch 44/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1032 - accuracy: 0.9727 - val_loss: 0.9303 - val_accuracy: 0.8492
# Epoch 45/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0659 - accuracy: 0.9816 - val_loss: 0.9285 - val_accuracy: 0.8596
# Epoch 46/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0832 - accuracy: 0.9776 - val_loss: 0.9547 - val_accuracy: 0.8580
# Epoch 47/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0782 - accuracy: 0.9793 - val_loss: 0.8326 - val_accuracy: 0.8576
# Epoch 48/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0779 - accuracy: 0.9769 - val_loss: 0.9817 - val_accuracy: 0.8549
# Epoch 49/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0638 - accuracy: 0.9821 - val_loss: 0.8944 - val_accuracy: 0.8723
# Epoch 50/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.1074 - accuracy: 0.9735 - val_loss: 1.0412 - val_accuracy: 0.8461
# Epoch 51/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0833 - accuracy: 0.9787 - val_loss: 0.8507 - val_accuracy: 0.8596
# Epoch 52/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0780 - accuracy: 0.9789 - val_loss: 0.8514 - val_accuracy: 0.8657
# Epoch 53/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0533 - accuracy: 0.9835 - val_loss: 0.9373 - val_accuracy: 0.8634
# Epoch 54/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0537 - accuracy: 0.9840 - val_loss: 0.8375 - val_accuracy: 0.8634
# Epoch 55/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0727 - accuracy: 0.9829 - val_loss: 0.9184 - val_accuracy: 0.8484
# Epoch 56/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0778 - accuracy: 0.9787 - val_loss: 0.8998 - val_accuracy: 0.8611
# Epoch 57/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0544 - accuracy: 0.9832 - val_loss: 0.9791 - val_accuracy: 0.8615
# Epoch 58/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0847 - accuracy: 0.9769 - val_loss: 0.9206 - val_accuracy: 0.8522
# Epoch 59/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0729 - accuracy: 0.9793 - val_loss: 0.9017 - val_accuracy: 0.8669
# Epoch 60/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0684 - accuracy: 0.9820 - val_loss: 0.9589 - val_accuracy: 0.8715
# Epoch 61/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0675 - accuracy: 0.9816 - val_loss: 0.8870 - val_accuracy: 0.8723
# Epoch 62/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0609 - accuracy: 0.9830 - val_loss: 0.9615 - val_accuracy: 0.8569
# Epoch 63/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0636 - accuracy: 0.9826 - val_loss: 0.9272 - val_accuracy: 0.8738
# Epoch 64/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0633 - accuracy: 0.9822 - val_loss: 0.9618 - val_accuracy: 0.8596
# Epoch 65/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0828 - accuracy: 0.9795 - val_loss: 0.8893 - val_accuracy: 0.8758
# Epoch 66/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0552 - accuracy: 0.9851 - val_loss: 0.9802 - val_accuracy: 0.8673
# Epoch 67/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0795 - accuracy: 0.9790 - val_loss: 0.8306 - val_accuracy: 0.8696
# Epoch 68/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0810 - accuracy: 0.9808 - val_loss: 0.7692 - val_accuracy: 0.8789
# Epoch 69/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0487 - accuracy: 0.9853 - val_loss: 0.9111 - val_accuracy: 0.8715
# Epoch 70/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0576 - accuracy: 0.9848 - val_loss: 0.9499 - val_accuracy: 0.8719
# Epoch 71/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0479 - accuracy: 0.9863 - val_loss: 1.0708 - val_accuracy: 0.8580
# Epoch 72/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0740 - accuracy: 0.9811 - val_loss: 0.9078 - val_accuracy: 0.8665
# Epoch 73/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0535 - accuracy: 0.9852 - val_loss: 0.9394 - val_accuracy: 0.8762
# Epoch 74/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0683 - accuracy: 0.9835 - val_loss: 1.1743 - val_accuracy: 0.8607
# Epoch 75/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0728 - accuracy: 0.9838 - val_loss: 1.1855 - val_accuracy: 0.8569
# Epoch 76/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0838 - accuracy: 0.9809 - val_loss: 0.9242 - val_accuracy: 0.8727
# Epoch 77/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0747 - accuracy: 0.9830 - val_loss: 1.1724 - val_accuracy: 0.8526
# Epoch 78/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0617 - accuracy: 0.9839 - val_loss: 1.0265 - val_accuracy: 0.8681
# Epoch 79/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0696 - accuracy: 0.9825 - val_loss: 1.0159 - val_accuracy: 0.8754
# Epoch 80/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0492 - accuracy: 0.9854 - val_loss: 1.0042 - val_accuracy: 0.8769
# Epoch 81/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0511 - accuracy: 0.9852 - val_loss: 0.9855 - val_accuracy: 0.8777
# Epoch 82/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0770 - accuracy: 0.9805 - val_loss: 0.9200 - val_accuracy: 0.8688
# Epoch 83/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0417 - accuracy: 0.9880 - val_loss: 1.0461 - val_accuracy: 0.8723
# Epoch 84/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0400 - accuracy: 0.9893 - val_loss: 1.2062 - val_accuracy: 0.8711
# Epoch 85/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0586 - accuracy: 0.9867 - val_loss: 1.0658 - val_accuracy: 0.8719
# Epoch 86/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0630 - accuracy: 0.9852 - val_loss: 1.0640 - val_accuracy: 0.8754
# Epoch 87/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0491 - accuracy: 0.9862 - val_loss: 1.0107 - val_accuracy: 0.8765
# Epoch 88/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0530 - accuracy: 0.9863 - val_loss: 1.1940 - val_accuracy: 0.8627
# Epoch 89/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0486 - accuracy: 0.9871 - val_loss: 1.0873 - val_accuracy: 0.8781
# Epoch 90/100
# 243/243 [==============================] - 3s 13ms/step - loss: 0.0437 - accuracy: 0.9881 - val_loss: 1.4446 - val_accuracy: 0.8503
# Epoch 91/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0805 - accuracy: 0.9813 - val_loss: 1.1091 - val_accuracy: 0.8669
# Epoch 92/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0668 - accuracy: 0.9839 - val_loss: 1.1633 - val_accuracy: 0.8684
# Epoch 93/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0528 - accuracy: 0.9851 - val_loss: 1.0744 - val_accuracy: 0.8758
# Epoch 94/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0536 - accuracy: 0.9861 - val_loss: 0.9514 - val_accuracy: 0.8792
# Epoch 95/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0294 - accuracy: 0.9916 - val_loss: 0.9836 - val_accuracy: 0.8808
# Epoch 96/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0396 - accuracy: 0.9897 - val_loss: 1.1752 - val_accuracy: 0.8661
# Epoch 97/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0489 - accuracy: 0.9867 - val_loss: 1.0947 - val_accuracy: 0.8711
# Epoch 98/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0769 - accuracy: 0.9823 - val_loss: 1.0660 - val_accuracy: 0.8727
# Epoch 99/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0828 - accuracy: 0.9822 - val_loss: 1.1879 - val_accuracy: 0.8638
# Epoch 100/100
# 243/243 [==============================] - 3s 12ms/step - loss: 0.0732 - accuracy: 0.9829 - val_loss: 1.2852 - val_accuracy: 0.8654

# %%
create_train_val_plot(improved_history.history)

# %% [markdown]
# Alleniamo il modello per 100 epoche (dobbiamo dargli più tempo per apprendere, 30 epoche non sarebbero bastate) e visualizziamo le **curve di addestramento** e **validazione**.
#
# L'obbiettivo di ridurre **l'overfitting è stato comunque raggiunto**, dato che il modello ha iniziato ad andare in overfitting verso **l'epoca 30**.

# %%
improved_best_model = tf.keras.models.load_model("bestmodels/adam/improved_basic_model.keras")
test_loss, test_acc = improved_best_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 7ms/step - loss: 0.6523 - accuracy: 0.8346
# Accuratezza: 0.835

# %% [markdown]
# In questo caso non abbiamo ottenuto alcun tipo di miglioramento a livello di prestazioni, anzi è peggiorato!

# %%
for audio, label in test_ds:
    create_distribution_plot(improved_best_model, audio, label)
    break

# %% [markdown]
# In questo caso il modello era molto più indeciso di prima. Il modello aveva intuito potesse essere un audio con **classe no** ma era convinto fosse invece la **classe go**.

# %% [markdown]
# ## Miglioramenti all'architettura del modello
#
# Durante il corso abbiamo visto anche delle best practice architetturali che possono aiutare a ottenere maggiori prestazioni col modello. Il nostro scopo è provare le tecniche viste e studiate durante il corso e capire come reagiscono al task.

# %% [markdown]
# Le tre tecniche che andremo ad applicare sono:
# - blocchi residuali
# - normalizzazione dei batch
# - convoluzioni separabili

# %% [markdown]
# ### Blocchi residuali
# I blocchi residuali sono un'applicazione efficace quando riscontriamo il problema dei **gradienti che svaniscono**. Non sono una tecnica strettamente legata ai modelli convolutivi, ma sono una best practice generale che viene applicare nella maggior parte delle architetture.
#
# I **gradienti che vaniscono** sono causati dalle **catene di funzioni troppo lunghe**, che nel nostro caso non sono altro che **una sequenza di livelli convolutivi**. Per ogni livello convolutivo **una certa quantità di rumore** viene introdotta, finché essa non arriva a **sopraffare** le informazioni sul gradiente.
#
# Se le informazioni sul gradiente sono sopraffatte la **backpropagation smette di funzionare**, e quindi il nostro **modello non impara**.

# %% [markdown]
# L'**idea basilare** dietro ai blocchi residuali è quella di **salvare l'informazione** contenuta nell'input precedente al livello convolutivo, e **sommarla all'output** dello stesso livello convolutivo.

# %% [markdown]
# Per applicare i blocchi residuali abbiamo implementato la funzione `residual_block(x, filters, pooling=False)` vista a lezione. La funzione è ovviamente adattata al modello da noi implementato, e utilizza le altre due best practice citate precedentemente.

# %%
def residual_block(x, filters, pooling=False):
    residual = x

    x = tf.keras.layers.SeparableConv2D(filters, 3, padding="same", use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    if pooling:
      x = tf.keras.layers.MaxPooling2D(pool_size=2, padding="same")(x)
      residual = tf.keras.layers.Conv2D(filters, 1, strides=2)(residual)
    elif filters != residual.shape[-1]:
      residual = tf.keras.layers.Conv2D(filters, 1)(residual)

    x = tf.keras.layers.add([x, residual])
    return x

# %% [markdown]
# ### Normalizzazione dei batch e convoluzioni separabili
# La **normalizzazione dei batch** è un concetto che abbiamo già affrontato nel notebook, infatti il suo scopo rimane quello di rendere i dati **più simili tra loro** centrandoli sullo zero, e ciò aiuta la **propagazione del gradiente**. Questa normalizzazione, a differenza della precedente, è in grado di normalizzare i dati in modo adattivo anche quando la media e la varianza cambiano durante l'addestramento.

# %% [markdown]
# Le **convoluzione separabili** invece sono un **sostituto** ai livelli convolutivi utilizzati fino ad adesso, e offrono un modello con maggiori prestazioni e meno parametri.

# %%
def bp_basic_model():
    # input e pre processamento
    inputs = tf.keras.Input(shape=(124, 129, 1))
    # x = data_augmentation(inputs)
    x = tf.keras.layers.Resizing(120, 120)(inputs)

    x = residual_block(x, 32, pooling=True)
    x = residual_block(x, 64, pooling=True)
    x = residual_block(x, 128, pooling=True)
    x = residual_block(x, 256, pooling=True)
    x = residual_block(x, 256, pooling=False)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Livelli per la classificazione
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(30, activation="softmax")(x)

    # Modello
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
bp_basic_model = bp_basic_model()
bp_basic_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

bp_basic_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 124, 129, 1)]        0         []
#
#  resizing_2 (Resizing)       (None, 120, 120, 1)          0         ['input_3[0][0]']
#
#  separable_conv2d (Separabl  (None, 120, 120, 32)         41        ['resizing_2[0][0]']
#  eConv2D)
#
#  batch_normalization (Batch  (None, 120, 120, 32)         128       ['separable_conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 120, 120, 32)         0         ['batch_normalization[0][0]']
#
#  max_pooling2d_8 (MaxPoolin  (None, 60, 60, 32)           0         ['activation[0][0]']
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 60, 60, 32)           64        ['resizing_2[0][0]']
#
#  add (Add)                   (None, 60, 60, 32)           0         ['max_pooling2d_8[0][0]',
#                                                                      'conv2d_10[0][0]']
#
#  separable_conv2d_1 (Separa  (None, 60, 60, 64)           2336      ['add[0][0]']
#  bleConv2D)
#
#  batch_normalization_1 (Bat  (None, 60, 60, 64)           256       ['separable_conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 60, 60, 64)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d_9 (MaxPoolin  (None, 30, 30, 64)           0         ['activation_1[0][0]']
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 30, 30, 64)           2112      ['add[0][0]']
#
#  add_1 (Add)                 (None, 30, 30, 64)           0         ['max_pooling2d_9[0][0]',
#                                                                      'conv2d_11[0][0]']
#
#  separable_conv2d_2 (Separa  (None, 30, 30, 128)          8768      ['add_1[0][0]']
#  bleConv2D)
#
#  batch_normalization_2 (Bat  (None, 30, 30, 128)          512       ['separable_conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 30, 30, 128)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d_10 (MaxPooli  (None, 15, 15, 128)          0         ['activation_2[0][0]']
#  ng2D)
#
#  conv2d_12 (Conv2D)          (None, 15, 15, 128)          8320      ['add_1[0][0]']
#
#  add_2 (Add)                 (None, 15, 15, 128)          0         ['max_pooling2d_10[0][0]',
#                                                                      'conv2d_12[0][0]']
#
#  separable_conv2d_3 (Separa  (None, 15, 15, 256)          33920     ['add_2[0][0]']
#  bleConv2D)
#
#  batch_normalization_3 (Bat  (None, 15, 15, 256)          1024      ['separable_conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 15, 15, 256)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling2d_11 (MaxPooli  (None, 8, 8, 256)            0         ['activation_3[0][0]']
#  ng2D)
#
#  conv2d_13 (Conv2D)          (None, 8, 8, 256)            33024     ['add_2[0][0]']
#
#  add_3 (Add)                 (None, 8, 8, 256)            0         ['max_pooling2d_11[0][0]',
#                                                                      'conv2d_13[0][0]']
#
#  separable_conv2d_4 (Separa  (None, 8, 8, 256)            67840     ['add_3[0][0]']
#  bleConv2D)
#
#  batch_normalization_4 (Bat  (None, 8, 8, 256)            1024      ['separable_conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 8, 8, 256)            0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  add_4 (Add)                 (None, 8, 8, 256)            0         ['activation_4[0][0]',
#                                                                      'add_3[0][0]']
#
#  global_average_pooling2d (  (None, 256)                  0         ['add_4[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 256)                  0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense_2 (Dense)             (None, 30)                   7710      ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 167079 (652.65 KB)
# Trainable params: 165607 (646.90 KB)
# Non-trainable params: 1472 (5.75 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# Le best practice, insieme al `tf.keras.layers.GlobalAveragePooling2D()` applicato al posto del Flatten, hanno formato un modello con circa **160000 parametri addestrabili** (circa il 16% del modello precedente).

# %%
bp_basic_model_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath="bestmodels/adam/bp_basic_model.keras", save_best_only=True, monitor="val_loss")]
bp_model_history = bp_basic_model.fit(train_ds, epochs=100, validation_data=val_ds, callbacks=bp_basic_model_callbacks)
# Out:
# Epoch 1/100
# 243/243 [==============================] - 12s 23ms/step - loss: 3.1909 - accuracy: 0.1282 - val_loss: 3.3535 - val_accuracy: 0.0594
# Epoch 2/100
# 243/243 [==============================] - 4s 18ms/step - loss: 2.5897 - accuracy: 0.2763 - val_loss: 2.8159 - val_accuracy: 0.2049
# Epoch 3/100
# 243/243 [==============================] - 4s 18ms/step - loss: 2.0361 - accuracy: 0.4483 - val_loss: 1.7282 - val_accuracy: 0.5617
# Epoch 4/100
# 243/243 [==============================] - 4s 18ms/step - loss: 1.5456 - accuracy: 0.5803 - val_loss: 1.5322 - val_accuracy: 0.5575
# Epoch 5/100
# 243/243 [==============================] - 4s 18ms/step - loss: 1.2207 - accuracy: 0.6765 - val_loss: 1.1094 - val_accuracy: 0.6968
# Epoch 6/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.9949 - accuracy: 0.7385 - val_loss: 0.9834 - val_accuracy: 0.7353
# Epoch 7/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.8000 - accuracy: 0.7875 - val_loss: 0.9390 - val_accuracy: 0.7365
# Epoch 8/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.6956 - accuracy: 0.8156 - val_loss: 0.9003 - val_accuracy: 0.7438
# Epoch 9/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.6176 - accuracy: 0.8294 - val_loss: 0.8598 - val_accuracy: 0.7512
# Epoch 10/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.5547 - accuracy: 0.8482 - val_loss: 0.7122 - val_accuracy: 0.7971
# Epoch 11/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.4921 - accuracy: 0.8643 - val_loss: 0.6985 - val_accuracy: 0.8029
# Epoch 12/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.4557 - accuracy: 0.8787 - val_loss: 0.6199 - val_accuracy: 0.8206
# Epoch 13/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.4105 - accuracy: 0.8892 - val_loss: 0.6036 - val_accuracy: 0.8318
# Epoch 14/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.4047 - accuracy: 0.8893 - val_loss: 0.7018 - val_accuracy: 0.8144
# Epoch 15/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.3545 - accuracy: 0.9019 - val_loss: 0.6242 - val_accuracy: 0.8248
# Epoch 16/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.3323 - accuracy: 0.9081 - val_loss: 0.7864 - val_accuracy: 0.7955
# Epoch 17/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.3134 - accuracy: 0.9113 - val_loss: 1.1858 - val_accuracy: 0.7334
# Epoch 18/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.3056 - accuracy: 0.9173 - val_loss: 0.5352 - val_accuracy: 0.8472
# Epoch 19/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.2777 - accuracy: 0.9231 - val_loss: 0.4870 - val_accuracy: 0.8700
# Epoch 20/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.2668 - accuracy: 0.9271 - val_loss: 0.7185 - val_accuracy: 0.7990
# Epoch 21/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.2705 - accuracy: 0.9220 - val_loss: 0.9274 - val_accuracy: 0.7697
# Epoch 22/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.2801 - accuracy: 0.9231 - val_loss: 0.4747 - val_accuracy: 0.8630
# Epoch 23/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.2341 - accuracy: 0.9329 - val_loss: 0.9634 - val_accuracy: 0.7631
# Epoch 24/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.2237 - accuracy: 0.9375 - val_loss: 0.7438 - val_accuracy: 0.8198
# Epoch 25/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.2046 - accuracy: 0.9427 - val_loss: 0.5399 - val_accuracy: 0.8584
# Epoch 26/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.2026 - accuracy: 0.9407 - val_loss: 0.6618 - val_accuracy: 0.8191
# Epoch 27/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1973 - accuracy: 0.9466 - val_loss: 0.5227 - val_accuracy: 0.8638
# Epoch 28/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1980 - accuracy: 0.9442 - val_loss: 0.5480 - val_accuracy: 0.8561
# Epoch 29/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1944 - accuracy: 0.9451 - val_loss: 0.6754 - val_accuracy: 0.8306
# Epoch 30/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.2105 - accuracy: 0.9423 - val_loss: 0.5650 - val_accuracy: 0.8607
# Epoch 31/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1696 - accuracy: 0.9554 - val_loss: 0.5296 - val_accuracy: 0.8561
# Epoch 32/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1724 - accuracy: 0.9509 - val_loss: 0.6091 - val_accuracy: 0.8642
# Epoch 33/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1741 - accuracy: 0.9519 - val_loss: 0.6592 - val_accuracy: 0.8252
# Epoch 34/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1872 - accuracy: 0.9457 - val_loss: 0.6719 - val_accuracy: 0.8314
# Epoch 35/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1500 - accuracy: 0.9563 - val_loss: 0.5275 - val_accuracy: 0.8584
# Epoch 36/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1654 - accuracy: 0.9540 - val_loss: 1.1671 - val_accuracy: 0.7596
# Epoch 37/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1612 - accuracy: 0.9570 - val_loss: 0.6104 - val_accuracy: 0.8407
# Epoch 38/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1544 - accuracy: 0.9536 - val_loss: 0.6504 - val_accuracy: 0.8430
# Epoch 39/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1633 - accuracy: 0.9546 - val_loss: 0.5082 - val_accuracy: 0.8738
# Epoch 40/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1319 - accuracy: 0.9613 - val_loss: 0.6745 - val_accuracy: 0.8410
# Epoch 41/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1332 - accuracy: 0.9615 - val_loss: 0.6020 - val_accuracy: 0.8573
# Epoch 42/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1526 - accuracy: 0.9595 - val_loss: 0.6771 - val_accuracy: 0.8337
# Epoch 43/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1638 - accuracy: 0.9540 - val_loss: 0.5106 - val_accuracy: 0.8738
# Epoch 44/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1500 - accuracy: 0.9591 - val_loss: 0.6979 - val_accuracy: 0.8414
# Epoch 45/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1486 - accuracy: 0.9576 - val_loss: 0.4616 - val_accuracy: 0.8785
# Epoch 46/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1009 - accuracy: 0.9744 - val_loss: 0.4846 - val_accuracy: 0.8808
# Epoch 47/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1080 - accuracy: 0.9719 - val_loss: 0.7281 - val_accuracy: 0.8364
# Epoch 48/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1431 - accuracy: 0.9599 - val_loss: 0.4930 - val_accuracy: 0.8719
# Epoch 49/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1453 - accuracy: 0.9601 - val_loss: 0.4826 - val_accuracy: 0.8831
# Epoch 50/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1344 - accuracy: 0.9629 - val_loss: 0.6698 - val_accuracy: 0.8306
# Epoch 51/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1130 - accuracy: 0.9674 - val_loss: 0.8116 - val_accuracy: 0.8260
# Epoch 52/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1168 - accuracy: 0.9671 - val_loss: 0.4694 - val_accuracy: 0.8835
# Epoch 53/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1212 - accuracy: 0.9665 - val_loss: 0.7118 - val_accuracy: 0.8306
# Epoch 54/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1364 - accuracy: 0.9608 - val_loss: 0.6184 - val_accuracy: 0.8569
# Epoch 55/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1298 - accuracy: 0.9640 - val_loss: 0.5924 - val_accuracy: 0.8661
# Epoch 56/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1027 - accuracy: 0.9720 - val_loss: 0.4652 - val_accuracy: 0.8777
# Epoch 57/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0945 - accuracy: 0.9740 - val_loss: 0.4187 - val_accuracy: 0.9001
# Epoch 58/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1235 - accuracy: 0.9661 - val_loss: 0.8324 - val_accuracy: 0.8248
# Epoch 59/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1094 - accuracy: 0.9716 - val_loss: 0.6329 - val_accuracy: 0.8488
# Epoch 60/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0861 - accuracy: 0.9764 - val_loss: 0.4765 - val_accuracy: 0.8804
# Epoch 61/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0860 - accuracy: 0.9759 - val_loss: 0.4798 - val_accuracy: 0.8904
# Epoch 62/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1098 - accuracy: 0.9679 - val_loss: 0.6197 - val_accuracy: 0.8573
# Epoch 63/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1363 - accuracy: 0.9603 - val_loss: 0.6879 - val_accuracy: 0.8511
# Epoch 64/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1205 - accuracy: 0.9653 - val_loss: 0.6020 - val_accuracy: 0.8530
# Epoch 65/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1126 - accuracy: 0.9679 - val_loss: 0.6838 - val_accuracy: 0.8615
# Epoch 66/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0964 - accuracy: 0.9720 - val_loss: 0.5399 - val_accuracy: 0.8738
# Epoch 67/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0897 - accuracy: 0.9746 - val_loss: 0.6477 - val_accuracy: 0.8592
# Epoch 68/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0893 - accuracy: 0.9764 - val_loss: 0.5119 - val_accuracy: 0.8758
# Epoch 69/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0812 - accuracy: 0.9785 - val_loss: 0.6040 - val_accuracy: 0.8623
# Epoch 70/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1217 - accuracy: 0.9673 - val_loss: 0.4862 - val_accuracy: 0.8854
# Epoch 71/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1117 - accuracy: 0.9673 - val_loss: 0.5499 - val_accuracy: 0.8630
# Epoch 72/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0865 - accuracy: 0.9777 - val_loss: 0.4621 - val_accuracy: 0.8897
# Epoch 73/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0708 - accuracy: 0.9820 - val_loss: 0.4986 - val_accuracy: 0.8866
# Epoch 74/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0899 - accuracy: 0.9756 - val_loss: 0.6551 - val_accuracy: 0.8654
# Epoch 75/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0975 - accuracy: 0.9718 - val_loss: 0.5546 - val_accuracy: 0.8804
# Epoch 76/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0935 - accuracy: 0.9726 - val_loss: 0.4978 - val_accuracy: 0.8796
# Epoch 77/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1003 - accuracy: 0.9718 - val_loss: 0.4932 - val_accuracy: 0.8893
# Epoch 78/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0949 - accuracy: 0.9753 - val_loss: 0.6087 - val_accuracy: 0.8603
# Epoch 79/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0916 - accuracy: 0.9751 - val_loss: 0.9836 - val_accuracy: 0.8156
# Epoch 80/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0871 - accuracy: 0.9760 - val_loss: 0.5082 - val_accuracy: 0.8827
# Epoch 81/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0748 - accuracy: 0.9791 - val_loss: 0.5753 - val_accuracy: 0.8704
# Epoch 82/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0660 - accuracy: 0.9831 - val_loss: 0.4131 - val_accuracy: 0.9074
# Epoch 83/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0744 - accuracy: 0.9800 - val_loss: 0.7433 - val_accuracy: 0.8480
# Epoch 84/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.1126 - accuracy: 0.9677 - val_loss: 0.5680 - val_accuracy: 0.8708
# Epoch 85/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0997 - accuracy: 0.9714 - val_loss: 0.6182 - val_accuracy: 0.8700
# Epoch 86/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0722 - accuracy: 0.9808 - val_loss: 0.5628 - val_accuracy: 0.8846
# Epoch 87/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0596 - accuracy: 0.9844 - val_loss: 0.5100 - val_accuracy: 0.8866
# Epoch 88/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0880 - accuracy: 0.9751 - val_loss: 1.1277 - val_accuracy: 0.7774
# Epoch 89/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0851 - accuracy: 0.9755 - val_loss: 0.5482 - val_accuracy: 0.8843
# Epoch 90/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.1084 - accuracy: 0.9700 - val_loss: 0.5009 - val_accuracy: 0.8796
# Epoch 91/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0726 - accuracy: 0.9799 - val_loss: 0.4956 - val_accuracy: 0.8885
# Epoch 92/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0632 - accuracy: 0.9813 - val_loss: 1.1450 - val_accuracy: 0.8071
# Epoch 93/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0802 - accuracy: 0.9789 - val_loss: 0.5761 - val_accuracy: 0.8735
# Epoch 94/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0962 - accuracy: 0.9723 - val_loss: 0.4770 - val_accuracy: 0.8846
# Epoch 95/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0983 - accuracy: 0.9729 - val_loss: 0.6764 - val_accuracy: 0.8765
# Epoch 96/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0723 - accuracy: 0.9796 - val_loss: 0.5841 - val_accuracy: 0.8673
# Epoch 97/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0661 - accuracy: 0.9831 - val_loss: 0.4662 - val_accuracy: 0.8916
# Epoch 98/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0590 - accuracy: 0.9845 - val_loss: 0.4701 - val_accuracy: 0.8885
# Epoch 99/100
# 243/243 [==============================] - 4s 18ms/step - loss: 0.0786 - accuracy: 0.9787 - val_loss: 0.4629 - val_accuracy: 0.8962
# Epoch 100/100
# 243/243 [==============================] - 4s 17ms/step - loss: 0.0784 - accuracy: 0.9791 - val_loss: 0.6202 - val_accuracy: 0.8684

# %%
create_train_val_plot(bp_model_history.history, overfit=False)

# %% [markdown]
# Possiamo notare che il modello **NON ha raggiunto l'overfitting**, infatti probabilmente 100 epoche di addestramento erano troppo poche. La **loss della validazione** stava continuando a scendere, e allo stesso tempo **l'accuratezza della validazione era crescente**.

# %%
best_bp_basic_model = tf.keras.models.load_model("bestmodels/adam/bp_basic_model.keras")
test_loss, test_acc = best_bp_basic_model.evaluate(test_ds)
print(f"Accuratezza: {test_acc:.3f}")
# Out:
# 81/81 [==============================] - 1s 8ms/step - loss: 0.4275 - accuracy: 0.9031
# Accuratezza: 0.903

# %% [markdown]
# Non abbiamo ottenuto miglioramenti a livello di prestazioni rispetto al primo modello presentato, però ci siamo avvicinati molto con il **16% dei parametri**

# %%
for audio, label in test_ds:
    create_distribution_plot(best_bp_basic_model, audio, label)
    break

# %% [markdown]
# La decisione del modello in questo caso è nuovamente molto chiara.
